# %%
# %matplotlib nbagg
import sys
import matplotlib.pyplot as plt
import qcodes as qc
import numpy as np
#import instrument
import qcodes.instrument_drivers.rohde_schwarz.ZNB as ZNB

from qcodes.dataset.measurements import Measurement
from qcodes.dataset.plotting import plot_by_id, load_by_id
from qcodes import new_experiment, Station, Instrument
from qcodes.dataset.data_export import get_data_by_id

# %% [markdown]
# # initialize database

# %%
#initialize database
import datetime
dataset_name = 'ABS_W1_5_1_1'
qc.config["core"]["db_location"] = datetime.date.today().strftime(r'D:\OneDrive\BF3\Data\%Y%m%d_'+dataset_name+'.db')
# automatically uses a different DB file for each month
qc.dataset.database.initialise_database()
qc.config.core.db_location
# Out:
# Upgrading database: : 0it [00:00, ?it/s]
# 'D:\\OneDrive\\BF3\\Data\\20190509_ABS_W1_5_1_1.db'

# %%
station = qc.Station()

# %%
exp = qc.new_experiment("VNA analysis", sample_name="lines")

# %% [markdown]
# # Bluefors fridge log tunnel

# %% [markdown]
# ## Bluefors log opening

# %%
#set the path here of the shared desktop file
BF_PC_PATH = '\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\' 

import time

# %%
import csv
class BF_Logfile():
    def __init__(self, logfile_path):
        #initiate the path here
        self.logfile_path = logfile_path
    
    def make_timestamp(days_in_the_past = 0):
        """
        by default makes today
        """
        return datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
    
    def open_file(logfile_name, timestamp=None):
        
        if timestamp is None:
            timestamp = self.make_timestamp()
     
        ds = '%02d-%02d-%02d'%(timestamp.year-2000, timestamp.month, timestamp.day) 
        pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'
        
        file_list = []
        with open(pth) as csvFile:
            reader = csv.reader(csvFile)
            for row in reader:
                #print(row)
                file_list.append(row)
        csvFile.close()

# %%
logfile_name = 'CH5 T'
days_in_the_past = 1
ts = datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day) 
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'

T = np.loadtxt(pth, usecols = (2), delimiter = ',')
plt.figure()
plt.plot(T)
plt.title(ds + ' ' + pth)

logfile_name = 'CH9 T'
ts = datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day) 
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'

T = np.loadtxt(pth, usecols = (2), delimiter = ',')
plt.figure()
plt.plot(T)
plt.title(pth)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\19-05-21\\CH9 T 19-05-21.log')

# %%
import csv
BF_PC_PATH = '\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\' 

#code to get the timestamp copied here from the thermometer class

logfile_name = 'maxigauge'
days_in_the_past = 0
ts = datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day) 
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'

file_list = []
with open(pth) as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        #print(row)
        file_list.append(row)
csvFile.close()

#
print(file_list[0])
times = [file_list[i][1] for i in range(len(file_list))]
Ps = []
for k in range(0,6):
    Ps.append(np.array([float(file_list[i][5+k*6]) for i in range(len(file_list))]))

i_start = 0
i_stop = -1
for k in range(len(Ps)):
    plt.figure()
    plt.plot(times[i_start:i_stop], Ps[k][i_start:i_stop])
    plt.ylabel('Pressure (mBar)')
    plt.xlabel('Timestamp')
    plt.title('P%d at ' % (k+1) + ds )
# Out:
# ['22-05-19', '00:00:58', 'CH1', 'P1  ', '1', ' 3.22E-6', '0', '1', 'CH2', 'P2  ', '1', ' 8.61E-3', '0', '1', 'CH3', 'P3  ', '1', ' 3.66E+2', '0', '1', 'CH4', 'P4  ', '1', ' 9.50E+1', '0', '1', 'CH5', 'P5  ', '1', ' 1.15E+0', '0', '1', 'CH6', 'P6', '1', ' 1.86E-1', '0', '1', '']
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
ts = datetime.datetime.today()
ds = '19-04-18'
logfile_name = 'CH9 T'
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'

time.sleep(0.1)
try:
    T = np.loadtxt(pth, usecols = (2), delimiter = ',')
except: # in the first few seconds of a day, a new log file hasn't been created
    ts = datetime.datetime.today() - datetime.timedelta(days=1) # use the last entry in the previous day
    ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
    pth = self.logfile_path + ds + '\\CH9 T '+ds+'.log'
    T = np.loadtxt(pth, usecols = (2), delimiter = ',')[-1]
print(T)

plt.plot(T)

# %% [markdown]
# ## Thermometer using BF logs

# %%
#set the path here of the shared desktop file
from pytopo.sweep import sweep, measure, nest, chain, szip, getter, setter, time_trace, do_experiment
from pytopo.qctools.instruments import create_inst

class Thermometer(Instrument):
    
    def __init__(self, name, logfile_path, **kw):
        super().__init__(name, **kw)        
        self.add_parameter('temperature', get_cmd=self._get_temperature, set_cmd=None, unit='K')
        
        self.add_parameter('counter', get_cmd=self._counter, set_cmd=None, unit='')
        self._ind = 0
        print('Path of network drive(set this manually dear USER): ', logfile_path)
        self.logfile_path = logfile_path
        
    def _counter(self):
        self._ind += 1
        return self._ind
    def _get_temperature(self):
        ts = datetime.datetime.today()
        ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
        pth = self.logfile_path + ds + '\\CH9 T '+ds+'.log'
        time.sleep(0.1)
        try:
            T = np.loadtxt(pth, usecols = (2), delimiter = ',')[-1]
        except: # in the first few seconds of a day, a new log file hasn't been created
            ts = datetime.datetime.today() - datetime.timedelta(days=1) # use the last entry in the previous day
            ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
            pth = self.logfile_path + ds + '\\CH9 T '+ds+'.log'
            T = np.loadtxt(pth, usecols = (2), delimiter = ',')[-1]
        return T
    
        
    
T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
T_probe.temperature()
# Out:
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# 0.023621099999999999

# %%
BF_PC_PATH = '\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\'
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
pth = BF_PC_PATH+ ds + '\\CH9 T '+ds+'.log'

# %%
vna.add_channel('S12')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-aa722393dae2> in <module>()
# ----> 1 vna.add_channel('S12')
#
# NameError: name 'vna' is not defined

# %% [markdown]
# # VNA measurements of lines.
# https://github.com/QCoDeS/Qcodes/blob/master/docs/examples/driver_examples/Qcodes%20example%20with%20Rohde%20Schwarz%20ZNB.ipynb

# %%
vna = create_inst(ZNB.ZNB, "VNA", 'USB0::0x0AAD::0x01A1::101879::INSTR', force_new_instance=True, init_s_params=False)
#station.remove_component(vna)
station.add_component(vna)
# the channel we want to measure. we set init_s_params false to not have to measure all channels, thus saving time 
channel_name = 'S12' ##Now we add a channel S12: Since the HEMT is connected to port 1. 
vna.add_channel(channel_name)
# Out:
# Connected to: Rohde-Schwarz ZNB20-2Port (serial:1311601062101879, firmware:2.86) in 0.71s

# %%
vna.rf_off()

# %%
vna = create_inst(ZNB.ZNB, "VNA", 'USB0::0x0AAD::0x01A1::101879::INSTR', force_new_instance=True)
# Out:
# Instrument VNA already exists.
# Connected to: Rohde-Schwarz ZNB20-2Port (serial:1311601062101879, firmware:2.86) in 0.23s

# %%
vna.rf_off()
station = qc.Station(vna)

# %% [markdown]
# To use the VNA we likely want to turn on RF Power, which is off by default for safty in this driver. The driver default to low power but for safety lets set it to -50 dBm. The rf can be turned on and off globally and the power adjusted individually for each channel

# %%
vna.channels.autoscale()
vna.channels.power(-40)

# %%
#vna.channels.power(-50)
#vna.rf_off()
vna.channels.autoscale()

# %%
station = qc.Station(vna)

# %%
import time
import numpy as np
def do_single_sweep(n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, power=-60, n_avg=10, channel_name='S12'):

    # let's set the trace properties. 
    trace = getattr(vna.channels, channel_name)
    trace.avg(n_avg)
    trace.npts(n_pts)
    trace.power(power)
    trace.start(f_start)
    trace.stop(f_stop)
    vna.rf_on()
    
    
    #now setup the qcodes measurement object
    meas = Measurement()
    #meas.register_parameter(temperature, setpoints=['time',])
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('time', unit='s', paramtype='numeric')
    meas.register_custom_parameter('power', unit='dBm', setpoints=['time'])
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                    setpoints=['frequency'],
                                   paramtype='array'),
    meas.register_custom_parameter('magnitude_raw', unit='V', 
                                   setpoints=['frequency'],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=[ 'frequency'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        fvals = np.linspace(trace.start(), trace.stop(), trace.npts())
        mag, phase = trace.trace_mag_phase()
        mag_db = 20*np.log10(mag) #convert to dB
        result = [ ('time', time.time()),
           # (temperature, temperature()),
           # (temperature_sample, temperature_sample()),
            ('frequency', fvals),
            ('magnitude_raw', mag),
            ('magnitude_dB',mag_db ),
            ('phase', phase),
            ('power', power)]
        datasaver.add_result(
            *result
           )
    return datasaver.run_id


def do_single_sweep_with_temperature(n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, power=-60, n_avg=10, channel_name='S12'):

    """
    Saves a timestamp and a temperature. 
    """
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    trace = getattr(vna.channels, channel_name)
    trace.avg(n_avg)
    trace.npts(n_pts)
    trace.power(power)
    trace.start(f_start)
    trace.stop(f_stop)
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    #meas.register_parameter(temperature, setpoints=['time',])
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('time', unit='s', paramtype='numeric')
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric', setpoints=['time'])
    meas.register_custom_parameter('power', unit='dBm', setpoints=['time'])
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                    setpoints=['frequency'],
                                   paramtype='array'),
    meas.register_custom_parameter('magnitude_raw', unit='V', 
                                   setpoints=['frequency'],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=[ 'frequency'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        fvals = np.linspace(trace.start(), trace.stop(), trace.npts())
        mag, phase = trace.trace_mag_phase()
        mag_db = 20*np.log10(mag) #convert to dB
        result = [ ('time', time.time()),
           # (temperature, temperature()),
           # (temperature_sample, temperature_sample()),
            ('frequency', fvals),
            ('magnitude_raw', mag),
            ('magnitude_dB',mag_db ),
            ('phase', phase),
            ('power', power),
            ('temperature', temperature)]
        datasaver.add_result(
            *result
           )
    return datasaver.run_id

# %%
power_levels = list(range(5,15,5))
res_freqs = [3.535e9, 4.020e9, 4.847e9, 5.889e9]
df = 0.1e9

for power in power_levels:   
    for freq in res_freqs:
        print(freq-df)
        print(freq+df)
        print(power)
        run_id = do_single_sweep_with_temperature(n_pts = 30000, f_start = freq-df, f_stop = freq+df,
                                                  power=power, n_avg=30, channel_name=channel_name)

# %%
run_id = do_single_sweep_with_temperature(n_pts = 10000, f_start = 3e9, f_stop = 7e9,
                                                  power=-33, n_avg=5, channel_name=channel_name)

# %%
aves, bla = plot_by_id(run_id)

# %%
aves, bla = plot_by_id(16)

# %%
vna.rf_off()

# %%
meas = Measurement()
vna.channels.S12.format('dB')
meas.register_parameter(vna.channels.S12.trace)
with meas.run() as datasaver:
    get_v = vna.channels.S12.trace.get()
    datasaver.add_result((vna.channels.S12.trace, get_v))
ax, cbax = plot_by_id(datasaver.run_id)

# %% [markdown]
# ## 2 D sweeps: power

# %%
def do_2d_power_sweep(powers=[],n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
. 
    """
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    channel = getattr(vna.channels, channel_name)
    
    channel.avg(n_avg)
    channel.npts(n_pts)
    channel.start(f_start)
    channel.stop(f_stop)
    channel.power(powers[0])
    channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency','power'],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', 'power'],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', 'power'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        for power in powers:
            channel.power(power)
            fvals = np.linspace(channel.start(), channel.stop(), channel.npts())
            S12 = channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('power', power),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id

# %%
np.arange(-30,16, 1)

# %%
res_freqs = [3.535e9, 4.020e9, 4.847e9, 5.889e9]
df = 0.02e9
  
for freq in res_freqs:
    print(freq-df)
    print(freq+df)
    run_id_1 = do_2d_power_sweep(powers=np.arange(-20,15, 5),n_pts = 2000, f_start = freq-df, f_stop = freq+df, n_avg=500, channel_name='S12')
vna.rf_off()
# Out:
# 3515000000.0
# 3555000000.0
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 52
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -20
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -15
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -10
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 0
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 10
# 4000000000.0
# 4040000000.0
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 53
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -20
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -15
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -10
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 0
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 10
# 4827000000.0
# 4867000000.0
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 54
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -20
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -15
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -10
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 0
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 10
# 5869000000.0
# 5909000000.0
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 55
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -20
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -15
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -10
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 0
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 5
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power 10

# %%
data = load_by_id(23)
freqs = np.squeeze(np.array(data.get_data('frequency')))
powers = np.squeeze(np.array(data.get_data('power')))
mag = np.squeeze(np.array(data.get_data('magnitude_dB')))
plt.figure()
plt.plot(freqs.T,mag.T, 'x')

# %%
vna.rf_off()

# %%
do_2d_power_sweep(powers=np.arange(-40,0, 5),n_pts = 30000, f_start = 2.9e9, f_stop = 12e9, n_avg=50, channel_name='S12')
# Out:
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 51
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -40
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -35
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -30
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -25
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -20
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -15
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -10
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -5
# 51

# %% [markdown]
# ## Temperature sweep

# %%
def do_2d_T_sweep(T_max = 20, power = -20,n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
. 
    """

    # let's set the trace properties. 
    channel = getattr(vna.channels, channel_name)
    
    channel.avg(n_avg)
    channel.npts(n_pts)
    channel.start(f_start)
    channel.stop(f_stop)
    channel.power(power)
    channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency','temperature'],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', 'temperature'],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', 'temperature'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
      #first try to get temperature:
        T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
        temperature = T_probe.temperature()
        while temperature <  T_max:
            T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
            temperature = T_probe.temperature()
            
            fvals = np.linspace(channel.start(), channel.stop(), channel.npts())
            S12 = channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('power', power),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done T=%.3f' % temperature)
    return datasaver.run_id

# %%
do_2d_T_sweep(power=20,T_max=20, n_pts = 5000, f_start = 2.5e9, f_stop = 10e9, n_avg=5, channel_name='S12')
# Out:
# Starting experimental run with id: 92
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.005
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.003
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.028
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.013
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.016
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.041
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.034
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.054
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.079
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.089
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.106
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.108
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.111
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.113
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.113
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.144
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.151
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.150
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.153
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.152
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.150
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.180
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.191
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.196
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.216
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.202
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.200
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.227
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.225
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.232
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.237
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.247
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.253
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.289
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.289
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.285
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.296
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.304
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.287
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.298
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.311
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.329
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.329
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.316
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.317
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.327
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.324
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.310
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.309
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.302
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.296
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.278
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.262
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.249
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.226
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.215
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.205
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.199
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.198
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.159
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.117
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.088
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.083
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.048
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.027
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=12.020
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.980
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.932
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.914
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.873
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.836
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.799
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.770
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.733
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.707
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.686
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.655
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.601
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.583
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.564
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.525
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.451
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.416
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.389
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.349
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.320
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.290
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.244
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.221
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.186
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.164
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.119
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.084
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.033
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=11.010
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.964
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.942
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.912
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.889
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.799
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.790
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.759
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.715
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.699
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.669
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.593
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.576
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.556
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.524
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.478
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.450
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.393
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.385
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.353
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.331
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.286
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.266
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.217
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.197
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.181
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.134
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.097
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.083
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.036
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=10.005
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.960
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.946
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.925
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.903
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.842
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.807
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.797
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.775
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.760
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.745
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.687
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.647
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.618
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.617
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.584
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.563
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.538
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.493
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.462
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.437
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.429
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.413
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.385
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.347
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.330
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.303
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=9.271
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# ...
# done T=3.882
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.881
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.884
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.886
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.890
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.893
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.886
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.884
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.888
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.886
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.880
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.878
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.882
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.885
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.882
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.884
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.883
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.883
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.885
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.880
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.876
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.878
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.875
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.879
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.880
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.877
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.877
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.880
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.881
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.882
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.878
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.877
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.875
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.874
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.876
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.882
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.881
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.877
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done T=3.878
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-159-67e2d02f5436> in <module>()
# ----> 1 do_2d_T_sweep(power=20,T_max=20, n_pts = 5000, f_start = 2.5e9, f_stop = 10e9, n_avg=5, channel_name='S12')
#
# <ipython-input-145-4070cbcb97c5> in do_2d_T_sweep(T_max, power, n_pts, f_start, f_stop, n_avg, channel_name)
#      42
#      43             fvals = np.linspace(channel.start(), channel.stop(), channel.npts())
# ---> 44             S12 = channel.trace.get()
#      45             mag_db = 20*np.log10(np.abs(S12)) #convert to dB
#      46             result = [
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in get_raw(self)
#      84
#      85     def get_raw(self):
# ---> 86         data = self._instrument._get_sweep_data()
#      87         if self._instrument.format() in ['Polar', 'Complex',
#      88                                          'Smith', 'Inverse Smith']:
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in _get_sweep_data(self, force_polar)
#     348             # need to ensure averaged result is returned
#     349             for avgcount in range(self.avg()):
# --> 350                 self.write('INIT{}:IMM; *WAI'.format(self._instrument_channel))
#     351             data_str = self.ask(
#     352                 'CALC{}:DATA? {}'.format(self._instrument_channel,
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\channel.py in write(self, cmd)
#      60     # Pass any commands to read or write from the instrument up to the parent
#      61     def write(self, cmd):
# ---> 62         return self._parent.write(cmd)
#      63
#      64     def write_raw(self, cmd):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in write(self, cmd)
#     697         """
#     698         try:
# --> 699             self.write_raw(cmd)
#     700         except Exception as e:
#     701             inst = repr(self)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\visa.py in write_raw(self, cmd)
#     213         self.visa_log.debug(f"Writing: {cmd}")
#     214
# --> 215         nr_bytes_written, ret_code = self.visa_handle.write(cmd)
#     216         self.check_error(ret_code)
#     217
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write(self, message, termination, encoding)
#     221             message += term
#     222
# --> 223         count = self.write_raw(message.encode(enco))
#     224
#     225         return count
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write_raw(self, message)
#     199         :rtype: int
#     200         """
# --> 201         return self.visalib.write(self.session, message)
#     202
#     203     def write(self, message, termination=None, encoding=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\functions.py in write(library, session, data)
#    1864     return_count = ViUInt32()
#    1865     # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 1866     ret = library.viWrite(session, data, len(data), byref(return_count))
#    1867     return return_count.value, ret
#    1868
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     147             setattr(self, method_name, getattr(self.lib, method_name))
#     148
# --> 149     def _return_handler(self, ret_value, func, arguments):
#     150         """Check return values for errors and warnings.
#     151         """
#
# KeyboardInterrupt:

# %% [markdown]
# # MDac

# %%
mdac.restart

# %%
sys.path.append(r"D:\OneDrive\BF3\Code");
sys.path.append(r"D:\OneDrive\BF3\Code\labtools-master")
sys.path.append(r"D:\OneDrive\BF3\Code\StationQ\MDAC\Driver")
from MDAC import MDAC
from pytopo.sweep import sweep, measure, nest, chain, szip, getter, setter, time_trace, do_experiment
from pytopo.qctools.instruments import create_inst


mdac = MDAC('MDAC', 'ASRL4::INSTR', debug=False, logging=False)

station.add_component(mdac)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\functions.py:1649: VisaIOWarning: VI_WARN_NSUP_ATTR_STATE (1073676420): Although the specified state of the attribute is valid, it is not supported by this implementation.
#   return library.viSetAttribute(session, attribute, attribute_state)
# Connected to: QNL Sydney MDAC (serial:0x32353532353551040028003E, firmware:1.4) in 2.62s
# 'MDAC'

# %%
station.add_component(mdac)

# %% [markdown]
# ### Keysight DMM

# %%
from qcodes.instrument_drivers.Keysight.Keysight_34465A import Keysight_34465A
key1 = create_inst(Keysight_34465A, "key1", "USB0::0x2A8D::0x0301::MY57505052::INSTR", force_new_instance=True)

station.add_component(key1)
# Out:
# Connected to: Keysight Technologies 34465A (serial:MY57505052, firmware:A.02.16-02.40-02.16-00.51-03-01) in 0.39s
# 'key1'

# %%
key2 = create_inst(Keysight_34465A, "key2", "USB0::0x2A8D::0x0301::MY57505146::INSTR", force_new_instance=True)

station.add_component(key2)
# Out:
# Connected to: Keysight Technologies 34465A (serial:MY57505146, firmware:A.02.16-02.40-02.16-00.51-03-01) in 0.34s
# 'key2'

# %%
key3 = create_inst(Keysight_34465A, "key3", "USB0::0x2A8D::0x0101::MY57505157::INSTR", force_new_instance=True)

station.add_component(key3)
# Out:
# Connected to: Keysight Technologies 34465A (serial:MY57505157, firmware:A.02.16-02.40-02.16-00.51-03-01) in 0.29s
# 'key3'

# %% [markdown]
# ## MDAC helper functions

# %%
def initialize(*channels):
    for s in channels:
        ramp(s.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
    #     ramp(g.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        s.smc('close')
        s.dac_output('close')
    #     d.gnd('close')
    #     g.dac_output('close')
    #     g.smc('close')
    
def initialize_leakage(channels_to_close, channels_to_open):
    for s in channels_to_close:
        ramp(s.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        s.smc('close')
        s.dac_output('close')
    for s in channels_to_open:
        ramp(s.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        s.smc('open')
        s.dac_output('open')
        
        
gate_ramp_stepsize = 1e-3  #[V] previously was 1e-3
gate_ramp_delay = 0.01  #[s]

def ramp(param, target, step_size, delay): 
    current_value = param()
    step_size *= np.sign(target - current_value)
    if abs(step_size) < 1E-10: 
        return 
    
    steps = np.arange(current_value, target, step_size)
    for step in steps: 
        param(step)
        time.sleep(delay)
    
    param(target)
    
def set_mdac_in_safemode(nchan=64):
    #ivvi.dac1(0)
    #ivvi.dac3(0)
    #lockin1.amplitude(0)
    #lockin1.sine_outdc(0)
    
    print('setting mdac in safe mode')
    
    for ch in mdac.channels[:nchan]:
        ramp(ch.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

    # Note: we do this in separate loops because we want to be sure that
    # no currents are running anywhere before switching the relays
    for ch in mdac.channels[:nchan]:
        ch.dac_output('open')
        ch.bus('open')
        ch.gnd('open')
        ch.smc('open')
        ch.microd('open')
        #ch.divider('off')
    print('Done')

def chs_safe(*channels):
    lockin1.amplitude(0)
    lockin1.sine_outdc(0)   
    print('setting mdac in safe mode')
    for ch in channels:
        ramp(ch.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        ch.dac_output('open')
        ch.bus('open')
        ch.gnd('open')
        ch.smc('open')
        ch.microd('open')
    print('Done')
    
    
    
### added function by jaap

def print_voltage_current(channel):
    voltage = channel.voltage()
    gain = 1e6
    key_raw1 = key1.volt()
    current_dc1 = -key_raw1/gain
    print('raw v key 1' ,key_raw1)
    print('current_dc1', current_dc1)
    print('voltage: ', voltage)

# %% [markdown]
# ### MDAC channel definition

# %%
MDAC_channels = {
    'V_bot_A' : mdac.ch18,
    'V_cut_A' : mdac.ch01,
    'V_pl_A' : mdac.ch17,
    'V_pl_B' : mdac.ch25,
    'V_bot_B' : mdac.ch01, #note that this is doubly bonded. 
    'V_pr_B' : mdac.ch26,
    'V_pr_C' : mdac.ch25,
    'V_cut_C' : mdac.ch09,
    
    
}

# %% [markdown]
# ## MDAC gate testing

# %%
set_mdac_in_safemode()
# Out:
# setting mdac in safe mode
# Done

# %%
mdac.ch01.voltage()
# Out:
# 2.014996

# %%
mdac.ch49.voltage()
gain = 1e6
key_raw1 = key1.volt()
current_dc1 = -key_raw1/gain
print('raw v key 1' ,key_raw1)
print('current_dc1', current_dc1)

# %%
print('ch V', mdac.ch49.voltage())
initialize(mdac.ch49)
gain = 1e6
key_raw1 = key1.volt()
current_dc1 = -key_raw1/gain
print('raw v key 1' ,key_raw1)
print('current_dc1', current_dc1)

# %%
mdac.ch09.voltage()

# %%
mdac.ch49.voltage(1e-3)
print('ch V', mdac.ch49.voltage())
key_raw1 = key1.volt()
current_dc1 = -key_raw1/gain
print('raw v key 1' ,key_raw1)
print('current_dc1', current_dc1)

# %%
#initialize(mdac.ch09) 
ramp(mdac.ch09.voltage, 0.0, gate_ramp_stepsize, gate_ramp_delay)

# %%
initialize(mdac.ch26) # Vpr B
initialize(mdac.ch01) # V(Vbot B, VC A)
initialize(mdac.ch17) # (Vpl A) 
initialize(mdac.ch18) # (V_bot A)
initialize(mdac.ch25) # 1. V_pr C 1. V_pr C
initialize(mdac.ch09)
initialize(mdac.ch03)
#initialize(mdac.ch24)

# %% [markdown]
# ## 2D gate frequency sweeps

# %%
def do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name='V_g',
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
   
    """
    #check the gate voltage
    print("Starting voltage", gate_channel.voltage())
    
    
    
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    vna_channel = getattr(vna.channels, channel_name)
    
    vna_channel.avg(n_avg)
    vna_channel.npts(n_pts)
    vna_channel.start(f_start)
    vna_channel.stop(f_stop)
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter(gate_name, unit='V'),
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency',gate_name],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['frequency', gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='V', 
                                   setpoints=['frequency', gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', gate_name],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            #ramp the gate voltage
            print("Ramping %s to %.2e" % (gate_name, gate_voltage))
            ramp(gate_channel.voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
            print("Done ramping")
            fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
            S12 = vna_channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('phase', np.angle(S12)),
                ('mag', np.abs(S12)),
                ('power', power),
                (gate_name, gate_voltage),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id




def do_multiple_gate_resonator_sweep(
                            gate_channel, gate_voltages,gate_name='V_g',
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
   
    """
    if not isinstance(gate_channel, list):
        gate_channel = [gate_channel] #allow for multple gates to be swept at once. 
        if not isinstance(gate_name, list):
            gate_name = [gate_name]
        else:
            raise Exception('Either give both gate channel and gate name as a list or both as a value..')
    
    #check the gate voltage
    for chan in gate_channel:
        print(chan,chan.voltage())
    
    #set the gate name to be all gates together
    long_gate_name = ''
    for name in gate_name:
        long_gate_name += name + '_' #make one variable out of multiple gates snce they are swept together
    
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    vna_channel = getattr(vna.channels, channel_name)
    
    vna_channel.avg(n_avg)
    vna_channel.npts(n_pts)
    vna_channel.start(f_start)
    vna_channel.stop(f_stop)
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter(long_gate_name, unit='V'),
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency',long_gate_name],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', long_gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['frequency', long_gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='V', 
                                   setpoints=['frequency', long_gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', long_gate_name],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            #ramp the gate voltage
            for i in range(len(gate_channel)):
                print("Ramping %s to %.2e" % (gate_name[i], gate_voltage))
                ramp(gate_channel[i].voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
                print("Done ramping")
            fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
            S12 = vna_channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('phase', np.angle(S12)),
                ('mag', np.abs(S12)),
                ('power', power),
                (long_gate_name, gate_voltage),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id

# %%
gate_channel = mdac.ch09
gate_voltages = np.linspace(-2,2,21)
gate_name = 'V_cutter_C'

run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-20, n_pts = 30000, f_start = 4.01e9, f_stop = 4.03e9, n_avg=100, channel_name='S12')

# %%
plot_by_id(run_id)

# %%
data = load_by_id(run_id)
freqs = np.squeeze(np.array(data.get_data('frequency')))
powers = np.squeeze(np.array(data.get_data('power')))
mag = np.squeeze(np.array(data.get_data('magnitude_dB')))
re_s21 = np.squeeze(np.array(data.get_data('Re_S'))) 
im_s21 = np.squeeze(np.array(data.get_data('Im_S'))) 
s21 = re_s21 + 1j*im_s21
phase_s21 = np.angle(s21)
amp_s21 = np.abs(s21)
plt.figure()
i_min = 0
i_max = -1
plt.plot(freqs[:,i_min:i_max].T,mag[:,i_min:i_max].T)
plt.figure()
plt.plot(freqs[:,i_min:i_max].T,phase_s21[:,i_min:i_max].T)
plt.figure()
plt.plot(freqs[:,i_min:i_max].T,amp_s21[:,i_min:i_max].T)

# %%
plt.figure()
plt.imshow(freqs,mag_dB)

# %% [markdown]
# #### Vbot B, Vcutter A

# %%
gate_channel = mdac.ch01
gate_voltages = np.linspace(-2,2,101)
gate_name = 'V_bot_B_Cut_A'

run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 100, f_start = 4.844e9, f_stop = 4.853e9, n_avg=40, channel_name='S12')

run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 100, f_start = 5.88e9, f_stop = 5.90e9, n_avg=40, channel_name='S12')

# %% [markdown]
# #### V bot A + Vcutter A

# %%
gate_channel = mdac.ch01
gate_voltages = np.linspace(1,2,51)
gate_name = 'V_cut_A'


df = 0.004e9
Vbots = [-4]
#resonator A
for vBot in Vbots:
    ramp(mdac.ch18.voltage, vBot, gate_ramp_stepsize,gate_ramp_delay)
    f0 = 4.847e9
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-30, n_pts = 300, f_start = f0-df, f_stop = f0+df, n_avg=1000, channel_name='S12')

# %% [markdown]
# #### More Vbot A + VCutter A

# %%
gate_channel = mdac.ch01
gate_voltages = np.linspace(-3,3,201)
gate_name = 'V_cut_A'


df = 0.005e9
Vbots = [-3]
#resonator A
for vBot in Vbots:
    ramp(mdac.ch18.voltage, vBot, gate_ramp_stepsize,gate_ramp_delay)
    f0 = 4.847e9
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 600, f_start = f0-df, f_stop = f0+df, n_avg=100, channel_name='S12')

# %%
gate_channel = mdac.ch18
gate_voltages = np.linspace(-3,3,151)
gate_name = 'V_bot_B_Cut_A'


f0s = [5.89e9]
df = 0.01e9
#resonator A
for f0 in f0s:
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 400, f_start = f0-df, f_stop = f0+df, n_avg=100, channel_name='S12')

# %% [markdown]
# #### Vpr C V pl B

# %%
gate_channel = mdac.ch25
gate_voltages = np.linspace(-3,3,151)
gate_name = 'V_Pr_C_V_pl_B'


f0s = [4.02e9, 4.847e9, 5.89e9]
df = 0.004e9
#resonator A
for f0 in f0s:
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 400, f_start = f0-df, f_stop = f0+df, n_avg=100, channel_name='S12')

# %% [markdown]
# #### V plunger right B

# %%
initialize(mdac.ch26)

# %%
gate_channel = mdac.ch26
gate_voltages = np.linspace(-3,3,151)
gate_name = 'V_Pr_C_V_pl_B'


f0s = [3.535e9, 4.02e9, 4.847e9, 5.89e9]
df = 0.005e9
#resonator A
for f0 in f0s:
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 400, f_start = f0-df, f_stop = f0+df, n_avg=100, channel_name='S12')

# %% [markdown]
# #### Vcutter C

# %%
initialize(mdac.ch09)
initialize(mdac)

# %%
gate_channel = mdac.ch09
gate_voltages = np.linspace(-3.0,3.0,151)
gate_name = 'V_cutter_C'


f0s = [5.89e9, 3.535e9, 4.02e9, 4.847e9]
df = 0.005e9
#resonator A
for f0 in f0s:
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 1200, f_start = f0-df, f_stop = f0+df, n_avg=100, channel_name='S12')

# %%
ramp(mdac.ch17.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
#initialize(mdac.ch17)

# %%
gate_channel = mdac.ch17
gate_voltages = np.linspace(-3,3,151)
gate_name = 'V_Pl_A'


f0s = [3.535e9, 4.02e9, 4.847e9, 5.89e9]
df = 0.004e9
#resonator A
for f0 in f0s:
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 300, f_start = f0-df, f_stop = f0+df, n_avg=100, channel_name='S12')

# %%
ramp(mdac.ch18.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %% [markdown]
# ### Multiple gates at the same time frequency sweep

# %%
power = -30
n_pts = 1000
n_avg = 300
f = 4.84725e9
df = 3e6

#set the Bfield. 
set_yoko_field(0)

exp = qc.new_experiment("Multi-gate-freq sweep B=%.4e npts=%d n_avg=%d power=%d" %(get_yoko_field(),n_pts, n_avg,power)  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False

gate_channel = [MDAC_channels['V_cut_A'], MDAC_channels['V_bot_A'], MDAC_channels['V_pl_A']]
#gate_channel = [MDAC_channels['V_bot_B'], MDAC_channels['V_pr_B'], MDAC_channels['V_pl_B']]
gate_voltages = np.arange(3,3.2,0.005)
gate_name = ['V_cut_A', 'V_bot_A', 'V_pl_A']
#gate_name = ['V_bot_B', 'V_pr_B', 'V_pl_B']
if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_name:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

t0 = time.time()
#now do the real thing
do_multiple_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-33, n_pts = 500, f_start = f-df, f_stop = f+df, n_avg=n_avg, channel_name='S12')

print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# <MDACChannel: MDAC_chan1 of MDAC: MDAC> 2.014996
# <MDACChannel: MDAC_chan18 of MDAC: MDAC> 2.014997
# <MDACChannel: MDAC_chan17 of MDAC: MDAC> 2.014999
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 1
# Ramping V_cut_A to 2.00e+00
# Done ramping
# Ramping V_bot_A to 2.00e+00
# Done ramping
# Ramping V_pl_A to 2.00e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.00e+00
# Done ramping
# Ramping V_bot_A to 2.00e+00
# Done ramping
# Ramping V_pl_A to 2.00e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.01e+00
# Done ramping
# Ramping V_bot_A to 2.01e+00
# Done ramping
# Ramping V_pl_A to 2.01e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.01e+00
# Done ramping
# Ramping V_bot_A to 2.01e+00
# Done ramping
# Ramping V_pl_A to 2.01e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.02e+00
# Done ramping
# Ramping V_bot_A to 2.02e+00
# Done ramping
# Ramping V_pl_A to 2.02e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.02e+00
# Done ramping
# Ramping V_bot_A to 2.02e+00
# Done ramping
# Ramping V_pl_A to 2.02e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.03e+00
# Done ramping
# Ramping V_bot_A to 2.03e+00
# Done ramping
# Ramping V_pl_A to 2.03e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.03e+00
# Done ramping
# Ramping V_bot_A to 2.03e+00
# Done ramping
# Ramping V_pl_A to 2.03e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.04e+00
# Done ramping
# Ramping V_bot_A to 2.04e+00
# Done ramping
# Ramping V_pl_A to 2.04e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.04e+00
# Done ramping
# Ramping V_bot_A to 2.04e+00
# Done ramping
# Ramping V_pl_A to 2.04e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.05e+00
# Done ramping
# Ramping V_bot_A to 2.05e+00
# Done ramping
# Ramping V_pl_A to 2.05e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.05e+00
# Done ramping
# Ramping V_bot_A to 2.05e+00
# Done ramping
# Ramping V_pl_A to 2.05e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.06e+00
# Done ramping
# Ramping V_bot_A to 2.06e+00
# Done ramping
# Ramping V_pl_A to 2.06e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.06e+00
# Done ramping
# Ramping V_bot_A to 2.06e+00
# Done ramping
# Ramping V_pl_A to 2.06e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.07e+00
# Done ramping
# Ramping V_bot_A to 2.07e+00
# Done ramping
# Ramping V_pl_A to 2.07e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.07e+00
# Done ramping
# Ramping V_bot_A to 2.07e+00
# Done ramping
# Ramping V_pl_A to 2.07e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.08e+00
# Done ramping
# Ramping V_bot_A to 2.08e+00
# Done ramping
# Ramping V_pl_A to 2.08e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.08e+00
# Done ramping
# Ramping V_bot_A to 2.08e+00
# Done ramping
# Ramping V_pl_A to 2.08e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.09e+00
# Done ramping
# Ramping V_bot_A to 2.09e+00
# Done ramping
# Ramping V_pl_A to 2.09e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.09e+00
# Done ramping
# Ramping V_bot_A to 2.09e+00
# Done ramping
# Ramping V_pl_A to 2.09e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.10e+00
# Done ramping
# Ramping V_bot_A to 2.10e+00
# Done ramping
# Ramping V_pl_A to 2.10e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.10e+00
# Done ramping
# Ramping V_bot_A to 2.10e+00
# Done ramping
# Ramping V_pl_A to 2.10e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.11e+00
# Done ramping
# Ramping V_bot_A to 2.11e+00
# Done ramping
# Ramping V_pl_A to 2.11e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.11e+00
# Done ramping
# Ramping V_bot_A to 2.11e+00
# Done ramping
# Ramping V_pl_A to 2.11e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.12e+00
# Done ramping
# Ramping V_bot_A to 2.12e+00
# Done ramping
# Ramping V_pl_A to 2.12e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.12e+00
# Done ramping
# Ramping V_bot_A to 2.12e+00
# Done ramping
# Ramping V_pl_A to 2.12e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.13e+00
# Done ramping
# Ramping V_bot_A to 2.13e+00
# Done ramping
# Ramping V_pl_A to 2.13e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.13e+00
# Done ramping
# Ramping V_bot_A to 2.13e+00
# Done ramping
# Ramping V_pl_A to 2.13e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.14e+00
# Done ramping
# Ramping V_bot_A to 2.14e+00
# Done ramping
# Ramping V_pl_A to 2.14e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.14e+00
# Done ramping
# Ramping V_bot_A to 2.14e+00
# Done ramping
# Ramping V_pl_A to 2.14e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.15e+00
# Done ramping
# Ramping V_bot_A to 2.15e+00
# Done ramping
# Ramping V_pl_A to 2.15e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.15e+00
# Done ramping
# Ramping V_bot_A to 2.15e+00
# Done ramping
# Ramping V_pl_A to 2.15e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.16e+00
# Done ramping
# Ramping V_bot_A to 2.16e+00
# Done ramping
# Ramping V_pl_A to 2.16e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.16e+00
# Done ramping
# Ramping V_bot_A to 2.16e+00
# Done ramping
# Ramping V_pl_A to 2.16e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.17e+00
# Done ramping
# Ramping V_bot_A to 2.17e+00
# Done ramping
# Ramping V_pl_A to 2.17e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.17e+00
# Done ramping
# Ramping V_bot_A to 2.17e+00
# Done ramping
# Ramping V_pl_A to 2.17e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.18e+00
# Done ramping
# Ramping V_bot_A to 2.18e+00
# Done ramping
# Ramping V_pl_A to 2.18e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.18e+00
# Done ramping
# Ramping V_bot_A to 2.18e+00
# Done ramping
# Ramping V_pl_A to 2.18e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.19e+00
# Done ramping
# Ramping V_bot_A to 2.19e+00
# Done ramping
# Ramping V_pl_A to 2.19e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.19e+00
# Done ramping
# Ramping V_bot_A to 2.19e+00
# Done ramping
# Ramping V_pl_A to 2.19e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.20e+00
# Done ramping
# Ramping V_bot_A to 2.20e+00
# Done ramping
# Ramping V_pl_A to 2.20e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.20e+00
# Done ramping
# Ramping V_bot_A to 2.20e+00
# Done ramping
# Ramping V_pl_A to 2.20e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.21e+00
# Done ramping
# Ramping V_bot_A to 2.21e+00
# Done ramping
# Ramping V_pl_A to 2.21e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.21e+00
# Done ramping
# Ramping V_bot_A to 2.21e+00
# Done ramping
# Ramping V_pl_A to 2.21e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.22e+00
# Done ramping
# Ramping V_bot_A to 2.22e+00
# Done ramping
# Ramping V_pl_A to 2.22e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.22e+00
# Done ramping
# Ramping V_bot_A to 2.22e+00
# Done ramping
# Ramping V_pl_A to 2.22e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.23e+00
# Done ramping
# Ramping V_bot_A to 2.23e+00
# Done ramping
# Ramping V_pl_A to 2.23e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.23e+00
# Done ramping
# Ramping V_bot_A to 2.23e+00
# Done ramping
# Ramping V_pl_A to 2.23e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.24e+00
# Done ramping
# Ramping V_bot_A to 2.24e+00
# Done ramping
# Ramping V_pl_A to 2.24e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.24e+00
# Done ramping
# Ramping V_bot_A to 2.24e+00
# Done ramping
# Ramping V_pl_A to 2.24e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.25e+00
# Done ramping
# Ramping V_bot_A to 2.25e+00
# Done ramping
# Ramping V_pl_A to 2.25e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.25e+00
# Done ramping
# Ramping V_bot_A to 2.25e+00
# Done ramping
# Ramping V_pl_A to 2.25e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.26e+00
# Done ramping
# Ramping V_bot_A to 2.26e+00
# Done ramping
# Ramping V_pl_A to 2.26e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.26e+00
# Done ramping
# Ramping V_bot_A to 2.26e+00
# Done ramping
# Ramping V_pl_A to 2.26e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.27e+00
# Done ramping
# Ramping V_bot_A to 2.27e+00
# Done ramping
# Ramping V_pl_A to 2.27e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.27e+00
# Done ramping
# Ramping V_bot_A to 2.27e+00
# Done ramping
# Ramping V_pl_A to 2.27e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.28e+00
# Done ramping
# Ramping V_bot_A to 2.28e+00
# Done ramping
# Ramping V_pl_A to 2.28e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.28e+00
# Done ramping
# Ramping V_bot_A to 2.28e+00
# Done ramping
# Ramping V_pl_A to 2.28e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.29e+00
# Done ramping
# Ramping V_bot_A to 2.29e+00
# Done ramping
# Ramping V_pl_A to 2.29e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.29e+00
# Done ramping
# Ramping V_bot_A to 2.29e+00
# Done ramping
# Ramping V_pl_A to 2.29e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.30e+00
# Done ramping
# Ramping V_bot_A to 2.30e+00
# Done ramping
# Ramping V_pl_A to 2.30e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.30e+00
# Done ramping
# Ramping V_bot_A to 2.30e+00
# Done ramping
# Ramping V_pl_A to 2.30e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.31e+00
# Done ramping
# Ramping V_bot_A to 2.31e+00
# Done ramping
# Ramping V_pl_A to 2.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.31e+00
# Done ramping
# Ramping V_bot_A to 2.31e+00
# Done ramping
# Ramping V_pl_A to 2.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.32e+00
# Done ramping
# Ramping V_bot_A to 2.32e+00
# Done ramping
# Ramping V_pl_A to 2.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.32e+00
# Done ramping
# Ramping V_bot_A to 2.32e+00
# Done ramping
# Ramping V_pl_A to 2.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.33e+00
# Done ramping
# Ramping V_bot_A to 2.33e+00
# Done ramping
# Ramping V_pl_A to 2.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.33e+00
# Done ramping
# Ramping V_bot_A to 2.33e+00
# Done ramping
# Ramping V_pl_A to 2.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.34e+00
# Done ramping
# Ramping V_bot_A to 2.34e+00
# Done ramping
# Ramping V_pl_A to 2.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.34e+00
# Done ramping
# Ramping V_bot_A to 2.34e+00
# Done ramping
# Ramping V_pl_A to 2.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.35e+00
# Done ramping
# Ramping V_bot_A to 2.35e+00
# Done ramping
# Ramping V_pl_A to 2.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.35e+00
# Done ramping
# Ramping V_bot_A to 2.35e+00
# Done ramping
# Ramping V_pl_A to 2.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.36e+00
# Done ramping
# Ramping V_bot_A to 2.36e+00
# Done ramping
# Ramping V_pl_A to 2.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.36e+00
# Done ramping
# Ramping V_bot_A to 2.36e+00
# Done ramping
# Ramping V_pl_A to 2.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.37e+00
# Done ramping
# Ramping V_bot_A to 2.37e+00
# Done ramping
# Ramping V_pl_A to 2.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.37e+00
# Done ramping
# Ramping V_bot_A to 2.37e+00
# Done ramping
# Ramping V_pl_A to 2.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.38e+00
# Done ramping
# Ramping V_bot_A to 2.38e+00
# Done ramping
# Ramping V_pl_A to 2.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.38e+00
# Done ramping
# Ramping V_bot_A to 2.38e+00
# Done ramping
# Ramping V_pl_A to 2.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.39e+00
# Done ramping
# Ramping V_bot_A to 2.39e+00
# Done ramping
# Ramping V_pl_A to 2.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.39e+00
# Done ramping
# Ramping V_bot_A to 2.39e+00
# Done ramping
# Ramping V_pl_A to 2.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.40e+00
# Done ramping
# Ramping V_bot_A to 2.40e+00
# Done ramping
# Ramping V_pl_A to 2.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.40e+00
# Done ramping
# Ramping V_bot_A to 2.40e+00
# Done ramping
# Ramping V_pl_A to 2.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.41e+00
# Done ramping
# Ramping V_bot_A to 2.41e+00
# Done ramping
# Ramping V_pl_A to 2.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.41e+00
# Done ramping
# Ramping V_bot_A to 2.41e+00
# Done ramping
# Ramping V_pl_A to 2.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.42e+00
# Done ramping
# Ramping V_bot_A to 2.42e+00
# Done ramping
# Ramping V_pl_A to 2.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.42e+00
# Done ramping
# Ramping V_bot_A to 2.42e+00
# Done ramping
# Ramping V_pl_A to 2.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.43e+00
# Done ramping
# Ramping V_bot_A to 2.43e+00
# Done ramping
# Ramping V_pl_A to 2.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.43e+00
# Done ramping
# Ramping V_bot_A to 2.43e+00
# Done ramping
# Ramping V_pl_A to 2.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.44e+00
# Done ramping
# Ramping V_bot_A to 2.44e+00
# Done ramping
# Ramping V_pl_A to 2.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.44e+00
# Done ramping
# Ramping V_bot_A to 2.44e+00
# Done ramping
# Ramping V_pl_A to 2.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.45e+00
# Done ramping
# Ramping V_bot_A to 2.45e+00
# Done ramping
# Ramping V_pl_A to 2.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.45e+00
# Done ramping
# Ramping V_bot_A to 2.45e+00
# Done ramping
# Ramping V_pl_A to 2.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.46e+00
# Done ramping
# Ramping V_bot_A to 2.46e+00
# Done ramping
# Ramping V_pl_A to 2.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.46e+00
# Done ramping
# Ramping V_bot_A to 2.46e+00
# Done ramping
# Ramping V_pl_A to 2.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.47e+00
# Done ramping
# Ramping V_bot_A to 2.47e+00
# Done ramping
# Ramping V_pl_A to 2.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.47e+00
# Done ramping
# Ramping V_bot_A to 2.47e+00
# Done ramping
# Ramping V_pl_A to 2.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.48e+00
# Done ramping
# Ramping V_bot_A to 2.48e+00
# Done ramping
# Ramping V_pl_A to 2.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.48e+00
# Done ramping
# Ramping V_bot_A to 2.48e+00
# Done ramping
# Ramping V_pl_A to 2.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.49e+00
# Done ramping
# Ramping V_bot_A to 2.49e+00
# Done ramping
# Ramping V_pl_A to 2.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.49e+00
# Done ramping
# Ramping V_bot_A to 2.49e+00
# Done ramping
# Ramping V_pl_A to 2.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.50e+00
# Done ramping
# Ramping V_bot_A to 2.50e+00
# Done ramping
# Ramping V_pl_A to 2.50e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.50e+00
# Done ramping
# Ramping V_bot_A to 2.50e+00
# Done ramping
# Ramping V_pl_A to 2.50e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.51e+00
# Done ramping
# Ramping V_bot_A to 2.51e+00
# Done ramping
# Ramping V_pl_A to 2.51e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.51e+00
# Done ramping
# Ramping V_bot_A to 2.51e+00
# Done ramping
# Ramping V_pl_A to 2.51e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.52e+00
# Done ramping
# Ramping V_bot_A to 2.52e+00
# Done ramping
# Ramping V_pl_A to 2.52e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.52e+00
# Done ramping
# Ramping V_bot_A to 2.52e+00
# Done ramping
# Ramping V_pl_A to 2.52e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.53e+00
# Done ramping
# Ramping V_bot_A to 2.53e+00
# Done ramping
# Ramping V_pl_A to 2.53e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.53e+00
# Done ramping
# Ramping V_bot_A to 2.53e+00
# Done ramping
# Ramping V_pl_A to 2.53e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.54e+00
# Done ramping
# Ramping V_bot_A to 2.54e+00
# Done ramping
# Ramping V_pl_A to 2.54e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.54e+00
# Done ramping
# Ramping V_bot_A to 2.54e+00
# Done ramping
# Ramping V_pl_A to 2.54e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.55e+00
# Done ramping
# Ramping V_bot_A to 2.55e+00
# Done ramping
# Ramping V_pl_A to 2.55e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.55e+00
# Done ramping
# Ramping V_bot_A to 2.55e+00
# Done ramping
# Ramping V_pl_A to 2.55e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.56e+00
# Done ramping
# Ramping V_bot_A to 2.56e+00
# Done ramping
# Ramping V_pl_A to 2.56e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.56e+00
# Done ramping
# Ramping V_bot_A to 2.56e+00
# Done ramping
# Ramping V_pl_A to 2.56e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.57e+00
# Done ramping
# Ramping V_bot_A to 2.57e+00
# Done ramping
# Ramping V_pl_A to 2.57e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.57e+00
# Done ramping
# Ramping V_bot_A to 2.57e+00
# Done ramping
# Ramping V_pl_A to 2.57e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.58e+00
# Done ramping
# Ramping V_bot_A to 2.58e+00
# Done ramping
# Ramping V_pl_A to 2.58e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.58e+00
# Done ramping
# Ramping V_bot_A to 2.58e+00
# Done ramping
# Ramping V_pl_A to 2.58e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.59e+00
# Done ramping
# Ramping V_bot_A to 2.59e+00
# Done ramping
# Ramping V_pl_A to 2.59e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.59e+00
# Done ramping
# Ramping V_bot_A to 2.59e+00
# Done ramping
# Ramping V_pl_A to 2.59e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.60e+00
# Done ramping
# Ramping V_bot_A to 2.60e+00
# Done ramping
# Ramping V_pl_A to 2.60e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.60e+00
# Done ramping
# Ramping V_bot_A to 2.60e+00
# Done ramping
# Ramping V_pl_A to 2.60e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.61e+00
# Done ramping
# Ramping V_bot_A to 2.61e+00
# Done ramping
# Ramping V_pl_A to 2.61e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.61e+00
# Done ramping
# Ramping V_bot_A to 2.61e+00
# Done ramping
# Ramping V_pl_A to 2.61e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.62e+00
# Done ramping
# Ramping V_bot_A to 2.62e+00
# Done ramping
# Ramping V_pl_A to 2.62e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.62e+00
# Done ramping
# Ramping V_bot_A to 2.62e+00
# Done ramping
# Ramping V_pl_A to 2.62e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.63e+00
# Done ramping
# Ramping V_bot_A to 2.63e+00
# Done ramping
# Ramping V_pl_A to 2.63e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.63e+00
# Done ramping
# Ramping V_bot_A to 2.63e+00
# Done ramping
# Ramping V_pl_A to 2.63e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.64e+00
# Done ramping
# Ramping V_bot_A to 2.64e+00
# Done ramping
# Ramping V_pl_A to 2.64e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.64e+00
# Done ramping
# Ramping V_bot_A to 2.64e+00
# Done ramping
# Ramping V_pl_A to 2.64e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.65e+00
# Done ramping
# Ramping V_bot_A to 2.65e+00
# Done ramping
# Ramping V_pl_A to 2.65e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.65e+00
# Done ramping
# Ramping V_bot_A to 2.65e+00
# Done ramping
# Ramping V_pl_A to 2.65e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.66e+00
# Done ramping
# Ramping V_bot_A to 2.66e+00
# Done ramping
# Ramping V_pl_A to 2.66e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.66e+00
# Done ramping
# Ramping V_bot_A to 2.66e+00
# Done ramping
# Ramping V_pl_A to 2.66e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.67e+00
# Done ramping
# Ramping V_bot_A to 2.67e+00
# Done ramping
# Ramping V_pl_A to 2.67e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.67e+00
# Done ramping
# Ramping V_bot_A to 2.67e+00
# Done ramping
# Ramping V_pl_A to 2.67e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.68e+00
# Done ramping
# Ramping V_bot_A to 2.68e+00
# Done ramping
# Ramping V_pl_A to 2.68e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.68e+00
# Done ramping
# Ramping V_bot_A to 2.68e+00
# Done ramping
# Ramping V_pl_A to 2.68e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.69e+00
# Done ramping
# Ramping V_bot_A to 2.69e+00
# Done ramping
# Ramping V_pl_A to 2.69e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.69e+00
# Done ramping
# Ramping V_bot_A to 2.69e+00
# Done ramping
# Ramping V_pl_A to 2.69e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.70e+00
# Done ramping
# Ramping V_bot_A to 2.70e+00
# Done ramping
# Ramping V_pl_A to 2.70e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.70e+00
# Done ramping
# Ramping V_bot_A to 2.70e+00
# Done ramping
# Ramping V_pl_A to 2.70e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.71e+00
# Done ramping
# Ramping V_bot_A to 2.71e+00
# Done ramping
# Ramping V_pl_A to 2.71e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.71e+00
# Done ramping
# Ramping V_bot_A to 2.71e+00
# Done ramping
# Ramping V_pl_A to 2.71e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.72e+00
# Done ramping
# Ramping V_bot_A to 2.72e+00
# Done ramping
# Ramping V_pl_A to 2.72e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.72e+00
# Done ramping
# Ramping V_bot_A to 2.72e+00
# Done ramping
# Ramping V_pl_A to 2.72e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.73e+00
# Done ramping
# Ramping V_bot_A to 2.73e+00
# Done ramping
# Ramping V_pl_A to 2.73e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.73e+00
# Done ramping
# Ramping V_bot_A to 2.73e+00
# Done ramping
# Ramping V_pl_A to 2.73e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.74e+00
# Done ramping
# Ramping V_bot_A to 2.74e+00
# Done ramping
# Ramping V_pl_A to 2.74e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.74e+00
# Done ramping
# Ramping V_bot_A to 2.74e+00
# Done ramping
# Ramping V_pl_A to 2.74e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.75e+00
# Done ramping
# Ramping V_bot_A to 2.75e+00
# Done ramping
# Ramping V_pl_A to 2.75e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.75e+00
# Done ramping
# Ramping V_bot_A to 2.75e+00
# Done ramping
# Ramping V_pl_A to 2.75e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.76e+00
# Done ramping
# Ramping V_bot_A to 2.76e+00
# Done ramping
# Ramping V_pl_A to 2.76e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 2.76e+00
# Done ramping
# Ramping V_bot_A to 2.76e+00
# Done ramping
# Ramping V_pl_A to 2.76e+00
# Done ramping
# ...
# done power -33
# Ramping V_cut_A to 3.24e+00
# Done ramping
# Ramping V_bot_A to 3.24e+00
# Done ramping
# Ramping V_pl_A to 3.24e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.25e+00
# Done ramping
# Ramping V_bot_A to 3.25e+00
# Done ramping
# Ramping V_pl_A to 3.25e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.25e+00
# Done ramping
# Ramping V_bot_A to 3.25e+00
# Done ramping
# Ramping V_pl_A to 3.25e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.26e+00
# Done ramping
# Ramping V_bot_A to 3.26e+00
# Done ramping
# Ramping V_pl_A to 3.26e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.26e+00
# Done ramping
# Ramping V_bot_A to 3.26e+00
# Done ramping
# Ramping V_pl_A to 3.26e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.27e+00
# Done ramping
# Ramping V_bot_A to 3.27e+00
# Done ramping
# Ramping V_pl_A to 3.27e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.27e+00
# Done ramping
# Ramping V_bot_A to 3.27e+00
# Done ramping
# Ramping V_pl_A to 3.27e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.28e+00
# Done ramping
# Ramping V_bot_A to 3.28e+00
# Done ramping
# Ramping V_pl_A to 3.28e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.28e+00
# Done ramping
# Ramping V_bot_A to 3.28e+00
# Done ramping
# Ramping V_pl_A to 3.28e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.29e+00
# Done ramping
# Ramping V_bot_A to 3.29e+00
# Done ramping
# Ramping V_pl_A to 3.29e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.29e+00
# Done ramping
# Ramping V_bot_A to 3.29e+00
# Done ramping
# Ramping V_pl_A to 3.29e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.30e+00
# Done ramping
# Ramping V_bot_A to 3.30e+00
# Done ramping
# Ramping V_pl_A to 3.30e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.30e+00
# Done ramping
# Ramping V_bot_A to 3.30e+00
# Done ramping
# Ramping V_pl_A to 3.30e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.31e+00
# Done ramping
# Ramping V_bot_A to 3.31e+00
# Done ramping
# Ramping V_pl_A to 3.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.31e+00
# Done ramping
# Ramping V_bot_A to 3.31e+00
# Done ramping
# Ramping V_pl_A to 3.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.32e+00
# Done ramping
# Ramping V_bot_A to 3.32e+00
# Done ramping
# Ramping V_pl_A to 3.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.32e+00
# Done ramping
# Ramping V_bot_A to 3.32e+00
# Done ramping
# Ramping V_pl_A to 3.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.33e+00
# Done ramping
# Ramping V_bot_A to 3.33e+00
# Done ramping
# Ramping V_pl_A to 3.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.33e+00
# Done ramping
# Ramping V_bot_A to 3.33e+00
# Done ramping
# Ramping V_pl_A to 3.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.34e+00
# Done ramping
# Ramping V_bot_A to 3.34e+00
# Done ramping
# Ramping V_pl_A to 3.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.34e+00
# Done ramping
# Ramping V_bot_A to 3.34e+00
# Done ramping
# Ramping V_pl_A to 3.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.35e+00
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_pl_A to 3.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.35e+00
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_pl_A to 3.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.36e+00
# Done ramping
# Ramping V_bot_A to 3.36e+00
# Done ramping
# Ramping V_pl_A to 3.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.36e+00
# Done ramping
# Ramping V_bot_A to 3.36e+00
# Done ramping
# Ramping V_pl_A to 3.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.37e+00
# Done ramping
# Ramping V_bot_A to 3.37e+00
# Done ramping
# Ramping V_pl_A to 3.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.37e+00
# Done ramping
# Ramping V_bot_A to 3.37e+00
# Done ramping
# Ramping V_pl_A to 3.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.38e+00
# Done ramping
# Ramping V_bot_A to 3.38e+00
# Done ramping
# Ramping V_pl_A to 3.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.38e+00
# Done ramping
# Ramping V_bot_A to 3.38e+00
# Done ramping
# Ramping V_pl_A to 3.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.39e+00
# Done ramping
# Ramping V_bot_A to 3.39e+00
# Done ramping
# Ramping V_pl_A to 3.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.39e+00
# Done ramping
# Ramping V_bot_A to 3.39e+00
# Done ramping
# Ramping V_pl_A to 3.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.40e+00
# Done ramping
# Ramping V_bot_A to 3.40e+00
# Done ramping
# Ramping V_pl_A to 3.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.40e+00
# Done ramping
# Ramping V_bot_A to 3.40e+00
# Done ramping
# Ramping V_pl_A to 3.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.41e+00
# Done ramping
# Ramping V_bot_A to 3.41e+00
# Done ramping
# Ramping V_pl_A to 3.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.41e+00
# Done ramping
# Ramping V_bot_A to 3.41e+00
# Done ramping
# Ramping V_pl_A to 3.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.42e+00
# Done ramping
# Ramping V_bot_A to 3.42e+00
# Done ramping
# Ramping V_pl_A to 3.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.42e+00
# Done ramping
# Ramping V_bot_A to 3.42e+00
# Done ramping
# Ramping V_pl_A to 3.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.43e+00
# Done ramping
# Ramping V_bot_A to 3.43e+00
# Done ramping
# Ramping V_pl_A to 3.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.43e+00
# Done ramping
# Ramping V_bot_A to 3.43e+00
# Done ramping
# Ramping V_pl_A to 3.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.44e+00
# Done ramping
# Ramping V_bot_A to 3.44e+00
# Done ramping
# Ramping V_pl_A to 3.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.44e+00
# Done ramping
# Ramping V_bot_A to 3.44e+00
# Done ramping
# Ramping V_pl_A to 3.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.45e+00
# Done ramping
# Ramping V_bot_A to 3.45e+00
# Done ramping
# Ramping V_pl_A to 3.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.45e+00
# Done ramping
# Ramping V_bot_A to 3.45e+00
# Done ramping
# Ramping V_pl_A to 3.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_pl_A to 3.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_pl_A to 3.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.47e+00
# Done ramping
# Ramping V_bot_A to 3.47e+00
# Done ramping
# Ramping V_pl_A to 3.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.47e+00
# Done ramping
# Ramping V_bot_A to 3.47e+00
# Done ramping
# Ramping V_pl_A to 3.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_pl_A to 3.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_pl_A to 3.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.49e+00
# Done ramping
# Ramping V_bot_A to 3.49e+00
# Done ramping
# Ramping V_pl_A to 3.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
# Ramping V_cut_A to 3.49e+00
# Done ramping
# Ramping V_bot_A to 3.49e+00
# Done ramping
# Ramping V_pl_A to 3.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -33
#  Time elapsed: 5596.1009

# %% [markdown]
# # Magnet

# %% [markdown]
# Check that the magnet is the "right" one and so the parameters (coil constant and so on...)

# %%
from qcodes.instrument_drivers.american_magnetics.AMI430 import AMI430,AMI430_3D
from pytopo.qctools import instruments as instools

# %%
ami_x = instools.create_inst(AMI430, "AMI430_x", "169.254.178.28", port = 7180, has_current_rating=True)
#ami_y = instools.create_inst(AMI430, "AMI430_y", "169.254.175.39", port = 7180, has_current_rating=True)
ami_z = instools.create_inst(AMI430, "AMI430_z", "169.254.137.107", port = 7180, has_current_rating=True)

ramp_limit_multiplier = 0.6
ami_x.current_ramp_limit(0.1805*ramp_limit_multiplier) #for QT3 magnet 0.1802
ami_x.coil_constant(0.01464)  #for QT3 magnet 0.01466
ami_x.current_rating(68.31)  #for QT3 magnet 68.21

#ami_y.current_ramp_limit(0.1810*ramp_limit_multiplier) #for QT3 magnet 0.1784
#ami_y.coil_constant(0.01477) #for QT3 magnet 0.01464
#ami_y.current_rating(67.7) #for QT3 magnet 68.31

ami_z.current_ramp_limit(0.0760*ramp_limit_multiplier) #for QT3 magnet 0.0775
ami_z.coil_constant(0.0836)  #for QT3 magnet 0.0818
ami_z.current_rating(71.77)  #for QT3 magnet 73.35

#ami = instools.create_inst(AMI430_3D, "AMI430", ami_x, ami_y, ami_z, 2)
#ami_3d = AMI430_3D("AMI_3D", ami_x, ami_y, ami_z, 1);
# Out:
# Connected to: AMERICAN MAGNETICS INC. 430 (serial:170029, firmware:2.59) in 1.14s
# Connected to: AMERICAN MAGNETICS INC. 430 (serial:170027, firmware:2.59) in 1.01s
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py:407: AMI430Warning: Increasing maximum ramp rate: we have a default current ramp rate limit of 0.1 A/s. We do not want to ramp faster than a set maximum so as to avoid quenching the magnet. A value of 0.1 A/s seems like a safe, conservative value for any magnet. Change this value at your own responsibility after consulting the specs of your particular magnet
#   warn(warning_message, category=AMI430Warning)

# %%
print(ami_x.ramp_rate(), 'T/ ramp rate unit')
print(ami_y.ramp_rate())
print(ami_z.ramp_rate())
print(ami_x.ramp_rate_units())
print(ami_z.current_ramp_limit())
#30.1802*ramp_limit_multiplier
print(ami_x.field())
print(ami_y.field())
print(ami_z.field())
print (ami_3d.field_measured())
print(ami_3d.phi_measured())

# %%
ami_y.ramp_rate(0.1e-3)

# %%
#note that 0.01 mT is already fluctuating between 
ami_y.field(0)

# %%
set_yoko_field(0.1e-4)

# %% [markdown]
# ## Yoko current source for y axis

# %%
from qcodes.instrument_drivers.yokogawa.GS200 import GS200
yoko1 = create_inst(GS200,"yoko1", "USB0::0x0B21::0x0039::91T926460::INSTR", force_new_instance=True)
station.add_component(yoko1)
#yoko1.off()
# Out:
# [yoko1(GS200)] Snapshot: Could not update parameter: voltage_range
# [yoko1(GS200)] Snapshot: Could not update parameter: voltage
# 'yoko1'

# %%
yoko1.off()

# %%
yoko1.current_limit(200e-3)
yoko1.source_mode("CURR")
yoko1.on()
yoko1.auto_range(True)
yoko1.current()
#yoko1.current(0)
# Out:
# 0.0

# %%
def set_yoko_field(field_strength, current_rating= 67.7, #QT2 current rating y-axis magnet. 
                  yoko_ramp_step = 1e-7, # in A
                  yoko_ramp_delay = 1e-6): # in s):
    """
    goes as 67.7A/T
    """
    amp = field_strength * current_rating
    if(np.abs(amp) > 200e-3):
        raise Exception("Required current for field beyond yoko limit")
    
    yoko1.ramp_current(amp, yoko_ramp_step, yoko_ramp_delay)
def get_yoko_field(current_rating= 67.7):
    """
    returns the field in Tesla
    """
    return yoko1.current() / current_rating 
print(get_yoko_field())


class YokoMagnet(Instrument):
    """
    Just a class to do 3D magnet stuff but then with the yoko as y-axis instead of ami-y
    """    
    def __init__(self, name, ami_x, ami_z, **kwargs):
        super().__init__(name, **kwargs)
        
        #use the ami x and z params
        self.add_parameter('z', get_cmd=ami_z.field, set_cmd=ami_z.field, unit='T')
        self.add_parameter('x', get_cmd=ami_x.field, set_cmd=ami_x.field, unit='T')
        #but define custom function for y
        self.add_parameter('y', get_cmd=get_yoko_field, set_cmd=set_yoko_field, unit='T')
    
    def transform_spherical_to_cartesian(self, r, theta, phi):
        """
        Does what it sais, uses the same convention as FieldVector QCodes math helper function and thus as the AMI_3D driver
        note radians...
        """
        z = r * np.cos(theta)
        x = r * np.sin(theta) * np.cos(phi)
        y = r * np.sin(theta) * np.sin(phi)
        return x, y, z
# Out:
# 0.0

# %%
yoko_magnet = create_inst(YokoMagnet, 'yoko_magnet',ami_x = ami_x,ami_z = ami_z, force_new_instance=True)
station.add_component(yoko_magnet)
# Out:
# Instrument yoko_magnet already exists.
# 'yoko_magnet'

# %%
yoko_magnet.z(0)
yoko_magnet.x(0)
yoko_magnet.y(0)

# %% [markdown]
# ## Magnet sweep

# %%
b_min = 0e-3 #
b_max = 6e-3 # should be approximately 2 periods
y_fields = np.linspace(b_min,b_max,100)

#set the voltages corresponding to the MDAC channels
gate_settings = {
    'V_bot_A' : 4,
    'V_cut_A' : 2,
}

exp = qc.new_experiment("Field_sweep A v_bot=%.2f v_cut=%.2f" % (gate_settings['V_bot_A'], gate_settings['V_cut_A'])  , sample_name="abs_w1_5_1_1")

gate_ramp_stepsize = 1e-3 #[V] previously was 1e-3
gate_ramp_delay = 0.01  #[s]


power=-60
n_pts = 100
f_start = 4.8472e9 - 0.0015e9
f_stop = 4.8472e9 + 0.0015e9
n_avg=100
channel_name='S12'


#get temperature:
T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
temperature = T_probe.temperature()

# set VNA stuff
vna_channel = getattr(vna.channels, channel_name)

vna_channel.avg(n_avg)
vna_channel.npts(n_pts)
vna_channel.start(f_start)
vna_channel.stop(f_stop)
vna_channel.power(power)
vna_channel.format('Complex')
vna.rf_on()


#START OF THE MSM
#now setup the qcodes measurement object
meas = Measurement()

meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')

meas.register_custom_parameter('frequency', unit='Hz',
                               paramtype='array')

meas.register_custom_parameter('B_y', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_x', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_z', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_y_meas', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_x_meas', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_z_meas', unit='T', paramtype='numeric')

#save all gates that are available
for gate_name, value in MDAC_channels.items():
    meas.register_custom_parameter(gate_name, unit='V')

    
# set vna props
vna_trace_setpoints = ['frequency', 'B_y']

meas.register_custom_parameter('power', unit='dBm'),
meas.register_custom_parameter('Re_S', unit='V', 
                                setpoints=vna_trace_setpoints,
                               paramtype='array'),
meas.register_custom_parameter('Im_S', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('mag', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('phase', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('magnitude_dB', unit='dB', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')



#gate voltages

print("Setting gate voltages")
for gate_name, volt in gate_settings.items():
    print("Setting %s voltage to %3.f" %(gate_name, volt))
    ramp(MDAC_channels[gate_name].voltage, volt, gate_ramp_stepsize, gate_ramp_delay )
print("Done setting gate voltages")

with meas.run() as datasaver:
    for field in y_fields:
        #set the B field
        print("Setting Bfield to %.2e" % field)
        ami_y.field(field)
        
        #VNA stuff
        fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
        S12 = vna_channel.trace.get()
        mag_db = 20*np.log10(np.abs(S12)) #convert to dB
        result = [ 
            ('frequency', fvals),
            ('Re_S', np.real(S12)),
            ('magnitude_dB',mag_db ),
            ('Im_S', np.imag(S12)),
            ('phase', np.angle(S12)),
            ('mag', np.abs(S12)),
            ('power', power),
            ('temperature', temperature)]
       
        #save the measured fields
        result.append(('B_y_meas', ami_y.field()))
        result.append(('B_x_meas', ami_x.field()))
        result.append(('B_z_meas', ami_z.field()))
        #save the target field
        result.append(('B_y', field))
        
        
        #save the gate voltages
        for gate_name, voltage in gate_settings.items():
            result.append((gate_name, MDAC_channels[gate_name].voltage()))
        
        run_id = datasaver.add_result(
            *result
           )
print(run_id)

# %%
plot_by_id(53)

# %%
### try bot at different fields.
ami_y.field(0)
ami_z.field(0)

# %%
gate_channel = mdac.ch01
gate_voltages = np.linspace(-1,2,11)
gate_name = 'V_cut_A'

fields=np.linspace(0,4e-3,10)
df = 0.004e9
Vbot = 3
ramp(mdac.ch18.voltage, vBot, gate_ramp_stepsize,gate_ramp_delay)
#resonator A
for y_field in fields:
    #set the B field
    print("Setting Bfield to %.2e" % y_field)
    ami_y.field(y_field)
    f0 = 4.847e9
    run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                            gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.003 , #[s]
                            power=-60, n_pts = 200, f_start = f0-df, f_stop = f0+df, n_avg=50, channel_name='S12')

# %% [markdown]
# # Checking VNA with 40dB attenuation

# %%
power = -30
exp = qc.new_experiment("Single (-40dB atten) VNA trace power %d" %power  , sample_name="abs_w1_5_1_1")
f0 = 6e9
df = 3e9
run_id = do_single_sweep(n_pts = 10000, f_start = f0-df, f_stop = f0+df, power=power, n_avg=500, channel_name='S12')

# %%
plot_by_id(run_id)

# %% [markdown]
# ## single sweeps:

# %%
gate_ramp_stepsize = 0.001
gate_ramp_delay=0.01

# %%
T_probe.temperature()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-53f3e2ad0569> in <module>()
# ----> 1 T_probe.temperature()
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\helpers.py in __getattr__(self, key)
#     418         raise AttributeError(
#     419             "'{}' object and its delegates have no attribute '{}'".format(
# --> 420                 self.__class__.__name__, key))
#     421
#     422     def __dir__(self):
#
# AttributeError: 'Thermometer' object and its delegates have no attribute 'temperature'

# %%
power = -33
n_avgs = 1000
n_pts = 100
vBot = 2
exp = qc.new_experiment("(-40dB atten extra) gate Vbot=%.3fV power=-40-%d dbM navg=%d n_points=200" %(vBot, power, n_avgs)  , sample_name="abs_w1_5_1_1")
gate_channel = mdac.ch01
gate_voltages = np.arange(0.0,4.5,0.002)
gate_name = 'V_cut_A'

#set a field 
set_yoko_field(9e-6)

df = 0.0020e9
#ramp back to the -4. 
print("ramping back and setting vbot")
ramp(mdac.ch18.voltage, vBot, gate_ramp_stepsize,gate_ramp_delay)
ramp(mdac.ch01.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
time.sleep(20)
print("")
#ramp(mdac.ch01.voltage, 1, gate_ramp_stepsize, gate_ramp_delay)
print("")
#resonator A
#ramp(mdac.ch18.voltage, -4, gate_ramp_stepsize,gate_ramp_delay)
f0 = 4.84725e9
run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                        gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                        gate_ramp_delay = 0.003 , #[s]
                        power=power, n_pts = n_pts, f_start = f0-df, f_stop = f0+df, n_avg=n_avgs, channel_name='S12')

# %% [markdown]
# ### Single sweep with bot gate

# %%
print(mdac.ch18.voltage())

# %%
## BOTTOM GATE SWEEP WITH FIXED CUTTERs
power = -33
n_avgs = 400
n_pts = 100
v_cuts = np.arange(3,-3,-0.1)

for v_cut in v_cuts:
    exp = qc.new_experiment("Bot sweep: Vcut=%.3fV power=%d dbM navg=%d n_points=%d" %(v_cut, power, n_avgs, n_pts)  , sample_name="abs_w1_5_1_1")
    gate_channel = mdac.ch18
    gate_voltages = np.arange(-4,4,0.02)
    gate_name = 'V_bot_A'

    df = 0.0045e9

    #ramp back to the -4. 
    #print("ramping back ")
    #ramp(mdac.ch01.voltage, v_cut, gate_ramp_stepsize, gate_ramp_delay)
    #print("")
    #ramp(mdac.ch01.voltage, 1, gate_ramp_stepsize, gate_ramp_delay)
    #print("")
    #resonator A
    for vBot in Vbots:
        ramp(mdac.ch01.voltage, v_cut, gate_ramp_stepsize,gate_ramp_delay)
        f0 = 4.84725e9
        run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                                gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                                gate_ramp_delay = 0.003 , #[s]
                                power=power, n_pts = n_pts, f_start = f0-df, f_stop = f0+df, n_avg=n_avgs, channel_name='S12')

# %% [markdown]
# ## Sweep of magnet at cutter gate

# %%
#For resonator C

b_min = get_yoko_field()#
b_max = 2.5e-3 # should be approximately 2 periods
y_fields = np.arange(b_min,b_max,1e-6)

# ramp back the yoko and set to min field
set_yoko_field(0)
set_yoko_field(b_min)


#first ramp the cutter gate back to its original value:
#ramp back to the -4. 
print("ramping back ")
#ramp(mdac.ch01.voltage, -3, gate_ramp_stepsize, gate_ramp_delay)
print("")

#set the voltages corresponding to the MDAC channels
gate_settings = {
    'V_bot_A' : 2,
    'V_cut_A' : 0.75,
}

exp = qc.new_experiment("Field_sweep "  , sample_name="abs_w1_5_1_1")

gate_ramp_stepsize = 1e-3 #[V] previously was 1e-3
gate_ramp_delay = 0.01 #[s]

#f0 = 3.535e9
#f0 =  5.889e9
#f0 = 4.020e9
f0  = 4.84725e9
df = 0.0045e9


power=-33
n_pts = 200
f_start = f0-df
f_stop = f0+df
n_avg=1000
channel_name='S12'


#get temperature:
T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
temperature = T_probe.temperature()

# set VNA stuff
vna_channel = getattr(vna.channels, channel_name)

vna_channel.avg(n_avg)
vna_channel.npts(n_pts)
vna_channel.start(f_start)
vna_channel.stop(f_stop)
vna_channel.power(power)
vna_channel.format('Complex')
vna.rf_on()


#START OF THE MSM
#now setup the qcodes measurement object
meas = Measurement()

meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')

meas.register_custom_parameter('frequency', unit='Hz',
                               paramtype='array')

meas.register_custom_parameter('B_y', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_x', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_z', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_y_meas', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_x_meas', unit='T', paramtype='numeric')
meas.register_custom_parameter('B_z_meas', unit='T', paramtype='numeric')

#save all gates that are available
for gate_name, value in MDAC_channels.items():
    meas.register_custom_parameter(gate_name, unit='V')

    
# set vna props
vna_trace_setpoints = ['frequency', 'B_y']

meas.register_custom_parameter('power', unit='dBm'),
meas.register_custom_parameter('Re_S', unit='V', 
                                setpoints=vna_trace_setpoints,
                               paramtype='array'),
meas.register_custom_parameter('Im_S', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('mag', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('phase', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('magnitude_dB', unit='dB', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')



#gate voltages

print("Setting gate voltages")
for gate_name, volt in gate_settings.items():
    print("Setting %s voltage to %3.f" %(gate_name, volt))
    #ramp(MDAC_channels[gate_name].voltage, volt, gate_ramp_stepsize, gate_ramp_delay )
print("Done setting gate voltages")

with meas.run() as datasaver:
    t0 = time.time()
    n= 1
    for field in y_fields:
        print("Setting Bfield to %.2e" % field)
        set_yoko_field(field)
        print("finsihed setting Bfield")
        #VNA stuff
        fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
        S12 = vna_channel.trace.get()
        mag_db = 20*np.log10(np.abs(S12)) #convert to dB
        result = [('frequency', fvals),
                  ('Re_S', np.real(S12)),
                  ('magnitude_dB',mag_db ),
                  ('Im_S', np.imag(S12)),
                  ('phase', np.angle(S12)),
                  ('mag', np.abs(S12)),
                  ('power', power),
                  ('temperature', temperature)]      
        #save the measured fields
        result.append(('B_y_meas', get_yoko_field()))
        #result.append(('B_x_meas', ami_x.field()))
        #result.append(('B_z_meas', ami_z.field()))
        #save the target field
        result.append(('B_y', field))
        #save the gate voltages
        #for gate_name, voltage in gate_settings.items():
        # result.append((gate_name, MDAC_channels[gate_name].voltage()))
        print('cum time for this point: %.2f s, time remaining %d points= %2.f s' %(time.time()-t0, (len(y_fields)-n), (time.time()-t0) / n * (len(y_fields)-n))  )
        n+= 1
        datasaver.add_result(*result)
# Out:
# ramping back
#
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Setting gate voltages
# Setting V_bot_A voltage to   2
# Setting V_cut_A voltage to   1
# Done setting gate voltages
# Starting experimental run with id: 15
# Setting Bfield to 1.34e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 24.71 s, time remaining 1160 points= 28661 s
# Setting Bfield to 1.34e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 49.68 s, time remaining 1159 points= 28790 s
# Setting Bfield to 1.34e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 74.62 s, time remaining 1158 points= 28803 s
# Setting Bfield to 1.34e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 99.57 s, time remaining 1157 points= 28801 s
# Setting Bfield to 1.34e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 124.53 s, time remaining 1156 points= 28791 s
# Setting Bfield to 1.34e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 149.50 s, time remaining 1155 points= 28779 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 174.48 s, time remaining 1154 points= 28765 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 199.42 s, time remaining 1153 points= 28742 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 224.40 s, time remaining 1152 points= 28723 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 249.36 s, time remaining 1151 points= 28701 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 274.32 s, time remaining 1150 points= 28679 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 299.26 s, time remaining 1149 points= 28654 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 324.20 s, time remaining 1148 points= 28629 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 349.16 s, time remaining 1147 points= 28607 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 374.13 s, time remaining 1146 points= 28583 s
# Setting Bfield to 1.35e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 399.10 s, time remaining 1145 points= 28560 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 424.06 s, time remaining 1144 points= 28537 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 449.04 s, time remaining 1143 points= 28514 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 474.00 s, time remaining 1142 points= 28490 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 498.92 s, time remaining 1141 points= 28463 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 523.86 s, time remaining 1140 points= 28438 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 548.81 s, time remaining 1139 points= 28413 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 573.79 s, time remaining 1138 points= 28390 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 598.75 s, time remaining 1137 points= 28366 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 623.69 s, time remaining 1136 points= 28340 s
# Setting Bfield to 1.36e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 648.67 s, time remaining 1135 points= 28317 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 673.61 s, time remaining 1134 points= 28292 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 698.54 s, time remaining 1133 points= 28266 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 723.49 s, time remaining 1132 points= 28241 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 748.46 s, time remaining 1131 points= 28217 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 773.38 s, time remaining 1130 points= 28191 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 798.33 s, time remaining 1129 points= 28166 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 823.30 s, time remaining 1128 points= 28142 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 848.25 s, time remaining 1127 points= 28117 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 873.19 s, time remaining 1126 points= 28092 s
# Setting Bfield to 1.37e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 898.16 s, time remaining 1125 points= 28067 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 923.11 s, time remaining 1124 points= 28043 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 948.08 s, time remaining 1123 points= 28018 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 973.05 s, time remaining 1122 points= 27994 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 998.02 s, time remaining 1121 points= 27970 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1022.97 s, time remaining 1120 points= 27944 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1047.92 s, time remaining 1119 points= 27920 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1072.89 s, time remaining 1118 points= 27895 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1097.81 s, time remaining 1117 points= 27869 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1122.78 s, time remaining 1116 points= 27845 s
# Setting Bfield to 1.38e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1147.75 s, time remaining 1115 points= 27821 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1172.70 s, time remaining 1114 points= 27795 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1197.64 s, time remaining 1113 points= 27770 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1222.60 s, time remaining 1112 points= 27745 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1247.58 s, time remaining 1111 points= 27721 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1272.51 s, time remaining 1110 points= 27696 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1297.48 s, time remaining 1109 points= 27671 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1322.42 s, time remaining 1108 points= 27646 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1347.35 s, time remaining 1107 points= 27621 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1372.32 s, time remaining 1106 points= 27596 s
# Setting Bfield to 1.39e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1397.29 s, time remaining 1105 points= 27572 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1422.21 s, time remaining 1104 points= 27546 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1447.18 s, time remaining 1103 points= 27521 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1472.12 s, time remaining 1102 points= 27496 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1497.08 s, time remaining 1101 points= 27471 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1522.06 s, time remaining 1100 points= 27447 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1546.99 s, time remaining 1099 points= 27422 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1571.95 s, time remaining 1098 points= 27397 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1596.91 s, time remaining 1097 points= 27372 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1621.86 s, time remaining 1096 points= 27347 s
# Setting Bfield to 1.40e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1646.83 s, time remaining 1095 points= 27322 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1671.77 s, time remaining 1094 points= 27297 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1696.73 s, time remaining 1093 points= 27272 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1721.69 s, time remaining 1092 points= 27248 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1746.64 s, time remaining 1091 points= 27223 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1771.62 s, time remaining 1090 points= 27198 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1796.60 s, time remaining 1089 points= 27174 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1821.55 s, time remaining 1088 points= 27149 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1846.52 s, time remaining 1087 points= 27124 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1871.50 s, time remaining 1086 points= 27099 s
# Setting Bfield to 1.41e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1896.46 s, time remaining 1085 points= 27074 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1921.41 s, time remaining 1084 points= 27049 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1946.38 s, time remaining 1083 points= 27025 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1971.36 s, time remaining 1082 points= 27000 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 1996.32 s, time remaining 1081 points= 26975 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2021.28 s, time remaining 1080 points= 26950 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2046.22 s, time remaining 1079 points= 26925 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2071.18 s, time remaining 1078 points= 26900 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2096.13 s, time remaining 1077 points= 26875 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2121.10 s, time remaining 1076 points= 26851 s
# Setting Bfield to 1.42e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2146.08 s, time remaining 1075 points= 26826 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2171.06 s, time remaining 1074 points= 26801 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2196.01 s, time remaining 1073 points= 26776 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2220.98 s, time remaining 1072 points= 26752 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2245.95 s, time remaining 1071 points= 26727 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2270.91 s, time remaining 1070 points= 26702 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2295.87 s, time remaining 1069 points= 26677 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2320.83 s, time remaining 1068 points= 26652 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2345.81 s, time remaining 1067 points= 26627 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2370.77 s, time remaining 1066 points= 26603 s
# Setting Bfield to 1.43e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2395.74 s, time remaining 1065 points= 26578 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2420.70 s, time remaining 1064 points= 26553 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2445.63 s, time remaining 1063 points= 26528 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2470.57 s, time remaining 1062 points= 26503 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2495.55 s, time remaining 1061 points= 26478 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2520.52 s, time remaining 1060 points= 26453 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2545.47 s, time remaining 1059 points= 26428 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2570.44 s, time remaining 1058 points= 26403 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2595.42 s, time remaining 1057 points= 26378 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2620.36 s, time remaining 1056 points= 26353 s
# Setting Bfield to 1.44e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2645.32 s, time remaining 1055 points= 26328 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2670.25 s, time remaining 1054 points= 26303 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2695.21 s, time remaining 1053 points= 26278 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2720.15 s, time remaining 1052 points= 26253 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2745.10 s, time remaining 1051 points= 26228 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2770.04 s, time remaining 1050 points= 26203 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2794.99 s, time remaining 1049 points= 26178 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2819.93 s, time remaining 1048 points= 26153 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2844.89 s, time remaining 1047 points= 26128 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2869.82 s, time remaining 1046 points= 26103 s
# Setting Bfield to 1.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2894.78 s, time remaining 1045 points= 26078 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2919.71 s, time remaining 1044 points= 26053 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2944.65 s, time remaining 1043 points= 26028 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2969.63 s, time remaining 1042 points= 26003 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 2994.58 s, time remaining 1041 points= 25978 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3019.53 s, time remaining 1040 points= 25953 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3044.49 s, time remaining 1039 points= 25928 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3069.44 s, time remaining 1038 points= 25903 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3094.40 s, time remaining 1037 points= 25878 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3119.36 s, time remaining 1036 points= 25853 s
# Setting Bfield to 1.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3144.31 s, time remaining 1035 points= 25828 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3169.25 s, time remaining 1034 points= 25803 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3194.18 s, time remaining 1033 points= 25778 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3219.15 s, time remaining 1032 points= 25753 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3244.12 s, time remaining 1031 points= 25728 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3269.07 s, time remaining 1030 points= 25703 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3294.01 s, time remaining 1029 points= 25678 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3318.99 s, time remaining 1028 points= 25654 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3343.93 s, time remaining 1027 points= 25629 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3368.88 s, time remaining 1026 points= 25603 s
# Setting Bfield to 1.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3393.85 s, time remaining 1025 points= 25579 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3418.80 s, time remaining 1024 points= 25554 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3443.74 s, time remaining 1023 points= 25529 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3468.65 s, time remaining 1022 points= 25503 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3493.58 s, time remaining 1021 points= 25478 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3518.51 s, time remaining 1020 points= 25453 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3543.44 s, time remaining 1019 points= 25428 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3568.37 s, time remaining 1018 points= 25403 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3593.30 s, time remaining 1017 points= 25378 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3618.24 s, time remaining 1016 points= 25353 s
# Setting Bfield to 1.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3643.18 s, time remaining 1015 points= 25328 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3668.12 s, time remaining 1014 points= 25303 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3693.07 s, time remaining 1013 points= 25278 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3718.00 s, time remaining 1012 points= 25252 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3742.93 s, time remaining 1011 points= 25227 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3767.88 s, time remaining 1010 points= 25202 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3792.78 s, time remaining 1009 points= 25177 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3817.71 s, time remaining 1008 points= 25152 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3842.64 s, time remaining 1007 points= 25127 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3867.57 s, time remaining 1006 points= 25102 s
# Setting Bfield to 1.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3892.51 s, time remaining 1005 points= 25077 s
# Setting Bfield to 1.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3917.45 s, time remaining 1004 points= 25052 s
# Setting Bfield to 1.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3942.38 s, time remaining 1003 points= 25027 s
# Setting Bfield to 1.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3967.28 s, time remaining 1002 points= 25001 s
# Setting Bfield to 1.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 3992.20 s, time remaining 1001 points= 24976 s
# Setting Bfield to 1.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 4017.13 s, time remaining 1000 points= 24951 s
# Setting Bfield to 1.50e-03
# finsihed setting Bfield
# ...
# cum time for this point: 27602.11 s, time remaining 54 points= 1346 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27627.04 s, time remaining 53 points= 1322 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27651.98 s, time remaining 52 points= 1297 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27676.91 s, time remaining 51 points= 1272 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27701.85 s, time remaining 50 points= 1247 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27726.79 s, time remaining 49 points= 1222 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27751.68 s, time remaining 48 points= 1197 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27776.63 s, time remaining 47 points= 1172 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27801.56 s, time remaining 46 points= 1147 s
# Setting Bfield to 2.45e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27826.51 s, time remaining 45 points= 1122 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27851.45 s, time remaining 44 points= 1097 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27876.37 s, time remaining 43 points= 1072 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27901.32 s, time remaining 42 points= 1047 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27926.25 s, time remaining 41 points= 1022 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27951.19 s, time remaining 40 points= 997 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 27976.12 s, time remaining 39 points= 972 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28001.04 s, time remaining 38 points= 947 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28025.98 s, time remaining 37 points= 923 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28050.92 s, time remaining 36 points= 898 s
# Setting Bfield to 2.46e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28075.83 s, time remaining 35 points= 873 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28100.76 s, time remaining 34 points= 848 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28125.69 s, time remaining 33 points= 823 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28150.61 s, time remaining 32 points= 798 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28175.52 s, time remaining 31 points= 773 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28200.45 s, time remaining 30 points= 748 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28225.38 s, time remaining 29 points= 723 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28250.31 s, time remaining 28 points= 698 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28275.25 s, time remaining 27 points= 673 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28300.20 s, time remaining 26 points= 648 s
# Setting Bfield to 2.47e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28325.15 s, time remaining 25 points= 623 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28350.08 s, time remaining 24 points= 598 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28374.98 s, time remaining 23 points= 573 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28399.92 s, time remaining 22 points= 549 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28424.83 s, time remaining 21 points= 524 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28449.76 s, time remaining 20 points= 499 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28474.69 s, time remaining 19 points= 474 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28499.63 s, time remaining 18 points= 449 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28524.58 s, time remaining 17 points= 424 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28549.52 s, time remaining 16 points= 399 s
# Setting Bfield to 2.48e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28574.43 s, time remaining 15 points= 374 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28599.36 s, time remaining 14 points= 349 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28624.28 s, time remaining 13 points= 324 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28649.23 s, time remaining 12 points= 299 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28674.17 s, time remaining 11 points= 274 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28699.10 s, time remaining 10 points= 249 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28724.04 s, time remaining 9 points= 224 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28748.96 s, time remaining 8 points= 199 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28773.87 s, time remaining 7 points= 175 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28798.81 s, time remaining 6 points= 150 s
# Setting Bfield to 2.49e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28823.74 s, time remaining 5 points= 125 s
# Setting Bfield to 2.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28848.68 s, time remaining 4 points= 100 s
# Setting Bfield to 2.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28873.62 s, time remaining 3 points= 75 s
# Setting Bfield to 2.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28898.57 s, time remaining 2 points= 50 s
# Setting Bfield to 2.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28923.49 s, time remaining 1 points= 25 s
# Setting Bfield to 2.50e-03
# finsihed setting Bfield
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# cum time for this point: 28948.42 s, time remaining 0 points=  0 s

# %% [markdown]
# ## Sweep of cutter at magnet value

# %%
B_fields = [0.03,0.06,0.09,0.12,0.15,0.18,0.21,0.24,0,0.03,0.06,0.09,0.12,0.15,0.18,0.21,0.24,0]
B_fields = [i * 1e-3 for i in B_fields]
print(B_fields)
set_yoko_field(0)
power=-33
n_avg = 1000
n_pts = 100
for i in range(0,len(B_fields)):
    exp = qc.new_experiment(" B_y=%2.e gate Vbot=2V power=-40-%d dbM navg=%d n_points=%d" %(B_fields[i], power, n_avg, n_pts)  , sample_name="abs_w1_5_1_1")
    gate_channel = mdac.ch01
    gate_voltages = np.linspace(0,3,201)
    gate_name = 'V_cut_A'

    df = 0.0010e9

    Vbots = [2]

    #ramp back to the -4. 
    print("ramping back ")
    #ramp(mdac.ch01.voltage, -4, gate_ramp_stepsize*1.5, gate_ramp_delay/2)
    print("")
    ramp(mdac.ch01.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
    print("")
    
    print("ramping B_field to %.2e" % B_fields[i])
    set_yoko_field(B_fields[i])
    
    #resonator A
    for vBot in Vbots:
        ramp(mdac.ch18.voltage, vBot, gate_ramp_stepsize,gate_ramp_delay)
        f0 = 4.84725e9
        run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                                gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                                gate_ramp_delay = 0.001 , #[s]
                                power=power, n_pts = n_pts f_start = f0-df, f_stop = f0+df, n_avg=n_avg, channel_name='S12')

# %%
set_yoko_field(0.0)

# %%
get_yoko_field()

# %%
ramp(MDAC_channels['V_bot_A'].voltage,2, gate_ramp_stepsize, gate_ramp_delay)
ramp(MDAC_channels['V_cut_A'].voltage,0, gate_ramp_stepsize, gate_ramp_delay)

# %% [markdown]
# # Doing single point sweeps.

# %%
def setup_single_vna_point(frq, npts, power,  chan='S12', span=1, n_avg=10, rf_on = True):
    vna_channel = getattr(vna.channels, chan)
    
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna_channel.center(frq)
    vna_channel.span(span)
    vna_channel.npts(npts)
    vna_channel.avg(n_avg) #todo check which is faster, avg 1 or more points.. #seems like avg is faster
    vna_channel.autoscale()
    if(rf_on):
        vna.rf_on()
    else:
        vna.rf_off()
    
def measure_complex_point_vna(chan='S12'):
    vna_channel = getattr(vna.channels, chan)
    S12 = vna_channel.trace.get()
    
    return np.mean(S12, dtype=complex)

    
def measure_mag_phase_point_vna(chan='S12'):
    vna_channel = getattr(vna.channels, chan)
    mag, phase = vna_channel.trace_mag_phase()
    
    return np.mean(mag), np.mean(phase)

def measure_and_process_point_vna(chan='S12'):
    """
    Measures processes a single point in vna and returns it as qcodes result object
    with param names:
    phase
    mag
    magnitude_dB
    """
    mag, phase = measure_mag_phase_point_vna(chan=channel_name)
    mag_db = 20*np.log10(mag) #convert to dB
    result = [ 
        ('phase', phase),
        ('mag', mag),
        ('magnitude_dB',mag_db )]
    return result


def do_gate_sweep_single_frequency(gate_channel, gate_voltages,gate_name='V_g',
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 100, f = 4.8523e9, n_avg=100, channel_name='S12'):

    """
    performs a gate sweep at a single frequency. Can also sweep multiple parameters settiong the same voltages 
    
    """
    if not isinstance(gate_channel, list):
        gate_channel = [gate_channel] #allow for multple gates to be swept at once. 
        if not isinstance(gate_name, list):
            gate_name = [gate_name]
        else:
            raise Exception('Either give both gate channel and gate name as a list or both as a value..')
    
    #check the gate voltage
    for chan in gate_channel:
        print(chan,chan.voltage())
        
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    print("STARTING TEMPERATURE: %.3f" % temperature)
    
    # let's set the trace properties. 
    setup_single_vna_point( f,n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    long_gate_name = ''
    for name in gate_name:
        long_gate_name += name + '_' #make one variable out of multiple gates snce they are swept together
    
    meas.register_custom_parameter(long_gate_name, unit='V')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=[long_gate_name],
                                   paramtype='numeric')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=[long_gate_name],
                                   paramtype='numeric')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[long_gate_name],
                                   paramtype='numeric')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            result=[]
            
            #ramp the gate voltage
            for i in range(len(gate_channel)):
                print("Ramping %s to %.2e" % (gate_name[i], gate_voltage))
                ramp(gate_channel[i].voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
                print("Done ramping")
            
            result.append((long_gate_name, gate_voltage))
            
            vna_result= measure_and_process_point_vna(chan=channel_name)
            result.extend(vna_result)
            
            result.extend([
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id



def do_field_sweep_single_frequency(B_ys, power=-30, n_pts = 100, f = 4.8523e9, n_avg=100, channel_name='S12'):

    """
    performs a field sweep at a single frequency. Can also sweep multiple parameters settiong the same voltages 
    
    """
   
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    setup_single_vna_point( f,n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    meas.register_custom_parameter('B_y', unit='T', paramtype='numeric')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['B_y'],
                                   paramtype='numeric')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=['B_y'],
                                   paramtype='numeric')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=['B_y'],
                                   paramtype='numeric')
    
    with meas.run() as datasaver:
        for field in B_ys:      
   
            #ramp the field
            print("Setting field to", field)
            set_yoko_field(field)
            
            result= measure_and_process_point_vna(chan=channel_name)
            
            result.extend([
                ('B_y', field),
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id



def do_3D_field_sweep_single_frequency(B_field_mags, phi, theta, power=-30, n_pts = 100, f = 4.8523e9, n_avg=100, channel_name='S12'):

    """
    performs a field sweep at a single frequency.
    But now it sweeps the magnitude of the field at a certain phi and theta
    
    """
   
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    setup_single_vna_point( f,n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    meas.register_custom_parameter('B_field', unit='T', paramtype='numeric')
    meas.register_custom_parameter('B_x', unit='T', paramtype='numeric')
    meas.register_custom_parameter('B_y', unit='T', paramtype='numeric')
    meas.register_custom_parameter('B_z', unit='T', paramtype='numeric')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['B_field'],
                                   paramtype='numeric')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=['B_field'],
                                   paramtype='numeric')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=['B_field'],
                                   paramtype='numeric')
    
    with meas.run() as datasaver:
        for field in B_field_mags:
            
            #ramp the field
            print("Setting field (magntidue) to", field)
            x, y, z = yoko_magnet.transform_spherical_to_cartesian(field, phi=phi, theta=theta)
            print("Setting x, y, z to %.3e, %.3e, %.3e" %(x,y,z))
            yoko_magnet.x(x)
            yoko_magnet.y(y)
            yoko_magnet.z(z)
            
            result= measure_and_process_point_vna(chan=channel_name)
            
            result.extend([
                ('B_field', field),
                ('B_x', x),
                ('B_y', y),
                ('B_z', z),
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id

# %% [markdown]
# ### Quick aquisition test.

# %%
#do a test single point sweep:
f0= 4.84725e9
df=0
npts = 100
power = -33
npts = [100,500,1000,5000,10000]
N_repeats = 100
S12s = np.zeros((len(npts),N_repeats))
S12s_std = np.zeros((len(npts),N_repeats))
ts=  np.zeros((len(npts),N_repeats))

for k in range(0,len(npts)):
    setup_single_vna_point( f0+df,npts[k], -33)
    for i in range(0,100):
        t1 = time.time()
        S12 = measure_complex_point_vna()
        S12s[k,i] = S12
        S12s_std[k,i] = S12_std
        ts[k,i] = time.time() - t1

# %%
plt.figure()
for i in range(len(npts)):
    
    print(np.std(20*np.log10(np.abs(S12s[i,:]))))
    plt.plot(20*np.log10(np.abs(S12s[i,:])), label='%d %.2e pp' % (npts[i], np.mean(ts[i,:])))
plt.xlabel('points')
plt.ylabel('mag (dB)')
plt.legend()
plt.figure()
for i in range(len(npts)):
    print(np.std(np.abs(S12s[i,:])))
    plt.plot(np.abs(S12s[i,:]), label=npts[i])
plt.xlabel('points')
plt.ylabel('mag')
plt.legend()
plt.figure()
for i in range(len(npts)):
    print(np.std(np.angle(S12s[i,:])))
    plt.plot(np.angle(S12s[i,:]), label=npts[i])
plt.xlabel('points')
plt.ylabel('phase')         
plt.legend()

# %% [markdown]
# ## single gate sweep

# %%
power = -33
n_pts = 20000
vBot = 2
f = 4.84725e9
t0 = time.time()

exp = qc.new_experiment("jump %.4e f=%.5e Vbot=%.3fV power=%d n=%d" %(time.time()-t0,f,vBot, power, n_pts)  , sample_name="abs_w1_5_1_1")
gate_channel = mdac.ch01
gate_voltages = np.arange(0,3,0.005)
gate_name = 'V_cut_A'

#set vBot
ramp(mdac.ch18.voltage, vBot, gate_ramp_stepsize,gate_ramp_delay)

#ramp back to the -4. 
print("ramping back ")
ramp(mdac.ch01.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
print("")
#ramp(mdac.ch01.voltage, 1, gate_ramp_stepsize, gate_ramp_delay)
print("")

do_gate_sweep_single_frequency(gate_channel, gate_voltages,gate_name,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, f = f, channel_name='S12')

print(" Time elapsed: %.4f" % (time.time()-t0))

# %%
f = 4.84725e9
run_id = do_single_sweep(n_pts = 500, f_start = f-6e6, f_stop = f+6e6, power=power, n_avg=100, channel_name='S12')
plot_by_id(run_id)
# Out:
# Starting experimental run with id: 12
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# ([<matplotlib.axes._subplots.AxesSubplot at 0x22f85477d68>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f85453828>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f854adb38>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f854da860>],
#  [None, None, None, None])

# %%
f = 4.84725e9
run_id = do_single_sweep(n_pts = 500, f_start = f-6e6, f_stop = f+6e6, power=power, n_avg=100, channel_name='S12')
plot_by_id(run_id)
# Out:
# Starting experimental run with id: 13
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="698">
# ([<matplotlib.axes._subplots.AxesSubplot at 0x22f862360f0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f86249ac8>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f8622b278>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f86293a58>],
#  [None, None, None, None])

# %%
f = 4.84725e9
run_id = do_single_sweep(n_pts = 500, f_start = f-6e6, f_stop = f+6e6, power=power, n_avg=100, channel_name='S12')
plot_by_id(run_id)
# Out:
# Starting experimental run with id: 14
# <img src="data:image/png;base64,..." width="698">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="698">
# ([<matplotlib.axes._subplots.AxesSubplot at 0x22f86f61a20>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f8701f898>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f87002518>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x22f86fa00f0>],
#  [None, None, None, None])

# %% [markdown]
# ## multiple gate 1D sweep

# %%
power = -39
n_pts = 500
n_avg = 500
f = 4.84725e9#5.8865e9#4.8470e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = True

#set_yoko_field(0)

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

gate_channel = [MDAC_channels['V_cut_A'], MDAC_channels['V_bot_A'], MDAC_channels['V_pl_A']]
#gate_channel = [MDAC_channels['V_bot_B'], MDAC_channels['V_pr_B'], MDAC_channels['V_pl_B']]
gate_voltages = np.arange(0,4,0.005)
gate_name = ['V_cut_A', 'V_bot_A', 'V_pl_A']
#gate_name = ['V_bot_B', 'V_pr_B', 'V_pl_B']
if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_name:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=400, channel_name='S12')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_single_frequency(gate_channel, gate_voltages,gate_name,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')

print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# ramping back gates
# Taking single sweep
# Starting experimental run with id: 67
# Taking trace took 24.5494544506073
# <MDACChannel: MDAC_chan1 of MDAC: MDAC> 0.0
# <MDACChannel: MDAC_chan18 of MDAC: MDAC> 0.0
# <MDACChannel: MDAC_chan17 of MDAC: MDAC> 0.0
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# STARTING TEMPERATURE: 0.024
# Starting experimental run with id: 68
# Ramping V_cut_A to 0.00e+00
# Done ramping
# Ramping V_bot_A to 0.00e+00
# Done ramping
# Ramping V_pl_A to 0.00e+00
# Done ramping
# Ramping V_cut_A to 5.00e-03
# Done ramping
# Ramping V_bot_A to 5.00e-03
# Done ramping
# Ramping V_pl_A to 5.00e-03
# Done ramping
# Ramping V_cut_A to 1.00e-02
# Done ramping
# Ramping V_bot_A to 1.00e-02
# Done ramping
# Ramping V_pl_A to 1.00e-02
# Done ramping
# Ramping V_cut_A to 1.50e-02
# Done ramping
# Ramping V_bot_A to 1.50e-02
# Done ramping
# Ramping V_pl_A to 1.50e-02
# Done ramping
# Ramping V_cut_A to 2.00e-02
# Done ramping
# Ramping V_bot_A to 2.00e-02
# Done ramping
# Ramping V_pl_A to 2.00e-02
# Done ramping
# Ramping V_cut_A to 2.50e-02
# Done ramping
# Ramping V_bot_A to 2.50e-02
# Done ramping
# Ramping V_pl_A to 2.50e-02
# Done ramping
# Ramping V_cut_A to 3.00e-02
# Done ramping
# Ramping V_bot_A to 3.00e-02
# Done ramping
# Ramping V_pl_A to 3.00e-02
# Done ramping
# Ramping V_cut_A to 3.50e-02
# Done ramping
# Ramping V_bot_A to 3.50e-02
# Done ramping
# Ramping V_pl_A to 3.50e-02
# Done ramping
# Ramping V_cut_A to 4.00e-02
# Done ramping
# Ramping V_bot_A to 4.00e-02
# Done ramping
# Ramping V_pl_A to 4.00e-02
# Done ramping
# Ramping V_cut_A to 4.50e-02
# Done ramping
# Ramping V_bot_A to 4.50e-02
# Done ramping
# Ramping V_pl_A to 4.50e-02
# Done ramping
# Ramping V_cut_A to 5.00e-02
# Done ramping
# Ramping V_bot_A to 5.00e-02
# Done ramping
# Ramping V_pl_A to 5.00e-02
# Done ramping
# Ramping V_cut_A to 5.50e-02
# Done ramping
# Ramping V_bot_A to 5.50e-02
# Done ramping
# Ramping V_pl_A to 5.50e-02
# Done ramping
# Ramping V_cut_A to 6.00e-02
# Done ramping
# Ramping V_bot_A to 6.00e-02
# Done ramping
# Ramping V_pl_A to 6.00e-02
# Done ramping
# Ramping V_cut_A to 6.50e-02
# Done ramping
# Ramping V_bot_A to 6.50e-02
# Done ramping
# Ramping V_pl_A to 6.50e-02
# Done ramping
# Ramping V_cut_A to 7.00e-02
# Done ramping
# Ramping V_bot_A to 7.00e-02
# Done ramping
# Ramping V_pl_A to 7.00e-02
# Done ramping
# Ramping V_cut_A to 7.50e-02
# Done ramping
# Ramping V_bot_A to 7.50e-02
# Done ramping
# Ramping V_pl_A to 7.50e-02
# Done ramping
# Ramping V_cut_A to 8.00e-02
# Done ramping
# Ramping V_bot_A to 8.00e-02
# Done ramping
# Ramping V_pl_A to 8.00e-02
# Done ramping
# Ramping V_cut_A to 8.50e-02
# Done ramping
# Ramping V_bot_A to 8.50e-02
# Done ramping
# Ramping V_pl_A to 8.50e-02
# Done ramping
# Ramping V_cut_A to 9.00e-02
# Done ramping
# Ramping V_bot_A to 9.00e-02
# Done ramping
# Ramping V_pl_A to 9.00e-02
# Done ramping
# Ramping V_cut_A to 9.50e-02
# Done ramping
# Ramping V_bot_A to 9.50e-02
# Done ramping
# Ramping V_pl_A to 9.50e-02
# Done ramping
# Ramping V_cut_A to 1.00e-01
# Done ramping
# Ramping V_bot_A to 1.00e-01
# Done ramping
# Ramping V_pl_A to 1.00e-01
# Done ramping
# Ramping V_cut_A to 1.05e-01
# Done ramping
# Ramping V_bot_A to 1.05e-01
# Done ramping
# Ramping V_pl_A to 1.05e-01
# Done ramping
# Ramping V_cut_A to 1.10e-01
# Done ramping
# Ramping V_bot_A to 1.10e-01
# Done ramping
# Ramping V_pl_A to 1.10e-01
# Done ramping
# Ramping V_cut_A to 1.15e-01
# Done ramping
# Ramping V_bot_A to 1.15e-01
# Done ramping
# Ramping V_pl_A to 1.15e-01
# Done ramping
# Ramping V_cut_A to 1.20e-01
# Done ramping
# Ramping V_bot_A to 1.20e-01
# Done ramping
# Ramping V_pl_A to 1.20e-01
# Done ramping
# Ramping V_cut_A to 1.25e-01
# Done ramping
# Ramping V_bot_A to 1.25e-01
# Done ramping
# Ramping V_pl_A to 1.25e-01
# Done ramping
# Ramping V_cut_A to 1.30e-01
# Done ramping
# Ramping V_bot_A to 1.30e-01
# Done ramping
# Ramping V_pl_A to 1.30e-01
# Done ramping
# Ramping V_cut_A to 1.35e-01
# Done ramping
# Ramping V_bot_A to 1.35e-01
# Done ramping
# Ramping V_pl_A to 1.35e-01
# Done ramping
# Ramping V_cut_A to 1.40e-01
# Done ramping
# Ramping V_bot_A to 1.40e-01
# Done ramping
# Ramping V_pl_A to 1.40e-01
# Done ramping
# Ramping V_cut_A to 1.45e-01
# Done ramping
# Ramping V_bot_A to 1.45e-01
# Done ramping
# Ramping V_pl_A to 1.45e-01
# Done ramping
# Ramping V_cut_A to 1.50e-01
# Done ramping
# Ramping V_bot_A to 1.50e-01
# Done ramping
# Ramping V_pl_A to 1.50e-01
# Done ramping
# Ramping V_cut_A to 1.55e-01
# Done ramping
# Ramping V_bot_A to 1.55e-01
# Done ramping
# Ramping V_pl_A to 1.55e-01
# Done ramping
# Ramping V_cut_A to 1.60e-01
# Done ramping
# Ramping V_bot_A to 1.60e-01
# Done ramping
# Ramping V_pl_A to 1.60e-01
# Done ramping
# Ramping V_cut_A to 1.65e-01
# Done ramping
# Ramping V_bot_A to 1.65e-01
# Done ramping
# Ramping V_pl_A to 1.65e-01
# Done ramping
# Ramping V_cut_A to 1.70e-01
# Done ramping
# Ramping V_bot_A to 1.70e-01
# Done ramping
# Ramping V_pl_A to 1.70e-01
# Done ramping
# Ramping V_cut_A to 1.75e-01
# Done ramping
# Ramping V_bot_A to 1.75e-01
# Done ramping
# Ramping V_pl_A to 1.75e-01
# Done ramping
# Ramping V_cut_A to 1.80e-01
# Done ramping
# Ramping V_bot_A to 1.80e-01
# Done ramping
# Ramping V_pl_A to 1.80e-01
# Done ramping
# Ramping V_cut_A to 1.85e-01
# Done ramping
# Ramping V_bot_A to 1.85e-01
# Done ramping
# Ramping V_pl_A to 1.85e-01
# Done ramping
# Ramping V_cut_A to 1.90e-01
# Done ramping
# Ramping V_bot_A to 1.90e-01
# Done ramping
# Ramping V_pl_A to 1.90e-01
# Done ramping
# Ramping V_cut_A to 1.95e-01
# Done ramping
# Ramping V_bot_A to 1.95e-01
# Done ramping
# Ramping V_pl_A to 1.95e-01
# Done ramping
# Ramping V_cut_A to 2.00e-01
# Done ramping
# Ramping V_bot_A to 2.00e-01
# Done ramping
# Ramping V_pl_A to 2.00e-01
# Done ramping
# Ramping V_cut_A to 2.05e-01
# Done ramping
# Ramping V_bot_A to 2.05e-01
# Done ramping
# Ramping V_pl_A to 2.05e-01
# Done ramping
# Ramping V_cut_A to 2.10e-01
# Done ramping
# Ramping V_bot_A to 2.10e-01
# Done ramping
# Ramping V_pl_A to 2.10e-01
# Done ramping
# Ramping V_cut_A to 2.15e-01
# Done ramping
# Ramping V_bot_A to 2.15e-01
# Done ramping
# Ramping V_pl_A to 2.15e-01
# Done ramping
# Ramping V_cut_A to 2.20e-01
# Done ramping
# Ramping V_bot_A to 2.20e-01
# Done ramping
# Ramping V_pl_A to 2.20e-01
# Done ramping
# Ramping V_cut_A to 2.25e-01
# Done ramping
# Ramping V_bot_A to 2.25e-01
# Done ramping
# Ramping V_pl_A to 2.25e-01
# Done ramping
# Ramping V_cut_A to 2.30e-01
# Done ramping
# Ramping V_bot_A to 2.30e-01
# Done ramping
# Ramping V_pl_A to 2.30e-01
# Done ramping
# Ramping V_cut_A to 2.35e-01
# Done ramping
# Ramping V_bot_A to 2.35e-01
# Done ramping
# Ramping V_pl_A to 2.35e-01
# Done ramping
# Ramping V_cut_A to 2.40e-01
# Done ramping
# Ramping V_bot_A to 2.40e-01
# Done ramping
# Ramping V_pl_A to 2.40e-01
# Done ramping
# Ramping V_cut_A to 2.45e-01
# Done ramping
# Ramping V_bot_A to 2.45e-01
# Done ramping
# Ramping V_pl_A to 2.45e-01
# Done ramping
# Ramping V_cut_A to 2.50e-01
# Done ramping
# Ramping V_bot_A to 2.50e-01
# Done ramping
# Ramping V_pl_A to 2.50e-01
# Done ramping
# Ramping V_cut_A to 2.55e-01
# Done ramping
# Ramping V_bot_A to 2.55e-01
# Done ramping
# Ramping V_pl_A to 2.55e-01
# Done ramping
# Ramping V_cut_A to 2.60e-01
# Done ramping
# Ramping V_bot_A to 2.60e-01
# Done ramping
# Ramping V_pl_A to 2.60e-01
# Done ramping
# Ramping V_cut_A to 2.65e-01
# Done ramping
# Ramping V_bot_A to 2.65e-01
# Done ramping
# Ramping V_pl_A to 2.65e-01
# Done ramping
# Ramping V_cut_A to 2.70e-01
# Done ramping
# Ramping V_bot_A to 2.70e-01
# Done ramping
# Ramping V_pl_A to 2.70e-01
# Done ramping
# Ramping V_cut_A to 2.75e-01
# Done ramping
# Ramping V_bot_A to 2.75e-01
# Done ramping
# Ramping V_pl_A to 2.75e-01
# Done ramping
# Ramping V_cut_A to 2.80e-01
# Done ramping
# Ramping V_bot_A to 2.80e-01
# Done ramping
# Ramping V_pl_A to 2.80e-01
# Done ramping
# Ramping V_cut_A to 2.85e-01
# Done ramping
# Ramping V_bot_A to 2.85e-01
# Done ramping
# Ramping V_pl_A to 2.85e-01
# Done ramping
# Ramping V_cut_A to 2.90e-01
# Done ramping
# Ramping V_bot_A to 2.90e-01
# Done ramping
# Ramping V_pl_A to 2.90e-01
# Done ramping
# Ramping V_cut_A to 2.95e-01
# Done ramping
# Ramping V_bot_A to 2.95e-01
# Done ramping
# Ramping V_pl_A to 2.95e-01
# Done ramping
# Ramping V_cut_A to 3.00e-01
# Done ramping
# Ramping V_bot_A to 3.00e-01
# Done ramping
# Ramping V_pl_A to 3.00e-01
# Done ramping
# Ramping V_cut_A to 3.05e-01
# Done ramping
# Ramping V_bot_A to 3.05e-01
# Done ramping
# Ramping V_pl_A to 3.05e-01
# Done ramping
# Ramping V_cut_A to 3.10e-01
# Done ramping
# Ramping V_bot_A to 3.10e-01
# Done ramping
# Ramping V_pl_A to 3.10e-01
# Done ramping
# Ramping V_cut_A to 3.15e-01
# Done ramping
# Ramping V_bot_A to 3.15e-01
# Done ramping
# Ramping V_pl_A to 3.15e-01
# Done ramping
# Ramping V_cut_A to 3.20e-01
# Done ramping
# Ramping V_bot_A to 3.20e-01
# Done ramping
# Ramping V_pl_A to 3.20e-01
# Done ramping
# Ramping V_cut_A to 3.25e-01
# Done ramping
# Ramping V_bot_A to 3.25e-01
# Done ramping
# Ramping V_pl_A to 3.25e-01
# Done ramping
# Ramping V_cut_A to 3.30e-01
# Done ramping
# Ramping V_bot_A to 3.30e-01
# Done ramping
# Ramping V_pl_A to 3.30e-01
# Done ramping
# Ramping V_cut_A to 3.35e-01
# Done ramping
# Ramping V_bot_A to 3.35e-01
# Done ramping
# Ramping V_pl_A to 3.35e-01
# Done ramping
# Ramping V_cut_A to 3.40e-01
# Done ramping
# Ramping V_bot_A to 3.40e-01
# Done ramping
# Ramping V_pl_A to 3.40e-01
# Done ramping
# Ramping V_cut_A to 3.45e-01
# Done ramping
# Ramping V_bot_A to 3.45e-01
# Done ramping
# Ramping V_pl_A to 3.45e-01
# Done ramping
# Ramping V_cut_A to 3.50e-01
# Done ramping
# Ramping V_bot_A to 3.50e-01
# Done ramping
# Ramping V_pl_A to 3.50e-01
# Done ramping
# Ramping V_cut_A to 3.55e-01
# Done ramping
# Ramping V_bot_A to 3.55e-01
# Done ramping
# Ramping V_pl_A to 3.55e-01
# Done ramping
# Ramping V_cut_A to 3.60e-01
# Done ramping
# Ramping V_bot_A to 3.60e-01
# Done ramping
# Ramping V_pl_A to 3.60e-01
# Done ramping
# Ramping V_cut_A to 3.65e-01
# Done ramping
# Ramping V_bot_A to 3.65e-01
# Done ramping
# Ramping V_pl_A to 3.65e-01
# Done ramping
# Ramping V_cut_A to 3.70e-01
# Done ramping
# Ramping V_bot_A to 3.70e-01
# Done ramping
# Ramping V_pl_A to 3.70e-01
# Done ramping
# Ramping V_cut_A to 3.75e-01
# Done ramping
# Ramping V_bot_A to 3.75e-01
# Done ramping
# Ramping V_pl_A to 3.75e-01
# Done ramping
# Ramping V_cut_A to 3.80e-01
# Done ramping
# Ramping V_bot_A to 3.80e-01
# Done ramping
# Ramping V_pl_A to 3.80e-01
# Done ramping
# Ramping V_cut_A to 3.85e-01
# Done ramping
# Ramping V_bot_A to 3.85e-01
# Done ramping
# Ramping V_pl_A to 3.85e-01
# Done ramping
# Ramping V_cut_A to 3.90e-01
# Done ramping
# Ramping V_bot_A to 3.90e-01
# Done ramping
# Ramping V_pl_A to 3.90e-01
# Done ramping
# Ramping V_cut_A to 3.95e-01
# Done ramping
# Ramping V_bot_A to 3.95e-01
# Done ramping
# Ramping V_pl_A to 3.95e-01
# Done ramping
# Ramping V_cut_A to 4.00e-01
# Done ramping
# Ramping V_bot_A to 4.00e-01
# Done ramping
# Ramping V_pl_A to 4.00e-01
# Done ramping
# Ramping V_cut_A to 4.05e-01
# Done ramping
# Ramping V_bot_A to 4.05e-01
# Done ramping
# Ramping V_pl_A to 4.05e-01
# Done ramping
# Ramping V_cut_A to 4.10e-01
# Done ramping
# Ramping V_bot_A to 4.10e-01
# Done ramping
# Ramping V_pl_A to 4.10e-01
# Done ramping
# Ramping V_cut_A to 4.15e-01
# Done ramping
# Ramping V_bot_A to 4.15e-01
# Done ramping
# Ramping V_pl_A to 4.15e-01
# Done ramping
# Ramping V_cut_A to 4.20e-01
# Done ramping
# Ramping V_bot_A to 4.20e-01
# Done ramping
# Ramping V_pl_A to 4.20e-01
# Done ramping
# Ramping V_cut_A to 4.25e-01
# Done ramping
# Ramping V_bot_A to 4.25e-01
# Done ramping
# Ramping V_pl_A to 4.25e-01
# Done ramping
# Ramping V_cut_A to 4.30e-01
# Done ramping
# Ramping V_bot_A to 4.30e-01
# Done ramping
# Ramping V_pl_A to 4.30e-01
# Done ramping
# Ramping V_cut_A to 4.35e-01
# Done ramping
# Ramping V_bot_A to 4.35e-01
# Done ramping
# Ramping V_pl_A to 4.35e-01
# Done ramping
# Ramping V_cut_A to 4.40e-01
# Done ramping
# Ramping V_bot_A to 4.40e-01
# Done ramping
# Ramping V_pl_A to 4.40e-01
# Done ramping
# Ramping V_cut_A to 4.45e-01
# Done ramping
# Ramping V_bot_A to 4.45e-01
# Done ramping
# Ramping V_pl_A to 4.45e-01
# Done ramping
# Ramping V_cut_A to 4.50e-01
# Done ramping
# Ramping V_bot_A to 4.50e-01
# Done ramping
# Ramping V_pl_A to 4.50e-01
# Done ramping
# Ramping V_cut_A to 4.55e-01
# Done ramping
# Ramping V_bot_A to 4.55e-01
# Done ramping
# Ramping V_pl_A to 4.55e-01
# Done ramping
# Ramping V_cut_A to 4.60e-01
# Done ramping
# Ramping V_bot_A to 4.60e-01
# Done ramping
# Ramping V_pl_A to 4.60e-01
# Done ramping
# Ramping V_cut_A to 4.65e-01
# Done ramping
# Ramping V_bot_A to 4.65e-01
# Done ramping
# Ramping V_pl_A to 4.65e-01
# Done ramping
# Ramping V_cut_A to 4.70e-01
# Done ramping
# Ramping V_bot_A to 4.70e-01
# Done ramping
# Ramping V_pl_A to 4.70e-01
# Done ramping
# Ramping V_cut_A to 4.75e-01
# Done ramping
# Ramping V_bot_A to 4.75e-01
# Done ramping
# Ramping V_pl_A to 4.75e-01
# Done ramping
# Ramping V_cut_A to 4.80e-01
# Done ramping
# Ramping V_bot_A to 4.80e-01
# Done ramping
# Ramping V_pl_A to 4.80e-01
# Done ramping
# Ramping V_cut_A to 4.85e-01
# Done ramping
# Ramping V_bot_A to 4.85e-01
# Done ramping
# Ramping V_pl_A to 4.85e-01
# Done ramping
# Ramping V_cut_A to 4.90e-01
# Done ramping
# Ramping V_bot_A to 4.90e-01
# Done ramping
# Ramping V_pl_A to 4.90e-01
# Done ramping
# Ramping V_cut_A to 4.95e-01
# Done ramping
# Ramping V_bot_A to 4.95e-01
# Done ramping
# Ramping V_pl_A to 4.95e-01
# Done ramping
# Ramping V_cut_A to 5.00e-01
# Done ramping
# Ramping V_bot_A to 5.00e-01
# Done ramping
# Ramping V_pl_A to 5.00e-01
# Done ramping
# Ramping V_cut_A to 5.05e-01
# Done ramping
# Ramping V_bot_A to 5.05e-01
# Done ramping
# Ramping V_pl_A to 5.05e-01
# Done ramping
# Ramping V_cut_A to 5.10e-01
# Done ramping
# Ramping V_bot_A to 5.10e-01
# Done ramping
# Ramping V_pl_A to 5.10e-01
# Done ramping
# Ramping V_cut_A to 5.15e-01
# Done ramping
# Ramping V_bot_A to 5.15e-01
# Done ramping
# Ramping V_pl_A to 5.15e-01
# Done ramping
# Ramping V_cut_A to 5.20e-01
# Done ramping
# Ramping V_bot_A to 5.20e-01
# Done ramping
# Ramping V_pl_A to 5.20e-01
# Done ramping
# Ramping V_cut_A to 5.25e-01
# Done ramping
# Ramping V_bot_A to 5.25e-01
# Done ramping
# Ramping V_pl_A to 5.25e-01
# Done ramping
# Ramping V_cut_A to 5.30e-01
# Done ramping
# Ramping V_bot_A to 5.30e-01
# Done ramping
# Ramping V_pl_A to 5.30e-01
# Done ramping
# Ramping V_cut_A to 5.35e-01
# Done ramping
# Ramping V_bot_A to 5.35e-01
# Done ramping
# Ramping V_pl_A to 5.35e-01
# Done ramping
# Ramping V_cut_A to 5.40e-01
# Done ramping
# Ramping V_bot_A to 5.40e-01
# Done ramping
# Ramping V_pl_A to 5.40e-01
# Done ramping
# Ramping V_cut_A to 5.45e-01
# Done ramping
# Ramping V_bot_A to 5.45e-01
# Done ramping
# Ramping V_pl_A to 5.45e-01
# Done ramping
# Ramping V_cut_A to 5.50e-01
# Done ramping
# Ramping V_bot_A to 5.50e-01
# Done ramping
# Ramping V_pl_A to 5.50e-01
# Done ramping
# Ramping V_cut_A to 5.55e-01
# Done ramping
# Ramping V_bot_A to 5.55e-01
# Done ramping
# Ramping V_pl_A to 5.55e-01
# Done ramping
# Ramping V_cut_A to 5.60e-01
# Done ramping
# Ramping V_bot_A to 5.60e-01
# Done ramping
# Ramping V_pl_A to 5.60e-01
# Done ramping
# Ramping V_cut_A to 5.65e-01
# Done ramping
# Ramping V_bot_A to 5.65e-01
# Done ramping
# Ramping V_pl_A to 5.65e-01
# Done ramping
# Ramping V_cut_A to 5.70e-01
# Done ramping
# Ramping V_bot_A to 5.70e-01
# Done ramping
# Ramping V_pl_A to 5.70e-01
# Done ramping
# Ramping V_cut_A to 5.75e-01
# Done ramping
# Ramping V_bot_A to 5.75e-01
# Done ramping
# Ramping V_pl_A to 5.75e-01
# Done ramping
# Ramping V_cut_A to 5.80e-01
# Done ramping
# Ramping V_bot_A to 5.80e-01
# Done ramping
# Ramping V_pl_A to 5.80e-01
# Done ramping
# Ramping V_cut_A to 5.85e-01
# Done ramping
# Ramping V_bot_A to 5.85e-01
# Done ramping
# Ramping V_pl_A to 5.85e-01
# Done ramping
# Ramping V_cut_A to 5.90e-01
# Done ramping
# Ramping V_bot_A to 5.90e-01
# Done ramping
# Ramping V_pl_A to 5.90e-01
# Done ramping
# Ramping V_cut_A to 5.95e-01
# Done ramping
# Ramping V_bot_A to 5.95e-01
# Done ramping
# Ramping V_pl_A to 5.95e-01
# Done ramping
# Ramping V_cut_A to 6.00e-01
# Done ramping
# Ramping V_bot_A to 6.00e-01
# Done ramping
# Ramping V_pl_A to 6.00e-01
# Done ramping
# Ramping V_cut_A to 6.05e-01
# Done ramping
# Ramping V_bot_A to 6.05e-01
# Done ramping
# Ramping V_pl_A to 6.05e-01
# Done ramping
# Ramping V_cut_A to 6.10e-01
# Done ramping
# Ramping V_bot_A to 6.10e-01
# Done ramping
# Ramping V_pl_A to 6.10e-01
# Done ramping
# Ramping V_cut_A to 6.15e-01
# Done ramping
# Ramping V_bot_A to 6.15e-01
# Done ramping
# Ramping V_pl_A to 6.15e-01
# Done ramping
# Ramping V_cut_A to 6.20e-01
# Done ramping
# Ramping V_bot_A to 6.20e-01
# Done ramping
# Ramping V_pl_A to 6.20e-01
# Done ramping
# Ramping V_cut_A to 6.25e-01
# Done ramping
# Ramping V_bot_A to 6.25e-01
# Done ramping
# Ramping V_pl_A to 6.25e-01
# Done ramping
# Ramping V_cut_A to 6.30e-01
# Done ramping
# Ramping V_bot_A to 6.30e-01
# Done ramping
# Ramping V_pl_A to 6.30e-01
# Done ramping
# Ramping V_cut_A to 6.35e-01
# Done ramping
# Ramping V_bot_A to 6.35e-01
# Done ramping
# Ramping V_pl_A to 6.35e-01
# Done ramping
# Ramping V_cut_A to 6.40e-01
# Done ramping
# Ramping V_bot_A to 6.40e-01
# Done ramping
# Ramping V_pl_A to 6.40e-01
# Done ramping
# Ramping V_cut_A to 6.45e-01
# Done ramping
# Ramping V_bot_A to 6.45e-01
# Done ramping
# Ramping V_pl_A to 6.45e-01
# Done ramping
# Ramping V_cut_A to 6.50e-01
# Done ramping
# Ramping V_bot_A to 6.50e-01
# Done ramping
# Ramping V_pl_A to 6.50e-01
# Done ramping
# Ramping V_cut_A to 6.55e-01
# Done ramping
# Ramping V_bot_A to 6.55e-01
# Done ramping
# Ramping V_pl_A to 6.55e-01
# Done ramping
# Ramping V_cut_A to 6.60e-01
# Done ramping
# Ramping V_bot_A to 6.60e-01
# Done ramping
# Ramping V_pl_A to 6.60e-01
# Done ramping
# Ramping V_cut_A to 6.65e-01
# Done ramping
# Ramping V_bot_A to 6.65e-01
# Done ramping
# Ramping V_pl_A to 6.65e-01
# Done ramping
# Ramping V_cut_A to 6.70e-01
# Done ramping
# Ramping V_bot_A to 6.70e-01
# Done ramping
# Ramping V_pl_A to 6.70e-01
# Done ramping
# Ramping V_cut_A to 6.75e-01
# Done ramping
# Ramping V_bot_A to 6.75e-01
# Done ramping
# Ramping V_pl_A to 6.75e-01
# Done ramping
# Ramping V_cut_A to 6.80e-01
# Done ramping
# Ramping V_bot_A to 6.80e-01
# Done ramping
# Ramping V_pl_A to 6.80e-01
# Done ramping
# Ramping V_cut_A to 6.85e-01
# Done ramping
# Ramping V_bot_A to 6.85e-01
# Done ramping
# Ramping V_pl_A to 6.85e-01
# Done ramping
# Ramping V_cut_A to 6.90e-01
# Done ramping
# Ramping V_bot_A to 6.90e-01
# Done ramping
# Ramping V_pl_A to 6.90e-01
# Done ramping
# Ramping V_cut_A to 6.95e-01
# Done ramping
# Ramping V_bot_A to 6.95e-01
# Done ramping
# Ramping V_pl_A to 6.95e-01
# Done ramping
# Ramping V_cut_A to 7.00e-01
# Done ramping
# Ramping V_bot_A to 7.00e-01
# Done ramping
# Ramping V_pl_A to 7.00e-01
# Done ramping
# Ramping V_cut_A to 7.05e-01
# Done ramping
# Ramping V_bot_A to 7.05e-01
# Done ramping
# Ramping V_pl_A to 7.05e-01
# Done ramping
# Ramping V_cut_A to 7.10e-01
# Done ramping
# Ramping V_bot_A to 7.10e-01
# Done ramping
# Ramping V_pl_A to 7.10e-01
# Done ramping
# Ramping V_cut_A to 7.15e-01
# Done ramping
# Ramping V_bot_A to 7.15e-01
# Done ramping
# Ramping V_pl_A to 7.15e-01
# Done ramping
# Ramping V_cut_A to 7.20e-01
# Done ramping
# Ramping V_bot_A to 7.20e-01
# Done ramping
# Ramping V_pl_A to 7.20e-01
# Done ramping
# Ramping V_cut_A to 7.25e-01
# Done ramping
# Ramping V_bot_A to 7.25e-01
# Done ramping
# Ramping V_pl_A to 7.25e-01
# Done ramping
# Ramping V_cut_A to 7.30e-01
# Done ramping
# Ramping V_bot_A to 7.30e-01
# Done ramping
# Ramping V_pl_A to 7.30e-01
# Done ramping
# Ramping V_cut_A to 7.35e-01
# Done ramping
# Ramping V_bot_A to 7.35e-01
# Done ramping
# Ramping V_pl_A to 7.35e-01
# Done ramping
# Ramping V_cut_A to 7.40e-01
# Done ramping
# Ramping V_bot_A to 7.40e-01
# Done ramping
# Ramping V_pl_A to 7.40e-01
# Done ramping
# Ramping V_cut_A to 7.45e-01
# Done ramping
# Ramping V_bot_A to 7.45e-01
# Done ramping
# Ramping V_pl_A to 7.45e-01
# Done ramping
# Ramping V_cut_A to 7.50e-01
# Done ramping
# Ramping V_bot_A to 7.50e-01
# Done ramping
# Ramping V_pl_A to 7.50e-01
# Done ramping
# Ramping V_cut_A to 7.55e-01
# Done ramping
# Ramping V_bot_A to 7.55e-01
# Done ramping
# Ramping V_pl_A to 7.55e-01
# Done ramping
# Ramping V_cut_A to 7.60e-01
# Done ramping
# Ramping V_bot_A to 7.60e-01
# Done ramping
# Ramping V_pl_A to 7.60e-01
# Done ramping
# Ramping V_cut_A to 7.65e-01
# Done ramping
# Ramping V_bot_A to 7.65e-01
# Done ramping
# Ramping V_pl_A to 7.65e-01
# Done ramping
# Ramping V_cut_A to 7.70e-01
# Done ramping
# Ramping V_bot_A to 7.70e-01
# Done ramping
# Ramping V_pl_A to 7.70e-01
# Done ramping
# Ramping V_cut_A to 7.75e-01
# Done ramping
# Ramping V_bot_A to 7.75e-01
# Done ramping
# Ramping V_pl_A to 7.75e-01
# Done ramping
# Ramping V_cut_A to 7.80e-01
# Done ramping
# Ramping V_bot_A to 7.80e-01
# Done ramping
# Ramping V_pl_A to 7.80e-01
# Done ramping
# Ramping V_cut_A to 7.85e-01
# Done ramping
# Ramping V_bot_A to 7.85e-01
# Done ramping
# Ramping V_pl_A to 7.85e-01
# Done ramping
# Ramping V_cut_A to 7.90e-01
# Done ramping
# Ramping V_bot_A to 7.90e-01
# Done ramping
# Ramping V_pl_A to 7.90e-01
# Done ramping
# Ramping V_cut_A to 7.95e-01
# Done ramping
# Ramping V_bot_A to 7.95e-01
# Done ramping
# Ramping V_pl_A to 7.95e-01
# Done ramping
# Ramping V_cut_A to 8.00e-01
# Done ramping
# Ramping V_bot_A to 8.00e-01
# Done ramping
# Ramping V_pl_A to 8.00e-01
# Done ramping
# Ramping V_cut_A to 8.05e-01
# Done ramping
# Ramping V_bot_A to 8.05e-01
# Done ramping
# Ramping V_pl_A to 8.05e-01
# Done ramping
# Ramping V_cut_A to 8.10e-01
# Done ramping
# Ramping V_bot_A to 8.10e-01
# Done ramping
# Ramping V_pl_A to 8.10e-01
# Done ramping
# Ramping V_cut_A to 8.15e-01
# Done ramping
# Ramping V_bot_A to 8.15e-01
# Done ramping
# Ramping V_pl_A to 8.15e-01
# Done ramping
# Ramping V_cut_A to 8.20e-01
# Done ramping
# Ramping V_bot_A to 8.20e-01
# Done ramping
# Ramping V_pl_A to 8.20e-01
# Done ramping
# Ramping V_cut_A to 8.25e-01
# Done ramping
# Ramping V_bot_A to 8.25e-01
# Done ramping
# Ramping V_pl_A to 8.25e-01
# Done ramping
# Ramping V_cut_A to 8.30e-01
# Done ramping
# Ramping V_bot_A to 8.30e-01
# Done ramping
# Ramping V_pl_A to 8.30e-01
# Done ramping
# Ramping V_cut_A to 8.35e-01
# Done ramping
# Ramping V_bot_A to 8.35e-01
# Done ramping
# Ramping V_pl_A to 8.35e-01
# Done ramping
# Ramping V_cut_A to 8.40e-01
# Done ramping
# Ramping V_bot_A to 8.40e-01
# Done ramping
# Ramping V_pl_A to 8.40e-01
# Done ramping
# Ramping V_cut_A to 8.45e-01
# Done ramping
# Ramping V_bot_A to 8.45e-01
# Done ramping
# Ramping V_pl_A to 8.45e-01
# Done ramping
# Ramping V_cut_A to 8.50e-01
# Done ramping
# Ramping V_bot_A to 8.50e-01
# Done ramping
# Ramping V_pl_A to 8.50e-01
# Done ramping
# Ramping V_cut_A to 8.55e-01
# Done ramping
# Ramping V_bot_A to 8.55e-01
# Done ramping
# Ramping V_pl_A to 8.55e-01
# Done ramping
# Ramping V_cut_A to 8.60e-01
# Done ramping
# Ramping V_bot_A to 8.60e-01
# Done ramping
# Ramping V_pl_A to 8.60e-01
# Done ramping
# Ramping V_cut_A to 8.65e-01
# Done ramping
# Ramping V_bot_A to 8.65e-01
# Done ramping
# Ramping V_pl_A to 8.65e-01
# Done ramping
# Ramping V_cut_A to 8.70e-01
# Done ramping
# Ramping V_bot_A to 8.70e-01
# Done ramping
# Ramping V_pl_A to 8.70e-01
# Done ramping
# Ramping V_cut_A to 8.75e-01
# Done ramping
# Ramping V_bot_A to 8.75e-01
# Done ramping
# Ramping V_pl_A to 8.75e-01
# Done ramping
# Ramping V_cut_A to 8.80e-01
# Done ramping
# Ramping V_bot_A to 8.80e-01
# Done ramping
# Ramping V_pl_A to 8.80e-01
# Done ramping
# Ramping V_cut_A to 8.85e-01
# Done ramping
# Ramping V_bot_A to 8.85e-01
# Done ramping
# Ramping V_pl_A to 8.85e-01
# Done ramping
# Ramping V_cut_A to 8.90e-01
# Done ramping
# Ramping V_bot_A to 8.90e-01
# Done ramping
# Ramping V_pl_A to 8.90e-01
# Done ramping
# Ramping V_cut_A to 8.95e-01
# Done ramping
# Ramping V_bot_A to 8.95e-01
# Done ramping
# Ramping V_pl_A to 8.95e-01
# Done ramping
# Ramping V_cut_A to 9.00e-01
# Done ramping
# Ramping V_bot_A to 9.00e-01
# Done ramping
# Ramping V_pl_A to 9.00e-01
# Done ramping
# Ramping V_cut_A to 9.05e-01
# Done ramping
# Ramping V_bot_A to 9.05e-01
# Done ramping
# Ramping V_pl_A to 9.05e-01
# Done ramping
# Ramping V_cut_A to 9.10e-01
# Done ramping
# Ramping V_bot_A to 9.10e-01
# Done ramping
# Ramping V_pl_A to 9.10e-01
# Done ramping
# Ramping V_cut_A to 9.15e-01
# Done ramping
# Ramping V_bot_A to 9.15e-01
# Done ramping
# Ramping V_pl_A to 9.15e-01
# Done ramping
# Ramping V_cut_A to 9.20e-01
# Done ramping
# Ramping V_bot_A to 9.20e-01
# Done ramping
# Ramping V_pl_A to 9.20e-01
# Done ramping
# Ramping V_cut_A to 9.25e-01
# Done ramping
# Ramping V_bot_A to 9.25e-01
# Done ramping
# Ramping V_pl_A to 9.25e-01
# Done ramping
# Ramping V_cut_A to 9.30e-01
# Done ramping
# Ramping V_bot_A to 9.30e-01
# Done ramping
# Ramping V_pl_A to 9.30e-01
# Done ramping
# Ramping V_cut_A to 9.35e-01
# Done ramping
# Ramping V_bot_A to 9.35e-01
# Done ramping
# Ramping V_pl_A to 9.35e-01
# Done ramping
# Ramping V_cut_A to 9.40e-01
# Done ramping
# Ramping V_bot_A to 9.40e-01
# Done ramping
# Ramping V_pl_A to 9.40e-01
# Done ramping
# Ramping V_cut_A to 9.45e-01
# Done ramping
# Ramping V_bot_A to 9.45e-01
# Done ramping
# Ramping V_pl_A to 9.45e-01
# Done ramping
# Ramping V_cut_A to 9.50e-01
# Done ramping
# Ramping V_bot_A to 9.50e-01
# Done ramping
# Ramping V_pl_A to 9.50e-01
# Done ramping
# Ramping V_cut_A to 9.55e-01
# Done ramping
# Ramping V_bot_A to 9.55e-01
# Done ramping
# Ramping V_pl_A to 9.55e-01
# Done ramping
# Ramping V_cut_A to 9.60e-01
# Done ramping
# Ramping V_bot_A to 9.60e-01
# Done ramping
# Ramping V_pl_A to 9.60e-01
# Done ramping
# Ramping V_cut_A to 9.65e-01
# Done ramping
# Ramping V_bot_A to 9.65e-01
# Done ramping
# Ramping V_pl_A to 9.65e-01
# Done ramping
# Ramping V_cut_A to 9.70e-01
# Done ramping
# Ramping V_bot_A to 9.70e-01
# Done ramping
# Ramping V_pl_A to 9.70e-01
# Done ramping
# Ramping V_cut_A to 9.75e-01
# Done ramping
# Ramping V_bot_A to 9.75e-01
# Done ramping
# Ramping V_pl_A to 9.75e-01
# Done ramping
# Ramping V_cut_A to 9.80e-01
# Done ramping
# Ramping V_bot_A to 9.80e-01
# Done ramping
# Ramping V_pl_A to 9.80e-01
# Done ramping
# Ramping V_cut_A to 9.85e-01
# Done ramping
# Ramping V_bot_A to 9.85e-01
# Done ramping
# Ramping V_pl_A to 9.85e-01
# Done ramping
# Ramping V_cut_A to 9.90e-01
# Done ramping
# Ramping V_bot_A to 9.90e-01
# Done ramping
# Ramping V_pl_A to 9.90e-01
# Done ramping
# Ramping V_cut_A to 9.95e-01
# Done ramping
# Ramping V_bot_A to 9.95e-01
# Done ramping
# Ramping V_pl_A to 9.95e-01
# Done ramping
# Ramping V_cut_A to 1.00e+00
# Done ramping
# Ramping V_bot_A to 1.00e+00
# Done ramping
# Ramping V_pl_A to 1.00e+00
# Done ramping
# Ramping V_cut_A to 1.01e+00
# Done ramping
# Ramping V_bot_A to 1.01e+00
# Done ramping
# Ramping V_pl_A to 1.01e+00
# Done ramping
# Ramping V_cut_A to 1.01e+00
# Done ramping
# Ramping V_bot_A to 1.01e+00
# Done ramping
# Ramping V_pl_A to 1.01e+00
# Done ramping
# Ramping V_cut_A to 1.02e+00
# Done ramping
# Ramping V_bot_A to 1.02e+00
# Done ramping
# Ramping V_pl_A to 1.02e+00
# Done ramping
# Ramping V_cut_A to 1.02e+00
# Done ramping
# Ramping V_bot_A to 1.02e+00
# Done ramping
# Ramping V_pl_A to 1.02e+00
# Done ramping
# Ramping V_cut_A to 1.02e+00
# Done ramping
# Ramping V_bot_A to 1.02e+00
# Done ramping
# Ramping V_pl_A to 1.02e+00
# Done ramping
# Ramping V_cut_A to 1.03e+00
# Done ramping
# Ramping V_bot_A to 1.03e+00
# Done ramping
# Ramping V_pl_A to 1.03e+00
# Done ramping
# Ramping V_cut_A to 1.03e+00
# Done ramping
# Ramping V_bot_A to 1.03e+00
# Done ramping
# Ramping V_pl_A to 1.03e+00
# Done ramping
# Ramping V_cut_A to 1.04e+00
# Done ramping
# Ramping V_bot_A to 1.04e+00
# Done ramping
# Ramping V_pl_A to 1.04e+00
# Done ramping
# Ramping V_cut_A to 1.04e+00
# Done ramping
# Ramping V_bot_A to 1.04e+00
# Done ramping
# Ramping V_pl_A to 1.04e+00
# Done ramping
# Ramping V_cut_A to 1.05e+00
# Done ramping
# Ramping V_bot_A to 1.05e+00
# Done ramping
# Ramping V_pl_A to 1.05e+00
# Done ramping
# Ramping V_cut_A to 1.05e+00
# Done ramping
# Ramping V_bot_A to 1.05e+00
# Done ramping
# Ramping V_pl_A to 1.05e+00
# Done ramping
# Ramping V_cut_A to 1.06e+00
# Done ramping
# Ramping V_bot_A to 1.06e+00
# Done ramping
# Ramping V_pl_A to 1.06e+00
# Done ramping
# Ramping V_cut_A to 1.06e+00
# Done ramping
# Ramping V_bot_A to 1.06e+00
# Done ramping
# Ramping V_pl_A to 1.06e+00
# Done ramping
# Ramping V_cut_A to 1.07e+00
# Done ramping
# Ramping V_bot_A to 1.07e+00
# Done ramping
# Ramping V_pl_A to 1.07e+00
# Done ramping
# Ramping V_cut_A to 1.07e+00
# Done ramping
# Ramping V_bot_A to 1.07e+00
# Done ramping
# Ramping V_pl_A to 1.07e+00
# Done ramping
# Ramping V_cut_A to 1.08e+00
# Done ramping
# Ramping V_bot_A to 1.08e+00
# Done ramping
# Ramping V_pl_A to 1.08e+00
# Done ramping
# Ramping V_cut_A to 1.08e+00
# Done ramping
# Ramping V_bot_A to 1.08e+00
# Done ramping
# Ramping V_pl_A to 1.08e+00
# Done ramping
# Ramping V_cut_A to 1.09e+00
# Done ramping
# Ramping V_bot_A to 1.09e+00
# Done ramping
# Ramping V_pl_A to 1.09e+00
# Done ramping
# Ramping V_cut_A to 1.09e+00
# Done ramping
# Ramping V_bot_A to 1.09e+00
# Done ramping
# Ramping V_pl_A to 1.09e+00
# Done ramping
# Ramping V_cut_A to 1.10e+00
# Done ramping
# Ramping V_bot_A to 1.10e+00
# Done ramping
# Ramping V_pl_A to 1.10e+00
# Done ramping
# Ramping V_cut_A to 1.10e+00
# Done ramping
# Ramping V_bot_A to 1.10e+00
# Done ramping
# Ramping V_pl_A to 1.10e+00
# Done ramping
# Ramping V_cut_A to 1.11e+00
# Done ramping
# Ramping V_bot_A to 1.11e+00
# Done ramping
# Ramping V_pl_A to 1.11e+00
# Done ramping
# Ramping V_cut_A to 1.11e+00
# Done ramping
# Ramping V_bot_A to 1.11e+00
# Done ramping
# Ramping V_pl_A to 1.11e+00
# Done ramping
# Ramping V_cut_A to 1.12e+00
# Done ramping
# Ramping V_bot_A to 1.12e+00
# Done ramping
# Ramping V_pl_A to 1.12e+00
# Done ramping
# Ramping V_cut_A to 1.12e+00
# Done ramping
# Ramping V_bot_A to 1.12e+00
# Done ramping
# Ramping V_pl_A to 1.12e+00
# Done ramping
# Ramping V_cut_A to 1.13e+00
# Done ramping
# Ramping V_bot_A to 1.13e+00
# Done ramping
# Ramping V_pl_A to 1.13e+00
# Done ramping
# Ramping V_cut_A to 1.14e+00
# Done ramping
# Ramping V_bot_A to 1.14e+00
# Done ramping
# Ramping V_pl_A to 1.14e+00
# Done ramping
# Ramping V_cut_A to 1.14e+00
# Done ramping
# Ramping V_bot_A to 1.14e+00
# Done ramping
# Ramping V_pl_A to 1.14e+00
# Done ramping
# Ramping V_cut_A to 1.15e+00
# Done ramping
# Ramping V_bot_A to 1.15e+00
# Done ramping
# Ramping V_pl_A to 1.15e+00
# Done ramping
# Ramping V_cut_A to 1.15e+00
# Done ramping
# Ramping V_bot_A to 1.15e+00
# Done ramping
# Ramping V_pl_A to 1.15e+00
# Done ramping
# Ramping V_cut_A to 1.16e+00
# Done ramping
# Ramping V_bot_A to 1.16e+00
# Done ramping
# Ramping V_pl_A to 1.16e+00
# Done ramping
# Ramping V_cut_A to 1.16e+00
# Done ramping
# Ramping V_bot_A to 1.16e+00
# Done ramping
# Ramping V_pl_A to 1.16e+00
# Done ramping
# Ramping V_cut_A to 1.17e+00
# Done ramping
# Ramping V_bot_A to 1.17e+00
# Done ramping
# Ramping V_pl_A to 1.17e+00
# Done ramping
# Ramping V_cut_A to 1.17e+00
# Done ramping
# Ramping V_bot_A to 1.17e+00
# Done ramping
# Ramping V_pl_A to 1.17e+00
# Done ramping
# Ramping V_cut_A to 1.18e+00
# Done ramping
# Ramping V_bot_A to 1.18e+00
# Done ramping
# Ramping V_pl_A to 1.18e+00
# Done ramping
# Ramping V_cut_A to 1.18e+00
# Done ramping
# Ramping V_bot_A to 1.18e+00
# Done ramping
# Ramping V_pl_A to 1.18e+00
# Done ramping
# Ramping V_cut_A to 1.19e+00
# Done ramping
# Ramping V_bot_A to 1.19e+00
# Done ramping
# Ramping V_pl_A to 1.19e+00
# Done ramping
# Ramping V_cut_A to 1.19e+00
# Done ramping
# Ramping V_bot_A to 1.19e+00
# Done ramping
# Ramping V_pl_A to 1.19e+00
# Done ramping
# Ramping V_cut_A to 1.20e+00
# Done ramping
# Ramping V_bot_A to 1.20e+00
# Done ramping
# Ramping V_pl_A to 1.20e+00
# Done ramping
# Ramping V_cut_A to 1.20e+00
# Done ramping
# Ramping V_bot_A to 1.20e+00
# Done ramping
# Ramping V_pl_A to 1.20e+00
# Done ramping
# Ramping V_cut_A to 1.21e+00
# Done ramping
# Ramping V_bot_A to 1.21e+00
# Done ramping
# Ramping V_pl_A to 1.21e+00
# Done ramping
# Ramping V_cut_A to 1.21e+00
# Done ramping
# Ramping V_bot_A to 1.21e+00
# Done ramping
# Ramping V_pl_A to 1.21e+00
# Done ramping
# Ramping V_cut_A to 1.22e+00
# Done ramping
# Ramping V_bot_A to 1.22e+00
# Done ramping
# Ramping V_pl_A to 1.22e+00
# Done ramping
# Ramping V_cut_A to 1.22e+00
# Done ramping
# Ramping V_bot_A to 1.22e+00
# Done ramping
# Ramping V_pl_A to 1.22e+00
# Done ramping
# Ramping V_cut_A to 1.23e+00
# Done ramping
# Ramping V_bot_A to 1.23e+00
# Done ramping
# Ramping V_pl_A to 1.23e+00
# Done ramping
# Ramping V_cut_A to 1.23e+00
# Done ramping
# Ramping V_bot_A to 1.23e+00
# Done ramping
# Ramping V_pl_A to 1.23e+00
# Done ramping
# Ramping V_cut_A to 1.24e+00
# Done ramping
# Ramping V_bot_A to 1.24e+00
# Done ramping
# Ramping V_pl_A to 1.24e+00
# Done ramping
# Ramping V_cut_A to 1.24e+00
# Done ramping
# Ramping V_bot_A to 1.24e+00
# Done ramping
# Ramping V_pl_A to 1.24e+00
# Done ramping
# Ramping V_cut_A to 1.25e+00
# Done ramping
# Ramping V_bot_A to 1.25e+00
# Done ramping
# Ramping V_pl_A to 1.25e+00
# Done ramping
# Ramping V_cut_A to 1.25e+00
# Done ramping
# Ramping V_bot_A to 1.25e+00
# Done ramping
# Ramping V_pl_A to 1.25e+00
# Done ramping
# Ramping V_cut_A to 1.26e+00
# Done ramping
# Ramping V_bot_A to 1.26e+00
# Done ramping
# Ramping V_pl_A to 1.26e+00
# Done ramping
# Ramping V_cut_A to 1.26e+00
# Done ramping
# Ramping V_bot_A to 1.26e+00
# Done ramping
# Ramping V_pl_A to 1.26e+00
# Done ramping
# Ramping V_cut_A to 1.27e+00
# Done ramping
# Ramping V_bot_A to 1.27e+00
# Done ramping
# Ramping V_pl_A to 1.27e+00
# Done ramping
# Ramping V_cut_A to 1.27e+00
# Done ramping
# Ramping V_bot_A to 1.27e+00
# Done ramping
# Ramping V_pl_A to 1.27e+00
# Done ramping
# Ramping V_cut_A to 1.28e+00
# Done ramping
# Ramping V_bot_A to 1.28e+00
# Done ramping
# Ramping V_pl_A to 1.28e+00
# Done ramping
# Ramping V_cut_A to 1.28e+00
# Done ramping
# Ramping V_bot_A to 1.28e+00
# Done ramping
# Ramping V_pl_A to 1.28e+00
# Done ramping
# Ramping V_cut_A to 1.28e+00
# Done ramping
# Ramping V_bot_A to 1.28e+00
# Done ramping
# Ramping V_pl_A to 1.28e+00
# Done ramping
# Ramping V_cut_A to 1.29e+00
# Done ramping
# Ramping V_bot_A to 1.29e+00
# Done ramping
# Ramping V_pl_A to 1.29e+00
# Done ramping
# Ramping V_cut_A to 1.29e+00
# Done ramping
# Ramping V_bot_A to 1.29e+00
# Done ramping
# Ramping V_pl_A to 1.29e+00
# Done ramping
# Ramping V_cut_A to 1.30e+00
# Done ramping
# Ramping V_bot_A to 1.30e+00
# Done ramping
# Ramping V_pl_A to 1.30e+00
# Done ramping
# Ramping V_cut_A to 1.30e+00
# Done ramping
# Ramping V_bot_A to 1.30e+00
# Done ramping
# Ramping V_pl_A to 1.30e+00
# Done ramping
# Ramping V_cut_A to 1.31e+00
# Done ramping
# Ramping V_bot_A to 1.31e+00
# Done ramping
# Ramping V_pl_A to 1.31e+00
# Done ramping
# Ramping V_cut_A to 1.31e+00
# Done ramping
# Ramping V_bot_A to 1.31e+00
# Done ramping
# Ramping V_pl_A to 1.31e+00
# Done ramping
# Ramping V_cut_A to 1.32e+00
# Done ramping
# Ramping V_bot_A to 1.32e+00
# Done ramping
# Ramping V_pl_A to 1.32e+00
# Done ramping
# Ramping V_cut_A to 1.32e+00
# Done ramping
# Ramping V_bot_A to 1.32e+00
# Done ramping
# Ramping V_pl_A to 1.32e+00
# Done ramping
# Ramping V_cut_A to 1.33e+00
# Done ramping
# Ramping V_bot_A to 1.33e+00
# Done ramping
# Ramping V_pl_A to 1.33e+00
# Done ramping
# Ramping V_cut_A to 1.33e+00
# Done ramping
# Ramping V_bot_A to 1.33e+00
# Done ramping
# Ramping V_pl_A to 1.33e+00
# Done ramping
# Ramping V_cut_A to 1.34e+00
# Done ramping
# Ramping V_bot_A to 1.34e+00
# Done ramping
# Ramping V_pl_A to 1.34e+00
# Done ramping
# Ramping V_cut_A to 1.34e+00
# Done ramping
# Ramping V_bot_A to 1.34e+00
# Done ramping
# Ramping V_pl_A to 1.34e+00
# Done ramping
# Ramping V_cut_A to 1.35e+00
# Done ramping
# Ramping V_bot_A to 1.35e+00
# Done ramping
# Ramping V_pl_A to 1.35e+00
# Done ramping
# Ramping V_cut_A to 1.35e+00
# Done ramping
# Ramping V_bot_A to 1.35e+00
# Done ramping
# Ramping V_pl_A to 1.35e+00
# Done ramping
# Ramping V_cut_A to 1.36e+00
# Done ramping
# Ramping V_bot_A to 1.36e+00
# Done ramping
# Ramping V_pl_A to 1.36e+00
# Done ramping
# Ramping V_cut_A to 1.36e+00
# Done ramping
# Ramping V_bot_A to 1.36e+00
# Done ramping
# Ramping V_pl_A to 1.36e+00
# Done ramping
# Ramping V_cut_A to 1.37e+00
# Done ramping
# Ramping V_bot_A to 1.37e+00
# Done ramping
# Ramping V_pl_A to 1.37e+00
# Done ramping
# Ramping V_cut_A to 1.38e+00
# Done ramping
# Ramping V_bot_A to 1.38e+00
# Done ramping
# Ramping V_pl_A to 1.38e+00
# Done ramping
# Ramping V_cut_A to 1.38e+00
# Done ramping
# Ramping V_bot_A to 1.38e+00
# Done ramping
# Ramping V_pl_A to 1.38e+00
# Done ramping
# Ramping V_cut_A to 1.39e+00
# Done ramping
# Ramping V_bot_A to 1.39e+00
# Done ramping
# Ramping V_pl_A to 1.39e+00
# Done ramping
# Ramping V_cut_A to 1.39e+00
# Done ramping
# Ramping V_bot_A to 1.39e+00
# Done ramping
# Ramping V_pl_A to 1.39e+00
# Done ramping
# Ramping V_cut_A to 1.40e+00
# Done ramping
# Ramping V_bot_A to 1.40e+00
# Done ramping
# Ramping V_pl_A to 1.40e+00
# Done ramping
# Ramping V_cut_A to 1.40e+00
# Done ramping
# Ramping V_bot_A to 1.40e+00
# Done ramping
# Ramping V_pl_A to 1.40e+00
# Done ramping
# Ramping V_cut_A to 1.41e+00
# Done ramping
# Ramping V_bot_A to 1.41e+00
# Done ramping
# Ramping V_pl_A to 1.41e+00
# Done ramping
# Ramping V_cut_A to 1.41e+00
# Done ramping
# Ramping V_bot_A to 1.41e+00
# Done ramping
# Ramping V_pl_A to 1.41e+00
# Done ramping
# Ramping V_cut_A to 1.42e+00
# Done ramping
# Ramping V_bot_A to 1.42e+00
# Done ramping
# Ramping V_pl_A to 1.42e+00
# Done ramping
# Ramping V_cut_A to 1.42e+00
# Done ramping
# Ramping V_bot_A to 1.42e+00
# Done ramping
# Ramping V_pl_A to 1.42e+00
# Done ramping
# Ramping V_cut_A to 1.43e+00
# Done ramping
# Ramping V_bot_A to 1.43e+00
# Done ramping
# Ramping V_pl_A to 1.43e+00
# Done ramping
# Ramping V_cut_A to 1.43e+00
# Done ramping
# Ramping V_bot_A to 1.43e+00
# Done ramping
# Ramping V_pl_A to 1.43e+00
# Done ramping
# Ramping V_cut_A to 1.44e+00
# Done ramping
# Ramping V_bot_A to 1.44e+00
# Done ramping
# Ramping V_pl_A to 1.44e+00
# Done ramping
# Ramping V_cut_A to 1.44e+00
# Done ramping
# Ramping V_bot_A to 1.44e+00
# Done ramping
# Ramping V_pl_A to 1.44e+00
# Done ramping
# Ramping V_cut_A to 1.45e+00
# Done ramping
# Ramping V_bot_A to 1.45e+00
# Done ramping
# Ramping V_pl_A to 1.45e+00
# Done ramping
# Ramping V_cut_A to 1.45e+00
# Done ramping
# Ramping V_bot_A to 1.45e+00
# Done ramping
# Ramping V_pl_A to 1.45e+00
# Done ramping
# Ramping V_cut_A to 1.46e+00
# Done ramping
# Ramping V_bot_A to 1.46e+00
# Done ramping
# Ramping V_pl_A to 1.46e+00
# Done ramping
# Ramping V_cut_A to 1.46e+00
# Done ramping
# Ramping V_bot_A to 1.46e+00
# Done ramping
# Ramping V_pl_A to 1.46e+00
# Done ramping
# Ramping V_cut_A to 1.47e+00
# Done ramping
# Ramping V_bot_A to 1.47e+00
# Done ramping
# Ramping V_pl_A to 1.47e+00
# Done ramping
# Ramping V_cut_A to 1.47e+00
# Done ramping
# Ramping V_bot_A to 1.47e+00
# Done ramping
# Ramping V_pl_A to 1.47e+00
# Done ramping
# Ramping V_cut_A to 1.48e+00
# Done ramping
# Ramping V_bot_A to 1.48e+00
# Done ramping
# Ramping V_pl_A to 1.48e+00
# Done ramping
# Ramping V_cut_A to 1.48e+00
# Done ramping
# Ramping V_bot_A to 1.48e+00
# Done ramping
# Ramping V_pl_A to 1.48e+00
# Done ramping
# Ramping V_cut_A to 1.49e+00
# Done ramping
# Ramping V_bot_A to 1.49e+00
# Done ramping
# Ramping V_pl_A to 1.49e+00
# Done ramping
# Ramping V_cut_A to 1.49e+00
# Done ramping
# Ramping V_bot_A to 1.49e+00
# Done ramping
# Ramping V_pl_A to 1.49e+00
# Done ramping
# Ramping V_cut_A to 1.50e+00
# Done ramping
# Ramping V_bot_A to 1.50e+00
# Done ramping
# Ramping V_pl_A to 1.50e+00
# Done ramping
# Ramping V_cut_A to 1.50e+00
# Done ramping
# Ramping V_bot_A to 1.50e+00
# Done ramping
# Ramping V_pl_A to 1.50e+00
# Done ramping
# Ramping V_cut_A to 1.51e+00
# Done ramping
# Ramping V_bot_A to 1.51e+00
# Done ramping
# Ramping V_pl_A to 1.51e+00
# Done ramping
# Ramping V_cut_A to 1.51e+00
# Done ramping
# Ramping V_bot_A to 1.51e+00
# Done ramping
# Ramping V_pl_A to 1.51e+00
# Done ramping
# Ramping V_cut_A to 1.52e+00
# Done ramping
# Ramping V_bot_A to 1.52e+00
# Done ramping
# Ramping V_pl_A to 1.52e+00
# Done ramping
# Ramping V_cut_A to 1.52e+00
# Done ramping
# Ramping V_bot_A to 1.52e+00
# Done ramping
# Ramping V_pl_A to 1.52e+00
# Done ramping
# Ramping V_cut_A to 1.53e+00
# Done ramping
# Ramping V_bot_A to 1.53e+00
# Done ramping
# Ramping V_pl_A to 1.53e+00
# Done ramping
# Ramping V_cut_A to 1.53e+00
# Done ramping
# Ramping V_bot_A to 1.53e+00
# Done ramping
# Ramping V_pl_A to 1.53e+00
# Done ramping
# Ramping V_cut_A to 1.54e+00
# Done ramping
# Ramping V_bot_A to 1.54e+00
# Done ramping
# Ramping V_pl_A to 1.54e+00
# Done ramping
# Ramping V_cut_A to 1.54e+00
# Done ramping
# Ramping V_bot_A to 1.54e+00
# Done ramping
# Ramping V_pl_A to 1.54e+00
# Done ramping
# Ramping V_cut_A to 1.54e+00
# Done ramping
# Ramping V_bot_A to 1.54e+00
# Done ramping
# Ramping V_pl_A to 1.54e+00
# Done ramping
# Ramping V_cut_A to 1.55e+00
# Done ramping
# Ramping V_bot_A to 1.55e+00
# Done ramping
# Ramping V_pl_A to 1.55e+00
# Done ramping
# Ramping V_cut_A to 1.55e+00
# Done ramping
# Ramping V_bot_A to 1.55e+00
# Done ramping
# Ramping V_pl_A to 1.55e+00
# Done ramping
# Ramping V_cut_A to 1.56e+00
# Done ramping
# Ramping V_bot_A to 1.56e+00
# Done ramping
# Ramping V_pl_A to 1.56e+00
# Done ramping
# Ramping V_cut_A to 1.56e+00
# Done ramping
# Ramping V_bot_A to 1.56e+00
# Done ramping
# Ramping V_pl_A to 1.56e+00
# Done ramping
# Ramping V_cut_A to 1.57e+00
# Done ramping
# Ramping V_bot_A to 1.57e+00
# Done ramping
# Ramping V_pl_A to 1.57e+00
# Done ramping
# Ramping V_cut_A to 1.57e+00
# Done ramping
# Ramping V_bot_A to 1.57e+00
# Done ramping
# Ramping V_pl_A to 1.57e+00
# Done ramping
# Ramping V_cut_A to 1.58e+00
# Done ramping
# Ramping V_bot_A to 1.58e+00
# Done ramping
# Ramping V_pl_A to 1.58e+00
# Done ramping
# Ramping V_cut_A to 1.58e+00
# Done ramping
# Ramping V_bot_A to 1.58e+00
# Done ramping
# Ramping V_pl_A to 1.58e+00
# Done ramping
# Ramping V_cut_A to 1.59e+00
# Done ramping
# Ramping V_bot_A to 1.59e+00
# Done ramping
# Ramping V_pl_A to 1.59e+00
# Done ramping
# Ramping V_cut_A to 1.59e+00
# Done ramping
# Ramping V_bot_A to 1.59e+00
# Done ramping
# Ramping V_pl_A to 1.59e+00
# Done ramping
# Ramping V_cut_A to 1.60e+00
# Done ramping
# Ramping V_bot_A to 1.60e+00
# Done ramping
# Ramping V_pl_A to 1.60e+00
# Done ramping
# Ramping V_cut_A to 1.60e+00
# Done ramping
# Ramping V_bot_A to 1.60e+00
# Done ramping
# Ramping V_pl_A to 1.60e+00
# Done ramping
# Ramping V_cut_A to 1.61e+00
# Done ramping
# Ramping V_bot_A to 1.61e+00
# Done ramping
# Ramping V_pl_A to 1.61e+00
# Done ramping
# Ramping V_cut_A to 1.61e+00
# Done ramping
# Ramping V_bot_A to 1.61e+00
# Done ramping
# Ramping V_pl_A to 1.61e+00
# Done ramping
# Ramping V_cut_A to 1.62e+00
# Done ramping
# Ramping V_bot_A to 1.62e+00
# Done ramping
# Ramping V_pl_A to 1.62e+00
# Done ramping
# Ramping V_cut_A to 1.62e+00
# Done ramping
# Ramping V_bot_A to 1.62e+00
# Done ramping
# Ramping V_pl_A to 1.62e+00
# Done ramping
# Ramping V_cut_A to 1.63e+00
# Done ramping
# Ramping V_bot_A to 1.63e+00
# Done ramping
# Ramping V_pl_A to 1.63e+00
# Done ramping
# Ramping V_cut_A to 1.64e+00
# Done ramping
# Ramping V_bot_A to 1.64e+00
# Done ramping
# Ramping V_pl_A to 1.64e+00
# Done ramping
# Ramping V_cut_A to 1.64e+00
# Done ramping
# Ramping V_bot_A to 1.64e+00
# Done ramping
# Ramping V_pl_A to 1.64e+00
# Done ramping
# Ramping V_cut_A to 1.65e+00
# Done ramping
# Ramping V_bot_A to 1.65e+00
# Done ramping
# Ramping V_pl_A to 1.65e+00
# Done ramping
# Ramping V_cut_A to 1.65e+00
# Done ramping
# Ramping V_bot_A to 1.65e+00
# Done ramping
# Ramping V_pl_A to 1.65e+00
# Done ramping
# Ramping V_cut_A to 1.66e+00
# Done ramping
# Ramping V_bot_A to 1.66e+00
# Done ramping
# Ramping V_pl_A to 1.66e+00
# Done ramping
# Ramping V_cut_A to 1.66e+00
# Done ramping
# Ramping V_bot_A to 1.66e+00
# Done ramping
# Ramping V_pl_A to 1.66e+00
# Done ramping
# Ramping V_cut_A to 1.67e+00
# Done ramping
# Ramping V_bot_A to 1.67e+00
# Done ramping
# Ramping V_pl_A to 1.67e+00
# Done ramping
# Ramping V_cut_A to 1.67e+00
# Done ramping
# Ramping V_bot_A to 1.67e+00
# Done ramping
# Ramping V_pl_A to 1.67e+00
# Done ramping
# Ramping V_cut_A to 1.68e+00
# Done ramping
# Ramping V_bot_A to 1.68e+00
# Done ramping
# Ramping V_pl_A to 1.68e+00
# Done ramping
# Ramping V_cut_A to 1.68e+00
# Done ramping
# Ramping V_bot_A to 1.68e+00
# Done ramping
# Ramping V_pl_A to 1.68e+00
# Done ramping
# Ramping V_cut_A to 1.69e+00
# Done ramping
# Ramping V_bot_A to 1.69e+00
# Done ramping
# Ramping V_pl_A to 1.69e+00
# Done ramping
# Ramping V_cut_A to 1.69e+00
# Done ramping
# Ramping V_bot_A to 1.69e+00
# Done ramping
# Ramping V_pl_A to 1.69e+00
# Done ramping
# Ramping V_cut_A to 1.70e+00
# Done ramping
# Ramping V_bot_A to 1.70e+00
# Done ramping
# Ramping V_pl_A to 1.70e+00
# Done ramping
# Ramping V_cut_A to 1.70e+00
# Done ramping
# Ramping V_bot_A to 1.70e+00
# Done ramping
# Ramping V_pl_A to 1.70e+00
# Done ramping
# Ramping V_cut_A to 1.71e+00
# Done ramping
# Ramping V_bot_A to 1.71e+00
# Done ramping
# Ramping V_pl_A to 1.71e+00
# Done ramping
# Ramping V_cut_A to 1.71e+00
# Done ramping
# Ramping V_bot_A to 1.71e+00
# Done ramping
# Ramping V_pl_A to 1.71e+00
# Done ramping
# Ramping V_cut_A to 1.72e+00
# Done ramping
# Ramping V_bot_A to 1.72e+00
# Done ramping
# Ramping V_pl_A to 1.72e+00
# Done ramping
# Ramping V_cut_A to 1.72e+00
# Done ramping
# Ramping V_bot_A to 1.72e+00
# Done ramping
# Ramping V_pl_A to 1.72e+00
# Done ramping
# Ramping V_cut_A to 1.73e+00
# Done ramping
# Ramping V_bot_A to 1.73e+00
# Done ramping
# Ramping V_pl_A to 1.73e+00
# Done ramping
# Ramping V_cut_A to 1.73e+00
# Done ramping
# Ramping V_bot_A to 1.73e+00
# Done ramping
# Ramping V_pl_A to 1.73e+00
# Done ramping
# Ramping V_cut_A to 1.74e+00
# Done ramping
# Ramping V_bot_A to 1.74e+00
# Done ramping
# Ramping V_pl_A to 1.74e+00
# Done ramping
# Ramping V_cut_A to 1.74e+00
# Done ramping
# Ramping V_bot_A to 1.74e+00
# Done ramping
# Ramping V_pl_A to 1.74e+00
# Done ramping
# Ramping V_cut_A to 1.75e+00
# Done ramping
# Ramping V_bot_A to 1.75e+00
# Done ramping
# Ramping V_pl_A to 1.75e+00
# Done ramping
# Ramping V_cut_A to 1.75e+00
# Done ramping
# Ramping V_bot_A to 1.75e+00
# Done ramping
# Ramping V_pl_A to 1.75e+00
# Done ramping
# Ramping V_cut_A to 1.76e+00
# Done ramping
# Ramping V_bot_A to 1.76e+00
# Done ramping
# Ramping V_pl_A to 1.76e+00
# Done ramping
# Ramping V_cut_A to 1.76e+00
# Done ramping
# Ramping V_bot_A to 1.76e+00
# Done ramping
# Ramping V_pl_A to 1.76e+00
# Done ramping
# Ramping V_cut_A to 1.77e+00
# Done ramping
# Ramping V_bot_A to 1.77e+00
# Done ramping
# Ramping V_pl_A to 1.77e+00
# Done ramping
# Ramping V_cut_A to 1.77e+00
# Done ramping
# Ramping V_bot_A to 1.77e+00
# Done ramping
# Ramping V_pl_A to 1.77e+00
# Done ramping
# Ramping V_cut_A to 1.78e+00
# Done ramping
# Ramping V_bot_A to 1.78e+00
# Done ramping
# Ramping V_pl_A to 1.78e+00
# Done ramping
# Ramping V_cut_A to 1.78e+00
# Done ramping
# Ramping V_bot_A to 1.78e+00
# Done ramping
# Ramping V_pl_A to 1.78e+00
# Done ramping
# Ramping V_cut_A to 1.79e+00
# Done ramping
# Ramping V_bot_A to 1.79e+00
# Done ramping
# Ramping V_pl_A to 1.79e+00
# Done ramping
# Ramping V_cut_A to 1.79e+00
# Done ramping
# Ramping V_bot_A to 1.79e+00
# Done ramping
# Ramping V_pl_A to 1.79e+00
# Done ramping
# Ramping V_cut_A to 1.79e+00
# Done ramping
# Ramping V_bot_A to 1.79e+00
# Done ramping
# Ramping V_pl_A to 1.79e+00
# Done ramping
# Ramping V_cut_A to 1.80e+00
# Done ramping
# Ramping V_bot_A to 1.80e+00
# Done ramping
# Ramping V_pl_A to 1.80e+00
# Done ramping
# Ramping V_cut_A to 1.80e+00
# Done ramping
# Ramping V_bot_A to 1.80e+00
# Done ramping
# Ramping V_pl_A to 1.80e+00
# Done ramping
# Ramping V_cut_A to 1.81e+00
# Done ramping
# Ramping V_bot_A to 1.81e+00
# Done ramping
# Ramping V_pl_A to 1.81e+00
# Done ramping
# Ramping V_cut_A to 1.81e+00
# Done ramping
# Ramping V_bot_A to 1.81e+00
# Done ramping
# Ramping V_pl_A to 1.81e+00
# Done ramping
# Ramping V_cut_A to 1.82e+00
# Done ramping
# Ramping V_bot_A to 1.82e+00
# Done ramping
# Ramping V_pl_A to 1.82e+00
# Done ramping
# Ramping V_cut_A to 1.82e+00
# Done ramping
# Ramping V_bot_A to 1.82e+00
# Done ramping
# Ramping V_pl_A to 1.82e+00
# Done ramping
# Ramping V_cut_A to 1.83e+00
# Done ramping
# Ramping V_bot_A to 1.83e+00
# Done ramping
# Ramping V_pl_A to 1.83e+00
# Done ramping
# Ramping V_cut_A to 1.83e+00
# Done ramping
# Ramping V_bot_A to 1.83e+00
# Done ramping
# Ramping V_pl_A to 1.83e+00
# Done ramping
# Ramping V_cut_A to 1.84e+00
# Done ramping
# Ramping V_bot_A to 1.84e+00
# Done ramping
# Ramping V_pl_A to 1.84e+00
# Done ramping
# Ramping V_cut_A to 1.84e+00
# Done ramping
# Ramping V_bot_A to 1.84e+00
# Done ramping
# Ramping V_pl_A to 1.84e+00
# Done ramping
# Ramping V_cut_A to 1.85e+00
# Done ramping
# Ramping V_bot_A to 1.85e+00
# Done ramping
# Ramping V_pl_A to 1.85e+00
# Done ramping
# Ramping V_cut_A to 1.85e+00
# Done ramping
# Ramping V_bot_A to 1.85e+00
# Done ramping
# Ramping V_pl_A to 1.85e+00
# Done ramping
# Ramping V_cut_A to 1.86e+00
# Done ramping
# Ramping V_bot_A to 1.86e+00
# Done ramping
# Ramping V_pl_A to 1.86e+00
# Done ramping
# Ramping V_cut_A to 1.86e+00
# Done ramping
# Ramping V_bot_A to 1.86e+00
# Done ramping
# Ramping V_pl_A to 1.86e+00
# Done ramping
# Ramping V_cut_A to 1.87e+00
# Done ramping
# Ramping V_bot_A to 1.87e+00
# Done ramping
# Ramping V_pl_A to 1.87e+00
# Done ramping
# Ramping V_cut_A to 1.88e+00
# Done ramping
# Ramping V_bot_A to 1.88e+00
# Done ramping
# Ramping V_pl_A to 1.88e+00
# Done ramping
# Ramping V_cut_A to 1.88e+00
# Done ramping
# Ramping V_bot_A to 1.88e+00
# Done ramping
# Ramping V_pl_A to 1.88e+00
# Done ramping
# Ramping V_cut_A to 1.89e+00
# Done ramping
# Ramping V_bot_A to 1.89e+00
# Done ramping
# Ramping V_pl_A to 1.89e+00
# Done ramping
# Ramping V_cut_A to 1.89e+00
# Done ramping
# Ramping V_bot_A to 1.89e+00
# Done ramping
# Ramping V_pl_A to 1.89e+00
# Done ramping
# Ramping V_cut_A to 1.90e+00
# Done ramping
# Ramping V_bot_A to 1.90e+00
# Done ramping
# Ramping V_pl_A to 1.90e+00
# Done ramping
# Ramping V_cut_A to 1.90e+00
# Done ramping
# Ramping V_bot_A to 1.90e+00
# Done ramping
# Ramping V_pl_A to 1.90e+00
# Done ramping
# Ramping V_cut_A to 1.91e+00
# Done ramping
# Ramping V_bot_A to 1.91e+00
# Done ramping
# Ramping V_pl_A to 1.91e+00
# Done ramping
# Ramping V_cut_A to 1.91e+00
# Done ramping
# Ramping V_bot_A to 1.91e+00
# Done ramping
# Ramping V_pl_A to 1.91e+00
# Done ramping
# Ramping V_cut_A to 1.92e+00
# Done ramping
# Ramping V_bot_A to 1.92e+00
# Done ramping
# Ramping V_pl_A to 1.92e+00
# Done ramping
# Ramping V_cut_A to 1.92e+00
# Done ramping
# Ramping V_bot_A to 1.92e+00
# Done ramping
# Ramping V_pl_A to 1.92e+00
# Done ramping
# Ramping V_cut_A to 1.93e+00
# Done ramping
# Ramping V_bot_A to 1.93e+00
# Done ramping
# Ramping V_pl_A to 1.93e+00
# Done ramping
# Ramping V_cut_A to 1.93e+00
# Done ramping
# Ramping V_bot_A to 1.93e+00
# Done ramping
# Ramping V_pl_A to 1.93e+00
# Done ramping
# Ramping V_cut_A to 1.94e+00
# Done ramping
# Ramping V_bot_A to 1.94e+00
# Done ramping
# Ramping V_pl_A to 1.94e+00
# Done ramping
# Ramping V_cut_A to 1.94e+00
# Done ramping
# Ramping V_bot_A to 1.94e+00
# Done ramping
# Ramping V_pl_A to 1.94e+00
# Done ramping
# Ramping V_cut_A to 1.95e+00
# Done ramping
# Ramping V_bot_A to 1.95e+00
# Done ramping
# ...
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_pl_A to 3.35e+00
# Done ramping
# Ramping V_cut_A to 3.35e+00
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_pl_A to 3.35e+00
# Done ramping
# Ramping V_cut_A to 3.35e+00
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_pl_A to 3.35e+00
# Done ramping
# Ramping V_cut_A to 3.36e+00
# Done ramping
# Ramping V_bot_A to 3.36e+00
# Done ramping
# Ramping V_pl_A to 3.36e+00
# Done ramping
# Ramping V_cut_A to 3.37e+00
# Done ramping
# Ramping V_bot_A to 3.37e+00
# Done ramping
# Ramping V_pl_A to 3.37e+00
# Done ramping
# Ramping V_cut_A to 3.37e+00
# Done ramping
# Ramping V_bot_A to 3.37e+00
# Done ramping
# Ramping V_pl_A to 3.37e+00
# Done ramping
# Ramping V_cut_A to 3.38e+00
# Done ramping
# Ramping V_bot_A to 3.38e+00
# Done ramping
# Ramping V_pl_A to 3.38e+00
# Done ramping
# Ramping V_cut_A to 3.38e+00
# Done ramping
# Ramping V_bot_A to 3.38e+00
# Done ramping
# Ramping V_pl_A to 3.38e+00
# Done ramping
# Ramping V_cut_A to 3.39e+00
# Done ramping
# Ramping V_bot_A to 3.39e+00
# Done ramping
# Ramping V_pl_A to 3.39e+00
# Done ramping
# Ramping V_cut_A to 3.39e+00
# Done ramping
# Ramping V_bot_A to 3.39e+00
# Done ramping
# Ramping V_pl_A to 3.39e+00
# Done ramping
# Ramping V_cut_A to 3.40e+00
# Done ramping
# Ramping V_bot_A to 3.40e+00
# Done ramping
# Ramping V_pl_A to 3.40e+00
# Done ramping
# Ramping V_cut_A to 3.40e+00
# Done ramping
# Ramping V_bot_A to 3.40e+00
# Done ramping
# Ramping V_pl_A to 3.40e+00
# Done ramping
# Ramping V_cut_A to 3.41e+00
# Done ramping
# Ramping V_bot_A to 3.41e+00
# Done ramping
# Ramping V_pl_A to 3.41e+00
# Done ramping
# Ramping V_cut_A to 3.41e+00
# Done ramping
# Ramping V_bot_A to 3.41e+00
# Done ramping
# Ramping V_pl_A to 3.41e+00
# Done ramping
# Ramping V_cut_A to 3.42e+00
# Done ramping
# Ramping V_bot_A to 3.42e+00
# Done ramping
# Ramping V_pl_A to 3.42e+00
# Done ramping
# Ramping V_cut_A to 3.42e+00
# Done ramping
# Ramping V_bot_A to 3.42e+00
# Done ramping
# Ramping V_pl_A to 3.42e+00
# Done ramping
# Ramping V_cut_A to 3.43e+00
# Done ramping
# Ramping V_bot_A to 3.43e+00
# Done ramping
# Ramping V_pl_A to 3.43e+00
# Done ramping
# Ramping V_cut_A to 3.43e+00
# Done ramping
# Ramping V_bot_A to 3.43e+00
# Done ramping
# Ramping V_pl_A to 3.43e+00
# Done ramping
# Ramping V_cut_A to 3.44e+00
# Done ramping
# Ramping V_bot_A to 3.44e+00
# Done ramping
# Ramping V_pl_A to 3.44e+00
# Done ramping
# Ramping V_cut_A to 3.44e+00
# Done ramping
# Ramping V_bot_A to 3.44e+00
# Done ramping
# Ramping V_pl_A to 3.44e+00
# Done ramping
# Ramping V_cut_A to 3.45e+00
# Done ramping
# Ramping V_bot_A to 3.45e+00
# Done ramping
# Ramping V_pl_A to 3.45e+00
# Done ramping
# Ramping V_cut_A to 3.45e+00
# Done ramping
# Ramping V_bot_A to 3.45e+00
# Done ramping
# Ramping V_pl_A to 3.45e+00
# Done ramping
# Ramping V_cut_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_pl_A to 3.46e+00
# Done ramping
# Ramping V_cut_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_pl_A to 3.46e+00
# Done ramping
# Ramping V_cut_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_pl_A to 3.46e+00
# Done ramping
# Ramping V_cut_A to 3.47e+00
# Done ramping
# Ramping V_bot_A to 3.47e+00
# Done ramping
# Ramping V_pl_A to 3.47e+00
# Done ramping
# Ramping V_cut_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_pl_A to 3.48e+00
# Done ramping
# Ramping V_cut_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_pl_A to 3.48e+00
# Done ramping
# Ramping V_cut_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_pl_A to 3.48e+00
# Done ramping
# Ramping V_cut_A to 3.49e+00
# Done ramping
# Ramping V_bot_A to 3.49e+00
# Done ramping
# Ramping V_pl_A to 3.49e+00
# Done ramping
# Ramping V_cut_A to 3.50e+00
# Done ramping
# Ramping V_bot_A to 3.50e+00
# Done ramping
# Ramping V_pl_A to 3.50e+00
# Done ramping
# Ramping V_cut_A to 3.50e+00
# Done ramping
# Ramping V_bot_A to 3.50e+00
# Done ramping
# Ramping V_pl_A to 3.50e+00
# Done ramping
# Ramping V_cut_A to 3.50e+00
# Done ramping
# Ramping V_bot_A to 3.50e+00
# Done ramping
# Ramping V_pl_A to 3.50e+00
# Done ramping
# Ramping V_cut_A to 3.51e+00
# Done ramping
# Ramping V_bot_A to 3.51e+00
# Done ramping
# Ramping V_pl_A to 3.51e+00
# Done ramping
# Ramping V_cut_A to 3.52e+00
# Done ramping
# Ramping V_bot_A to 3.52e+00
# Done ramping
# Ramping V_pl_A to 3.52e+00
# Done ramping
# Ramping V_cut_A to 3.52e+00
# Done ramping
# Ramping V_bot_A to 3.52e+00
# Done ramping
# Ramping V_pl_A to 3.52e+00
# Done ramping
# Ramping V_cut_A to 3.52e+00
# Done ramping
# Ramping V_bot_A to 3.52e+00
# Done ramping
# Ramping V_pl_A to 3.52e+00
# Done ramping
# Ramping V_cut_A to 3.53e+00
# Done ramping
# Ramping V_bot_A to 3.53e+00
# Done ramping
# Ramping V_pl_A to 3.53e+00
# Done ramping
# Ramping V_cut_A to 3.54e+00
# Done ramping
# Ramping V_bot_A to 3.54e+00
# Done ramping
# Ramping V_pl_A to 3.54e+00
# Done ramping
# Ramping V_cut_A to 3.54e+00
# Done ramping
# Ramping V_bot_A to 3.54e+00
# Done ramping
# Ramping V_pl_A to 3.54e+00
# Done ramping
# Ramping V_cut_A to 3.54e+00
# Done ramping
# Ramping V_bot_A to 3.54e+00
# Done ramping
# Ramping V_pl_A to 3.54e+00
# Done ramping
# Ramping V_cut_A to 3.55e+00
# Done ramping
# Ramping V_bot_A to 3.55e+00
# Done ramping
# Ramping V_pl_A to 3.55e+00
# Done ramping
# Ramping V_cut_A to 3.56e+00
# Done ramping
# Ramping V_bot_A to 3.56e+00
# Done ramping
# Ramping V_pl_A to 3.56e+00
# Done ramping
# Ramping V_cut_A to 3.56e+00
# Done ramping
# Ramping V_bot_A to 3.56e+00
# Done ramping
# Ramping V_pl_A to 3.56e+00
# Done ramping
# Ramping V_cut_A to 3.56e+00
# Done ramping
# Ramping V_bot_A to 3.56e+00
# Done ramping
# Ramping V_pl_A to 3.56e+00
# Done ramping
# Ramping V_cut_A to 3.57e+00
# Done ramping
# Ramping V_bot_A to 3.57e+00
# Done ramping
# Ramping V_pl_A to 3.57e+00
# Done ramping
# Ramping V_cut_A to 3.58e+00
# Done ramping
# Ramping V_bot_A to 3.58e+00
# Done ramping
# Ramping V_pl_A to 3.58e+00
# Done ramping
# Ramping V_cut_A to 3.58e+00
# Done ramping
# Ramping V_bot_A to 3.58e+00
# Done ramping
# Ramping V_pl_A to 3.58e+00
# Done ramping
# Ramping V_cut_A to 3.58e+00
# Done ramping
# Ramping V_bot_A to 3.58e+00
# Done ramping
# Ramping V_pl_A to 3.58e+00
# Done ramping
# Ramping V_cut_A to 3.59e+00
# Done ramping
# Ramping V_bot_A to 3.59e+00
# Done ramping
# Ramping V_pl_A to 3.59e+00
# Done ramping
# Ramping V_cut_A to 3.60e+00
# Done ramping
# Ramping V_bot_A to 3.60e+00
# Done ramping
# Ramping V_pl_A to 3.60e+00
# Done ramping
# Ramping V_cut_A to 3.60e+00
# Done ramping
# Ramping V_bot_A to 3.60e+00
# Done ramping
# Ramping V_pl_A to 3.60e+00
# Done ramping
# Ramping V_cut_A to 3.60e+00
# Done ramping
# Ramping V_bot_A to 3.60e+00
# Done ramping
# Ramping V_pl_A to 3.60e+00
# Done ramping
# Ramping V_cut_A to 3.61e+00
# Done ramping
# Ramping V_bot_A to 3.61e+00
# Done ramping
# Ramping V_pl_A to 3.61e+00
# Done ramping
# Ramping V_cut_A to 3.62e+00
# Done ramping
# Ramping V_bot_A to 3.62e+00
# Done ramping
# Ramping V_pl_A to 3.62e+00
# Done ramping
# Ramping V_cut_A to 3.62e+00
# Done ramping
# Ramping V_bot_A to 3.62e+00
# Done ramping
# Ramping V_pl_A to 3.62e+00
# Done ramping
# Ramping V_cut_A to 3.62e+00
# Done ramping
# Ramping V_bot_A to 3.62e+00
# Done ramping
# Ramping V_pl_A to 3.62e+00
# Done ramping
# Ramping V_cut_A to 3.63e+00
# Done ramping
# Ramping V_bot_A to 3.63e+00
# Done ramping
# Ramping V_pl_A to 3.63e+00
# Done ramping
# Ramping V_cut_A to 3.64e+00
# Done ramping
# Ramping V_bot_A to 3.64e+00
# Done ramping
# Ramping V_pl_A to 3.64e+00
# Done ramping
# Ramping V_cut_A to 3.64e+00
# Done ramping
# Ramping V_bot_A to 3.64e+00
# Done ramping
# Ramping V_pl_A to 3.64e+00
# Done ramping
# Ramping V_cut_A to 3.65e+00
# Done ramping
# Ramping V_bot_A to 3.65e+00
# Done ramping
# Ramping V_pl_A to 3.65e+00
# Done ramping
# Ramping V_cut_A to 3.65e+00
# Done ramping
# Ramping V_bot_A to 3.65e+00
# Done ramping
# Ramping V_pl_A to 3.65e+00
# Done ramping
# Ramping V_cut_A to 3.66e+00
# Done ramping
# Ramping V_bot_A to 3.66e+00
# Done ramping
# Ramping V_pl_A to 3.66e+00
# Done ramping
# Ramping V_cut_A to 3.66e+00
# Done ramping
# Ramping V_bot_A to 3.66e+00
# Done ramping
# Ramping V_pl_A to 3.66e+00
# Done ramping
# Ramping V_cut_A to 3.67e+00
# Done ramping
# Ramping V_bot_A to 3.67e+00
# Done ramping
# Ramping V_pl_A to 3.67e+00
# Done ramping
# Ramping V_cut_A to 3.67e+00
# Done ramping
# Ramping V_bot_A to 3.67e+00
# Done ramping
# Ramping V_pl_A to 3.67e+00
# Done ramping
# Ramping V_cut_A to 3.68e+00
# Done ramping
# Ramping V_bot_A to 3.68e+00
# Done ramping
# Ramping V_pl_A to 3.68e+00
# Done ramping
# Ramping V_cut_A to 3.68e+00
# Done ramping
# Ramping V_bot_A to 3.68e+00
# Done ramping
# Ramping V_pl_A to 3.68e+00
# Done ramping
# Ramping V_cut_A to 3.69e+00
# Done ramping
# Ramping V_bot_A to 3.69e+00
# Done ramping
# Ramping V_pl_A to 3.69e+00
# Done ramping
# Ramping V_cut_A to 3.69e+00
# Done ramping
# Ramping V_bot_A to 3.69e+00
# Done ramping
# Ramping V_pl_A to 3.69e+00
# Done ramping
# Ramping V_cut_A to 3.70e+00
# Done ramping
# Ramping V_bot_A to 3.70e+00
# Done ramping
# Ramping V_pl_A to 3.70e+00
# Done ramping
# Ramping V_cut_A to 3.70e+00
# Done ramping
# Ramping V_bot_A to 3.70e+00
# Done ramping
# Ramping V_pl_A to 3.70e+00
# Done ramping
# Ramping V_cut_A to 3.71e+00
# Done ramping
# Ramping V_bot_A to 3.71e+00
# Done ramping
# Ramping V_pl_A to 3.71e+00
# Done ramping
# Ramping V_cut_A to 3.71e+00
# Done ramping
# Ramping V_bot_A to 3.71e+00
# Done ramping
# Ramping V_pl_A to 3.71e+00
# Done ramping
# Ramping V_cut_A to 3.71e+00
# Done ramping
# Ramping V_bot_A to 3.71e+00
# Done ramping
# Ramping V_pl_A to 3.71e+00
# Done ramping
# Ramping V_cut_A to 3.72e+00
# Done ramping
# Ramping V_bot_A to 3.72e+00
# Done ramping
# Ramping V_pl_A to 3.72e+00
# Done ramping
# Ramping V_cut_A to 3.73e+00
# Done ramping
# Ramping V_bot_A to 3.73e+00
# Done ramping
# Ramping V_pl_A to 3.73e+00
# Done ramping
# Ramping V_cut_A to 3.73e+00
# Done ramping
# Ramping V_bot_A to 3.73e+00
# Done ramping
# Ramping V_pl_A to 3.73e+00
# Done ramping
# Ramping V_cut_A to 3.73e+00
# Done ramping
# Ramping V_bot_A to 3.73e+00
# Done ramping
# Ramping V_pl_A to 3.73e+00
# Done ramping
# Ramping V_cut_A to 3.74e+00
# Done ramping
# Ramping V_bot_A to 3.74e+00
# Done ramping
# Ramping V_pl_A to 3.74e+00
# Done ramping
# Ramping V_cut_A to 3.75e+00
# Done ramping
# Ramping V_bot_A to 3.75e+00
# Done ramping
# Ramping V_pl_A to 3.75e+00
# Done ramping
# Ramping V_cut_A to 3.75e+00
# Done ramping
# Ramping V_bot_A to 3.75e+00
# Done ramping
# Ramping V_pl_A to 3.75e+00
# Done ramping
# Ramping V_cut_A to 3.75e+00
# Done ramping
# Ramping V_bot_A to 3.75e+00
# Done ramping
# Ramping V_pl_A to 3.75e+00
# Done ramping
# Ramping V_cut_A to 3.76e+00
# Done ramping
# Ramping V_bot_A to 3.76e+00
# Done ramping
# Ramping V_pl_A to 3.76e+00
# Done ramping
# Ramping V_cut_A to 3.77e+00
# Done ramping
# Ramping V_bot_A to 3.77e+00
# Done ramping
# Ramping V_pl_A to 3.77e+00
# Done ramping
# Ramping V_cut_A to 3.77e+00
# Done ramping
# Ramping V_bot_A to 3.77e+00
# Done ramping
# Ramping V_pl_A to 3.77e+00
# Done ramping
# Ramping V_cut_A to 3.77e+00
# Done ramping
# Ramping V_bot_A to 3.77e+00
# Done ramping
# Ramping V_pl_A to 3.77e+00
# Done ramping
# Ramping V_cut_A to 3.78e+00
# Done ramping
# Ramping V_bot_A to 3.78e+00
# Done ramping
# Ramping V_pl_A to 3.78e+00
# Done ramping
# Ramping V_cut_A to 3.79e+00
# Done ramping
# Ramping V_bot_A to 3.79e+00
# Done ramping
# Ramping V_pl_A to 3.79e+00
# Done ramping
# Ramping V_cut_A to 3.79e+00
# Done ramping
# Ramping V_bot_A to 3.79e+00
# Done ramping
# Ramping V_pl_A to 3.79e+00
# Done ramping
# Ramping V_cut_A to 3.79e+00
# Done ramping
# Ramping V_bot_A to 3.79e+00
# Done ramping
# Ramping V_pl_A to 3.79e+00
# Done ramping
# Ramping V_cut_A to 3.80e+00
# Done ramping
# Ramping V_bot_A to 3.80e+00
# Done ramping
# Ramping V_pl_A to 3.80e+00
# Done ramping
# Ramping V_cut_A to 3.81e+00
# Done ramping
# Ramping V_bot_A to 3.81e+00
# Done ramping
# Ramping V_pl_A to 3.81e+00
# Done ramping
# Ramping V_cut_A to 3.81e+00
# Done ramping
# Ramping V_bot_A to 3.81e+00
# Done ramping
# Ramping V_pl_A to 3.81e+00
# Done ramping
# Ramping V_cut_A to 3.81e+00
# Done ramping
# Ramping V_bot_A to 3.81e+00
# Done ramping
# Ramping V_pl_A to 3.81e+00
# Done ramping
# Ramping V_cut_A to 3.82e+00
# Done ramping
# Ramping V_bot_A to 3.82e+00
# Done ramping
# Ramping V_pl_A to 3.82e+00
# Done ramping
# Ramping V_cut_A to 3.83e+00
# Done ramping
# Ramping V_bot_A to 3.83e+00
# Done ramping
# Ramping V_pl_A to 3.83e+00
# Done ramping
# Ramping V_cut_A to 3.83e+00
# Done ramping
# Ramping V_bot_A to 3.83e+00
# Done ramping
# Ramping V_pl_A to 3.83e+00
# Done ramping
# Ramping V_cut_A to 3.83e+00
# Done ramping
# Ramping V_bot_A to 3.83e+00
# Done ramping
# Ramping V_pl_A to 3.83e+00
# Done ramping
# Ramping V_cut_A to 3.84e+00
# Done ramping
# Ramping V_bot_A to 3.84e+00
# Done ramping
# Ramping V_pl_A to 3.84e+00
# Done ramping
# Ramping V_cut_A to 3.85e+00
# Done ramping
# Ramping V_bot_A to 3.85e+00
# Done ramping
# Ramping V_pl_A to 3.85e+00
# Done ramping
# Ramping V_cut_A to 3.85e+00
# Done ramping
# Ramping V_bot_A to 3.85e+00
# Done ramping
# Ramping V_pl_A to 3.85e+00
# Done ramping
# Ramping V_cut_A to 3.85e+00
# Done ramping
# Ramping V_bot_A to 3.85e+00
# Done ramping
# Ramping V_pl_A to 3.85e+00
# Done ramping
# Ramping V_cut_A to 3.86e+00
# Done ramping
# Ramping V_bot_A to 3.86e+00
# Done ramping
# Ramping V_pl_A to 3.86e+00
# Done ramping
# Ramping V_cut_A to 3.87e+00
# Done ramping
# Ramping V_bot_A to 3.87e+00
# Done ramping
# Ramping V_pl_A to 3.87e+00
# Done ramping
# Ramping V_cut_A to 3.87e+00
# Done ramping
# Ramping V_bot_A to 3.87e+00
# Done ramping
# Ramping V_pl_A to 3.87e+00
# Done ramping
# Ramping V_cut_A to 3.88e+00
# Done ramping
# Ramping V_bot_A to 3.88e+00
# Done ramping
# Ramping V_pl_A to 3.88e+00
# Done ramping
# Ramping V_cut_A to 3.88e+00
# Done ramping
# Ramping V_bot_A to 3.88e+00
# Done ramping
# Ramping V_pl_A to 3.88e+00
# Done ramping
# Ramping V_cut_A to 3.89e+00
# Done ramping
# Ramping V_bot_A to 3.89e+00
# Done ramping
# Ramping V_pl_A to 3.89e+00
# Done ramping
# Ramping V_cut_A to 3.89e+00
# Done ramping
# Ramping V_bot_A to 3.89e+00
# Done ramping
# Ramping V_pl_A to 3.89e+00
# Done ramping
# Ramping V_cut_A to 3.90e+00
# Done ramping
# Ramping V_bot_A to 3.90e+00
# Done ramping
# Ramping V_pl_A to 3.90e+00
# Done ramping
# Ramping V_cut_A to 3.90e+00
# Done ramping
# Ramping V_bot_A to 3.90e+00
# Done ramping
# Ramping V_pl_A to 3.90e+00
# Done ramping
# Ramping V_cut_A to 3.91e+00
# Done ramping
# Ramping V_bot_A to 3.91e+00
# Done ramping
# Ramping V_pl_A to 3.91e+00
# Done ramping
# Ramping V_cut_A to 3.91e+00
# Done ramping
# Ramping V_bot_A to 3.91e+00
# Done ramping
# Ramping V_pl_A to 3.91e+00
# Done ramping
# Ramping V_cut_A to 3.92e+00
# Done ramping
# Ramping V_bot_A to 3.92e+00
# Done ramping
# Ramping V_pl_A to 3.92e+00
# Done ramping
# Ramping V_cut_A to 3.92e+00
# Done ramping
# Ramping V_bot_A to 3.92e+00
# Done ramping
# Ramping V_pl_A to 3.92e+00
# Done ramping
# Ramping V_cut_A to 3.93e+00
# Done ramping
# Ramping V_bot_A to 3.93e+00
# Done ramping
# Ramping V_pl_A to 3.93e+00
# Done ramping
# Ramping V_cut_A to 3.93e+00
# Done ramping
# Ramping V_bot_A to 3.93e+00
# Done ramping
# Ramping V_pl_A to 3.93e+00
# Done ramping
# Ramping V_cut_A to 3.94e+00
# Done ramping
# Ramping V_bot_A to 3.94e+00
# Done ramping
# Ramping V_pl_A to 3.94e+00
# Done ramping
# Ramping V_cut_A to 3.94e+00
# Done ramping
# Ramping V_bot_A to 3.94e+00
# Done ramping
# Ramping V_pl_A to 3.94e+00
# Done ramping
# Ramping V_cut_A to 3.95e+00
# Done ramping
# Ramping V_bot_A to 3.95e+00
# Done ramping
# Ramping V_pl_A to 3.95e+00
# Done ramping
# Ramping V_cut_A to 3.95e+00
# Done ramping
# Ramping V_bot_A to 3.95e+00
# Done ramping
# Ramping V_pl_A to 3.95e+00
# Done ramping
# Ramping V_cut_A to 3.96e+00
# Done ramping
# Ramping V_bot_A to 3.96e+00
# Done ramping
# Ramping V_pl_A to 3.96e+00
# Done ramping
# Ramping V_cut_A to 3.96e+00
# Done ramping
# Ramping V_bot_A to 3.96e+00
# Done ramping
# Ramping V_pl_A to 3.96e+00
# Done ramping
# Ramping V_cut_A to 3.97e+00
# Done ramping
# Ramping V_bot_A to 3.97e+00
# Done ramping
# Ramping V_pl_A to 3.97e+00
# Done ramping
# Ramping V_cut_A to 3.97e+00
# Done ramping
# Ramping V_bot_A to 3.97e+00
# Done ramping
# Ramping V_pl_A to 3.97e+00
# Done ramping
# Ramping V_cut_A to 3.98e+00
# Done ramping
# Ramping V_bot_A to 3.98e+00
# Done ramping
# Ramping V_pl_A to 3.98e+00
# Done ramping
# Ramping V_cut_A to 3.98e+00
# Done ramping
# Ramping V_bot_A to 3.98e+00
# Done ramping
# Ramping V_pl_A to 3.98e+00
# Done ramping
# Ramping V_cut_A to 3.98e+00
# Done ramping
# Ramping V_bot_A to 3.98e+00
# Done ramping
# Ramping V_pl_A to 3.98e+00
# Done ramping
# Ramping V_cut_A to 3.99e+00
# Done ramping
# Ramping V_bot_A to 3.99e+00
# Done ramping
# Ramping V_pl_A to 3.99e+00
# Done ramping
# Ramping V_cut_A to 4.00e+00
# Done ramping
# Ramping V_bot_A to 4.00e+00
# Done ramping
# Ramping V_pl_A to 4.00e+00
# Done ramping
#  Time elapsed: 24665.7295

# %%
get_yoko_field()
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-127-d20edc2f8aa1> in <module>()
# ----> 1 get_yoko_field()
#
# <ipython-input-55-b0358f9f9119> in get_yoko_field(current_rating)
#      14     returns the field in Tesla
#      15     """
# ---> 16     return yoko1.current() / current_rating
#      17 print(get_yoko_field())
#      18
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     404             except Exception as e:
#     405                 e.args = e.args + ('getting {}'.format(self),)
# --> 406                 raise e
#     407
#     408         return get_wrapper
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\yokogawa\GS200.py in _get_set_output(self, mode, output_level)
#     367             return None
#     368         else:
# --> 369             return float(self.ask(":SOUR:LEV?"))
#     370
#     371     def _set_output(self, output_level: float) -> None:
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     744             inst = repr(self)
#     745             e.args = e.args + ('asking ' + repr(cmd) + ' to ' + inst,)
# --> 746             raise e
#     747
#     748     def ask_raw(self, cmd: str) -> str:
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     737         """
#     738         try:
# --> 739             answer = self.ask_raw(cmd)
#     740
#     741             return answer
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\visa.py in ask_raw(self, cmd)
#     227         """
#     228         self.visa_log.debug(f"Querying: {cmd}")
# --> 229         response = self.visa_handle.query(cmd)
#     230         self.visa_log.debug(f"Response: {response}")
#     231         return response
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in query(self, message, delay)
#     561         """
#     562
# --> 563         self.write(message)
#     564
#     565         delay = self.query_delay if delay is None else delay
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write(self, message, termination, encoding)
#     221             message += term
#     222
# --> 223         count = self.write_raw(message.encode(enco))
#     224
#     225         return count
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write_raw(self, message)
#     199         :rtype: int
#     200         """
# --> 201         return self.visalib.write(self.session, message)
#     202
#     203     def write(self, message, termination=None, encoding=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\functions.py in write(library, session, data)
#    1864     return_count = ViUInt32()
#    1865     # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 1866     ret = library.viWrite(session, data, len(data), byref(return_count))
#    1867     return return_count.value, ret
#    1868
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     186
#     187         if ret_value < 0:
# --> 188             raise errors.VisaIOError(ret_value)
#     189
#     190         if ret_value in self.issue_warning_on:
#
# VisaIOError: ('VI_ERROR_SYSTEM_ERROR (-1073807360): Unknown system error (miscellaneous error).', "asking ':SOUR:LEV?' to <GS200: yoko1>", 'getting yoko1_current')

# %% [markdown]
# ## Multiple gate setting: Magnet 1D sweep

# %%
power = -39
n_pts = 500
n_avg = 500
f = 4.84725e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

B_fields = np.arange(0,2.5e-3,2e-6)

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")
gate_channel = [MDAC_channels['V_cut_A'], MDAC_channels['V_bot_A'], MDAC_channels['V_pl_A']]

gate_voltages = 4
gate_name = ['V_cut_A', 'V_bot_A', 'V_pl_A']

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_name:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
print("ramping up gates")
for gate in gate_name:
    ramp(MDAC_channels[gate].voltage, gate_voltages, gate_ramp_stepsize, gate_ramp_delay)
#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 100, f_start = f-2e6, f_stop = f+2e6, power=power, n_avg=1000, channel_name='S12')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_field_sweep_single_frequency(B_fields, power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')


print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# ramping up gates
# Taking single sweep
# Starting experimental run with id: 69
# Taking trace took 13.07645320892334
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 70
# Setting field to 0.0
# Setting field to 2e-06
# Setting field to 4e-06
# Setting field to 6e-06
# Setting field to 8e-06
# Setting field to 1e-05
# Setting field to 1.2e-05
# Setting field to 1.4e-05
# Setting field to 1.6e-05
# Setting field to 1.8e-05
# Setting field to 2e-05
# Setting field to 2.2e-05
# Setting field to 2.4e-05
# Setting field to 2.6e-05
# Setting field to 2.8e-05
# Setting field to 3e-05
# Setting field to 3.2e-05
# Setting field to 3.4e-05
# Setting field to 3.6e-05
# Setting field to 3.8e-05
# Setting field to 4e-05
# Setting field to 4.2e-05
# Setting field to 4.4e-05
# Setting field to 4.6e-05
# Setting field to 4.8e-05
# Setting field to 5e-05
# Setting field to 5.2e-05
# Setting field to 5.4e-05
# Setting field to 5.6e-05
# Setting field to 5.8e-05
# Setting field to 6e-05
# Setting field to 6.2e-05
# Setting field to 6.4e-05
# Setting field to 6.6e-05
# Setting field to 6.8e-05
# Setting field to 7e-05
# Setting field to 7.2e-05
# Setting field to 7.4e-05
# Setting field to 7.6e-05
# Setting field to 7.8e-05
# Setting field to 8e-05
# Setting field to 8.2e-05
# Setting field to 8.4e-05
# Setting field to 8.6e-05
# Setting field to 8.8e-05
# Setting field to 9e-05
# Setting field to 9.2e-05
# Setting field to 9.4e-05
# Setting field to 9.6e-05
# Setting field to 9.8e-05
# Setting field to 0.0001
# Setting field to 0.000102
# Setting field to 0.000104
# Setting field to 0.000106
# Setting field to 0.000108
# Setting field to 0.00011
# Setting field to 0.000112
# Setting field to 0.000114
# Setting field to 0.000116
# Setting field to 0.000118
# Setting field to 0.00012
# Setting field to 0.000122
# Setting field to 0.000124
# Setting field to 0.000126
# Setting field to 0.000128
# Setting field to 0.00013
# Setting field to 0.000132
# Setting field to 0.000134
# Setting field to 0.000136
# Setting field to 0.000138
# Setting field to 0.00014
# Setting field to 0.000142
# Setting field to 0.000144
# Setting field to 0.000146
# Setting field to 0.000148
# Setting field to 0.00015
# Setting field to 0.000152
# Setting field to 0.000154
# Setting field to 0.000156
# Setting field to 0.000158
# Setting field to 0.00016
# Setting field to 0.000162
# Setting field to 0.000164
# Setting field to 0.000166
# Setting field to 0.000168
# Setting field to 0.00017
# Setting field to 0.000172
# Setting field to 0.000174
# Setting field to 0.000176
# Setting field to 0.000178
# Setting field to 0.00018
# Setting field to 0.000182
# Setting field to 0.000184
# Setting field to 0.000186
# Setting field to 0.000188
# Setting field to 0.00019
# Setting field to 0.000192
# Setting field to 0.000194
# Setting field to 0.000196
# Setting field to 0.000198
# Setting field to 0.0002
# Setting field to 0.000202
# Setting field to 0.000204
# Setting field to 0.000206
# Setting field to 0.000208
# Setting field to 0.00021
# Setting field to 0.000212
# Setting field to 0.000214
# Setting field to 0.000216
# Setting field to 0.000218
# Setting field to 0.00022
# Setting field to 0.000222
# Setting field to 0.000224
# Setting field to 0.000226
# Setting field to 0.000228
# Setting field to 0.00023
# Setting field to 0.000232
# Setting field to 0.000234
# Setting field to 0.000236
# Setting field to 0.000238
# Setting field to 0.00024
# Setting field to 0.000242
# Setting field to 0.000244
# Setting field to 0.000246
# Setting field to 0.000248
# Setting field to 0.00025
# Setting field to 0.000252
# Setting field to 0.000254
# Setting field to 0.000256
# Setting field to 0.000258
# Setting field to 0.00026
# Setting field to 0.000262
# Setting field to 0.000264
# Setting field to 0.000266
# Setting field to 0.000268
# Setting field to 0.00027
# Setting field to 0.000272
# Setting field to 0.000274
# Setting field to 0.000276
# Setting field to 0.000278
# Setting field to 0.00028
# Setting field to 0.000282
# Setting field to 0.000284
# Setting field to 0.000286
# Setting field to 0.000288
# Setting field to 0.00029
# Setting field to 0.000292
# Setting field to 0.000294
# Setting field to 0.000296
# Setting field to 0.000298
# Setting field to 0.0003
# Setting field to 0.000302
# Setting field to 0.000304
# Setting field to 0.000306
# Setting field to 0.000308
# Setting field to 0.00031
# Setting field to 0.000312
# Setting field to 0.000314
# Setting field to 0.000316
# Setting field to 0.000318
# Setting field to 0.00032
# Setting field to 0.000322
# Setting field to 0.000324
# Setting field to 0.000326
# Setting field to 0.000328
# Setting field to 0.00033
# Setting field to 0.000332
# Setting field to 0.000334
# Setting field to 0.000336
# Setting field to 0.000338
# Setting field to 0.00034
# Setting field to 0.000342
# Setting field to 0.000344
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-626960fa2d05> in <module>()
#      30
#      31 #now do the real thing
# ---> 32 do_field_sweep_single_frequency(B_fields, power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')
#      33
#      34
#
# <ipython-input-122-a6f06a6945a4> in do_field_sweep_single_frequency(B_ys, power, n_pts, f, n_avg, channel_name)
#     165             set_yoko_field(field)
#     166
# --> 167             result= measure_and_process_point_vna(chan=channel_name)
#     168
#     169             result.extend([
#
# <ipython-input-122-a6f06a6945a4> in measure_and_process_point_vna(chan)
#      35     magnitude_dB
#      36     """
# ---> 37     mag, phase = measure_mag_phase_point_vna(chan=channel_name)
#      38     mag_db = 20*np.log10(mag) #convert to dB
#      39     result = [
#
# <ipython-input-122-a6f06a6945a4> in measure_mag_phase_point_vna(chan)
#      23 def measure_mag_phase_point_vna(chan='S12'):
#      24     vna_channel = getattr(vna.channels, chan)
# ---> 25     mag, phase = vna_channel.trace_mag_phase()
#      26
#      27     return np.mean(mag), np.mean(phase)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in get_raw(self)
#      40         old_format = self._instrument.format()
#      41         self._instrument.format('Complex')
# ---> 42         data = self._instrument._get_sweep_data(force_polar = True)
#      43         self._instrument.format(old_format)
#      44         return abs(data), np.angle(data)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in _get_sweep_data(self, force_polar)
#     348             # need to ensure averaged result is returned
#     349             for avgcount in range(self.avg()):
# --> 350                 self.write('INIT{}:IMM; *WAI'.format(self._instrument_channel))
#     351             data_str = self.ask(
#     352                 'CALC{}:DATA? {}'.format(self._instrument_channel,
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\channel.py in write(self, cmd)
#      60     # Pass any commands to read or write from the instrument up to the parent
#      61     def write(self, cmd):
# ---> 62         return self._parent.write(cmd)
#      63
#      64     def write_raw(self, cmd):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in write(self, cmd)
#     697         """
#     698         try:
# --> 699             self.write_raw(cmd)
#     700         except Exception as e:
#     701             inst = repr(self)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\visa.py in write_raw(self, cmd)
#     213         self.visa_log.debug(f"Writing: {cmd}")
#     214
# --> 215         nr_bytes_written, ret_code = self.visa_handle.write(cmd)
#     216         self.check_error(ret_code)
#     217
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write(self, message, termination, encoding)
#     221             message += term
#     222
# --> 223         count = self.write_raw(message.encode(enco))
#     224
#     225         return count
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write_raw(self, message)
#     199         :rtype: int
#     200         """
# --> 201         return self.visalib.write(self.session, message)
#     202
#     203     def write(self, message, termination=None, encoding=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\functions.py in write(library, session, data)
#    1864     return_count = ViUInt32()
#    1865     # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 1866     ret = library.viWrite(session, data, len(data), byref(return_count))
#    1867     return return_count.value, ret
#    1868
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     147             setattr(self, method_name, getattr(self.lib, method_name))
#     148
# --> 149     def _return_handler(self, ret_value, func, arguments):
#     150         """Check return values for errors and warnings.
#     151         """
#
# KeyboardInterrupt:

# %% [markdown]
# ## Multiple axis Magnet sweep

# %%
power = -30
n_pts = 200
n_avg = 200
f = 4.84725e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

B_fields = np.arange(0,1e-3,1e-6)
phis = np.arange(80,100,2.5) # in degrees
thetas = [90] #in degrees

phis_rad=np.radians(phis) #convert to radians
thetas_rad = np.radians(thetas)

gate_channel = [MDAC_channels['V_cut_A'], MDAC_channels['V_bot_A'], MDAC_channels['V_pl_A']]

gate_voltages = 4
gate_name = ['V_cut_A', 'V_bot_A', 'V_pl_A']

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_name:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
print("ramping up gates")
for gate in gate_name:
    ramp(MDAC_channels[gate].voltage, gate_voltages, gate_ramp_stepsize, gate_ramp_delay)
#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 100, f_start = f-4e6, f_stop = f+4e6, power=power, n_avg=1000, channel_name='S12')
    print("Taking trace took", time.time()-t0)

    
#now do the real thing
for i in range(len(phis)):
    for j in range(len(thetas)):
        exp = qc.new_experiment("field phi=%d theta=%d, freq f=%.5e power=%d n=%d x %d" %(phis[i],thetas[j],f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")
        do_3D_field_sweep_single_frequency(B_fields, phis_rad[i], thetas_rad[j],  power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')
# Out:
# ramping up gates
# Taking single sweep
# Starting experimental run with id: 74
# Taking trace took 13.06200098991394
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 75
# Setting field (magntidue) to 0.0
# Setting x, y, z to 0.000e+00, 0.000e+00, 0.000e+00
# Setting field (magntidue) to 1e-06
# Setting x, y, z to 1.736e-07, 9.848e-07, 6.123e-23
# Setting field (magntidue) to 2e-06
# Setting x, y, z to 3.473e-07, 1.970e-06, 1.225e-22
# Setting field (magntidue) to 3e-06
# Setting x, y, z to 5.209e-07, 2.954e-06, 1.837e-22
# Setting field (magntidue) to 4e-06
# Setting x, y, z to 6.946e-07, 3.939e-06, 2.449e-22
# Setting field (magntidue) to 5e-06
# Setting x, y, z to 8.682e-07, 4.924e-06, 3.062e-22
# Setting field (magntidue) to 6e-06
# Setting x, y, z to 1.042e-06, 5.909e-06, 3.674e-22
# Setting field (magntidue) to 7e-06
# Setting x, y, z to 1.216e-06, 6.894e-06, 4.286e-22
# Setting field (magntidue) to 8e-06
# Setting x, y, z to 1.389e-06, 7.878e-06, 4.899e-22
# Setting field (magntidue) to 9e-06
# Setting x, y, z to 1.563e-06, 8.863e-06, 5.511e-22
# Setting field (magntidue) to 1e-05
# Setting x, y, z to 1.736e-06, 9.848e-06, 6.123e-22
# Setting field (magntidue) to 1.1e-05
# Setting x, y, z to 1.910e-06, 1.083e-05, 6.736e-22
# Setting field (magntidue) to 1.2e-05
# Setting x, y, z to 2.084e-06, 1.182e-05, 7.348e-22
# Setting field (magntidue) to 1.3e-05
# Setting x, y, z to 2.257e-06, 1.280e-05, 7.960e-22
# Setting field (magntidue) to 1.4e-05
# Setting x, y, z to 2.431e-06, 1.379e-05, 8.573e-22
# Setting field (magntidue) to 1.5e-05
# Setting x, y, z to 2.605e-06, 1.477e-05, 9.185e-22
# Setting field (magntidue) to 1.6e-05
# Setting x, y, z to 2.778e-06, 1.576e-05, 9.797e-22
# Setting field (magntidue) to 1.7e-05
# Setting x, y, z to 2.952e-06, 1.674e-05, 1.041e-21
# Setting field (magntidue) to 1.8e-05
# Setting x, y, z to 3.126e-06, 1.773e-05, 1.102e-21
# Setting field (magntidue) to 1.9e-05
# Setting x, y, z to 3.299e-06, 1.871e-05, 1.163e-21
# Setting field (magntidue) to 2e-05
# Setting x, y, z to 3.473e-06, 1.970e-05, 1.225e-21
# Setting field (magntidue) to 2.1e-05
# Setting x, y, z to 3.647e-06, 2.068e-05, 1.286e-21
# Setting field (magntidue) to 2.2e-05
# Setting x, y, z to 3.820e-06, 2.167e-05, 1.347e-21
# Setting field (magntidue) to 2.3e-05
# Setting x, y, z to 3.994e-06, 2.265e-05, 1.408e-21
# Setting field (magntidue) to 2.4e-05
# Setting x, y, z to 4.168e-06, 2.364e-05, 1.470e-21
# Setting field (magntidue) to 2.5e-05
# Setting x, y, z to 4.341e-06, 2.462e-05, 1.531e-21
# Setting field (magntidue) to 2.6e-05
# Setting x, y, z to 4.515e-06, 2.561e-05, 1.592e-21
# Setting field (magntidue) to 2.7e-05
# Setting x, y, z to 4.689e-06, 2.659e-05, 1.653e-21
# Setting field (magntidue) to 2.8e-05
# Setting x, y, z to 4.862e-06, 2.757e-05, 1.715e-21
# Setting field (magntidue) to 2.9e-05
# Setting x, y, z to 5.036e-06, 2.856e-05, 1.776e-21
# Setting field (magntidue) to 3e-05
# Setting x, y, z to 5.209e-06, 2.954e-05, 1.837e-21
# Setting field (magntidue) to 3.1e-05
# Setting x, y, z to 5.383e-06, 3.053e-05, 1.898e-21
# Setting field (magntidue) to 3.2e-05
# Setting x, y, z to 5.557e-06, 3.151e-05, 1.959e-21
# Setting field (magntidue) to 3.3e-05
# Setting x, y, z to 5.730e-06, 3.250e-05, 2.021e-21
# Setting field (magntidue) to 3.4e-05
# Setting x, y, z to 5.904e-06, 3.348e-05, 2.082e-21
# Setting field (magntidue) to 3.5e-05
# Setting x, y, z to 6.078e-06, 3.447e-05, 2.143e-21
# Setting field (magntidue) to 3.6e-05
# Setting x, y, z to 6.251e-06, 3.545e-05, 2.204e-21
# Setting field (magntidue) to 3.7e-05
# Setting x, y, z to 6.425e-06, 3.644e-05, 2.266e-21
# Setting field (magntidue) to 3.8e-05
# Setting x, y, z to 6.599e-06, 3.742e-05, 2.327e-21
# Setting field (magntidue) to 3.9e-05
# Setting x, y, z to 6.772e-06, 3.841e-05, 2.388e-21
# Setting field (magntidue) to 4e-05
# Setting x, y, z to 6.946e-06, 3.939e-05, 2.449e-21
# Setting field (magntidue) to 4.1e-05
# Setting x, y, z to 7.120e-06, 4.038e-05, 2.511e-21
# Setting field (magntidue) to 4.2e-05
# Setting x, y, z to 7.293e-06, 4.136e-05, 2.572e-21
# Setting field (magntidue) to 4.3e-05
# Setting x, y, z to 7.467e-06, 4.235e-05, 2.633e-21
# Setting field (magntidue) to 4.4e-05
# Setting x, y, z to 7.641e-06, 4.333e-05, 2.694e-21
# Setting field (magntidue) to 4.5e-05
# Setting x, y, z to 7.814e-06, 4.432e-05, 2.755e-21
# Setting field (magntidue) to 4.6e-05
# Setting x, y, z to 7.988e-06, 4.530e-05, 2.817e-21
# Setting field (magntidue) to 4.7e-05
# Setting x, y, z to 8.161e-06, 4.629e-05, 2.878e-21
# Setting field (magntidue) to 4.8e-05
# Setting x, y, z to 8.335e-06, 4.727e-05, 2.939e-21
# Setting field (magntidue) to 4.9e-05
# Setting x, y, z to 8.509e-06, 4.826e-05, 3.000e-21
# Setting field (magntidue) to 5e-05
# Setting x, y, z to 8.682e-06, 4.924e-05, 3.062e-21
# Setting field (magntidue) to 5.1e-05
# Setting x, y, z to 8.856e-06, 5.023e-05, 3.123e-21
# Setting field (magntidue) to 5.2e-05
# Setting x, y, z to 9.030e-06, 5.121e-05, 3.184e-21
# Setting field (magntidue) to 5.3e-05
# Setting x, y, z to 9.203e-06, 5.219e-05, 3.245e-21
# Setting field (magntidue) to 5.4e-05
# Setting x, y, z to 9.377e-06, 5.318e-05, 3.307e-21
# Setting field (magntidue) to 5.5e-05
# Setting x, y, z to 9.551e-06, 5.416e-05, 3.368e-21
# Setting field (magntidue) to 5.6e-05
# Setting x, y, z to 9.724e-06, 5.515e-05, 3.429e-21
# Setting field (magntidue) to 5.7e-05
# Setting x, y, z to 9.898e-06, 5.613e-05, 3.490e-21
# Setting field (magntidue) to 5.8e-05
# Setting x, y, z to 1.007e-05, 5.712e-05, 3.551e-21
# Setting field (magntidue) to 5.9e-05
# Setting x, y, z to 1.025e-05, 5.810e-05, 3.613e-21
# Setting field (magntidue) to 6e-05
# Setting x, y, z to 1.042e-05, 5.909e-05, 3.674e-21
# Setting field (magntidue) to 6.1e-05
# Setting x, y, z to 1.059e-05, 6.007e-05, 3.735e-21
# Setting field (magntidue) to 6.2e-05
# Setting x, y, z to 1.077e-05, 6.106e-05, 3.796e-21
# Setting field (magntidue) to 6.3e-05
# Setting x, y, z to 1.094e-05, 6.204e-05, 3.858e-21
# Setting field (magntidue) to 6.4e-05
# Setting x, y, z to 1.111e-05, 6.303e-05, 3.919e-21
# Setting field (magntidue) to 6.5e-05
# Setting x, y, z to 1.129e-05, 6.401e-05, 3.980e-21
# Setting field (magntidue) to 6.6e-05
# Setting x, y, z to 1.146e-05, 6.500e-05, 4.041e-21
# Setting field (magntidue) to 6.7e-05
# Setting x, y, z to 1.163e-05, 6.598e-05, 4.103e-21
# Setting field (magntidue) to 6.8e-05
# Setting x, y, z to 1.181e-05, 6.697e-05, 4.164e-21
# Setting field (magntidue) to 6.9e-05
# Setting x, y, z to 1.198e-05, 6.795e-05, 4.225e-21
# Setting field (magntidue) to 7e-05
# Setting x, y, z to 1.216e-05, 6.894e-05, 4.286e-21
# Setting field (magntidue) to 7.1e-05
# Setting x, y, z to 1.233e-05, 6.992e-05, 4.347e-21
# Setting field (magntidue) to 7.2e-05
# Setting x, y, z to 1.250e-05, 7.091e-05, 4.409e-21
# Setting field (magntidue) to 7.3e-05
# Setting x, y, z to 1.268e-05, 7.189e-05, 4.470e-21
# Setting field (magntidue) to 7.4e-05
# Setting x, y, z to 1.285e-05, 7.288e-05, 4.531e-21
# Setting field (magntidue) to 7.5e-05
# Setting x, y, z to 1.302e-05, 7.386e-05, 4.592e-21
# Setting field (magntidue) to 7.6e-05
# Setting x, y, z to 1.320e-05, 7.485e-05, 4.654e-21
# Setting field (magntidue) to 7.7e-05
# Setting x, y, z to 1.337e-05, 7.583e-05, 4.715e-21
# Setting field (magntidue) to 7.8e-05
# Setting x, y, z to 1.354e-05, 7.682e-05, 4.776e-21
# Setting field (magntidue) to 7.9e-05
# Setting x, y, z to 1.372e-05, 7.780e-05, 4.837e-21
# Setting field (magntidue) to 8e-05
# Setting x, y, z to 1.389e-05, 7.878e-05, 4.899e-21
# Setting field (magntidue) to 8.1e-05
# Setting x, y, z to 1.407e-05, 7.977e-05, 4.960e-21
# Setting field (magntidue) to 8.2e-05
# Setting x, y, z to 1.424e-05, 8.075e-05, 5.021e-21
# Setting field (magntidue) to 8.3e-05
# Setting x, y, z to 1.441e-05, 8.174e-05, 5.082e-21
# Setting field (magntidue) to 8.4e-05
# Setting x, y, z to 1.459e-05, 8.272e-05, 5.144e-21
# Setting field (magntidue) to 8.5e-05
# Setting x, y, z to 1.476e-05, 8.371e-05, 5.205e-21
# Setting field (magntidue) to 8.6e-05
# Setting x, y, z to 1.493e-05, 8.469e-05, 5.266e-21
# Setting field (magntidue) to 8.7e-05
# Setting x, y, z to 1.511e-05, 8.568e-05, 5.327e-21
# Setting field (magntidue) to 8.8e-05
# Setting x, y, z to 1.528e-05, 8.666e-05, 5.388e-21
# Setting field (magntidue) to 8.9e-05
# Setting x, y, z to 1.545e-05, 8.765e-05, 5.450e-21
# Setting field (magntidue) to 9e-05
# Setting x, y, z to 1.563e-05, 8.863e-05, 5.511e-21
# Setting field (magntidue) to 9.1e-05
# Setting x, y, z to 1.580e-05, 8.962e-05, 5.572e-21
# Setting field (magntidue) to 9.2e-05
# Setting x, y, z to 1.598e-05, 9.060e-05, 5.633e-21
# Setting field (magntidue) to 9.3e-05
# Setting x, y, z to 1.615e-05, 9.159e-05, 5.695e-21
# Setting field (magntidue) to 9.4e-05
# Setting x, y, z to 1.632e-05, 9.257e-05, 5.756e-21
# Setting field (magntidue) to 9.5e-05
# Setting x, y, z to 1.650e-05, 9.356e-05, 5.817e-21
# Setting field (magntidue) to 9.6e-05
# Setting x, y, z to 1.667e-05, 9.454e-05, 5.878e-21
# Setting field (magntidue) to 9.7e-05
# Setting x, y, z to 1.684e-05, 9.553e-05, 5.940e-21
# Setting field (magntidue) to 9.8e-05
# Setting x, y, z to 1.702e-05, 9.651e-05, 6.001e-21
# Setting field (magntidue) to 9.9e-05
# Setting x, y, z to 1.719e-05, 9.750e-05, 6.062e-21
# Setting field (magntidue) to 0.0001
# Setting x, y, z to 1.736e-05, 9.848e-05, 6.123e-21
# Setting field (magntidue) to 0.000101
# Setting x, y, z to 1.754e-05, 9.947e-05, 6.184e-21
# Setting field (magntidue) to 0.000102
# Setting x, y, z to 1.771e-05, 1.005e-04, 6.246e-21
# Setting field (magntidue) to 0.000103
# Setting x, y, z to 1.789e-05, 1.014e-04, 6.307e-21
# Setting field (magntidue) to 0.000104
# Setting x, y, z to 1.806e-05, 1.024e-04, 6.368e-21
# Setting field (magntidue) to 0.000105
# Setting x, y, z to 1.823e-05, 1.034e-04, 6.429e-21
# Setting field (magntidue) to 0.000106
# Setting x, y, z to 1.841e-05, 1.044e-04, 6.491e-21
# Setting field (magntidue) to 0.000107
# Setting x, y, z to 1.858e-05, 1.054e-04, 6.552e-21
# Setting field (magntidue) to 0.000108
# Setting x, y, z to 1.875e-05, 1.064e-04, 6.613e-21
# Setting field (magntidue) to 0.000109
# Setting x, y, z to 1.893e-05, 1.073e-04, 6.674e-21
# Setting field (magntidue) to 0.00011
# Setting x, y, z to 1.910e-05, 1.083e-04, 6.736e-21
# Setting field (magntidue) to 0.000111
# Setting x, y, z to 1.927e-05, 1.093e-04, 6.797e-21
# Setting field (magntidue) to 0.000112
# Setting x, y, z to 1.945e-05, 1.103e-04, 6.858e-21
# Setting field (magntidue) to 0.000113
# Setting x, y, z to 1.962e-05, 1.113e-04, 6.919e-21
# Setting field (magntidue) to 0.000114
# Setting x, y, z to 1.980e-05, 1.123e-04, 6.980e-21
# Setting field (magntidue) to 0.000115
# Setting x, y, z to 1.997e-05, 1.133e-04, 7.042e-21
# Setting field (magntidue) to 0.000116
# Setting x, y, z to 2.014e-05, 1.142e-04, 7.103e-21
# Setting field (magntidue) to 0.000117
# Setting x, y, z to 2.032e-05, 1.152e-04, 7.164e-21
# Setting field (magntidue) to 0.000118
# Setting x, y, z to 2.049e-05, 1.162e-04, 7.225e-21
# Setting field (magntidue) to 0.000119
# Setting x, y, z to 2.066e-05, 1.172e-04, 7.287e-21
# Setting field (magntidue) to 0.00012
# Setting x, y, z to 2.084e-05, 1.182e-04, 7.348e-21
# Setting field (magntidue) to 0.000121
# Setting x, y, z to 2.101e-05, 1.192e-04, 7.409e-21
# Setting field (magntidue) to 0.000122
# Setting x, y, z to 2.119e-05, 1.201e-04, 7.470e-21
# Setting field (magntidue) to 0.000123
# Setting x, y, z to 2.136e-05, 1.211e-04, 7.532e-21
# Setting field (magntidue) to 0.000124
# Setting x, y, z to 2.153e-05, 1.221e-04, 7.593e-21
# Setting field (magntidue) to 0.000125
# Setting x, y, z to 2.171e-05, 1.231e-04, 7.654e-21
# Setting field (magntidue) to 0.000126
# Setting x, y, z to 2.188e-05, 1.241e-04, 7.715e-21
# Setting field (magntidue) to 0.000127
# Setting x, y, z to 2.205e-05, 1.251e-04, 7.777e-21
# Setting field (magntidue) to 0.000128
# Setting x, y, z to 2.223e-05, 1.261e-04, 7.838e-21
# Setting field (magntidue) to 0.000129
# Setting x, y, z to 2.240e-05, 1.270e-04, 7.899e-21
# Setting field (magntidue) to 0.00013
# Setting x, y, z to 2.257e-05, 1.280e-04, 7.960e-21
# Setting field (magntidue) to 0.000131
# Setting x, y, z to 2.275e-05, 1.290e-04, 8.021e-21
# Setting field (magntidue) to 0.000132
# Setting x, y, z to 2.292e-05, 1.300e-04, 8.083e-21
# Setting field (magntidue) to 0.000133
# Setting x, y, z to 2.310e-05, 1.310e-04, 8.144e-21
# Setting field (magntidue) to 0.000134
# Setting x, y, z to 2.327e-05, 1.320e-04, 8.205e-21
# Setting field (magntidue) to 0.000135
# Setting x, y, z to 2.344e-05, 1.329e-04, 8.266e-21
# Setting field (magntidue) to 0.000136
# Setting x, y, z to 2.362e-05, 1.339e-04, 8.328e-21
# Setting field (magntidue) to 0.000137
# Setting x, y, z to 2.379e-05, 1.349e-04, 8.389e-21
# Setting field (magntidue) to 0.000138
# Setting x, y, z to 2.396e-05, 1.359e-04, 8.450e-21
# Setting field (magntidue) to 0.000139
# Setting x, y, z to 2.414e-05, 1.369e-04, 8.511e-21
# Setting field (magntidue) to 0.00014
# Setting x, y, z to 2.431e-05, 1.379e-04, 8.573e-21
# Setting field (magntidue) to 0.000141
# Setting x, y, z to 2.448e-05, 1.389e-04, 8.634e-21
# Setting field (magntidue) to 0.000142
# Setting x, y, z to 2.466e-05, 1.398e-04, 8.695e-21
# Setting field (magntidue) to 0.000143
# Setting x, y, z to 2.483e-05, 1.408e-04, 8.756e-21
# Setting field (magntidue) to 0.000144
# Setting x, y, z to 2.501e-05, 1.418e-04, 8.817e-21
# Setting field (magntidue) to 0.000145
# Setting x, y, z to 2.518e-05, 1.428e-04, 8.879e-21
# Setting field (magntidue) to 0.000146
# Setting x, y, z to 2.535e-05, 1.438e-04, 8.940e-21
# Setting field (magntidue) to 0.000147
# Setting x, y, z to 2.553e-05, 1.448e-04, 9.001e-21
# Setting field (magntidue) to 0.000148
# Setting x, y, z to 2.570e-05, 1.458e-04, 9.062e-21
# Setting field (magntidue) to 0.000149
# Setting x, y, z to 2.587e-05, 1.467e-04, 9.124e-21
# Setting field (magntidue) to 0.00015
# Setting x, y, z to 2.605e-05, 1.477e-04, 9.185e-21
# Setting field (magntidue) to 0.000151
# Setting x, y, z to 2.622e-05, 1.487e-04, 9.246e-21
# Setting field (magntidue) to 0.000152
# Setting x, y, z to 2.639e-05, 1.497e-04, 9.307e-21
# Setting field (magntidue) to 0.000153
# Setting x, y, z to 2.657e-05, 1.507e-04, 9.369e-21
# Setting field (magntidue) to 0.000154
# Setting x, y, z to 2.674e-05, 1.517e-04, 9.430e-21
# Setting field (magntidue) to 0.000155
# Setting x, y, z to 2.692e-05, 1.526e-04, 9.491e-21
# Setting field (magntidue) to 0.000156
# Setting x, y, z to 2.709e-05, 1.536e-04, 9.552e-21
# Setting field (magntidue) to 0.000157
# Setting x, y, z to 2.726e-05, 1.546e-04, 9.613e-21
# Setting field (magntidue) to 0.000158
# Setting x, y, z to 2.744e-05, 1.556e-04, 9.675e-21
# Setting field (magntidue) to 0.000159
# Setting x, y, z to 2.761e-05, 1.566e-04, 9.736e-21
# Setting field (magntidue) to 0.00016
# Setting x, y, z to 2.778e-05, 1.576e-04, 9.797e-21
# Setting field (magntidue) to 0.000161
# Setting x, y, z to 2.796e-05, 1.586e-04, 9.858e-21
# Setting field (magntidue) to 0.000162
# Setting x, y, z to 2.813e-05, 1.595e-04, 9.920e-21
# Setting field (magntidue) to 0.000163
# Setting x, y, z to 2.830e-05, 1.605e-04, 9.981e-21
# Setting field (magntidue) to 0.000164
# Setting x, y, z to 2.848e-05, 1.615e-04, 1.004e-20
# Setting field (magntidue) to 0.000165
# Setting x, y, z to 2.865e-05, 1.625e-04, 1.010e-20
# Setting field (magntidue) to 0.000166
# Setting x, y, z to 2.883e-05, 1.635e-04, 1.016e-20
# Setting field (magntidue) to 0.000167
# Setting x, y, z to 2.900e-05, 1.645e-04, 1.023e-20
# Setting field (magntidue) to 0.000168
# Setting x, y, z to 2.917e-05, 1.654e-04, 1.029e-20
# Setting field (magntidue) to 0.000169
# Setting x, y, z to 2.935e-05, 1.664e-04, 1.035e-20
# Setting field (magntidue) to 0.00017
# Setting x, y, z to 2.952e-05, 1.674e-04, 1.041e-20
# Setting field (magntidue) to 0.000171
# Setting x, y, z to 2.969e-05, 1.684e-04, 1.047e-20
# Setting field (magntidue) to 0.000172
# Setting x, y, z to 2.987e-05, 1.694e-04, 1.053e-20
# Setting field (magntidue) to 0.000173
# Setting x, y, z to 3.004e-05, 1.704e-04, 1.059e-20
# Setting field (magntidue) to 0.000174
# Setting x, y, z to 3.021e-05, 1.714e-04, 1.065e-20
# Setting field (magntidue) to 0.000175
# Setting x, y, z to 3.039e-05, 1.723e-04, 1.072e-20
# Setting field (magntidue) to 0.000176
# Setting x, y, z to 3.056e-05, 1.733e-04, 1.078e-20
# Setting field (magntidue) to 0.000177
# Setting x, y, z to 3.074e-05, 1.743e-04, 1.084e-20
# Setting field (magntidue) to 0.000178
# Setting x, y, z to 3.091e-05, 1.753e-04, 1.090e-20
# Setting field (magntidue) to 0.000179
# Setting x, y, z to 3.108e-05, 1.763e-04, 1.096e-20
# Setting field (magntidue) to 0.00018
# Setting x, y, z to 3.126e-05, 1.773e-04, 1.102e-20
# Setting field (magntidue) to 0.000181
# Setting x, y, z to 3.143e-05, 1.783e-04, 1.108e-20
# Setting field (magntidue) to 0.000182
# Setting x, y, z to 3.160e-05, 1.792e-04, 1.114e-20
# Setting field (magntidue) to 0.000183
# Setting x, y, z to 3.178e-05, 1.802e-04, 1.121e-20
# Setting field (magntidue) to 0.000184
# Setting x, y, z to 3.195e-05, 1.812e-04, 1.127e-20
# Setting field (magntidue) to 0.000185
# Setting x, y, z to 3.212e-05, 1.822e-04, 1.133e-20
# Setting field (magntidue) to 0.000186
# Setting x, y, z to 3.230e-05, 1.832e-04, 1.139e-20
# Setting field (magntidue) to 0.000187
# Setting x, y, z to 3.247e-05, 1.842e-04, 1.145e-20
# Setting field (magntidue) to 0.000188
# Setting x, y, z to 3.265e-05, 1.851e-04, 1.151e-20
# Setting field (magntidue) to 0.000189
# Setting x, y, z to 3.282e-05, 1.861e-04, 1.157e-20
# Setting field (magntidue) to 0.00019
# Setting x, y, z to 3.299e-05, 1.871e-04, 1.163e-20
# Setting field (magntidue) to 0.000191
# Setting x, y, z to 3.317e-05, 1.881e-04, 1.170e-20
# Setting field (magntidue) to 0.000192
# Setting x, y, z to 3.334e-05, 1.891e-04, 1.176e-20
# Setting field (magntidue) to 0.000193
# Setting x, y, z to 3.351e-05, 1.901e-04, 1.182e-20
# Setting field (magntidue) to 0.000194
# Setting x, y, z to 3.369e-05, 1.911e-04, 1.188e-20
# Setting field (magntidue) to 0.000195
# Setting x, y, z to 3.386e-05, 1.920e-04, 1.194e-20
# Setting field (magntidue) to 0.000196
# Setting x, y, z to 3.404e-05, 1.930e-04, 1.200e-20
# Setting field (magntidue) to 0.000197
# Setting x, y, z to 3.421e-05, 1.940e-04, 1.206e-20
# Setting field (magntidue) to 0.000198
# Setting x, y, z to 3.438e-05, 1.950e-04, 1.212e-20
# Setting field (magntidue) to 0.000199
# Setting x, y, z to 3.456e-05, 1.960e-04, 1.219e-20
# Setting field (magntidue) to 0.0002
# Setting x, y, z to 3.473e-05, 1.970e-04, 1.225e-20
# Setting field (magntidue) to 0.000201
# Setting x, y, z to 3.490e-05, 1.979e-04, 1.231e-20
# Setting field (magntidue) to 0.000202
# Setting x, y, z to 3.508e-05, 1.989e-04, 1.237e-20
# Setting field (magntidue) to 0.000203
# Setting x, y, z to 3.525e-05, 1.999e-04, 1.243e-20
# Setting field (magntidue) to 0.000204
# Setting x, y, z to 3.542e-05, 2.009e-04, 1.249e-20
# Setting field (magntidue) to 0.000205
# Setting x, y, z to 3.560e-05, 2.019e-04, 1.255e-20
# Setting field (magntidue) to 0.000206
# Setting x, y, z to 3.577e-05, 2.029e-04, 1.261e-20
# Setting field (magntidue) to 0.000207
# Setting x, y, z to 3.595e-05, 2.039e-04, 1.268e-20
# Setting field (magntidue) to 0.000208
# Setting x, y, z to 3.612e-05, 2.048e-04, 1.274e-20
# Setting field (magntidue) to 0.000209
# Setting x, y, z to 3.629e-05, 2.058e-04, 1.280e-20
# Setting field (magntidue) to 0.00021
# Setting x, y, z to 3.647e-05, 2.068e-04, 1.286e-20
# Setting field (magntidue) to 0.000211
# Setting x, y, z to 3.664e-05, 2.078e-04, 1.292e-20
# Setting field (magntidue) to 0.000212
# Setting x, y, z to 3.681e-05, 2.088e-04, 1.298e-20
# Setting field (magntidue) to 0.000213
# Setting x, y, z to 3.699e-05, 2.098e-04, 1.304e-20
# Setting field (magntidue) to 0.000214
# Setting x, y, z to 3.716e-05, 2.107e-04, 1.310e-20
# Setting field (magntidue) to 0.000215
# Setting x, y, z to 3.733e-05, 2.117e-04, 1.316e-20
# Setting field (magntidue) to 0.000216
# Setting x, y, z to 3.751e-05, 2.127e-04, 1.323e-20
# Setting field (magntidue) to 0.000217
# Setting x, y, z to 3.768e-05, 2.137e-04, 1.329e-20
# Setting field (magntidue) to 0.000218
# Setting x, y, z to 3.786e-05, 2.147e-04, 1.335e-20
# Setting field (magntidue) to 0.000219
# Setting x, y, z to 3.803e-05, 2.157e-04, 1.341e-20
# Setting field (magntidue) to 0.00022
# Setting x, y, z to 3.820e-05, 2.167e-04, 1.347e-20
# Setting field (magntidue) to 0.000221
# Setting x, y, z to 3.838e-05, 2.176e-04, 1.353e-20
# Setting field (magntidue) to 0.000222
# Setting x, y, z to 3.855e-05, 2.186e-04, 1.359e-20
# Setting field (magntidue) to 0.000223
# Setting x, y, z to 3.872e-05, 2.196e-04, 1.365e-20
# Setting field (magntidue) to 0.000224
# Setting x, y, z to 3.890e-05, 2.206e-04, 1.372e-20
# Setting field (magntidue) to 0.000225
# Setting x, y, z to 3.907e-05, 2.216e-04, 1.378e-20
# Setting field (magntidue) to 0.000226
# Setting x, y, z to 3.924e-05, 2.226e-04, 1.384e-20
# Setting field (magntidue) to 0.000227
# Setting x, y, z to 3.942e-05, 2.236e-04, 1.390e-20
# Setting field (magntidue) to 0.000228
# Setting x, y, z to 3.959e-05, 2.245e-04, 1.396e-20
# Setting field (magntidue) to 0.000229
# Setting x, y, z to 3.977e-05, 2.255e-04, 1.402e-20
# Setting field (magntidue) to 0.00023
# Setting x, y, z to 3.994e-05, 2.265e-04, 1.408e-20
# Setting field (magntidue) to 0.000231
# Setting x, y, z to 4.011e-05, 2.275e-04, 1.414e-20
# Setting field (magntidue) to 0.000232
# Setting x, y, z to 4.029e-05, 2.285e-04, 1.421e-20
# Setting field (magntidue) to 0.000233
# Setting x, y, z to 4.046e-05, 2.295e-04, 1.427e-20
# Setting field (magntidue) to 0.000234
# Setting x, y, z to 4.063e-05, 2.304e-04, 1.433e-20
# Setting field (magntidue) to 0.000235
# Setting x, y, z to 4.081e-05, 2.314e-04, 1.439e-20
# Setting field (magntidue) to 0.000236
# Setting x, y, z to 4.098e-05, 2.324e-04, 1.445e-20
# Setting field (magntidue) to 0.000237
# Setting x, y, z to 4.115e-05, 2.334e-04, 1.451e-20
# Setting field (magntidue) to 0.000238
# Setting x, y, z to 4.133e-05, 2.344e-04, 1.457e-20
# Setting field (magntidue) to 0.000239
# Setting x, y, z to 4.150e-05, 2.354e-04, 1.463e-20
# Setting field (magntidue) to 0.00024
# Setting x, y, z to 4.168e-05, 2.364e-04, 1.470e-20
# Setting field (magntidue) to 0.000241
# Setting x, y, z to 4.185e-05, 2.373e-04, 1.476e-20
# Setting field (magntidue) to 0.000242
# Setting x, y, z to 4.202e-05, 2.383e-04, 1.482e-20
# Setting field (magntidue) to 0.000243
# Setting x, y, z to 4.220e-05, 2.393e-04, 1.488e-20
# Setting field (magntidue) to 0.000244
# Setting x, y, z to 4.237e-05, 2.403e-04, 1.494e-20
# Setting field (magntidue) to 0.000245
# Setting x, y, z to 4.254e-05, 2.413e-04, 1.500e-20
# Setting field (magntidue) to 0.000246
# Setting x, y, z to 4.272e-05, 2.423e-04, 1.506e-20
# Setting field (magntidue) to 0.000247
# Setting x, y, z to 4.289e-05, 2.432e-04, 1.512e-20
# Setting field (magntidue) to 0.000248
# Setting x, y, z to 4.306e-05, 2.442e-04, 1.519e-20
# Setting field (magntidue) to 0.000249
# Setting x, y, z to 4.324e-05, 2.452e-04, 1.525e-20
# Setting field (magntidue) to 0.00025
# Setting x, y, z to 4.341e-05, 2.462e-04, 1.531e-20
# Setting field (magntidue) to 0.000251
# Setting x, y, z to 4.359e-05, 2.472e-04, 1.537e-20
# Setting field (magntidue) to 0.000252
# Setting x, y, z to 4.376e-05, 2.482e-04, 1.543e-20
# Setting field (magntidue) to 0.000253
# Setting x, y, z to 4.393e-05, 2.492e-04, 1.549e-20
# Setting field (magntidue) to 0.000254
# Setting x, y, z to 4.411e-05, 2.501e-04, 1.555e-20
# Setting field (magntidue) to 0.000255
# Setting x, y, z to 4.428e-05, 2.511e-04, 1.561e-20
# Setting field (magntidue) to 0.000256
# Setting x, y, z to 4.445e-05, 2.521e-04, 1.568e-20
# Setting field (magntidue) to 0.000257
# Setting x, y, z to 4.463e-05, 2.531e-04, 1.574e-20
# Setting field (magntidue) to 0.000258
# Setting x, y, z to 4.480e-05, 2.541e-04, 1.580e-20
# Setting field (magntidue) to 0.000259
# Setting x, y, z to 4.497e-05, 2.551e-04, 1.586e-20
# Setting field (magntidue) to 0.00026
# Setting x, y, z to 4.515e-05, 2.561e-04, 1.592e-20
# Setting field (magntidue) to 0.000261
# Setting x, y, z to 4.532e-05, 2.570e-04, 1.598e-20
# Setting field (magntidue) to 0.000262
# Setting x, y, z to 4.550e-05, 2.580e-04, 1.604e-20
# Setting field (magntidue) to 0.000263
# Setting x, y, z to 4.567e-05, 2.590e-04, 1.610e-20
# Setting field (magntidue) to 0.000264
# Setting x, y, z to 4.584e-05, 2.600e-04, 1.617e-20
# Setting field (magntidue) to 0.000265
# Setting x, y, z to 4.602e-05, 2.610e-04, 1.623e-20
# Setting field (magntidue) to 0.000266
# Setting x, y, z to 4.619e-05, 2.620e-04, 1.629e-20
# Setting field (magntidue) to 0.000267
# Setting x, y, z to 4.636e-05, 2.629e-04, 1.635e-20
# Setting field (magntidue) to 0.000268
# Setting x, y, z to 4.654e-05, 2.639e-04, 1.641e-20
# Setting field (magntidue) to 0.000269
# Setting x, y, z to 4.671e-05, 2.649e-04, 1.647e-20
# Setting field (magntidue) to 0.00027
# Setting x, y, z to 4.689e-05, 2.659e-04, 1.653e-20
# Setting field (magntidue) to 0.000271
# Setting x, y, z to 4.706e-05, 2.669e-04, 1.659e-20
# Setting field (magntidue) to 0.000272
# Setting x, y, z to 4.723e-05, 2.679e-04, 1.666e-20
# Setting field (magntidue) to 0.000273
# Setting x, y, z to 4.741e-05, 2.689e-04, 1.672e-20
# Setting field (magntidue) to 0.000274
# Setting x, y, z to 4.758e-05, 2.698e-04, 1.678e-20
# Setting field (magntidue) to 0.000275
# Setting x, y, z to 4.775e-05, 2.708e-04, 1.684e-20
# Setting field (magntidue) to 0.000276
# Setting x, y, z to 4.793e-05, 2.718e-04, 1.690e-20
# Setting field (magntidue) to 0.000277
# Setting x, y, z to 4.810e-05, 2.728e-04, 1.696e-20
# Setting field (magntidue) to 0.000278
# Setting x, y, z to 4.827e-05, 2.738e-04, 1.702e-20
# Setting field (magntidue) to 0.000279
# Setting x, y, z to 4.845e-05, 2.748e-04, 1.708e-20
# Setting field (magntidue) to 0.00028
# Setting x, y, z to 4.862e-05, 2.757e-04, 1.715e-20
# Setting field (magntidue) to 0.000281
# Setting x, y, z to 4.880e-05, 2.767e-04, 1.721e-20
# Setting field (magntidue) to 0.000282
# Setting x, y, z to 4.897e-05, 2.777e-04, 1.727e-20
# Setting field (magntidue) to 0.000283
# Setting x, y, z to 4.914e-05, 2.787e-04, 1.733e-20
# Setting field (magntidue) to 0.000284
# Setting x, y, z to 4.932e-05, 2.797e-04, 1.739e-20
# Setting field (magntidue) to 0.000285
# Setting x, y, z to 4.949e-05, 2.807e-04, 1.745e-20
# Setting field (magntidue) to 0.000286
# Setting x, y, z to 4.966e-05, 2.817e-04, 1.751e-20
# Setting field (magntidue) to 0.000287
# Setting x, y, z to 4.984e-05, 2.826e-04, 1.757e-20
# Setting field (magntidue) to 0.000288
# Setting x, y, z to 5.001e-05, 2.836e-04, 1.763e-20
# Setting field (magntidue) to 0.000289
# Setting x, y, z to 5.018e-05, 2.846e-04, 1.770e-20
# Setting field (magntidue) to 0.00029
# Setting x, y, z to 5.036e-05, 2.856e-04, 1.776e-20
# Setting field (magntidue) to 0.000291
# Setting x, y, z to 5.053e-05, 2.866e-04, 1.782e-20
# Setting field (magntidue) to 0.000292
# Setting x, y, z to 5.071e-05, 2.876e-04, 1.788e-20
# Setting field (magntidue) to 0.000293
# Setting x, y, z to 5.088e-05, 2.885e-04, 1.794e-20
# Setting field (magntidue) to 0.000294
# Setting x, y, z to 5.105e-05, 2.895e-04, 1.800e-20
# Setting field (magntidue) to 0.000295
# Setting x, y, z to 5.123e-05, 2.905e-04, 1.806e-20
# Setting field (magntidue) to 0.000296
# Setting x, y, z to 5.140e-05, 2.915e-04, 1.812e-20
# Setting field (magntidue) to 0.000297
# Setting x, y, z to 5.157e-05, 2.925e-04, 1.819e-20
# Setting field (magntidue) to 0.000298
# Setting x, y, z to 5.175e-05, 2.935e-04, 1.825e-20
# Setting field (magntidue) to 0.000299
# Setting x, y, z to 5.192e-05, 2.945e-04, 1.831e-20
# Setting field (magntidue) to 0.0003
# Setting x, y, z to 5.209e-05, 2.954e-04, 1.837e-20
# Setting field (magntidue) to 0.000301
# Setting x, y, z to 5.227e-05, 2.964e-04, 1.843e-20
# Setting field (magntidue) to 0.000302
# Setting x, y, z to 5.244e-05, 2.974e-04, 1.849e-20
# Setting field (magntidue) to 0.000303
# Setting x, y, z to 5.262e-05, 2.984e-04, 1.855e-20
# Setting field (magntidue) to 0.000304
# Setting x, y, z to 5.279e-05, 2.994e-04, 1.861e-20
# Setting field (magntidue) to 0.000305
# Setting x, y, z to 5.296e-05, 3.004e-04, 1.868e-20
# Setting field (magntidue) to 0.000306
# Setting x, y, z to 5.314e-05, 3.014e-04, 1.874e-20
# Setting field (magntidue) to 0.000307
# Setting x, y, z to 5.331e-05, 3.023e-04, 1.880e-20
# Setting field (magntidue) to 0.000308
# Setting x, y, z to 5.348e-05, 3.033e-04, 1.886e-20
# Setting field (magntidue) to 0.000309
# Setting x, y, z to 5.366e-05, 3.043e-04, 1.892e-20
# Setting field (magntidue) to 0.00031
# Setting x, y, z to 5.383e-05, 3.053e-04, 1.898e-20
# Setting field (magntidue) to 0.000311
# Setting x, y, z to 5.400e-05, 3.063e-04, 1.904e-20
# Setting field (magntidue) to 0.000312
# Setting x, y, z to 5.418e-05, 3.073e-04, 1.910e-20
# Setting field (magntidue) to 0.000313
# Setting x, y, z to 5.435e-05, 3.082e-04, 1.917e-20
# Setting field (magntidue) to 0.000314
# Setting x, y, z to 5.453e-05, 3.092e-04, 1.923e-20
# Setting field (magntidue) to 0.000315
# Setting x, y, z to 5.470e-05, 3.102e-04, 1.929e-20
# Setting field (magntidue) to 0.000316
# Setting x, y, z to 5.487e-05, 3.112e-04, 1.935e-20
# Setting field (magntidue) to 0.000317
# Setting x, y, z to 5.505e-05, 3.122e-04, 1.941e-20
# Setting field (magntidue) to 0.000318
# Setting x, y, z to 5.522e-05, 3.132e-04, 1.947e-20
# Setting field (magntidue) to 0.000319
# Setting x, y, z to 5.539e-05, 3.142e-04, 1.953e-20
# Setting field (magntidue) to 0.00032
# Setting x, y, z to 5.557e-05, 3.151e-04, 1.959e-20
# Setting field (magntidue) to 0.000321
# Setting x, y, z to 5.574e-05, 3.161e-04, 1.966e-20
# Setting field (magntidue) to 0.000322
# Setting x, y, z to 5.591e-05, 3.171e-04, 1.972e-20
# Setting field (magntidue) to 0.000323
# Setting x, y, z to 5.609e-05, 3.181e-04, 1.978e-20
# Setting field (magntidue) to 0.000324
# Setting x, y, z to 5.626e-05, 3.191e-04, 1.984e-20
# Setting field (magntidue) to 0.000325
# Setting x, y, z to 5.644e-05, 3.201e-04, 1.990e-20
# Setting field (magntidue) to 0.000326
# Setting x, y, z to 5.661e-05, 3.210e-04, 1.996e-20
# Setting field (magntidue) to 0.000327
# Setting x, y, z to 5.678e-05, 3.220e-04, 2.002e-20
# Setting field (magntidue) to 0.000328
# Setting x, y, z to 5.696e-05, 3.230e-04, 2.008e-20
# Setting field (magntidue) to 0.000329
# Setting x, y, z to 5.713e-05, 3.240e-04, 2.015e-20
# Setting field (magntidue) to 0.00033
# Setting x, y, z to 5.730e-05, 3.250e-04, 2.021e-20
# Setting field (magntidue) to 0.000331
# Setting x, y, z to 5.748e-05, 3.260e-04, 2.027e-20
# Setting field (magntidue) to 0.000332
# Setting x, y, z to 5.765e-05, 3.270e-04, 2.033e-20
# Setting field (magntidue) to 0.000333
# Setting x, y, z to 5.782e-05, 3.279e-04, 2.039e-20
# Setting field (magntidue) to 0.000334
# Setting x, y, z to 5.800e-05, 3.289e-04, 2.045e-20
# Setting field (magntidue) to 0.000335
# Setting x, y, z to 5.817e-05, 3.299e-04, 2.051e-20
# Setting field (magntidue) to 0.000336
# Setting x, y, z to 5.835e-05, 3.309e-04, 2.057e-20
# Setting field (magntidue) to 0.000337
# Setting x, y, z to 5.852e-05, 3.319e-04, 2.064e-20
# Setting field (magntidue) to 0.000338
# Setting x, y, z to 5.869e-05, 3.329e-04, 2.070e-20
# Setting field (magntidue) to 0.000339
# Setting x, y, z to 5.887e-05, 3.338e-04, 2.076e-20
# Setting field (magntidue) to 0.00034
# Setting x, y, z to 5.904e-05, 3.348e-04, 2.082e-20
# Setting field (magntidue) to 0.000341
# Setting x, y, z to 5.921e-05, 3.358e-04, 2.088e-20
# Setting field (magntidue) to 0.000342
# Setting x, y, z to 5.939e-05, 3.368e-04, 2.094e-20
# Setting field (magntidue) to 0.000343
# Setting x, y, z to 5.956e-05, 3.378e-04, 2.100e-20
# Setting field (magntidue) to 0.000344
# Setting x, y, z to 5.973e-05, 3.388e-04, 2.106e-20
# Setting field (magntidue) to 0.000345
# Setting x, y, z to 5.991e-05, 3.398e-04, 2.113e-20
# Setting field (magntidue) to 0.000346
# Setting x, y, z to 6.008e-05, 3.407e-04, 2.119e-20
# Setting field (magntidue) to 0.000347
# Setting x, y, z to 6.026e-05, 3.417e-04, 2.125e-20
# Setting field (magntidue) to 0.000348
# Setting x, y, z to 6.043e-05, 3.427e-04, 2.131e-20
# Setting field (magntidue) to 0.000349
# Setting x, y, z to 6.060e-05, 3.437e-04, 2.137e-20
# Setting field (magntidue) to 0.00035
# Setting x, y, z to 6.078e-05, 3.447e-04, 2.143e-20
# Setting field (magntidue) to 0.000351
# Setting x, y, z to 6.095e-05, 3.457e-04, 2.149e-20
# Setting field (magntidue) to 0.000352
# Setting x, y, z to 6.112e-05, 3.467e-04, 2.155e-20
# Setting field (magntidue) to 0.000353
# Setting x, y, z to 6.130e-05, 3.476e-04, 2.162e-20
# Setting field (magntidue) to 0.000354
# Setting x, y, z to 6.147e-05, 3.486e-04, 2.168e-20
# Setting field (magntidue) to 0.000355
# Setting x, y, z to 6.165e-05, 3.496e-04, 2.174e-20
# Setting field (magntidue) to 0.000356
# Setting x, y, z to 6.182e-05, 3.506e-04, 2.180e-20
# Setting field (magntidue) to 0.000357
# Setting x, y, z to 6.199e-05, 3.516e-04, 2.186e-20
# Setting field (magntidue) to 0.000358
# Setting x, y, z to 6.217e-05, 3.526e-04, 2.192e-20
# Setting field (magntidue) to 0.000359
# Setting x, y, z to 6.234e-05, 3.535e-04, 2.198e-20
# Setting field (magntidue) to 0.00036
# Setting x, y, z to 6.251e-05, 3.545e-04, 2.204e-20
# Setting field (magntidue) to 0.000361
# Setting x, y, z to 6.269e-05, 3.555e-04, 2.210e-20
# Setting field (magntidue) to 0.000362
# Setting x, y, z to 6.286e-05, 3.565e-04, 2.217e-20
# Setting field (magntidue) to 0.000363
# Setting x, y, z to 6.303e-05, 3.575e-04, 2.223e-20
# Setting field (magntidue) to 0.000364
# Setting x, y, z to 6.321e-05, 3.585e-04, 2.229e-20
# Setting field (magntidue) to 0.000365
# Setting x, y, z to 6.338e-05, 3.595e-04, 2.235e-20
# Setting field (magntidue) to 0.000366
# Setting x, y, z to 6.356e-05, 3.604e-04, 2.241e-20
# Setting field (magntidue) to 0.000367
# Setting x, y, z to 6.373e-05, 3.614e-04, 2.247e-20
# Setting field (magntidue) to 0.000368
# Setting x, y, z to 6.390e-05, 3.624e-04, 2.253e-20
# Setting field (magntidue) to 0.000369
# Setting x, y, z to 6.408e-05, 3.634e-04, 2.259e-20
# Setting field (magntidue) to 0.00037
# Setting x, y, z to 6.425e-05, 3.644e-04, 2.266e-20
# Setting field (magntidue) to 0.000371
# Setting x, y, z to 6.442e-05, 3.654e-04, 2.272e-20
# Setting field (magntidue) to 0.000372
# Setting x, y, z to 6.460e-05, 3.663e-04, 2.278e-20
# Setting field (magntidue) to 0.000373
# Setting x, y, z to 6.477e-05, 3.673e-04, 2.284e-20
# Setting field (magntidue) to 0.000374
# Setting x, y, z to 6.494e-05, 3.683e-04, 2.290e-20
# Setting field (magntidue) to 0.000375
# Setting x, y, z to 6.512e-05, 3.693e-04, 2.296e-20
# Setting field (magntidue) to 0.000376
# Setting x, y, z to 6.529e-05, 3.703e-04, 2.302e-20
# Setting field (magntidue) to 0.000377
# Setting x, y, z to 6.547e-05, 3.713e-04, 2.308e-20
# Setting field (magntidue) to 0.000378
# Setting x, y, z to 6.564e-05, 3.723e-04, 2.315e-20
# Setting field (magntidue) to 0.000379
# Setting x, y, z to 6.581e-05, 3.732e-04, 2.321e-20
# Setting field (magntidue) to 0.00038
# Setting x, y, z to 6.599e-05, 3.742e-04, 2.327e-20
# Setting field (magntidue) to 0.000381
# Setting x, y, z to 6.616e-05, 3.752e-04, 2.333e-20
# Setting field (magntidue) to 0.000382
# Setting x, y, z to 6.633e-05, 3.762e-04, 2.339e-20
# Setting field (magntidue) to 0.000383
# Setting x, y, z to 6.651e-05, 3.772e-04, 2.345e-20
# Setting field (magntidue) to 0.000384
# Setting x, y, z to 6.668e-05, 3.782e-04, 2.351e-20
# Setting field (magntidue) to 0.000385
# Setting x, y, z to 6.685e-05, 3.792e-04, 2.357e-20
# Setting field (magntidue) to 0.000386
# Setting x, y, z to 6.703e-05, 3.801e-04, 2.364e-20
# Setting field (magntidue) to 0.000387
# Setting x, y, z to 6.720e-05, 3.811e-04, 2.370e-20
# Setting field (magntidue) to 0.000388
# Setting x, y, z to 6.738e-05, 3.821e-04, 2.376e-20
# Setting field (magntidue) to 0.000389
# Setting x, y, z to 6.755e-05, 3.831e-04, 2.382e-20
# Setting field (magntidue) to 0.00039
# Setting x, y, z to 6.772e-05, 3.841e-04, 2.388e-20
# Setting field (magntidue) to 0.000391
# Setting x, y, z to 6.790e-05, 3.851e-04, 2.394e-20
# Setting field (magntidue) to 0.000392
# Setting x, y, z to 6.807e-05, 3.860e-04, 2.400e-20
# Setting field (magntidue) to 0.000393
# Setting x, y, z to 6.824e-05, 3.870e-04, 2.406e-20
# Setting field (magntidue) to 0.000394
# Setting x, y, z to 6.842e-05, 3.880e-04, 2.413e-20
# Setting field (magntidue) to 0.000395
# Setting x, y, z to 6.859e-05, 3.890e-04, 2.419e-20
# Setting field (magntidue) to 0.000396
# Setting x, y, z to 6.876e-05, 3.900e-04, 2.425e-20
# Setting field (magntidue) to 0.000397
# Setting x, y, z to 6.894e-05, 3.910e-04, 2.431e-20
# Setting field (magntidue) to 0.000398
# Setting x, y, z to 6.911e-05, 3.920e-04, 2.437e-20
# Setting field (magntidue) to 0.000399
# Setting x, y, z to 6.929e-05, 3.929e-04, 2.443e-20
# Setting field (magntidue) to 0.0004
# Setting x, y, z to 6.946e-05, 3.939e-04, 2.449e-20
# Setting field (magntidue) to 0.000401
# Setting x, y, z to 6.963e-05, 3.949e-04, 2.455e-20
# Setting field (magntidue) to 0.000402
# Setting x, y, z to 6.981e-05, 3.959e-04, 2.462e-20
# Setting field (magntidue) to 0.000403
# Setting x, y, z to 6.998e-05, 3.969e-04, 2.468e-20
# Setting field (magntidue) to 0.000404
# Setting x, y, z to 7.015e-05, 3.979e-04, 2.474e-20
# Setting field (magntidue) to 0.000405
# Setting x, y, z to 7.033e-05, 3.988e-04, 2.480e-20
# Setting field (magntidue) to 0.000406
# Setting x, y, z to 7.050e-05, 3.998e-04, 2.486e-20
# Setting field (magntidue) to 0.000407
# Setting x, y, z to 7.067e-05, 4.008e-04, 2.492e-20
# Setting field (magntidue) to 0.000408
# Setting x, y, z to 7.085e-05, 4.018e-04, 2.498e-20
# Setting field (magntidue) to 0.000409
# Setting x, y, z to 7.102e-05, 4.028e-04, 2.504e-20
# Setting field (magntidue) to 0.00041
# Setting x, y, z to 7.120e-05, 4.038e-04, 2.511e-20
# Setting field (magntidue) to 0.000411
# Setting x, y, z to 7.137e-05, 4.048e-04, 2.517e-20
# Setting field (magntidue) to 0.000412
# Setting x, y, z to 7.154e-05, 4.057e-04, 2.523e-20
# Setting field (magntidue) to 0.000413
# Setting x, y, z to 7.172e-05, 4.067e-04, 2.529e-20
# Setting field (magntidue) to 0.000414
# Setting x, y, z to 7.189e-05, 4.077e-04, 2.535e-20
# Setting field (magntidue) to 0.000415
# Setting x, y, z to 7.206e-05, 4.087e-04, 2.541e-20
# Setting field (magntidue) to 0.000416
# Setting x, y, z to 7.224e-05, 4.097e-04, 2.547e-20
# Setting field (magntidue) to 0.000417
# Setting x, y, z to 7.241e-05, 4.107e-04, 2.553e-20
# Setting field (magntidue) to 0.000418
# Setting x, y, z to 7.258e-05, 4.116e-04, 2.560e-20
# Setting field (magntidue) to 0.000419
# Setting x, y, z to 7.276e-05, 4.126e-04, 2.566e-20
# Setting field (magntidue) to 0.00042
# Setting x, y, z to 7.293e-05, 4.136e-04, 2.572e-20
# Setting field (magntidue) to 0.000421
# Setting x, y, z to 7.311e-05, 4.146e-04, 2.578e-20
# Setting field (magntidue) to 0.000422
# Setting x, y, z to 7.328e-05, 4.156e-04, 2.584e-20
# Setting field (magntidue) to 0.000423
# Setting x, y, z to 7.345e-05, 4.166e-04, 2.590e-20
# Setting field (magntidue) to 0.000424
# Setting x, y, z to 7.363e-05, 4.176e-04, 2.596e-20
# Setting field (magntidue) to 0.000425
# Setting x, y, z to 7.380e-05, 4.185e-04, 2.602e-20
# Setting field (magntidue) to 0.000426
# Setting x, y, z to 7.397e-05, 4.195e-04, 2.608e-20
# Setting field (magntidue) to 0.000427
# Setting x, y, z to 7.415e-05, 4.205e-04, 2.615e-20
# Setting field (magntidue) to 0.000428
# Setting x, y, z to 7.432e-05, 4.215e-04, 2.621e-20
# Setting field (magntidue) to 0.000429
# Setting x, y, z to 7.450e-05, 4.225e-04, 2.627e-20
# Setting field (magntidue) to 0.00043
# Setting x, y, z to 7.467e-05, 4.235e-04, 2.633e-20
# Setting field (magntidue) to 0.000431
# Setting x, y, z to 7.484e-05, 4.245e-04, 2.639e-20
# Setting field (magntidue) to 0.000432
# Setting x, y, z to 7.502e-05, 4.254e-04, 2.645e-20
# Setting field (magntidue) to 0.000433
# Setting x, y, z to 7.519e-05, 4.264e-04, 2.651e-20
# Setting field (magntidue) to 0.000434
# Setting x, y, z to 7.536e-05, 4.274e-04, 2.657e-20
# Setting field (magntidue) to 0.000435
# Setting x, y, z to 7.554e-05, 4.284e-04, 2.664e-20
# Setting field (magntidue) to 0.000436
# Setting x, y, z to 7.571e-05, 4.294e-04, 2.670e-20
# Setting field (magntidue) to 0.000437
# Setting x, y, z to 7.588e-05, 4.304e-04, 2.676e-20
# Setting field (magntidue) to 0.000438
# Setting x, y, z to 7.606e-05, 4.313e-04, 2.682e-20
# Setting field (magntidue) to 0.000439
# Setting x, y, z to 7.623e-05, 4.323e-04, 2.688e-20
# Setting field (magntidue) to 0.00044
# Setting x, y, z to 7.641e-05, 4.333e-04, 2.694e-20
# Setting field (magntidue) to 0.000441
# Setting x, y, z to 7.658e-05, 4.343e-04, 2.700e-20
# Setting field (magntidue) to 0.000442
# Setting x, y, z to 7.675e-05, 4.353e-04, 2.706e-20
# Setting field (magntidue) to 0.000443
# Setting x, y, z to 7.693e-05, 4.363e-04, 2.713e-20
# Setting field (magntidue) to 0.000444
# Setting x, y, z to 7.710e-05, 4.373e-04, 2.719e-20
# Setting field (magntidue) to 0.000445
# Setting x, y, z to 7.727e-05, 4.382e-04, 2.725e-20
# Setting field (magntidue) to 0.000446
# Setting x, y, z to 7.745e-05, 4.392e-04, 2.731e-20
# Setting field (magntidue) to 0.000447
# Setting x, y, z to 7.762e-05, 4.402e-04, 2.737e-20
# Setting field (magntidue) to 0.000448
# Setting x, y, z to 7.779e-05, 4.412e-04, 2.743e-20
# Setting field (magntidue) to 0.000449
# Setting x, y, z to 7.797e-05, 4.422e-04, 2.749e-20
# Setting field (magntidue) to 0.00045
# Setting x, y, z to 7.814e-05, 4.432e-04, 2.755e-20
# Setting field (magntidue) to 0.000451
# Setting x, y, z to 7.832e-05, 4.441e-04, 2.762e-20
# Setting field (magntidue) to 0.000452
# Setting x, y, z to 7.849e-05, 4.451e-04, 2.768e-20
# Setting field (magntidue) to 0.000453
# Setting x, y, z to 7.866e-05, 4.461e-04, 2.774e-20
# Setting field (magntidue) to 0.000454
# Setting x, y, z to 7.884e-05, 4.471e-04, 2.780e-20
# Setting field (magntidue) to 0.000455
# Setting x, y, z to 7.901e-05, 4.481e-04, 2.786e-20
# Setting field (magntidue) to 0.000456
# Setting x, y, z to 7.918e-05, 4.491e-04, 2.792e-20
# Setting field (magntidue) to 0.000457
# Setting x, y, z to 7.936e-05, 4.501e-04, 2.798e-20
# Setting field (magntidue) to 0.000458
# Setting x, y, z to 7.953e-05, 4.510e-04, 2.804e-20
# Setting field (magntidue) to 0.000459
# Setting x, y, z to 7.970e-05, 4.520e-04, 2.811e-20
# Setting field (magntidue) to 0.00046
# Setting x, y, z to 7.988e-05, 4.530e-04, 2.817e-20
# Setting field (magntidue) to 0.000461
# Setting x, y, z to 8.005e-05, 4.540e-04, 2.823e-20
# Setting field (magntidue) to 0.000462
# Setting x, y, z to 8.023e-05, 4.550e-04, 2.829e-20
# Setting field (magntidue) to 0.000463
# Setting x, y, z to 8.040e-05, 4.560e-04, 2.835e-20
# Setting field (magntidue) to 0.000464
# Setting x, y, z to 8.057e-05, 4.570e-04, 2.841e-20
# Setting field (magntidue) to 0.000465
# Setting x, y, z to 8.075e-05, 4.579e-04, 2.847e-20
# Setting field (magntidue) to 0.000466
# Setting x, y, z to 8.092e-05, 4.589e-04, 2.853e-20
# Setting field (magntidue) to 0.000467
# Setting x, y, z to 8.109e-05, 4.599e-04, 2.860e-20
# Setting field (magntidue) to 0.000468
# Setting x, y, z to 8.127e-05, 4.609e-04, 2.866e-20
# Setting field (magntidue) to 0.000469
# Setting x, y, z to 8.144e-05, 4.619e-04, 2.872e-20
# Setting field (magntidue) to 0.00047
# Setting x, y, z to 8.161e-05, 4.629e-04, 2.878e-20
# Setting field (magntidue) to 0.000471
# Setting x, y, z to 8.179e-05, 4.638e-04, 2.884e-20
# Setting field (magntidue) to 0.000472
# Setting x, y, z to 8.196e-05, 4.648e-04, 2.890e-20
# Setting field (magntidue) to 0.000473
# Setting x, y, z to 8.214e-05, 4.658e-04, 2.896e-20
# Setting field (magntidue) to 0.000474
# Setting x, y, z to 8.231e-05, 4.668e-04, 2.902e-20
# Setting field (magntidue) to 0.000475
# Setting x, y, z to 8.248e-05, 4.678e-04, 2.909e-20
# Setting field (magntidue) to 0.000476
# Setting x, y, z to 8.266e-05, 4.688e-04, 2.915e-20
# Setting field (magntidue) to 0.000477
# Setting x, y, z to 8.283e-05, 4.698e-04, 2.921e-20
# Setting field (magntidue) to 0.000478
# Setting x, y, z to 8.300e-05, 4.707e-04, 2.927e-20
# Setting field (magntidue) to 0.000479
# Setting x, y, z to 8.318e-05, 4.717e-04, 2.933e-20
# Setting field (magntidue) to 0.00048
# Setting x, y, z to 8.335e-05, 4.727e-04, 2.939e-20
# Setting field (magntidue) to 0.000481
# Setting x, y, z to 8.352e-05, 4.737e-04, 2.945e-20
# Setting field (magntidue) to 0.000482
# Setting x, y, z to 8.370e-05, 4.747e-04, 2.951e-20
# Setting field (magntidue) to 0.000483
# Setting x, y, z to 8.387e-05, 4.757e-04, 2.958e-20
# Setting field (magntidue) to 0.000484
# Setting x, y, z to 8.405e-05, 4.766e-04, 2.964e-20
# Setting field (magntidue) to 0.000485
# Setting x, y, z to 8.422e-05, 4.776e-04, 2.970e-20
# Setting field (magntidue) to 0.000486
# Setting x, y, z to 8.439e-05, 4.786e-04, 2.976e-20
# Setting field (magntidue) to 0.000487
# Setting x, y, z to 8.457e-05, 4.796e-04, 2.982e-20
# Setting field (magntidue) to 0.000488
# Setting x, y, z to 8.474e-05, 4.806e-04, 2.988e-20
# Setting field (magntidue) to 0.000489
# Setting x, y, z to 8.491e-05, 4.816e-04, 2.994e-20
# Setting field (magntidue) to 0.00049
# Setting x, y, z to 8.509e-05, 4.826e-04, 3.000e-20
# Setting field (magntidue) to 0.000491
# Setting x, y, z to 8.526e-05, 4.835e-04, 3.007e-20
# Setting field (magntidue) to 0.000492
# Setting x, y, z to 8.543e-05, 4.845e-04, 3.013e-20
# Setting field (magntidue) to 0.000493
# Setting x, y, z to 8.561e-05, 4.855e-04, 3.019e-20
# Setting field (magntidue) to 0.000494
# Setting x, y, z to 8.578e-05, 4.865e-04, 3.025e-20
# Setting field (magntidue) to 0.000495
# Setting x, y, z to 8.596e-05, 4.875e-04, 3.031e-20
# Setting field (magntidue) to 0.000496
# Setting x, y, z to 8.613e-05, 4.885e-04, 3.037e-20
# Setting field (magntidue) to 0.000497
# Setting x, y, z to 8.630e-05, 4.894e-04, 3.043e-20
# Setting field (magntidue) to 0.000498
# Setting x, y, z to 8.648e-05, 4.904e-04, 3.049e-20
# Setting field (magntidue) to 0.000499
# Setting x, y, z to 8.665e-05, 4.914e-04, 3.055e-20
# Setting field (magntidue) to 0.0005
# Setting x, y, z to 8.682e-05, 4.924e-04, 3.062e-20
# Setting field (magntidue) to 0.000501
# Setting x, y, z to 8.700e-05, 4.934e-04, 3.068e-20
# Setting field (magntidue) to 0.000502
# Setting x, y, z to 8.717e-05, 4.944e-04, 3.074e-20
# Setting field (magntidue) to 0.000503
# Setting x, y, z to 8.735e-05, 4.954e-04, 3.080e-20
# Setting field (magntidue) to 0.000504
# Setting x, y, z to 8.752e-05, 4.963e-04, 3.086e-20
# Setting field (magntidue) to 0.000505
# Setting x, y, z to 8.769e-05, 4.973e-04, 3.092e-20
# Setting field (magntidue) to 0.000506
# Setting x, y, z to 8.787e-05, 4.983e-04, 3.098e-20
# Setting field (magntidue) to 0.000507
# Setting x, y, z to 8.804e-05, 4.993e-04, 3.104e-20
# Setting field (magntidue) to 0.000508
# Setting x, y, z to 8.821e-05, 5.003e-04, 3.111e-20
# Setting field (magntidue) to 0.000509
# Setting x, y, z to 8.839e-05, 5.013e-04, 3.117e-20
# Setting field (magntidue) to 0.00051
# Setting x, y, z to 8.856e-05, 5.023e-04, 3.123e-20
# Setting field (magntidue) to 0.000511
# Setting x, y, z to 8.873e-05, 5.032e-04, 3.129e-20
# Setting field (magntidue) to 0.000512
# Setting x, y, z to 8.891e-05, 5.042e-04, 3.135e-20
# Setting field (magntidue) to 0.000513
# Setting x, y, z to 8.908e-05, 5.052e-04, 3.141e-20
# Setting field (magntidue) to 0.000514
# Setting x, y, z to 8.926e-05, 5.062e-04, 3.147e-20
# Setting field (magntidue) to 0.000515
# Setting x, y, z to 8.943e-05, 5.072e-04, 3.153e-20
# Setting field (magntidue) to 0.000516
# Setting x, y, z to 8.960e-05, 5.082e-04, 3.160e-20
# Setting field (magntidue) to 0.000517
# Setting x, y, z to 8.978e-05, 5.091e-04, 3.166e-20
# Setting field (magntidue) to 0.000518
# Setting x, y, z to 8.995e-05, 5.101e-04, 3.172e-20
# Setting field (magntidue) to 0.000519
# Setting x, y, z to 9.012e-05, 5.111e-04, 3.178e-20
# Setting field (magntidue) to 0.00052
# Setting x, y, z to 9.030e-05, 5.121e-04, 3.184e-20
# Setting field (magntidue) to 0.000521
# Setting x, y, z to 9.047e-05, 5.131e-04, 3.190e-20
# Setting field (magntidue) to 0.000522
# Setting x, y, z to 9.064e-05, 5.141e-04, 3.196e-20
# Setting field (magntidue) to 0.000523
# Setting x, y, z to 9.082e-05, 5.151e-04, 3.202e-20
# Setting field (magntidue) to 0.000524
# Setting x, y, z to 9.099e-05, 5.160e-04, 3.209e-20
# Setting field (magntidue) to 0.000525
# Setting x, y, z to 9.117e-05, 5.170e-04, 3.215e-20
# Setting field (magntidue) to 0.000526
# Setting x, y, z to 9.134e-05, 5.180e-04, 3.221e-20
# Setting field (magntidue) to 0.000527
# Setting x, y, z to 9.151e-05, 5.190e-04, 3.227e-20
# Setting field (magntidue) to 0.000528
# Setting x, y, z to 9.169e-05, 5.200e-04, 3.233e-20
# Setting field (magntidue) to 0.000529
# Setting x, y, z to 9.186e-05, 5.210e-04, 3.239e-20
# Setting field (magntidue) to 0.00053
# Setting x, y, z to 9.203e-05, 5.219e-04, 3.245e-20
# Setting field (magntidue) to 0.000531
# Setting x, y, z to 9.221e-05, 5.229e-04, 3.251e-20
# Setting field (magntidue) to 0.000532
# Setting x, y, z to 9.238e-05, 5.239e-04, 3.258e-20
# Setting field (magntidue) to 0.000533
# Setting x, y, z to 9.255e-05, 5.249e-04, 3.264e-20
# Setting field (magntidue) to 0.000534
# Setting x, y, z to 9.273e-05, 5.259e-04, 3.270e-20
# Setting field (magntidue) to 0.000535
# Setting x, y, z to 9.290e-05, 5.269e-04, 3.276e-20
# Setting field (magntidue) to 0.000536
# Setting x, y, z to 9.308e-05, 5.279e-04, 3.282e-20
# Setting field (magntidue) to 0.000537
# Setting x, y, z to 9.325e-05, 5.288e-04, 3.288e-20
# ...
# Setting x, y, z to 1.291e-04, 9.805e-04, 6.056e-20
# Setting field (magntidue) to 0.00099
# Setting x, y, z to 1.292e-04, 9.815e-04, 6.062e-20
# Setting field (magntidue) to 0.000991
# Setting x, y, z to 1.294e-04, 9.825e-04, 6.068e-20
# Setting field (magntidue) to 0.000992
# Setting x, y, z to 1.295e-04, 9.835e-04, 6.074e-20
# Setting field (magntidue) to 0.000993
# Setting x, y, z to 1.296e-04, 9.845e-04, 6.080e-20
# Setting field (magntidue) to 0.000994
# Setting x, y, z to 1.297e-04, 9.855e-04, 6.086e-20
# Setting field (magntidue) to 0.000995
# Setting x, y, z to 1.299e-04, 9.865e-04, 6.093e-20
# Setting field (magntidue) to 0.000996
# Setting x, y, z to 1.300e-04, 9.875e-04, 6.099e-20
# Setting field (magntidue) to 0.000997
# Setting x, y, z to 1.301e-04, 9.885e-04, 6.105e-20
# Setting field (magntidue) to 0.000998
# Setting x, y, z to 1.303e-04, 9.895e-04, 6.111e-20
# Setting field (magntidue) to 0.000999
# Setting x, y, z to 1.304e-04, 9.905e-04, 6.117e-20
# Setting field (magntidue) to 0.001
# Setting x, y, z to 1.305e-04, 9.914e-04, 6.123e-20
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 77
# Setting field (magntidue) to 0.0
# Setting x, y, z to 0.000e+00, 0.000e+00, 0.000e+00
# Setting field (magntidue) to 1e-06
# Setting x, y, z to 8.716e-08, 9.962e-07, 6.123e-23
# Setting field (magntidue) to 2e-06
# Setting x, y, z to 1.743e-07, 1.992e-06, 1.225e-22
# Setting field (magntidue) to 3e-06
# Setting x, y, z to 2.615e-07, 2.989e-06, 1.837e-22
# Setting field (magntidue) to 4e-06
# Setting x, y, z to 3.486e-07, 3.985e-06, 2.449e-22
# Setting field (magntidue) to 5e-06
# Setting x, y, z to 4.358e-07, 4.981e-06, 3.062e-22
# Setting field (magntidue) to 6e-06
# Setting x, y, z to 5.229e-07, 5.977e-06, 3.674e-22
# Setting field (magntidue) to 7e-06
# Setting x, y, z to 6.101e-07, 6.973e-06, 4.286e-22
# Setting field (magntidue) to 8e-06
# Setting x, y, z to 6.972e-07, 7.970e-06, 4.899e-22
# Setting field (magntidue) to 9e-06
# Setting x, y, z to 7.844e-07, 8.966e-06, 5.511e-22
# Setting field (magntidue) to 1e-05
# Setting x, y, z to 8.716e-07, 9.962e-06, 6.123e-22
# Setting field (magntidue) to 1.1e-05
# Setting x, y, z to 9.587e-07, 1.096e-05, 6.736e-22
# Setting field (magntidue) to 1.2e-05
# Setting x, y, z to 1.046e-06, 1.195e-05, 7.348e-22
# Setting field (magntidue) to 1.3e-05
# Setting x, y, z to 1.133e-06, 1.295e-05, 7.960e-22
# Setting field (magntidue) to 1.4e-05
# Setting x, y, z to 1.220e-06, 1.395e-05, 8.573e-22
# Setting field (magntidue) to 1.5e-05
# Setting x, y, z to 1.307e-06, 1.494e-05, 9.185e-22
# Setting field (magntidue) to 1.6e-05
# Setting x, y, z to 1.394e-06, 1.594e-05, 9.797e-22
# Setting field (magntidue) to 1.7e-05
# Setting x, y, z to 1.482e-06, 1.694e-05, 1.041e-21
# Setting field (magntidue) to 1.8e-05
# Setting x, y, z to 1.569e-06, 1.793e-05, 1.102e-21
# Setting field (magntidue) to 1.9e-05
# Setting x, y, z to 1.656e-06, 1.893e-05, 1.163e-21
# Setting field (magntidue) to 2e-05
# Setting x, y, z to 1.743e-06, 1.992e-05, 1.225e-21
# Setting field (magntidue) to 2.1e-05
# Setting x, y, z to 1.830e-06, 2.092e-05, 1.286e-21
# Setting field (magntidue) to 2.2e-05
# Setting x, y, z to 1.917e-06, 2.192e-05, 1.347e-21
# Setting field (magntidue) to 2.3e-05
# Setting x, y, z to 2.005e-06, 2.291e-05, 1.408e-21
# Setting field (magntidue) to 2.4e-05
# Setting x, y, z to 2.092e-06, 2.391e-05, 1.470e-21
# Setting field (magntidue) to 2.5e-05
# Setting x, y, z to 2.179e-06, 2.490e-05, 1.531e-21
# Setting field (magntidue) to 2.6e-05
# Setting x, y, z to 2.266e-06, 2.590e-05, 1.592e-21
# Setting field (magntidue) to 2.7e-05
# Setting x, y, z to 2.353e-06, 2.690e-05, 1.653e-21
# Setting field (magntidue) to 2.8e-05
# Setting x, y, z to 2.440e-06, 2.789e-05, 1.715e-21
# Setting field (magntidue) to 2.9e-05
# Setting x, y, z to 2.528e-06, 2.889e-05, 1.776e-21
# Setting field (magntidue) to 3e-05
# Setting x, y, z to 2.615e-06, 2.989e-05, 1.837e-21
# Setting field (magntidue) to 3.1e-05
# Setting x, y, z to 2.702e-06, 3.088e-05, 1.898e-21
# Setting field (magntidue) to 3.2e-05
# Setting x, y, z to 2.789e-06, 3.188e-05, 1.959e-21
# Setting field (magntidue) to 3.3e-05
# Setting x, y, z to 2.876e-06, 3.287e-05, 2.021e-21
# Setting field (magntidue) to 3.4e-05
# Setting x, y, z to 2.963e-06, 3.387e-05, 2.082e-21
# Setting field (magntidue) to 3.5e-05
# Setting x, y, z to 3.050e-06, 3.487e-05, 2.143e-21
# Setting field (magntidue) to 3.6e-05
# Setting x, y, z to 3.138e-06, 3.586e-05, 2.204e-21
# Setting field (magntidue) to 3.7e-05
# Setting x, y, z to 3.225e-06, 3.686e-05, 2.266e-21
# Setting field (magntidue) to 3.8e-05
# Setting x, y, z to 3.312e-06, 3.786e-05, 2.327e-21
# Setting field (magntidue) to 3.9e-05
# Setting x, y, z to 3.399e-06, 3.885e-05, 2.388e-21
# Setting field (magntidue) to 4e-05
# Setting x, y, z to 3.486e-06, 3.985e-05, 2.449e-21
# Setting field (magntidue) to 4.1e-05
# Setting x, y, z to 3.573e-06, 4.084e-05, 2.511e-21
# Setting field (magntidue) to 4.2e-05
# Setting x, y, z to 3.661e-06, 4.184e-05, 2.572e-21
# Setting field (magntidue) to 4.3e-05
# Setting x, y, z to 3.748e-06, 4.284e-05, 2.633e-21
# Setting field (magntidue) to 4.4e-05
# Setting x, y, z to 3.835e-06, 4.383e-05, 2.694e-21
# Setting field (magntidue) to 4.5e-05
# Setting x, y, z to 3.922e-06, 4.483e-05, 2.755e-21
# Setting field (magntidue) to 4.6e-05
# Setting x, y, z to 4.009e-06, 4.582e-05, 2.817e-21
# Setting field (magntidue) to 4.7e-05
# Setting x, y, z to 4.096e-06, 4.682e-05, 2.878e-21
# Setting field (magntidue) to 4.8e-05
# Setting x, y, z to 4.183e-06, 4.782e-05, 2.939e-21
# Setting field (magntidue) to 4.9e-05
# Setting x, y, z to 4.271e-06, 4.881e-05, 3.000e-21
# Setting field (magntidue) to 5e-05
# Setting x, y, z to 4.358e-06, 4.981e-05, 3.062e-21
# Setting field (magntidue) to 5.1e-05
# Setting x, y, z to 4.445e-06, 5.081e-05, 3.123e-21
# Setting field (magntidue) to 5.2e-05
# Setting x, y, z to 4.532e-06, 5.180e-05, 3.184e-21
# Setting field (magntidue) to 5.3e-05
# Setting x, y, z to 4.619e-06, 5.280e-05, 3.245e-21
# Setting field (magntidue) to 5.4e-05
# Setting x, y, z to 4.706e-06, 5.379e-05, 3.307e-21
# Setting field (magntidue) to 5.5e-05
# Setting x, y, z to 4.794e-06, 5.479e-05, 3.368e-21
# Setting field (magntidue) to 5.6e-05
# Setting x, y, z to 4.881e-06, 5.579e-05, 3.429e-21
# Setting field (magntidue) to 5.7e-05
# Setting x, y, z to 4.968e-06, 5.678e-05, 3.490e-21
# Setting field (magntidue) to 5.8e-05
# Setting x, y, z to 5.055e-06, 5.778e-05, 3.551e-21
# Setting field (magntidue) to 5.9e-05
# Setting x, y, z to 5.142e-06, 5.878e-05, 3.613e-21
# Setting field (magntidue) to 6e-05
# Setting x, y, z to 5.229e-06, 5.977e-05, 3.674e-21
# Setting field (magntidue) to 6.1e-05
# Setting x, y, z to 5.317e-06, 6.077e-05, 3.735e-21
# Setting field (magntidue) to 6.2e-05
# Setting x, y, z to 5.404e-06, 6.176e-05, 3.796e-21
# Setting field (magntidue) to 6.3e-05
# Setting x, y, z to 5.491e-06, 6.276e-05, 3.858e-21
# Setting field (magntidue) to 6.4e-05
# Setting x, y, z to 5.578e-06, 6.376e-05, 3.919e-21
# Setting field (magntidue) to 6.5e-05
# Setting x, y, z to 5.665e-06, 6.475e-05, 3.980e-21
# Setting field (magntidue) to 6.6e-05
# Setting x, y, z to 5.752e-06, 6.575e-05, 4.041e-21
# Setting field (magntidue) to 6.7e-05
# Setting x, y, z to 5.839e-06, 6.675e-05, 4.103e-21
# Setting field (magntidue) to 6.8e-05
# Setting x, y, z to 5.927e-06, 6.774e-05, 4.164e-21
# Setting field (magntidue) to 6.9e-05
# Setting x, y, z to 6.014e-06, 6.874e-05, 4.225e-21
# Setting field (magntidue) to 7e-05
# Setting x, y, z to 6.101e-06, 6.973e-05, 4.286e-21
# Setting field (magntidue) to 7.1e-05
# Setting x, y, z to 6.188e-06, 7.073e-05, 4.347e-21
# Setting field (magntidue) to 7.2e-05
# Setting x, y, z to 6.275e-06, 7.173e-05, 4.409e-21
# Setting field (magntidue) to 7.3e-05
# Setting x, y, z to 6.362e-06, 7.272e-05, 4.470e-21
# Setting field (magntidue) to 7.4e-05
# Setting x, y, z to 6.450e-06, 7.372e-05, 4.531e-21
# Setting field (magntidue) to 7.5e-05
# Setting x, y, z to 6.537e-06, 7.471e-05, 4.592e-21
# Setting field (magntidue) to 7.6e-05
# Setting x, y, z to 6.624e-06, 7.571e-05, 4.654e-21
# Setting field (magntidue) to 7.7e-05
# Setting x, y, z to 6.711e-06, 7.671e-05, 4.715e-21
# Setting field (magntidue) to 7.8e-05
# Setting x, y, z to 6.798e-06, 7.770e-05, 4.776e-21
# Setting field (magntidue) to 7.9e-05
# Setting x, y, z to 6.885e-06, 7.870e-05, 4.837e-21
# Setting field (magntidue) to 8e-05
# Setting x, y, z to 6.972e-06, 7.970e-05, 4.899e-21
# Setting field (magntidue) to 8.1e-05
# Setting x, y, z to 7.060e-06, 8.069e-05, 4.960e-21
# Setting field (magntidue) to 8.2e-05
# Setting x, y, z to 7.147e-06, 8.169e-05, 5.021e-21
# Setting field (magntidue) to 8.3e-05
# Setting x, y, z to 7.234e-06, 8.268e-05, 5.082e-21
# Setting field (magntidue) to 8.4e-05
# Setting x, y, z to 7.321e-06, 8.368e-05, 5.144e-21
# Setting field (magntidue) to 8.5e-05
# Setting x, y, z to 7.408e-06, 8.468e-05, 5.205e-21
# Setting field (magntidue) to 8.6e-05
# Setting x, y, z to 7.495e-06, 8.567e-05, 5.266e-21
# Setting field (magntidue) to 8.7e-05
# Setting x, y, z to 7.583e-06, 8.667e-05, 5.327e-21
# Setting field (magntidue) to 8.8e-05
# Setting x, y, z to 7.670e-06, 8.767e-05, 5.388e-21
# Setting field (magntidue) to 8.9e-05
# Setting x, y, z to 7.757e-06, 8.866e-05, 5.450e-21
# Setting field (magntidue) to 9e-05
# Setting x, y, z to 7.844e-06, 8.966e-05, 5.511e-21
# Setting field (magntidue) to 9.1e-05
# Setting x, y, z to 7.931e-06, 9.065e-05, 5.572e-21
# Setting field (magntidue) to 9.2e-05
# Setting x, y, z to 8.018e-06, 9.165e-05, 5.633e-21
# Setting field (magntidue) to 9.3e-05
# Setting x, y, z to 8.105e-06, 9.265e-05, 5.695e-21
# Setting field (magntidue) to 9.4e-05
# Setting x, y, z to 8.193e-06, 9.364e-05, 5.756e-21
# Setting field (magntidue) to 9.5e-05
# Setting x, y, z to 8.280e-06, 9.464e-05, 5.817e-21
# Setting field (magntidue) to 9.6e-05
# Setting x, y, z to 8.367e-06, 9.563e-05, 5.878e-21
# Setting field (magntidue) to 9.7e-05
# Setting x, y, z to 8.454e-06, 9.663e-05, 5.940e-21
# Setting field (magntidue) to 9.8e-05
# Setting x, y, z to 8.541e-06, 9.763e-05, 6.001e-21
# Setting field (magntidue) to 9.9e-05
# Setting x, y, z to 8.628e-06, 9.862e-05, 6.062e-21
# Setting field (magntidue) to 0.0001
# Setting x, y, z to 8.716e-06, 9.962e-05, 6.123e-21
# Setting field (magntidue) to 0.000101
# Setting x, y, z to 8.803e-06, 1.006e-04, 6.184e-21
# Setting field (magntidue) to 0.000102
# Setting x, y, z to 8.890e-06, 1.016e-04, 6.246e-21
# Setting field (magntidue) to 0.000103
# Setting x, y, z to 8.977e-06, 1.026e-04, 6.307e-21
# Setting field (magntidue) to 0.000104
# Setting x, y, z to 9.064e-06, 1.036e-04, 6.368e-21
# Setting field (magntidue) to 0.000105
# Setting x, y, z to 9.151e-06, 1.046e-04, 6.429e-21
# Setting field (magntidue) to 0.000106
# Setting x, y, z to 9.239e-06, 1.056e-04, 6.491e-21
# Setting field (magntidue) to 0.000107
# Setting x, y, z to 9.326e-06, 1.066e-04, 6.552e-21
# Setting field (magntidue) to 0.000108
# Setting x, y, z to 9.413e-06, 1.076e-04, 6.613e-21
# Setting field (magntidue) to 0.000109
# Setting x, y, z to 9.500e-06, 1.086e-04, 6.674e-21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-8db5a5904696> in <module>()
#      38     for j in range(len(thetas)):
#      39         exp = qc.new_experiment("field phi=%d theta=%d, freq f=%.5e power=%d n=%d x %d" %(phis[i],thetas[j],f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")
# ---> 40         do_3D_field_sweep_single_frequency(B_fields, phis_rad[i], thetas_rad[j],  power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')
#
# <ipython-input-122-a6f06a6945a4> in do_3D_field_sweep_single_frequency(B_field_mags, phi, theta, power, n_pts, f, n_avg, channel_name)
#     227             yoko_magnet.x(x)
#     228             yoko_magnet.y(y)
# --> 229             yoko_magnet.z(z)
#     230
#     231             result= measure_and_process_point_vna(chan=channel_name)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     287         else:
#     288             if hasattr(self, 'set'):
# --> 289                 self.set(*args, **kwargs)
#     290             else:
#     291                 raise NotImplementedError('no set cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     465                     t0 = time.perf_counter()
#     466
# --> 467                     set_function(raw_value, **kwargs)
#     468                     self.raw_value = raw_value
#     469                     self._save_val(val_step,
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     287         else:
#     288             if hasattr(self, 'set'):
# --> 289                 self.set(*args, **kwargs)
#     290             else:
#     291                 raise NotImplementedError('no set cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     465                     t0 = time.perf_counter()
#     466
# --> 467                     set_function(raw_value, **kwargs)
#     468                     self.raw_value = raw_value
#     469                     self._save_val(val_step,
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py in set_field(self, value, block, perform_safety_check)
#     321
#     322         # If we have a persistent switch, make sure it is resistive
# --> 323         if self.switch_heater.enabled():
#     324             if not self.switch_heater.state():
#     325                 raise AMI430Exception("Switch heater is not on")
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py in check_enabled(self)
#      87
#      88     def check_enabled(self):
# ---> 89         return bool(self.ask('PS:INST?').strip())
#      90
#      91     @_Decorators.check_enabled
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\channel.py in ask(self, cmd)
#      66
#      67     def ask(self, cmd):
# ---> 68         return self._parent.ask(cmd)
#      69
#      70     def ask_raw(self, cmd):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     737         """
#     738         try:
# --> 739             answer = self.ask_raw(cmd)
#     740
#     741             return answer
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\ip.py in ask_raw(self, cmd)
#     187         with self._ensure_connection:
#     188             self._send(cmd)
# --> 189             return self._recv()
#     190
#     191     def __del__(self):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\ip.py in _recv(self)
#     150
#     151     def _recv(self):
# --> 152         result = self._socket.recv(self._buffer_size)
#     153         log.debug(f"Got {result} from instrument {self.name}")
#     154         if result == b'':
#
# KeyboardInterrupt:

# %%
get_yoko_field()
# Out:
# 0.0004228064992614475

# %%
power = -27
n_pts = 200
n_avg = 200
f = 4.8470e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

B_fields = np.arange(0,1e-3,2e-6)
phis = [90] #in degrees
thetas = np.arange(80,100,2.5) # in degrees

phis_rad=np.radians(phis) #convert to radians
thetas_rad = np.radians(thetas)

gate_channel = [MDAC_channels['V_cut_A'], MDAC_channels['V_bot_A'], MDAC_channels['V_pl_A']]

gate_voltages = 3.1
gate_name = ['V_cut_A', 'V_bot_A', 'V_pl_A']

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_name:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
print("ramping up gates")
for gate in gate_name:
    ramp(MDAC_channels[gate].voltage, gate_voltages, gate_ramp_stepsize, gate_ramp_delay)
#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 100, f_start = f-4e6, f_stop = f+4e6, power=power, n_avg=1000, channel_name='S12')
    print("Taking trace took", time.time()-t0)

    
#now do the real thing
for i in range(len(phis)):
    for j in range(len(thetas)):
        exp = qc.new_experiment("field phi=%d theta=%d, freq f=%.5e power=%d n=%d x %d" %(phis[i],thetas[j],f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")
        do_3D_field_sweep_single_frequency(B_fields, phis_rad[i], thetas_rad[j],  power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')
# Out:
# ramping up gates
# Taking single sweep
# Starting experimental run with id: 31
# Taking trace took 13.051497220993042
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 32
# Setting field (magntidue) to 0.0
# Setting x, y, z to 0.000e+00, 0.000e+00, 0.000e+00
# Setting field (magntidue) to 2e-06
# Setting x, y, z to 1.206e-22, 1.970e-06, 3.473e-07
# Setting field (magntidue) to 4e-06
# Setting x, y, z to 2.412e-22, 3.939e-06, 6.946e-07
# Setting field (magntidue) to 6e-06
# Setting x, y, z to 3.618e-22, 5.909e-06, 1.042e-06
# Setting field (magntidue) to 8e-06
# Setting x, y, z to 4.824e-22, 7.878e-06, 1.389e-06
# Setting field (magntidue) to 1e-05
# Setting x, y, z to 6.030e-22, 9.848e-06, 1.736e-06
# Setting field (magntidue) to 1.2e-05
# Setting x, y, z to 7.236e-22, 1.182e-05, 2.084e-06
# Setting field (magntidue) to 1.4e-05
# Setting x, y, z to 8.442e-22, 1.379e-05, 2.431e-06
# Setting field (magntidue) to 1.6e-05
# Setting x, y, z to 9.648e-22, 1.576e-05, 2.778e-06
# Setting field (magntidue) to 1.8e-05
# Setting x, y, z to 1.085e-21, 1.773e-05, 3.126e-06
# Setting field (magntidue) to 2e-05
# Setting x, y, z to 1.206e-21, 1.970e-05, 3.473e-06
# Setting field (magntidue) to 2.2e-05
# Setting x, y, z to 1.327e-21, 2.167e-05, 3.820e-06
# Setting field (magntidue) to 2.4e-05
# Setting x, y, z to 1.447e-21, 2.364e-05, 4.168e-06
# Setting field (magntidue) to 2.6e-05
# Setting x, y, z to 1.568e-21, 2.561e-05, 4.515e-06
# Setting field (magntidue) to 2.8e-05
# Setting x, y, z to 1.688e-21, 2.757e-05, 4.862e-06
# Setting field (magntidue) to 3e-05
# Setting x, y, z to 1.809e-21, 2.954e-05, 5.209e-06
# Setting field (magntidue) to 3.2e-05
# Setting x, y, z to 1.930e-21, 3.151e-05, 5.557e-06
# Setting field (magntidue) to 3.4e-05
# Setting x, y, z to 2.050e-21, 3.348e-05, 5.904e-06
# Setting field (magntidue) to 3.6e-05
# Setting x, y, z to 2.171e-21, 3.545e-05, 6.251e-06
# Setting field (magntidue) to 3.8e-05
# Setting x, y, z to 2.291e-21, 3.742e-05, 6.599e-06
# Setting field (magntidue) to 4e-05
# Setting x, y, z to 2.412e-21, 3.939e-05, 6.946e-06
# Setting field (magntidue) to 4.2e-05
# Setting x, y, z to 2.533e-21, 4.136e-05, 7.293e-06
# Setting field (magntidue) to 4.4e-05
# Setting x, y, z to 2.653e-21, 4.333e-05, 7.641e-06
# Setting field (magntidue) to 4.6e-05
# Setting x, y, z to 2.774e-21, 4.530e-05, 7.988e-06
# Setting field (magntidue) to 4.8e-05
# Setting x, y, z to 2.894e-21, 4.727e-05, 8.335e-06
# Setting field (magntidue) to 5e-05
# Setting x, y, z to 3.015e-21, 4.924e-05, 8.682e-06
# Setting field (magntidue) to 5.2e-05
# Setting x, y, z to 3.136e-21, 5.121e-05, 9.030e-06
# Setting field (magntidue) to 5.4e-05
# Setting x, y, z to 3.256e-21, 5.318e-05, 9.377e-06
# Setting field (magntidue) to 5.6e-05
# Setting x, y, z to 3.377e-21, 5.515e-05, 9.724e-06
# Setting field (magntidue) to 5.8e-05
# Setting x, y, z to 3.498e-21, 5.712e-05, 1.007e-05
# Setting field (magntidue) to 6e-05
# Setting x, y, z to 3.618e-21, 5.909e-05, 1.042e-05
# Setting field (magntidue) to 6.2e-05
# Setting x, y, z to 3.739e-21, 6.106e-05, 1.077e-05
# Setting field (magntidue) to 6.4e-05
# Setting x, y, z to 3.859e-21, 6.303e-05, 1.111e-05
# Setting field (magntidue) to 6.6e-05
# Setting x, y, z to 3.980e-21, 6.500e-05, 1.146e-05
# Setting field (magntidue) to 6.8e-05
# Setting x, y, z to 4.101e-21, 6.697e-05, 1.181e-05
# Setting field (magntidue) to 7e-05
# Setting x, y, z to 4.221e-21, 6.894e-05, 1.216e-05
# Setting field (magntidue) to 7.2e-05
# Setting x, y, z to 4.342e-21, 7.091e-05, 1.250e-05
# Setting field (magntidue) to 7.4e-05
# Setting x, y, z to 4.462e-21, 7.288e-05, 1.285e-05
# Setting field (magntidue) to 7.6e-05
# Setting x, y, z to 4.583e-21, 7.485e-05, 1.320e-05
# Setting field (magntidue) to 7.8e-05
# Setting x, y, z to 4.704e-21, 7.682e-05, 1.354e-05
# Setting field (magntidue) to 8e-05
# Setting x, y, z to 4.824e-21, 7.878e-05, 1.389e-05
# Setting field (magntidue) to 8.2e-05
# Setting x, y, z to 4.945e-21, 8.075e-05, 1.424e-05
# Setting field (magntidue) to 8.4e-05
# Setting x, y, z to 5.065e-21, 8.272e-05, 1.459e-05
# Setting field (magntidue) to 8.6e-05
# Setting x, y, z to 5.186e-21, 8.469e-05, 1.493e-05
# Setting field (magntidue) to 8.8e-05
# Setting x, y, z to 5.307e-21, 8.666e-05, 1.528e-05
# Setting field (magntidue) to 9e-05
# Setting x, y, z to 5.427e-21, 8.863e-05, 1.563e-05
# Setting field (magntidue) to 9.2e-05
# Setting x, y, z to 5.548e-21, 9.060e-05, 1.598e-05
# Setting field (magntidue) to 9.4e-05
# Setting x, y, z to 5.668e-21, 9.257e-05, 1.632e-05
# Setting field (magntidue) to 9.6e-05
# Setting x, y, z to 5.789e-21, 9.454e-05, 1.667e-05
# Setting field (magntidue) to 9.8e-05
# Setting x, y, z to 5.910e-21, 9.651e-05, 1.702e-05
# Setting field (magntidue) to 0.0001
# Setting x, y, z to 6.030e-21, 9.848e-05, 1.736e-05
# Setting field (magntidue) to 0.000102
# Setting x, y, z to 6.151e-21, 1.005e-04, 1.771e-05
# Setting field (magntidue) to 0.000104
# Setting x, y, z to 6.271e-21, 1.024e-04, 1.806e-05
# Setting field (magntidue) to 0.000106
# Setting x, y, z to 6.392e-21, 1.044e-04, 1.841e-05
# Setting field (magntidue) to 0.000108
# Setting x, y, z to 6.513e-21, 1.064e-04, 1.875e-05
# Setting field (magntidue) to 0.00011
# Setting x, y, z to 6.633e-21, 1.083e-04, 1.910e-05
# Setting field (magntidue) to 0.000112
# Setting x, y, z to 6.754e-21, 1.103e-04, 1.945e-05
# Setting field (magntidue) to 0.000114
# Setting x, y, z to 6.874e-21, 1.123e-04, 1.980e-05
# Setting field (magntidue) to 0.000116
# Setting x, y, z to 6.995e-21, 1.142e-04, 2.014e-05
# Setting field (magntidue) to 0.000118
# Setting x, y, z to 7.116e-21, 1.162e-04, 2.049e-05
# Setting field (magntidue) to 0.00012
# Setting x, y, z to 7.236e-21, 1.182e-04, 2.084e-05
# Setting field (magntidue) to 0.000122
# Setting x, y, z to 7.357e-21, 1.201e-04, 2.119e-05
# Setting field (magntidue) to 0.000124
# Setting x, y, z to 7.477e-21, 1.221e-04, 2.153e-05
# Setting field (magntidue) to 0.000126
# Setting x, y, z to 7.598e-21, 1.241e-04, 2.188e-05
# Setting field (magntidue) to 0.000128
# Setting x, y, z to 7.719e-21, 1.261e-04, 2.223e-05
# Setting field (magntidue) to 0.00013
# Setting x, y, z to 7.839e-21, 1.280e-04, 2.257e-05
# Setting field (magntidue) to 0.000132
# Setting x, y, z to 7.960e-21, 1.300e-04, 2.292e-05
# Setting field (magntidue) to 0.000134
# Setting x, y, z to 8.080e-21, 1.320e-04, 2.327e-05
# Setting field (magntidue) to 0.000136
# Setting x, y, z to 8.201e-21, 1.339e-04, 2.362e-05
# Setting field (magntidue) to 0.000138
# Setting x, y, z to 8.322e-21, 1.359e-04, 2.396e-05
# Setting field (magntidue) to 0.00014
# Setting x, y, z to 8.442e-21, 1.379e-04, 2.431e-05
# Setting field (magntidue) to 0.000142
# Setting x, y, z to 8.563e-21, 1.398e-04, 2.466e-05
# Setting field (magntidue) to 0.000144
# Setting x, y, z to 8.683e-21, 1.418e-04, 2.501e-05
# Setting field (magntidue) to 0.000146
# Setting x, y, z to 8.804e-21, 1.438e-04, 2.535e-05
# Setting field (magntidue) to 0.000148
# Setting x, y, z to 8.925e-21, 1.458e-04, 2.570e-05
# Setting field (magntidue) to 0.00015
# Setting x, y, z to 9.045e-21, 1.477e-04, 2.605e-05
# Setting field (magntidue) to 0.000152
# Setting x, y, z to 9.166e-21, 1.497e-04, 2.639e-05
# Setting field (magntidue) to 0.000154
# Setting x, y, z to 9.287e-21, 1.517e-04, 2.674e-05
# Setting field (magntidue) to 0.000156
# Setting x, y, z to 9.407e-21, 1.536e-04, 2.709e-05
# Setting field (magntidue) to 0.000158
# Setting x, y, z to 9.528e-21, 1.556e-04, 2.744e-05
# Setting field (magntidue) to 0.00016
# Setting x, y, z to 9.648e-21, 1.576e-04, 2.778e-05
# Setting field (magntidue) to 0.000162
# Setting x, y, z to 9.769e-21, 1.595e-04, 2.813e-05
# Setting field (magntidue) to 0.000164
# Setting x, y, z to 9.890e-21, 1.615e-04, 2.848e-05
# Setting field (magntidue) to 0.000166
# Setting x, y, z to 1.001e-20, 1.635e-04, 2.883e-05
# Setting field (magntidue) to 0.000168
# Setting x, y, z to 1.013e-20, 1.654e-04, 2.917e-05
# Setting field (magntidue) to 0.00017
# Setting x, y, z to 1.025e-20, 1.674e-04, 2.952e-05
# Setting field (magntidue) to 0.000172
# Setting x, y, z to 1.037e-20, 1.694e-04, 2.987e-05
# Setting field (magntidue) to 0.000174
# Setting x, y, z to 1.049e-20, 1.714e-04, 3.021e-05
# Setting field (magntidue) to 0.000176
# Setting x, y, z to 1.061e-20, 1.733e-04, 3.056e-05
# Setting field (magntidue) to 0.000178
# Setting x, y, z to 1.073e-20, 1.753e-04, 3.091e-05
# Setting field (magntidue) to 0.00018
# Setting x, y, z to 1.085e-20, 1.773e-04, 3.126e-05
# Setting field (magntidue) to 0.000182
# Setting x, y, z to 1.097e-20, 1.792e-04, 3.160e-05
# Setting field (magntidue) to 0.000184
# Setting x, y, z to 1.110e-20, 1.812e-04, 3.195e-05
# Setting field (magntidue) to 0.000186
# Setting x, y, z to 1.122e-20, 1.832e-04, 3.230e-05
# Setting field (magntidue) to 0.000188
# Setting x, y, z to 1.134e-20, 1.851e-04, 3.265e-05
# Setting field (magntidue) to 0.00019
# Setting x, y, z to 1.146e-20, 1.871e-04, 3.299e-05
# Setting field (magntidue) to 0.000192
# Setting x, y, z to 1.158e-20, 1.891e-04, 3.334e-05
# Setting field (magntidue) to 0.000194
# Setting x, y, z to 1.170e-20, 1.911e-04, 3.369e-05
# Setting field (magntidue) to 0.000196
# Setting x, y, z to 1.182e-20, 1.930e-04, 3.404e-05
# Setting field (magntidue) to 0.000198
# Setting x, y, z to 1.194e-20, 1.950e-04, 3.438e-05
# Setting field (magntidue) to 0.0002
# Setting x, y, z to 1.206e-20, 1.970e-04, 3.473e-05
# Setting field (magntidue) to 0.000202
# Setting x, y, z to 1.218e-20, 1.989e-04, 3.508e-05
# Setting field (magntidue) to 0.000204
# Setting x, y, z to 1.230e-20, 2.009e-04, 3.542e-05
# Setting field (magntidue) to 0.000206
# Setting x, y, z to 1.242e-20, 2.029e-04, 3.577e-05
# Setting field (magntidue) to 0.000208
# Setting x, y, z to 1.254e-20, 2.048e-04, 3.612e-05
# Setting field (magntidue) to 0.00021
# Setting x, y, z to 1.266e-20, 2.068e-04, 3.647e-05
# Setting field (magntidue) to 0.000212
# Setting x, y, z to 1.278e-20, 2.088e-04, 3.681e-05
# Setting field (magntidue) to 0.000214
# Setting x, y, z to 1.290e-20, 2.107e-04, 3.716e-05
# Setting field (magntidue) to 0.000216
# Setting x, y, z to 1.303e-20, 2.127e-04, 3.751e-05
# Setting field (magntidue) to 0.000218
# Setting x, y, z to 1.315e-20, 2.147e-04, 3.786e-05
# Setting field (magntidue) to 0.00022
# Setting x, y, z to 1.327e-20, 2.167e-04, 3.820e-05
# Setting field (magntidue) to 0.000222
# Setting x, y, z to 1.339e-20, 2.186e-04, 3.855e-05
# Setting field (magntidue) to 0.000224
# Setting x, y, z to 1.351e-20, 2.206e-04, 3.890e-05
# Setting field (magntidue) to 0.000226
# Setting x, y, z to 1.363e-20, 2.226e-04, 3.924e-05
# Setting field (magntidue) to 0.000228
# Setting x, y, z to 1.375e-20, 2.245e-04, 3.959e-05
# Setting field (magntidue) to 0.00023
# Setting x, y, z to 1.387e-20, 2.265e-04, 3.994e-05
# Setting field (magntidue) to 0.000232
# Setting x, y, z to 1.399e-20, 2.285e-04, 4.029e-05
# Setting field (magntidue) to 0.000234
# Setting x, y, z to 1.411e-20, 2.304e-04, 4.063e-05
# Setting field (magntidue) to 0.000236
# Setting x, y, z to 1.423e-20, 2.324e-04, 4.098e-05
# Setting field (magntidue) to 0.000238
# Setting x, y, z to 1.435e-20, 2.344e-04, 4.133e-05
# Setting field (magntidue) to 0.00024
# Setting x, y, z to 1.447e-20, 2.364e-04, 4.168e-05
# Setting field (magntidue) to 0.000242
# Setting x, y, z to 1.459e-20, 2.383e-04, 4.202e-05
# Setting field (magntidue) to 0.000244
# Setting x, y, z to 1.471e-20, 2.403e-04, 4.237e-05
# Setting field (magntidue) to 0.000246
# Setting x, y, z to 1.483e-20, 2.423e-04, 4.272e-05
# Setting field (magntidue) to 0.000248
# Setting x, y, z to 1.495e-20, 2.442e-04, 4.306e-05
# Setting field (magntidue) to 0.00025
# Setting x, y, z to 1.508e-20, 2.462e-04, 4.341e-05
# Setting field (magntidue) to 0.000252
# Setting x, y, z to 1.520e-20, 2.482e-04, 4.376e-05
# Setting field (magntidue) to 0.000254
# Setting x, y, z to 1.532e-20, 2.501e-04, 4.411e-05
# Setting field (magntidue) to 0.000256
# Setting x, y, z to 1.544e-20, 2.521e-04, 4.445e-05
# Setting field (magntidue) to 0.000258
# Setting x, y, z to 1.556e-20, 2.541e-04, 4.480e-05
# Setting field (magntidue) to 0.00026
# Setting x, y, z to 1.568e-20, 2.561e-04, 4.515e-05
# Setting field (magntidue) to 0.000262
# Setting x, y, z to 1.580e-20, 2.580e-04, 4.550e-05
# Setting field (magntidue) to 0.000264
# Setting x, y, z to 1.592e-20, 2.600e-04, 4.584e-05
# Setting field (magntidue) to 0.000266
# Setting x, y, z to 1.604e-20, 2.620e-04, 4.619e-05
# Setting field (magntidue) to 0.000268
# Setting x, y, z to 1.616e-20, 2.639e-04, 4.654e-05
# Setting field (magntidue) to 0.00027
# Setting x, y, z to 1.628e-20, 2.659e-04, 4.689e-05
# Setting field (magntidue) to 0.000272
# Setting x, y, z to 1.640e-20, 2.679e-04, 4.723e-05
# Setting field (magntidue) to 0.000274
# Setting x, y, z to 1.652e-20, 2.698e-04, 4.758e-05
# Setting field (magntidue) to 0.000276
# Setting x, y, z to 1.664e-20, 2.718e-04, 4.793e-05
# Setting field (magntidue) to 0.000278
# Setting x, y, z to 1.676e-20, 2.738e-04, 4.827e-05
# Setting field (magntidue) to 0.00028
# Setting x, y, z to 1.688e-20, 2.757e-04, 4.862e-05
# Setting field (magntidue) to 0.000282
# Setting x, y, z to 1.701e-20, 2.777e-04, 4.897e-05
# Setting field (magntidue) to 0.000284
# Setting x, y, z to 1.713e-20, 2.797e-04, 4.932e-05
# Setting field (magntidue) to 0.000286
# Setting x, y, z to 1.725e-20, 2.817e-04, 4.966e-05
# Setting field (magntidue) to 0.000288
# Setting x, y, z to 1.737e-20, 2.836e-04, 5.001e-05
# Setting field (magntidue) to 0.00029
# Setting x, y, z to 1.749e-20, 2.856e-04, 5.036e-05
# Setting field (magntidue) to 0.000292
# Setting x, y, z to 1.761e-20, 2.876e-04, 5.071e-05
# Setting field (magntidue) to 0.000294
# Setting x, y, z to 1.773e-20, 2.895e-04, 5.105e-05
# Setting field (magntidue) to 0.000296
# Setting x, y, z to 1.785e-20, 2.915e-04, 5.140e-05
# Setting field (magntidue) to 0.000298
# Setting x, y, z to 1.797e-20, 2.935e-04, 5.175e-05
# Setting field (magntidue) to 0.0003
# Setting x, y, z to 1.809e-20, 2.954e-04, 5.209e-05
# Setting field (magntidue) to 0.000302
# Setting x, y, z to 1.821e-20, 2.974e-04, 5.244e-05
# Setting field (magntidue) to 0.000304
# Setting x, y, z to 1.833e-20, 2.994e-04, 5.279e-05
# Setting field (magntidue) to 0.000306
# Setting x, y, z to 1.845e-20, 3.014e-04, 5.314e-05
# Setting field (magntidue) to 0.000308
# Setting x, y, z to 1.857e-20, 3.033e-04, 5.348e-05
# Setting field (magntidue) to 0.00031
# Setting x, y, z to 1.869e-20, 3.053e-04, 5.383e-05
# Setting field (magntidue) to 0.000312
# Setting x, y, z to 1.881e-20, 3.073e-04, 5.418e-05
# Setting field (magntidue) to 0.000314
# Setting x, y, z to 1.893e-20, 3.092e-04, 5.453e-05
# Setting field (magntidue) to 0.000316
# Setting x, y, z to 1.906e-20, 3.112e-04, 5.487e-05
# Setting field (magntidue) to 0.000318
# Setting x, y, z to 1.918e-20, 3.132e-04, 5.522e-05
# Setting field (magntidue) to 0.00032
# Setting x, y, z to 1.930e-20, 3.151e-04, 5.557e-05
# Setting field (magntidue) to 0.000322
# Setting x, y, z to 1.942e-20, 3.171e-04, 5.591e-05
# Setting field (magntidue) to 0.000324
# Setting x, y, z to 1.954e-20, 3.191e-04, 5.626e-05
# Setting field (magntidue) to 0.000326
# Setting x, y, z to 1.966e-20, 3.210e-04, 5.661e-05
# Setting field (magntidue) to 0.000328
# Setting x, y, z to 1.978e-20, 3.230e-04, 5.696e-05
# Setting field (magntidue) to 0.00033
# Setting x, y, z to 1.990e-20, 3.250e-04, 5.730e-05
# Setting field (magntidue) to 0.000332
# Setting x, y, z to 2.002e-20, 3.270e-04, 5.765e-05
# Setting field (magntidue) to 0.000334
# Setting x, y, z to 2.014e-20, 3.289e-04, 5.800e-05
# Setting field (magntidue) to 0.000336
# Setting x, y, z to 2.026e-20, 3.309e-04, 5.835e-05
# Setting field (magntidue) to 0.000338
# Setting x, y, z to 2.038e-20, 3.329e-04, 5.869e-05
# Setting field (magntidue) to 0.00034
# Setting x, y, z to 2.050e-20, 3.348e-04, 5.904e-05
# Setting field (magntidue) to 0.000342
# Setting x, y, z to 2.062e-20, 3.368e-04, 5.939e-05
# Setting field (magntidue) to 0.000344
# Setting x, y, z to 2.074e-20, 3.388e-04, 5.973e-05
# Setting field (magntidue) to 0.000346
# Setting x, y, z to 2.086e-20, 3.407e-04, 6.008e-05
# Setting field (magntidue) to 0.000348
# Setting x, y, z to 2.099e-20, 3.427e-04, 6.043e-05
# Setting field (magntidue) to 0.00035
# Setting x, y, z to 2.111e-20, 3.447e-04, 6.078e-05
# Setting field (magntidue) to 0.000352
# Setting x, y, z to 2.123e-20, 3.467e-04, 6.112e-05
# Setting field (magntidue) to 0.000354
# Setting x, y, z to 2.135e-20, 3.486e-04, 6.147e-05
# Setting field (magntidue) to 0.000356
# Setting x, y, z to 2.147e-20, 3.506e-04, 6.182e-05
# Setting field (magntidue) to 0.000358
# Setting x, y, z to 2.159e-20, 3.526e-04, 6.217e-05
# Setting field (magntidue) to 0.00036
# Setting x, y, z to 2.171e-20, 3.545e-04, 6.251e-05
# Setting field (magntidue) to 0.000362
# Setting x, y, z to 2.183e-20, 3.565e-04, 6.286e-05
# Setting field (magntidue) to 0.000364
# Setting x, y, z to 2.195e-20, 3.585e-04, 6.321e-05
# Setting field (magntidue) to 0.000366
# Setting x, y, z to 2.207e-20, 3.604e-04, 6.356e-05
# Setting field (magntidue) to 0.000368
# Setting x, y, z to 2.219e-20, 3.624e-04, 6.390e-05
# Setting field (magntidue) to 0.00037
# Setting x, y, z to 2.231e-20, 3.644e-04, 6.425e-05
# Setting field (magntidue) to 0.000372
# Setting x, y, z to 2.243e-20, 3.663e-04, 6.460e-05
# Setting field (magntidue) to 0.000374
# Setting x, y, z to 2.255e-20, 3.683e-04, 6.494e-05
# Setting field (magntidue) to 0.000376
# Setting x, y, z to 2.267e-20, 3.703e-04, 6.529e-05
# Setting field (magntidue) to 0.000378
# Setting x, y, z to 2.279e-20, 3.723e-04, 6.564e-05
# Setting field (magntidue) to 0.00038
# Setting x, y, z to 2.291e-20, 3.742e-04, 6.599e-05
# Setting field (magntidue) to 0.000382
# Setting x, y, z to 2.304e-20, 3.762e-04, 6.633e-05
# Setting field (magntidue) to 0.000384
# Setting x, y, z to 2.316e-20, 3.782e-04, 6.668e-05
# Setting field (magntidue) to 0.000386
# Setting x, y, z to 2.328e-20, 3.801e-04, 6.703e-05
# Setting field (magntidue) to 0.000388
# Setting x, y, z to 2.340e-20, 3.821e-04, 6.738e-05
# Setting field (magntidue) to 0.00039
# Setting x, y, z to 2.352e-20, 3.841e-04, 6.772e-05
# Setting field (magntidue) to 0.000392
# Setting x, y, z to 2.364e-20, 3.860e-04, 6.807e-05
# Setting field (magntidue) to 0.000394
# Setting x, y, z to 2.376e-20, 3.880e-04, 6.842e-05
# Setting field (magntidue) to 0.000396
# Setting x, y, z to 2.388e-20, 3.900e-04, 6.876e-05
# Setting field (magntidue) to 0.000398
# Setting x, y, z to 2.400e-20, 3.920e-04, 6.911e-05
# Setting field (magntidue) to 0.0004
# Setting x, y, z to 2.412e-20, 3.939e-04, 6.946e-05
# Setting field (magntidue) to 0.000402
# Setting x, y, z to 2.424e-20, 3.959e-04, 6.981e-05
# Setting field (magntidue) to 0.000404
# Setting x, y, z to 2.436e-20, 3.979e-04, 7.015e-05
# Setting field (magntidue) to 0.000406
# Setting x, y, z to 2.448e-20, 3.998e-04, 7.050e-05
# Setting field (magntidue) to 0.000408
# Setting x, y, z to 2.460e-20, 4.018e-04, 7.085e-05
# Setting field (magntidue) to 0.00041
# Setting x, y, z to 2.472e-20, 4.038e-04, 7.120e-05
# Setting field (magntidue) to 0.000412
# Setting x, y, z to 2.484e-20, 4.057e-04, 7.154e-05
# Setting field (magntidue) to 0.000414
# Setting x, y, z to 2.497e-20, 4.077e-04, 7.189e-05
# Setting field (magntidue) to 0.000416
# Setting x, y, z to 2.509e-20, 4.097e-04, 7.224e-05
# Setting field (magntidue) to 0.000418
# Setting x, y, z to 2.521e-20, 4.116e-04, 7.258e-05
# Setting field (magntidue) to 0.00042
# Setting x, y, z to 2.533e-20, 4.136e-04, 7.293e-05
# Setting field (magntidue) to 0.000422
# Setting x, y, z to 2.545e-20, 4.156e-04, 7.328e-05
# Setting field (magntidue) to 0.000424
# Setting x, y, z to 2.557e-20, 4.176e-04, 7.363e-05
# Setting field (magntidue) to 0.000426
# Setting x, y, z to 2.569e-20, 4.195e-04, 7.397e-05
# Setting field (magntidue) to 0.000428
# Setting x, y, z to 2.581e-20, 4.215e-04, 7.432e-05
# Setting field (magntidue) to 0.00043
# Setting x, y, z to 2.593e-20, 4.235e-04, 7.467e-05
# Setting field (magntidue) to 0.000432
# Setting x, y, z to 2.605e-20, 4.254e-04, 7.502e-05
# Setting field (magntidue) to 0.000434
# Setting x, y, z to 2.617e-20, 4.274e-04, 7.536e-05
# Setting field (magntidue) to 0.000436
# Setting x, y, z to 2.629e-20, 4.294e-04, 7.571e-05
# Setting field (magntidue) to 0.000438
# Setting x, y, z to 2.641e-20, 4.313e-04, 7.606e-05
# Setting field (magntidue) to 0.00044
# Setting x, y, z to 2.653e-20, 4.333e-04, 7.641e-05
# Setting field (magntidue) to 0.000442
# Setting x, y, z to 2.665e-20, 4.353e-04, 7.675e-05
# Setting field (magntidue) to 0.000444
# Setting x, y, z to 2.677e-20, 4.373e-04, 7.710e-05
# Setting field (magntidue) to 0.000446
# Setting x, y, z to 2.689e-20, 4.392e-04, 7.745e-05
# Setting field (magntidue) to 0.000448
# Setting x, y, z to 2.702e-20, 4.412e-04, 7.779e-05
# Setting field (magntidue) to 0.00045
# Setting x, y, z to 2.714e-20, 4.432e-04, 7.814e-05
# Setting field (magntidue) to 0.000452
# Setting x, y, z to 2.726e-20, 4.451e-04, 7.849e-05
# Setting field (magntidue) to 0.000454
# Setting x, y, z to 2.738e-20, 4.471e-04, 7.884e-05
# Setting field (magntidue) to 0.000456
# Setting x, y, z to 2.750e-20, 4.491e-04, 7.918e-05
# Setting field (magntidue) to 0.000458
# Setting x, y, z to 2.762e-20, 4.510e-04, 7.953e-05
# Setting field (magntidue) to 0.00046
# Setting x, y, z to 2.774e-20, 4.530e-04, 7.988e-05
# Setting field (magntidue) to 0.000462
# Setting x, y, z to 2.786e-20, 4.550e-04, 8.023e-05
# Setting field (magntidue) to 0.000464
# Setting x, y, z to 2.798e-20, 4.570e-04, 8.057e-05
# Setting field (magntidue) to 0.000466
# Setting x, y, z to 2.810e-20, 4.589e-04, 8.092e-05
# Setting field (magntidue) to 0.000468
# Setting x, y, z to 2.822e-20, 4.609e-04, 8.127e-05
# Setting field (magntidue) to 0.00047
# Setting x, y, z to 2.834e-20, 4.629e-04, 8.161e-05
# Setting field (magntidue) to 0.000472
# Setting x, y, z to 2.846e-20, 4.648e-04, 8.196e-05
# Setting field (magntidue) to 0.000474
# Setting x, y, z to 2.858e-20, 4.668e-04, 8.231e-05
# Setting field (magntidue) to 0.000476
# Setting x, y, z to 2.870e-20, 4.688e-04, 8.266e-05
# Setting field (magntidue) to 0.000478
# Setting x, y, z to 2.882e-20, 4.707e-04, 8.300e-05
# Setting field (magntidue) to 0.00048
# Setting x, y, z to 2.894e-20, 4.727e-04, 8.335e-05
# Setting field (magntidue) to 0.000482
# Setting x, y, z to 2.907e-20, 4.747e-04, 8.370e-05
# Setting field (magntidue) to 0.000484
# Setting x, y, z to 2.919e-20, 4.766e-04, 8.405e-05
# Setting field (magntidue) to 0.000486
# Setting x, y, z to 2.931e-20, 4.786e-04, 8.439e-05
# Setting field (magntidue) to 0.000488
# Setting x, y, z to 2.943e-20, 4.806e-04, 8.474e-05
# Setting field (magntidue) to 0.00049
# Setting x, y, z to 2.955e-20, 4.826e-04, 8.509e-05
# Setting field (magntidue) to 0.000492
# Setting x, y, z to 2.967e-20, 4.845e-04, 8.543e-05
# Setting field (magntidue) to 0.000494
# Setting x, y, z to 2.979e-20, 4.865e-04, 8.578e-05
# Setting field (magntidue) to 0.000496
# Setting x, y, z to 2.991e-20, 4.885e-04, 8.613e-05
# Setting field (magntidue) to 0.000498
# Setting x, y, z to 3.003e-20, 4.904e-04, 8.648e-05
# Setting field (magntidue) to 0.0005
# Setting x, y, z to 3.015e-20, 4.924e-04, 8.682e-05
# Setting field (magntidue) to 0.000502
# Setting x, y, z to 3.027e-20, 4.944e-04, 8.717e-05
# Setting field (magntidue) to 0.000504
# Setting x, y, z to 3.039e-20, 4.963e-04, 8.752e-05
# Setting field (magntidue) to 0.000506
# Setting x, y, z to 3.051e-20, 4.983e-04, 8.787e-05
# Setting field (magntidue) to 0.000508
# Setting x, y, z to 3.063e-20, 5.003e-04, 8.821e-05
# Setting field (magntidue) to 0.00051
# Setting x, y, z to 3.075e-20, 5.023e-04, 8.856e-05
# Setting field (magntidue) to 0.000512
# Setting x, y, z to 3.087e-20, 5.042e-04, 8.891e-05
# Setting field (magntidue) to 0.000514
# Setting x, y, z to 3.100e-20, 5.062e-04, 8.926e-05
# Setting field (magntidue) to 0.000516
# Setting x, y, z to 3.112e-20, 5.082e-04, 8.960e-05
# Setting field (magntidue) to 0.000518
# Setting x, y, z to 3.124e-20, 5.101e-04, 8.995e-05
# Setting field (magntidue) to 0.00052
# Setting x, y, z to 3.136e-20, 5.121e-04, 9.030e-05
# Setting field (magntidue) to 0.000522
# Setting x, y, z to 3.148e-20, 5.141e-04, 9.064e-05
# Setting field (magntidue) to 0.000524
# Setting x, y, z to 3.160e-20, 5.160e-04, 9.099e-05
# Setting field (magntidue) to 0.000526
# Setting x, y, z to 3.172e-20, 5.180e-04, 9.134e-05
# Setting field (magntidue) to 0.000528
# Setting x, y, z to 3.184e-20, 5.200e-04, 9.169e-05
# Setting field (magntidue) to 0.00053
# Setting x, y, z to 3.196e-20, 5.219e-04, 9.203e-05
# Setting field (magntidue) to 0.000532
# Setting x, y, z to 3.208e-20, 5.239e-04, 9.238e-05
# Setting field (magntidue) to 0.000534
# Setting x, y, z to 3.220e-20, 5.259e-04, 9.273e-05
# Setting field (magntidue) to 0.000536
# Setting x, y, z to 3.232e-20, 5.279e-04, 9.308e-05
# Setting field (magntidue) to 0.000538
# Setting x, y, z to 3.244e-20, 5.298e-04, 9.342e-05
# Setting field (magntidue) to 0.00054
# Setting x, y, z to 3.256e-20, 5.318e-04, 9.377e-05
# Setting field (magntidue) to 0.000542
# Setting x, y, z to 3.268e-20, 5.338e-04, 9.412e-05
# Setting field (magntidue) to 0.000544
# Setting x, y, z to 3.280e-20, 5.357e-04, 9.446e-05
# Setting field (magntidue) to 0.000546
# Setting x, y, z to 3.292e-20, 5.377e-04, 9.481e-05
# Setting field (magntidue) to 0.000548
# Setting x, y, z to 3.305e-20, 5.397e-04, 9.516e-05
# Setting field (magntidue) to 0.00055
# Setting x, y, z to 3.317e-20, 5.416e-04, 9.551e-05
# Setting field (magntidue) to 0.000552
# Setting x, y, z to 3.329e-20, 5.436e-04, 9.585e-05
# Setting field (magntidue) to 0.000554
# Setting x, y, z to 3.341e-20, 5.456e-04, 9.620e-05
# Setting field (magntidue) to 0.000556
# Setting x, y, z to 3.353e-20, 5.476e-04, 9.655e-05
# Setting field (magntidue) to 0.000558
# Setting x, y, z to 3.365e-20, 5.495e-04, 9.690e-05
# Setting field (magntidue) to 0.00056
# Setting x, y, z to 3.377e-20, 5.515e-04, 9.724e-05
# Setting field (magntidue) to 0.000562
# Setting x, y, z to 3.389e-20, 5.535e-04, 9.759e-05
# Setting field (magntidue) to 0.000564
# Setting x, y, z to 3.401e-20, 5.554e-04, 9.794e-05
# Setting field (magntidue) to 0.000566
# Setting x, y, z to 3.413e-20, 5.574e-04, 9.828e-05
# Setting field (magntidue) to 0.000568
# Setting x, y, z to 3.425e-20, 5.594e-04, 9.863e-05
# Setting field (magntidue) to 0.00057
# Setting x, y, z to 3.437e-20, 5.613e-04, 9.898e-05
# Setting field (magntidue) to 0.000572
# Setting x, y, z to 3.449e-20, 5.633e-04, 9.933e-05
# Setting field (magntidue) to 0.000574
# Setting x, y, z to 3.461e-20, 5.653e-04, 9.967e-05
# Setting field (magntidue) to 0.000576
# Setting x, y, z to 3.473e-20, 5.672e-04, 1.000e-04
# Setting field (magntidue) to 0.000578
# Setting x, y, z to 3.485e-20, 5.692e-04, 1.004e-04
# Setting field (magntidue) to 0.00058
# Setting x, y, z to 3.498e-20, 5.712e-04, 1.007e-04
# Setting field (magntidue) to 0.000582
# Setting x, y, z to 3.510e-20, 5.732e-04, 1.011e-04
# Setting field (magntidue) to 0.000584
# Setting x, y, z to 3.522e-20, 5.751e-04, 1.014e-04
# Setting field (magntidue) to 0.000586
# Setting x, y, z to 3.534e-20, 5.771e-04, 1.018e-04
# Setting field (magntidue) to 0.000588
# Setting x, y, z to 3.546e-20, 5.791e-04, 1.021e-04
# Setting field (magntidue) to 0.00059
# Setting x, y, z to 3.558e-20, 5.810e-04, 1.025e-04
# Setting field (magntidue) to 0.000592
# Setting x, y, z to 3.570e-20, 5.830e-04, 1.028e-04
# Setting field (magntidue) to 0.000594
# Setting x, y, z to 3.582e-20, 5.850e-04, 1.031e-04
# Setting field (magntidue) to 0.000596
# Setting x, y, z to 3.594e-20, 5.869e-04, 1.035e-04
# Setting field (magntidue) to 0.000598
# Setting x, y, z to 3.606e-20, 5.889e-04, 1.038e-04
# Setting field (magntidue) to 0.0006
# Setting x, y, z to 3.618e-20, 5.909e-04, 1.042e-04
# Setting field (magntidue) to 0.000602
# Setting x, y, z to 3.630e-20, 5.929e-04, 1.045e-04
# Setting field (magntidue) to 0.000604
# Setting x, y, z to 3.642e-20, 5.948e-04, 1.049e-04
# Setting field (magntidue) to 0.000606
# Setting x, y, z to 3.654e-20, 5.968e-04, 1.052e-04
# Setting field (magntidue) to 0.000608
# Setting x, y, z to 3.666e-20, 5.988e-04, 1.056e-04
# Setting field (magntidue) to 0.00061
# Setting x, y, z to 3.678e-20, 6.007e-04, 1.059e-04
# Setting field (magntidue) to 0.000612
# Setting x, y, z to 3.690e-20, 6.027e-04, 1.063e-04
# Setting field (magntidue) to 0.000614
# Setting x, y, z to 3.703e-20, 6.047e-04, 1.066e-04
# Setting field (magntidue) to 0.000616
# Setting x, y, z to 3.715e-20, 6.066e-04, 1.070e-04
# Setting field (magntidue) to 0.000618
# Setting x, y, z to 3.727e-20, 6.086e-04, 1.073e-04
# Setting field (magntidue) to 0.00062
# Setting x, y, z to 3.739e-20, 6.106e-04, 1.077e-04
# Setting field (magntidue) to 0.000622
# Setting x, y, z to 3.751e-20, 6.126e-04, 1.080e-04
# Setting field (magntidue) to 0.000624
# Setting x, y, z to 3.763e-20, 6.145e-04, 1.084e-04
# Setting field (magntidue) to 0.000626
# Setting x, y, z to 3.775e-20, 6.165e-04, 1.087e-04
# Setting field (magntidue) to 0.000628
# Setting x, y, z to 3.787e-20, 6.185e-04, 1.091e-04
# Setting field (magntidue) to 0.00063
# Setting x, y, z to 3.799e-20, 6.204e-04, 1.094e-04
# Setting field (magntidue) to 0.000632
# Setting x, y, z to 3.811e-20, 6.224e-04, 1.097e-04
# Setting field (magntidue) to 0.000634
# Setting x, y, z to 3.823e-20, 6.244e-04, 1.101e-04
# Setting field (magntidue) to 0.000636
# Setting x, y, z to 3.835e-20, 6.263e-04, 1.104e-04
# Setting field (magntidue) to 0.000638
# Setting x, y, z to 3.847e-20, 6.283e-04, 1.108e-04
# Setting field (magntidue) to 0.00064
# Setting x, y, z to 3.859e-20, 6.303e-04, 1.111e-04
# Setting field (magntidue) to 0.000642
# Setting x, y, z to 3.871e-20, 6.322e-04, 1.115e-04
# Setting field (magntidue) to 0.000644
# Setting x, y, z to 3.883e-20, 6.342e-04, 1.118e-04
# Setting field (magntidue) to 0.000646
# Setting x, y, z to 3.896e-20, 6.362e-04, 1.122e-04
# Setting field (magntidue) to 0.000648
# Setting x, y, z to 3.908e-20, 6.382e-04, 1.125e-04
# Setting field (magntidue) to 0.00065
# Setting x, y, z to 3.920e-20, 6.401e-04, 1.129e-04
# Setting field (magntidue) to 0.000652
# Setting x, y, z to 3.932e-20, 6.421e-04, 1.132e-04
# Setting field (magntidue) to 0.000654
# Setting x, y, z to 3.944e-20, 6.441e-04, 1.136e-04
# Setting field (magntidue) to 0.000656
# Setting x, y, z to 3.956e-20, 6.460e-04, 1.139e-04
# Setting field (magntidue) to 0.000658
# Setting x, y, z to 3.968e-20, 6.480e-04, 1.143e-04
# Setting field (magntidue) to 0.00066
# Setting x, y, z to 3.980e-20, 6.500e-04, 1.146e-04
# Setting field (magntidue) to 0.000662
# Setting x, y, z to 3.992e-20, 6.519e-04, 1.150e-04
# Setting field (magntidue) to 0.000664
# Setting x, y, z to 4.004e-20, 6.539e-04, 1.153e-04
# Setting field (magntidue) to 0.000666
# Setting x, y, z to 4.016e-20, 6.559e-04, 1.156e-04
# Setting field (magntidue) to 0.000668
# Setting x, y, z to 4.028e-20, 6.579e-04, 1.160e-04
# Setting field (magntidue) to 0.00067
# Setting x, y, z to 4.040e-20, 6.598e-04, 1.163e-04
# Setting field (magntidue) to 0.000672
# Setting x, y, z to 4.052e-20, 6.618e-04, 1.167e-04
# Setting field (magntidue) to 0.000674
# Setting x, y, z to 4.064e-20, 6.638e-04, 1.170e-04
# Setting field (magntidue) to 0.000676
# Setting x, y, z to 4.076e-20, 6.657e-04, 1.174e-04
# Setting field (magntidue) to 0.000678
# Setting x, y, z to 4.088e-20, 6.677e-04, 1.177e-04
# Setting field (magntidue) to 0.00068
# Setting x, y, z to 4.101e-20, 6.697e-04, 1.181e-04
# Setting field (magntidue) to 0.000682
# Setting x, y, z to 4.113e-20, 6.716e-04, 1.184e-04
# Setting field (magntidue) to 0.000684
# Setting x, y, z to 4.125e-20, 6.736e-04, 1.188e-04
# Setting field (magntidue) to 0.000686
# Setting x, y, z to 4.137e-20, 6.756e-04, 1.191e-04
# Setting field (magntidue) to 0.000688
# Setting x, y, z to 4.149e-20, 6.775e-04, 1.195e-04
# Setting field (magntidue) to 0.00069
# Setting x, y, z to 4.161e-20, 6.795e-04, 1.198e-04
# Setting field (magntidue) to 0.000692
# Setting x, y, z to 4.173e-20, 6.815e-04, 1.202e-04
# Setting field (magntidue) to 0.000694
# Setting x, y, z to 4.185e-20, 6.835e-04, 1.205e-04
# Setting field (magntidue) to 0.000696
# Setting x, y, z to 4.197e-20, 6.854e-04, 1.209e-04
# Setting field (magntidue) to 0.000698
# Setting x, y, z to 4.209e-20, 6.874e-04, 1.212e-04
# Setting field (magntidue) to 0.0007
# Setting x, y, z to 4.221e-20, 6.894e-04, 1.216e-04
# Setting field (magntidue) to 0.000702
# Setting x, y, z to 4.233e-20, 6.913e-04, 1.219e-04
# Setting field (magntidue) to 0.000704
# Setting x, y, z to 4.245e-20, 6.933e-04, 1.222e-04
# Setting field (magntidue) to 0.000706
# Setting x, y, z to 4.257e-20, 6.953e-04, 1.226e-04
# Setting field (magntidue) to 0.000708
# Setting x, y, z to 4.269e-20, 6.972e-04, 1.229e-04
# Setting field (magntidue) to 0.00071
# Setting x, y, z to 4.281e-20, 6.992e-04, 1.233e-04
# Setting field (magntidue) to 0.000712
# Setting x, y, z to 4.294e-20, 7.012e-04, 1.236e-04
# Setting field (magntidue) to 0.000714
# Setting x, y, z to 4.306e-20, 7.032e-04, 1.240e-04
# Setting field (magntidue) to 0.000716
# Setting x, y, z to 4.318e-20, 7.051e-04, 1.243e-04
# Setting field (magntidue) to 0.000718
# Setting x, y, z to 4.330e-20, 7.071e-04, 1.247e-04
# Setting field (magntidue) to 0.00072
# Setting x, y, z to 4.342e-20, 7.091e-04, 1.250e-04
# Setting field (magntidue) to 0.000722
# Setting x, y, z to 4.354e-20, 7.110e-04, 1.254e-04
# Setting field (magntidue) to 0.000724
# Setting x, y, z to 4.366e-20, 7.130e-04, 1.257e-04
# Setting field (magntidue) to 0.000726
# Setting x, y, z to 4.378e-20, 7.150e-04, 1.261e-04
# Setting field (magntidue) to 0.000728
# Setting x, y, z to 4.390e-20, 7.169e-04, 1.264e-04
# Setting field (magntidue) to 0.00073
# Setting x, y, z to 4.402e-20, 7.189e-04, 1.268e-04
# Setting field (magntidue) to 0.000732
# Setting x, y, z to 4.414e-20, 7.209e-04, 1.271e-04
# Setting field (magntidue) to 0.000734
# Setting x, y, z to 4.426e-20, 7.228e-04, 1.275e-04
# Setting field (magntidue) to 0.000736
# Setting x, y, z to 4.438e-20, 7.248e-04, 1.278e-04
# Setting field (magntidue) to 0.000738
# Setting x, y, z to 4.450e-20, 7.268e-04, 1.282e-04
# Setting field (magntidue) to 0.00074
# Setting x, y, z to 4.462e-20, 7.288e-04, 1.285e-04
# Setting field (magntidue) to 0.000742
# Setting x, y, z to 4.474e-20, 7.307e-04, 1.288e-04
# Setting field (magntidue) to 0.000744
# Setting x, y, z to 4.486e-20, 7.327e-04, 1.292e-04
# Setting field (magntidue) to 0.000746
# Setting x, y, z to 4.499e-20, 7.347e-04, 1.295e-04
# Setting field (magntidue) to 0.000748
# Setting x, y, z to 4.511e-20, 7.366e-04, 1.299e-04
# Setting field (magntidue) to 0.00075
# Setting x, y, z to 4.523e-20, 7.386e-04, 1.302e-04
# Setting field (magntidue) to 0.000752
# Setting x, y, z to 4.535e-20, 7.406e-04, 1.306e-04
# Setting field (magntidue) to 0.000754
# Setting x, y, z to 4.547e-20, 7.425e-04, 1.309e-04
# Setting field (magntidue) to 0.000756
# Setting x, y, z to 4.559e-20, 7.445e-04, 1.313e-04
# Setting field (magntidue) to 0.000758
# Setting x, y, z to 4.571e-20, 7.465e-04, 1.316e-04
# Setting field (magntidue) to 0.00076
# Setting x, y, z to 4.583e-20, 7.485e-04, 1.320e-04
# Setting field (magntidue) to 0.000762
# Setting x, y, z to 4.595e-20, 7.504e-04, 1.323e-04
# Setting field (magntidue) to 0.000764
# Setting x, y, z to 4.607e-20, 7.524e-04, 1.327e-04
# Setting field (magntidue) to 0.000766
# Setting x, y, z to 4.619e-20, 7.544e-04, 1.330e-04
# Setting field (magntidue) to 0.000768
# Setting x, y, z to 4.631e-20, 7.563e-04, 1.334e-04
# Setting field (magntidue) to 0.00077
# Setting x, y, z to 4.643e-20, 7.583e-04, 1.337e-04
# Setting field (magntidue) to 0.000772
# Setting x, y, z to 4.655e-20, 7.603e-04, 1.341e-04
# Setting field (magntidue) to 0.000774
# Setting x, y, z to 4.667e-20, 7.622e-04, 1.344e-04
# Setting field (magntidue) to 0.000776
# Setting x, y, z to 4.679e-20, 7.642e-04, 1.348e-04
# Setting field (magntidue) to 0.000778
# Setting x, y, z to 4.692e-20, 7.662e-04, 1.351e-04
# Setting field (magntidue) to 0.00078
# Setting x, y, z to 4.704e-20, 7.682e-04, 1.354e-04
# Setting field (magntidue) to 0.000782
# Setting x, y, z to 4.716e-20, 7.701e-04, 1.358e-04
# Setting field (magntidue) to 0.000784
# Setting x, y, z to 4.728e-20, 7.721e-04, 1.361e-04
# Setting field (magntidue) to 0.000786
# Setting x, y, z to 4.740e-20, 7.741e-04, 1.365e-04
# Setting field (magntidue) to 0.000788
# Setting x, y, z to 4.752e-20, 7.760e-04, 1.368e-04
# Setting field (magntidue) to 0.00079
# Setting x, y, z to 4.764e-20, 7.780e-04, 1.372e-04
# Setting field (magntidue) to 0.000792
# Setting x, y, z to 4.776e-20, 7.800e-04, 1.375e-04
# Setting field (magntidue) to 0.000794
# Setting x, y, z to 4.788e-20, 7.819e-04, 1.379e-04
# Setting field (magntidue) to 0.000796
# Setting x, y, z to 4.800e-20, 7.839e-04, 1.382e-04
# Setting field (magntidue) to 0.000798
# Setting x, y, z to 4.812e-20, 7.859e-04, 1.386e-04
# Setting field (magntidue) to 0.0008
# Setting x, y, z to 4.824e-20, 7.878e-04, 1.389e-04
# Setting field (magntidue) to 0.000802
# Setting x, y, z to 4.836e-20, 7.898e-04, 1.393e-04
# Setting field (magntidue) to 0.000804
# Setting x, y, z to 4.848e-20, 7.918e-04, 1.396e-04
# Setting field (magntidue) to 0.000806
# Setting x, y, z to 4.860e-20, 7.938e-04, 1.400e-04
# Setting field (magntidue) to 0.000808
# Setting x, y, z to 4.872e-20, 7.957e-04, 1.403e-04
# Setting field (magntidue) to 0.00081
# Setting x, y, z to 4.884e-20, 7.977e-04, 1.407e-04
# Setting field (magntidue) to 0.000812
# Setting x, y, z to 4.897e-20, 7.997e-04, 1.410e-04
# Setting field (magntidue) to 0.000814
# Setting x, y, z to 4.909e-20, 8.016e-04, 1.413e-04
# Setting field (magntidue) to 0.000816
# Setting x, y, z to 4.921e-20, 8.036e-04, 1.417e-04
# Setting field (magntidue) to 0.000818
# Setting x, y, z to 4.933e-20, 8.056e-04, 1.420e-04
# Setting field (magntidue) to 0.00082
# Setting x, y, z to 4.945e-20, 8.075e-04, 1.424e-04
# Setting field (magntidue) to 0.000822
# Setting x, y, z to 4.957e-20, 8.095e-04, 1.427e-04
# Setting field (magntidue) to 0.000824
# Setting x, y, z to 4.969e-20, 8.115e-04, 1.431e-04
# Setting field (magntidue) to 0.000826
# Setting x, y, z to 4.981e-20, 8.135e-04, 1.434e-04
# Setting field (magntidue) to 0.000828
# Setting x, y, z to 4.993e-20, 8.154e-04, 1.438e-04
# Setting field (magntidue) to 0.00083
# Setting x, y, z to 5.005e-20, 8.174e-04, 1.441e-04
# Setting field (magntidue) to 0.000832
# Setting x, y, z to 5.017e-20, 8.194e-04, 1.445e-04
# Setting field (magntidue) to 0.000834
# Setting x, y, z to 5.029e-20, 8.213e-04, 1.448e-04
# Setting field (magntidue) to 0.000836
# Setting x, y, z to 5.041e-20, 8.233e-04, 1.452e-04
# Setting field (magntidue) to 0.000838
# Setting x, y, z to 5.053e-20, 8.253e-04, 1.455e-04
# Setting field (magntidue) to 0.00084
# Setting x, y, z to 5.065e-20, 8.272e-04, 1.459e-04
# Setting field (magntidue) to 0.000842
# Setting x, y, z to 5.077e-20, 8.292e-04, 1.462e-04
# Setting field (magntidue) to 0.000844
# Setting x, y, z to 5.089e-20, 8.312e-04, 1.466e-04
# Setting field (magntidue) to 0.000846
# Setting x, y, z to 5.102e-20, 8.331e-04, 1.469e-04
# Setting field (magntidue) to 0.000848
# Setting x, y, z to 5.114e-20, 8.351e-04, 1.473e-04
# Setting field (magntidue) to 0.00085
# Setting x, y, z to 5.126e-20, 8.371e-04, 1.476e-04
# Setting field (magntidue) to 0.000852
# Setting x, y, z to 5.138e-20, 8.391e-04, 1.479e-04
# Setting field (magntidue) to 0.000854
# Setting x, y, z to 5.150e-20, 8.410e-04, 1.483e-04
# Setting field (magntidue) to 0.000856
# Setting x, y, z to 5.162e-20, 8.430e-04, 1.486e-04
# Setting field (magntidue) to 0.000858
# Setting x, y, z to 5.174e-20, 8.450e-04, 1.490e-04
# Setting field (magntidue) to 0.00086
# Setting x, y, z to 5.186e-20, 8.469e-04, 1.493e-04
# Setting field (magntidue) to 0.000862
# Setting x, y, z to 5.198e-20, 8.489e-04, 1.497e-04
# Setting field (magntidue) to 0.000864
# Setting x, y, z to 5.210e-20, 8.509e-04, 1.500e-04
# Setting field (magntidue) to 0.000866
# Setting x, y, z to 5.222e-20, 8.528e-04, 1.504e-04
# Setting field (magntidue) to 0.000868
# Setting x, y, z to 5.234e-20, 8.548e-04, 1.507e-04
# Setting field (magntidue) to 0.00087
# Setting x, y, z to 5.246e-20, 8.568e-04, 1.511e-04
# Setting field (magntidue) to 0.000872
# Setting x, y, z to 5.258e-20, 8.588e-04, 1.514e-04
# Setting field (magntidue) to 0.000874
# Setting x, y, z to 5.270e-20, 8.607e-04, 1.518e-04
# Setting field (magntidue) to 0.000876
# Setting x, y, z to 5.282e-20, 8.627e-04, 1.521e-04
# Setting field (magntidue) to 0.000878
# Setting x, y, z to 5.295e-20, 8.647e-04, 1.525e-04
# Setting field (magntidue) to 0.00088
# Setting x, y, z to 5.307e-20, 8.666e-04, 1.528e-04
# Setting field (magntidue) to 0.000882
# Setting x, y, z to 5.319e-20, 8.686e-04, 1.532e-04
# Setting field (magntidue) to 0.000884
# Setting x, y, z to 5.331e-20, 8.706e-04, 1.535e-04
# Setting field (magntidue) to 0.000886
# Setting x, y, z to 5.343e-20, 8.725e-04, 1.539e-04
# Setting field (magntidue) to 0.000888
# Setting x, y, z to 5.355e-20, 8.745e-04, 1.542e-04
# Setting field (magntidue) to 0.00089
# Setting x, y, z to 5.367e-20, 8.765e-04, 1.545e-04
# Setting field (magntidue) to 0.000892
# Setting x, y, z to 5.379e-20, 8.784e-04, 1.549e-04
# Setting field (magntidue) to 0.000894
# Setting x, y, z to 5.391e-20, 8.804e-04, 1.552e-04
# Setting field (magntidue) to 0.000896
# Setting x, y, z to 5.403e-20, 8.824e-04, 1.556e-04
# Setting field (magntidue) to 0.000898
# Setting x, y, z to 5.415e-20, 8.844e-04, 1.559e-04
# Setting field (magntidue) to 0.0009
# Setting x, y, z to 5.427e-20, 8.863e-04, 1.563e-04
# Setting field (magntidue) to 0.000902
# Setting x, y, z to 5.439e-20, 8.883e-04, 1.566e-04
# Setting field (magntidue) to 0.000904
# Setting x, y, z to 5.451e-20, 8.903e-04, 1.570e-04
# Setting field (magntidue) to 0.000906
# Setting x, y, z to 5.463e-20, 8.922e-04, 1.573e-04
# Setting field (magntidue) to 0.000908
# Setting x, y, z to 5.475e-20, 8.942e-04, 1.577e-04
# Setting field (magntidue) to 0.00091
# Setting x, y, z to 5.487e-20, 8.962e-04, 1.580e-04
# Setting field (magntidue) to 0.000912
# Setting x, y, z to 5.500e-20, 8.981e-04, 1.584e-04
# Setting field (magntidue) to 0.000914
# Setting x, y, z to 5.512e-20, 9.001e-04, 1.587e-04
# Setting field (magntidue) to 0.000916
# Setting x, y, z to 5.524e-20, 9.021e-04, 1.591e-04
# Setting field (magntidue) to 0.000918
# Setting x, y, z to 5.536e-20, 9.041e-04, 1.594e-04
# Setting field (magntidue) to 0.00092
# Setting x, y, z to 5.548e-20, 9.060e-04, 1.598e-04
# Setting field (magntidue) to 0.000922
# Setting x, y, z to 5.560e-20, 9.080e-04, 1.601e-04
# Setting field (magntidue) to 0.000924
# Setting x, y, z to 5.572e-20, 9.100e-04, 1.605e-04
# Setting field (magntidue) to 0.000926
# Setting x, y, z to 5.584e-20, 9.119e-04, 1.608e-04
# Setting field (magntidue) to 0.000928
# Setting x, y, z to 5.596e-20, 9.139e-04, 1.611e-04
# Setting field (magntidue) to 0.00093
# Setting x, y, z to 5.608e-20, 9.159e-04, 1.615e-04
# Setting field (magntidue) to 0.000932
# Setting x, y, z to 5.620e-20, 9.178e-04, 1.618e-04
# Setting field (magntidue) to 0.000934
# Setting x, y, z to 5.632e-20, 9.198e-04, 1.622e-04
# Setting field (magntidue) to 0.000936
# Setting x, y, z to 5.644e-20, 9.218e-04, 1.625e-04
# Setting field (magntidue) to 0.000938
# Setting x, y, z to 5.656e-20, 9.237e-04, 1.629e-04
# Setting field (magntidue) to 0.00094
# Setting x, y, z to 5.668e-20, 9.257e-04, 1.632e-04
# Setting field (magntidue) to 0.000942
# Setting x, y, z to 5.680e-20, 9.277e-04, 1.636e-04
# Setting field (magntidue) to 0.000944
# Setting x, y, z to 5.693e-20, 9.297e-04, 1.639e-04
# Setting field (magntidue) to 0.000946
# Setting x, y, z to 5.705e-20, 9.316e-04, 1.643e-04
# Setting field (magntidue) to 0.000948
# Setting x, y, z to 5.717e-20, 9.336e-04, 1.646e-04
# Setting field (magntidue) to 0.00095
# Setting x, y, z to 5.729e-20, 9.356e-04, 1.650e-04
# Setting field (magntidue) to 0.000952
# Setting x, y, z to 5.741e-20, 9.375e-04, 1.653e-04
# Setting field (magntidue) to 0.000954
# Setting x, y, z to 5.753e-20, 9.395e-04, 1.657e-04
# Setting field (magntidue) to 0.000956
# Setting x, y, z to 5.765e-20, 9.415e-04, 1.660e-04
# Setting field (magntidue) to 0.000958
# Setting x, y, z to 5.777e-20, 9.434e-04, 1.664e-04
# Setting field (magntidue) to 0.00096
# Setting x, y, z to 5.789e-20, 9.454e-04, 1.667e-04
# Setting field (magntidue) to 0.000962
# Setting x, y, z to 5.801e-20, 9.474e-04, 1.670e-04
# Setting field (magntidue) to 0.000964
# Setting x, y, z to 5.813e-20, 9.494e-04, 1.674e-04
# Setting field (magntidue) to 0.000966
# Setting x, y, z to 5.825e-20, 9.513e-04, 1.677e-04
# Setting field (magntidue) to 0.000968
# Setting x, y, z to 5.837e-20, 9.533e-04, 1.681e-04
# Setting field (magntidue) to 0.00097
# Setting x, y, z to 5.849e-20, 9.553e-04, 1.684e-04
# Setting field (magntidue) to 0.000972
# Setting x, y, z to 5.861e-20, 9.572e-04, 1.688e-04
# Setting field (magntidue) to 0.000974
# Setting x, y, z to 5.873e-20, 9.592e-04, 1.691e-04
# Setting field (magntidue) to 0.000976
# Setting x, y, z to 5.885e-20, 9.612e-04, 1.695e-04
# Setting field (magntidue) to 0.000978
# Setting x, y, z to 5.898e-20, 9.631e-04, 1.698e-04
# Setting field (magntidue) to 0.00098
# Setting x, y, z to 5.910e-20, 9.651e-04, 1.702e-04
# Setting field (magntidue) to 0.000982
# Setting x, y, z to 5.922e-20, 9.671e-04, 1.705e-04
# Setting field (magntidue) to 0.000984
# Setting x, y, z to 5.934e-20, 9.691e-04, 1.709e-04
# Setting field (magntidue) to 0.000986
# Setting x, y, z to 5.946e-20, 9.710e-04, 1.712e-04
# Setting field (magntidue) to 0.000988
# Setting x, y, z to 5.958e-20, 9.730e-04, 1.716e-04
# Setting field (magntidue) to 0.00099
# Setting x, y, z to 5.970e-20, 9.750e-04, 1.719e-04
# Setting field (magntidue) to 0.000992
# Setting x, y, z to 5.982e-20, 9.769e-04, 1.723e-04
# Setting field (magntidue) to 0.000994
# Setting x, y, z to 5.994e-20, 9.789e-04, 1.726e-04
# Setting field (magntidue) to 0.000996
# Setting x, y, z to 6.006e-20, 9.809e-04, 1.730e-04
# Setting field (magntidue) to 0.000998
# Setting x, y, z to 6.018e-20, 9.828e-04, 1.733e-04
# Setting field (magntidue) to 0.001
# Setting x, y, z to 6.030e-20, 9.848e-04, 1.736e-04
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 33
# Setting field (magntidue) to 0.0
# Setting x, y, z to 0.000e+00, 0.000e+00, 0.000e+00
# Setting field (magntidue) to 2e-06
# Setting x, y, z to 1.214e-22, 1.983e-06, 2.611e-07
# Setting field (magntidue) to 4e-06
# Setting x, y, z to 2.428e-22, 3.966e-06, 5.221e-07
# Setting field (magntidue) to 6e-06
# Setting x, y, z to 3.643e-22, 5.949e-06, 7.832e-07
# Setting field (magntidue) to 8e-06
# Setting x, y, z to 4.857e-22, 7.932e-06, 1.044e-06
# Setting field (magntidue) to 1e-05
# Setting x, y, z to 6.071e-22, 9.914e-06, 1.305e-06
# Setting field (magntidue) to 1.2e-05
# Setting x, y, z to 7.285e-22, 1.190e-05, 1.566e-06
# Setting field (magntidue) to 1.4e-05
# Setting x, y, z to 8.499e-22, 1.388e-05, 1.827e-06
# Setting field (magntidue) to 1.6e-05
# Setting x, y, z to 9.713e-22, 1.586e-05, 2.088e-06
# Setting field (magntidue) to 1.8e-05
# Setting x, y, z to 1.093e-21, 1.785e-05, 2.349e-06
# Setting field (magntidue) to 2e-05
# Setting x, y, z to 1.214e-21, 1.983e-05, 2.611e-06
# Setting field (magntidue) to 2.2e-05
# Setting x, y, z to 1.336e-21, 2.181e-05, 2.872e-06
# Setting field (magntidue) to 2.4e-05
# Setting x, y, z to 1.457e-21, 2.379e-05, 3.133e-06
# Setting field (magntidue) to 2.6e-05
# Setting x, y, z to 1.578e-21, 2.578e-05, 3.394e-06
# Setting field (magntidue) to 2.8e-05
# Setting x, y, z to 1.700e-21, 2.776e-05, 3.655e-06
# Setting field (magntidue) to 3e-05
# Setting x, y, z to 1.821e-21, 2.974e-05, 3.916e-06
# Setting field (magntidue) to 3.2e-05
# Setting x, y, z to 1.943e-21, 3.173e-05, 4.177e-06
# Setting field (magntidue) to 3.4e-05
# Setting x, y, z to 2.064e-21, 3.371e-05, 4.438e-06
# Setting field (magntidue) to 3.6e-05
# Setting x, y, z to 2.186e-21, 3.569e-05, 4.699e-06
# Setting field (magntidue) to 3.8e-05
# Setting x, y, z to 2.307e-21, 3.767e-05, 4.960e-06
# Setting field (magntidue) to 4e-05
# Setting x, y, z to 2.428e-21, 3.966e-05, 5.221e-06
# Setting field (magntidue) to 4.2e-05
# Setting x, y, z to 2.550e-21, 4.164e-05, 5.482e-06
# Setting field (magntidue) to 4.4e-05
# Setting x, y, z to 2.671e-21, 4.362e-05, 5.743e-06
# Setting field (magntidue) to 4.6e-05
# Setting x, y, z to 2.793e-21, 4.561e-05, 6.004e-06
# Setting field (magntidue) to 4.8e-05
# Setting x, y, z to 2.914e-21, 4.759e-05, 6.265e-06
# Setting field (magntidue) to 5e-05
# Setting x, y, z to 3.035e-21, 4.957e-05, 6.526e-06
# Setting field (magntidue) to 5.2e-05
# Setting x, y, z to 3.157e-21, 5.156e-05, 6.787e-06
# Setting field (magntidue) to 5.4e-05
# Setting x, y, z to 3.278e-21, 5.354e-05, 7.048e-06
# Setting field (magntidue) to 5.6e-05
# Setting x, y, z to 3.400e-21, 5.552e-05, 7.309e-06
# Setting field (magntidue) to 5.8e-05
# Setting x, y, z to 3.521e-21, 5.750e-05, 7.571e-06
# Setting field (magntidue) to 6e-05
# Setting x, y, z to 3.643e-21, 5.949e-05, 7.832e-06
# Setting field (magntidue) to 6.2e-05
# Setting x, y, z to 3.764e-21, 6.147e-05, 8.093e-06
# Setting field (magntidue) to 6.4e-05
# Setting x, y, z to 3.885e-21, 6.345e-05, 8.354e-06
# Setting field (magntidue) to 6.6e-05
# Setting x, y, z to 4.007e-21, 6.544e-05, 8.615e-06
# Setting field (magntidue) to 6.8e-05
# Setting x, y, z to 4.128e-21, 6.742e-05, 8.876e-06
# Setting field (magntidue) to 7e-05
# Setting x, y, z to 4.250e-21, 6.940e-05, 9.137e-06
# ...
# Setting x, y, z to 6.344e-21, 1.036e-04, -9.064e-06
# Setting field (magntidue) to 0.000106
# Setting x, y, z to 6.466e-21, 1.056e-04, -9.239e-06
# Setting field (magntidue) to 0.000108
# Setting x, y, z to 6.588e-21, 1.076e-04, -9.413e-06
# Setting field (magntidue) to 0.00011
# Setting x, y, z to 6.710e-21, 1.096e-04, -9.587e-06
# Setting field (magntidue) to 0.000112
# Setting x, y, z to 6.832e-21, 1.116e-04, -9.761e-06
# Setting field (magntidue) to 0.000114
# Setting x, y, z to 6.954e-21, 1.136e-04, -9.936e-06
# Setting field (magntidue) to 0.000116
# Setting x, y, z to 7.076e-21, 1.156e-04, -1.011e-05
# Setting field (magntidue) to 0.000118
# Setting x, y, z to 7.198e-21, 1.176e-04, -1.028e-05
# Setting field (magntidue) to 0.00012
# Setting x, y, z to 7.320e-21, 1.195e-04, -1.046e-05
# Setting field (magntidue) to 0.000122
# Setting x, y, z to 7.442e-21, 1.215e-04, -1.063e-05
# Setting field (magntidue) to 0.000124
# Setting x, y, z to 7.564e-21, 1.235e-04, -1.081e-05
# Setting field (magntidue) to 0.000126
# Setting x, y, z to 7.686e-21, 1.255e-04, -1.098e-05
# Setting field (magntidue) to 0.000128
# Setting x, y, z to 7.808e-21, 1.275e-04, -1.116e-05
# Setting field (magntidue) to 0.00013
# Setting x, y, z to 7.930e-21, 1.295e-04, -1.133e-05
# Setting field (magntidue) to 0.000132
# Setting x, y, z to 8.052e-21, 1.315e-04, -1.150e-05
# Setting field (magntidue) to 0.000134
# Setting x, y, z to 8.174e-21, 1.335e-04, -1.168e-05
# Setting field (magntidue) to 0.000136
# Setting x, y, z to 8.296e-21, 1.355e-04, -1.185e-05
# Setting field (magntidue) to 0.000138
# Setting x, y, z to 8.418e-21, 1.375e-04, -1.203e-05
# Setting field (magntidue) to 0.00014
# Setting x, y, z to 8.540e-21, 1.395e-04, -1.220e-05
# Setting field (magntidue) to 0.000142
# Setting x, y, z to 8.662e-21, 1.415e-04, -1.238e-05
# Setting field (magntidue) to 0.000144
# Setting x, y, z to 8.784e-21, 1.435e-04, -1.255e-05
# Setting field (magntidue) to 0.000146
# Setting x, y, z to 8.906e-21, 1.454e-04, -1.272e-05
# Setting field (magntidue) to 0.000148
# Setting x, y, z to 9.028e-21, 1.474e-04, -1.290e-05
# Setting field (magntidue) to 0.00015
# Setting x, y, z to 9.150e-21, 1.494e-04, -1.307e-05
# Setting field (magntidue) to 0.000152
# Setting x, y, z to 9.272e-21, 1.514e-04, -1.325e-05
# Setting field (magntidue) to 0.000154
# Setting x, y, z to 9.394e-21, 1.534e-04, -1.342e-05
# Setting field (magntidue) to 0.000156
# Setting x, y, z to 9.516e-21, 1.554e-04, -1.360e-05
# Setting field (magntidue) to 0.000158
# Setting x, y, z to 9.638e-21, 1.574e-04, -1.377e-05
# Setting field (magntidue) to 0.00016
# Setting x, y, z to 9.760e-21, 1.594e-04, -1.394e-05
# Setting field (magntidue) to 0.000162
# Setting x, y, z to 9.882e-21, 1.614e-04, -1.412e-05
# Setting field (magntidue) to 0.000164
# Setting x, y, z to 1.000e-20, 1.634e-04, -1.429e-05
# Setting field (magntidue) to 0.000166
# Setting x, y, z to 1.013e-20, 1.654e-04, -1.447e-05
# Setting field (magntidue) to 0.000168
# Setting x, y, z to 1.025e-20, 1.674e-04, -1.464e-05
# Setting field (magntidue) to 0.00017
# Setting x, y, z to 1.037e-20, 1.694e-04, -1.482e-05
# Setting field (magntidue) to 0.000172
# Setting x, y, z to 1.049e-20, 1.713e-04, -1.499e-05
# Setting field (magntidue) to 0.000174
# Setting x, y, z to 1.061e-20, 1.733e-04, -1.517e-05
# Setting field (magntidue) to 0.000176
# Setting x, y, z to 1.074e-20, 1.753e-04, -1.534e-05
# Setting field (magntidue) to 0.000178
# Setting x, y, z to 1.086e-20, 1.773e-04, -1.551e-05
# Setting field (magntidue) to 0.00018
# Setting x, y, z to 1.098e-20, 1.793e-04, -1.569e-05
# Setting field (magntidue) to 0.000182
# Setting x, y, z to 1.110e-20, 1.813e-04, -1.586e-05
# Setting field (magntidue) to 0.000184
# Setting x, y, z to 1.122e-20, 1.833e-04, -1.604e-05
# Setting field (magntidue) to 0.000186
# Setting x, y, z to 1.135e-20, 1.853e-04, -1.621e-05
# Setting field (magntidue) to 0.000188
# Setting x, y, z to 1.147e-20, 1.873e-04, -1.639e-05
# Setting field (magntidue) to 0.00019
# Setting x, y, z to 1.159e-20, 1.893e-04, -1.656e-05
# Setting field (magntidue) to 0.000192
# Setting x, y, z to 1.171e-20, 1.913e-04, -1.673e-05
# Setting field (magntidue) to 0.000194
# Setting x, y, z to 1.183e-20, 1.933e-04, -1.691e-05
# Setting field (magntidue) to 0.000196
# Setting x, y, z to 1.196e-20, 1.953e-04, -1.708e-05
# Setting field (magntidue) to 0.000198
# Setting x, y, z to 1.208e-20, 1.972e-04, -1.726e-05
# Setting field (magntidue) to 0.0002
# Setting x, y, z to 1.220e-20, 1.992e-04, -1.743e-05
# Setting field (magntidue) to 0.000202
# Setting x, y, z to 1.232e-20, 2.012e-04, -1.761e-05
# Setting field (magntidue) to 0.000204
# Setting x, y, z to 1.244e-20, 2.032e-04, -1.778e-05
# Setting field (magntidue) to 0.000206
# Setting x, y, z to 1.257e-20, 2.052e-04, -1.795e-05
# Setting field (magntidue) to 0.000208
# Setting x, y, z to 1.269e-20, 2.072e-04, -1.813e-05
# Setting field (magntidue) to 0.00021
# Setting x, y, z to 1.281e-20, 2.092e-04, -1.830e-05
# Setting field (magntidue) to 0.000212
# Setting x, y, z to 1.293e-20, 2.112e-04, -1.848e-05
# Setting field (magntidue) to 0.000214
# Setting x, y, z to 1.305e-20, 2.132e-04, -1.865e-05
# Setting field (magntidue) to 0.000216
# Setting x, y, z to 1.318e-20, 2.152e-04, -1.883e-05
# Setting field (magntidue) to 0.000218
# Setting x, y, z to 1.330e-20, 2.172e-04, -1.900e-05
# Setting field (magntidue) to 0.00022
# Setting x, y, z to 1.342e-20, 2.192e-04, -1.917e-05
# Setting field (magntidue) to 0.000222
# Setting x, y, z to 1.354e-20, 2.212e-04, -1.935e-05
# Setting field (magntidue) to 0.000224
# Setting x, y, z to 1.366e-20, 2.231e-04, -1.952e-05
# Setting field (magntidue) to 0.000226
# Setting x, y, z to 1.379e-20, 2.251e-04, -1.970e-05
# Setting field (magntidue) to 0.000228
# Setting x, y, z to 1.391e-20, 2.271e-04, -1.987e-05
# Setting field (magntidue) to 0.00023
# Setting x, y, z to 1.403e-20, 2.291e-04, -2.005e-05
# Setting field (magntidue) to 0.000232
# Setting x, y, z to 1.415e-20, 2.311e-04, -2.022e-05
# Setting field (magntidue) to 0.000234
# Setting x, y, z to 1.427e-20, 2.331e-04, -2.039e-05
# Setting field (magntidue) to 0.000236
# Setting x, y, z to 1.440e-20, 2.351e-04, -2.057e-05
# Setting field (magntidue) to 0.000238
# Setting x, y, z to 1.452e-20, 2.371e-04, -2.074e-05
# Setting field (magntidue) to 0.00024
# Setting x, y, z to 1.464e-20, 2.391e-04, -2.092e-05
# Setting field (magntidue) to 0.000242
# Setting x, y, z to 1.476e-20, 2.411e-04, -2.109e-05
# Setting field (magntidue) to 0.000244
# Setting x, y, z to 1.488e-20, 2.431e-04, -2.127e-05
# Setting field (magntidue) to 0.000246
# Setting x, y, z to 1.501e-20, 2.451e-04, -2.144e-05
# Setting field (magntidue) to 0.000248
# Setting x, y, z to 1.513e-20, 2.471e-04, -2.161e-05
# Setting field (magntidue) to 0.00025
# Setting x, y, z to 1.525e-20, 2.490e-04, -2.179e-05
# Setting field (magntidue) to 0.000252
# Setting x, y, z to 1.537e-20, 2.510e-04, -2.196e-05
# Setting field (magntidue) to 0.000254
# Setting x, y, z to 1.549e-20, 2.530e-04, -2.214e-05
# Setting field (magntidue) to 0.000256
# Setting x, y, z to 1.562e-20, 2.550e-04, -2.231e-05
# Setting field (magntidue) to 0.000258
# Setting x, y, z to 1.574e-20, 2.570e-04, -2.249e-05
# Setting field (magntidue) to 0.00026
# Setting x, y, z to 1.586e-20, 2.590e-04, -2.266e-05
# Setting field (magntidue) to 0.000262
# Setting x, y, z to 1.598e-20, 2.610e-04, -2.283e-05
# Setting field (magntidue) to 0.000264
# Setting x, y, z to 1.610e-20, 2.630e-04, -2.301e-05
# Setting field (magntidue) to 0.000266
# Setting x, y, z to 1.623e-20, 2.650e-04, -2.318e-05
# Setting field (magntidue) to 0.000268
# Setting x, y, z to 1.635e-20, 2.670e-04, -2.336e-05
# Setting field (magntidue) to 0.00027
# Setting x, y, z to 1.647e-20, 2.690e-04, -2.353e-05
# Setting field (magntidue) to 0.000272
# Setting x, y, z to 1.659e-20, 2.710e-04, -2.371e-05
# Setting field (magntidue) to 0.000274
# Setting x, y, z to 1.671e-20, 2.730e-04, -2.388e-05
# Setting field (magntidue) to 0.000276
# Setting x, y, z to 1.684e-20, 2.749e-04, -2.405e-05
# Setting field (magntidue) to 0.000278
# Setting x, y, z to 1.696e-20, 2.769e-04, -2.423e-05
# Setting field (magntidue) to 0.00028
# Setting x, y, z to 1.708e-20, 2.789e-04, -2.440e-05
# Setting field (magntidue) to 0.000282
# Setting x, y, z to 1.720e-20, 2.809e-04, -2.458e-05
# Setting field (magntidue) to 0.000284
# Setting x, y, z to 1.732e-20, 2.829e-04, -2.475e-05
# Setting field (magntidue) to 0.000286
# Setting x, y, z to 1.745e-20, 2.849e-04, -2.493e-05
# Setting field (magntidue) to 0.000288
# Setting x, y, z to 1.757e-20, 2.869e-04, -2.510e-05
# Setting field (magntidue) to 0.00029
# Setting x, y, z to 1.769e-20, 2.889e-04, -2.528e-05
# Setting field (magntidue) to 0.000292
# Setting x, y, z to 1.781e-20, 2.909e-04, -2.545e-05
# Setting field (magntidue) to 0.000294
# Setting x, y, z to 1.793e-20, 2.929e-04, -2.562e-05
# Setting field (magntidue) to 0.000296
# Setting x, y, z to 1.806e-20, 2.949e-04, -2.580e-05
# Setting field (magntidue) to 0.000298
# Setting x, y, z to 1.818e-20, 2.969e-04, -2.597e-05
# Setting field (magntidue) to 0.0003
# Setting x, y, z to 1.830e-20, 2.989e-04, -2.615e-05
# Setting field (magntidue) to 0.000302
# Setting x, y, z to 1.842e-20, 3.009e-04, -2.632e-05
# Setting field (magntidue) to 0.000304
# Setting x, y, z to 1.854e-20, 3.028e-04, -2.650e-05
# Setting field (magntidue) to 0.000306
# Setting x, y, z to 1.867e-20, 3.048e-04, -2.667e-05
# Setting field (magntidue) to 0.000308
# Setting x, y, z to 1.879e-20, 3.068e-04, -2.684e-05
# Setting field (magntidue) to 0.00031
# Setting x, y, z to 1.891e-20, 3.088e-04, -2.702e-05
# Setting field (magntidue) to 0.000312
# Setting x, y, z to 1.903e-20, 3.108e-04, -2.719e-05
# Setting field (magntidue) to 0.000314
# Setting x, y, z to 1.915e-20, 3.128e-04, -2.737e-05
# Setting field (magntidue) to 0.000316
# Setting x, y, z to 1.928e-20, 3.148e-04, -2.754e-05
# Setting field (magntidue) to 0.000318
# Setting x, y, z to 1.940e-20, 3.168e-04, -2.772e-05
# Setting field (magntidue) to 0.00032
# Setting x, y, z to 1.952e-20, 3.188e-04, -2.789e-05
# Setting field (magntidue) to 0.000322
# Setting x, y, z to 1.964e-20, 3.208e-04, -2.806e-05
# Setting field (magntidue) to 0.000324
# Setting x, y, z to 1.976e-20, 3.228e-04, -2.824e-05
# Setting field (magntidue) to 0.000326
# Setting x, y, z to 1.989e-20, 3.248e-04, -2.841e-05
# Setting field (magntidue) to 0.000328
# Setting x, y, z to 2.001e-20, 3.268e-04, -2.859e-05
# Setting field (magntidue) to 0.00033
# Setting x, y, z to 2.013e-20, 3.287e-04, -2.876e-05
# Setting field (magntidue) to 0.000332
# Setting x, y, z to 2.025e-20, 3.307e-04, -2.894e-05
# Setting field (magntidue) to 0.000334
# Setting x, y, z to 2.037e-20, 3.327e-04, -2.911e-05
# Setting field (magntidue) to 0.000336
# Setting x, y, z to 2.050e-20, 3.347e-04, -2.928e-05
# Setting field (magntidue) to 0.000338
# Setting x, y, z to 2.062e-20, 3.367e-04, -2.946e-05
# Setting field (magntidue) to 0.00034
# Setting x, y, z to 2.074e-20, 3.387e-04, -2.963e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-fd020951d01f> in <module>()
#      38     for j in range(len(thetas)):
#      39         exp = qc.new_experiment("field phi=%d theta=%d, freq f=%.5e power=%d n=%d x %d" %(phis[i],thetas[j],f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")
# ---> 40         do_3D_field_sweep_single_frequency(B_fields, phis_rad[i], thetas_rad[j],  power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S12')
#
# <ipython-input-76-959d7a572fb7> in do_3D_field_sweep_single_frequency(B_field_mags, phi, theta, power, n_pts, f, n_avg, channel_name)
#     224             x, y, z = yoko_magnet.transform_spherical_to_cartesian(field, phi=phi, theta=theta)
#     225             print("Setting x, y, z to %.3e, %.3e, %.3e" %(x,y,z))
# --> 226             yoko_magnet.x(x)
#     227             yoko_magnet.y(y)
#     228             yoko_magnet.z(z)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     287         else:
#     288             if hasattr(self, 'set'):
# --> 289                 self.set(*args, **kwargs)
#     290             else:
#     291                 raise NotImplementedError('no set cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     465                     t0 = time.perf_counter()
#     466
# --> 467                     set_function(raw_value, **kwargs)
#     468                     self.raw_value = raw_value
#     469                     self._save_val(val_step,
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     287         else:
#     288             if hasattr(self, 'set'):
# --> 289                 self.set(*args, **kwargs)
#     290             else:
#     291                 raise NotImplementedError('no set cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     465                     t0 = time.perf_counter()
#     466
# --> 467                     set_function(raw_value, **kwargs)
#     468                     self.raw_value = raw_value
#     469                     self._save_val(val_step,
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py in set_field(self, value, block, perform_safety_check)
#     312
#     313         # Check we can ramp
# --> 314         if not self._can_start_ramping():
#     315             raise AMI430Exception("Cannot ramp in current state")
#     316
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py in _can_start_ramping(self)
#     269         Check the current state of the magnet to see if we can start ramping
#     270         """
# --> 271         if self.is_quenched():
#     272             logging.error(__name__ + ': Could not ramp because of quench')
#     273             return False
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in call_by_str(self, *args)
#     124     def call_by_str(self, *args):
#     125         """Execute a formatted string."""
# --> 126         return self.exec_str(self.cmd_str.format(*args))
#     127
#     128     def call_by_str_parsed_out(self, *args):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     737         """
#     738         try:
# --> 739             answer = self.ask_raw(cmd)
#     740
#     741             return answer
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\ip.py in ask_raw(self, cmd)
#     187         with self._ensure_connection:
#     188             self._send(cmd)
# --> 189             return self._recv()
#     190
#     191     def __del__(self):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\ip.py in _recv(self)
#     150
#     151     def _recv(self):
# --> 152         result = self._socket.recv(self._buffer_size)
#     153         log.debug(f"Got {result} from instrument {self.name}")
#     154         if result == b'':
#
# KeyboardInterrupt:

# %%
print("Taking single sweep")
t0=time.time()
do_single_sweep(n_pts = 200, f_start = f-10e6, f_stop = f+10e6, power=power, n_avg=1000, channel_name='S12')
print("Taking trace took", time.time()-t0)
# Out:
# Taking single sweep
# Starting experimental run with id: 6
# Taking trace took 24.959965705871582

# %% [markdown]
# ## New heading

# %% [markdown]
# # Two tone spec

# %%
from qcodes.instrument_drivers.rohde_schwarz.SGS100A import RohdeSchwarz_SGS100A
#LO = instools.create_inst(RohdeSchwarz_SGS100A, 'LO', address="TCPIP0::169.254.2.20", force_new_instance=True)
#station = add2station(station, LO)

drive = instools.create_inst(RohdeSchwarz_SGS100A, 'drive', address="TCPIP0::169.254.251.130", force_new_instance=True)
station.add_component(drive)
drive.off()

# %%
for key,value in station.snapshot()['instruments'].items():
    print(key)

# %%
vna.S12.start(4e9)
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-108-516de4be113b> in <module>()
# ----> 1 vna.S12.start(4e9)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     287         else:
#     288             if hasattr(self, 'set'):
# --> 289                 self.set(*args, **kwargs)
#     290             else:
#     291                 raise NotImplementedError('no set cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     481             except Exception as e:
#     482                 e.args = e.args + ('setting {} to {}'.format(self, value),)
# --> 483                 raise e
#     484
#     485         return set_wrapper
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     465                     t0 = time.perf_counter()
#     466
# --> 467                     set_function(raw_value, **kwargs)
#     468                     self.raw_value = raw_value
#     469                     self._save_val(val_step,
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in _set_start(self, val)
#     267         channel = self._instrument_channel
#     268         self.write('SENS{}:FREQ:START {:.7f}'.format(channel, val))
# --> 269         stop = self.stop()
#     270         if val >= stop:
#     271             raise ValueError(
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     404             except Exception as e:
#     405                 e.args = e.args + ('getting {}'.format(self),)
# --> 406                 raise e
#     407
#     408         return get_wrapper
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\bf3\code\qcodes\qcodes\utils\command.py in call_by_str(self, *args)
#     124     def call_by_str(self, *args):
#     125         """Execute a formatted string."""
# --> 126         return self.exec_str(self.cmd_str.format(*args))
#     127
#     128     def call_by_str_parsed_out(self, *args):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\channel.py in ask(self, cmd)
#      66
#      67     def ask(self, cmd):
# ---> 68         return self._parent.ask(cmd)
#      69
#      70     def ask_raw(self, cmd):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     744             inst = repr(self)
#     745             e.args = e.args + ('asking ' + repr(cmd) + ' to ' + inst,)
# --> 746             raise e
#     747
#     748     def ask_raw(self, cmd: str) -> str:
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     737         """
#     738         try:
# --> 739             answer = self.ask_raw(cmd)
#     740
#     741             return answer
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\visa.py in ask_raw(self, cmd)
#     227         """
#     228         self.visa_log.debug(f"Querying: {cmd}")
# --> 229         response = self.visa_handle.query(cmd)
#     230         self.visa_log.debug(f"Response: {response}")
#     231         return response
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in query(self, message, delay)
#     567         if delay > 0.0:
#     568             time.sleep(delay)
# --> 569         return self.read()
#     570
#     571     def ask(self, message, delay=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in read(self, termination, encoding)
#     411         if termination is None:
#     412             termination = self._read_termination
# --> 413             message = self._read_raw().decode(enco)
#     414         else:
#     415             with self.read_termination_context(termination):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in _read_raw(self, size)
#     384                     logger.debug('%s - reading %d bytes (last status %r)',
#     385                                  self._resource_name, size, status)
# --> 386                     chunk, status = self.visalib.read(self.session, size)
#     387                     ret.extend(chunk)
#     388             except errors.VisaIOError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\functions.py in read(library, session, count)
#    1582     buffer = create_string_buffer(count)
#    1583     return_count = ViUInt32()
# -> 1584     ret = library.viRead(session, buffer, count, byref(return_count))
#    1585     return buffer.raw[:return_count.value], ret
#    1586
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     186
#     187         if ret_value < 0:
# --> 188             raise errors.VisaIOError(ret_value)
#     189
#     190         if ret_value in self.issue_warning_on:
#
# VisaIOError: ('VI_ERROR_INP_PROT_VIOL (-1073807305): Device reported an input protocol error during transfer.', "asking 'SENS1:FREQ:STOP?' to <ZNB: VNA>", 'getting VNA_S12_stop', 'setting VNA_S12_start to 4000000000.0')

# %%
drive.ref_osc_source()

# %%
drive.frequency(5e9)
drive.power(-30)
drive.off()

# %%
RF.parameters

# %%
a = [3,2]
print(a)
a.extend([3,2])
print(a)

# %% [markdown]
# ## Testing response

# %%
#note that the frequency set on the VNA doesn't matter since we don't turn RF on. 
npts_vna = 1000
#setup_single_vna_point(frq =1e9 , npts =npts_vna, power = -30,  chan='S12', span=1, n_avg=1, rf_on = False)
power_drive = -60
f0 = 4.84725e9
#f0 = 5.889e9
df = 8e6
N_points_drive = 100
freqs= np.linspace(f0-df,f0+df,N_points_drive)
S_arr = []
#drive.on()
drive.power(power_drive)
for freq in freqs:
    setup_single_vna_point(frq =freq , npts =npts_vna, power = -60,  chan='S12', span=1, n_avg=1, rf_on = True)
    drive.frequency(freq)
    drive.on()
    S_arr.append(measure_complex_point_vna())
    
S_arr = np.array(S_arr, dtype=complex)

# %%
plt.plot(freqs, np.angle(S_arr), 'r--')
plt.ylabel('Angle(rad)')
plt.twinx()
plt.plot(freqs, 20*np.log10(np.abs(S_arr)))
plt.title('drive_testing at P_drive=%d npts_vna=%d' % (power_drive, npts_vna))
plt.xlabel('freq')
plt.ylabel('mag(dB)')
plt.axvline(x=f0,color='g',label='f0')

# %%
#note that the frequency set on the VNA doesn't matter since we don't turn RF on. 
npts_vna = 1000
#setup_single_vna_point(frq =1e9 , npts =npts_vna, power = -30,  chan='S12', span=1, n_avg=1, rf_on = False)
power_drive = -50
f0 = 4.84725e9
#f0 = 5.889e9
df = 8e6
N_points_drive = 100
freqs= np.linspace(f0-df,f0+df,N_points_drive)
S_mags = np.zeros(N_points_drive)
S_phase = np.zeros(N_points_drive)
#drive.on()
drive.power(power_drive)
i=0
for freq in freqs:
    setup_single_vna_point(frq =freq , npts =npts_vna, power = -60,  chan='S12', span=1, n_avg=1, rf_on = True)
    drive.frequency(freq)
    drive.on()
    mag, phase = measure_mag_phase_point_vna()
    S_mags[i] = mag
    S_phase[i] = phase
    i=i+1

# %%
plt.plot(freqs, S_phase, 'r--')
plt.ylabel('Angle(rad)')
plt.twinx()
plt.plot(freqs, 20*np.log10(S_mags))
plt.title('drive_testing at P_drive=%d npts_vna=%d' % (power_drive, npts_vna))
plt.xlabel('freq')
plt.ylabel('mag(dB)')
plt.axvline(x=f0,color='g',label='f0')

# %%
drive.power()

# %%
exp = qc.new_experiment("cross driving test"  , sample_name="abs_w1_5_1_1")

do_single_sweep(n_pts = 20000, f_start = 3.2e9, f_stop = 20e9, power=-25, n_avg=50, channel_name='S12')

# %%
freqs = [3.535e9, 4.020e9, 4.847e9, 5.889e9]
df = 20e6
for f in freqs:
    exp = qc.new_experiment("cross driving test %.5e" % f , sample_name="abs_w1_5_1_1")
    do_single_sweep(n_pts = 5000, f_start =f-df, f_stop=f+df, power=-20, n_avg=50, channel_name='S12')

# %% [markdown]
# ## F drive at diff powers but fixed f0

# %%
mdac.ch01.voltage()

# %%
mdac.ch18.voltage()

# %%
#note that the frequency set on the VNA doesn't matter since we don't turn RF on. 
npts_vna = 10000
power_drive = 0
power_readout = -33
f0 = 4.84725e9 #readout frequency at resonance
f_readout = f0


f_drive_start = 4.849e9
f_drive_stop = 4.853e9
df_drive = 0.03e6

#set the voltages corresponding to the MDAC channels
gate_settings = {
    'V_bot_A' : 2,
    'V_cut_A' : 2.02,
}
print('ramping cutter back')
#ramp(MDAC_channels['V_cut_A'].voltage, 0, gate_ramp_stepsize, gate_ramp_delay )
#time.sleep(10)
exp = qc.new_experiment("Two tone f_meas=%.4e" % f_readout  , sample_name="abs_w1_5_1_1")


#now setup the qcodes measurement object
meas = Measurement()

meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')

#parameters for reference (should be saved in a snapshot as well)
meas.register_custom_parameter('frequency_drive', unit='Hz',
                               paramtype='numeric')
meas.register_custom_parameter('f_readout', unit='Hz', paramtype='numeric')
meas.register_custom_parameter('power_drive', unit='dBm')
meas.register_custom_parameter('power_readout', unit='dBm')
meas.register_custom_parameter('df_drive', unit='Hz')
meas.register_custom_parameter('npts_vna', unit='')

#parameters for the vna                 

vna_trace_setpoints=['frequency_drive']
meas.register_custom_parameter('Re_S', unit='V', 
                                setpoints=vna_trace_setpoints,
                               paramtype='numeric'),
meas.register_custom_parameter('Im_S', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
meas.register_custom_parameter('mag', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
meas.register_custom_parameter('phase', unit='rad', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
meas.register_custom_parameter('magnitude_dB', unit='dB', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
#save all gates that are available
for gate_name, value in MDAC_channels.items():
    meas.register_custom_parameter(gate_name, unit='V')
                               
print("Setting gate voltages")
for gate_name, volt in gate_settings.items():
    print("Setting %s voltage to %3.f" %(gate_name, volt))
    ramp(MDAC_channels[gate_name].voltage, volt, gate_ramp_stepsize, gate_ramp_delay )
print("Done setting gate voltages")
for power_drive in [-10,-20,-30,-40]:
    print(power_drive)
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()


    with meas.run() as datasaver:
        #setup the drive
        freqs= np.arange(f_drive_start, f_drive_stop,df_drive)
        drive.power(power_drive)
        drive.frequency(f_drive_start)
        drive.on()

        #setup the vna for a single point measurement
        setup_single_vna_point(frq =f_readout, npts =npts_vna, power = power_readout, 
                               chan='S12', span=1, n_avg=1, rf_on = True)
        #now start the measurement loop
        for freq in freqs:
            drive.frequency(freq)
            print(freq)
            time.sleep(0.1)
            S = measure_complex_point_vna()
            result = [('frequency_drive', freq),
                      ('Re_S', np.real(S)),
                      ('magnitude_dB',20*np.log10(np.abs(S)) ),
                      ('Im_S', np.imag(S)),
                      ('phase', np.angle(S)),
                      ('mag', np.abs(S)),
                      ('power_drive', power_drive),
                      ('power_readout', power_readout),
                      ('df_drive', df_drive),
                      ('npts_vna', npts_vna),
                      ('f_readout', f_readout),
                      ('temperature', temperature)]
            datasaver.add_result(*result)



    drive.off()

# %%
T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
temperature = T_probe.temperature()

# %% [markdown]
# ## 2D f_measure vs f_drive

# %%
#note that the frequency set on the VNA doesn't matter since we don't turn RF on. 
npts = 200
n_avg = 1000


power_drive = -10
power_readout = -33
f0 = 4.84725e9 #readout frequency at resonance
f_readout = f0
df = 0.0035e9

f_start = f0-df
f_stop = f0+df

f_drive_start = 4.84e9
f_drive_stop = 10e9
df_drive = 0.5e6

set_yoko_field(9e-6)

#set the voltages corresponding to the MDAC channels
gate_settings = {
    'V_bot_A' : 2,
    'V_cut_A' : 2.3,
}
print('ramping cutter back')
#ramp(MDAC_channels['V_cut_A'].voltage, 0, gate_ramp_stepsize, gate_ramp_delay )

exp = qc.new_experiment("Two tone f_meas=%.4e" % f_readout  , sample_name="abs_w1_5_1_1")

# let's set the trace properties. 
vna_channel = getattr(vna.channels, channel_name)

vna_channel.avg(n_avg)
vna_channel.npts(n_pts)
vna_channel.start(f_start)
vna_channel.stop(f_stop)
vna_channel.power(power_readout)
vna_channel.format('Complex')
vna.rf_on()
    
#now setup the qcodes measurement object
meas = Measurement()

meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')

#parameters for reference (should be saved in a snapshot as well)
meas.register_custom_parameter('frequency_drive', unit='Hz',
                               paramtype='numeric')
meas.register_custom_parameter('frequency', unit='Hz', paramtype='array')
meas.register_custom_parameter('f_readout', unit='Hz', paramtype='numeric')
meas.register_custom_parameter('power_drive', unit='dBm')
meas.register_custom_parameter('power_readout', unit='dBm')
meas.register_custom_parameter('df_drive', unit='Hz')
meas.register_custom_parameter('npts_vna', unit='')

#parameters for the vna                 

vna_trace_setpoints=['frequency','frequency_drive']
meas.register_custom_parameter('Re_S', unit='V', 
                                setpoints=vna_trace_setpoints,
                               paramtype='array'),
meas.register_custom_parameter('Im_S', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('mag', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('phase', unit='rad', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
meas.register_custom_parameter('magnitude_dB', unit='dB', 
                               setpoints=vna_trace_setpoints,
                               paramtype='array')
#save all gates that are available
for gate_name, value in MDAC_channels.items():
    meas.register_custom_parameter(gate_name, unit='V')
                               
print("Setting gate voltages")
for gate_name, volt in gate_settings.items():
    print("Setting %s voltage to %3.f" %(gate_name, volt))
    ramp(MDAC_channels[gate_name].voltage, volt, gate_ramp_stepsize, gate_ramp_delay )
print("Done setting gate voltages")

with meas.run() as datasaver:
    #setup the drive
    freqs= np.arange(f_drive_start, f_drive_stop,df_drive)
    drive.power(power_drive)
    drive.frequency(f_drive_start)
    drive.on()
                               
    #now start the measurement loop
    for freq in freqs:
        drive.frequency(freq)
        print(freq)
        fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
        S12 = vna_channel.trace.get()
        mag_db = 20*np.log10(np.abs(S12)) #convert to dB
        result = [ 
            ('frequency', fvals),
            ('Re_S', np.real(S12)),
            ('magnitude_dB',mag_db ),
            ('Im_S', np.imag(S12)),
            ('phase', np.angle(S12)),
            ('mag', np.abs(S12)),
            ('frequency_drive', freq),
                  ('power_drive', power_drive),
                  ('power_readout', power_readout),
                  ('df_drive', df_drive),
                  ('npts_vna', npts_vna),
                  ('f_readout', f_readout),
                  ('temperature', temperature)]
        datasaver.add_result(*result)   
    drive.off()

# %% [markdown]
# ## 2D f_Drive vs gate.

# %%
#note that the frequency set on the VNA doesn't matter since we don't turn RF on. 
npts_vna = 10000
power_drive = -0
power_readout = -33
f0 = 4.84725e9 #readout frequency at resonance
f_readout = f0


f_drive_start = 4.8440e9
f_drive_stop = 4.855e9
df_drive = 0.1e6

#set the voltages corresponding to the MDAC channels
gate_settings = {
    'V_bot_A' : 2,
    #'V_cut_A' : 0.4,
}

#set the cutter gate voltages
vcuts = np.arange(2.0,2.4,0.02)



print('ramping cutter back')
#ramp(MDAC_channels['V_cut_A'].voltage, 0, gate_ramp_stepsize, gate_ramp_delay )
#time.sleep(10)
exp = qc.new_experiment("Two tone f_meas=%.4e Pdrive=%d, Pread=%d" % (f_readout,power_drive,power_readout)  , sample_name="abs_w1_5_1_1")




#first try to get temperature:
T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
temperature = T_probe.temperature()


#now setup the qcodes measurement object
meas = Measurement()

meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')

#parameters for reference (should be saved in a snapshot as well)
meas.register_custom_parameter('frequency_drive', unit='Hz',
                               paramtype='numeric')
meas.register_custom_parameter('v_cut_a', unit='V', paramtype='numeric')
meas.register_custom_parameter('f_readout', unit='Hz', paramtype='numeric')
meas.register_custom_parameter('power_drive', unit='dBm')
meas.register_custom_parameter('power_readout', unit='dBm')
meas.register_custom_parameter('df_drive', unit='Hz')
meas.register_custom_parameter('npts_vna', unit='')
meas.register_custom_parameter('B_y', unit='T')

#parameters for the vna                 

vna_trace_setpoints=['frequency_drive', 'v_cut_a']
meas.register_custom_parameter('Re_S', unit='V', 
                                setpoints=vna_trace_setpoints,
                               paramtype='numeric'),
meas.register_custom_parameter('Im_S', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
meas.register_custom_parameter('mag', unit='V', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
meas.register_custom_parameter('phase', unit='rad', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
meas.register_custom_parameter('magnitude_dB', unit='dB', 
                               setpoints=vna_trace_setpoints,
                               paramtype='numeric')
#save all gates that are available
for gate_name, value in gate_settings.items():
    meas.register_custom_parameter(gate_name, unit='V')
                               
print("Setting gate voltages")
for gate_name, volt in gate_settings.items():
    print("Setting %s voltage to %3.f" %(gate_name, volt))
    ramp(MDAC_channels[gate_name].voltage, volt, gate_ramp_stepsize, gate_ramp_delay )
print("Done setting gate voltages")

with meas.run() as datasaver:
    #setup the drive
    freqs= np.arange(f_drive_start, f_drive_stop,df_drive)
    drive.power(power_drive)
    drive.frequency(f_drive_start)
    drive.on()
                               
    #setup the vna for a single point measurement
    setup_single_vna_point(frq =f_readout, npts =npts_vna, power = power_readout, 
                           chan='S12', span=1, n_avg=1, rf_on = True)
    #now start the measurement loop
    for vcut in vcuts:
        print("Ramping vcut to %.3e" % vcut)
        ramp(MDAC_channels['V_cut_A'].voltage, vcut, gate_ramp_stepsize, gate_ramp_delay )
        B_y = get_yoko_field()
        for freq in freqs:
            drive.frequency(freq)
            time.sleep(0.1) # to protect against overload
            print(freq)
            S = measure_complex_point_vna()
            result = [('frequency_drive', freq),
                      ('v_cut_a', vcut),
                      ('Re_S', np.real(S)),
                      ('magnitude_dB',20*np.log10(np.abs(S)) ),
                      ('Im_S', np.imag(S)),
                      ('phase', np.angle(S)),
                      ('mag', np.abs(S)),
                      ('power_drive', power_drive),
                      ('power_readout', power_readout),
                      ('df_drive', df_drive),
                      ('npts_vna', npts_vna),
                      ('f_readout', f_readout),
                      ('temperature', temperature),
                      ('B_y', B_y)
                     ]
            for gate_name, voltage in gate_settings.items():
                result.append((gate_name, MDAC_channels[gate_name].voltage()))
       
            datasaver.add_result(*result)

                               
            
    drive.off()
    S_arr = np.array(S_arr, dtype=complex)

# %%
vna.rf_off()

# %%
vna.rf_on()

# %%
vna.S12.start(4e9)
