# %%
import os, sys, time, datetime
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib notebook

import qcodes as qc
from qcodes.dataset.data_set import load_by_id
from qcodes.dataset.plotting import plot_by_id
from qcodes.dataset.database import initialise_database, get_DB_location

# %%
sys.path.append(r"D:\OneDrive\BF3\Code");
sys.path.append(r"D:\OneDrive\BF3\Code\labtools-master")

# %%
qc.config["core"]["db_location"] = datetime.date.today().strftime(r'D:\OneDrive\BF3\Data\experiments_%Y-%m-%d.db')
# automatically uses a different DB file for each month
initialise_database()
# creates a new DB file if nonexistant; leaves it untouched if file already exists

# %%
plot_by_id(11)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axes._subplots.AxesSubplot at 0x247815bdf28>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x247815e71d0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x2478160ba90>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24781639208>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24781664a58>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24781697128>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x247816c2978>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x247816f42e8>],
#  [None, None, None, None, None, None, None, None])

# %%
plot_by_id(13)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axes._subplots.AxesSubplot at 0x24782cdba58>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24782ceb160>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24782cec9b0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24782d591d0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24782d76860>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24782da21d0>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24782dc7908>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x24783dcb128>],
#  [None, None, None, None, None, None, None, None])
