# %%
# %matplotlib nbagg
import sys
import matplotlib.pyplot as plt
import qcodes as qc
import numpy as np
#import instrument
import qcodes.instrument_drivers.rohde_schwarz.ZNB as ZNB

from qcodes.dataset.measurements import Measurement
from qcodes.dataset.plotting import plot_by_id, load_by_id
from qcodes import new_experiment, Station, Instrument
from qcodes.dataset.data_export import get_data_by_id
from qcodes import Parameter

# %%
import reload
reload(qcodes)

# %% [markdown]
# # initialize database

# %%
#initialize database
import datetime
dataset_name = 'ABS_W1_5_1_1'
qc.config["core"]["db_location"] = datetime.date.today().strftime(r'D:\OneDrive\BF3\Data\%Y%m%d_'+dataset_name+'.db')
# automatically uses a different DB file for each month
qc.dataset.database.initialise_database()
qc.config.core.db_location

# %%
station = qc.Station()

# %%
exp = qc.new_experiment("Andreev spectroscopy", sample_name="ABS W1 #5(1,1)")

# %% [markdown]
# # Bluefors fridge log tunnel

# %% [markdown]
# ## Bluefors log opening

# %%
#set the path here of the shared desktop file
BF_PC_PATH = '\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\' 

import time

# %%
logfile_name = 'CH5 T'
days_in_the_past = 0
ts = datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day) 
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'

T = np.loadtxt(pth, usecols = (2), delimiter = ',')
plt.figure()
plt.plot(T)
plt.title(ds + ' ' + pth)
plt.xlim(18000, 22000)
logfile_name = 'CH9 T'
ts = datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day) 
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'
T1 = T
T = np.loadtxt(pth, usecols = (2), delimiter = ',')
#plt.figure()
plt.plot(T)
plt.title(pth)
plt.xlim(18000,22000)
plt.ylim((0,2))

plt.figure()
plt.plot(T1-T)
plt.title(pth)
plt.xlim(18000,22000)
plt.ylim((-1,1))

# %%
import csv
BF_PC_PATH = '\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\' 

#code to get the timestamp copied here from the thermometer class

logfile_name = 'maxigauge'
days_in_the_past = 0
ts = datetime.datetime.today() - datetime.timedelta(days=days_in_the_past)
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day) 
pth = BF_PC_PATH + ds + '\\' + logfile_name+ ' ' + ds+'.log'

file_list = []
with open(pth) as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        #print(row)
        file_list.append(row)
csvFile.close()

#
print(file_list[0])
times = [file_list[i][1] for i in range(len(file_list))]
Ps = []
for k in range(0,6):
    Ps.append(np.array([float(file_list[i][5+k*6]) for i in range(len(file_list))]))

i_start = 0
i_stop = -1
for k in range(len(Ps)):
    plt.figure()
    plt.plot(times[i_start:i_stop], Ps[k][i_start:i_stop])
    plt.ylabel('Pressure (mBar)')
    plt.xlabel('Timestamp')
    plt.title('P%d at ' % (k+1) + ds )

# %% [markdown]
# ## Thermometer using BF logs

# %%
#set the path here of the shared desktop file
from pytopo.sweep import sweep, measure, nest, chain, szip, getter, setter, time_trace, do_experiment
from pytopo.qctools.instruments import create_inst

class Thermometer(Instrument):
    
    def __init__(self, name, logfile_path, **kw):
        super().__init__(name, **kw)        
        self.add_parameter('temperature', get_cmd=self._get_temperature, set_cmd=None, unit='K')
        
        self.add_parameter('counter', get_cmd=self._counter, set_cmd=None, unit='')
        self._ind = 0
        print('Path of network drive(set this manually dear USER): ', logfile_path)
        self.logfile_path = logfile_path
        
    def _counter(self):
        self._ind += 1
        return self._ind
    def _get_temperature(self):
        ts = datetime.datetime.today()
        ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
        pth = self.logfile_path + ds + '\\CH9 T '+ds+'.log'
        time.sleep(0.1)
        try:
            T = np.loadtxt(pth, usecols = (2), delimiter = ',')[-1]
        except: # in the first few seconds of a day, a new log file hasn't been created
            ts = datetime.datetime.today() - datetime.timedelta(days=1) # use the last entry in the previous day
            ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
            pth = self.logfile_path + ds + '\\CH9 T '+ds+'.log'
            T = np.loadtxt(pth, usecols = (2), delimiter = ',')[-1]
        return T
    
        
    
T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
T_probe.temperature()

# %%
BF_PC_PATH = '\\\\MININT-ETA6HHA\\Desktop\\BF Log Files\\'
ds = '%02d-%02d-%02d'%(ts.year-2000, ts.month, ts.day)
pth = BF_PC_PATH+ ds + '\\CH9 T '+ds+'.log'

# %% [markdown]
# # VNA measurements of lines.
# https://github.com/QCoDeS/Qcodes/blob/master/docs/examples/driver_examples/Qcodes%20example%20with%20Rohde%20Schwarz%20ZNB.ipynb

# %%
vna = create_inst(ZNB.ZNB, "VNA", 'USB0::0x0AAD::0x01A1::101879::INSTR', force_new_instance=True, init_s_params=False)
#station.remove_component(vna)
station.add_component(vna)
# the channel we want to measure. we set init_s_params false to not have to measure all channels, thus saving time 
channel_name = 'S21' ##Now we add a channel S12: Since the HEMT is connected to port 1. 
vna.add_channel(channel_name)

# %%
 meas = Measurement()

# %%
import time
import numpy as np
def do_single_sweep(n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, power=-60, n_avg=10, channel_name='S12',
                   extra_params = []):
    """
    extra_params expects [(qcodes.Parameter, value)...]
    """

    # let's set the trace properties. 
    trace = getattr(vna.channels, channel_name)
    trace.avg(n_avg)
    trace.npts(n_pts)
    trace.power(power)
    trace.start(f_start)
    trace.stop(f_stop)
    vna.rf_on()
    
    
    #now setup the qcodes measurement object
    meas = Measurement()
    #meas.register_parameter(temperature, setpoints=['time',])
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('time', unit='s', paramtype='numeric')
    meas.register_custom_parameter('power', unit='dBm', setpoints=['time'])
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                    setpoints=['frequency'],
                                   paramtype='array'),
    meas.register_custom_parameter('magnitude_raw', unit='V', 
                                   setpoints=['frequency'],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=[ 'frequency'],
                                   paramtype='array')
    
    #any custom params that someone wants to save as well in the measuremebt
    for param in extra_params:
        meas.register_parameter(param[0])
    
    with meas.run() as datasaver:
        fvals = np.linspace(trace.start(), trace.stop(), trace.npts())
        mag, phase = trace.trace_mag_phase()
        mag_db = 20*np.log10(mag) #convert to dB
        result = [ ('time', time.time()),
           # (temperature, temperature()),
           # (temperature_sample, temperature_sample()),
            ('frequency', fvals),
            ('magnitude_raw', mag),
            ('magnitude_dB',mag_db ),
            ('phase', phase),
            ('power', power)]
        result.extend(extra_params)
        datasaver.add_result(
            *result
           )
    return datasaver.run_id


def do_single_sweep_with_temperature(n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, power=-60, n_avg=10, channel_name='S12'):

    """
    Saves a timestamp and a temperature. 
    """
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    trace = getattr(vna.channels, channel_name)
    trace.avg(n_avg)
    trace.npts(n_pts)
    trace.power(power)
    trace.start(f_start)
    trace.stop(f_stop)
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    #meas.register_parameter(temperature, setpoints=['time',])
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('time', unit='s', paramtype='numeric')
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric', setpoints=['time'])
    meas.register_custom_parameter('power', unit='dBm', setpoints=['time'])
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                    setpoints=['frequency'],
                                   paramtype='array'),
    meas.register_custom_parameter('magnitude_raw', unit='V', 
                                   setpoints=['frequency'],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=[ 'frequency'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        fvals = np.linspace(trace.start(), trace.stop(), trace.npts())
        mag, phase = trace.trace_mag_phase()
        mag_db = 20*np.log10(mag) #convert to dB
        result = [ ('time', time.time()),
           # (temperature, temperature()),
           # (temperature_sample, temperature_sample()),
            ('frequency', fvals),
            ('magnitude_raw', mag),
            ('magnitude_dB',mag_db ),
            ('phase', phase),
            ('power', power),
            ('temperature', temperature)]
        datasaver.add_result(
            *result
           )
    return datasaver.run_id

# %%
power_levels = list(range(5,15,5))
res_freqs = [3.535e9, 4.020e9, 4.847e9, 5.889e9]
df = 0.1e9

for power in power_levels:   
    for freq in res_freqs:
        print(freq-df)
        print(freq+df)
        print(power)
        run_id = do_single_sweep_with_temperature(n_pts = 30000, f_start = freq-df, f_stop = freq+df,
                                                  power=power, n_avg=30, channel_name=channel_name)

# %%
run_id = do_single_sweep_with_temperature(n_pts = 10000, f_start = 3e9, f_stop = 7e9,
                                                  power=-20, n_avg=50, channel_name='S21')

# %%
aves, bla = plot_by_id(run_id)

# %%
dat=load_by_id(run_id)
freqs = np.squeeze(dat.get_data('frequency'))
mag_db = np.squeeze(dat.get_data('magnitude_dB'))

plt.figure()
plt.plot(freqs,mag_db)
plt.grid()

plt.axhline(y = np.max(mag_db), label='Max S21=%.3f dB' % np.max(mag_db), color='g')
plt.legend()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude (dB)')
#plt.xlim(4e9,8e9)

# %%
vna.rf_off()

# %%
meas = Measurement()
vna.channels.S12.format('dB')
meas.register_parameter(vna.channels.S12.trace)
with meas.run() as datasaver:
    get_v = vna.channels.S12.trace.get()
    datasaver.add_result((vna.channels.S12.trace, get_v))
ax, cbax = plot_by_id(datasaver.run_id)

# %% [markdown]
# ## 2 D sweeps: power

# %%
def do_2d_power_sweep(powers=[],n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
. 
    """
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    channel = getattr(vna.channels, channel_name)
    
    channel.avg(n_avg)
    channel.npts(n_pts)
    channel.start(f_start)
    channel.stop(f_stop)
    channel.power(powers[0])
    channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency','power'],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', 'power'],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', 'power'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        for power in powers:
            channel.power(power)
            fvals = np.linspace(channel.start(), channel.stop(), channel.npts())
            S12 = channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('power', power),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id

# %%
np.arange(-30,16, 1)

# %%
res_freqs = [3.535e9, 4.020e9, 4.847e9, 5.889e9]
df = 0.02e9
  
for freq in res_freqs:
    print(freq-df)
    print(freq+df)
    run_id_1 = do_2d_power_sweep(powers=np.arange(-20,15, 5),n_pts = 2000, f_start = freq-df, f_stop = freq+df, n_avg=500, channel_name='S12')
vna.rf_off()

# %%
data = load_by_id(23)
freqs = np.squeeze(np.array(data.get_data('frequency')))
powers = np.squeeze(np.array(data.get_data('power')))
mag = np.squeeze(np.array(data.get_data('magnitude_dB')))
plt.figure()
plt.plot(freqs.T,mag.T, 'x')

# %%
vna.rf_off()

# %%
do_2d_power_sweep(powers=np.arange(-40,0, 5),n_pts = 30000, f_start = 2.9e9, f_stop = 12e9, n_avg=50, channel_name='S12')

# %% [markdown]
# ## Temperature sweep

# %%
def do_2d_T_sweep(T_max = 20, power = -20,n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
. 
    """

    # let's set the trace properties. 
    channel = getattr(vna.channels, channel_name)
    
    channel.avg(n_avg)
    channel.npts(n_pts)
    channel.start(f_start)
    channel.stop(f_stop)
    channel.power(power)
    channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency','temperature'],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', 'temperature'],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', 'temperature'],
                                   paramtype='array')
    
    with meas.run() as datasaver:
      #first try to get temperature:
        T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
        temperature = T_probe.temperature()
        while temperature <  T_max:
            T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
            temperature = T_probe.temperature()
            
            fvals = np.linspace(channel.start(), channel.stop(), channel.npts())
            S12 = channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('power', power),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done T=%.3f' % temperature)
    return datasaver.run_id

# %%
do_2d_T_sweep(power=20,T_max=20, n_pts = 5000, f_start = 2.5e9, f_stop = 10e9, n_avg=5, channel_name='S12')

# %% [markdown]
# # MDac

# %%
sys.path.append(r"D:\OneDrive\BF3\Code");
sys.path.append(r"D:\OneDrive\BF3\Code\labtools-master")
sys.path.append(r"D:\OneDrive\BF3\Code\StationQ\MDAC\Driver")
from MDAC import MDAC
from pytopo.sweep import sweep, measure, nest, chain, szip, getter, setter, time_trace, do_experiment
from pytopo.qctools.instruments import create_inst


mdac = MDAC('MDAC', 'ASRL4::INSTR', debug=False, logging=False)

station.add_component(mdac)

# %%
station.add_component(mdac)

# %% [markdown]
# ## MDAC helper functions

# %%
gate_ramp_stepsize = 1e-3  #[V] previously was 1e-3
gate_ramp_delay = 0.01  #[s]

def initialize(*channels):
    for s in channels:
        ramp(s.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
    #     ramp(g.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        s.smc('close')
        s.dac_output('close')
    #     d.gnd('close')
    #     g.dac_output('close')
    #     g.smc('close')
    
def initialize_leakage(channels_to_close, channels_to_open):
    for s in channels_to_close:
        ramp(s.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        s.smc('close')
        s.dac_output('close')
    for s in channels_to_open:
        ramp(s.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        s.smc('open')
        s.dac_output('open')
        
        


def ramp(param, target, step_size, delay): 
    current_value = param()
    step_size *= np.sign(target - current_value)
    if abs(step_size) < 1E-10: 
        return 
    
    steps = np.arange(current_value, target, step_size)
    for step in steps: 
        param(step)
        time.sleep(delay)
    
    param(target)
    
def set_mdac_in_safemode(nchan=64):
    #ivvi.dac1(0)
    #ivvi.dac3(0)
    #lockin1.amplitude(0)
    #lockin1.sine_outdc(0)
    
    print('setting mdac in safe mode')
    
    for ch in mdac.channels[:nchan]:
        ramp(ch.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

    # Note: we do this in separate loops because we want to be sure that
    # no currents are running anywhere before switching the relays
    for ch in mdac.channels[:nchan]:
        ch.dac_output('open')
        ch.bus('open')
        ch.gnd('open')
        ch.smc('open')
        ch.microd('open')
        #ch.divider('off')
    print('Done')

def chs_safe(*channels):
    lockin1.amplitude(0)
    lockin1.sine_outdc(0)   
    print('setting mdac in safe mode')
    for ch in channels:
        ramp(ch.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
        ch.dac_output('open')
        ch.bus('open')
        ch.gnd('open')
        ch.smc('open')
        ch.microd('open')
    print('Done')
    
    
    
### added function by jaap

def print_voltage_current(channel):
    voltage = channel.voltage()
    gain = 1e6
    key_raw1 = key1.volt()
    current_dc1 = -key_raw1/gain
    print('raw v key 1' ,key_raw1)
    print('current_dc1', current_dc1)
    print('voltage: ', voltage)

# %% [markdown]
# ### MDAC channel definition

# %%
MDAC_channels = {
    'A' : {
        'V_pl_A' : mdac.ch02,
        'V_cut_A' : mdac.ch01,
        'V_pr_A' : mdac.ch03,
        'V_bot_A' : mdac.ch04
    },
    'B' : {
        'V_pl_B' : mdac.ch09,
        'V_cut_B' : mdac.ch10,
        'V_pr_B' : mdac.ch11,
        'V_bot_B' : mdac.ch01
    },
    'C' : {
        'V_pl_C' : mdac.ch25,
        'V_cut_C' : mdac.ch26,
        'V_pr_C' : mdac.ch09,
        'V_bot_C' : mdac.ch27
    },
    'D' : {
        'V_pl_D' : mdac.ch41,
        #'V_cut' : mdac.ch01, cutter doesnt exist in D
        'V_pr_D' : mdac.ch42,
        'V_bot_D' : mdac.ch25
    }
}

# %% [markdown]
# ## MDAC gate testing

# %%
set_mdac_in_safemode()

# %%
mdac.ch01.voltage()

# %%
#initialize all channels:

for res in MDAC_channels:
    for chan in MDAC_channels[res]:
        print("Initializing %s %s %s" % (res,chan, MDAC_channels[res][chan]))
        initialize(MDAC_channels[res][chan])

# %% [markdown]
# ## class def

# %%
class CustomInstrument(Instrument):
    
    def add_params_to_measurement(measurement):
        for 
    
class VNASweep(CustomInstrument):
    
    def __init__(self, name, **kw):
        super().__init__(name, **kw)        
        self.add_parameter('mag', get_cmd=None, set_cmd=None, paramtype='array', unit='V')
        self.add_parameter('phase', get_cmd=None, set_cmd=None, paramtype='array', unit='rad')
        self.add_parameter('magnitude_dB', get_cmd=None, set_cmd=None, paramtype='array', unit='dB')
        self.add_parameter('Re_S',  get_cmd=None, set_cmd=None, paramtype='array', unit='V')
        self.add_parameter('Im_S',  get_cmd=None, set_cmd=None, paramtype='array', unit='V')
        self.add_parameter('frequency', get_cmd=None,set_cmd=None, paramtype='array')

vnasweep = VNASweep('VNA_sweep')

# %% [markdown]
# # Magnet

# %% [markdown]
# Check that the magnet is the "right" one and so the parameters (coil constant and so on...)

# %%
from qcodes.instrument_drivers.american_magnetics.AMI430 import AMI430,AMI430_3D
from pytopo.qctools import instruments as instools

# %%
ami_x = instools.create_inst(AMI430, "AMI430_x", "169.254.178.28", port = 7180, has_current_rating=True)
#ami_y = instools.create_inst(AMI430, "AMI430_y", "169.254.175.39", port = 7180, has_current_rating=True)
ami_z = instools.create_inst(AMI430, "AMI430_z", "169.254.137.107", port = 7180, has_current_rating=True)

ramp_limit_multiplier = 0.6
ami_x.current_ramp_limit(0.1805*ramp_limit_multiplier) #for QT3 magnet 0.1802
ami_x.coil_constant(0.01464)  #for QT3 magnet 0.01466
ami_x.current_rating(68.31)  #for QT3 magnet 68.21

#ami_y.current_ramp_limit(0.1810*ramp_limit_multiplier) #for QT3 magnet 0.1784
#ami_y.coil_constant(0.01477) #for QT3 magnet 0.01464
#ami_y.current_rating(67.7) #for QT3 magnet 68.31

ami_z.current_ramp_limit(0.0760*ramp_limit_multiplier) #for QT3 magnet 0.0775
ami_z.coil_constant(0.0836)  #for QT3 magnet 0.0818
ami_z.current_rating(71.77)  #for QT3 magnet 73.35

#ami = instools.create_inst(AMI430_3D, "AMI430", ami_x, ami_y, ami_z, 2)
#ami_3d = AMI430_3D("AMI_3D", ami_x, ami_y, ami_z, 1);
# Out:
# Instrument AMI430_x already exists.
# Instrument AMI430_z already exists.
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\american_magnetics\AMI430.py:407: AMI430Warning: Increasing maximum ramp rate: we have a default current ramp rate limit of 0.1 A/s. We do not want to ramp faster than a set maximum so as to avoid quenching the magnet. A value of 0.1 A/s seems like a safe, conservative value for any magnet. Change this value at your own responsibility after consulting the specs of your particular magnet
#   warn(warning_message, category=AMI430Warning)

# %%
print(ami_x.ramp_rate(), 'T/ ramp rate unit')
#print(ami_y.ramp_rate())
print(ami_z.ramp_rate())
print(ami_x.ramp_rate_units())
print(ami_z.current_ramp_limit())
#30.1802*ramp_limit_multiplier
print(ami_x.field())
#print(ami_y.field())
print(ami_z.field())
print (ami_3d.field_measured())
print(ami_3d.phi_measured())
# Out:
# 0.000499318 T/ ramp rate unit
# 0.001
# seconds
# 0.045599999999999995
# 6.4e-06
# 0.6000388
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-bb2d62f8e6f3> in <module>()
#       8 #print(ami_y.field())
#       9 print(ami_z.field())
# ---> 10 print (ami_3d.field_measured())
#      11 print(ami_3d.phi_measured())
#
# NameError: name 'ami_3d' is not defined

# %%
ami_y.ramp_rate(0.1e-3)

# %%
#note that 0.01 mT is already fluctuating between 
ami_y.field(0)

# %%
set_yoko_field(0.1e-4)

# %% [markdown]
# ## Yoko current source for y axis

# %%
from qcodes.instrument_drivers.yokogawa.GS200 import GS200
yoko1 = create_inst(GS200,"yoko1", "USB0::0x0B21::0x0039::91T926460::INSTR", force_new_instance=True)
station.add_component(yoko1)
#yoko1.off()

# %%
yoko1.off()

# %%
yoko1.current_limit(200e-3)
yoko1.source_mode("CURR")
yoko1.on()
yoko1.auto_range(True)
yoko1.current()
#yoko1.current(0)

# %%
def set_yoko_field(field_strength, current_rating= 67.7, #QT2 current rating y-axis magnet. 
                  yoko_ramp_step = 1e-7, # in A
                  yoko_ramp_delay = 1e-6): # in s):
    """
    goes as 67.7A/T
    """
    amp = field_strength * current_rating
    if(np.abs(amp) > 200e-3):
        raise Exception("Required current for field beyond yoko limit")
    
    yoko1.ramp_current(amp, yoko_ramp_step, yoko_ramp_delay)
def get_yoko_field(current_rating= 67.7):
    """
    returns the field in Tesla
    """
    return yoko1.current() / current_rating 
print(get_yoko_field())


class YokoMagnet(Instrument):
    """
    Just a class to do 3D magnet stuff but then with the yoko as y-axis instead of ami-y
    """    
    def __init__(self, name, ami_x, ami_z, **kwargs):
        super().__init__(name, **kwargs)
        
        #use the ami x and z params
        self.add_parameter('z', get_cmd=ami_z.field, set_cmd=ami_z.field, unit='T')
        self.add_parameter('x', get_cmd=ami_x.field, set_cmd=ami_x.field, unit='T')
        #but define custom function for y
        self.add_parameter('y', get_cmd=get_yoko_field, set_cmd=set_yoko_field, unit='T')
    
    def transform_spherical_to_cartesian(self, r, theta, phi):
        """
        Does what it sais, uses the same convention as FieldVector QCodes math helper function and thus as the AMI_3D driver
        note radians...
        """
        z = r * np.cos(theta)
        x = r * np.sin(theta) * np.cos(phi)
        y = r * np.sin(theta) * np.sin(phi)
        return x, y, z

# %%
yoko_magnet = create_inst(YokoMagnet, 'yoko_magnet',ami_x = ami_x,ami_z = ami_z, force_new_instance=True)
station.add_component(yoko_magnet)

# %%
yoko_magnet.z(0)
yoko_magnet.x(0)
yoko_magnet.y(0)

# %% [markdown]
# ## 2D gate frequency sweeps

# %%
def do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name='V_g',
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
   
    """
    #check the gate voltage
    print("Starting voltage", gate_channel.voltage())
    
    
    
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    vna_channel = getattr(vna.channels, channel_name)
    
    vna_channel.avg(n_avg)
    vna_channel.npts(n_pts)
    vna_channel.start(f_start)
    vna_channel.stop(f_stop)
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter(gate_name, unit='V'),
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency',gate_name],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['frequency', gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='V', 
                                   setpoints=['frequency', gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', gate_name],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            #ramp the gate voltage
            print("Ramping %s to %.2e" % (gate_name, gate_voltage))
            ramp(gate_channel.voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
            print("Done ramping")
            fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
            S12 = vna_channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('phase', np.angle(S12)),
                ('mag', np.abs(S12)),
                ('power', power),
                (gate_name, gate_voltage),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id




def do_multiple_gate_resonator_sweep(
                            gate_channel, gate_voltages,gate_name='V_g',
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 10000, f_start = 3.2e9, f_stop = 6.5e9, n_avg=10, channel_name='S12'):

    """
   
    """
    if not isinstance(gate_channel, list):
        gate_channel = [gate_channel] #allow for multple gates to be swept at once. 
        if not isinstance(gate_name, list):
            gate_name = [gate_name]
        else:
            raise Exception('Either give both gate channel and gate name as a list or both as a value..')
    
    #check the gate voltage
    for chan in gate_channel:
        print(chan,chan.voltage())
    
    #set the gate name to be all gates together
    long_gate_name = ''
    for name in gate_name:
        long_gate_name += name + '_' #make one variable out of multiple gates snce they are swept together
    
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    vna_channel = getattr(vna.channels, channel_name)
    
    vna_channel.avg(n_avg)
    vna_channel.npts(n_pts)
    vna_channel.start(f_start)
    vna_channel.stop(f_stop)
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency', unit='Hz',
                                   paramtype='array')
    meas.register_custom_parameter(long_gate_name, unit='V'),
    meas.register_custom_parameter('power', unit='dBm'),
    meas.register_custom_parameter('Re_S', unit='V', 
                                    setpoints=['frequency',long_gate_name],
                                   paramtype='array'),
    meas.register_custom_parameter('Im_S', unit='V', 
                                   setpoints=['frequency', long_gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['frequency', long_gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('phase', unit='V', 
                                   setpoints=['frequency', long_gate_name],
                                   paramtype='array')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[ 'frequency', long_gate_name],
                                   paramtype='array')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            #ramp the gate voltage
            for i in range(len(gate_channel)):
                print("Ramping %s to %.2e" % (gate_name[i], gate_voltage))
                ramp(gate_channel[i].voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
                print("Done ramping")
            fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
            S12 = vna_channel.trace.get()
            mag_db = 20*np.log10(np.abs(S12)) #convert to dB
            result = [ 
                ('frequency', fvals),
                ('Re_S', np.real(S12)),
                ('magnitude_dB',mag_db ),
                ('Im_S', np.imag(S12)),
                ('phase', np.angle(S12)),
                ('mag', np.abs(S12)),
                ('power', power),
                (long_gate_name, gate_voltage),
                ('temperature', temperature)]
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id


def do_multiple_gate_multiple_resonator_sweep(
                            gate_channel, gate_voltages,gate_name='V_g',
                            f_starts = [3.2e9], f_stops = [6.5e9], f_names=['A'],
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 10000, n_avg=10, channel_name='S12'):

    """
   
    """
    if not isinstance(gate_channel, list):
        gate_channel = [gate_channel] #allow for multple gates to be swept at once. 
        if not isinstance(gate_name, list):
            gate_name = [gate_name]
        else:
            raise Exception('Either give both gate channel and gate name as a list or both as a value..')
    
    #check the gate voltage
    for chan in gate_channel:
        print(chan,chan.voltage())
    
    #set the gate name to be all gates together
    long_gate_name = ''
    for name in gate_name:
        long_gate_name += name + '_' #make one variable out of multiple gates snce they are swept together
    
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    vna_channel = getattr(vna.channels, channel_name)
    
    vna_channel.avg(n_avg)
    vna_channel.npts(n_pts)
    vna_channel.start(f_starts[0])
    vna_channel.stop(f_stops[0])
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna.rf_on()
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    
    meas.register_custom_parameter(long_gate_name, unit='V'),
    meas.register_custom_parameter('power', unit='dBm'),
    
    for i in range(len(fstarts)):
        meas.register_custom_parameter('frequency_'+f_names[i], unit='Hz',
                                   paramtype='array')
        meas.register_custom_parameter('mag_'+f_names[i], unit='V', 
                                       setpoints=['frequency_'+f_names[i], long_gate_name],
                                       paramtype='array')
        meas.register_custom_parameter('phase_'+f_names[i], unit='V', 
                                       setpoints=['frequency_'+f_names[i], long_gate_name],
                                       paramtype='array')
        meas.register_custom_parameter('magnitude_dB_'+f_names[i], unit='dB', 
                                       setpoints=[ 'frequency_'+f_names[i], long_gate_name],
                                       paramtype='array')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            #ramp the gate voltage
            for i in range(len(gate_channel)):
                print("Ramping %s to %.2e" % (gate_name[i], gate_voltage))
                ramp(gate_channel[i].voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
                print("Done ramping")
            
            result = [ 
                    ('power', power),
                    (long_gate_name, gate_voltage),
                    ('temperature', temperature)]
            
            for i in range(len(fstarts)): 
                vna_channel.start(f_starts[i])
                vna_channel.stop(f_stops[i])
                fvals = np.linspace(vna_channel.start(), vna_channel.stop(), vna_channel.npts())
                S12 = vna_channel.trace.get()
                mag_db = 20*np.log10(np.abs(S12)) #convert to dB
                result.extend([
                    ('frequency_'+f_names[i], fvals),
                    ('magnitude_dB_'+f_names[i],mag_db ),
                    ('phase_'+f_names[i], np.angle(S12)),
                    ('mag_'+f_names[i], np.abs(S12)),
                ])
               
                
            datasaver.add_result(
                *result
               )
            print('done power %d' % power)
    return datasaver.run_id

# %%
list(MDAC_channels['A'].values())

# %% [markdown]
# ### Multiple gates at the same time frequency sweep

# %%
power = -33
n_pts = 200
n_avg = 400
f = f0s[3]
df = 2.5e6
resonator='A'
gate_voltages = np.arange(2.65,2.3,-0.003)
#set the Bfield. 
#set_yoko_field(0.2e-3)

exp = qc.new_experiment("Multi-gate-freq sweep B=%.4e npts=%d n_avg=%d power=%d" %(get_yoko_field(),n_pts, n_avg,power)  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False

#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

t0 = time.time()
#now do the real thing
do_multiple_gate_resonator_sweep(gate_channels, gate_voltages,gate_names,
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=power, n_pts = n_pts, f_start = f-df, f_stop = f+df, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# <MDACChannel: MDAC_chan25 of MDAC: MDAC> 2.668996
# <MDACChannel: MDAC_chan26 of MDAC: MDAC> 2.669003
# <MDACChannel: MDAC_chan9 of MDAC: MDAC> 2.669
# <MDACChannel: MDAC_chan27 of MDAC: MDAC> 2.669004
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 38
# Ramping V_pl_C to 2.65e+00
# Done ramping
# Ramping V_cut_C to 2.65e+00
# Done ramping
# Ramping V_pr_C to 2.65e+00
# Done ramping
# Ramping V_bot_C to 2.65e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.65e+00
# Done ramping
# Ramping V_cut_C to 2.65e+00
# Done ramping
# Ramping V_pr_C to 2.65e+00
# Done ramping
# Ramping V_bot_C to 2.65e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.64e+00
# Done ramping
# Ramping V_cut_C to 2.64e+00
# Done ramping
# Ramping V_pr_C to 2.64e+00
# Done ramping
# Ramping V_bot_C to 2.64e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.64e+00
# Done ramping
# Ramping V_cut_C to 2.64e+00
# Done ramping
# Ramping V_pr_C to 2.64e+00
# Done ramping
# Ramping V_bot_C to 2.64e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.64e+00
# Done ramping
# Ramping V_cut_C to 2.64e+00
# Done ramping
# Ramping V_pr_C to 2.64e+00
# Done ramping
# Ramping V_bot_C to 2.64e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.63e+00
# Done ramping
# Ramping V_cut_C to 2.63e+00
# Done ramping
# Ramping V_pr_C to 2.63e+00
# Done ramping
# Ramping V_bot_C to 2.63e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.63e+00
# Done ramping
# Ramping V_cut_C to 2.63e+00
# Done ramping
# Ramping V_pr_C to 2.63e+00
# Done ramping
# Ramping V_bot_C to 2.63e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.63e+00
# Done ramping
# Ramping V_cut_C to 2.63e+00
# Done ramping
# Ramping V_pr_C to 2.63e+00
# Done ramping
# Ramping V_bot_C to 2.63e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.63e+00
# Done ramping
# Ramping V_cut_C to 2.63e+00
# Done ramping
# Ramping V_pr_C to 2.63e+00
# Done ramping
# Ramping V_bot_C to 2.63e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.62e+00
# Done ramping
# Ramping V_cut_C to 2.62e+00
# Done ramping
# Ramping V_pr_C to 2.62e+00
# Done ramping
# Ramping V_bot_C to 2.62e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.62e+00
# Done ramping
# Ramping V_cut_C to 2.62e+00
# Done ramping
# Ramping V_pr_C to 2.62e+00
# Done ramping
# Ramping V_bot_C to 2.62e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.62e+00
# Done ramping
# Ramping V_cut_C to 2.62e+00
# Done ramping
# Ramping V_pr_C to 2.62e+00
# Done ramping
# Ramping V_bot_C to 2.62e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.61e+00
# Done ramping
# Ramping V_cut_C to 2.61e+00
# Done ramping
# Ramping V_pr_C to 2.61e+00
# Done ramping
# Ramping V_bot_C to 2.61e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.61e+00
# Done ramping
# Ramping V_cut_C to 2.61e+00
# Done ramping
# Ramping V_pr_C to 2.61e+00
# Done ramping
# Ramping V_bot_C to 2.61e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.61e+00
# Done ramping
# Ramping V_cut_C to 2.61e+00
# Done ramping
# Ramping V_pr_C to 2.61e+00
# Done ramping
# Ramping V_bot_C to 2.61e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.60e+00
# Done ramping
# Ramping V_cut_C to 2.60e+00
# Done ramping
# Ramping V_pr_C to 2.60e+00
# Done ramping
# Ramping V_bot_C to 2.60e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.60e+00
# Done ramping
# Ramping V_cut_C to 2.60e+00
# Done ramping
# Ramping V_pr_C to 2.60e+00
# Done ramping
# Ramping V_bot_C to 2.60e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.60e+00
# Done ramping
# Ramping V_cut_C to 2.60e+00
# Done ramping
# Ramping V_pr_C to 2.60e+00
# Done ramping
# Ramping V_bot_C to 2.60e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.60e+00
# Done ramping
# Ramping V_cut_C to 2.60e+00
# Done ramping
# Ramping V_pr_C to 2.60e+00
# Done ramping
# Ramping V_bot_C to 2.60e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.59e+00
# Done ramping
# Ramping V_cut_C to 2.59e+00
# Done ramping
# Ramping V_pr_C to 2.59e+00
# Done ramping
# Ramping V_bot_C to 2.59e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.59e+00
# Done ramping
# Ramping V_cut_C to 2.59e+00
# Done ramping
# Ramping V_pr_C to 2.59e+00
# Done ramping
# Ramping V_bot_C to 2.59e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.59e+00
# Done ramping
# Ramping V_cut_C to 2.59e+00
# Done ramping
# Ramping V_pr_C to 2.59e+00
# Done ramping
# Ramping V_bot_C to 2.59e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.58e+00
# Done ramping
# Ramping V_cut_C to 2.58e+00
# Done ramping
# Ramping V_pr_C to 2.58e+00
# Done ramping
# Ramping V_bot_C to 2.58e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.58e+00
# Done ramping
# Ramping V_cut_C to 2.58e+00
# Done ramping
# Ramping V_pr_C to 2.58e+00
# Done ramping
# Ramping V_bot_C to 2.58e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.58e+00
# Done ramping
# Ramping V_cut_C to 2.58e+00
# Done ramping
# Ramping V_pr_C to 2.58e+00
# Done ramping
# Ramping V_bot_C to 2.58e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.57e+00
# Done ramping
# Ramping V_cut_C to 2.57e+00
# Done ramping
# Ramping V_pr_C to 2.57e+00
# Done ramping
# Ramping V_bot_C to 2.57e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.57e+00
# Done ramping
# Ramping V_cut_C to 2.57e+00
# Done ramping
# Ramping V_pr_C to 2.57e+00
# Done ramping
# Ramping V_bot_C to 2.57e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.57e+00
# Done ramping
# Ramping V_cut_C to 2.57e+00
# Done ramping
# Ramping V_pr_C to 2.57e+00
# Done ramping
# Ramping V_bot_C to 2.57e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.57e+00
# Done ramping
# Ramping V_cut_C to 2.57e+00
# Done ramping
# Ramping V_pr_C to 2.57e+00
# Done ramping
# Ramping V_bot_C to 2.57e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.56e+00
# Done ramping
# Ramping V_cut_C to 2.56e+00
# Done ramping
# Ramping V_pr_C to 2.56e+00
# Done ramping
# Ramping V_bot_C to 2.56e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.56e+00
# Done ramping
# Ramping V_cut_C to 2.56e+00
# Done ramping
# Ramping V_pr_C to 2.56e+00
# Done ramping
# Ramping V_bot_C to 2.56e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.56e+00
# Done ramping
# Ramping V_cut_C to 2.56e+00
# Done ramping
# Ramping V_pr_C to 2.56e+00
# Done ramping
# Ramping V_bot_C to 2.56e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.55e+00
# Done ramping
# Ramping V_cut_C to 2.55e+00
# Done ramping
# Ramping V_pr_C to 2.55e+00
# Done ramping
# Ramping V_bot_C to 2.55e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.55e+00
# Done ramping
# Ramping V_cut_C to 2.55e+00
# Done ramping
# Ramping V_pr_C to 2.55e+00
# Done ramping
# Ramping V_bot_C to 2.55e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.55e+00
# Done ramping
# Ramping V_cut_C to 2.55e+00
# Done ramping
# Ramping V_pr_C to 2.55e+00
# Done ramping
# Ramping V_bot_C to 2.55e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.54e+00
# Done ramping
# Ramping V_cut_C to 2.54e+00
# Done ramping
# Ramping V_pr_C to 2.54e+00
# Done ramping
# Ramping V_bot_C to 2.54e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.54e+00
# Done ramping
# Ramping V_cut_C to 2.54e+00
# Done ramping
# Ramping V_pr_C to 2.54e+00
# Done ramping
# Ramping V_bot_C to 2.54e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.54e+00
# Done ramping
# Ramping V_cut_C to 2.54e+00
# Done ramping
# Ramping V_pr_C to 2.54e+00
# Done ramping
# Ramping V_bot_C to 2.54e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.54e+00
# Done ramping
# Ramping V_cut_C to 2.54e+00
# Done ramping
# Ramping V_pr_C to 2.54e+00
# Done ramping
# Ramping V_bot_C to 2.54e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.53e+00
# Done ramping
# Ramping V_cut_C to 2.53e+00
# Done ramping
# Ramping V_pr_C to 2.53e+00
# Done ramping
# Ramping V_bot_C to 2.53e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.53e+00
# Done ramping
# Ramping V_cut_C to 2.53e+00
# Done ramping
# Ramping V_pr_C to 2.53e+00
# Done ramping
# Ramping V_bot_C to 2.53e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.53e+00
# Done ramping
# Ramping V_cut_C to 2.53e+00
# Done ramping
# Ramping V_pr_C to 2.53e+00
# Done ramping
# Ramping V_bot_C to 2.53e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.52e+00
# Done ramping
# Ramping V_cut_C to 2.52e+00
# Done ramping
# Ramping V_pr_C to 2.52e+00
# Done ramping
# Ramping V_bot_C to 2.52e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.52e+00
# Done ramping
# Ramping V_cut_C to 2.52e+00
# Done ramping
# Ramping V_pr_C to 2.52e+00
# Done ramping
# Ramping V_bot_C to 2.52e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.52e+00
# Done ramping
# Ramping V_cut_C to 2.52e+00
# Done ramping
# Ramping V_pr_C to 2.52e+00
# Done ramping
# Ramping V_bot_C to 2.52e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.51e+00
# Done ramping
# Ramping V_cut_C to 2.51e+00
# Done ramping
# Ramping V_pr_C to 2.51e+00
# Done ramping
# Ramping V_bot_C to 2.51e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.51e+00
# Done ramping
# Ramping V_cut_C to 2.51e+00
# Done ramping
# Ramping V_pr_C to 2.51e+00
# Done ramping
# Ramping V_bot_C to 2.51e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.51e+00
# Done ramping
# Ramping V_cut_C to 2.51e+00
# Done ramping
# Ramping V_pr_C to 2.51e+00
# Done ramping
# Ramping V_bot_C to 2.51e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.51e+00
# Done ramping
# Ramping V_cut_C to 2.51e+00
# Done ramping
# Ramping V_pr_C to 2.51e+00
# Done ramping
# Ramping V_bot_C to 2.51e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.50e+00
# Done ramping
# Ramping V_cut_C to 2.50e+00
# Done ramping
# Ramping V_pr_C to 2.50e+00
# Done ramping
# Ramping V_bot_C to 2.50e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.50e+00
# Done ramping
# Ramping V_cut_C to 2.50e+00
# Done ramping
# Ramping V_pr_C to 2.50e+00
# Done ramping
# Ramping V_bot_C to 2.50e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.50e+00
# Done ramping
# Ramping V_cut_C to 2.50e+00
# Done ramping
# Ramping V_pr_C to 2.50e+00
# Done ramping
# Ramping V_bot_C to 2.50e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.49e+00
# Done ramping
# Ramping V_cut_C to 2.49e+00
# Done ramping
# Ramping V_pr_C to 2.49e+00
# Done ramping
# Ramping V_bot_C to 2.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.49e+00
# Done ramping
# Ramping V_cut_C to 2.49e+00
# Done ramping
# Ramping V_pr_C to 2.49e+00
# Done ramping
# Ramping V_bot_C to 2.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.49e+00
# Done ramping
# Ramping V_cut_C to 2.49e+00
# Done ramping
# Ramping V_pr_C to 2.49e+00
# Done ramping
# Ramping V_bot_C to 2.49e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.48e+00
# Done ramping
# Ramping V_cut_C to 2.48e+00
# Done ramping
# Ramping V_pr_C to 2.48e+00
# Done ramping
# Ramping V_bot_C to 2.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.48e+00
# Done ramping
# Ramping V_cut_C to 2.48e+00
# Done ramping
# Ramping V_pr_C to 2.48e+00
# Done ramping
# Ramping V_bot_C to 2.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.48e+00
# Done ramping
# Ramping V_cut_C to 2.48e+00
# Done ramping
# Ramping V_pr_C to 2.48e+00
# Done ramping
# Ramping V_bot_C to 2.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.48e+00
# Done ramping
# Ramping V_cut_C to 2.48e+00
# Done ramping
# Ramping V_pr_C to 2.48e+00
# Done ramping
# Ramping V_bot_C to 2.48e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.47e+00
# Done ramping
# Ramping V_cut_C to 2.47e+00
# Done ramping
# Ramping V_pr_C to 2.47e+00
# Done ramping
# Ramping V_bot_C to 2.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.47e+00
# Done ramping
# Ramping V_cut_C to 2.47e+00
# Done ramping
# Ramping V_pr_C to 2.47e+00
# Done ramping
# Ramping V_bot_C to 2.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.47e+00
# Done ramping
# Ramping V_cut_C to 2.47e+00
# Done ramping
# Ramping V_pr_C to 2.47e+00
# Done ramping
# Ramping V_bot_C to 2.47e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.46e+00
# Done ramping
# Ramping V_cut_C to 2.46e+00
# Done ramping
# Ramping V_pr_C to 2.46e+00
# Done ramping
# Ramping V_bot_C to 2.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.46e+00
# Done ramping
# Ramping V_cut_C to 2.46e+00
# Done ramping
# Ramping V_pr_C to 2.46e+00
# Done ramping
# Ramping V_bot_C to 2.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.46e+00
# Done ramping
# Ramping V_cut_C to 2.46e+00
# Done ramping
# Ramping V_pr_C to 2.46e+00
# Done ramping
# Ramping V_bot_C to 2.46e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.45e+00
# Done ramping
# Ramping V_cut_C to 2.45e+00
# Done ramping
# Ramping V_pr_C to 2.45e+00
# Done ramping
# Ramping V_bot_C to 2.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.45e+00
# Done ramping
# Ramping V_cut_C to 2.45e+00
# Done ramping
# Ramping V_pr_C to 2.45e+00
# Done ramping
# Ramping V_bot_C to 2.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.45e+00
# Done ramping
# Ramping V_cut_C to 2.45e+00
# Done ramping
# Ramping V_pr_C to 2.45e+00
# Done ramping
# Ramping V_bot_C to 2.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.45e+00
# Done ramping
# Ramping V_cut_C to 2.45e+00
# Done ramping
# Ramping V_pr_C to 2.45e+00
# Done ramping
# Ramping V_bot_C to 2.45e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.44e+00
# Done ramping
# Ramping V_cut_C to 2.44e+00
# Done ramping
# Ramping V_pr_C to 2.44e+00
# Done ramping
# Ramping V_bot_C to 2.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.44e+00
# Done ramping
# Ramping V_cut_C to 2.44e+00
# Done ramping
# Ramping V_pr_C to 2.44e+00
# Done ramping
# Ramping V_bot_C to 2.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.44e+00
# Done ramping
# Ramping V_cut_C to 2.44e+00
# Done ramping
# Ramping V_pr_C to 2.44e+00
# Done ramping
# Ramping V_bot_C to 2.44e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.43e+00
# Done ramping
# Ramping V_cut_C to 2.43e+00
# Done ramping
# Ramping V_pr_C to 2.43e+00
# Done ramping
# Ramping V_bot_C to 2.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.43e+00
# Done ramping
# Ramping V_cut_C to 2.43e+00
# Done ramping
# Ramping V_pr_C to 2.43e+00
# Done ramping
# Ramping V_bot_C to 2.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.43e+00
# Done ramping
# Ramping V_cut_C to 2.43e+00
# Done ramping
# Ramping V_pr_C to 2.43e+00
# Done ramping
# Ramping V_bot_C to 2.43e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.42e+00
# Done ramping
# Ramping V_cut_C to 2.42e+00
# Done ramping
# Ramping V_pr_C to 2.42e+00
# Done ramping
# Ramping V_bot_C to 2.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.42e+00
# Done ramping
# Ramping V_cut_C to 2.42e+00
# Done ramping
# Ramping V_pr_C to 2.42e+00
# Done ramping
# Ramping V_bot_C to 2.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.42e+00
# Done ramping
# Ramping V_cut_C to 2.42e+00
# Done ramping
# Ramping V_pr_C to 2.42e+00
# Done ramping
# Ramping V_bot_C to 2.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.42e+00
# Done ramping
# Ramping V_cut_C to 2.42e+00
# Done ramping
# Ramping V_pr_C to 2.42e+00
# Done ramping
# Ramping V_bot_C to 2.42e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.41e+00
# Done ramping
# Ramping V_cut_C to 2.41e+00
# Done ramping
# Ramping V_pr_C to 2.41e+00
# Done ramping
# Ramping V_bot_C to 2.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.41e+00
# Done ramping
# Ramping V_cut_C to 2.41e+00
# Done ramping
# Ramping V_pr_C to 2.41e+00
# Done ramping
# Ramping V_bot_C to 2.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.41e+00
# Done ramping
# Ramping V_cut_C to 2.41e+00
# Done ramping
# Ramping V_pr_C to 2.41e+00
# Done ramping
# Ramping V_bot_C to 2.41e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.40e+00
# Done ramping
# Ramping V_cut_C to 2.40e+00
# Done ramping
# Ramping V_pr_C to 2.40e+00
# Done ramping
# Ramping V_bot_C to 2.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.40e+00
# Done ramping
# Ramping V_cut_C to 2.40e+00
# Done ramping
# Ramping V_pr_C to 2.40e+00
# Done ramping
# Ramping V_bot_C to 2.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.40e+00
# Done ramping
# Ramping V_cut_C to 2.40e+00
# Done ramping
# Ramping V_pr_C to 2.40e+00
# Done ramping
# Ramping V_bot_C to 2.40e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.39e+00
# Done ramping
# Ramping V_cut_C to 2.39e+00
# Done ramping
# Ramping V_pr_C to 2.39e+00
# Done ramping
# Ramping V_bot_C to 2.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.39e+00
# Done ramping
# Ramping V_cut_C to 2.39e+00
# Done ramping
# Ramping V_pr_C to 2.39e+00
# Done ramping
# Ramping V_bot_C to 2.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.39e+00
# Done ramping
# Ramping V_cut_C to 2.39e+00
# Done ramping
# Ramping V_pr_C to 2.39e+00
# Done ramping
# Ramping V_bot_C to 2.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.39e+00
# Done ramping
# Ramping V_cut_C to 2.39e+00
# Done ramping
# Ramping V_pr_C to 2.39e+00
# Done ramping
# Ramping V_bot_C to 2.39e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.38e+00
# Done ramping
# Ramping V_cut_C to 2.38e+00
# Done ramping
# Ramping V_pr_C to 2.38e+00
# Done ramping
# Ramping V_bot_C to 2.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.38e+00
# Done ramping
# Ramping V_cut_C to 2.38e+00
# Done ramping
# Ramping V_pr_C to 2.38e+00
# Done ramping
# Ramping V_bot_C to 2.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.38e+00
# Done ramping
# Ramping V_cut_C to 2.38e+00
# Done ramping
# Ramping V_pr_C to 2.38e+00
# Done ramping
# Ramping V_bot_C to 2.38e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.37e+00
# Done ramping
# Ramping V_cut_C to 2.37e+00
# Done ramping
# Ramping V_pr_C to 2.37e+00
# Done ramping
# Ramping V_bot_C to 2.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.37e+00
# Done ramping
# Ramping V_cut_C to 2.37e+00
# Done ramping
# Ramping V_pr_C to 2.37e+00
# Done ramping
# Ramping V_bot_C to 2.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.37e+00
# Done ramping
# Ramping V_cut_C to 2.37e+00
# Done ramping
# Ramping V_pr_C to 2.37e+00
# Done ramping
# Ramping V_bot_C to 2.37e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.36e+00
# Done ramping
# Ramping V_cut_C to 2.36e+00
# Done ramping
# Ramping V_pr_C to 2.36e+00
# Done ramping
# Ramping V_bot_C to 2.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.36e+00
# Done ramping
# Ramping V_cut_C to 2.36e+00
# Done ramping
# Ramping V_pr_C to 2.36e+00
# Done ramping
# Ramping V_bot_C to 2.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.36e+00
# Done ramping
# Ramping V_cut_C to 2.36e+00
# Done ramping
# Ramping V_pr_C to 2.36e+00
# Done ramping
# Ramping V_bot_C to 2.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.36e+00
# Done ramping
# Ramping V_cut_C to 2.36e+00
# Done ramping
# Ramping V_pr_C to 2.36e+00
# Done ramping
# Ramping V_bot_C to 2.36e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.35e+00
# Done ramping
# Ramping V_cut_C to 2.35e+00
# Done ramping
# Ramping V_pr_C to 2.35e+00
# Done ramping
# Ramping V_bot_C to 2.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.35e+00
# Done ramping
# Ramping V_cut_C to 2.35e+00
# Done ramping
# Ramping V_pr_C to 2.35e+00
# Done ramping
# Ramping V_bot_C to 2.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.35e+00
# Done ramping
# Ramping V_cut_C to 2.35e+00
# Done ramping
# Ramping V_pr_C to 2.35e+00
# Done ramping
# Ramping V_bot_C to 2.35e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.34e+00
# Done ramping
# Ramping V_cut_C to 2.34e+00
# Done ramping
# Ramping V_pr_C to 2.34e+00
# Done ramping
# Ramping V_bot_C to 2.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.34e+00
# Done ramping
# Ramping V_cut_C to 2.34e+00
# Done ramping
# Ramping V_pr_C to 2.34e+00
# Done ramping
# Ramping V_bot_C to 2.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.34e+00
# Done ramping
# Ramping V_cut_C to 2.34e+00
# Done ramping
# Ramping V_pr_C to 2.34e+00
# Done ramping
# Ramping V_bot_C to 2.34e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.33e+00
# Done ramping
# Ramping V_cut_C to 2.33e+00
# Done ramping
# Ramping V_pr_C to 2.33e+00
# Done ramping
# Ramping V_bot_C to 2.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.33e+00
# Done ramping
# Ramping V_cut_C to 2.33e+00
# Done ramping
# Ramping V_pr_C to 2.33e+00
# Done ramping
# Ramping V_bot_C to 2.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.33e+00
# Done ramping
# Ramping V_cut_C to 2.33e+00
# Done ramping
# Ramping V_pr_C to 2.33e+00
# Done ramping
# Ramping V_bot_C to 2.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.33e+00
# Done ramping
# Ramping V_cut_C to 2.33e+00
# Done ramping
# Ramping V_pr_C to 2.33e+00
# Done ramping
# Ramping V_bot_C to 2.33e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.32e+00
# Done ramping
# Ramping V_cut_C to 2.32e+00
# Done ramping
# Ramping V_pr_C to 2.32e+00
# Done ramping
# Ramping V_bot_C to 2.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.32e+00
# Done ramping
# Ramping V_cut_C to 2.32e+00
# Done ramping
# Ramping V_pr_C to 2.32e+00
# Done ramping
# Ramping V_bot_C to 2.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.32e+00
# Done ramping
# Ramping V_cut_C to 2.32e+00
# Done ramping
# Ramping V_pr_C to 2.32e+00
# Done ramping
# Ramping V_bot_C to 2.32e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.31e+00
# Done ramping
# Ramping V_cut_C to 2.31e+00
# Done ramping
# Ramping V_pr_C to 2.31e+00
# Done ramping
# Ramping V_bot_C to 2.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.31e+00
# Done ramping
# Ramping V_cut_C to 2.31e+00
# Done ramping
# Ramping V_pr_C to 2.31e+00
# Done ramping
# Ramping V_bot_C to 2.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.31e+00
# Done ramping
# Ramping V_cut_C to 2.31e+00
# Done ramping
# Ramping V_pr_C to 2.31e+00
# Done ramping
# Ramping V_bot_C to 2.31e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.30e+00
# Done ramping
# Ramping V_cut_C to 2.30e+00
# Done ramping
# Ramping V_pr_C to 2.30e+00
# Done ramping
# Ramping V_bot_C to 2.30e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
# Ramping V_pl_C to 2.30e+00
# Done ramping
# Ramping V_cut_C to 2.30e+00
# Done ramping
# Ramping V_pr_C to 2.30e+00
# Done ramping
# Ramping V_bot_C to 2.30e+00
# Done ramping
# QCoDeS Dataset does not currently support Complex values. Will discard the imaginary part. In order to acquire phase and amplitude use the FrequencySweepMagPhase parameter.
# done power -23
#  Time elapsed: 936.8814

# %%
vna.S21.bandwidth(1000)

# %% [markdown]
# ## multiple gates multiple res sweep

# %%
power = -30
n_pts = 100
n_avg = 50
df = 5e6
fstarts=np.array(f0s)-df
fstops=np.array(f0s)+df
f_names=['D','C','A','B']
resonator='A' # for gate
gate_voltages = np.arange(-4,4,0.002)
#set the Bfield. 
set_yoko_field(0.2e-3)

exp = qc.new_experiment("Multi-res-gate-freq sweep B=%.4e npts=%d n_avg=%d power=%d" %(get_yoko_field(),n_pts, n_avg,power)  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False

#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

t0 = time.time()
#now do the real thing
do_multiple_gate_multiple_resonator_sweep(gate_channels, gate_voltages,gate_names,
                                 f_starts = fstarts, f_stops = fstops, f_names=f_names,
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))

# %% [markdown]
# ### Single sweep with bot gate

# %%
set_mdac_in_safemode()
# Out:
# setting mdac in safe mode
# Done

# %%
## BOTTOM GATE SWEEP WITH FIXED CUTTERs
power = -33
n_avgs = 400
n_pts = 100
v_cuts = np.arange(3,-3,-0.1)

for v_cut in v_cuts:
    exp = qc.new_experiment("Bot sweep: Vcut=%.3fV power=%d dbM navg=%d n_points=%d" %(v_cut, power, n_avgs, n_pts)  , sample_name="abs_w1_5_1_1")
    gate_channel = mdac.ch18
    gate_voltages = np.arange(-4,4,0.02)
    gate_name = 'V_bot_A'

    df = 0.0045e9

    #ramp back to the -4. 
    #print("ramping back ")
    #ramp(mdac.ch01.voltage, v_cut, gate_ramp_stepsize, gate_ramp_delay)
    #print("")
    #ramp(mdac.ch01.voltage, 1, gate_ramp_stepsize, gate_ramp_delay)
    #print("")
    #resonator A
    for vBot in Vbots:
        ramp(mdac.ch01.voltage, v_cut, gate_ramp_stepsize,gate_ramp_delay)
        f0 = 4.84725e9
        run_id=do_gate_resonator_sweep(gate_channel, gate_voltages,gate_name,
                                gate_ramp_stepsize = 2e-3,  #[V] previously was 1e-3
                                gate_ramp_delay = 0.003 , #[s]
                                power=power, n_pts = n_pts, f_start = f0-df, f_stop = f0+df, n_avg=n_avgs, channel_name='S12')

# %% [markdown]
# ## Sweep of magnet at cutter gate

# %% [markdown]
# # Doing single point sweeps.

# %%
def setup_single_vna_point(frq, npts, power,  chan='S12', span=1, n_avg=10, rf_on = True):
    vna_channel = getattr(vna.channels, chan)
    
    vna_channel.power(power)
    vna_channel.format('Complex')
    vna_channel.center(frq)
    vna_channel.span(span)
    vna_channel.npts(npts)
    vna_channel.avg(n_avg) #todo check which is faster, avg 1 or more points.. #seems like avg is faster
    vna_channel.autoscale()
    if(rf_on):
        vna.rf_on()
    else:
        vna.rf_off()
    
def measure_complex_point_vna(chan='S12'):
    vna_channel = getattr(vna.channels, chan)
    S12 = vna_channel.trace.get()
    
    return np.mean(S12, dtype=complex)

    
def measure_mag_phase_point_vna(chan='S12'):
    vna_channel = getattr(vna.channels, chan)
    mag, phase = vna_channel.trace_mag_phase()
    
    return np.mean(mag), np.mean(phase)

def measure_and_process_point_vna(chan='S12'):
    """
    Measures processes a single point in vna and returns it as qcodes result object
    with param names:
    phase
    mag
    magnitude_dB
    """
    mag, phase = measure_mag_phase_point_vna(chan=channel_name)
    mag_db = 20*np.log10(mag) #convert to dB
    result = [ 
        ('phase', phase),
        ('mag', mag),
        ('magnitude_dB',mag_db )]
    return result


def do_gate_sweep_single_frequency(gate_channel, gate_voltages,gate_name='V_g',
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 100, f = 4.8523e9, n_avg=100, channel_name='S12'):

    """
    performs a gate sweep at a single frequency. Can also sweep multiple parameters settiong the same voltages 
    
    """
    if not isinstance(gate_channel, list):
        gate_channel = [gate_channel] #allow for multple gates to be swept at once. 
        if not isinstance(gate_name, list):
            gate_name = [gate_name]
        else:
            raise Exception('Either give both gate channel and gate name as a list or both as a value..')
    
    #check the gate voltage
    for chan in gate_channel:
        print(chan,chan.voltage())
        
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    print("STARTING TEMPERATURE: %.3f" % temperature)
    
    # let's set the trace properties. 
    setup_single_vna_point( f,n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    long_gate_name = ''
    for name in gate_name:
        long_gate_name += name + '_' #make one variable out of multiple gates snce they are swept together
    
    meas.register_custom_parameter(long_gate_name, unit='V')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=[long_gate_name],
                                   paramtype='numeric')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=[long_gate_name],
                                   paramtype='numeric')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=[long_gate_name],
                                   paramtype='numeric')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            result=[]
            
            #ramp the gate voltage
            for i in range(len(gate_channel)):
                print("Ramping %s to %.2e" % (gate_name[i], gate_voltage))
                ramp(gate_channel[i].voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
                print("Done ramping")
            
            result.append((long_gate_name, gate_voltage))
            
            vna_result= measure_and_process_point_vna(chan=channel_name)
            result.extend(vna_result)
            
            result.extend([
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id



def do_field_sweep_single_frequency(B_ys, power=-30, n_pts = 100, f = 4.8523e9, n_avg=100, channel_name='S12'):

    """
    performs a field sweep at a single frequency. Can also sweep multiple parameters settiong the same voltages 
    
    """
   
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    setup_single_vna_point( f,n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    meas.register_custom_parameter('B_y', unit='T', paramtype='numeric')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['B_y'],
                                   paramtype='numeric')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=['B_y'],
                                   paramtype='numeric')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=['B_y'],
                                   paramtype='numeric')
    
    with meas.run() as datasaver:
        for field in B_ys:      
   
            #ramp the field
            print("Setting field to", field)
            set_yoko_field(field)
            
            result= measure_and_process_point_vna(chan=channel_name)
            
            result.extend([
                ('B_y', field),
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id



def do_3D_field_sweep_single_frequency(B_field_mags, phi, theta, power=-30, n_pts = 100, f = 4.8523e9, n_avg=100, channel_name='S12'):

    """
    performs a field sweep at a single frequency.
    But now it sweeps the magnitude of the field at a certain phi and theta
    
    """
   
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    
    # let's set the trace properties. 
    setup_single_vna_point( f,n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    meas.register_custom_parameter('B_field', unit='T', paramtype='numeric')
    meas.register_custom_parameter('B_x', unit='T', paramtype='numeric')
    meas.register_custom_parameter('B_y', unit='T', paramtype='numeric')
    meas.register_custom_parameter('B_z', unit='T', paramtype='numeric')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    meas.register_custom_parameter('mag', unit='V', 
                                   setpoints=['B_field'],
                                   paramtype='numeric')
    meas.register_custom_parameter('phase', unit='rad', 
                                   setpoints=['B_field'],
                                   paramtype='numeric')
    meas.register_custom_parameter('magnitude_dB', unit='dB', 
                                   setpoints=['B_field'],
                                   paramtype='numeric')
    
    with meas.run() as datasaver:
        for field in B_field_mags:
            
            #ramp the field
            print("Setting field (magntidue) to", field)
            x, y, z = yoko_magnet.transform_spherical_to_cartesian(field, phi=phi, theta=theta)
            print("Setting x, y, z to %.3e, %.3e, %.3e" %(x,y,z))
            yoko_magnet.x(x)
            yoko_magnet.y(y)
            yoko_magnet.z(z)
            
            result= measure_and_process_point_vna(chan=channel_name)
            
            result.extend([
                ('B_field', field),
                ('B_x', x),
                ('B_y', y),
                ('B_z', z),
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id

# %%
def do_gate_sweep_multiple_frequency(gate_channel, gate_voltages,gate_name='V_g',
                                     fs = [4.8523e9], f_names=['A'],
                            gate_ramp_stepsize = 1e-3,  #[V] previously was 1e-3
                            gate_ramp_delay = 0.01 , #[s]
                            power=-30, n_pts = 100, n_avg=100, channel_name='S12'):

    """
    performs a gate sweep at a MULTIPLE frequencies. Can also sweep multiple parameters settiong the same voltages 
    
    """
    vna_channel = getattr(vna.channels, channel_name)
    
    if not isinstance(gate_channel, list):
        gate_channel = [gate_channel] #allow for multple gates to be swept at once. 
        if not isinstance(gate_name, list):
            gate_name = [gate_name]
        else:
            raise Exception('Either give both gate channel and gate name as a list or both as a value..')
    
    #check the gate voltage
    for chan in gate_channel:
        print(chan,chan.voltage())
        
    #first try to get temperature:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    print("STARTING TEMPERATURE: %.3f" % temperature)
    
    # let's set the trace properties. 
    setup_single_vna_point( fs[0],n_pts, power, n_avg=n_avg, chan=channel_name)
    
    #now setup the qcodes measurement object
    meas = Measurement()
    meas.register_custom_parameter('temperature', unit='K', paramtype='numeric')
    #meas.register_parameter(temperature_sample, setpoints=['time',])
    meas.register_custom_parameter('frequency_readout', unit='Hz',
                                   paramtype='numeric')
    long_gate_name = ''
    for name in gate_name:
        long_gate_name += name + '_' #make one variable out of multiple gates snce they are swept together
    
    meas.register_custom_parameter(long_gate_name, unit='V')
    
    meas.register_custom_parameter('power', unit='dBm')
    meas.register_custom_parameter('n_pts', unit='')
    for i in range(len(fs)):
        meas.register_custom_parameter('frequency_'+f_names[i], unit='Hz',
                                   paramtype='numeric')
        meas.register_custom_parameter('mag_'+f_names[i], unit='V', 
                                       setpoints=[long_gate_name],
                                       paramtype='numeric')
        meas.register_custom_parameter('phase_'+f_names[i], unit='V', 
                                       setpoints=[long_gate_name],
                                       paramtype='numeric')
        meas.register_custom_parameter('magnitude_dB_'+f_names[i], unit='dB', 
                                       setpoints=[long_gate_name],
                                       paramtype='numeric')
    
    with meas.run() as datasaver:
        for gate_voltage in gate_voltages:
            
            result=[]
            
            #ramp the gate voltage
            for i in range(len(gate_channel)):
                print("Ramping %s to %.2e" % (gate_name[i], gate_voltage))
                ramp(gate_channel[i].voltage, gate_voltage, gate_ramp_stepsize, gate_ramp_delay )
                print("Done ramping")
            
            result.append((long_gate_name, gate_voltage))
            
            phases= np.array(len(fs))
            mags = np.array(len(fs))
            magnitude_dbs = np.array(len(fs)) 
            for i in range(len(fs)):
                vna_channel.center(fs[i])
                mag, phase = measure_mag_phase_point_vna(chan=channel_name)
                mag_db = 20*np.log10(mag) #convert to dB
                
                result.extend([
                    ('magnitude_dB_'+f_names[i],mag_db ),
                    ('phase_'+f_names[i], phase),
                    ('mag_'+f_names[i], mag),
                ])
            
            result.extend([
                ('temperature', temperature),
                ('power', power),
                ('frequency_readout', f),
                ('n_pts', n_pts)])
        
            datasaver.add_result(*result)
    
    return datasaver.run_id

# %% [markdown]
# ## SEt MDAC voltage

# %%
for resonator in MDAC_channels:
    for gate in MDAC_channels[resonator]:
        print(resonator, gate)
        print(MDAC_channels[resonator][gate].voltage())
        ramp(MDAC_channels[resonator][gate].voltage, 0, step_size=1e-3, delay=0.001)
# Out:
# A V_pl_A
# 0.0
# A V_cut_A
# 0.0
# A V_pr_A
# 0.0
# A V_bot_A
# 0.0
# B V_pl_B
# 0.0
# B V_cut_B
# 0.0
# B V_pr_B
# 0.0
# B V_bot_B
# 0.0
# C V_pl_C
# 0.0
# C V_cut_C
# 0.0
# C V_pr_C
# 0.0
# C V_bot_C
# 0.0
# D V_pl_D
# 0.0
# D V_pr_D
# 0.0
# D V_bot_D
# 0.0

# %%
f_readouts[1]

# %% [markdown]
# ## single gate sweep

# %%
yoko_magnet.z()
# Out:
# -3.58e-05

# %% [markdown]
# ## Field sweep of resonators.

# %%
param = yoko_magnet.z
print(np.append(np.arange(0,2,0.02),np.arange(2,-0.02,-0.02)))
# Out:
# [  0.00000000e+00   2.00000000e-02   4.00000000e-02   6.00000000e-02
#    8.00000000e-02   1.00000000e-01   1.20000000e-01   1.40000000e-01
#    1.60000000e-01   1.80000000e-01   2.00000000e-01   2.20000000e-01
#    2.40000000e-01   2.60000000e-01   2.80000000e-01   3.00000000e-01
#    3.20000000e-01   3.40000000e-01   3.60000000e-01   3.80000000e-01
#    4.00000000e-01   4.20000000e-01   4.40000000e-01   4.60000000e-01
#    4.80000000e-01   5.00000000e-01   5.20000000e-01   5.40000000e-01
#    5.60000000e-01   5.80000000e-01   6.00000000e-01   6.20000000e-01
#    6.40000000e-01   6.60000000e-01   6.80000000e-01   7.00000000e-01
#    7.20000000e-01   7.40000000e-01   7.60000000e-01   7.80000000e-01
#    8.00000000e-01   8.20000000e-01   8.40000000e-01   8.60000000e-01
#    8.80000000e-01   9.00000000e-01   9.20000000e-01   9.40000000e-01
#    9.60000000e-01   9.80000000e-01   1.00000000e+00   1.02000000e+00
#    1.04000000e+00   1.06000000e+00   1.08000000e+00   1.10000000e+00
#    1.12000000e+00   1.14000000e+00   1.16000000e+00   1.18000000e+00
#    1.20000000e+00   1.22000000e+00   1.24000000e+00   1.26000000e+00
#    1.28000000e+00   1.30000000e+00   1.32000000e+00   1.34000000e+00
#    1.36000000e+00   1.38000000e+00   1.40000000e+00   1.42000000e+00
#    1.44000000e+00   1.46000000e+00   1.48000000e+00   1.50000000e+00
#    1.52000000e+00   1.54000000e+00   1.56000000e+00   1.58000000e+00
#    1.60000000e+00   1.62000000e+00   1.64000000e+00   1.66000000e+00
#    1.68000000e+00   1.70000000e+00   1.72000000e+00   1.74000000e+00
#    1.76000000e+00   1.78000000e+00   1.80000000e+00   1.82000000e+00
#    1.84000000e+00   1.86000000e+00   1.88000000e+00   1.90000000e+00
#    1.92000000e+00   1.94000000e+00   1.96000000e+00   1.98000000e+00
#    2.00000000e+00   1.98000000e+00   1.96000000e+00   1.94000000e+00
#    1.92000000e+00   1.90000000e+00   1.88000000e+00   1.86000000e+00
#    1.84000000e+00   1.82000000e+00   1.80000000e+00   1.78000000e+00
#    1.76000000e+00   1.74000000e+00   1.72000000e+00   1.70000000e+00
#    1.68000000e+00   1.66000000e+00   1.64000000e+00   1.62000000e+00
#    1.60000000e+00   1.58000000e+00   1.56000000e+00   1.54000000e+00
#    1.52000000e+00   1.50000000e+00   1.48000000e+00   1.46000000e+00
#    1.44000000e+00   1.42000000e+00   1.40000000e+00   1.38000000e+00
#    1.36000000e+00   1.34000000e+00   1.32000000e+00   1.30000000e+00
#    1.28000000e+00   1.26000000e+00   1.24000000e+00   1.22000000e+00
#    1.20000000e+00   1.18000000e+00   1.16000000e+00   1.14000000e+00
#    1.12000000e+00   1.10000000e+00   1.08000000e+00   1.06000000e+00
#    1.04000000e+00   1.02000000e+00   1.00000000e+00   9.80000000e-01
#    9.60000000e-01   9.40000000e-01   9.20000000e-01   9.00000000e-01
#    8.80000000e-01   8.60000000e-01   8.40000000e-01   8.20000000e-01
#    8.00000000e-01   7.80000000e-01   7.60000000e-01   7.40000000e-01
#    7.20000000e-01   7.00000000e-01   6.80000000e-01   6.60000000e-01
#    6.40000000e-01   6.20000000e-01   6.00000000e-01   5.80000000e-01
#    5.60000000e-01   5.40000000e-01   5.20000000e-01   5.00000000e-01
#    4.80000000e-01   4.60000000e-01   4.40000000e-01   4.20000000e-01
#    4.00000000e-01   3.80000000e-01   3.60000000e-01   3.40000000e-01
#    3.20000000e-01   3.00000000e-01   2.80000000e-01   2.60000000e-01
#    2.40000000e-01   2.20000000e-01   2.00000000e-01   1.80000000e-01
#    1.60000000e-01   1.40000000e-01   1.20000000e-01   1.00000000e-01
#    8.00000000e-02   6.00000000e-02   4.00000000e-02   2.00000000e-02
#   -1.77635684e-15]

# %%
f_readouts=  [3533000000.0, 4018000000.0, 4844500000.0, 5884000000.0]

# %%
power = -27
f0s_sweep = f0s
df = 10e6
n_pts = 1000
n_avg = 1000
B_fields = np.arange(2.25,3.5,0.05)

for field in B_fields:
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    print('T before ramping: ', temperature)
    yoko_magnet.z(field)
    temperature = T_probe.temperature()
    print('T after ramping: ', temperature)
    T_probe = create_inst(Thermometer, 'T_probe', logfile_path=BF_PC_PATH, force_new_instance=True)
    temperature = T_probe.temperature()
    print(' T before start', temperature)
    print(field)
    for i in range(len(f0s)):
        f = f0s_sweep[i]
        print("Taking single sweep")
        t0=time.time()
        exp = qc.new_experiment("freq sweep f0=%.5e df=%.3e power=%d n=%d x %d Bz=%.2e" %(f,df, power, n_pts, n_avg, field)  , sample_name="abs_w1_5_1_1")
        run_id = do_single_sweep(n_pts = n_pts, f_start = f-df, f_stop = f+df, power=power, n_avg=n_avg, channel_name='S21',
                                extra_params = [(yoko_magnet.z, field)])
        print("Taking trace took", time.time()-t0)
        dat = load_by_id(run_id)

        #now update the readout frequency
        freqs = np.squeeze(dat.get_data('frequency'))
        mag = np.squeeze(dat.get_data('magnitude_raw'))
        f0s_sweep[i] = freqs[np.argmin(mag)]
    print(f0s_sweep)
yoko_magnet.z(0)
# Out:
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# T before ramping:  0.0420907
# T after ramping:  0.0420907
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
#  T before start 0.0420907
# 2.25
# Taking single sweep
# Could not set start to 3512736467.08016 setting it to 3512736467.0
# Could not set stop to 3532736467.08016 setting it to 3532736467.0
# Starting experimental run with id: 278
# Taking trace took 120.84049797058105
# Taking single sweep
# Could not set start to 3996173346.995992 setting it to 3996173347.0
# Could not set stop to 4016173346.995992 setting it to 4016173347.0
# Starting experimental run with id: 279
# Taking trace took 120.73923087120056
# Taking single sweep
# Could not set start to 4819245488.35471 setting it to 4819245488.0
# Could not set stop to 4839245488.35471 setting it to 4839245488.0
# Starting experimental run with id: 280
# Taking trace took 120.58030247688293
# Taking single sweep
# Could not set start to 5843515027.865731 setting it to 5843515028.0
# Could not set stop to 5863515027.865731 setting it to 5863515028.0
# Starting experimental run with id: 281
# Taking trace took 121.45770931243896
# [3522506236.7697697, 4005202376.0290289, 4828875117.6296301, 5853545058.0300303]
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# T before ramping:  0.0427914
# T after ramping:  0.0434386
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
#  T before start 0.0434386
# 2.3
# Taking single sweep
# Could not set start to 3512506236.7697697 setting it to 3512506237.0
# Could not set stop to 3532506236.7697697 setting it to 3532506237.0
# Starting experimental run with id: 282
# Taking trace took 120.87670850753784
# Taking single sweep
# Could not set start to 3995202376.029029 setting it to 3995202376.0
# Could not set stop to 4015202376.029029 setting it to 4015202376.0
# Starting experimental run with id: 283
# Taking trace took 120.73823404312134
# Taking single sweep
# Could not set start to 4818875117.62963 setting it to 4818875118.0
# Could not set stop to 4838875117.62963 setting it to 4838875118.0
# Starting experimental run with id: 284
# Taking trace took 120.57775807380676
# Taking single sweep
# Could not set start to 5843545058.03003 setting it to 5843545058.0
# Could not set stop to 5863545058.03003 setting it to 5863545058.0
# Starting experimental run with id: 285
# Taking trace took 121.56872177124023
# [3521755486.2492495, 4005152325.9499497, 4827343586.4684687, 5851412925.8678675]
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# T before ramping:  0.0416496

# %%
freqs = np.squeeze(dat.get_data('frequency'))
mag = np.squeeze(dat.get_data('magnitude_raw'))
freqs[np.argmin(mag)]
# Out:
# 3534039078.1563125

# %%
vna.S21.bandwidth(10000)

# %%
power = -33
n_pts = 100
n_avg = 200
f = f_readouts[2]
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

resonator='A'
gate_voltages = np.arange(-2,2,0.005)
#set the Bfield. 
#set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d B=%.2e" %(f, power, n_pts, n_avg, get_yoko_field())  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False
back_ramp_value = 2.5

#ramp all gates of resonator X
ramp(MDAC_channels[resonator]['V_cut_A'].voltage,0,1e-3,0.01)
ramp(MDAC_channels[resonator]['V_pr_A'].voltage,0,1e-3,0.01)
ramp(MDAC_channels[resonator]['V_pl_A'].voltage,0,1e-3,0.01)
gate_names = ['V_bot_'+resonator]
gate_channels=[MDAC_channels[resonator][gate_names[0]]]



if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, back_ramp_value, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=100, channel_name='S21')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_single_frequency(gate_channels, gate_voltages,gate_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# Taking single sweep
# Starting experimental run with id: 53
# Taking trace took 6.3551435470581055
# <MDACChannel: MDAC_chan4 of MDAC: MDAC> 0.0
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# STARTING TEMPERATURE: 0.023
# Starting experimental run with id: 54
# Ramping V_bot_A to -2.00e+00
# Done ramping
# Ramping V_bot_A to -2.00e+00
# Done ramping
# Ramping V_bot_A to -1.99e+00
# Done ramping
# Ramping V_bot_A to -1.99e+00
# Done ramping
# Ramping V_bot_A to -1.98e+00
# Done ramping
# Ramping V_bot_A to -1.98e+00
# Done ramping
# Ramping V_bot_A to -1.97e+00
# Done ramping
# Ramping V_bot_A to -1.97e+00
# Done ramping
# Ramping V_bot_A to -1.96e+00
# Done ramping
# Ramping V_bot_A to -1.96e+00
# Done ramping
# Ramping V_bot_A to -1.95e+00
# Done ramping
# Ramping V_bot_A to -1.95e+00
# Done ramping
# Ramping V_bot_A to -1.94e+00
# Done ramping
# Ramping V_bot_A to -1.94e+00
# Done ramping
# Ramping V_bot_A to -1.93e+00
# Done ramping
# Ramping V_bot_A to -1.93e+00
# Done ramping
# Ramping V_bot_A to -1.92e+00
# Done ramping
# Ramping V_bot_A to -1.92e+00
# Done ramping
# Ramping V_bot_A to -1.91e+00
# Done ramping
# Ramping V_bot_A to -1.91e+00
# Done ramping
# Ramping V_bot_A to -1.90e+00
# Done ramping
# Ramping V_bot_A to -1.90e+00
# Done ramping
# Ramping V_bot_A to -1.89e+00
# Done ramping
# Ramping V_bot_A to -1.89e+00
# Done ramping
# Ramping V_bot_A to -1.88e+00
# Done ramping
# Ramping V_bot_A to -1.88e+00
# Done ramping
# Ramping V_bot_A to -1.87e+00
# Done ramping
# Ramping V_bot_A to -1.87e+00
# Done ramping
# Ramping V_bot_A to -1.86e+00
# Done ramping
# Ramping V_bot_A to -1.86e+00
# Done ramping
# Ramping V_bot_A to -1.85e+00
# Done ramping
# Ramping V_bot_A to -1.85e+00
# Done ramping
# Ramping V_bot_A to -1.84e+00
# Done ramping
# Ramping V_bot_A to -1.84e+00
# Done ramping
# Ramping V_bot_A to -1.83e+00
# Done ramping
# Ramping V_bot_A to -1.83e+00
# Done ramping
# Ramping V_bot_A to -1.82e+00
# Done ramping
# Ramping V_bot_A to -1.82e+00
# Done ramping
# Ramping V_bot_A to -1.81e+00
# Done ramping
# Ramping V_bot_A to -1.81e+00
# Done ramping
# Ramping V_bot_A to -1.80e+00
# Done ramping
# Ramping V_bot_A to -1.80e+00
# Done ramping
# Ramping V_bot_A to -1.79e+00
# Done ramping
# Ramping V_bot_A to -1.79e+00
# Done ramping
# Ramping V_bot_A to -1.78e+00
# Done ramping
# Ramping V_bot_A to -1.78e+00
# Done ramping
# Ramping V_bot_A to -1.77e+00
# Done ramping
# Ramping V_bot_A to -1.77e+00
# Done ramping
# Ramping V_bot_A to -1.76e+00
# Done ramping
# Ramping V_bot_A to -1.76e+00
# Done ramping
# Ramping V_bot_A to -1.75e+00
# Done ramping
# Ramping V_bot_A to -1.75e+00
# Done ramping
# Ramping V_bot_A to -1.74e+00
# Done ramping
# Ramping V_bot_A to -1.74e+00
# Done ramping
# Ramping V_bot_A to -1.73e+00
# Done ramping
# Ramping V_bot_A to -1.73e+00
# Done ramping
# Ramping V_bot_A to -1.72e+00
# Done ramping
# Ramping V_bot_A to -1.72e+00
# Done ramping
# Ramping V_bot_A to -1.71e+00
# Done ramping
# Ramping V_bot_A to -1.71e+00
# Done ramping
# Ramping V_bot_A to -1.70e+00
# Done ramping
# Ramping V_bot_A to -1.70e+00
# Done ramping
# Ramping V_bot_A to -1.69e+00
# Done ramping
# Ramping V_bot_A to -1.69e+00
# Done ramping
# Ramping V_bot_A to -1.68e+00
# Done ramping
# Ramping V_bot_A to -1.68e+00
# Done ramping
# Ramping V_bot_A to -1.67e+00
# Done ramping
# Ramping V_bot_A to -1.67e+00
# Done ramping
# Ramping V_bot_A to -1.66e+00
# Done ramping
# Ramping V_bot_A to -1.66e+00
# Done ramping
# Ramping V_bot_A to -1.65e+00
# Done ramping
# Ramping V_bot_A to -1.65e+00
# Done ramping
# Ramping V_bot_A to -1.64e+00
# Done ramping
# Ramping V_bot_A to -1.64e+00
# Done ramping
# Ramping V_bot_A to -1.63e+00
# Done ramping
# Ramping V_bot_A to -1.63e+00
# Done ramping
# Ramping V_bot_A to -1.62e+00
# Done ramping
# Ramping V_bot_A to -1.62e+00
# Done ramping
# Ramping V_bot_A to -1.61e+00
# Done ramping
# Ramping V_bot_A to -1.61e+00
# Done ramping
# Ramping V_bot_A to -1.60e+00
# Done ramping
# Ramping V_bot_A to -1.60e+00
# Done ramping
# Ramping V_bot_A to -1.59e+00
# Done ramping
# Ramping V_bot_A to -1.59e+00
# Done ramping
# Ramping V_bot_A to -1.58e+00
# Done ramping
# Ramping V_bot_A to -1.58e+00
# Done ramping
# Ramping V_bot_A to -1.57e+00
# Done ramping
# Ramping V_bot_A to -1.57e+00
# Done ramping
# Ramping V_bot_A to -1.56e+00
# Done ramping
# Ramping V_bot_A to -1.56e+00
# Done ramping
# Ramping V_bot_A to -1.55e+00
# Done ramping
# Ramping V_bot_A to -1.55e+00
# Done ramping
# Ramping V_bot_A to -1.54e+00
# Done ramping
# Ramping V_bot_A to -1.54e+00
# Done ramping
# Ramping V_bot_A to -1.53e+00
# Done ramping
# Ramping V_bot_A to -1.53e+00
# Done ramping
# Ramping V_bot_A to -1.52e+00
# Done ramping
# Ramping V_bot_A to -1.52e+00
# Done ramping
# Ramping V_bot_A to -1.51e+00
# Done ramping
# Ramping V_bot_A to -1.51e+00
# Done ramping
# Ramping V_bot_A to -1.50e+00
# Done ramping
# Ramping V_bot_A to -1.50e+00
# Done ramping
# Ramping V_bot_A to -1.49e+00
# Done ramping
# Ramping V_bot_A to -1.49e+00
# Done ramping
# Ramping V_bot_A to -1.48e+00
# Done ramping
# Ramping V_bot_A to -1.48e+00
# Done ramping
# Ramping V_bot_A to -1.47e+00
# Done ramping
# Ramping V_bot_A to -1.47e+00
# Done ramping
# Ramping V_bot_A to -1.46e+00
# Done ramping
# Ramping V_bot_A to -1.46e+00
# Done ramping
# Ramping V_bot_A to -1.45e+00
# Done ramping
# Ramping V_bot_A to -1.45e+00
# Done ramping
# Ramping V_bot_A to -1.44e+00
# Done ramping
# Ramping V_bot_A to -1.44e+00
# Done ramping
# Ramping V_bot_A to -1.43e+00
# Done ramping
# Ramping V_bot_A to -1.43e+00
# Done ramping
# Ramping V_bot_A to -1.42e+00
# Done ramping
# Ramping V_bot_A to -1.42e+00
# Done ramping
# Ramping V_bot_A to -1.41e+00
# Done ramping
# Ramping V_bot_A to -1.41e+00
# Done ramping
# Ramping V_bot_A to -1.40e+00
# Done ramping
# Ramping V_bot_A to -1.40e+00
# Done ramping
# Ramping V_bot_A to -1.39e+00
# Done ramping
# Ramping V_bot_A to -1.39e+00
# Done ramping
# Ramping V_bot_A to -1.38e+00
# Done ramping
# Ramping V_bot_A to -1.38e+00
# Done ramping
# Ramping V_bot_A to -1.37e+00
# Done ramping
# Ramping V_bot_A to -1.37e+00
# Done ramping
# Ramping V_bot_A to -1.36e+00
# Done ramping
# Ramping V_bot_A to -1.36e+00
# Done ramping
# Ramping V_bot_A to -1.35e+00
# Done ramping
# Ramping V_bot_A to -1.35e+00
# Done ramping
# Ramping V_bot_A to -1.34e+00
# Done ramping
# Ramping V_bot_A to -1.34e+00
# Done ramping
# Ramping V_bot_A to -1.33e+00
# Done ramping
# Ramping V_bot_A to -1.33e+00
# Done ramping
# Ramping V_bot_A to -1.32e+00
# Done ramping
# Ramping V_bot_A to -1.32e+00
# Done ramping
# Ramping V_bot_A to -1.31e+00
# Done ramping
# Ramping V_bot_A to -1.31e+00
# Done ramping
# Ramping V_bot_A to -1.30e+00
# Done ramping
# Ramping V_bot_A to -1.30e+00
# Done ramping
# Ramping V_bot_A to -1.29e+00
# Done ramping
# Ramping V_bot_A to -1.29e+00
# Done ramping
# Ramping V_bot_A to -1.28e+00
# Done ramping
# Ramping V_bot_A to -1.28e+00
# Done ramping
# Ramping V_bot_A to -1.27e+00
# Done ramping
# Ramping V_bot_A to -1.27e+00
# Done ramping
# Ramping V_bot_A to -1.26e+00
# Done ramping
# Ramping V_bot_A to -1.26e+00
# Done ramping
# Ramping V_bot_A to -1.25e+00
# Done ramping
# Ramping V_bot_A to -1.25e+00
# Done ramping
# Ramping V_bot_A to -1.24e+00
# Done ramping
# Ramping V_bot_A to -1.24e+00
# Done ramping
# Ramping V_bot_A to -1.23e+00
# Done ramping
# Ramping V_bot_A to -1.23e+00
# Done ramping
# Ramping V_bot_A to -1.22e+00
# Done ramping
# Ramping V_bot_A to -1.22e+00
# Done ramping
# Ramping V_bot_A to -1.21e+00
# Done ramping
# Ramping V_bot_A to -1.21e+00
# Done ramping
# Ramping V_bot_A to -1.20e+00
# Done ramping
# Ramping V_bot_A to -1.20e+00
# Done ramping
# Ramping V_bot_A to -1.19e+00
# Done ramping
# Ramping V_bot_A to -1.19e+00
# Done ramping
# Ramping V_bot_A to -1.18e+00
# Done ramping
# Ramping V_bot_A to -1.18e+00
# Done ramping
# Ramping V_bot_A to -1.17e+00
# Done ramping
# Ramping V_bot_A to -1.17e+00
# Done ramping
# Ramping V_bot_A to -1.16e+00
# Done ramping
# Ramping V_bot_A to -1.16e+00
# Done ramping
# Ramping V_bot_A to -1.15e+00
# Done ramping
# Ramping V_bot_A to -1.15e+00
# Done ramping
# Ramping V_bot_A to -1.14e+00
# Done ramping
# Ramping V_bot_A to -1.14e+00
# Done ramping
# Ramping V_bot_A to -1.13e+00
# Done ramping
# Ramping V_bot_A to -1.13e+00
# Done ramping
# Ramping V_bot_A to -1.12e+00
# Done ramping
# Ramping V_bot_A to -1.12e+00
# Done ramping
# Ramping V_bot_A to -1.11e+00
# Done ramping
# Ramping V_bot_A to -1.11e+00
# Done ramping
# Ramping V_bot_A to -1.10e+00
# Done ramping
# Ramping V_bot_A to -1.10e+00
# Done ramping
# Ramping V_bot_A to -1.09e+00
# Done ramping
# Ramping V_bot_A to -1.09e+00
# Done ramping
# Ramping V_bot_A to -1.08e+00
# Done ramping
# Ramping V_bot_A to -1.08e+00
# Done ramping
# Ramping V_bot_A to -1.07e+00
# Done ramping
# Ramping V_bot_A to -1.07e+00
# Done ramping
# Ramping V_bot_A to -1.06e+00
# Done ramping
# Ramping V_bot_A to -1.06e+00
# Done ramping
# Ramping V_bot_A to -1.05e+00
# Done ramping
# Ramping V_bot_A to -1.05e+00
# Done ramping
# Ramping V_bot_A to -1.04e+00
# Done ramping
# Ramping V_bot_A to -1.04e+00
# Done ramping
# Ramping V_bot_A to -1.03e+00
# Done ramping
# Ramping V_bot_A to -1.03e+00
# Done ramping
# Ramping V_bot_A to -1.02e+00
# Done ramping
# Ramping V_bot_A to -1.02e+00
# Done ramping
# Ramping V_bot_A to -1.01e+00
# Done ramping
# Ramping V_bot_A to -1.01e+00
# Done ramping
# Ramping V_bot_A to -1.00e+00
# Done ramping
# Ramping V_bot_A to -9.95e-01
# Done ramping
# Ramping V_bot_A to -9.90e-01
# Done ramping
# Ramping V_bot_A to -9.85e-01
# Done ramping
# Ramping V_bot_A to -9.80e-01
# Done ramping
# Ramping V_bot_A to -9.75e-01
# Done ramping
# Ramping V_bot_A to -9.70e-01
# Done ramping
# Ramping V_bot_A to -9.65e-01
# Done ramping
# Ramping V_bot_A to -9.60e-01
# Done ramping
# Ramping V_bot_A to -9.55e-01
# Done ramping
# Ramping V_bot_A to -9.50e-01
# Done ramping
# Ramping V_bot_A to -9.45e-01
# Done ramping
# Ramping V_bot_A to -9.40e-01
# Done ramping
# Ramping V_bot_A to -9.35e-01
# Done ramping
# Ramping V_bot_A to -9.30e-01
# Done ramping
# Ramping V_bot_A to -9.25e-01
# Done ramping
# Ramping V_bot_A to -9.20e-01
# Done ramping
# Ramping V_bot_A to -9.15e-01
# Done ramping
# Ramping V_bot_A to -9.10e-01
# Done ramping
# Ramping V_bot_A to -9.05e-01
# Done ramping
# Ramping V_bot_A to -9.00e-01
# Done ramping
# Ramping V_bot_A to -8.95e-01
# Done ramping
# Ramping V_bot_A to -8.90e-01
# Done ramping
# Ramping V_bot_A to -8.85e-01
# Done ramping
# Ramping V_bot_A to -8.80e-01
# Done ramping
# Ramping V_bot_A to -8.75e-01
# Done ramping
# Ramping V_bot_A to -8.70e-01
# Done ramping
# Ramping V_bot_A to -8.65e-01
# Done ramping
# Ramping V_bot_A to -8.60e-01
# Done ramping
# Ramping V_bot_A to -8.55e-01
# Done ramping
# Ramping V_bot_A to -8.50e-01
# Done ramping
# Ramping V_bot_A to -8.45e-01
# Done ramping
# Ramping V_bot_A to -8.40e-01
# Done ramping
# Ramping V_bot_A to -8.35e-01
# Done ramping
# Ramping V_bot_A to -8.30e-01
# Done ramping
# Ramping V_bot_A to -8.25e-01
# Done ramping
# Ramping V_bot_A to -8.20e-01
# Done ramping
# Ramping V_bot_A to -8.15e-01
# Done ramping
# Ramping V_bot_A to -8.10e-01
# Done ramping
# Ramping V_bot_A to -8.05e-01
# Done ramping
# Ramping V_bot_A to -8.00e-01
# Done ramping
# Ramping V_bot_A to -7.95e-01
# Done ramping
# Ramping V_bot_A to -7.90e-01
# Done ramping
# Ramping V_bot_A to -7.85e-01
# Done ramping
# Ramping V_bot_A to -7.80e-01
# Done ramping
# Ramping V_bot_A to -7.75e-01
# Done ramping
# Ramping V_bot_A to -7.70e-01
# Done ramping
# Ramping V_bot_A to -7.65e-01
# Done ramping
# Ramping V_bot_A to -7.60e-01
# Done ramping
# Ramping V_bot_A to -7.55e-01
# Done ramping
# Ramping V_bot_A to -7.50e-01
# Done ramping
# Ramping V_bot_A to -7.45e-01
# Done ramping
# Ramping V_bot_A to -7.40e-01
# Done ramping
# Ramping V_bot_A to -7.35e-01
# Done ramping
# Ramping V_bot_A to -7.30e-01
# Done ramping
# Ramping V_bot_A to -7.25e-01
# Done ramping
# Ramping V_bot_A to -7.20e-01
# Done ramping
# Ramping V_bot_A to -7.15e-01
# Done ramping
# Ramping V_bot_A to -7.10e-01
# Done ramping
# Ramping V_bot_A to -7.05e-01
# Done ramping
# Ramping V_bot_A to -7.00e-01
# Done ramping
# Ramping V_bot_A to -6.95e-01
# Done ramping
# Ramping V_bot_A to -6.90e-01
# Done ramping
# Ramping V_bot_A to -6.85e-01
# Done ramping
# Ramping V_bot_A to -6.80e-01
# Done ramping
# Ramping V_bot_A to -6.75e-01
# Done ramping
# Ramping V_bot_A to -6.70e-01
# Done ramping
# Ramping V_bot_A to -6.65e-01
# Done ramping
# Ramping V_bot_A to -6.60e-01
# Done ramping
# Ramping V_bot_A to -6.55e-01
# Done ramping
# Ramping V_bot_A to -6.50e-01
# Done ramping
# Ramping V_bot_A to -6.45e-01
# Done ramping
# Ramping V_bot_A to -6.40e-01
# Done ramping
# Ramping V_bot_A to -6.35e-01
# Done ramping
# Ramping V_bot_A to -6.30e-01
# Done ramping
# Ramping V_bot_A to -6.25e-01
# Done ramping
# Ramping V_bot_A to -6.20e-01
# Done ramping
# Ramping V_bot_A to -6.15e-01
# Done ramping
# Ramping V_bot_A to -6.10e-01
# Done ramping
# Ramping V_bot_A to -6.05e-01
# Done ramping
# Ramping V_bot_A to -6.00e-01
# Done ramping
# Ramping V_bot_A to -5.95e-01
# Done ramping
# Ramping V_bot_A to -5.90e-01
# Done ramping
# Ramping V_bot_A to -5.85e-01
# Done ramping
# Ramping V_bot_A to -5.80e-01
# Done ramping
# Ramping V_bot_A to -5.75e-01
# Done ramping
# Ramping V_bot_A to -5.70e-01
# Done ramping
# Ramping V_bot_A to -5.65e-01
# Done ramping
# Ramping V_bot_A to -5.60e-01
# Done ramping
# Ramping V_bot_A to -5.55e-01
# Done ramping
# Ramping V_bot_A to -5.50e-01
# Done ramping
# Ramping V_bot_A to -5.45e-01
# Done ramping
# Ramping V_bot_A to -5.40e-01
# Done ramping
# Ramping V_bot_A to -5.35e-01
# Done ramping
# Ramping V_bot_A to -5.30e-01
# Done ramping
# Ramping V_bot_A to -5.25e-01
# Done ramping
# Ramping V_bot_A to -5.20e-01
# Done ramping
# Ramping V_bot_A to -5.15e-01
# Done ramping
# Ramping V_bot_A to -5.10e-01
# Done ramping
# Ramping V_bot_A to -5.05e-01
# Done ramping
# Ramping V_bot_A to -5.00e-01
# Done ramping
# Ramping V_bot_A to -4.95e-01
# Done ramping
# Ramping V_bot_A to -4.90e-01
# Done ramping
# Ramping V_bot_A to -4.85e-01
# Done ramping
# Ramping V_bot_A to -4.80e-01
# Done ramping
# Ramping V_bot_A to -4.75e-01
# Done ramping
# Ramping V_bot_A to -4.70e-01
# Done ramping
# Ramping V_bot_A to -4.65e-01
# Done ramping
# Ramping V_bot_A to -4.60e-01
# Done ramping
# Ramping V_bot_A to -4.55e-01
# Done ramping
# Ramping V_bot_A to -4.50e-01
# Done ramping
# Ramping V_bot_A to -4.45e-01
# Done ramping
# Ramping V_bot_A to -4.40e-01
# Done ramping
# Ramping V_bot_A to -4.35e-01
# Done ramping
# Ramping V_bot_A to -4.30e-01
# Done ramping
# Ramping V_bot_A to -4.25e-01
# Done ramping
# Ramping V_bot_A to -4.20e-01
# Done ramping
# Ramping V_bot_A to -4.15e-01
# Done ramping
# Ramping V_bot_A to -4.10e-01
# Done ramping
# Ramping V_bot_A to -4.05e-01
# Done ramping
# Ramping V_bot_A to -4.00e-01
# Done ramping
# Ramping V_bot_A to -3.95e-01
# Done ramping
# Ramping V_bot_A to -3.90e-01
# Done ramping
# Ramping V_bot_A to -3.85e-01
# Done ramping
# Ramping V_bot_A to -3.80e-01
# Done ramping
# Ramping V_bot_A to -3.75e-01
# Done ramping
# Ramping V_bot_A to -3.70e-01
# Done ramping
# Ramping V_bot_A to -3.65e-01
# Done ramping
# Ramping V_bot_A to -3.60e-01
# Done ramping
# Ramping V_bot_A to -3.55e-01
# Done ramping
# Ramping V_bot_A to -3.50e-01
# Done ramping
# Ramping V_bot_A to -3.45e-01
# Done ramping
# Ramping V_bot_A to -3.40e-01
# Done ramping
# Ramping V_bot_A to -3.35e-01
# Done ramping
# Ramping V_bot_A to -3.30e-01
# Done ramping
# Ramping V_bot_A to -3.25e-01
# Done ramping
# Ramping V_bot_A to -3.20e-01
# Done ramping
# Ramping V_bot_A to -3.15e-01
# Done ramping
# Ramping V_bot_A to -3.10e-01
# Done ramping
# Ramping V_bot_A to -3.05e-01
# Done ramping
# Ramping V_bot_A to -3.00e-01
# Done ramping
# Ramping V_bot_A to -2.95e-01
# Done ramping
# Ramping V_bot_A to -2.90e-01
# Done ramping
# Ramping V_bot_A to -2.85e-01
# Done ramping
# Ramping V_bot_A to -2.80e-01
# Done ramping
# Ramping V_bot_A to -2.75e-01
# Done ramping
# Ramping V_bot_A to -2.70e-01
# Done ramping
# Ramping V_bot_A to -2.65e-01
# Done ramping
# Ramping V_bot_A to -2.60e-01
# Done ramping
# Ramping V_bot_A to -2.55e-01
# Done ramping
# Ramping V_bot_A to -2.50e-01
# Done ramping
# Ramping V_bot_A to -2.45e-01
# Done ramping
# Ramping V_bot_A to -2.40e-01
# Done ramping
# Ramping V_bot_A to -2.35e-01
# Done ramping
# Ramping V_bot_A to -2.30e-01
# Done ramping
# Ramping V_bot_A to -2.25e-01
# Done ramping
# Ramping V_bot_A to -2.20e-01
# Done ramping
# Ramping V_bot_A to -2.15e-01
# Done ramping
# Ramping V_bot_A to -2.10e-01
# Done ramping
# Ramping V_bot_A to -2.05e-01
# Done ramping
# Ramping V_bot_A to -2.00e-01
# Done ramping
# Ramping V_bot_A to -1.95e-01
# Done ramping
# Ramping V_bot_A to -1.90e-01
# Done ramping
# Ramping V_bot_A to -1.85e-01
# Done ramping
# Ramping V_bot_A to -1.80e-01
# Done ramping
# Ramping V_bot_A to -1.75e-01
# Done ramping
# Ramping V_bot_A to -1.70e-01
# Done ramping
# Ramping V_bot_A to -1.65e-01
# Done ramping
# Ramping V_bot_A to -1.60e-01
# Done ramping
# Ramping V_bot_A to -1.55e-01
# Done ramping
# Ramping V_bot_A to -1.50e-01
# Done ramping
# Ramping V_bot_A to -1.45e-01
# Done ramping
# Ramping V_bot_A to -1.40e-01
# Done ramping
# Ramping V_bot_A to -1.35e-01
# Done ramping
# Ramping V_bot_A to -1.30e-01
# Done ramping
# Ramping V_bot_A to -1.25e-01
# Done ramping
# Ramping V_bot_A to -1.20e-01
# Done ramping
# Ramping V_bot_A to -1.15e-01
# Done ramping
# Ramping V_bot_A to -1.10e-01
# Done ramping
# Ramping V_bot_A to -1.05e-01
# Done ramping
# Ramping V_bot_A to -1.00e-01
# Done ramping
# Ramping V_bot_A to -9.50e-02
# Done ramping
# Ramping V_bot_A to -9.00e-02
# Done ramping
# Ramping V_bot_A to -8.50e-02
# Done ramping
# Ramping V_bot_A to -8.00e-02
# Done ramping
# Ramping V_bot_A to -7.50e-02
# Done ramping
# Ramping V_bot_A to -7.00e-02
# Done ramping
# Ramping V_bot_A to -6.50e-02
# Done ramping
# Ramping V_bot_A to -6.00e-02
# Done ramping
# Ramping V_bot_A to -5.50e-02
# Done ramping
# Ramping V_bot_A to -5.00e-02
# Done ramping
# Ramping V_bot_A to -4.50e-02
# Done ramping
# Ramping V_bot_A to -4.00e-02
# Done ramping
# Ramping V_bot_A to -3.50e-02
# Done ramping
# Ramping V_bot_A to -3.00e-02
# Done ramping
# Ramping V_bot_A to -2.50e-02
# Done ramping
# Ramping V_bot_A to -2.00e-02
# Done ramping
# Ramping V_bot_A to -1.50e-02
# Done ramping
# Ramping V_bot_A to -1.00e-02
# Done ramping
# Ramping V_bot_A to -5.00e-03
# Done ramping
# Ramping V_bot_A to -4.26e-14
# Done ramping
# Ramping V_bot_A to 5.00e-03
# Done ramping
# Ramping V_bot_A to 1.00e-02
# Done ramping
# Ramping V_bot_A to 1.50e-02
# Done ramping
# Ramping V_bot_A to 2.00e-02
# Done ramping
# Ramping V_bot_A to 2.50e-02
# Done ramping
# Ramping V_bot_A to 3.00e-02
# Done ramping
# Ramping V_bot_A to 3.50e-02
# Done ramping
# Ramping V_bot_A to 4.00e-02
# Done ramping
# Ramping V_bot_A to 4.50e-02
# Done ramping
# Ramping V_bot_A to 5.00e-02
# Done ramping
# Ramping V_bot_A to 5.50e-02
# Done ramping
# Ramping V_bot_A to 6.00e-02
# Done ramping
# Ramping V_bot_A to 6.50e-02
# Done ramping
# Ramping V_bot_A to 7.00e-02
# Done ramping
# Ramping V_bot_A to 7.50e-02
# Done ramping
# Ramping V_bot_A to 8.00e-02
# Done ramping
# Ramping V_bot_A to 8.50e-02
# Done ramping
# Ramping V_bot_A to 9.00e-02
# Done ramping
# Ramping V_bot_A to 9.50e-02
# Done ramping
# Ramping V_bot_A to 1.00e-01
# Done ramping
# Ramping V_bot_A to 1.05e-01
# Done ramping
# Ramping V_bot_A to 1.10e-01
# Done ramping
# Ramping V_bot_A to 1.15e-01
# Done ramping
# Ramping V_bot_A to 1.20e-01
# Done ramping
# Ramping V_bot_A to 1.25e-01
# Done ramping
# Ramping V_bot_A to 1.30e-01
# Done ramping
# Ramping V_bot_A to 1.35e-01
# Done ramping
# Ramping V_bot_A to 1.40e-01
# Done ramping
# Ramping V_bot_A to 1.45e-01
# Done ramping
# Ramping V_bot_A to 1.50e-01
# Done ramping
# Ramping V_bot_A to 1.55e-01
# Done ramping
# Ramping V_bot_A to 1.60e-01
# Done ramping
# Ramping V_bot_A to 1.65e-01
# Done ramping
# Ramping V_bot_A to 1.70e-01
# Done ramping
# Ramping V_bot_A to 1.75e-01
# Done ramping
# Ramping V_bot_A to 1.80e-01
# Done ramping
# Ramping V_bot_A to 1.85e-01
# Done ramping
# Ramping V_bot_A to 1.90e-01
# Done ramping
# Ramping V_bot_A to 1.95e-01
# Done ramping
# Ramping V_bot_A to 2.00e-01
# Done ramping
# Ramping V_bot_A to 2.05e-01
# Done ramping
# Ramping V_bot_A to 2.10e-01
# Done ramping
# Ramping V_bot_A to 2.15e-01
# Done ramping
# Ramping V_bot_A to 2.20e-01
# Done ramping
# Ramping V_bot_A to 2.25e-01
# Done ramping
# Ramping V_bot_A to 2.30e-01
# Done ramping
# Ramping V_bot_A to 2.35e-01
# Done ramping
# Ramping V_bot_A to 2.40e-01
# Done ramping
# Ramping V_bot_A to 2.45e-01
# Done ramping
# Ramping V_bot_A to 2.50e-01
# Done ramping
# Ramping V_bot_A to 2.55e-01
# Done ramping
# Ramping V_bot_A to 2.60e-01
# Done ramping
# Ramping V_bot_A to 2.65e-01
# Done ramping
# Ramping V_bot_A to 2.70e-01
# Done ramping
# Ramping V_bot_A to 2.75e-01
# Done ramping
# Ramping V_bot_A to 2.80e-01
# Done ramping
# Ramping V_bot_A to 2.85e-01
# Done ramping
# Ramping V_bot_A to 2.90e-01
# Done ramping
# Ramping V_bot_A to 2.95e-01
# Done ramping
# Ramping V_bot_A to 3.00e-01
# Done ramping
# Ramping V_bot_A to 3.05e-01
# Done ramping
# Ramping V_bot_A to 3.10e-01
# Done ramping
# Ramping V_bot_A to 3.15e-01
# Done ramping
# Ramping V_bot_A to 3.20e-01
# Done ramping
# Ramping V_bot_A to 3.25e-01
# Done ramping
# Ramping V_bot_A to 3.30e-01
# Done ramping
# Ramping V_bot_A to 3.35e-01
# Done ramping
# Ramping V_bot_A to 3.40e-01
# Done ramping
# Ramping V_bot_A to 3.45e-01
# Done ramping
# Ramping V_bot_A to 3.50e-01
# Done ramping
# Ramping V_bot_A to 3.55e-01
# Done ramping
# Ramping V_bot_A to 3.60e-01
# Done ramping
# Ramping V_bot_A to 3.65e-01
# Done ramping
# Ramping V_bot_A to 3.70e-01
# Done ramping
# Ramping V_bot_A to 3.75e-01
# Done ramping
# Ramping V_bot_A to 3.80e-01
# Done ramping
# Ramping V_bot_A to 3.85e-01
# Done ramping
# Ramping V_bot_A to 3.90e-01
# Done ramping
# Ramping V_bot_A to 3.95e-01
# Done ramping
# Ramping V_bot_A to 4.00e-01
# Done ramping
# Ramping V_bot_A to 4.05e-01
# Done ramping
# Ramping V_bot_A to 4.10e-01
# Done ramping
# Ramping V_bot_A to 4.15e-01
# Done ramping
# Ramping V_bot_A to 4.20e-01
# Done ramping
# Ramping V_bot_A to 4.25e-01
# Done ramping
# Ramping V_bot_A to 4.30e-01
# Done ramping
# Ramping V_bot_A to 4.35e-01
# Done ramping
# Ramping V_bot_A to 4.40e-01
# Done ramping
# Ramping V_bot_A to 4.45e-01
# Done ramping
# Ramping V_bot_A to 4.50e-01
# Done ramping
# Ramping V_bot_A to 4.55e-01
# Done ramping
# Ramping V_bot_A to 4.60e-01
# Done ramping
# Ramping V_bot_A to 4.65e-01
# Done ramping
# Ramping V_bot_A to 4.70e-01
# Done ramping
# Ramping V_bot_A to 4.75e-01
# Done ramping
# Ramping V_bot_A to 4.80e-01
# Done ramping
# Ramping V_bot_A to 4.85e-01
# Done ramping
# Ramping V_bot_A to 4.90e-01
# Done ramping
# Ramping V_bot_A to 4.95e-01
# Done ramping
# Ramping V_bot_A to 5.00e-01
# Done ramping
# Ramping V_bot_A to 5.05e-01
# Done ramping
# Ramping V_bot_A to 5.10e-01
# Done ramping
# Ramping V_bot_A to 5.15e-01
# Done ramping
# Ramping V_bot_A to 5.20e-01
# Done ramping
# Ramping V_bot_A to 5.25e-01
# Done ramping
# Ramping V_bot_A to 5.30e-01
# Done ramping
# Ramping V_bot_A to 5.35e-01
# Done ramping
# Ramping V_bot_A to 5.40e-01
# Done ramping
# Ramping V_bot_A to 5.45e-01
# Done ramping
# Ramping V_bot_A to 5.50e-01
# Done ramping
# Ramping V_bot_A to 5.55e-01
# Done ramping
# Ramping V_bot_A to 5.60e-01
# Done ramping
# Ramping V_bot_A to 5.65e-01
# Done ramping
# Ramping V_bot_A to 5.70e-01
# Done ramping
# Ramping V_bot_A to 5.75e-01
# Done ramping
# Ramping V_bot_A to 5.80e-01
# Done ramping
# Ramping V_bot_A to 5.85e-01
# Done ramping
# Ramping V_bot_A to 5.90e-01
# Done ramping
# Ramping V_bot_A to 5.95e-01
# Done ramping
# Ramping V_bot_A to 6.00e-01
# Done ramping
# Ramping V_bot_A to 6.05e-01
# Done ramping
# Ramping V_bot_A to 6.10e-01
# Done ramping
# Ramping V_bot_A to 6.15e-01
# Done ramping
# Ramping V_bot_A to 6.20e-01
# Done ramping
# Ramping V_bot_A to 6.25e-01
# Done ramping
# Ramping V_bot_A to 6.30e-01
# Done ramping
# Ramping V_bot_A to 6.35e-01
# Done ramping
# Ramping V_bot_A to 6.40e-01
# Done ramping
# Ramping V_bot_A to 6.45e-01
# Done ramping
# Ramping V_bot_A to 6.50e-01
# Done ramping
# Ramping V_bot_A to 6.55e-01
# Done ramping
# Ramping V_bot_A to 6.60e-01
# Done ramping
# Ramping V_bot_A to 6.65e-01
# Done ramping
# Ramping V_bot_A to 6.70e-01
# Done ramping
# Ramping V_bot_A to 6.75e-01
# Done ramping
# Ramping V_bot_A to 6.80e-01
# Done ramping
# Ramping V_bot_A to 6.85e-01
# Done ramping
# Ramping V_bot_A to 6.90e-01
# Done ramping
# Ramping V_bot_A to 6.95e-01
# Done ramping
# Ramping V_bot_A to 7.00e-01
# Done ramping
# Ramping V_bot_A to 7.05e-01
# Done ramping
# Ramping V_bot_A to 7.10e-01
# Done ramping
# Ramping V_bot_A to 7.15e-01
# Done ramping
# Ramping V_bot_A to 7.20e-01
# Done ramping
# Ramping V_bot_A to 7.25e-01
# Done ramping
# Ramping V_bot_A to 7.30e-01
# Done ramping
# Ramping V_bot_A to 7.35e-01
# Done ramping
# Ramping V_bot_A to 7.40e-01
# Done ramping
# Ramping V_bot_A to 7.45e-01
# Done ramping
# Ramping V_bot_A to 7.50e-01
# Done ramping
# Ramping V_bot_A to 7.55e-01
# Done ramping
# Ramping V_bot_A to 7.60e-01
# Done ramping
# Ramping V_bot_A to 7.65e-01
# Done ramping
# Ramping V_bot_A to 7.70e-01
# Done ramping
# Ramping V_bot_A to 7.75e-01
# Done ramping
# Ramping V_bot_A to 7.80e-01
# Done ramping
# Ramping V_bot_A to 7.85e-01
# Done ramping
# Ramping V_bot_A to 7.90e-01
# Done ramping
# Ramping V_bot_A to 7.95e-01
# Done ramping
# Ramping V_bot_A to 8.00e-01
# Done ramping
# Ramping V_bot_A to 8.05e-01
# Done ramping
# Ramping V_bot_A to 8.10e-01
# Done ramping
# Ramping V_bot_A to 8.15e-01
# Done ramping
# Ramping V_bot_A to 8.20e-01
# Done ramping
# Ramping V_bot_A to 8.25e-01
# Done ramping
# Ramping V_bot_A to 8.30e-01
# Done ramping
# Ramping V_bot_A to 8.35e-01
# Done ramping
# Ramping V_bot_A to 8.40e-01
# Done ramping
# Ramping V_bot_A to 8.45e-01
# Done ramping
# Ramping V_bot_A to 8.50e-01
# Done ramping
# Ramping V_bot_A to 8.55e-01
# Done ramping
# Ramping V_bot_A to 8.60e-01
# Done ramping
# Ramping V_bot_A to 8.65e-01
# Done ramping
# Ramping V_bot_A to 8.70e-01
# Done ramping
# Ramping V_bot_A to 8.75e-01
# Done ramping
# Ramping V_bot_A to 8.80e-01
# Done ramping
# Ramping V_bot_A to 8.85e-01
# Done ramping
# Ramping V_bot_A to 8.90e-01
# Done ramping
# Ramping V_bot_A to 8.95e-01
# Done ramping
# Ramping V_bot_A to 9.00e-01
# Done ramping
# Ramping V_bot_A to 9.05e-01
# Done ramping
# Ramping V_bot_A to 9.10e-01
# Done ramping
# Ramping V_bot_A to 9.15e-01
# Done ramping
# Ramping V_bot_A to 9.20e-01
# Done ramping
# Ramping V_bot_A to 9.25e-01
# Done ramping
# Ramping V_bot_A to 9.30e-01
# Done ramping
# Ramping V_bot_A to 9.35e-01
# Done ramping
# Ramping V_bot_A to 9.40e-01
# Done ramping
# Ramping V_bot_A to 9.45e-01
# Done ramping
# Ramping V_bot_A to 9.50e-01
# Done ramping
# Ramping V_bot_A to 9.55e-01
# Done ramping
# Ramping V_bot_A to 9.60e-01
# Done ramping
# Ramping V_bot_A to 9.65e-01
# Done ramping
# Ramping V_bot_A to 9.70e-01
# Done ramping
# Ramping V_bot_A to 9.75e-01
# Done ramping
# Ramping V_bot_A to 9.80e-01
# Done ramping
# Ramping V_bot_A to 9.85e-01
# Done ramping
# Ramping V_bot_A to 9.90e-01
# Done ramping
# Ramping V_bot_A to 9.95e-01
# Done ramping
# Ramping V_bot_A to 1.00e+00
# Done ramping
# Ramping V_bot_A to 1.00e+00
# Done ramping
# Ramping V_bot_A to 1.01e+00
# Done ramping
# Ramping V_bot_A to 1.01e+00
# Done ramping
# Ramping V_bot_A to 1.02e+00
# Done ramping
# Ramping V_bot_A to 1.02e+00
# Done ramping
# Ramping V_bot_A to 1.03e+00
# Done ramping
# Ramping V_bot_A to 1.03e+00
# Done ramping
# Ramping V_bot_A to 1.04e+00
# Done ramping
# Ramping V_bot_A to 1.04e+00
# Done ramping
# Ramping V_bot_A to 1.05e+00
# Done ramping
# Ramping V_bot_A to 1.05e+00
# Done ramping
# Ramping V_bot_A to 1.06e+00
# Done ramping
# Ramping V_bot_A to 1.06e+00
# Done ramping
# Ramping V_bot_A to 1.07e+00
# Done ramping
# Ramping V_bot_A to 1.07e+00
# Done ramping
# Ramping V_bot_A to 1.08e+00
# Done ramping
# Ramping V_bot_A to 1.08e+00
# Done ramping
# Ramping V_bot_A to 1.09e+00
# Done ramping
# Ramping V_bot_A to 1.09e+00
# Done ramping
# Ramping V_bot_A to 1.10e+00
# Done ramping
# Ramping V_bot_A to 1.10e+00
# Done ramping
# Ramping V_bot_A to 1.11e+00
# Done ramping
# Ramping V_bot_A to 1.11e+00
# Done ramping
# Ramping V_bot_A to 1.12e+00
# Done ramping
# Ramping V_bot_A to 1.12e+00
# Done ramping
# Ramping V_bot_A to 1.13e+00
# Done ramping
# Ramping V_bot_A to 1.13e+00
# Done ramping
# Ramping V_bot_A to 1.14e+00
# Done ramping
# Ramping V_bot_A to 1.14e+00
# Done ramping
# Ramping V_bot_A to 1.15e+00
# Done ramping
# Ramping V_bot_A to 1.15e+00
# Done ramping
# Ramping V_bot_A to 1.16e+00
# Done ramping
# Ramping V_bot_A to 1.16e+00
# Done ramping
# Ramping V_bot_A to 1.17e+00
# Done ramping
# Ramping V_bot_A to 1.17e+00
# Done ramping
# Ramping V_bot_A to 1.18e+00
# Done ramping
# Ramping V_bot_A to 1.18e+00
# Done ramping
# Ramping V_bot_A to 1.19e+00
# Done ramping
# Ramping V_bot_A to 1.19e+00
# Done ramping
# Ramping V_bot_A to 1.20e+00
# Done ramping
# Ramping V_bot_A to 1.20e+00
# Done ramping
# Ramping V_bot_A to 1.21e+00
# Done ramping
# Ramping V_bot_A to 1.21e+00
# Done ramping
# Ramping V_bot_A to 1.22e+00
# Done ramping
# Ramping V_bot_A to 1.22e+00
# Done ramping
# Ramping V_bot_A to 1.23e+00
# Done ramping
# Ramping V_bot_A to 1.23e+00
# Done ramping
# Ramping V_bot_A to 1.24e+00
# Done ramping
# Ramping V_bot_A to 1.24e+00
# Done ramping
# Ramping V_bot_A to 1.25e+00
# Done ramping
# Ramping V_bot_A to 1.25e+00
# Done ramping
# Ramping V_bot_A to 1.26e+00
# Done ramping
# Ramping V_bot_A to 1.26e+00
# Done ramping
# Ramping V_bot_A to 1.27e+00
# Done ramping
# Ramping V_bot_A to 1.27e+00
# Done ramping
# Ramping V_bot_A to 1.28e+00
# Done ramping
# Ramping V_bot_A to 1.28e+00
# Done ramping
# Ramping V_bot_A to 1.29e+00
# Done ramping
# Ramping V_bot_A to 1.29e+00
# Done ramping
# Ramping V_bot_A to 1.30e+00
# Done ramping
# Ramping V_bot_A to 1.30e+00
# Done ramping
# Ramping V_bot_A to 1.31e+00
# Done ramping
# Ramping V_bot_A to 1.31e+00
# Done ramping
# Ramping V_bot_A to 1.32e+00
# Done ramping
# Ramping V_bot_A to 1.32e+00
# Done ramping
# Ramping V_bot_A to 1.33e+00
# Done ramping
# Ramping V_bot_A to 1.33e+00
# Done ramping
# Ramping V_bot_A to 1.34e+00
# Done ramping
# Ramping V_bot_A to 1.34e+00
# Done ramping
# Ramping V_bot_A to 1.35e+00
# Done ramping
# Ramping V_bot_A to 1.35e+00
# Done ramping
# Ramping V_bot_A to 1.36e+00
# Done ramping
# Ramping V_bot_A to 1.36e+00
# Done ramping
# Ramping V_bot_A to 1.37e+00
# Done ramping
# Ramping V_bot_A to 1.37e+00
# Done ramping
# Ramping V_bot_A to 1.38e+00
# Done ramping
# Ramping V_bot_A to 1.38e+00
# Done ramping
# Ramping V_bot_A to 1.39e+00
# Done ramping
# Ramping V_bot_A to 1.39e+00
# Done ramping
# Ramping V_bot_A to 1.40e+00
# Done ramping
# Ramping V_bot_A to 1.40e+00
# Done ramping
# Ramping V_bot_A to 1.41e+00
# Done ramping
# Ramping V_bot_A to 1.41e+00
# Done ramping
# Ramping V_bot_A to 1.42e+00
# Done ramping
# Ramping V_bot_A to 1.42e+00
# Done ramping
# Ramping V_bot_A to 1.43e+00
# Done ramping
# Ramping V_bot_A to 1.43e+00
# Done ramping
# Ramping V_bot_A to 1.44e+00
# Done ramping
# Ramping V_bot_A to 1.44e+00
# Done ramping
# Ramping V_bot_A to 1.45e+00
# Done ramping
# Ramping V_bot_A to 1.45e+00
# Done ramping
# Ramping V_bot_A to 1.46e+00
# Done ramping
# Ramping V_bot_A to 1.46e+00
# Done ramping
# Ramping V_bot_A to 1.47e+00
# Done ramping
# Ramping V_bot_A to 1.47e+00
# Done ramping
# Ramping V_bot_A to 1.48e+00
# Done ramping
# Ramping V_bot_A to 1.48e+00
# Done ramping
# Ramping V_bot_A to 1.49e+00
# Done ramping
# Ramping V_bot_A to 1.49e+00
# Done ramping
# Ramping V_bot_A to 1.50e+00
# Done ramping
# Ramping V_bot_A to 1.50e+00
# Done ramping
# Ramping V_bot_A to 1.51e+00
# Done ramping
# Ramping V_bot_A to 1.51e+00
# Done ramping
# Ramping V_bot_A to 1.52e+00
# Done ramping
# Ramping V_bot_A to 1.52e+00
# Done ramping
# Ramping V_bot_A to 1.53e+00
# Done ramping
# Ramping V_bot_A to 1.53e+00
# Done ramping
# Ramping V_bot_A to 1.54e+00
# Done ramping
# Ramping V_bot_A to 1.54e+00
# Done ramping
# Ramping V_bot_A to 1.55e+00
# Done ramping
# Ramping V_bot_A to 1.55e+00
# Done ramping
# Ramping V_bot_A to 1.56e+00
# Done ramping
# Ramping V_bot_A to 1.56e+00
# Done ramping
# Ramping V_bot_A to 1.57e+00
# Done ramping
# Ramping V_bot_A to 1.57e+00
# Done ramping
# Ramping V_bot_A to 1.58e+00
# Done ramping
# Ramping V_bot_A to 1.58e+00
# Done ramping
# Ramping V_bot_A to 1.59e+00
# Done ramping
# Ramping V_bot_A to 1.59e+00
# Done ramping
# Ramping V_bot_A to 1.60e+00
# Done ramping
# Ramping V_bot_A to 1.60e+00
# Done ramping
# Ramping V_bot_A to 1.61e+00
# Done ramping
# Ramping V_bot_A to 1.61e+00
# Done ramping
# Ramping V_bot_A to 1.62e+00
# Done ramping
# Ramping V_bot_A to 1.62e+00
# Done ramping
# Ramping V_bot_A to 1.63e+00
# Done ramping
# Ramping V_bot_A to 1.63e+00
# Done ramping
# Ramping V_bot_A to 1.64e+00
# Done ramping
# Ramping V_bot_A to 1.64e+00
# Done ramping
# Ramping V_bot_A to 1.65e+00
# Done ramping
# Ramping V_bot_A to 1.65e+00
# Done ramping
# Ramping V_bot_A to 1.66e+00
# Done ramping
# Ramping V_bot_A to 1.66e+00
# Done ramping
# Ramping V_bot_A to 1.67e+00
# Done ramping
# Ramping V_bot_A to 1.67e+00
# Done ramping
# Ramping V_bot_A to 1.68e+00
# Done ramping
# Ramping V_bot_A to 1.68e+00
# Done ramping
# Ramping V_bot_A to 1.69e+00
# Done ramping
# Ramping V_bot_A to 1.69e+00
# Done ramping
# Ramping V_bot_A to 1.70e+00
# Done ramping
# Ramping V_bot_A to 1.70e+00
# Done ramping
# Ramping V_bot_A to 1.71e+00
# Done ramping
# Ramping V_bot_A to 1.71e+00
# Done ramping
# Ramping V_bot_A to 1.72e+00
# Done ramping
# Ramping V_bot_A to 1.72e+00
# Done ramping
# Ramping V_bot_A to 1.73e+00
# Done ramping
# Ramping V_bot_A to 1.73e+00
# Done ramping
# Ramping V_bot_A to 1.74e+00
# Done ramping
# Ramping V_bot_A to 1.74e+00
# Done ramping
# Ramping V_bot_A to 1.75e+00
# Done ramping
# Ramping V_bot_A to 1.75e+00
# Done ramping
# Ramping V_bot_A to 1.76e+00
# Done ramping
# Ramping V_bot_A to 1.76e+00
# Done ramping
# Ramping V_bot_A to 1.77e+00
# Done ramping
# Ramping V_bot_A to 1.77e+00
# Done ramping
# Ramping V_bot_A to 1.78e+00
# Done ramping
# Ramping V_bot_A to 1.78e+00
# Done ramping
# Ramping V_bot_A to 1.79e+00
# Done ramping
# Ramping V_bot_A to 1.79e+00
# Done ramping
# Ramping V_bot_A to 1.80e+00
# Done ramping
# Ramping V_bot_A to 1.80e+00
# Done ramping
# Ramping V_bot_A to 1.81e+00
# Done ramping
# Ramping V_bot_A to 1.81e+00
# Done ramping
# Ramping V_bot_A to 1.82e+00
# Done ramping
# Ramping V_bot_A to 1.82e+00
# Done ramping
# Ramping V_bot_A to 1.83e+00
# Done ramping
# Ramping V_bot_A to 1.83e+00
# Done ramping
# Ramping V_bot_A to 1.84e+00
# Done ramping
# Ramping V_bot_A to 1.84e+00
# Done ramping
# Ramping V_bot_A to 1.85e+00
# Done ramping
# Ramping V_bot_A to 1.85e+00
# Done ramping
# Ramping V_bot_A to 1.86e+00
# Done ramping
# Ramping V_bot_A to 1.86e+00
# Done ramping
# Ramping V_bot_A to 1.87e+00
# Done ramping
# Ramping V_bot_A to 1.87e+00
# Done ramping
# Ramping V_bot_A to 1.88e+00
# Done ramping
# Ramping V_bot_A to 1.88e+00
# Done ramping
# Ramping V_bot_A to 1.89e+00
# Done ramping
# Ramping V_bot_A to 1.89e+00
# Done ramping
# Ramping V_bot_A to 1.90e+00
# Done ramping
# Ramping V_bot_A to 1.90e+00
# Done ramping
# Ramping V_bot_A to 1.91e+00
# Done ramping
# Ramping V_bot_A to 1.91e+00
# Done ramping
# Ramping V_bot_A to 1.92e+00
# Done ramping
# Ramping V_bot_A to 1.92e+00
# Done ramping
# Ramping V_bot_A to 1.93e+00
# Done ramping
# Ramping V_bot_A to 1.93e+00
# Done ramping
# Ramping V_bot_A to 1.94e+00
# Done ramping
# Ramping V_bot_A to 1.94e+00
# Done ramping
# Ramping V_bot_A to 1.95e+00
# Done ramping
# Ramping V_bot_A to 1.95e+00
# Done ramping
# Ramping V_bot_A to 1.96e+00
# Done ramping
# Ramping V_bot_A to 1.96e+00
# Done ramping
# Ramping V_bot_A to 1.97e+00
# Done ramping
# Ramping V_bot_A to 1.97e+00
# Done ramping
# Ramping V_bot_A to 1.98e+00
# Done ramping
# Ramping V_bot_A to 1.98e+00
# Done ramping
# Ramping V_bot_A to 1.99e+00
# Done ramping
# Ramping V_bot_A to 1.99e+00
# Done ramping
# Ramping V_bot_A to 2.00e+00
# Done ramping
# Ramping V_bot_A to 2.00e+00
# Done ramping
# Ramping V_bot_A to 2.01e+00
# Done ramping
# Ramping V_bot_A to 2.01e+00
# Done ramping
# Ramping V_bot_A to 2.02e+00
# Done ramping
# Ramping V_bot_A to 2.02e+00
# Done ramping
# Ramping V_bot_A to 2.03e+00
# Done ramping
# Ramping V_bot_A to 2.03e+00
# Done ramping
# Ramping V_bot_A to 2.04e+00
# Done ramping
# Ramping V_bot_A to 2.04e+00
# Done ramping
# Ramping V_bot_A to 2.05e+00
# Done ramping
# Ramping V_bot_A to 2.05e+00
# Done ramping
# Ramping V_bot_A to 2.06e+00
# Done ramping
# Ramping V_bot_A to 2.06e+00
# Done ramping
# Ramping V_bot_A to 2.07e+00
# Done ramping
# Ramping V_bot_A to 2.07e+00
# Done ramping
# Ramping V_bot_A to 2.08e+00
# Done ramping
# Ramping V_bot_A to 2.08e+00
# Done ramping
# Ramping V_bot_A to 2.09e+00
# Done ramping
# Ramping V_bot_A to 2.09e+00
# Done ramping
# Ramping V_bot_A to 2.10e+00
# Done ramping
# Ramping V_bot_A to 2.10e+00
# Done ramping
# Ramping V_bot_A to 2.11e+00
# Done ramping
# Ramping V_bot_A to 2.11e+00
# Done ramping
# Ramping V_bot_A to 2.12e+00
# Done ramping
# Ramping V_bot_A to 2.12e+00
# Done ramping
# Ramping V_bot_A to 2.13e+00
# Done ramping
# Ramping V_bot_A to 2.13e+00
# Done ramping
# Ramping V_bot_A to 2.14e+00
# Done ramping
# Ramping V_bot_A to 2.14e+00
# Done ramping
# Ramping V_bot_A to 2.15e+00
# Done ramping
# Ramping V_bot_A to 2.15e+00
# Done ramping
# Ramping V_bot_A to 2.16e+00
# Done ramping
# Ramping V_bot_A to 2.16e+00
# Done ramping
# Ramping V_bot_A to 2.17e+00
# Done ramping
# Ramping V_bot_A to 2.17e+00
# Done ramping
# Ramping V_bot_A to 2.18e+00
# Done ramping
# Ramping V_bot_A to 2.18e+00
# Done ramping
# Ramping V_bot_A to 2.19e+00
# Done ramping
# Ramping V_bot_A to 2.19e+00
# Done ramping
# Ramping V_bot_A to 2.20e+00
# Done ramping
# Ramping V_bot_A to 2.20e+00
# Done ramping
# Ramping V_bot_A to 2.21e+00
# Done ramping
# Ramping V_bot_A to 2.21e+00
# Done ramping
# Ramping V_bot_A to 2.22e+00
# Done ramping
# Ramping V_bot_A to 2.22e+00
# Done ramping
# Ramping V_bot_A to 2.23e+00
# Done ramping
# Ramping V_bot_A to 2.23e+00
# Done ramping
# Ramping V_bot_A to 2.24e+00
# Done ramping
# Ramping V_bot_A to 2.24e+00
# Done ramping
# Ramping V_bot_A to 2.25e+00
# Done ramping
# Ramping V_bot_A to 2.25e+00
# Done ramping
# Ramping V_bot_A to 2.26e+00
# Done ramping
# Ramping V_bot_A to 2.26e+00
# Done ramping
# Ramping V_bot_A to 2.27e+00
# Done ramping
# Ramping V_bot_A to 2.27e+00
# Done ramping
# Ramping V_bot_A to 2.28e+00
# Done ramping
# Ramping V_bot_A to 2.28e+00
# Done ramping
# Ramping V_bot_A to 2.29e+00
# Done ramping
# Ramping V_bot_A to 2.29e+00
# Done ramping
# Ramping V_bot_A to 2.30e+00
# Done ramping
# Ramping V_bot_A to 2.30e+00
# Done ramping
# Ramping V_bot_A to 2.31e+00
# Done ramping
# Ramping V_bot_A to 2.31e+00
# Done ramping
# Ramping V_bot_A to 2.32e+00
# Done ramping
# Ramping V_bot_A to 2.32e+00
# Done ramping
# Ramping V_bot_A to 2.33e+00
# Done ramping
# Ramping V_bot_A to 2.33e+00
# Done ramping
# Ramping V_bot_A to 2.34e+00
# Done ramping
# Ramping V_bot_A to 2.34e+00
# Done ramping
# Ramping V_bot_A to 2.35e+00
# Done ramping
# Ramping V_bot_A to 2.35e+00
# Done ramping
# Ramping V_bot_A to 2.36e+00
# Done ramping
# Ramping V_bot_A to 2.36e+00
# Done ramping
# Ramping V_bot_A to 2.37e+00
# Done ramping
# Ramping V_bot_A to 2.37e+00
# Done ramping
# Ramping V_bot_A to 2.38e+00
# Done ramping
# Ramping V_bot_A to 2.38e+00
# Done ramping
# Ramping V_bot_A to 2.39e+00
# Done ramping
# Ramping V_bot_A to 2.39e+00
# Done ramping
# Ramping V_bot_A to 2.40e+00
# Done ramping
# Ramping V_bot_A to 2.40e+00
# Done ramping
# Ramping V_bot_A to 2.41e+00
# Done ramping
# Ramping V_bot_A to 2.41e+00
# Done ramping
# Ramping V_bot_A to 2.42e+00
# Done ramping
# Ramping V_bot_A to 2.42e+00
# Done ramping
# Ramping V_bot_A to 2.43e+00
# Done ramping
# Ramping V_bot_A to 2.43e+00
# Done ramping
# Ramping V_bot_A to 2.44e+00
# Done ramping
# Ramping V_bot_A to 2.44e+00
# Done ramping
# Ramping V_bot_A to 2.45e+00
# Done ramping
# Ramping V_bot_A to 2.45e+00
# Done ramping
# Ramping V_bot_A to 2.46e+00
# Done ramping
# Ramping V_bot_A to 2.46e+00
# Done ramping
# Ramping V_bot_A to 2.47e+00
# Done ramping
# Ramping V_bot_A to 2.47e+00
# Done ramping
# Ramping V_bot_A to 2.48e+00
# Done ramping
# Ramping V_bot_A to 2.48e+00
# Done ramping
# Ramping V_bot_A to 2.49e+00
# Done ramping
# Ramping V_bot_A to 2.49e+00
# Done ramping
# Ramping V_bot_A to 2.50e+00
# Done ramping
# Ramping V_bot_A to 2.50e+00
# Done ramping
# Ramping V_bot_A to 2.51e+00
# Done ramping
# Ramping V_bot_A to 2.51e+00
# Done ramping
# Ramping V_bot_A to 2.52e+00
# Done ramping
# Ramping V_bot_A to 2.52e+00
# Done ramping
# Ramping V_bot_A to 2.53e+00
# Done ramping
# Ramping V_bot_A to 2.53e+00
# Done ramping
# Ramping V_bot_A to 2.54e+00
# Done ramping
# Ramping V_bot_A to 2.54e+00
# Done ramping
# Ramping V_bot_A to 2.55e+00
# Done ramping
# Ramping V_bot_A to 2.55e+00
# Done ramping
# Ramping V_bot_A to 2.56e+00
# Done ramping
# Ramping V_bot_A to 2.56e+00
# Done ramping
# Ramping V_bot_A to 2.57e+00
# Done ramping
# Ramping V_bot_A to 2.57e+00
# Done ramping
# Ramping V_bot_A to 2.58e+00
# Done ramping
# Ramping V_bot_A to 2.58e+00
# Done ramping
# Ramping V_bot_A to 2.59e+00
# Done ramping
# Ramping V_bot_A to 2.59e+00
# Done ramping
# Ramping V_bot_A to 2.60e+00
# Done ramping
# Ramping V_bot_A to 2.60e+00
# Done ramping
# Ramping V_bot_A to 2.61e+00
# Done ramping
# Ramping V_bot_A to 2.61e+00
# Done ramping
# Ramping V_bot_A to 2.62e+00
# Done ramping
# Ramping V_bot_A to 2.62e+00
# Done ramping
# Ramping V_bot_A to 2.63e+00
# Done ramping
# Ramping V_bot_A to 2.63e+00
# Done ramping
# Ramping V_bot_A to 2.64e+00
# Done ramping
# Ramping V_bot_A to 2.64e+00
# Done ramping
# Ramping V_bot_A to 2.65e+00
# Done ramping
# Ramping V_bot_A to 2.65e+00
# Done ramping
# Ramping V_bot_A to 2.66e+00
# Done ramping
# Ramping V_bot_A to 2.66e+00
# Done ramping
# Ramping V_bot_A to 2.67e+00
# Done ramping
# Ramping V_bot_A to 2.67e+00
# Done ramping
# Ramping V_bot_A to 2.68e+00
# Done ramping
# Ramping V_bot_A to 2.68e+00
# Done ramping
# Ramping V_bot_A to 2.69e+00
# Done ramping
# Ramping V_bot_A to 2.69e+00
# Done ramping
# Ramping V_bot_A to 2.70e+00
# Done ramping
# Ramping V_bot_A to 2.70e+00
# Done ramping
# Ramping V_bot_A to 2.71e+00
# Done ramping
# Ramping V_bot_A to 2.71e+00
# Done ramping
# Ramping V_bot_A to 2.72e+00
# Done ramping
# Ramping V_bot_A to 2.72e+00
# Done ramping
# Ramping V_bot_A to 2.73e+00
# Done ramping
# Ramping V_bot_A to 2.73e+00
# Done ramping
# Ramping V_bot_A to 2.74e+00
# Done ramping
# Ramping V_bot_A to 2.74e+00
# Done ramping
# Ramping V_bot_A to 2.75e+00
# Done ramping
# Ramping V_bot_A to 2.75e+00
# Done ramping
# Ramping V_bot_A to 2.76e+00
# Done ramping
# Ramping V_bot_A to 2.76e+00
# Done ramping
# Ramping V_bot_A to 2.77e+00
# Done ramping
# Ramping V_bot_A to 2.77e+00
# Done ramping
# Ramping V_bot_A to 2.78e+00
# Done ramping
# Ramping V_bot_A to 2.78e+00
# Done ramping
# Ramping V_bot_A to 2.79e+00
# Done ramping
# Ramping V_bot_A to 2.79e+00
# Done ramping
# Ramping V_bot_A to 2.80e+00
# Done ramping
# Ramping V_bot_A to 2.80e+00
# Done ramping
# Ramping V_bot_A to 2.81e+00
# Done ramping
# Ramping V_bot_A to 2.81e+00
# Done ramping
# Ramping V_bot_A to 2.82e+00
# Done ramping
# Ramping V_bot_A to 2.82e+00
# Done ramping
# Ramping V_bot_A to 2.83e+00
# Done ramping
# Ramping V_bot_A to 2.83e+00
# Done ramping
# Ramping V_bot_A to 2.84e+00
# Done ramping
# Ramping V_bot_A to 2.84e+00
# Done ramping
# Ramping V_bot_A to 2.85e+00
# Done ramping
# Ramping V_bot_A to 2.85e+00
# Done ramping
# Ramping V_bot_A to 2.86e+00
# Done ramping
# Ramping V_bot_A to 2.86e+00
# Done ramping
# Ramping V_bot_A to 2.87e+00
# Done ramping
# Ramping V_bot_A to 2.87e+00
# Done ramping
# Ramping V_bot_A to 2.88e+00
# Done ramping
# Ramping V_bot_A to 2.88e+00
# Done ramping
# Ramping V_bot_A to 2.89e+00
# Done ramping
# Ramping V_bot_A to 2.89e+00
# Done ramping
# Ramping V_bot_A to 2.90e+00
# Done ramping
# Ramping V_bot_A to 2.90e+00
# Done ramping
# Ramping V_bot_A to 2.91e+00
# Done ramping
# Ramping V_bot_A to 2.91e+00
# Done ramping
# Ramping V_bot_A to 2.92e+00
# Done ramping
# Ramping V_bot_A to 2.92e+00
# Done ramping
# Ramping V_bot_A to 2.93e+00
# Done ramping
# Ramping V_bot_A to 2.93e+00
# Done ramping
# Ramping V_bot_A to 2.94e+00
# Done ramping
# Ramping V_bot_A to 2.94e+00
# Done ramping
# Ramping V_bot_A to 2.95e+00
# Done ramping
# Ramping V_bot_A to 2.95e+00
# Done ramping
# Ramping V_bot_A to 2.96e+00
# Done ramping
# Ramping V_bot_A to 2.96e+00
# Done ramping
# Ramping V_bot_A to 2.97e+00
# Done ramping
# Ramping V_bot_A to 2.97e+00
# Done ramping
# Ramping V_bot_A to 2.98e+00
# Done ramping
# Ramping V_bot_A to 2.98e+00
# Done ramping
# Ramping V_bot_A to 2.99e+00
# Done ramping
# Ramping V_bot_A to 2.99e+00
# Done ramping
# Ramping V_bot_A to 3.00e+00
# Done ramping
# Ramping V_bot_A to 3.00e+00
# Done ramping
# Ramping V_bot_A to 3.01e+00
# Done ramping
# Ramping V_bot_A to 3.01e+00
# Done ramping
# Ramping V_bot_A to 3.02e+00
# Done ramping
# Ramping V_bot_A to 3.02e+00
# Done ramping
# Ramping V_bot_A to 3.03e+00
# Done ramping
# Ramping V_bot_A to 3.03e+00
# Done ramping
# Ramping V_bot_A to 3.04e+00
# Done ramping
# Ramping V_bot_A to 3.04e+00
# Done ramping
# Ramping V_bot_A to 3.05e+00
# Done ramping
# Ramping V_bot_A to 3.05e+00
# Done ramping
# Ramping V_bot_A to 3.06e+00
# Done ramping
# Ramping V_bot_A to 3.06e+00
# Done ramping
# Ramping V_bot_A to 3.07e+00
# Done ramping
# Ramping V_bot_A to 3.07e+00
# Done ramping
# Ramping V_bot_A to 3.08e+00
# Done ramping
# Ramping V_bot_A to 3.08e+00
# Done ramping
# Ramping V_bot_A to 3.09e+00
# Done ramping
# Ramping V_bot_A to 3.09e+00
# Done ramping
# Ramping V_bot_A to 3.10e+00
# Done ramping
# Ramping V_bot_A to 3.10e+00
# Done ramping
# Ramping V_bot_A to 3.11e+00
# Done ramping
# Ramping V_bot_A to 3.11e+00
# Done ramping
# Ramping V_bot_A to 3.12e+00
# Done ramping
# Ramping V_bot_A to 3.12e+00
# Done ramping
# Ramping V_bot_A to 3.13e+00
# Done ramping
# Ramping V_bot_A to 3.13e+00
# Done ramping
# Ramping V_bot_A to 3.14e+00
# Done ramping
# Ramping V_bot_A to 3.14e+00
# Done ramping
# Ramping V_bot_A to 3.15e+00
# Done ramping
# Ramping V_bot_A to 3.15e+00
# Done ramping
# Ramping V_bot_A to 3.16e+00
# Done ramping
# Ramping V_bot_A to 3.16e+00
# Done ramping
# Ramping V_bot_A to 3.17e+00
# Done ramping
# Ramping V_bot_A to 3.17e+00
# Done ramping
# Ramping V_bot_A to 3.18e+00
# Done ramping
# Ramping V_bot_A to 3.18e+00
# Done ramping
# Ramping V_bot_A to 3.19e+00
# Done ramping
# Ramping V_bot_A to 3.19e+00
# Done ramping
# Ramping V_bot_A to 3.20e+00
# Done ramping
# Ramping V_bot_A to 3.20e+00
# Done ramping
# Ramping V_bot_A to 3.21e+00
# Done ramping
# Ramping V_bot_A to 3.21e+00
# Done ramping
# Ramping V_bot_A to 3.22e+00
# Done ramping
# Ramping V_bot_A to 3.22e+00
# Done ramping
# Ramping V_bot_A to 3.23e+00
# Done ramping
# Ramping V_bot_A to 3.23e+00
# Done ramping
# Ramping V_bot_A to 3.24e+00
# Done ramping
# Ramping V_bot_A to 3.24e+00
# Done ramping
# Ramping V_bot_A to 3.25e+00
# Done ramping
# Ramping V_bot_A to 3.25e+00
# Done ramping
# Ramping V_bot_A to 3.26e+00
# Done ramping
# Ramping V_bot_A to 3.26e+00
# Done ramping
# Ramping V_bot_A to 3.27e+00
# Done ramping
# Ramping V_bot_A to 3.27e+00
# Done ramping
# Ramping V_bot_A to 3.28e+00
# Done ramping
# Ramping V_bot_A to 3.28e+00
# Done ramping
# Ramping V_bot_A to 3.29e+00
# Done ramping
# Ramping V_bot_A to 3.29e+00
# Done ramping
# Ramping V_bot_A to 3.30e+00
# Done ramping
# Ramping V_bot_A to 3.30e+00
# Done ramping
# Ramping V_bot_A to 3.31e+00
# Done ramping
# Ramping V_bot_A to 3.31e+00
# Done ramping
# Ramping V_bot_A to 3.32e+00
# Done ramping
# Ramping V_bot_A to 3.32e+00
# Done ramping
# Ramping V_bot_A to 3.33e+00
# Done ramping
# Ramping V_bot_A to 3.33e+00
# Done ramping
# Ramping V_bot_A to 3.34e+00
# Done ramping
# Ramping V_bot_A to 3.34e+00
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_bot_A to 3.35e+00
# Done ramping
# Ramping V_bot_A to 3.36e+00
# Done ramping
# Ramping V_bot_A to 3.36e+00
# Done ramping
# Ramping V_bot_A to 3.37e+00
# Done ramping
# Ramping V_bot_A to 3.37e+00
# Done ramping
# Ramping V_bot_A to 3.38e+00
# Done ramping
# Ramping V_bot_A to 3.38e+00
# Done ramping
# Ramping V_bot_A to 3.39e+00
# Done ramping
# Ramping V_bot_A to 3.39e+00
# Done ramping
# Ramping V_bot_A to 3.40e+00
# Done ramping
# Ramping V_bot_A to 3.40e+00
# Done ramping
# Ramping V_bot_A to 3.41e+00
# Done ramping
# Ramping V_bot_A to 3.41e+00
# Done ramping
# Ramping V_bot_A to 3.42e+00
# Done ramping
# Ramping V_bot_A to 3.42e+00
# Done ramping
# Ramping V_bot_A to 3.43e+00
# Done ramping
# Ramping V_bot_A to 3.43e+00
# Done ramping
# Ramping V_bot_A to 3.44e+00
# Done ramping
# Ramping V_bot_A to 3.44e+00
# Done ramping
# Ramping V_bot_A to 3.45e+00
# Done ramping
# Ramping V_bot_A to 3.45e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.46e+00
# Done ramping
# Ramping V_bot_A to 3.47e+00
# Done ramping
# Ramping V_bot_A to 3.47e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.48e+00
# Done ramping
# Ramping V_bot_A to 3.49e+00
# Done ramping
# Ramping V_bot_A to 3.49e+00
# Done ramping
# Ramping V_bot_A to 3.50e+00
# Done ramping
# Ramping V_bot_A to 3.50e+00
# Done ramping
# Ramping V_bot_A to 3.51e+00
# Done ramping
# Ramping V_bot_A to 3.51e+00
# Done ramping
# Ramping V_bot_A to 3.52e+00
# Done ramping
# Ramping V_bot_A to 3.52e+00
# Done ramping
# Ramping V_bot_A to 3.53e+00
# Done ramping
# Ramping V_bot_A to 3.53e+00
# Done ramping
# Ramping V_bot_A to 3.54e+00
# Done ramping
# Ramping V_bot_A to 3.54e+00
# Done ramping
# Ramping V_bot_A to 3.55e+00
# Done ramping
# Ramping V_bot_A to 3.55e+00
# Done ramping
# Ramping V_bot_A to 3.56e+00
# Done ramping
# Ramping V_bot_A to 3.56e+00
# Done ramping
# Ramping V_bot_A to 3.57e+00
# Done ramping
# Ramping V_bot_A to 3.57e+00
# Done ramping
# Ramping V_bot_A to 3.58e+00
# Done ramping
# Ramping V_bot_A to 3.58e+00
# Done ramping
# Ramping V_bot_A to 3.59e+00
# Done ramping
# Ramping V_bot_A to 3.59e+00
# Done ramping
# Ramping V_bot_A to 3.60e+00
# Done ramping
# Ramping V_bot_A to 3.60e+00
# Done ramping
# Ramping V_bot_A to 3.61e+00
# Done ramping
# Ramping V_bot_A to 3.61e+00
# Done ramping
# Ramping V_bot_A to 3.62e+00
# Done ramping
# Ramping V_bot_A to 3.62e+00
# Done ramping
# Ramping V_bot_A to 3.63e+00
# Done ramping
# Ramping V_bot_A to 3.63e+00
# Done ramping
# Ramping V_bot_A to 3.64e+00
# Done ramping
# Ramping V_bot_A to 3.64e+00
# Done ramping
# Ramping V_bot_A to 3.65e+00
# Done ramping
# Ramping V_bot_A to 3.65e+00
# Done ramping
# Ramping V_bot_A to 3.66e+00
# Done ramping
# Ramping V_bot_A to 3.66e+00
# Done ramping
# Ramping V_bot_A to 3.67e+00
# Done ramping
# Ramping V_bot_A to 3.67e+00
# Done ramping
# Ramping V_bot_A to 3.68e+00
# Done ramping
# Ramping V_bot_A to 3.68e+00
# Done ramping
# Ramping V_bot_A to 3.69e+00
# Done ramping
# Ramping V_bot_A to 3.69e+00
# Done ramping
# Ramping V_bot_A to 3.70e+00
# Done ramping
# Ramping V_bot_A to 3.70e+00
# Done ramping
# Ramping V_bot_A to 3.71e+00
# Done ramping
# Ramping V_bot_A to 3.71e+00
# Done ramping
# Ramping V_bot_A to 3.72e+00
# Done ramping
# Ramping V_bot_A to 3.72e+00
# Done ramping
# Ramping V_bot_A to 3.73e+00
# Done ramping
# Ramping V_bot_A to 3.73e+00
# Done ramping
# Ramping V_bot_A to 3.74e+00
# Done ramping
# Ramping V_bot_A to 3.74e+00
# Done ramping
# Ramping V_bot_A to 3.75e+00
# Done ramping
# Ramping V_bot_A to 3.75e+00
# Done ramping
# Ramping V_bot_A to 3.76e+00
# Done ramping
# Ramping V_bot_A to 3.76e+00
# Done ramping
# Ramping V_bot_A to 3.77e+00
# Done ramping
# Ramping V_bot_A to 3.77e+00
# Done ramping
# Ramping V_bot_A to 3.78e+00
# Done ramping
# Ramping V_bot_A to 3.78e+00
# Done ramping
# Ramping V_bot_A to 3.79e+00
# Done ramping
# Ramping V_bot_A to 3.79e+00
# Done ramping
# Ramping V_bot_A to 3.80e+00
# Done ramping
# Ramping V_bot_A to 3.80e+00
# Done ramping
# Ramping V_bot_A to 3.81e+00
# Done ramping
# Ramping V_bot_A to 3.81e+00
# Done ramping
# Ramping V_bot_A to 3.82e+00
# Done ramping
# Ramping V_bot_A to 3.82e+00
# Done ramping
# Ramping V_bot_A to 3.83e+00
# Done ramping
# Ramping V_bot_A to 3.83e+00
# Done ramping
# Ramping V_bot_A to 3.84e+00
# Done ramping
# Ramping V_bot_A to 3.84e+00
# Done ramping
# Ramping V_bot_A to 3.85e+00
# Done ramping
# Ramping V_bot_A to 3.85e+00
# Done ramping
# Ramping V_bot_A to 3.86e+00
# Done ramping
# Ramping V_bot_A to 3.86e+00
# Done ramping
# Ramping V_bot_A to 3.87e+00
# Done ramping
# Ramping V_bot_A to 3.87e+00
# Done ramping
# Ramping V_bot_A to 3.88e+00
# Done ramping
# Ramping V_bot_A to 3.88e+00
# Done ramping
# Ramping V_bot_A to 3.89e+00
# Done ramping
# Ramping V_bot_A to 3.89e+00
# Done ramping
# Ramping V_bot_A to 3.90e+00
# Done ramping
# Ramping V_bot_A to 3.90e+00
# Done ramping
# Ramping V_bot_A to 3.91e+00
# Done ramping
# Ramping V_bot_A to 3.91e+00
# Done ramping
# Ramping V_bot_A to 3.92e+00
# Done ramping
# Ramping V_bot_A to 3.92e+00
# Done ramping
# Ramping V_bot_A to 3.93e+00
# Done ramping
# Ramping V_bot_A to 3.93e+00
# Done ramping
# Ramping V_bot_A to 3.94e+00
# Done ramping
# Ramping V_bot_A to 3.94e+00
# Done ramping
# Ramping V_bot_A to 3.95e+00
# Done ramping
# Ramping V_bot_A to 3.95e+00
# Done ramping
# Ramping V_bot_A to 3.96e+00
# Done ramping
# Ramping V_bot_A to 3.96e+00
# Done ramping
# Ramping V_bot_A to 3.97e+00
# Done ramping
# Ramping V_bot_A to 3.97e+00
# Done ramping
# Ramping V_bot_A to 3.98e+00
# Done ramping
# Ramping V_bot_A to 3.98e+00
# Done ramping
# Ramping V_bot_A to 3.99e+00
# Done ramping
# Ramping V_bot_A to 3.99e+00
# Done ramping
# Ramping V_bot_A to 4.00e+00
# Done ramping
# Ramping V_bot_A to 4.00e+00
# Done ramping
# Ramping V_bot_A to 4.01e+00
# Done ramping
# Ramping V_bot_A to 4.01e+00
# Done ramping
# Ramping V_bot_A to 4.02e+00
# Done ramping
# Ramping V_bot_A to 4.02e+00
# Done ramping
# Ramping V_bot_A to 4.03e+00
# Done ramping
# Ramping V_bot_A to 4.03e+00
# Done ramping
# Ramping V_bot_A to 4.04e+00
# Done ramping
# Ramping V_bot_A to 4.04e+00
# Done ramping
# Ramping V_bot_A to 4.05e+00
# Done ramping
# Ramping V_bot_A to 4.05e+00
# Done ramping
# Ramping V_bot_A to 4.06e+00
# Done ramping
# Ramping V_bot_A to 4.06e+00
# Done ramping
# Ramping V_bot_A to 4.07e+00
# Done ramping
# Ramping V_bot_A to 4.07e+00
# Done ramping
# Ramping V_bot_A to 4.08e+00
# Done ramping
# Ramping V_bot_A to 4.08e+00
# Done ramping
# Ramping V_bot_A to 4.09e+00
# Done ramping
# Ramping V_bot_A to 4.09e+00
# Done ramping
# Ramping V_bot_A to 4.10e+00
# Done ramping
# Ramping V_bot_A to 4.10e+00
# Done ramping
# Ramping V_bot_A to 4.11e+00
# Done ramping
# Ramping V_bot_A to 4.11e+00
# Done ramping
# Ramping V_bot_A to 4.12e+00
# Done ramping
# Ramping V_bot_A to 4.12e+00
# Done ramping
# Ramping V_bot_A to 4.13e+00
# Done ramping
# Ramping V_bot_A to 4.13e+00
# Done ramping
# Ramping V_bot_A to 4.14e+00
# Done ramping
# Ramping V_bot_A to 4.14e+00
# Done ramping
# Ramping V_bot_A to 4.15e+00
# Done ramping
# Ramping V_bot_A to 4.15e+00
# Done ramping
# Ramping V_bot_A to 4.16e+00
# Done ramping
# Ramping V_bot_A to 4.16e+00
# Done ramping
# Ramping V_bot_A to 4.17e+00
# Done ramping
# Ramping V_bot_A to 4.17e+00
# Done ramping
# Ramping V_bot_A to 4.18e+00
# Done ramping
# Ramping V_bot_A to 4.18e+00
# Done ramping
# Ramping V_bot_A to 4.19e+00
# Done ramping
# Ramping V_bot_A to 4.19e+00
# Done ramping
# Ramping V_bot_A to 4.20e+00
# Done ramping
# Ramping V_bot_A to 4.20e+00
# Done ramping
# Ramping V_bot_A to 4.21e+00
# Done ramping
# Ramping V_bot_A to 4.21e+00
# Done ramping
# Ramping V_bot_A to 4.22e+00
# Done ramping
# Ramping V_bot_A to 4.22e+00
# Done ramping
# Ramping V_bot_A to 4.23e+00
# Done ramping
# Ramping V_bot_A to 4.23e+00
# Done ramping
# Ramping V_bot_A to 4.24e+00
# Done ramping
# Ramping V_bot_A to 4.24e+00
# Done ramping
# Ramping V_bot_A to 4.25e+00
# Done ramping
# Ramping V_bot_A to 4.25e+00
# Done ramping
# Ramping V_bot_A to 4.26e+00
# Done ramping
# Ramping V_bot_A to 4.26e+00
# Done ramping
# Ramping V_bot_A to 4.27e+00
# Done ramping
# Ramping V_bot_A to 4.27e+00
# Done ramping
# Ramping V_bot_A to 4.28e+00
# Done ramping
# Ramping V_bot_A to 4.28e+00
# Done ramping
# Ramping V_bot_A to 4.29e+00
# Done ramping
# Ramping V_bot_A to 4.29e+00
# Done ramping
# Ramping V_bot_A to 4.30e+00
# Done ramping
# Ramping V_bot_A to 4.30e+00
# Done ramping
# Ramping V_bot_A to 4.31e+00
# Done ramping
# Ramping V_bot_A to 4.31e+00
# Done ramping
# Ramping V_bot_A to 4.32e+00
# Done ramping
# Ramping V_bot_A to 4.32e+00
# Done ramping
# Ramping V_bot_A to 4.33e+00
# Done ramping
# Ramping V_bot_A to 4.33e+00
# Done ramping
# Ramping V_bot_A to 4.34e+00
# Done ramping
# Ramping V_bot_A to 4.34e+00
# Done ramping
# Ramping V_bot_A to 4.35e+00
# Done ramping
# Ramping V_bot_A to 4.35e+00
# Done ramping
# Ramping V_bot_A to 4.36e+00
# Done ramping
# Ramping V_bot_A to 4.36e+00
# Done ramping
# Ramping V_bot_A to 4.37e+00
# Done ramping
# Ramping V_bot_A to 4.37e+00
# Done ramping
# Ramping V_bot_A to 4.38e+00
# Done ramping
# Ramping V_bot_A to 4.38e+00
# Done ramping
# Ramping V_bot_A to 4.39e+00
# Done ramping
# Ramping V_bot_A to 4.39e+00
# Done ramping
# Ramping V_bot_A to 4.40e+00
# Done ramping
# Ramping V_bot_A to 4.40e+00
# Done ramping
# Ramping V_bot_A to 4.41e+00
# Done ramping
# Ramping V_bot_A to 4.41e+00
# Done ramping
# Ramping V_bot_A to 4.42e+00
# Done ramping
# Ramping V_bot_A to 4.42e+00
# Done ramping
# Ramping V_bot_A to 4.43e+00
# Done ramping
# Ramping V_bot_A to 4.43e+00
# Done ramping
# Ramping V_bot_A to 4.44e+00
# Done ramping
# Ramping V_bot_A to 4.44e+00
# Done ramping
# Ramping V_bot_A to 4.45e+00
# Done ramping
# Ramping V_bot_A to 4.45e+00
# Done ramping
# Ramping V_bot_A to 4.46e+00
# Done ramping
# Ramping V_bot_A to 4.46e+00
# Done ramping
# Ramping V_bot_A to 4.47e+00
# Done ramping
# Ramping V_bot_A to 4.47e+00
# Done ramping
# Ramping V_bot_A to 4.48e+00
# Done ramping
# Ramping V_bot_A to 4.48e+00
# Done ramping
# Ramping V_bot_A to 4.49e+00
# Done ramping
# Ramping V_bot_A to 4.49e+00
# Done ramping
#  Time elapsed: 3613.0332

# %%
for resonator in MDAC_channels:
    for gate in MDAC_channels[resonator]:
        print(resonator, gate)
        print(MDAC_channels[resonator][gate].voltage())
        ramp(MDAC_channels[resonator][gate].voltage, 0, step_size=1e-3, delay=0.001)
# Out:
# A V_pl_A
# 1.990003
# A V_cut_A
# 1.989997
# A V_pr_A
# 1.99
# A V_bot_A
# 1.989996
# B V_pl_B
# -0.7839972
# B V_cut_B
# -0.7839957
# B V_pr_B
# -0.7839989
# B V_bot_B
# 0.0
# C V_pl_C
# 0.0
# C V_cut_C
# 0.0
# C V_pr_C
# 0.0
# C V_bot_C
# 0.0
# D V_pl_D
# 0.0
# D V_pr_D
# 0.0
# D V_bot_D
# 0.0

# %%
vna.S21.bandwidth(1000)

# %%
power = -3
n_pts = 100
n_avg = 200
f = f_readouts[2]
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

resonator='A'
gate_voltages = np.arange(0,4.5,0.005)
#set the Bfield. 
#set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d B=%.2e" %(f, power, n_pts, n_avg, get_yoko_field())  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False
back_ramp_value = 2.5

#ramp all gates of resonator X
ramp(MDAC_channels[resonator]['V_bot_A'].voltage,1,1e-3,0.01)
ramp(MDAC_channels[resonator]['V_pr_A'].voltage,1,1e-3,0.01)
ramp(MDAC_channels[resonator]['V_pl_A'].voltage,1,1e-3,0.01)
gate_names = ['V_pr_B']
gate_channels=[MDAC_channels['B'][gate_names[0]]]



if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, back_ramp_value, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=100, channel_name='S21')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_single_frequency(gate_channels, gate_voltages,gate_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# Taking single sweep
# Starting experimental run with id: 45
# Taking trace took 6.357778787612915
# <MDACChannel: MDAC_chan11 of MDAC: MDAC> 0.0
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# STARTING TEMPERATURE: 0.024
# Starting experimental run with id: 46
# Ramping V_pr_B to 0.00e+00
# Done ramping
# Ramping V_pr_B to 5.00e-03
# Done ramping
# Ramping V_pr_B to 1.00e-02
# Done ramping
# Ramping V_pr_B to 1.50e-02
# Done ramping
# Ramping V_pr_B to 2.00e-02
# Done ramping
# Ramping V_pr_B to 2.50e-02
# Done ramping
# Ramping V_pr_B to 3.00e-02
# Done ramping
# Ramping V_pr_B to 3.50e-02
# Done ramping
# Ramping V_pr_B to 4.00e-02
# Done ramping
# Ramping V_pr_B to 4.50e-02
# Done ramping
# Ramping V_pr_B to 5.00e-02
# Done ramping
# Ramping V_pr_B to 5.50e-02
# Done ramping
# Ramping V_pr_B to 6.00e-02
# Done ramping
# Ramping V_pr_B to 6.50e-02
# Done ramping
# Ramping V_pr_B to 7.00e-02
# Done ramping
# Ramping V_pr_B to 7.50e-02
# Done ramping
# Ramping V_pr_B to 8.00e-02
# Done ramping
# Ramping V_pr_B to 8.50e-02
# Done ramping
# Ramping V_pr_B to 9.00e-02
# Done ramping
# Ramping V_pr_B to 9.50e-02
# Done ramping
# Ramping V_pr_B to 1.00e-01
# Done ramping
# Ramping V_pr_B to 1.05e-01
# Done ramping
# Ramping V_pr_B to 1.10e-01
# Done ramping
# Ramping V_pr_B to 1.15e-01
# Done ramping
# Ramping V_pr_B to 1.20e-01
# Done ramping
# Ramping V_pr_B to 1.25e-01
# Done ramping
# Ramping V_pr_B to 1.30e-01
# Done ramping
# Ramping V_pr_B to 1.35e-01
# Done ramping
# Ramping V_pr_B to 1.40e-01
# Done ramping
# Ramping V_pr_B to 1.45e-01
# Done ramping
# Ramping V_pr_B to 1.50e-01
# Done ramping
# Ramping V_pr_B to 1.55e-01
# Done ramping
# Ramping V_pr_B to 1.60e-01
# Done ramping
# Ramping V_pr_B to 1.65e-01
# Done ramping
# Ramping V_pr_B to 1.70e-01
# Done ramping
# Ramping V_pr_B to 1.75e-01
# Done ramping
# Ramping V_pr_B to 1.80e-01
# Done ramping
# Ramping V_pr_B to 1.85e-01
# Done ramping
# Ramping V_pr_B to 1.90e-01
# Done ramping
# Ramping V_pr_B to 1.95e-01
# Done ramping
# Ramping V_pr_B to 2.00e-01
# Done ramping
# Ramping V_pr_B to 2.05e-01
# Done ramping
# Ramping V_pr_B to 2.10e-01
# Done ramping
# Ramping V_pr_B to 2.15e-01
# Done ramping
# Ramping V_pr_B to 2.20e-01
# Done ramping
# Ramping V_pr_B to 2.25e-01
# Done ramping
# Ramping V_pr_B to 2.30e-01
# Done ramping
# Ramping V_pr_B to 2.35e-01
# Done ramping
# Ramping V_pr_B to 2.40e-01
# Done ramping
# Ramping V_pr_B to 2.45e-01
# Done ramping
# Ramping V_pr_B to 2.50e-01
# Done ramping
# Ramping V_pr_B to 2.55e-01
# Done ramping
# Ramping V_pr_B to 2.60e-01
# Done ramping
# Ramping V_pr_B to 2.65e-01
# Done ramping
# Ramping V_pr_B to 2.70e-01
# Done ramping
# Ramping V_pr_B to 2.75e-01
# Done ramping
# Ramping V_pr_B to 2.80e-01
# Done ramping
# Ramping V_pr_B to 2.85e-01
# Done ramping
# Ramping V_pr_B to 2.90e-01
# Done ramping
# Ramping V_pr_B to 2.95e-01
# Done ramping
# Ramping V_pr_B to 3.00e-01
# Done ramping
# Ramping V_pr_B to 3.05e-01
# Done ramping
# Ramping V_pr_B to 3.10e-01
# Done ramping
# Ramping V_pr_B to 3.15e-01
# Done ramping
# Ramping V_pr_B to 3.20e-01
# Done ramping
# Ramping V_pr_B to 3.25e-01
# Done ramping
# Ramping V_pr_B to 3.30e-01
# Done ramping
# Ramping V_pr_B to 3.35e-01
# Done ramping
# Ramping V_pr_B to 3.40e-01
# Done ramping
# Ramping V_pr_B to 3.45e-01
# Done ramping
# Ramping V_pr_B to 3.50e-01
# Done ramping
# Ramping V_pr_B to 3.55e-01
# Done ramping
# Ramping V_pr_B to 3.60e-01
# Done ramping
# Ramping V_pr_B to 3.65e-01
# Done ramping
# Ramping V_pr_B to 3.70e-01
# Done ramping
# Ramping V_pr_B to 3.75e-01
# Done ramping
# Ramping V_pr_B to 3.80e-01
# Done ramping
# Ramping V_pr_B to 3.85e-01
# Done ramping
# Ramping V_pr_B to 3.90e-01
# Done ramping
# Ramping V_pr_B to 3.95e-01
# Done ramping
# Ramping V_pr_B to 4.00e-01
# Done ramping
# Ramping V_pr_B to 4.05e-01
# Done ramping
# Ramping V_pr_B to 4.10e-01
# Done ramping
# Ramping V_pr_B to 4.15e-01
# Done ramping
# Ramping V_pr_B to 4.20e-01
# Done ramping
# Ramping V_pr_B to 4.25e-01
# Done ramping
# Ramping V_pr_B to 4.30e-01
# Done ramping
# Ramping V_pr_B to 4.35e-01
# Done ramping
# Ramping V_pr_B to 4.40e-01
# Done ramping
# Ramping V_pr_B to 4.45e-01
# Done ramping
# Ramping V_pr_B to 4.50e-01
# Done ramping
# Ramping V_pr_B to 4.55e-01
# Done ramping
# Ramping V_pr_B to 4.60e-01
# Done ramping
# Ramping V_pr_B to 4.65e-01
# Done ramping
# Ramping V_pr_B to 4.70e-01
# Done ramping
# Ramping V_pr_B to 4.75e-01
# Done ramping
# Ramping V_pr_B to 4.80e-01
# Done ramping
# Ramping V_pr_B to 4.85e-01
# Done ramping
# Ramping V_pr_B to 4.90e-01
# Done ramping
# Ramping V_pr_B to 4.95e-01
# Done ramping
# Ramping V_pr_B to 5.00e-01
# Done ramping
# Ramping V_pr_B to 5.05e-01
# Done ramping
# Ramping V_pr_B to 5.10e-01
# Done ramping
# Ramping V_pr_B to 5.15e-01
# Done ramping
# Ramping V_pr_B to 5.20e-01
# Done ramping
# Ramping V_pr_B to 5.25e-01
# Done ramping
# Ramping V_pr_B to 5.30e-01
# Done ramping
# Ramping V_pr_B to 5.35e-01
# Done ramping
# Ramping V_pr_B to 5.40e-01
# Done ramping
# Ramping V_pr_B to 5.45e-01
# Done ramping
# Ramping V_pr_B to 5.50e-01
# Done ramping
# Ramping V_pr_B to 5.55e-01
# Done ramping
# Ramping V_pr_B to 5.60e-01
# Done ramping
# Ramping V_pr_B to 5.65e-01
# Done ramping
# Ramping V_pr_B to 5.70e-01
# Done ramping
# Ramping V_pr_B to 5.75e-01
# Done ramping
# Ramping V_pr_B to 5.80e-01
# Done ramping
# Ramping V_pr_B to 5.85e-01
# Done ramping
# Ramping V_pr_B to 5.90e-01
# Done ramping
# Ramping V_pr_B to 5.95e-01
# Done ramping
# Ramping V_pr_B to 6.00e-01
# Done ramping
# Ramping V_pr_B to 6.05e-01
# Done ramping
# Ramping V_pr_B to 6.10e-01
# Done ramping
# Ramping V_pr_B to 6.15e-01
# Done ramping
# Ramping V_pr_B to 6.20e-01
# Done ramping
# Ramping V_pr_B to 6.25e-01
# Done ramping
# Ramping V_pr_B to 6.30e-01
# Done ramping
# Ramping V_pr_B to 6.35e-01
# Done ramping
# Ramping V_pr_B to 6.40e-01
# Done ramping
# Ramping V_pr_B to 6.45e-01
# Done ramping
# Ramping V_pr_B to 6.50e-01
# Done ramping
# Ramping V_pr_B to 6.55e-01
# Done ramping
# Ramping V_pr_B to 6.60e-01
# Done ramping
# Ramping V_pr_B to 6.65e-01
# Done ramping
# Ramping V_pr_B to 6.70e-01
# Done ramping
# Ramping V_pr_B to 6.75e-01
# Done ramping
# Ramping V_pr_B to 6.80e-01
# Done ramping
# Ramping V_pr_B to 6.85e-01
# Done ramping
# Ramping V_pr_B to 6.90e-01
# Done ramping
# Ramping V_pr_B to 6.95e-01
# Done ramping
# Ramping V_pr_B to 7.00e-01
# Done ramping
# Ramping V_pr_B to 7.05e-01
# Done ramping
# Ramping V_pr_B to 7.10e-01
# Done ramping
# Ramping V_pr_B to 7.15e-01
# Done ramping
# Ramping V_pr_B to 7.20e-01
# Done ramping
# Ramping V_pr_B to 7.25e-01
# Done ramping
# Ramping V_pr_B to 7.30e-01
# Done ramping
# Ramping V_pr_B to 7.35e-01
# Done ramping
# Ramping V_pr_B to 7.40e-01
# Done ramping
# Ramping V_pr_B to 7.45e-01
# Done ramping
# Ramping V_pr_B to 7.50e-01
# Done ramping
# Ramping V_pr_B to 7.55e-01
# Done ramping
# Ramping V_pr_B to 7.60e-01
# Done ramping
# Ramping V_pr_B to 7.65e-01
# Done ramping
# Ramping V_pr_B to 7.70e-01
# Done ramping
# Ramping V_pr_B to 7.75e-01
# Done ramping
# Ramping V_pr_B to 7.80e-01
# Done ramping
# Ramping V_pr_B to 7.85e-01
# Done ramping
# Ramping V_pr_B to 7.90e-01
# Done ramping
# Ramping V_pr_B to 7.95e-01
# Done ramping
# Ramping V_pr_B to 8.00e-01
# Done ramping
# Ramping V_pr_B to 8.05e-01
# Done ramping
# Ramping V_pr_B to 8.10e-01
# Done ramping
# Ramping V_pr_B to 8.15e-01
# Done ramping
# Ramping V_pr_B to 8.20e-01
# Done ramping
# Ramping V_pr_B to 8.25e-01
# Done ramping
# Ramping V_pr_B to 8.30e-01
# Done ramping
# Ramping V_pr_B to 8.35e-01
# Done ramping
# Ramping V_pr_B to 8.40e-01
# Done ramping
# Ramping V_pr_B to 8.45e-01
# Done ramping
# Ramping V_pr_B to 8.50e-01
# Done ramping
# Ramping V_pr_B to 8.55e-01
# Done ramping
# Ramping V_pr_B to 8.60e-01
# Done ramping
# Ramping V_pr_B to 8.65e-01
# Done ramping
# Ramping V_pr_B to 8.70e-01
# Done ramping
# Ramping V_pr_B to 8.75e-01
# Done ramping
# Ramping V_pr_B to 8.80e-01
# Done ramping
# Ramping V_pr_B to 8.85e-01
# Done ramping
# Ramping V_pr_B to 8.90e-01
# Done ramping
# Ramping V_pr_B to 8.95e-01
# Done ramping
# Ramping V_pr_B to 9.00e-01
# Done ramping
# Ramping V_pr_B to 9.05e-01
# Done ramping
# Ramping V_pr_B to 9.10e-01
# Done ramping
# Ramping V_pr_B to 9.15e-01
# Done ramping
# Ramping V_pr_B to 9.20e-01
# Done ramping
# Ramping V_pr_B to 9.25e-01
# Done ramping
# Ramping V_pr_B to 9.30e-01
# Done ramping
# Ramping V_pr_B to 9.35e-01
# Done ramping
# Ramping V_pr_B to 9.40e-01
# Done ramping
# Ramping V_pr_B to 9.45e-01
# Done ramping
# Ramping V_pr_B to 9.50e-01
# Done ramping
# Ramping V_pr_B to 9.55e-01
# Done ramping
# Ramping V_pr_B to 9.60e-01
# Done ramping
# Ramping V_pr_B to 9.65e-01
# Done ramping
# Ramping V_pr_B to 9.70e-01
# Done ramping
# Ramping V_pr_B to 9.75e-01
# Done ramping
# Ramping V_pr_B to 9.80e-01
# Done ramping
# Ramping V_pr_B to 9.85e-01
# Done ramping
# Ramping V_pr_B to 9.90e-01
# Done ramping
# Ramping V_pr_B to 9.95e-01
# Done ramping
# Ramping V_pr_B to 1.00e+00
# Done ramping
# Ramping V_pr_B to 1.01e+00
# Done ramping
# Ramping V_pr_B to 1.01e+00
# Done ramping
# Ramping V_pr_B to 1.02e+00
# Done ramping
# Ramping V_pr_B to 1.02e+00
# Done ramping
# Ramping V_pr_B to 1.02e+00
# Done ramping
# Ramping V_pr_B to 1.03e+00
# Done ramping
# Ramping V_pr_B to 1.03e+00
# Done ramping
# Ramping V_pr_B to 1.04e+00
# Done ramping
# Ramping V_pr_B to 1.04e+00
# Done ramping
# Ramping V_pr_B to 1.05e+00
# Done ramping
# Ramping V_pr_B to 1.05e+00
# Done ramping
# Ramping V_pr_B to 1.06e+00
# Done ramping
# Ramping V_pr_B to 1.06e+00
# Done ramping
# Ramping V_pr_B to 1.07e+00
# Done ramping
# Ramping V_pr_B to 1.07e+00
# Done ramping
# Ramping V_pr_B to 1.08e+00
# Done ramping
# Ramping V_pr_B to 1.08e+00
# Done ramping
# Ramping V_pr_B to 1.09e+00
# Done ramping
# Ramping V_pr_B to 1.09e+00
# Done ramping
# Ramping V_pr_B to 1.10e+00
# Done ramping
# Ramping V_pr_B to 1.10e+00
# Done ramping
# Ramping V_pr_B to 1.11e+00
# Done ramping
# Ramping V_pr_B to 1.11e+00
# Done ramping
# Ramping V_pr_B to 1.12e+00
# Done ramping
# Ramping V_pr_B to 1.12e+00
# Done ramping
# Ramping V_pr_B to 1.13e+00
# Done ramping
# Ramping V_pr_B to 1.14e+00
# Done ramping
# Ramping V_pr_B to 1.14e+00
# Done ramping
# Ramping V_pr_B to 1.15e+00
# Done ramping
# Ramping V_pr_B to 1.15e+00
# Done ramping
# Ramping V_pr_B to 1.16e+00
# Done ramping
# Ramping V_pr_B to 1.16e+00
# Done ramping
# Ramping V_pr_B to 1.17e+00
# Done ramping
# Ramping V_pr_B to 1.17e+00
# Done ramping
# Ramping V_pr_B to 1.18e+00
# Done ramping
# Ramping V_pr_B to 1.18e+00
# Done ramping
# Ramping V_pr_B to 1.19e+00
# Done ramping
# Ramping V_pr_B to 1.19e+00
# Done ramping
# Ramping V_pr_B to 1.20e+00
# Done ramping
# Ramping V_pr_B to 1.20e+00
# Done ramping
# Ramping V_pr_B to 1.21e+00
# Done ramping
# Ramping V_pr_B to 1.21e+00
# Done ramping
# Ramping V_pr_B to 1.22e+00
# Done ramping
# Ramping V_pr_B to 1.22e+00
# Done ramping
# Ramping V_pr_B to 1.23e+00
# Done ramping
# Ramping V_pr_B to 1.23e+00
# Done ramping
# Ramping V_pr_B to 1.24e+00
# Done ramping
# Ramping V_pr_B to 1.24e+00
# Done ramping
# Ramping V_pr_B to 1.25e+00
# Done ramping
# Ramping V_pr_B to 1.25e+00
# Done ramping
# Ramping V_pr_B to 1.26e+00
# Done ramping
# Ramping V_pr_B to 1.26e+00
# Done ramping
# Ramping V_pr_B to 1.27e+00
# Done ramping
# Ramping V_pr_B to 1.27e+00
# Done ramping
# Ramping V_pr_B to 1.28e+00
# Done ramping
# Ramping V_pr_B to 1.28e+00
# Done ramping
# Ramping V_pr_B to 1.28e+00
# Done ramping
# Ramping V_pr_B to 1.29e+00
# Done ramping
# Ramping V_pr_B to 1.29e+00
# Done ramping
# Ramping V_pr_B to 1.30e+00
# Done ramping
# Ramping V_pr_B to 1.30e+00
# Done ramping
# Ramping V_pr_B to 1.31e+00
# Done ramping
# Ramping V_pr_B to 1.31e+00
# Done ramping
# Ramping V_pr_B to 1.32e+00
# Done ramping
# Ramping V_pr_B to 1.32e+00
# Done ramping
# Ramping V_pr_B to 1.33e+00
# Done ramping
# Ramping V_pr_B to 1.33e+00
# Done ramping
# Ramping V_pr_B to 1.34e+00
# Done ramping
# Ramping V_pr_B to 1.34e+00
# Done ramping
# Ramping V_pr_B to 1.35e+00
# Done ramping
# Ramping V_pr_B to 1.35e+00
# Done ramping
# Ramping V_pr_B to 1.36e+00
# Done ramping
# Ramping V_pr_B to 1.36e+00
# Done ramping
# Ramping V_pr_B to 1.37e+00
# Done ramping
# Ramping V_pr_B to 1.38e+00
# Done ramping
# Ramping V_pr_B to 1.38e+00
# Done ramping
# Ramping V_pr_B to 1.39e+00
# Done ramping
# Ramping V_pr_B to 1.39e+00
# Done ramping
# Ramping V_pr_B to 1.40e+00
# Done ramping
# Ramping V_pr_B to 1.40e+00
# Done ramping
# Ramping V_pr_B to 1.41e+00
# Done ramping
# Ramping V_pr_B to 1.41e+00
# Done ramping
# Ramping V_pr_B to 1.42e+00
# Done ramping
# Ramping V_pr_B to 1.42e+00
# Done ramping
# Ramping V_pr_B to 1.43e+00
# Done ramping
# Ramping V_pr_B to 1.43e+00
# Done ramping
# Ramping V_pr_B to 1.44e+00
# Done ramping
# Ramping V_pr_B to 1.44e+00
# Done ramping
# Ramping V_pr_B to 1.45e+00
# Done ramping
# Ramping V_pr_B to 1.45e+00
# Done ramping
# Ramping V_pr_B to 1.46e+00
# Done ramping
# Ramping V_pr_B to 1.46e+00
# Done ramping
# Ramping V_pr_B to 1.47e+00
# Done ramping
# Ramping V_pr_B to 1.47e+00
# Done ramping
# Ramping V_pr_B to 1.48e+00
# Done ramping
# Ramping V_pr_B to 1.48e+00
# Done ramping
# Ramping V_pr_B to 1.49e+00
# Done ramping
# Ramping V_pr_B to 1.49e+00
# Done ramping
# Ramping V_pr_B to 1.50e+00
# Done ramping
# Ramping V_pr_B to 1.50e+00
# Done ramping
# Ramping V_pr_B to 1.51e+00
# Done ramping
# Ramping V_pr_B to 1.51e+00
# Done ramping
# Ramping V_pr_B to 1.52e+00
# Done ramping
# Ramping V_pr_B to 1.52e+00
# Done ramping
# Ramping V_pr_B to 1.53e+00
# Done ramping
# Ramping V_pr_B to 1.53e+00
# Done ramping
# Ramping V_pr_B to 1.54e+00
# Done ramping
# Ramping V_pr_B to 1.54e+00
# Done ramping
# Ramping V_pr_B to 1.54e+00
# Done ramping
# Ramping V_pr_B to 1.55e+00
# Done ramping
# Ramping V_pr_B to 1.55e+00
# Done ramping
# Ramping V_pr_B to 1.56e+00
# Done ramping
# Ramping V_pr_B to 1.56e+00
# Done ramping
# Ramping V_pr_B to 1.57e+00
# Done ramping
# Ramping V_pr_B to 1.57e+00
# Done ramping
# Ramping V_pr_B to 1.58e+00
# Done ramping
# Ramping V_pr_B to 1.58e+00
# Done ramping
# Ramping V_pr_B to 1.59e+00
# Done ramping
# Ramping V_pr_B to 1.59e+00
# Done ramping
# Ramping V_pr_B to 1.60e+00
# Done ramping
# Ramping V_pr_B to 1.60e+00
# Done ramping
# Ramping V_pr_B to 1.61e+00
# Done ramping
# Ramping V_pr_B to 1.61e+00
# Done ramping
# Ramping V_pr_B to 1.62e+00
# Done ramping
# Ramping V_pr_B to 1.62e+00
# Done ramping
# Ramping V_pr_B to 1.63e+00
# Done ramping
# Ramping V_pr_B to 1.64e+00
# Done ramping
# Ramping V_pr_B to 1.64e+00
# Done ramping
# Ramping V_pr_B to 1.65e+00
# Done ramping
# Ramping V_pr_B to 1.65e+00
# Done ramping
# Ramping V_pr_B to 1.66e+00
# Done ramping
# Ramping V_pr_B to 1.66e+00
# Done ramping
# Ramping V_pr_B to 1.67e+00
# Done ramping
# Ramping V_pr_B to 1.67e+00
# Done ramping
# Ramping V_pr_B to 1.68e+00
# Done ramping
# Ramping V_pr_B to 1.68e+00
# Done ramping
# Ramping V_pr_B to 1.69e+00
# Done ramping
# Ramping V_pr_B to 1.69e+00
# Done ramping
# Ramping V_pr_B to 1.70e+00
# Done ramping
# Ramping V_pr_B to 1.70e+00
# Done ramping
# Ramping V_pr_B to 1.71e+00
# Done ramping
# Ramping V_pr_B to 1.71e+00
# Done ramping
# Ramping V_pr_B to 1.72e+00
# Done ramping
# Ramping V_pr_B to 1.72e+00
# Done ramping
# Ramping V_pr_B to 1.73e+00
# Done ramping
# Ramping V_pr_B to 1.73e+00
# Done ramping
# Ramping V_pr_B to 1.74e+00
# Done ramping
# Ramping V_pr_B to 1.74e+00
# Done ramping
# Ramping V_pr_B to 1.75e+00
# Done ramping
# Ramping V_pr_B to 1.75e+00
# Done ramping
# Ramping V_pr_B to 1.76e+00
# Done ramping
# Ramping V_pr_B to 1.76e+00
# Done ramping
# Ramping V_pr_B to 1.77e+00
# Done ramping
# Ramping V_pr_B to 1.77e+00
# Done ramping
# Ramping V_pr_B to 1.78e+00
# Done ramping
# Ramping V_pr_B to 1.78e+00
# Done ramping
# Ramping V_pr_B to 1.79e+00
# Done ramping
# Ramping V_pr_B to 1.79e+00
# Done ramping
# Ramping V_pr_B to 1.79e+00
# Done ramping
# Ramping V_pr_B to 1.80e+00
# Done ramping
# Ramping V_pr_B to 1.80e+00
# Done ramping
# Ramping V_pr_B to 1.81e+00
# Done ramping
# Ramping V_pr_B to 1.81e+00
# Done ramping
# Ramping V_pr_B to 1.82e+00
# Done ramping
# Ramping V_pr_B to 1.82e+00
# Done ramping
# Ramping V_pr_B to 1.83e+00
# Done ramping
# Ramping V_pr_B to 1.83e+00
# Done ramping
# Ramping V_pr_B to 1.84e+00
# Done ramping
# Ramping V_pr_B to 1.84e+00
# Done ramping
# Ramping V_pr_B to 1.85e+00
# Done ramping
# Ramping V_pr_B to 1.85e+00
# Done ramping
# Ramping V_pr_B to 1.86e+00
# Done ramping
# Ramping V_pr_B to 1.86e+00
# Done ramping
# Ramping V_pr_B to 1.87e+00
# Done ramping
# Ramping V_pr_B to 1.88e+00
# Done ramping
# Ramping V_pr_B to 1.88e+00
# Done ramping
# Ramping V_pr_B to 1.89e+00
# Done ramping
# Ramping V_pr_B to 1.89e+00
# Done ramping
# Ramping V_pr_B to 1.90e+00
# Done ramping
# Ramping V_pr_B to 1.90e+00
# Done ramping
# Ramping V_pr_B to 1.91e+00
# Done ramping
# Ramping V_pr_B to 1.91e+00
# Done ramping
# Ramping V_pr_B to 1.92e+00
# Done ramping
# Ramping V_pr_B to 1.92e+00
# Done ramping
# Ramping V_pr_B to 1.93e+00
# Done ramping
# Ramping V_pr_B to 1.93e+00
# Done ramping
# Ramping V_pr_B to 1.94e+00
# Done ramping
# Ramping V_pr_B to 1.94e+00
# Done ramping
# Ramping V_pr_B to 1.95e+00
# Done ramping
# Ramping V_pr_B to 1.95e+00
# Done ramping
# Ramping V_pr_B to 1.96e+00
# Done ramping
# Ramping V_pr_B to 1.96e+00
# Done ramping
# Ramping V_pr_B to 1.97e+00
# Done ramping
# Ramping V_pr_B to 1.97e+00
# Done ramping
# Ramping V_pr_B to 1.98e+00
# Done ramping
# Ramping V_pr_B to 1.98e+00
# Done ramping
# Ramping V_pr_B to 1.99e+00
# Done ramping
# Ramping V_pr_B to 1.99e+00
# Done ramping
# Ramping V_pr_B to 2.00e+00
# Done ramping
# Ramping V_pr_B to 2.00e+00
# Done ramping
# Ramping V_pr_B to 2.00e+00
# Done ramping
# Ramping V_pr_B to 2.01e+00
# Done ramping
# Ramping V_pr_B to 2.02e+00
# Done ramping
# Ramping V_pr_B to 2.02e+00
# Done ramping
# Ramping V_pr_B to 2.02e+00
# Done ramping
# Ramping V_pr_B to 2.03e+00
# Done ramping
# Ramping V_pr_B to 2.04e+00
# Done ramping
# Ramping V_pr_B to 2.04e+00
# Done ramping
# Ramping V_pr_B to 2.04e+00
# Done ramping
# Ramping V_pr_B to 2.05e+00
# Done ramping
# Ramping V_pr_B to 2.06e+00
# Done ramping
# Ramping V_pr_B to 2.06e+00
# Done ramping
# Ramping V_pr_B to 2.06e+00
# Done ramping
# Ramping V_pr_B to 2.07e+00
# Done ramping
# Ramping V_pr_B to 2.08e+00
# Done ramping
# Ramping V_pr_B to 2.08e+00
# Done ramping
# Ramping V_pr_B to 2.08e+00
# Done ramping
# Ramping V_pr_B to 2.09e+00
# Done ramping
# Ramping V_pr_B to 2.10e+00
# Done ramping
# Ramping V_pr_B to 2.10e+00
# Done ramping
# Ramping V_pr_B to 2.10e+00
# Done ramping
# Ramping V_pr_B to 2.11e+00
# Done ramping
# Ramping V_pr_B to 2.12e+00
# Done ramping
# Ramping V_pr_B to 2.12e+00
# Done ramping
# Ramping V_pr_B to 2.12e+00
# Done ramping
# Ramping V_pr_B to 2.13e+00
# Done ramping
# Ramping V_pr_B to 2.14e+00
# Done ramping
# Ramping V_pr_B to 2.14e+00
# Done ramping
# Ramping V_pr_B to 2.15e+00
# Done ramping
# Ramping V_pr_B to 2.15e+00
# Done ramping
# Ramping V_pr_B to 2.16e+00
# Done ramping
# Ramping V_pr_B to 2.16e+00
# Done ramping
# Ramping V_pr_B to 2.17e+00
# Done ramping
# Ramping V_pr_B to 2.17e+00
# Done ramping
# Ramping V_pr_B to 2.18e+00
# Done ramping
# Ramping V_pr_B to 2.18e+00
# Done ramping
# Ramping V_pr_B to 2.19e+00
# Done ramping
# Ramping V_pr_B to 2.19e+00
# Done ramping
# Ramping V_pr_B to 2.19e+00
# Done ramping
# Ramping V_pr_B to 2.20e+00
# Done ramping
# Ramping V_pr_B to 2.21e+00
# Done ramping
# Ramping V_pr_B to 2.21e+00
# Done ramping
# Ramping V_pr_B to 2.21e+00
# Done ramping
# Ramping V_pr_B to 2.22e+00
# Done ramping
# Ramping V_pr_B to 2.23e+00
# Done ramping
# Ramping V_pr_B to 2.23e+00
# Done ramping
# Ramping V_pr_B to 2.23e+00
# Done ramping
# Ramping V_pr_B to 2.24e+00
# Done ramping
# Ramping V_pr_B to 2.25e+00
# Done ramping
# Ramping V_pr_B to 2.25e+00
# Done ramping
# Ramping V_pr_B to 2.25e+00
# Done ramping
# Ramping V_pr_B to 2.26e+00
# Done ramping
# Ramping V_pr_B to 2.27e+00
# Done ramping
# Ramping V_pr_B to 2.27e+00
# Done ramping
# Ramping V_pr_B to 2.27e+00
# Done ramping
# Ramping V_pr_B to 2.28e+00
# Done ramping
# Ramping V_pr_B to 2.29e+00
# Done ramping
# Ramping V_pr_B to 2.29e+00
# Done ramping
# Ramping V_pr_B to 2.29e+00
# Done ramping
# Ramping V_pr_B to 2.30e+00
# Done ramping
# Ramping V_pr_B to 2.31e+00
# Done ramping
# Ramping V_pr_B to 2.31e+00
# Done ramping
# Ramping V_pr_B to 2.31e+00
# Done ramping
# Ramping V_pr_B to 2.32e+00
# Done ramping
# Ramping V_pr_B to 2.33e+00
# Done ramping
# Ramping V_pr_B to 2.33e+00
# Done ramping
# Ramping V_pr_B to 2.33e+00
# Done ramping
# Ramping V_pr_B to 2.34e+00
# Done ramping
# Ramping V_pr_B to 2.35e+00
# Done ramping
# Ramping V_pr_B to 2.35e+00
# Done ramping
# Ramping V_pr_B to 2.35e+00
# Done ramping
# Ramping V_pr_B to 2.36e+00
# Done ramping
# Ramping V_pr_B to 2.37e+00
# Done ramping
# Ramping V_pr_B to 2.37e+00
# Done ramping
# Ramping V_pr_B to 2.38e+00
# Done ramping
# Ramping V_pr_B to 2.38e+00
# Done ramping
# Ramping V_pr_B to 2.39e+00
# Done ramping
# Ramping V_pr_B to 2.39e+00
# Done ramping
# Ramping V_pr_B to 2.40e+00
# Done ramping
# Ramping V_pr_B to 2.40e+00
# Done ramping
# Ramping V_pr_B to 2.41e+00
# Done ramping
# Ramping V_pr_B to 2.41e+00
# Done ramping
# Ramping V_pr_B to 2.42e+00
# Done ramping
# Ramping V_pr_B to 2.42e+00
# Done ramping
# Ramping V_pr_B to 2.43e+00
# Done ramping
# Ramping V_pr_B to 2.43e+00
# Done ramping
# Ramping V_pr_B to 2.44e+00
# Done ramping
# Ramping V_pr_B to 2.44e+00
# Done ramping
# Ramping V_pr_B to 2.44e+00
# Done ramping
# Ramping V_pr_B to 2.45e+00
# Done ramping
# Ramping V_pr_B to 2.46e+00
# Done ramping
# Ramping V_pr_B to 2.46e+00
# Done ramping
# Ramping V_pr_B to 2.46e+00
# Done ramping
# Ramping V_pr_B to 2.47e+00
# Done ramping
# Ramping V_pr_B to 2.48e+00
# Done ramping
# Ramping V_pr_B to 2.48e+00
# Done ramping
# Ramping V_pr_B to 2.48e+00
# Done ramping
# Ramping V_pr_B to 2.49e+00
# Done ramping
# Ramping V_pr_B to 2.50e+00
# Done ramping
# Ramping V_pr_B to 2.50e+00
# Done ramping
# Ramping V_pr_B to 2.50e+00
# Done ramping
# Ramping V_pr_B to 2.51e+00
# Done ramping
# Ramping V_pr_B to 2.52e+00
# Done ramping
# Ramping V_pr_B to 2.52e+00
# Done ramping
# Ramping V_pr_B to 2.52e+00
# Done ramping
# Ramping V_pr_B to 2.53e+00
# Done ramping
# Ramping V_pr_B to 2.54e+00
# Done ramping
# Ramping V_pr_B to 2.54e+00
# Done ramping
# Ramping V_pr_B to 2.54e+00
# Done ramping
# Ramping V_pr_B to 2.55e+00
# Done ramping
# Ramping V_pr_B to 2.56e+00
# Done ramping
# Ramping V_pr_B to 2.56e+00
# Done ramping
# Ramping V_pr_B to 2.56e+00
# Done ramping
# Ramping V_pr_B to 2.57e+00
# Done ramping
# Ramping V_pr_B to 2.58e+00
# Done ramping
# Ramping V_pr_B to 2.58e+00
# Done ramping
# Ramping V_pr_B to 2.58e+00
# Done ramping
# Ramping V_pr_B to 2.59e+00
# Done ramping
# Ramping V_pr_B to 2.60e+00
# Done ramping
# Ramping V_pr_B to 2.60e+00
# Done ramping
# Ramping V_pr_B to 2.60e+00
# Done ramping
# Ramping V_pr_B to 2.61e+00
# Done ramping
# Ramping V_pr_B to 2.62e+00
# Done ramping
# Ramping V_pr_B to 2.62e+00
# Done ramping
# Ramping V_pr_B to 2.62e+00
# Done ramping
# Ramping V_pr_B to 2.63e+00
# Done ramping
# Ramping V_pr_B to 2.64e+00
# Done ramping
# Ramping V_pr_B to 2.64e+00
# Done ramping
# Ramping V_pr_B to 2.65e+00
# Done ramping
# Ramping V_pr_B to 2.65e+00
# Done ramping
# Ramping V_pr_B to 2.66e+00
# Done ramping
# Ramping V_pr_B to 2.66e+00
# Done ramping
# Ramping V_pr_B to 2.67e+00
# Done ramping
# Ramping V_pr_B to 2.67e+00
# Done ramping
# Ramping V_pr_B to 2.68e+00
# Done ramping
# Ramping V_pr_B to 2.68e+00
# Done ramping
# Ramping V_pr_B to 2.69e+00
# Done ramping
# Ramping V_pr_B to 2.69e+00
# Done ramping
# Ramping V_pr_B to 2.69e+00
# Done ramping
# Ramping V_pr_B to 2.70e+00
# Done ramping
# Ramping V_pr_B to 2.71e+00
# Done ramping
# Ramping V_pr_B to 2.71e+00
# Done ramping
# Ramping V_pr_B to 2.71e+00
# Done ramping
# Ramping V_pr_B to 2.72e+00
# Done ramping
# Ramping V_pr_B to 2.73e+00
# Done ramping
# Ramping V_pr_B to 2.73e+00
# Done ramping
# Ramping V_pr_B to 2.73e+00
# Done ramping
# Ramping V_pr_B to 2.74e+00
# Done ramping
# Ramping V_pr_B to 2.75e+00
# Done ramping
# Ramping V_pr_B to 2.75e+00
# Done ramping
# Ramping V_pr_B to 2.75e+00
# Done ramping
# Ramping V_pr_B to 2.76e+00
# Done ramping
# Ramping V_pr_B to 2.77e+00
# Done ramping
# Ramping V_pr_B to 2.77e+00
# Done ramping
# Ramping V_pr_B to 2.77e+00
# Done ramping
# Ramping V_pr_B to 2.78e+00
# Done ramping
# Ramping V_pr_B to 2.79e+00
# Done ramping
# Ramping V_pr_B to 2.79e+00
# Done ramping
# Ramping V_pr_B to 2.79e+00
# Done ramping
# Ramping V_pr_B to 2.80e+00
# Done ramping
# Ramping V_pr_B to 2.81e+00
# Done ramping
# Ramping V_pr_B to 2.81e+00
# Done ramping
# Ramping V_pr_B to 2.81e+00
# Done ramping
# Ramping V_pr_B to 2.82e+00
# Done ramping
# Ramping V_pr_B to 2.83e+00
# Done ramping
# Ramping V_pr_B to 2.83e+00
# Done ramping
# Ramping V_pr_B to 2.83e+00
# Done ramping
# Ramping V_pr_B to 2.84e+00
# Done ramping
# Ramping V_pr_B to 2.85e+00
# Done ramping
# Ramping V_pr_B to 2.85e+00
# Done ramping
# Ramping V_pr_B to 2.85e+00
# Done ramping
# Ramping V_pr_B to 2.86e+00
# Done ramping
# Ramping V_pr_B to 2.87e+00
# Done ramping
# Ramping V_pr_B to 2.87e+00
# Done ramping
# Ramping V_pr_B to 2.88e+00
# Done ramping
# Ramping V_pr_B to 2.88e+00
# Done ramping
# Ramping V_pr_B to 2.89e+00
# Done ramping
# Ramping V_pr_B to 2.89e+00
# Done ramping
# Ramping V_pr_B to 2.90e+00
# Done ramping
# Ramping V_pr_B to 2.90e+00
# Done ramping
# Ramping V_pr_B to 2.91e+00
# Done ramping
# Ramping V_pr_B to 2.91e+00
# Done ramping
# Ramping V_pr_B to 2.92e+00
# Done ramping
# Ramping V_pr_B to 2.92e+00
# Done ramping
# Ramping V_pr_B to 2.93e+00
# Done ramping
# Ramping V_pr_B to 2.93e+00
# Done ramping
# Ramping V_pr_B to 2.94e+00
# Done ramping
# Ramping V_pr_B to 2.94e+00
# Done ramping
# Ramping V_pr_B to 2.94e+00
# Done ramping
# Ramping V_pr_B to 2.95e+00
# Done ramping
# Ramping V_pr_B to 2.96e+00
# Done ramping
# Ramping V_pr_B to 2.96e+00
# Done ramping
# Ramping V_pr_B to 2.96e+00
# Done ramping
# Ramping V_pr_B to 2.97e+00
# Done ramping
# Ramping V_pr_B to 2.98e+00
# Done ramping
# Ramping V_pr_B to 2.98e+00
# Done ramping
# Ramping V_pr_B to 2.98e+00
# Done ramping
# Ramping V_pr_B to 2.99e+00
# Done ramping
# Ramping V_pr_B to 3.00e+00
# Done ramping
# Ramping V_pr_B to 3.00e+00
# Done ramping
# Ramping V_pr_B to 3.00e+00
# Done ramping
# Ramping V_pr_B to 3.01e+00
# Done ramping
# Ramping V_pr_B to 3.02e+00
# Done ramping
# Ramping V_pr_B to 3.02e+00
# Done ramping
# Ramping V_pr_B to 3.02e+00
# Done ramping
# Ramping V_pr_B to 3.03e+00
# Done ramping
# Ramping V_pr_B to 3.04e+00
# Done ramping
# Ramping V_pr_B to 3.04e+00
# Done ramping
# Ramping V_pr_B to 3.04e+00
# Done ramping
# Ramping V_pr_B to 3.05e+00
# Done ramping
# Ramping V_pr_B to 3.06e+00
# Done ramping
# Ramping V_pr_B to 3.06e+00
# Done ramping
# Ramping V_pr_B to 3.06e+00
# Done ramping
# Ramping V_pr_B to 3.07e+00
# Done ramping
# Ramping V_pr_B to 3.08e+00
# Done ramping
# Ramping V_pr_B to 3.08e+00
# Done ramping
# Ramping V_pr_B to 3.08e+00
# Done ramping
# Ramping V_pr_B to 3.09e+00
# Done ramping
# Ramping V_pr_B to 3.10e+00
# Done ramping
# Ramping V_pr_B to 3.10e+00
# Done ramping
# Ramping V_pr_B to 3.10e+00
# Done ramping
# Ramping V_pr_B to 3.11e+00
# Done ramping
# Ramping V_pr_B to 3.12e+00
# Done ramping
# Ramping V_pr_B to 3.12e+00
# Done ramping
# Ramping V_pr_B to 3.12e+00
# Done ramping
# Ramping V_pr_B to 3.13e+00
# Done ramping
# Ramping V_pr_B to 3.14e+00
# Done ramping
# Ramping V_pr_B to 3.14e+00
# Done ramping
# Ramping V_pr_B to 3.15e+00
# Done ramping
# Ramping V_pr_B to 3.15e+00
# Done ramping
# Ramping V_pr_B to 3.16e+00
# Done ramping
# Ramping V_pr_B to 3.16e+00
# Done ramping
# Ramping V_pr_B to 3.17e+00
# Done ramping
# Ramping V_pr_B to 3.17e+00
# Done ramping
# Ramping V_pr_B to 3.18e+00
# Done ramping
# Ramping V_pr_B to 3.18e+00
# Done ramping
# Ramping V_pr_B to 3.19e+00
# Done ramping
# Ramping V_pr_B to 3.19e+00
# Done ramping
# Ramping V_pr_B to 3.20e+00
# Done ramping
# Ramping V_pr_B to 3.20e+00
# Done ramping
# Ramping V_pr_B to 3.21e+00
# Done ramping
# Ramping V_pr_B to 3.21e+00
# Done ramping
# Ramping V_pr_B to 3.21e+00
# Done ramping
# Ramping V_pr_B to 3.22e+00
# Done ramping
# Ramping V_pr_B to 3.23e+00
# Done ramping
# Ramping V_pr_B to 3.23e+00
# Done ramping
# Ramping V_pr_B to 3.23e+00
# Done ramping
# Ramping V_pr_B to 3.24e+00
# Done ramping
# Ramping V_pr_B to 3.25e+00
# Done ramping
# Ramping V_pr_B to 3.25e+00
# Done ramping
# Ramping V_pr_B to 3.25e+00
# Done ramping
# Ramping V_pr_B to 3.26e+00
# Done ramping
# Ramping V_pr_B to 3.27e+00
# Done ramping
# Ramping V_pr_B to 3.27e+00
# Done ramping
# Ramping V_pr_B to 3.27e+00
# Done ramping
# Ramping V_pr_B to 3.28e+00
# Done ramping
# Ramping V_pr_B to 3.29e+00
# Done ramping
# Ramping V_pr_B to 3.29e+00
# Done ramping
# Ramping V_pr_B to 3.29e+00
# Done ramping
# Ramping V_pr_B to 3.30e+00
# Done ramping
# Ramping V_pr_B to 3.31e+00
# Done ramping
# Ramping V_pr_B to 3.31e+00
# Done ramping
# Ramping V_pr_B to 3.31e+00
# Done ramping
# Ramping V_pr_B to 3.32e+00
# Done ramping
# Ramping V_pr_B to 3.33e+00
# Done ramping
# Ramping V_pr_B to 3.33e+00
# Done ramping
# Ramping V_pr_B to 3.33e+00
# Done ramping
# Ramping V_pr_B to 3.34e+00
# Done ramping
# Ramping V_pr_B to 3.35e+00
# Done ramping
# Ramping V_pr_B to 3.35e+00
# Done ramping
# Ramping V_pr_B to 3.35e+00
# Done ramping
# Ramping V_pr_B to 3.36e+00
# Done ramping
# Ramping V_pr_B to 3.37e+00
# Done ramping
# Ramping V_pr_B to 3.37e+00
# Done ramping
# Ramping V_pr_B to 3.38e+00
# Done ramping
# Ramping V_pr_B to 3.38e+00
# Done ramping
# Ramping V_pr_B to 3.39e+00
# Done ramping
# Ramping V_pr_B to 3.39e+00
# Done ramping
# Ramping V_pr_B to 3.40e+00
# Done ramping
# Ramping V_pr_B to 3.40e+00
# Done ramping
# Ramping V_pr_B to 3.41e+00
# Done ramping
# Ramping V_pr_B to 3.41e+00
# Done ramping
# Ramping V_pr_B to 3.42e+00
# Done ramping
# Ramping V_pr_B to 3.42e+00
# Done ramping
# Ramping V_pr_B to 3.43e+00
# Done ramping
# Ramping V_pr_B to 3.43e+00
# Done ramping
# Ramping V_pr_B to 3.44e+00
# Done ramping
# Ramping V_pr_B to 3.44e+00
# Done ramping
# Ramping V_pr_B to 3.45e+00
# Done ramping
# Ramping V_pr_B to 3.45e+00
# Done ramping
# Ramping V_pr_B to 3.46e+00
# Done ramping
# Ramping V_pr_B to 3.46e+00
# Done ramping
# Ramping V_pr_B to 3.46e+00
# Done ramping
# Ramping V_pr_B to 3.47e+00
# Done ramping
# Ramping V_pr_B to 3.48e+00
# Done ramping
# Ramping V_pr_B to 3.48e+00
# Done ramping
# Ramping V_pr_B to 3.48e+00
# Done ramping
# Ramping V_pr_B to 3.49e+00
# Done ramping
# Ramping V_pr_B to 3.50e+00
# Done ramping
# Ramping V_pr_B to 3.50e+00
# Done ramping
# Ramping V_pr_B to 3.50e+00
# Done ramping
# Ramping V_pr_B to 3.51e+00
# Done ramping
# Ramping V_pr_B to 3.52e+00
# Done ramping
# Ramping V_pr_B to 3.52e+00
# Done ramping
# Ramping V_pr_B to 3.52e+00
# Done ramping
# Ramping V_pr_B to 3.53e+00
# Done ramping
# Ramping V_pr_B to 3.54e+00
# Done ramping
# Ramping V_pr_B to 3.54e+00
# Done ramping
# Ramping V_pr_B to 3.54e+00
# Done ramping
# Ramping V_pr_B to 3.55e+00
# Done ramping
# Ramping V_pr_B to 3.56e+00
# Done ramping
# Ramping V_pr_B to 3.56e+00
# Done ramping
# Ramping V_pr_B to 3.56e+00
# Done ramping
# Ramping V_pr_B to 3.57e+00
# Done ramping
# Ramping V_pr_B to 3.58e+00
# Done ramping
# Ramping V_pr_B to 3.58e+00
# Done ramping
# Ramping V_pr_B to 3.58e+00
# Done ramping
# Ramping V_pr_B to 3.59e+00
# Done ramping
# Ramping V_pr_B to 3.60e+00
# Done ramping
# Ramping V_pr_B to 3.60e+00
# Done ramping
# Ramping V_pr_B to 3.60e+00
# Done ramping
# Ramping V_pr_B to 3.61e+00
# Done ramping
# Ramping V_pr_B to 3.62e+00
# Done ramping
# Ramping V_pr_B to 3.62e+00
# Done ramping
# Ramping V_pr_B to 3.62e+00
# Done ramping
# Ramping V_pr_B to 3.63e+00
# Done ramping
# Ramping V_pr_B to 3.64e+00
# Done ramping
# Ramping V_pr_B to 3.64e+00
# Done ramping
# Ramping V_pr_B to 3.65e+00
# Done ramping
# Ramping V_pr_B to 3.65e+00
# Done ramping
# Ramping V_pr_B to 3.66e+00
# Done ramping
# Ramping V_pr_B to 3.66e+00
# Done ramping
# Ramping V_pr_B to 3.67e+00
# Done ramping
# Ramping V_pr_B to 3.67e+00
# Done ramping
# Ramping V_pr_B to 3.68e+00
# Done ramping
# Ramping V_pr_B to 3.68e+00
# Done ramping
# Ramping V_pr_B to 3.69e+00
# Done ramping
# Ramping V_pr_B to 3.69e+00
# Done ramping
# Ramping V_pr_B to 3.70e+00
# Done ramping
# Ramping V_pr_B to 3.70e+00
# Done ramping
# Ramping V_pr_B to 3.71e+00
# Done ramping
# Ramping V_pr_B to 3.71e+00
# Done ramping
# Ramping V_pr_B to 3.71e+00
# Done ramping
# Ramping V_pr_B to 3.72e+00
# Done ramping
# Ramping V_pr_B to 3.73e+00
# Done ramping
# Ramping V_pr_B to 3.73e+00
# Done ramping
# Ramping V_pr_B to 3.73e+00
# Done ramping
# Ramping V_pr_B to 3.74e+00
# Done ramping
# Ramping V_pr_B to 3.75e+00
# Done ramping
# Ramping V_pr_B to 3.75e+00
# Done ramping
# Ramping V_pr_B to 3.75e+00
# Done ramping
# Ramping V_pr_B to 3.76e+00
# Done ramping
# Ramping V_pr_B to 3.77e+00
# Done ramping
# Ramping V_pr_B to 3.77e+00
# Done ramping
# Ramping V_pr_B to 3.77e+00
# Done ramping
# Ramping V_pr_B to 3.78e+00
# Done ramping
# Ramping V_pr_B to 3.79e+00
# Done ramping
# Ramping V_pr_B to 3.79e+00
# Done ramping
# Ramping V_pr_B to 3.79e+00
# Done ramping
# Ramping V_pr_B to 3.80e+00
# Done ramping
# Ramping V_pr_B to 3.81e+00
# Done ramping
# Ramping V_pr_B to 3.81e+00
# Done ramping
# Ramping V_pr_B to 3.81e+00
# Done ramping
# Ramping V_pr_B to 3.82e+00
# Done ramping
# Ramping V_pr_B to 3.83e+00
# Done ramping
# Ramping V_pr_B to 3.83e+00
# Done ramping
# Ramping V_pr_B to 3.83e+00
# Done ramping
# Ramping V_pr_B to 3.84e+00
# Done ramping
# Ramping V_pr_B to 3.85e+00
# Done ramping
# Ramping V_pr_B to 3.85e+00
# Done ramping
# Ramping V_pr_B to 3.85e+00
# Done ramping
# Ramping V_pr_B to 3.86e+00
# Done ramping
# Ramping V_pr_B to 3.87e+00
# Done ramping
# Ramping V_pr_B to 3.87e+00
# Done ramping
# Ramping V_pr_B to 3.88e+00
# Done ramping
# Ramping V_pr_B to 3.88e+00
# Done ramping
# Ramping V_pr_B to 3.89e+00
# Done ramping
# Ramping V_pr_B to 3.89e+00
# Done ramping
# Ramping V_pr_B to 3.90e+00
# Done ramping
# Ramping V_pr_B to 3.90e+00
# Done ramping
# Ramping V_pr_B to 3.91e+00
# Done ramping
# Ramping V_pr_B to 3.91e+00
# Done ramping
# Ramping V_pr_B to 3.92e+00
# Done ramping
# Ramping V_pr_B to 3.92e+00
# Done ramping
# Ramping V_pr_B to 3.93e+00
# Done ramping
# Ramping V_pr_B to 3.93e+00
# Done ramping
# Ramping V_pr_B to 3.94e+00
# Done ramping
# Ramping V_pr_B to 3.94e+00
# Done ramping
# Ramping V_pr_B to 3.95e+00
# Done ramping
# Ramping V_pr_B to 3.95e+00
# Done ramping
# Ramping V_pr_B to 3.96e+00
# Done ramping
# Ramping V_pr_B to 3.96e+00
# Done ramping
# Ramping V_pr_B to 3.97e+00
# Done ramping
# Ramping V_pr_B to 3.97e+00
# Done ramping
# Ramping V_pr_B to 3.98e+00
# Done ramping
# Ramping V_pr_B to 3.98e+00
# Done ramping
# Ramping V_pr_B to 3.98e+00
# Done ramping
# Ramping V_pr_B to 3.99e+00
# Done ramping
# Ramping V_pr_B to 4.00e+00
# Done ramping
# Ramping V_pr_B to 4.00e+00
# Done ramping
# Ramping V_pr_B to 4.00e+00
# Done ramping
# Ramping V_pr_B to 4.01e+00
# Done ramping
# Ramping V_pr_B to 4.01e+00
# Done ramping
# Ramping V_pr_B to 4.02e+00
# Done ramping
# Ramping V_pr_B to 4.03e+00
# Done ramping
# Ramping V_pr_B to 4.03e+00
# Done ramping
# Ramping V_pr_B to 4.04e+00
# Done ramping
# Ramping V_pr_B to 4.04e+00
# Done ramping
# Ramping V_pr_B to 4.04e+00
# Done ramping
# Ramping V_pr_B to 4.05e+00
# Done ramping
# Ramping V_pr_B to 4.05e+00
# Done ramping
# Ramping V_pr_B to 4.06e+00
# Done ramping
# Ramping V_pr_B to 4.07e+00
# Done ramping
# Ramping V_pr_B to 4.07e+00
# Done ramping
# Ramping V_pr_B to 4.08e+00
# Done ramping
# Ramping V_pr_B to 4.08e+00
# Done ramping
# Ramping V_pr_B to 4.08e+00
# Done ramping
# Ramping V_pr_B to 4.09e+00
# Done ramping
# Ramping V_pr_B to 4.09e+00
# Done ramping
# Ramping V_pr_B to 4.10e+00
# Done ramping
# Ramping V_pr_B to 4.11e+00
# Done ramping
# Ramping V_pr_B to 4.11e+00
# Done ramping
# Ramping V_pr_B to 4.12e+00
# Done ramping
# Ramping V_pr_B to 4.12e+00
# Done ramping
# Ramping V_pr_B to 4.12e+00
# Done ramping
# Ramping V_pr_B to 4.13e+00
# Done ramping
# Ramping V_pr_B to 4.13e+00
# Done ramping
# Ramping V_pr_B to 4.14e+00
# Done ramping
# Ramping V_pr_B to 4.15e+00
# Done ramping
# Ramping V_pr_B to 4.15e+00
# Done ramping
# Ramping V_pr_B to 4.16e+00
# Done ramping
# Ramping V_pr_B to 4.16e+00
# Done ramping
# Ramping V_pr_B to 4.17e+00
# Done ramping
# Ramping V_pr_B to 4.17e+00
# Done ramping
# Ramping V_pr_B to 4.17e+00
# Done ramping
# Ramping V_pr_B to 4.18e+00
# Done ramping
# Ramping V_pr_B to 4.19e+00
# Done ramping
# Ramping V_pr_B to 4.19e+00
# Done ramping
# Ramping V_pr_B to 4.20e+00
# Done ramping
# Ramping V_pr_B to 4.20e+00
# Done ramping
# Ramping V_pr_B to 4.21e+00
# Done ramping
# Ramping V_pr_B to 4.21e+00
# Done ramping
# Ramping V_pr_B to 4.21e+00
# Done ramping
# Ramping V_pr_B to 4.22e+00
# Done ramping
# Ramping V_pr_B to 4.22e+00
# Done ramping
# Ramping V_pr_B to 4.23e+00
# Done ramping
# Ramping V_pr_B to 4.24e+00
# Done ramping
# Ramping V_pr_B to 4.24e+00
# Done ramping
# Ramping V_pr_B to 4.25e+00
# Done ramping
# Ramping V_pr_B to 4.25e+00
# Done ramping
# Ramping V_pr_B to 4.25e+00
# Done ramping
# Ramping V_pr_B to 4.26e+00
# Done ramping
# Ramping V_pr_B to 4.26e+00
# Done ramping
# Ramping V_pr_B to 4.27e+00
# Done ramping
# Ramping V_pr_B to 4.28e+00
# Done ramping
# Ramping V_pr_B to 4.28e+00
# Done ramping
# Ramping V_pr_B to 4.29e+00
# Done ramping
# Ramping V_pr_B to 4.29e+00
# Done ramping
# Ramping V_pr_B to 4.29e+00
# Done ramping
# Ramping V_pr_B to 4.30e+00
# Done ramping
# Ramping V_pr_B to 4.30e+00
# Done ramping
# Ramping V_pr_B to 4.31e+00
# Done ramping
# Ramping V_pr_B to 4.32e+00
# Done ramping
# Ramping V_pr_B to 4.32e+00
# Done ramping
# Ramping V_pr_B to 4.33e+00
# Done ramping
# Ramping V_pr_B to 4.33e+00
# Done ramping
# Ramping V_pr_B to 4.33e+00
# Done ramping
# Ramping V_pr_B to 4.34e+00
# Done ramping
# Ramping V_pr_B to 4.34e+00
# Done ramping
# Ramping V_pr_B to 4.35e+00
# Done ramping
# Ramping V_pr_B to 4.36e+00
# Done ramping
# Ramping V_pr_B to 4.36e+00
# Done ramping
# Ramping V_pr_B to 4.37e+00
# Done ramping
# Ramping V_pr_B to 4.37e+00
# Done ramping
# Ramping V_pr_B to 4.38e+00
# Done ramping
# Ramping V_pr_B to 4.38e+00
# Done ramping
# Ramping V_pr_B to 4.38e+00
# Done ramping
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-215-447ae2104e87> in <module>()
#      41                         gate_ramp_stepsize = (1e-3),
#      42                         gate_ramp_delay = (0.01),
# ---> 43                         power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')
#      44
#      45 print(" Time elapsed: %.4f" % (time.time()-t0))
#
# <ipython-input-93-a6f06a6945a4> in do_gate_sweep_single_frequency(gate_channel, gate_voltages, gate_name, gate_ramp_stepsize, gate_ramp_delay, power, n_pts, f, n_avg, channel_name)
#     109             result.append((long_gate_name, gate_voltage))
#     110
# --> 111             vna_result= measure_and_process_point_vna(chan=channel_name)
#     112             result.extend(vna_result)
#     113
#
# <ipython-input-93-a6f06a6945a4> in measure_and_process_point_vna(chan)
#      35     magnitude_dB
#      36     """
# ---> 37     mag, phase = measure_mag_phase_point_vna(chan=channel_name)
#      38     mag_db = 20*np.log10(mag) #convert to dB
#      39     result = [
#
# <ipython-input-93-a6f06a6945a4> in measure_mag_phase_point_vna(chan)
#      23 def measure_mag_phase_point_vna(chan='S12'):
#      24     vna_channel = getattr(vna.channels, chan)
# ---> 25     mag, phase = vna_channel.trace_mag_phase()
#      26
#      27     return np.mean(mag), np.mean(phase)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in get_raw(self)
#      40         old_format = self._instrument.format()
#      41         self._instrument.format('Complex')
# ---> 42         data = self._instrument._get_sweep_data(force_polar = True)
#      43         self._instrument.format(old_format)
#      44         return abs(data), np.angle(data)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument_drivers\rohde_schwarz\ZNB.py in _get_sweep_data(self, force_polar)
#     348             # need to ensure averaged result is returned
#     349             for avgcount in range(self.avg()):
# --> 350                 self.write('INIT{}:IMM; *WAI'.format(self._instrument_channel))
#     351             data_str = self.ask(
#     352                 'CALC{}:DATA? {}'.format(self._instrument_channel,
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\channel.py in write(self, cmd)
#      60     # Pass any commands to read or write from the instrument up to the parent
#      61     def write(self, cmd):
# ---> 62         return self._parent.write(cmd)
#      63
#      64     def write_raw(self, cmd):
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\base.py in write(self, cmd)
#     697         """
#     698         try:
# --> 699             self.write_raw(cmd)
#     700         except Exception as e:
#     701             inst = repr(self)
#
# d:\onedrive\bf3\code\qcodes\qcodes\instrument\visa.py in write_raw(self, cmd)
#     213         self.visa_log.debug(f"Writing: {cmd}")
#     214
# --> 215         nr_bytes_written, ret_code = self.visa_handle.write(cmd)
#     216         self.check_error(ret_code)
#     217
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write(self, message, termination, encoding)
#     221             message += term
#     222
# --> 223         count = self.write_raw(message.encode(enco))
#     224
#     225         return count
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py in write_raw(self, message)
#     199         :rtype: int
#     200         """
# --> 201         return self.visalib.write(self.session, message)
#     202
#     203     def write(self, message, termination=None, encoding=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\functions.py in write(library, session, data)
#    1864     return_count = ViUInt32()
#    1865     # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 1866     ret = library.viWrite(session, data, len(data), byref(return_count))
#    1867     return return_count.value, ret
#    1868
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     147             setattr(self, method_name, getattr(self.lib, method_name))
#     148
# --> 149     def _return_handler(self, ret_value, func, arguments):
#     150         """Check return values for errors and warnings.
#     151         """
#
# KeyboardInterrupt:

# %% [markdown]
# ## multiple gate 1D sweep

# %%
vna.S21.bandwidth(10000)

# %%
power = -33
n_pts = 100
n_avg = 200
f = f_readouts[1]
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

resonator='C'
gate_voltages = np.arange(2.0,3.0,0.01)
#set the Bfield. 
set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d B=%.2e" %(f, power, n_pts, n_avg, get_yoko_field())  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False
back_ramp_value = 2.5

#ramp all gates of resonator X
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, back_ramp_value, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=100, channel_name='S21')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_single_frequency(gate_channels, gate_voltages,gate_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# Taking single sweep
# Starting experimental run with id: 65
# Taking trace took 6.366845369338989
# <MDACChannel: MDAC_chan25 of MDAC: MDAC> 3.989995
# <MDACChannel: MDAC_chan26 of MDAC: MDAC> 3.989997
# <MDACChannel: MDAC_chan9 of MDAC: MDAC> 3.990004
# <MDACChannel: MDAC_chan27 of MDAC: MDAC> 3.990003
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# STARTING TEMPERATURE: 0.023
# Starting experimental run with id: 66
# Ramping V_pl_C to 2.00e+00
# Done ramping
# Ramping V_cut_C to 2.00e+00
# Done ramping
# Ramping V_pr_C to 2.00e+00
# Done ramping
# Ramping V_bot_C to 2.00e+00
# Done ramping
# Ramping V_pl_C to 2.01e+00
# Done ramping
# Ramping V_cut_C to 2.01e+00
# Done ramping
# Ramping V_pr_C to 2.01e+00
# Done ramping
# Ramping V_bot_C to 2.01e+00
# Done ramping
# Ramping V_pl_C to 2.02e+00
# Done ramping
# Ramping V_cut_C to 2.02e+00
# Done ramping
# Ramping V_pr_C to 2.02e+00
# Done ramping
# Ramping V_bot_C to 2.02e+00
# Done ramping
# Ramping V_pl_C to 2.03e+00
# Done ramping
# Ramping V_cut_C to 2.03e+00
# Done ramping
# Ramping V_pr_C to 2.03e+00
# Done ramping
# Ramping V_bot_C to 2.03e+00
# Done ramping
# Ramping V_pl_C to 2.04e+00
# Done ramping
# Ramping V_cut_C to 2.04e+00
# Done ramping
# Ramping V_pr_C to 2.04e+00
# Done ramping
# Ramping V_bot_C to 2.04e+00
# Done ramping
# Ramping V_pl_C to 2.05e+00
# Done ramping
# Ramping V_cut_C to 2.05e+00
# Done ramping
# Ramping V_pr_C to 2.05e+00
# Done ramping
# Ramping V_bot_C to 2.05e+00
# Done ramping
# Ramping V_pl_C to 2.06e+00
# Done ramping
# Ramping V_cut_C to 2.06e+00
# Done ramping
# Ramping V_pr_C to 2.06e+00
# Done ramping
# Ramping V_bot_C to 2.06e+00
# Done ramping
# Ramping V_pl_C to 2.07e+00
# Done ramping
# Ramping V_cut_C to 2.07e+00
# Done ramping
# Ramping V_pr_C to 2.07e+00
# Done ramping
# Ramping V_bot_C to 2.07e+00
# Done ramping
# Ramping V_pl_C to 2.08e+00
# Done ramping
# Ramping V_cut_C to 2.08e+00
# Done ramping
# Ramping V_pr_C to 2.08e+00
# Done ramping
# Ramping V_bot_C to 2.08e+00
# Done ramping
# Ramping V_pl_C to 2.09e+00
# Done ramping
# Ramping V_cut_C to 2.09e+00
# Done ramping
# Ramping V_pr_C to 2.09e+00
# Done ramping
# Ramping V_bot_C to 2.09e+00
# Done ramping
# Ramping V_pl_C to 2.10e+00
# Done ramping
# Ramping V_cut_C to 2.10e+00
# Done ramping
# Ramping V_pr_C to 2.10e+00
# Done ramping
# Ramping V_bot_C to 2.10e+00
# Done ramping
# Ramping V_pl_C to 2.11e+00
# Done ramping
# Ramping V_cut_C to 2.11e+00
# Done ramping
# Ramping V_pr_C to 2.11e+00
# Done ramping
# Ramping V_bot_C to 2.11e+00
# Done ramping
# Ramping V_pl_C to 2.12e+00
# Done ramping
# Ramping V_cut_C to 2.12e+00
# Done ramping
# Ramping V_pr_C to 2.12e+00
# Done ramping
# Ramping V_bot_C to 2.12e+00
# Done ramping
# Ramping V_pl_C to 2.13e+00
# Done ramping
# Ramping V_cut_C to 2.13e+00
# Done ramping
# Ramping V_pr_C to 2.13e+00
# Done ramping
# Ramping V_bot_C to 2.13e+00
# Done ramping
# Ramping V_pl_C to 2.14e+00
# Done ramping
# Ramping V_cut_C to 2.14e+00
# Done ramping
# Ramping V_pr_C to 2.14e+00
# Done ramping
# Ramping V_bot_C to 2.14e+00
# Done ramping
# Ramping V_pl_C to 2.15e+00
# Done ramping
# Ramping V_cut_C to 2.15e+00
# Done ramping
# Ramping V_pr_C to 2.15e+00
# Done ramping
# Ramping V_bot_C to 2.15e+00
# Done ramping
# Ramping V_pl_C to 2.16e+00
# Done ramping
# Ramping V_cut_C to 2.16e+00
# Done ramping
# Ramping V_pr_C to 2.16e+00
# Done ramping
# Ramping V_bot_C to 2.16e+00
# Done ramping
# Ramping V_pl_C to 2.17e+00
# Done ramping
# Ramping V_cut_C to 2.17e+00
# Done ramping
# Ramping V_pr_C to 2.17e+00
# Done ramping
# Ramping V_bot_C to 2.17e+00
# Done ramping
# Ramping V_pl_C to 2.18e+00
# Done ramping
# Ramping V_cut_C to 2.18e+00
# Done ramping
# Ramping V_pr_C to 2.18e+00
# Done ramping
# Ramping V_bot_C to 2.18e+00
# Done ramping
# Ramping V_pl_C to 2.19e+00
# Done ramping
# Ramping V_cut_C to 2.19e+00
# Done ramping
# Ramping V_pr_C to 2.19e+00
# Done ramping
# Ramping V_bot_C to 2.19e+00
# Done ramping
# Ramping V_pl_C to 2.20e+00
# Done ramping
# Ramping V_cut_C to 2.20e+00
# Done ramping
# Ramping V_pr_C to 2.20e+00
# Done ramping
# Ramping V_bot_C to 2.20e+00
# Done ramping
# Ramping V_pl_C to 2.21e+00
# Done ramping
# Ramping V_cut_C to 2.21e+00
# Done ramping
# Ramping V_pr_C to 2.21e+00
# Done ramping
# Ramping V_bot_C to 2.21e+00
# Done ramping
# Ramping V_pl_C to 2.22e+00
# Done ramping
# Ramping V_cut_C to 2.22e+00
# Done ramping
# Ramping V_pr_C to 2.22e+00
# Done ramping
# Ramping V_bot_C to 2.22e+00
# Done ramping
# Ramping V_pl_C to 2.23e+00
# Done ramping
# Ramping V_cut_C to 2.23e+00
# Done ramping
# Ramping V_pr_C to 2.23e+00
# Done ramping
# Ramping V_bot_C to 2.23e+00
# Done ramping
# Ramping V_pl_C to 2.24e+00
# Done ramping
# Ramping V_cut_C to 2.24e+00
# Done ramping
# Ramping V_pr_C to 2.24e+00
# Done ramping
# Ramping V_bot_C to 2.24e+00
# Done ramping
# Ramping V_pl_C to 2.25e+00
# Done ramping
# Ramping V_cut_C to 2.25e+00
# Done ramping
# Ramping V_pr_C to 2.25e+00
# Done ramping
# Ramping V_bot_C to 2.25e+00
# Done ramping
# Ramping V_pl_C to 2.26e+00
# Done ramping
# Ramping V_cut_C to 2.26e+00
# Done ramping
# Ramping V_pr_C to 2.26e+00
# Done ramping
# Ramping V_bot_C to 2.26e+00
# Done ramping
# Ramping V_pl_C to 2.27e+00
# Done ramping
# Ramping V_cut_C to 2.27e+00
# Done ramping
# Ramping V_pr_C to 2.27e+00
# Done ramping
# Ramping V_bot_C to 2.27e+00
# Done ramping
# Ramping V_pl_C to 2.28e+00
# Done ramping
# Ramping V_cut_C to 2.28e+00
# Done ramping
# Ramping V_pr_C to 2.28e+00
# Done ramping
# Ramping V_bot_C to 2.28e+00
# Done ramping
# Ramping V_pl_C to 2.29e+00
# Done ramping
# Ramping V_cut_C to 2.29e+00
# Done ramping
# Ramping V_pr_C to 2.29e+00
# Done ramping
# Ramping V_bot_C to 2.29e+00
# Done ramping
# Ramping V_pl_C to 2.30e+00
# Done ramping
# Ramping V_cut_C to 2.30e+00
# Done ramping
# Ramping V_pr_C to 2.30e+00
# Done ramping
# Ramping V_bot_C to 2.30e+00
# Done ramping
# Ramping V_pl_C to 2.31e+00
# Done ramping
# Ramping V_cut_C to 2.31e+00
# Done ramping
# Ramping V_pr_C to 2.31e+00
# Done ramping
# Ramping V_bot_C to 2.31e+00
# Done ramping
# Ramping V_pl_C to 2.32e+00
# Done ramping
# Ramping V_cut_C to 2.32e+00
# Done ramping
# Ramping V_pr_C to 2.32e+00
# Done ramping
# Ramping V_bot_C to 2.32e+00
# Done ramping
# Ramping V_pl_C to 2.33e+00
# Done ramping
# Ramping V_cut_C to 2.33e+00
# Done ramping
# Ramping V_pr_C to 2.33e+00
# Done ramping
# Ramping V_bot_C to 2.33e+00
# Done ramping
# Ramping V_pl_C to 2.34e+00
# Done ramping
# Ramping V_cut_C to 2.34e+00
# Done ramping
# Ramping V_pr_C to 2.34e+00
# Done ramping
# Ramping V_bot_C to 2.34e+00
# Done ramping
# Ramping V_pl_C to 2.35e+00
# Done ramping
# Ramping V_cut_C to 2.35e+00
# Done ramping
# Ramping V_pr_C to 2.35e+00
# Done ramping
# Ramping V_bot_C to 2.35e+00
# Done ramping
# Ramping V_pl_C to 2.36e+00
# Done ramping
# Ramping V_cut_C to 2.36e+00
# Done ramping
# Ramping V_pr_C to 2.36e+00
# Done ramping
# Ramping V_bot_C to 2.36e+00
# Done ramping
# Ramping V_pl_C to 2.37e+00
# Done ramping
# Ramping V_cut_C to 2.37e+00
# Done ramping
# Ramping V_pr_C to 2.37e+00
# Done ramping
# Ramping V_bot_C to 2.37e+00
# Done ramping
# Ramping V_pl_C to 2.38e+00
# Done ramping
# Ramping V_cut_C to 2.38e+00
# Done ramping
# Ramping V_pr_C to 2.38e+00
# Done ramping
# Ramping V_bot_C to 2.38e+00
# Done ramping
# Ramping V_pl_C to 2.39e+00
# Done ramping
# Ramping V_cut_C to 2.39e+00
# Done ramping
# Ramping V_pr_C to 2.39e+00
# Done ramping
# Ramping V_bot_C to 2.39e+00
# Done ramping
# Ramping V_pl_C to 2.40e+00
# Done ramping
# Ramping V_cut_C to 2.40e+00
# Done ramping
# Ramping V_pr_C to 2.40e+00
# Done ramping
# Ramping V_bot_C to 2.40e+00
# Done ramping
# Ramping V_pl_C to 2.41e+00
# Done ramping
# Ramping V_cut_C to 2.41e+00
# Done ramping
# Ramping V_pr_C to 2.41e+00
# Done ramping
# Ramping V_bot_C to 2.41e+00
# Done ramping
# Ramping V_pl_C to 2.42e+00
# Done ramping
# Ramping V_cut_C to 2.42e+00
# Done ramping
# Ramping V_pr_C to 2.42e+00
# Done ramping
# Ramping V_bot_C to 2.42e+00
# Done ramping
# Ramping V_pl_C to 2.43e+00
# Done ramping
# Ramping V_cut_C to 2.43e+00
# Done ramping
# Ramping V_pr_C to 2.43e+00
# Done ramping
# Ramping V_bot_C to 2.43e+00
# Done ramping
# Ramping V_pl_C to 2.44e+00
# Done ramping
# Ramping V_cut_C to 2.44e+00
# Done ramping
# Ramping V_pr_C to 2.44e+00
# Done ramping
# Ramping V_bot_C to 2.44e+00
# Done ramping
# Ramping V_pl_C to 2.45e+00
# Done ramping
# Ramping V_cut_C to 2.45e+00
# Done ramping
# Ramping V_pr_C to 2.45e+00
# Done ramping
# Ramping V_bot_C to 2.45e+00
# Done ramping
# Ramping V_pl_C to 2.46e+00
# Done ramping
# Ramping V_cut_C to 2.46e+00
# Done ramping
# Ramping V_pr_C to 2.46e+00
# Done ramping
# Ramping V_bot_C to 2.46e+00
# Done ramping
# Ramping V_pl_C to 2.47e+00
# Done ramping
# Ramping V_cut_C to 2.47e+00
# Done ramping
# Ramping V_pr_C to 2.47e+00
# Done ramping
# Ramping V_bot_C to 2.47e+00
# Done ramping
# Ramping V_pl_C to 2.48e+00
# Done ramping
# Ramping V_cut_C to 2.48e+00
# Done ramping
# Ramping V_pr_C to 2.48e+00
# Done ramping
# Ramping V_bot_C to 2.48e+00
# Done ramping
# Ramping V_pl_C to 2.49e+00
# Done ramping
# Ramping V_cut_C to 2.49e+00
# Done ramping
# Ramping V_pr_C to 2.49e+00
# Done ramping
# Ramping V_bot_C to 2.49e+00
# Done ramping
# Ramping V_pl_C to 2.50e+00
# Done ramping
# Ramping V_cut_C to 2.50e+00
# Done ramping
# Ramping V_pr_C to 2.50e+00
# Done ramping
# Ramping V_bot_C to 2.50e+00
# Done ramping
# Ramping V_pl_C to 2.51e+00
# Done ramping
# Ramping V_cut_C to 2.51e+00
# Done ramping
# Ramping V_pr_C to 2.51e+00
# Done ramping
# Ramping V_bot_C to 2.51e+00
# Done ramping
# Ramping V_pl_C to 2.52e+00
# Done ramping
# Ramping V_cut_C to 2.52e+00
# Done ramping
# Ramping V_pr_C to 2.52e+00
# Done ramping
# Ramping V_bot_C to 2.52e+00
# Done ramping
# Ramping V_pl_C to 2.53e+00
# Done ramping
# Ramping V_cut_C to 2.53e+00
# Done ramping
# Ramping V_pr_C to 2.53e+00
# Done ramping
# Ramping V_bot_C to 2.53e+00
# Done ramping
# Ramping V_pl_C to 2.54e+00
# Done ramping
# Ramping V_cut_C to 2.54e+00
# Done ramping
# Ramping V_pr_C to 2.54e+00
# Done ramping
# Ramping V_bot_C to 2.54e+00
# Done ramping
# Ramping V_pl_C to 2.55e+00
# Done ramping
# Ramping V_cut_C to 2.55e+00
# Done ramping
# Ramping V_pr_C to 2.55e+00
# Done ramping
# Ramping V_bot_C to 2.55e+00
# Done ramping
# Ramping V_pl_C to 2.56e+00
# Done ramping
# Ramping V_cut_C to 2.56e+00
# Done ramping
# Ramping V_pr_C to 2.56e+00
# Done ramping
# Ramping V_bot_C to 2.56e+00
# Done ramping
# Ramping V_pl_C to 2.57e+00
# Done ramping
# Ramping V_cut_C to 2.57e+00
# Done ramping
# Ramping V_pr_C to 2.57e+00
# Done ramping
# Ramping V_bot_C to 2.57e+00
# Done ramping
# Ramping V_pl_C to 2.58e+00
# Done ramping
# Ramping V_cut_C to 2.58e+00
# Done ramping
# Ramping V_pr_C to 2.58e+00
# Done ramping
# Ramping V_bot_C to 2.58e+00
# Done ramping
# Ramping V_pl_C to 2.59e+00
# Done ramping
# Ramping V_cut_C to 2.59e+00
# Done ramping
# Ramping V_pr_C to 2.59e+00
# Done ramping
# Ramping V_bot_C to 2.59e+00
# Done ramping
# Ramping V_pl_C to 2.60e+00
# Done ramping
# Ramping V_cut_C to 2.60e+00
# Done ramping
# Ramping V_pr_C to 2.60e+00
# Done ramping
# Ramping V_bot_C to 2.60e+00
# Done ramping
# Ramping V_pl_C to 2.61e+00
# Done ramping
# Ramping V_cut_C to 2.61e+00
# Done ramping
# Ramping V_pr_C to 2.61e+00
# Done ramping
# Ramping V_bot_C to 2.61e+00
# Done ramping
# Ramping V_pl_C to 2.62e+00
# Done ramping
# Ramping V_cut_C to 2.62e+00
# Done ramping
# Ramping V_pr_C to 2.62e+00
# Done ramping
# Ramping V_bot_C to 2.62e+00
# Done ramping
# Ramping V_pl_C to 2.63e+00
# Done ramping
# Ramping V_cut_C to 2.63e+00
# Done ramping
# Ramping V_pr_C to 2.63e+00
# Done ramping
# Ramping V_bot_C to 2.63e+00
# Done ramping
# Ramping V_pl_C to 2.64e+00
# Done ramping
# Ramping V_cut_C to 2.64e+00
# Done ramping
# Ramping V_pr_C to 2.64e+00
# Done ramping
# Ramping V_bot_C to 2.64e+00
# Done ramping
# Ramping V_pl_C to 2.65e+00
# Done ramping
# Ramping V_cut_C to 2.65e+00
# Done ramping
# Ramping V_pr_C to 2.65e+00
# Done ramping
# Ramping V_bot_C to 2.65e+00
# Done ramping
# Ramping V_pl_C to 2.66e+00
# Done ramping
# Ramping V_cut_C to 2.66e+00
# Done ramping
# Ramping V_pr_C to 2.66e+00
# Done ramping
# Ramping V_bot_C to 2.66e+00
# Done ramping
# Ramping V_pl_C to 2.67e+00
# Done ramping
# Ramping V_cut_C to 2.67e+00
# Done ramping
# Ramping V_pr_C to 2.67e+00
# Done ramping
# Ramping V_bot_C to 2.67e+00
# Done ramping
# Ramping V_pl_C to 2.68e+00
# Done ramping
# Ramping V_cut_C to 2.68e+00
# Done ramping
# Ramping V_pr_C to 2.68e+00
# Done ramping
# Ramping V_bot_C to 2.68e+00
# Done ramping
# Ramping V_pl_C to 2.69e+00
# Done ramping
# Ramping V_cut_C to 2.69e+00
# Done ramping
# Ramping V_pr_C to 2.69e+00
# Done ramping
# Ramping V_bot_C to 2.69e+00
# Done ramping
# Ramping V_pl_C to 2.70e+00
# Done ramping
# Ramping V_cut_C to 2.70e+00
# Done ramping
# Ramping V_pr_C to 2.70e+00
# Done ramping
# Ramping V_bot_C to 2.70e+00
# Done ramping
# Ramping V_pl_C to 2.71e+00
# Done ramping
# Ramping V_cut_C to 2.71e+00
# Done ramping
# Ramping V_pr_C to 2.71e+00
# Done ramping
# Ramping V_bot_C to 2.71e+00
# Done ramping
# Ramping V_pl_C to 2.72e+00
# Done ramping
# Ramping V_cut_C to 2.72e+00
# Done ramping
# Ramping V_pr_C to 2.72e+00
# Done ramping
# Ramping V_bot_C to 2.72e+00
# Done ramping
# Ramping V_pl_C to 2.73e+00
# Done ramping
# Ramping V_cut_C to 2.73e+00
# Done ramping
# Ramping V_pr_C to 2.73e+00
# Done ramping
# Ramping V_bot_C to 2.73e+00
# Done ramping
# Ramping V_pl_C to 2.74e+00
# Done ramping
# Ramping V_cut_C to 2.74e+00
# Done ramping
# Ramping V_pr_C to 2.74e+00
# Done ramping
# Ramping V_bot_C to 2.74e+00
# Done ramping
# Ramping V_pl_C to 2.75e+00
# Done ramping
# Ramping V_cut_C to 2.75e+00
# Done ramping
# Ramping V_pr_C to 2.75e+00
# Done ramping
# Ramping V_bot_C to 2.75e+00
# Done ramping
# Ramping V_pl_C to 2.76e+00
# Done ramping
# Ramping V_cut_C to 2.76e+00
# Done ramping
# Ramping V_pr_C to 2.76e+00
# Done ramping
# Ramping V_bot_C to 2.76e+00
# Done ramping
# Ramping V_pl_C to 2.77e+00
# Done ramping
# Ramping V_cut_C to 2.77e+00
# Done ramping
# Ramping V_pr_C to 2.77e+00
# Done ramping
# Ramping V_bot_C to 2.77e+00
# Done ramping
# Ramping V_pl_C to 2.78e+00
# Done ramping
# Ramping V_cut_C to 2.78e+00
# Done ramping
# Ramping V_pr_C to 2.78e+00
# Done ramping
# Ramping V_bot_C to 2.78e+00
# Done ramping
# Ramping V_pl_C to 2.79e+00
# Done ramping
# Ramping V_cut_C to 2.79e+00
# Done ramping
# Ramping V_pr_C to 2.79e+00
# Done ramping
# Ramping V_bot_C to 2.79e+00
# Done ramping
# Ramping V_pl_C to 2.80e+00
# Done ramping
# Ramping V_cut_C to 2.80e+00
# Done ramping
# Ramping V_pr_C to 2.80e+00
# Done ramping
# Ramping V_bot_C to 2.80e+00
# Done ramping
# Ramping V_pl_C to 2.81e+00
# Done ramping
# Ramping V_cut_C to 2.81e+00
# Done ramping
# Ramping V_pr_C to 2.81e+00
# Done ramping
# Ramping V_bot_C to 2.81e+00
# Done ramping
# Ramping V_pl_C to 2.82e+00
# Done ramping
# Ramping V_cut_C to 2.82e+00
# Done ramping
# Ramping V_pr_C to 2.82e+00
# Done ramping
# Ramping V_bot_C to 2.82e+00
# Done ramping
# Ramping V_pl_C to 2.83e+00
# Done ramping
# Ramping V_cut_C to 2.83e+00
# Done ramping
# Ramping V_pr_C to 2.83e+00
# Done ramping
# Ramping V_bot_C to 2.83e+00
# Done ramping
# Ramping V_pl_C to 2.84e+00
# Done ramping
# Ramping V_cut_C to 2.84e+00
# Done ramping
# Ramping V_pr_C to 2.84e+00
# Done ramping
# Ramping V_bot_C to 2.84e+00
# Done ramping
# Ramping V_pl_C to 2.85e+00
# Done ramping
# Ramping V_cut_C to 2.85e+00
# Done ramping
# Ramping V_pr_C to 2.85e+00
# Done ramping
# Ramping V_bot_C to 2.85e+00
# Done ramping
# Ramping V_pl_C to 2.86e+00
# Done ramping
# Ramping V_cut_C to 2.86e+00
# Done ramping
# Ramping V_pr_C to 2.86e+00
# Done ramping
# Ramping V_bot_C to 2.86e+00
# Done ramping
# Ramping V_pl_C to 2.87e+00
# Done ramping
# Ramping V_cut_C to 2.87e+00
# Done ramping
# Ramping V_pr_C to 2.87e+00
# Done ramping
# Ramping V_bot_C to 2.87e+00
# Done ramping
# Ramping V_pl_C to 2.88e+00
# Done ramping
# Ramping V_cut_C to 2.88e+00
# Done ramping
# Ramping V_pr_C to 2.88e+00
# Done ramping
# Ramping V_bot_C to 2.88e+00
# Done ramping
# Ramping V_pl_C to 2.89e+00
# Done ramping
# Ramping V_cut_C to 2.89e+00
# Done ramping
# Ramping V_pr_C to 2.89e+00
# Done ramping
# Ramping V_bot_C to 2.89e+00
# Done ramping
# Ramping V_pl_C to 2.90e+00
# Done ramping
# Ramping V_cut_C to 2.90e+00
# Done ramping
# Ramping V_pr_C to 2.90e+00
# Done ramping
# Ramping V_bot_C to 2.90e+00
# Done ramping
# Ramping V_pl_C to 2.91e+00
# Done ramping
# Ramping V_cut_C to 2.91e+00
# Done ramping
# Ramping V_pr_C to 2.91e+00
# Done ramping
# Ramping V_bot_C to 2.91e+00
# Done ramping
# Ramping V_pl_C to 2.92e+00
# Done ramping
# Ramping V_cut_C to 2.92e+00
# Done ramping
# Ramping V_pr_C to 2.92e+00
# Done ramping
# Ramping V_bot_C to 2.92e+00
# Done ramping
# Ramping V_pl_C to 2.93e+00
# Done ramping
# Ramping V_cut_C to 2.93e+00
# Done ramping
# Ramping V_pr_C to 2.93e+00
# Done ramping
# Ramping V_bot_C to 2.93e+00
# Done ramping
# Ramping V_pl_C to 2.94e+00
# Done ramping
# Ramping V_cut_C to 2.94e+00
# Done ramping
# Ramping V_pr_C to 2.94e+00
# Done ramping
# Ramping V_bot_C to 2.94e+00
# Done ramping
# Ramping V_pl_C to 2.95e+00
# Done ramping
# Ramping V_cut_C to 2.95e+00
# Done ramping
# Ramping V_pr_C to 2.95e+00
# Done ramping
# Ramping V_bot_C to 2.95e+00
# Done ramping
# Ramping V_pl_C to 2.96e+00
# Done ramping
# Ramping V_cut_C to 2.96e+00
# Done ramping
# Ramping V_pr_C to 2.96e+00
# Done ramping
# Ramping V_bot_C to 2.96e+00
# Done ramping
# Ramping V_pl_C to 2.97e+00
# Done ramping
# Ramping V_cut_C to 2.97e+00
# Done ramping
# Ramping V_pr_C to 2.97e+00
# Done ramping
# Ramping V_bot_C to 2.97e+00
# Done ramping
# Ramping V_pl_C to 2.98e+00
# Done ramping
# Ramping V_cut_C to 2.98e+00
# Done ramping
# Ramping V_pr_C to 2.98e+00
# Done ramping
# Ramping V_bot_C to 2.98e+00
# Done ramping
# Ramping V_pl_C to 2.99e+00
# Done ramping
# Ramping V_cut_C to 2.99e+00
# Done ramping
# Ramping V_pr_C to 2.99e+00
# Done ramping
# Ramping V_bot_C to 2.99e+00
# Done ramping
#  Time elapsed: 555.0275

# %%
power = -33
n_pts = 100
n_avg = 200
f = f_readouts[1]
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

resonator='C'
gate_voltages = np.arange(2,2.7,0.005)
#set the Bfield. 
#set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d B=%.2e" %(f, power, n_pts, n_avg, get_yoko_field())  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False
back_ramp_value = 2.5

#ramp all gates of resonator X
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, back_ramp_value, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=100, channel_name='S21')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_single_frequency(gate_channels, gate_voltages,gate_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))

# %%
for f in f0s:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=100, channel_name='S21')
        print("Taking trace took", time.time()-t0)

# %% [markdown]
# ## multiple gate multiple freq sweep

# %%
power = -35
n_pts = 40
n_avg = 60

fs = f_readouts
f_names=['D','C','A','B']
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = True

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

resonator='C'
gate_voltages = np.arange(-4,4,0.001)
#set the Bfield. 
set_yoko_field(0.2e-3)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")


#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    for f in fs:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=100, channel_name='S21')
        print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_multiple_frequency(gate_channels, gate_voltages,gate_names,
                                 fs= fs, f_names=f_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))


print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %%
print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
power = -35
n_pts = 40
n_avg = 60

fs = f_readouts[3]
f_names=['B']
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = True

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

resonator='B'
gate_voltages = np.arange(-4,4,0.001)
#set the Bfield. 
set_yoko_field(0.2e-3)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")


#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    for f in fs:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=100, channel_name='S21')
        print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_multiple_frequency(gate_channels, gate_voltages,gate_names,
                                 fs= fs, f_names=f_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))


print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %%
print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
power = -35
n_pts = 40
n_avg = 60

fs = f_readouts[2]
f_names=['A']
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = True

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

resonator='A'
gate_voltages = np.arange(-4,4,0.001)
#set the Bfield. 
set_yoko_field(0.2e-3)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")


#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    for f in fs:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=100, channel_name='S21')
        print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_multiple_frequency(gate_channels, gate_voltages,gate_names,
                                 fs= fs, f_names=f_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))


print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %%
power = -30
n_pts = 100
n_avg = 200
fs = f0s
f_names=['D','C','A','B']
t0 = time.time()
take_trace_at_beginning = False
ramp_back_gates = True

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

resonator='B'
gate_voltages = np.arange(0,3,0.002)
#set the Bfield. 
set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False

#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    for f in fs:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=20, channel_name='S21')
        print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_multiple_frequency(gate_channels, gate_voltages,gate_names,
                                 fs= fs, f_names=f_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))

print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %%
power = -30
n_pts = 100
n_avg = 200
fs = f0s
f_names=['D','C','A','B']
t0 = time.time()
take_trace_at_beginning = False
ramp_back_gates = True

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

resonator='C'
gate_voltages = np.arange(0,3,0.002)
#set the Bfield. 
set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False

#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    for f in fs:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=20, channel_name='S21')
        print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_multiple_frequency(gate_channels, gate_voltages,gate_names,
                                 fs= fs, f_names=f_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))

print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %%
power = -30
n_pts = 100
n_avg = 200
fs = f0s
f_names=['D','C','A','B']
t0 = time.time()
take_trace_at_beginning = False
ramp_back_gates = True

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

resonator='A'
gate_voltages = np.arange(3,4,0.002)
#set the Bfield. 
set_yoko_field(0)
exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")

ramp_back_gates = False

#ramp all gates of resonator A
gate_channels =list(MDAC_channels[resonator].values())
gate_names = list(MDAC_channels[resonator].keys())

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_names:
        ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    for f in fs:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 500, f_start = f-5e6, f_stop = f+5e6, power=power+20, n_avg=20, channel_name='S21')
        print("Taking trace took", time.time()-t0)

#now do the real thing
do_gate_sweep_multiple_frequency(gate_channels, gate_voltages,gate_names,
                                 fs= fs, f_names=f_names,
                        gate_ramp_stepsize = (1e-3), 
                        gate_ramp_delay = (0.01),
                        power=power, n_pts = n_pts, n_avg=n_avg, channel_name='S21')

print(" Time elapsed: %.4f" % (time.time()-t0))


print('ramping back gates')
for gate in gate_names:
    ramp(MDAC_channels[resonator][gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)

# %% [markdown]
# ## Multiple gate setting: Magnet 1D sweep

# %%
power = -33
n_pts = 100
n_avg = 200
f = 4.7e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

B_fields = np.arange(0,2.5e-3,3e-6)

exp = qc.new_experiment("single freq f=%.5e power=%d n=%d x %d" %(f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")
gate_channel = []

gate_voltages = 4
gate_name = []

if ramp_back_gates:
    print('ramping back gates')
    for gate in gate_name:
        ramp(MDAC_channels[gate].voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
print("ramping up gates")
for gate in gate_name:
    ramp(MDAC_channels[gate].voltage, gate_voltages, gate_ramp_stepsize, gate_ramp_delay)
#take a trace around f first after ramping back the gates to check where we are
if take_trace_at_beginning:
    print("Taking single sweep")
    t0=time.time()
    do_single_sweep(n_pts = 100, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=1000, channel_name='S21')
    print("Taking trace took", time.time()-t0)

#now do the real thing
do_field_sweep_single_frequency(B_fields, power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')


print(" Time elapsed: %.4f" % (time.time()-t0))
# Out:
# ramping up gates
# Taking single sweep
# Starting experimental run with id: 77
# Taking trace took 13.087562322616577
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 78
# Setting field to 0.0
# Setting field to 3e-06
# Setting field to 6e-06
# Setting field to 9e-06
# Setting field to 1.2e-05
# Setting field to 1.5e-05
# Setting field to 1.8e-05
# Setting field to 2.1e-05
# Setting field to 2.4e-05
# Setting field to 2.7e-05
# Setting field to 3e-05
# Setting field to 3.3e-05
# Setting field to 3.6e-05
# Setting field to 3.9e-05
# Setting field to 4.2e-05
# Setting field to 4.5e-05
# Setting field to 4.8e-05
# Setting field to 5.1e-05
# Setting field to 5.4e-05
# Setting field to 5.7e-05
# Setting field to 6e-05
# Setting field to 6.3e-05
# Setting field to 6.6e-05
# Setting field to 6.9e-05
# Setting field to 7.2e-05
# Setting field to 7.5e-05
# Setting field to 7.8e-05
# Setting field to 8.1e-05
# Setting field to 8.4e-05
# Setting field to 8.7e-05
# Setting field to 9e-05
# Setting field to 9.3e-05
# Setting field to 9.6e-05
# Setting field to 9.9e-05
# Setting field to 0.000102
# Setting field to 0.000105
# Setting field to 0.000108
# Setting field to 0.000111
# Setting field to 0.000114
# Setting field to 0.000117
# Setting field to 0.00012
# Setting field to 0.000123
# Setting field to 0.000126
# Setting field to 0.000129
# Setting field to 0.000132
# Setting field to 0.000135
# Setting field to 0.000138
# Setting field to 0.000141
# Setting field to 0.000144
# Setting field to 0.000147
# Setting field to 0.00015
# Setting field to 0.000153
# Setting field to 0.000156
# Setting field to 0.000159
# Setting field to 0.000162
# Setting field to 0.000165
# Setting field to 0.000168
# Setting field to 0.000171
# Setting field to 0.000174
# Setting field to 0.000177
# Setting field to 0.00018
# Setting field to 0.000183
# Setting field to 0.000186
# Setting field to 0.000189
# Setting field to 0.000192
# Setting field to 0.000195
# Setting field to 0.000198
# Setting field to 0.000201
# Setting field to 0.000204
# Setting field to 0.000207
# Setting field to 0.00021
# Setting field to 0.000213
# Setting field to 0.000216
# Setting field to 0.000219
# Setting field to 0.000222
# Setting field to 0.000225
# Setting field to 0.000228
# Setting field to 0.000231
# Setting field to 0.000234
# Setting field to 0.000237
# Setting field to 0.00024
# Setting field to 0.000243
# Setting field to 0.000246
# Setting field to 0.000249
# Setting field to 0.000252
# Setting field to 0.000255
# Setting field to 0.000258
# Setting field to 0.000261
# Setting field to 0.000264
# Setting field to 0.000267
# Setting field to 0.00027
# Setting field to 0.000273
# Setting field to 0.000276
# Setting field to 0.000279
# Setting field to 0.000282
# Setting field to 0.000285
# Setting field to 0.000288
# Setting field to 0.000291
# Setting field to 0.000294
# Setting field to 0.000297
# Setting field to 0.0003
# Setting field to 0.000303
# Setting field to 0.000306
# Setting field to 0.000309
# Setting field to 0.000312
# Setting field to 0.000315
# Setting field to 0.000318
# Setting field to 0.000321
# Setting field to 0.000324
# Setting field to 0.000327
# Setting field to 0.00033
# Setting field to 0.000333
# Setting field to 0.000336
# Setting field to 0.000339
# Setting field to 0.000342
# Setting field to 0.000345
# Setting field to 0.000348
# Setting field to 0.000351
# Setting field to 0.000354
# Setting field to 0.000357
# Setting field to 0.00036
# Setting field to 0.000363
# Setting field to 0.000366
# Setting field to 0.000369
# Setting field to 0.000372
# Setting field to 0.000375
# Setting field to 0.000378
# Setting field to 0.000381
# Setting field to 0.000384
# Setting field to 0.000387
# Setting field to 0.00039
# Setting field to 0.000393
# Setting field to 0.000396
# Setting field to 0.000399
# Setting field to 0.000402
# Setting field to 0.000405
# Setting field to 0.000408
# Setting field to 0.000411
# Setting field to 0.000414
# Setting field to 0.000417
# Setting field to 0.00042
# Setting field to 0.000423
# Setting field to 0.000426
# Setting field to 0.000429
# Setting field to 0.000432
# Setting field to 0.000435
# Setting field to 0.000438
# Setting field to 0.000441
# Setting field to 0.000444
# Setting field to 0.000447
# Setting field to 0.00045
# Setting field to 0.000453
# Setting field to 0.000456
# Setting field to 0.000459
# Setting field to 0.000462
# Setting field to 0.000465
# Setting field to 0.000468
# Setting field to 0.000471
# Setting field to 0.000474
# Setting field to 0.000477
# Setting field to 0.00048
# Setting field to 0.000483
# Setting field to 0.000486
# Setting field to 0.000489
# Setting field to 0.000492
# Setting field to 0.000495
# Setting field to 0.000498
# Setting field to 0.000501
# Setting field to 0.000504
# Setting field to 0.000507
# Setting field to 0.00051
# Setting field to 0.000513
# Setting field to 0.000516
# Setting field to 0.000519
# Setting field to 0.000522
# Setting field to 0.000525
# Setting field to 0.000528
# Setting field to 0.000531
# Setting field to 0.000534
# Setting field to 0.000537
# Setting field to 0.00054
# Setting field to 0.000543
# Setting field to 0.000546
# Setting field to 0.000549
# Setting field to 0.000552
# Setting field to 0.000555
# Setting field to 0.000558
# Setting field to 0.000561
# Setting field to 0.000564
# Setting field to 0.000567
# Setting field to 0.00057
# Setting field to 0.000573
# Setting field to 0.000576
# Setting field to 0.000579
# Setting field to 0.000582
# Setting field to 0.000585
# Setting field to 0.000588
# Setting field to 0.000591
# Setting field to 0.000594
# Setting field to 0.000597
# Setting field to 0.0006
# Setting field to 0.000603
# Setting field to 0.000606
# Setting field to 0.000609
# Setting field to 0.000612
# Setting field to 0.000615
# Setting field to 0.000618
# Setting field to 0.000621
# Setting field to 0.000624
# Setting field to 0.000627
# Setting field to 0.00063
# Setting field to 0.000633
# Setting field to 0.000636
# Setting field to 0.000639
# Setting field to 0.000642
# Setting field to 0.000645
# Setting field to 0.000648
# Setting field to 0.000651
# Setting field to 0.000654
# Setting field to 0.000657
# Setting field to 0.00066
# Setting field to 0.000663
# Setting field to 0.000666
# Setting field to 0.000669
# Setting field to 0.000672
# Setting field to 0.000675
# Setting field to 0.000678
# Setting field to 0.000681
# Setting field to 0.000684
# Setting field to 0.000687
# Setting field to 0.00069
# Setting field to 0.000693
# Setting field to 0.000696
# Setting field to 0.000699
# Setting field to 0.000702
# Setting field to 0.000705
# Setting field to 0.000708
# Setting field to 0.000711
# Setting field to 0.000714
# Setting field to 0.000717
# Setting field to 0.00072
# Setting field to 0.000723
# Setting field to 0.000726
# Setting field to 0.000729
# Setting field to 0.000732
# Setting field to 0.000735
# Setting field to 0.000738
# Setting field to 0.000741
# Setting field to 0.000744
# Setting field to 0.000747
# Setting field to 0.00075
# Setting field to 0.000753
# Setting field to 0.000756
# Setting field to 0.000759
# Setting field to 0.000762
# Setting field to 0.000765
# Setting field to 0.000768
# Setting field to 0.000771
# Setting field to 0.000774
# Setting field to 0.000777
# Setting field to 0.00078
# Setting field to 0.000783
# Setting field to 0.000786
# Setting field to 0.000789
# Setting field to 0.000792
# Setting field to 0.000795
# Setting field to 0.000798
# Setting field to 0.000801
# Setting field to 0.000804
# Setting field to 0.000807
# Setting field to 0.00081
# Setting field to 0.000813
# Setting field to 0.000816
# Setting field to 0.000819
# Setting field to 0.000822
# Setting field to 0.000825
# Setting field to 0.000828
# Setting field to 0.000831
# Setting field to 0.000834
# Setting field to 0.000837
# Setting field to 0.00084
# Setting field to 0.000843
# Setting field to 0.000846
# Setting field to 0.000849
# Setting field to 0.000852
# Setting field to 0.000855
# Setting field to 0.000858
# Setting field to 0.000861
# Setting field to 0.000864
# Setting field to 0.000867
# Setting field to 0.00087
# Setting field to 0.000873
# Setting field to 0.000876
# Setting field to 0.000879
# Setting field to 0.000882
# Setting field to 0.000885
# Setting field to 0.000888
# Setting field to 0.000891
# Setting field to 0.000894
# Setting field to 0.000897
# Setting field to 0.0009
# Setting field to 0.000903
# Setting field to 0.000906
# Setting field to 0.000909
# Setting field to 0.000912
# Setting field to 0.000915
# Setting field to 0.000918
# Setting field to 0.000921
# Setting field to 0.000924
# Setting field to 0.000927
# Setting field to 0.00093
# Setting field to 0.000933
# Setting field to 0.000936
# Setting field to 0.000939
# Setting field to 0.000942
# Setting field to 0.000945
# Setting field to 0.000948
# Setting field to 0.000951
# Setting field to 0.000954
# Setting field to 0.000957
# Setting field to 0.00096
# Setting field to 0.000963
# Setting field to 0.000966
# Setting field to 0.000969
# Setting field to 0.000972
# Setting field to 0.000975
# Setting field to 0.000978
# Setting field to 0.000981
# Setting field to 0.000984
# Setting field to 0.000987
# Setting field to 0.00099
# Setting field to 0.000993
# Setting field to 0.000996
# Setting field to 0.000999
# Setting field to 0.001002
# Setting field to 0.001005
# Setting field to 0.001008
# Setting field to 0.001011
# Setting field to 0.001014
# Setting field to 0.001017
# Setting field to 0.00102
# Setting field to 0.001023
# Setting field to 0.001026
# Setting field to 0.001029
# Setting field to 0.001032
# Setting field to 0.001035
# Setting field to 0.001038
# Setting field to 0.001041
# Setting field to 0.001044
# Setting field to 0.001047
# Setting field to 0.00105
# Setting field to 0.001053
# Setting field to 0.001056
# Setting field to 0.001059
# Setting field to 0.001062
# Setting field to 0.001065
# Setting field to 0.001068
# Setting field to 0.001071
# Setting field to 0.001074
# Setting field to 0.001077
# Setting field to 0.00108
# Setting field to 0.001083
# Setting field to 0.001086
# Setting field to 0.001089
# Setting field to 0.001092
# Setting field to 0.001095
# Setting field to 0.001098
# Setting field to 0.001101
# Setting field to 0.001104
# Setting field to 0.001107
# Setting field to 0.00111
# Setting field to 0.001113
# Setting field to 0.001116
# Setting field to 0.001119
# Setting field to 0.001122
# Setting field to 0.001125
# Setting field to 0.001128
# Setting field to 0.001131
# Setting field to 0.001134
# Setting field to 0.001137
# Setting field to 0.00114
# Setting field to 0.001143
# Setting field to 0.001146
# Setting field to 0.001149
# Setting field to 0.001152
# Setting field to 0.001155
# Setting field to 0.001158
# Setting field to 0.001161
# Setting field to 0.001164
# Setting field to 0.001167
# Setting field to 0.00117
# Setting field to 0.001173
# Setting field to 0.001176
# Setting field to 0.001179
# Setting field to 0.001182
# Setting field to 0.001185
# Setting field to 0.001188
# Setting field to 0.001191
# Setting field to 0.001194
# Setting field to 0.001197
# Setting field to 0.0012
# Setting field to 0.001203
# Setting field to 0.001206
# Setting field to 0.001209
# Setting field to 0.001212
# Setting field to 0.001215
# Setting field to 0.001218
# Setting field to 0.001221
# Setting field to 0.001224
# Setting field to 0.001227
# Setting field to 0.00123
# Setting field to 0.001233
# Setting field to 0.001236
# Setting field to 0.001239
# Setting field to 0.001242
# Setting field to 0.001245
# Setting field to 0.001248
# Setting field to 0.001251
# Setting field to 0.001254
# Setting field to 0.001257
# Setting field to 0.00126
# Setting field to 0.001263
# Setting field to 0.001266
# Setting field to 0.001269
# Setting field to 0.001272
# Setting field to 0.001275
# Setting field to 0.001278
# Setting field to 0.001281
# Setting field to 0.001284
# Setting field to 0.001287
# Setting field to 0.00129
# Setting field to 0.001293
# Setting field to 0.001296
# Setting field to 0.001299
# Setting field to 0.001302
# Setting field to 0.001305
# Setting field to 0.001308
# Setting field to 0.001311
# Setting field to 0.001314
# Setting field to 0.001317
# Setting field to 0.00132
# Setting field to 0.001323
# Setting field to 0.001326
# Setting field to 0.001329
# Setting field to 0.001332
# Setting field to 0.001335
# Setting field to 0.001338
# Setting field to 0.001341
# Setting field to 0.001344
# Setting field to 0.001347
# Setting field to 0.00135
# Setting field to 0.001353
# Setting field to 0.001356
# Setting field to 0.001359
# Setting field to 0.001362
# Setting field to 0.001365
# Setting field to 0.001368
# Setting field to 0.001371
# Setting field to 0.001374
# Setting field to 0.001377
# Setting field to 0.00138
# Setting field to 0.001383
# Setting field to 0.001386
# Setting field to 0.001389
# Setting field to 0.001392
# Setting field to 0.001395
# Setting field to 0.001398
# Setting field to 0.001401
# Setting field to 0.001404
# Setting field to 0.001407
# Setting field to 0.00141
# Setting field to 0.001413
# Setting field to 0.001416
# Setting field to 0.001419
# Setting field to 0.001422
# Setting field to 0.001425
# Setting field to 0.001428
# Setting field to 0.001431
# Setting field to 0.001434
# Setting field to 0.001437
# Setting field to 0.00144
# Setting field to 0.001443
# Setting field to 0.001446
# Setting field to 0.001449
# Setting field to 0.001452
# Setting field to 0.001455
# Setting field to 0.001458
# Setting field to 0.001461
# Setting field to 0.001464
# Setting field to 0.001467
# Setting field to 0.00147
# Setting field to 0.001473
# Setting field to 0.001476
# Setting field to 0.001479
# Setting field to 0.001482
# Setting field to 0.001485
# Setting field to 0.001488
# Setting field to 0.001491
# Setting field to 0.001494
# Setting field to 0.001497
# Setting field to 0.0015
# Setting field to 0.001503
# Setting field to 0.001506
# Setting field to 0.001509
# Setting field to 0.001512
# Setting field to 0.001515
# Setting field to 0.001518
# Setting field to 0.001521
# Setting field to 0.001524
# Setting field to 0.001527
# Setting field to 0.00153
# Setting field to 0.001533
# Setting field to 0.001536
# Setting field to 0.001539
# Setting field to 0.001542
# Setting field to 0.001545
# Setting field to 0.001548
# Setting field to 0.001551
# Setting field to 0.001554
# Setting field to 0.001557
# Setting field to 0.00156
# Setting field to 0.001563
# Setting field to 0.001566
# Setting field to 0.001569
# Setting field to 0.001572
# Setting field to 0.001575
# Setting field to 0.001578
# Setting field to 0.001581
# Setting field to 0.001584
# Setting field to 0.001587
# Setting field to 0.00159
# Setting field to 0.001593
# Setting field to 0.001596
# Setting field to 0.001599
# Setting field to 0.001602
# Setting field to 0.001605
# Setting field to 0.001608
# Setting field to 0.001611
# Setting field to 0.001614
# Setting field to 0.001617
# Setting field to 0.00162
# Setting field to 0.001623
# Setting field to 0.001626
# Setting field to 0.001629
# Setting field to 0.001632
# Setting field to 0.001635
# Setting field to 0.001638
# Setting field to 0.001641
# Setting field to 0.001644
# Setting field to 0.001647
# Setting field to 0.00165
# Setting field to 0.001653
# Setting field to 0.001656
# Setting field to 0.001659
# Setting field to 0.001662
# Setting field to 0.001665
# Setting field to 0.001668
# Setting field to 0.001671
# Setting field to 0.001674
# Setting field to 0.001677
# Setting field to 0.00168
# Setting field to 0.001683
# Setting field to 0.001686
# Setting field to 0.001689
# Setting field to 0.001692
# Setting field to 0.001695
# Setting field to 0.001698
# Setting field to 0.001701
# Setting field to 0.001704
# Setting field to 0.001707
# Setting field to 0.00171
# Setting field to 0.001713
# Setting field to 0.001716
# Setting field to 0.001719
# Setting field to 0.001722
# Setting field to 0.001725
# Setting field to 0.001728
# Setting field to 0.001731
# Setting field to 0.001734
# Setting field to 0.001737
# Setting field to 0.00174
# Setting field to 0.001743
# Setting field to 0.001746
# Setting field to 0.001749
# Setting field to 0.001752
# Setting field to 0.001755
# Setting field to 0.001758
# Setting field to 0.001761
# Setting field to 0.001764
# Setting field to 0.001767
# Setting field to 0.00177
# Setting field to 0.001773
# Setting field to 0.001776
# Setting field to 0.001779
# Setting field to 0.001782
# Setting field to 0.001785
# Setting field to 0.001788
# Setting field to 0.001791
# Setting field to 0.001794
# Setting field to 0.001797
# Setting field to 0.0018
# Setting field to 0.001803
# Setting field to 0.001806
# Setting field to 0.001809
# Setting field to 0.001812
# Setting field to 0.001815
# Setting field to 0.001818
# Setting field to 0.001821
# Setting field to 0.001824
# Setting field to 0.001827
# Setting field to 0.00183
# Setting field to 0.001833
# Setting field to 0.001836
# Setting field to 0.001839
# Setting field to 0.001842
# Setting field to 0.001845
# Setting field to 0.001848
# Setting field to 0.001851
# Setting field to 0.001854
# Setting field to 0.001857
# Setting field to 0.00186
# Setting field to 0.001863
# Setting field to 0.001866
# Setting field to 0.001869
# Setting field to 0.001872
# Setting field to 0.001875
# Setting field to 0.001878
# Setting field to 0.001881
# Setting field to 0.001884
# Setting field to 0.001887
# Setting field to 0.00189
# Setting field to 0.001893
# Setting field to 0.001896
# Setting field to 0.001899
# Setting field to 0.001902
# Setting field to 0.001905
# Setting field to 0.001908
# Setting field to 0.001911
# Setting field to 0.001914
# Setting field to 0.001917
# Setting field to 0.00192
# Setting field to 0.001923
# Setting field to 0.001926
# Setting field to 0.001929
# Setting field to 0.001932
# Setting field to 0.001935
# Setting field to 0.001938
# Setting field to 0.001941
# Setting field to 0.001944
# Setting field to 0.001947
# Setting field to 0.00195
# Setting field to 0.001953
# Setting field to 0.001956
# Setting field to 0.001959
# Setting field to 0.001962
# Setting field to 0.001965
# Setting field to 0.001968
# Setting field to 0.001971
# Setting field to 0.001974
# Setting field to 0.001977
# Setting field to 0.00198
# Setting field to 0.001983
# Setting field to 0.001986
# Setting field to 0.001989
# Setting field to 0.001992
# Setting field to 0.001995
# Setting field to 0.001998
# Setting field to 0.002001
# Setting field to 0.002004
# Setting field to 0.002007
# Setting field to 0.00201
# Setting field to 0.002013
# Setting field to 0.002016
# Setting field to 0.002019
# Setting field to 0.002022
# Setting field to 0.002025
# Setting field to 0.002028
# Setting field to 0.002031
# Setting field to 0.002034
# Setting field to 0.002037
# Setting field to 0.00204
# Setting field to 0.002043
# Setting field to 0.002046
# Setting field to 0.002049
# Setting field to 0.002052
# Setting field to 0.002055
# Setting field to 0.002058
# Setting field to 0.002061
# Setting field to 0.002064
# Setting field to 0.002067
# Setting field to 0.00207
# Setting field to 0.002073
# Setting field to 0.002076
# Setting field to 0.002079
# Setting field to 0.002082
# Setting field to 0.002085
# Setting field to 0.002088
# Setting field to 0.002091
# Setting field to 0.002094
# Setting field to 0.002097
# Setting field to 0.0021
# Setting field to 0.002103
# Setting field to 0.002106
# Setting field to 0.002109
# Setting field to 0.002112
# Setting field to 0.002115
# Setting field to 0.002118
# Setting field to 0.002121
# Setting field to 0.002124
# Setting field to 0.002127
# Setting field to 0.00213
# Setting field to 0.002133
# Setting field to 0.002136
# Setting field to 0.002139
# Setting field to 0.002142
# Setting field to 0.002145
# Setting field to 0.002148
# Setting field to 0.002151
# Setting field to 0.002154
# Setting field to 0.002157
# Setting field to 0.00216
# Setting field to 0.002163
# Setting field to 0.002166
# Setting field to 0.002169
# Setting field to 0.002172
# Setting field to 0.002175
# Setting field to 0.002178
# Setting field to 0.002181
# Setting field to 0.002184
# Setting field to 0.002187
# Setting field to 0.00219
# Setting field to 0.002193
# Setting field to 0.002196
# Setting field to 0.002199
# Setting field to 0.002202
# Setting field to 0.002205
# Setting field to 0.002208
# Setting field to 0.002211
# Setting field to 0.002214
# Setting field to 0.002217
# Setting field to 0.00222
# Setting field to 0.002223
# Setting field to 0.002226
# Setting field to 0.002229
# Setting field to 0.002232
# Setting field to 0.002235
# Setting field to 0.002238
# Setting field to 0.002241
# Setting field to 0.002244
# Setting field to 0.002247
# Setting field to 0.00225
# Setting field to 0.002253
# Setting field to 0.002256
# Setting field to 0.002259
# Setting field to 0.002262
# Setting field to 0.002265
# Setting field to 0.002268
# Setting field to 0.002271
# Setting field to 0.002274
# Setting field to 0.002277
# Setting field to 0.00228
# Setting field to 0.002283
# Setting field to 0.002286
# Setting field to 0.002289
# Setting field to 0.002292
# Setting field to 0.002295
# Setting field to 0.002298
# Setting field to 0.002301
# Setting field to 0.002304
# Setting field to 0.002307
# Setting field to 0.00231
# Setting field to 0.002313
# Setting field to 0.002316
# Setting field to 0.002319
# Setting field to 0.002322
# Setting field to 0.002325
# Setting field to 0.002328
# Setting field to 0.002331
# Setting field to 0.002334
# Setting field to 0.002337
# Setting field to 0.00234
# Setting field to 0.002343
# Setting field to 0.002346
# Setting field to 0.002349
# Setting field to 0.002352
# Setting field to 0.002355
# Setting field to 0.002358
# Setting field to 0.002361
# Setting field to 0.002364
# Setting field to 0.002367
# Setting field to 0.00237
# Setting field to 0.002373
# Setting field to 0.002376
# Setting field to 0.002379
# Setting field to 0.002382
# Setting field to 0.002385
# Setting field to 0.002388
# Setting field to 0.002391
# Setting field to 0.002394
# Setting field to 0.002397
# Setting field to 0.0024
# Setting field to 0.002403
# Setting field to 0.002406
# Setting field to 0.002409
# Setting field to 0.002412
# Setting field to 0.002415
# Setting field to 0.002418
# Setting field to 0.002421
# Setting field to 0.002424
# Setting field to 0.002427
# Setting field to 0.00243
# Setting field to 0.002433
# Setting field to 0.002436
# Setting field to 0.002439
# Setting field to 0.002442
# Setting field to 0.002445
# Setting field to 0.002448
# Setting field to 0.002451
# Setting field to 0.002454
# Setting field to 0.002457
# Setting field to 0.00246
# Setting field to 0.002463
# Setting field to 0.002466
# Setting field to 0.002469
# Setting field to 0.002472
# Setting field to 0.002475
# Setting field to 0.002478
# Setting field to 0.002481
# Setting field to 0.002484
# Setting field to 0.002487
# Setting field to 0.00249
# Setting field to 0.002493
# Setting field to 0.002496
# Setting field to 0.002499
#  Time elapsed: 2888.1858

# %% [markdown]
# ## multiple gate setting: Magnet 1D sweep for each readout

# %%
power = -33
n_pts = 200
n_avg = 400
f = 4.84725e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

B_fields = np.arange(0,2.5e-3,1e-6)


gate_voltages = 4
gate_name = ['V_bot_A', 'V_pl_A']

resonators = ['A', 'C', 'B']
gate_vals = [3.76,2.5, 2.5]
fs = [f_readouts[2], f_readouts[1], f_readouts[3]]

for i in range(0,len(gate_vals)):
    f = fs[i]
    resonator=resonators[i]
    exp = qc.new_experiment("Res %s single freq field sweep all_gates=%.2f f=%.5e power=%d n=%d x %d" %(resonators[i],gate_vals[i],f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")


    #ramp all gates of resonator X
    gate_channels =list(MDAC_channels[resonator].values())
    gate_names = list(MDAC_channels[resonator].keys())

    print("ramping up gates")
    for gate_chan in gate_channels:
        print("ramping gate %s " % gate_chan)
        ramp(gate_chan.voltage, gate_vals[i], gate_ramp_stepsize, gate_ramp_delay)
    #take a trace around f first after ramping back the gates to check where we are
    if take_trace_at_beginning:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 100, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=1000, channel_name='S21')
        print("Taking trace took", time.time()-t0)

    #now do the real thing
    do_field_sweep_single_frequency(B_fields, power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')

    #take a trace around f first after ramping back the gates to check where we are
    print(" Time elapsed: %.4f" % (time.time()-t0))
    for gate_chan in gate_channels:
        print("ramping gate %s down " % gate_chan)
        ramp(gate_chan.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
# Out:
# ramping up gates
# ramping gate <MDACChannel: MDAC_chan2 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan1 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan3 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan4 of MDAC: MDAC>
# Taking single sweep
# Starting experimental run with id: 69
# Taking trace took 13.075860977172852
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 70
# Setting field to 0.0
# Setting field to 1e-06
# Setting field to 2e-06
# Setting field to 3e-06
# Setting field to 4e-06
# Setting field to 5e-06
# Setting field to 6e-06
# Setting field to 7e-06
# Setting field to 8e-06
# Setting field to 9e-06
# Setting field to 1e-05
# Setting field to 1.1e-05
# Setting field to 1.2e-05
# Setting field to 1.3e-05
# Setting field to 1.4e-05
# Setting field to 1.5e-05
# Setting field to 1.6e-05
# Setting field to 1.7e-05
# Setting field to 1.8e-05
# Setting field to 1.9e-05
# Setting field to 2e-05
# Setting field to 2.1e-05
# Setting field to 2.2e-05
# Setting field to 2.3e-05
# Setting field to 2.4e-05
# Setting field to 2.5e-05
# Setting field to 2.6e-05
# Setting field to 2.7e-05
# Setting field to 2.8e-05
# Setting field to 2.9e-05
# Setting field to 3e-05
# Setting field to 3.1e-05
# Setting field to 3.2e-05
# Setting field to 3.3e-05
# Setting field to 3.4e-05
# Setting field to 3.5e-05
# Setting field to 3.6e-05
# Setting field to 3.7e-05
# Setting field to 3.8e-05
# Setting field to 3.9e-05
# Setting field to 4e-05
# Setting field to 4.1e-05
# Setting field to 4.2e-05
# Setting field to 4.3e-05
# Setting field to 4.4e-05
# Setting field to 4.5e-05
# Setting field to 4.6e-05
# Setting field to 4.7e-05
# Setting field to 4.8e-05
# Setting field to 4.9e-05
# Setting field to 5e-05
# Setting field to 5.1e-05
# Setting field to 5.2e-05
# Setting field to 5.3e-05
# Setting field to 5.4e-05
# Setting field to 5.5e-05
# Setting field to 5.6e-05
# Setting field to 5.7e-05
# Setting field to 5.8e-05
# Setting field to 5.9e-05
# Setting field to 6e-05
# Setting field to 6.1e-05
# Setting field to 6.2e-05
# Setting field to 6.3e-05
# Setting field to 6.4e-05
# Setting field to 6.5e-05
# Setting field to 6.6e-05
# Setting field to 6.7e-05
# Setting field to 6.8e-05
# Setting field to 6.9e-05
# Setting field to 7e-05
# Setting field to 7.1e-05
# Setting field to 7.2e-05
# Setting field to 7.3e-05
# Setting field to 7.4e-05
# Setting field to 7.5e-05
# Setting field to 7.6e-05
# Setting field to 7.7e-05
# Setting field to 7.8e-05
# Setting field to 7.9e-05
# Setting field to 8e-05
# Setting field to 8.1e-05
# Setting field to 8.2e-05
# Setting field to 8.3e-05
# Setting field to 8.4e-05
# Setting field to 8.5e-05
# Setting field to 8.6e-05
# Setting field to 8.7e-05
# Setting field to 8.8e-05
# Setting field to 8.9e-05
# Setting field to 9e-05
# Setting field to 9.1e-05
# Setting field to 9.2e-05
# Setting field to 9.3e-05
# Setting field to 9.4e-05
# Setting field to 9.5e-05
# Setting field to 9.6e-05
# Setting field to 9.7e-05
# Setting field to 9.8e-05
# Setting field to 9.9e-05
# Setting field to 0.0001
# Setting field to 0.000101
# Setting field to 0.000102
# Setting field to 0.000103
# Setting field to 0.000104
# Setting field to 0.000105
# Setting field to 0.000106
# Setting field to 0.000107
# Setting field to 0.000108
# Setting field to 0.000109
# Setting field to 0.00011
# Setting field to 0.000111
# Setting field to 0.000112
# Setting field to 0.000113
# Setting field to 0.000114
# Setting field to 0.000115
# Setting field to 0.000116
# Setting field to 0.000117
# Setting field to 0.000118
# Setting field to 0.000119
# Setting field to 0.00012
# Setting field to 0.000121
# Setting field to 0.000122
# Setting field to 0.000123
# Setting field to 0.000124
# Setting field to 0.000125
# Setting field to 0.000126
# Setting field to 0.000127
# Setting field to 0.000128
# Setting field to 0.000129
# Setting field to 0.00013
# Setting field to 0.000131
# Setting field to 0.000132
# Setting field to 0.000133
# Setting field to 0.000134
# Setting field to 0.000135
# Setting field to 0.000136
# Setting field to 0.000137
# Setting field to 0.000138
# Setting field to 0.000139
# Setting field to 0.00014
# Setting field to 0.000141
# Setting field to 0.000142
# Setting field to 0.000143
# Setting field to 0.000144
# Setting field to 0.000145
# Setting field to 0.000146
# Setting field to 0.000147
# Setting field to 0.000148
# Setting field to 0.000149
# Setting field to 0.00015
# Setting field to 0.000151
# Setting field to 0.000152
# Setting field to 0.000153
# Setting field to 0.000154
# Setting field to 0.000155
# Setting field to 0.000156
# Setting field to 0.000157
# Setting field to 0.000158
# Setting field to 0.000159
# Setting field to 0.00016
# Setting field to 0.000161
# Setting field to 0.000162
# Setting field to 0.000163
# Setting field to 0.000164
# Setting field to 0.000165
# Setting field to 0.000166
# Setting field to 0.000167
# Setting field to 0.000168
# Setting field to 0.000169
# Setting field to 0.00017
# Setting field to 0.000171
# Setting field to 0.000172
# Setting field to 0.000173
# Setting field to 0.000174
# Setting field to 0.000175
# Setting field to 0.000176
# Setting field to 0.000177
# Setting field to 0.000178
# Setting field to 0.000179
# Setting field to 0.00018
# Setting field to 0.000181
# Setting field to 0.000182
# Setting field to 0.000183
# Setting field to 0.000184
# Setting field to 0.000185
# Setting field to 0.000186
# Setting field to 0.000187
# Setting field to 0.000188
# Setting field to 0.000189
# Setting field to 0.00019
# Setting field to 0.000191
# Setting field to 0.000192
# Setting field to 0.000193
# Setting field to 0.000194
# Setting field to 0.000195
# Setting field to 0.000196
# Setting field to 0.000197
# Setting field to 0.000198
# Setting field to 0.000199
# Setting field to 0.0002
# Setting field to 0.000201
# Setting field to 0.000202
# Setting field to 0.000203
# Setting field to 0.000204
# Setting field to 0.000205
# Setting field to 0.000206
# Setting field to 0.000207
# Setting field to 0.000208
# Setting field to 0.000209
# Setting field to 0.00021
# Setting field to 0.000211
# Setting field to 0.000212
# Setting field to 0.000213
# Setting field to 0.000214
# Setting field to 0.000215
# Setting field to 0.000216
# Setting field to 0.000217
# Setting field to 0.000218
# Setting field to 0.000219
# Setting field to 0.00022
# Setting field to 0.000221
# Setting field to 0.000222
# Setting field to 0.000223
# Setting field to 0.000224
# Setting field to 0.000225
# Setting field to 0.000226
# Setting field to 0.000227
# Setting field to 0.000228
# Setting field to 0.000229
# Setting field to 0.00023
# Setting field to 0.000231
# Setting field to 0.000232
# Setting field to 0.000233
# Setting field to 0.000234
# Setting field to 0.000235
# Setting field to 0.000236
# Setting field to 0.000237
# Setting field to 0.000238
# Setting field to 0.000239
# Setting field to 0.00024
# Setting field to 0.000241
# Setting field to 0.000242
# Setting field to 0.000243
# Setting field to 0.000244
# Setting field to 0.000245
# Setting field to 0.000246
# Setting field to 0.000247
# Setting field to 0.000248
# Setting field to 0.000249
# Setting field to 0.00025
# Setting field to 0.000251
# Setting field to 0.000252
# Setting field to 0.000253
# Setting field to 0.000254
# Setting field to 0.000255
# Setting field to 0.000256
# Setting field to 0.000257
# Setting field to 0.000258
# Setting field to 0.000259
# Setting field to 0.00026
# Setting field to 0.000261
# Setting field to 0.000262
# Setting field to 0.000263
# Setting field to 0.000264
# Setting field to 0.000265
# Setting field to 0.000266
# Setting field to 0.000267
# Setting field to 0.000268
# Setting field to 0.000269
# Setting field to 0.00027
# Setting field to 0.000271
# Setting field to 0.000272
# Setting field to 0.000273
# Setting field to 0.000274
# Setting field to 0.000275
# Setting field to 0.000276
# Setting field to 0.000277
# Setting field to 0.000278
# Setting field to 0.000279
# Setting field to 0.00028
# Setting field to 0.000281
# Setting field to 0.000282
# Setting field to 0.000283
# Setting field to 0.000284
# Setting field to 0.000285
# Setting field to 0.000286
# Setting field to 0.000287
# Setting field to 0.000288
# Setting field to 0.000289
# Setting field to 0.00029
# Setting field to 0.000291
# Setting field to 0.000292
# Setting field to 0.000293
# Setting field to 0.000294
# Setting field to 0.000295
# Setting field to 0.000296
# Setting field to 0.000297
# Setting field to 0.000298
# Setting field to 0.000299
# Setting field to 0.0003
# Setting field to 0.000301
# Setting field to 0.000302
# Setting field to 0.000303
# Setting field to 0.000304
# Setting field to 0.000305
# Setting field to 0.000306
# Setting field to 0.000307
# Setting field to 0.000308
# Setting field to 0.000309
# Setting field to 0.00031
# Setting field to 0.000311
# Setting field to 0.000312
# Setting field to 0.000313
# Setting field to 0.000314
# Setting field to 0.000315
# Setting field to 0.000316
# Setting field to 0.000317
# Setting field to 0.000318
# Setting field to 0.000319
# Setting field to 0.00032
# Setting field to 0.000321
# Setting field to 0.000322
# Setting field to 0.000323
# Setting field to 0.000324
# Setting field to 0.000325
# Setting field to 0.000326
# Setting field to 0.000327
# Setting field to 0.000328
# Setting field to 0.000329
# Setting field to 0.00033
# Setting field to 0.000331
# Setting field to 0.000332
# Setting field to 0.000333
# Setting field to 0.000334
# Setting field to 0.000335
# Setting field to 0.000336
# Setting field to 0.000337
# Setting field to 0.000338
# Setting field to 0.000339
# Setting field to 0.00034
# Setting field to 0.000341
# Setting field to 0.000342
# Setting field to 0.000343
# Setting field to 0.000344
# Setting field to 0.000345
# Setting field to 0.000346
# Setting field to 0.000347
# Setting field to 0.000348
# Setting field to 0.000349
# Setting field to 0.00035
# Setting field to 0.000351
# Setting field to 0.000352
# Setting field to 0.000353
# Setting field to 0.000354
# Setting field to 0.000355
# Setting field to 0.000356
# Setting field to 0.000357
# Setting field to 0.000358
# Setting field to 0.000359
# Setting field to 0.00036
# Setting field to 0.000361
# Setting field to 0.000362
# Setting field to 0.000363
# Setting field to 0.000364
# Setting field to 0.000365
# Setting field to 0.000366
# Setting field to 0.000367
# Setting field to 0.000368
# Setting field to 0.000369
# Setting field to 0.00037
# Setting field to 0.000371
# Setting field to 0.000372
# Setting field to 0.000373
# Setting field to 0.000374
# Setting field to 0.000375
# Setting field to 0.000376
# Setting field to 0.000377
# Setting field to 0.000378
# Setting field to 0.000379
# Setting field to 0.00038
# Setting field to 0.000381
# Setting field to 0.000382
# Setting field to 0.000383
# Setting field to 0.000384
# Setting field to 0.000385
# Setting field to 0.000386
# Setting field to 0.000387
# Setting field to 0.000388
# Setting field to 0.000389
# Setting field to 0.00039
# Setting field to 0.000391
# Setting field to 0.000392
# Setting field to 0.000393
# Setting field to 0.000394
# Setting field to 0.000395
# Setting field to 0.000396
# Setting field to 0.000397
# Setting field to 0.000398
# Setting field to 0.000399
# Setting field to 0.0004
# Setting field to 0.000401
# Setting field to 0.000402
# Setting field to 0.000403
# Setting field to 0.000404
# Setting field to 0.000405
# Setting field to 0.000406
# Setting field to 0.000407
# Setting field to 0.000408
# Setting field to 0.000409
# Setting field to 0.00041
# Setting field to 0.000411
# Setting field to 0.000412
# Setting field to 0.000413
# Setting field to 0.000414
# Setting field to 0.000415
# Setting field to 0.000416
# Setting field to 0.000417
# Setting field to 0.000418
# Setting field to 0.000419
# Setting field to 0.00042
# Setting field to 0.000421
# Setting field to 0.000422
# Setting field to 0.000423
# Setting field to 0.000424
# Setting field to 0.000425
# Setting field to 0.000426
# Setting field to 0.000427
# Setting field to 0.000428
# Setting field to 0.000429
# Setting field to 0.00043
# Setting field to 0.000431
# Setting field to 0.000432
# Setting field to 0.000433
# Setting field to 0.000434
# Setting field to 0.000435
# Setting field to 0.000436
# Setting field to 0.000437
# Setting field to 0.000438
# Setting field to 0.000439
# Setting field to 0.00044
# Setting field to 0.000441
# Setting field to 0.000442
# Setting field to 0.000443
# Setting field to 0.000444
# Setting field to 0.000445
# Setting field to 0.000446
# Setting field to 0.000447
# Setting field to 0.000448
# Setting field to 0.000449
# Setting field to 0.00045
# Setting field to 0.000451
# Setting field to 0.000452
# Setting field to 0.000453
# Setting field to 0.000454
# Setting field to 0.000455
# Setting field to 0.000456
# Setting field to 0.000457
# Setting field to 0.000458
# Setting field to 0.000459
# Setting field to 0.00046
# Setting field to 0.000461
# Setting field to 0.000462
# Setting field to 0.000463
# Setting field to 0.000464
# Setting field to 0.000465
# Setting field to 0.000466
# Setting field to 0.000467
# Setting field to 0.000468
# Setting field to 0.000469
# Setting field to 0.00047
# Setting field to 0.000471
# Setting field to 0.000472
# Setting field to 0.000473
# Setting field to 0.000474
# Setting field to 0.000475
# Setting field to 0.000476
# Setting field to 0.000477
# Setting field to 0.000478
# Setting field to 0.000479
# Setting field to 0.00048
# Setting field to 0.000481
# Setting field to 0.000482
# Setting field to 0.000483
# Setting field to 0.000484
# Setting field to 0.000485
# Setting field to 0.000486
# Setting field to 0.000487
# Setting field to 0.000488
# Setting field to 0.000489
# Setting field to 0.00049
# Setting field to 0.000491
# Setting field to 0.000492
# Setting field to 0.000493
# Setting field to 0.000494
# Setting field to 0.000495
# Setting field to 0.000496
# Setting field to 0.000497
# Setting field to 0.000498
# Setting field to 0.000499
# Setting field to 0.0005
# Setting field to 0.000501
# Setting field to 0.000502
# Setting field to 0.000503
# Setting field to 0.000504
# Setting field to 0.000505
# Setting field to 0.000506
# Setting field to 0.000507
# Setting field to 0.000508
# Setting field to 0.000509
# Setting field to 0.00051
# Setting field to 0.000511
# Setting field to 0.000512
# Setting field to 0.000513
# Setting field to 0.000514
# Setting field to 0.000515
# Setting field to 0.000516
# Setting field to 0.000517
# Setting field to 0.000518
# Setting field to 0.000519
# Setting field to 0.00052
# Setting field to 0.000521
# Setting field to 0.000522
# Setting field to 0.000523
# Setting field to 0.000524
# Setting field to 0.000525
# Setting field to 0.000526
# Setting field to 0.000527
# Setting field to 0.000528
# Setting field to 0.000529
# Setting field to 0.00053
# Setting field to 0.000531
# Setting field to 0.000532
# Setting field to 0.000533
# Setting field to 0.000534
# Setting field to 0.000535
# Setting field to 0.000536
# Setting field to 0.000537
# Setting field to 0.000538
# Setting field to 0.000539
# Setting field to 0.00054
# Setting field to 0.000541
# Setting field to 0.000542
# Setting field to 0.000543
# Setting field to 0.000544
# Setting field to 0.000545
# Setting field to 0.000546
# Setting field to 0.000547
# Setting field to 0.000548
# Setting field to 0.000549
# Setting field to 0.00055
# Setting field to 0.000551
# Setting field to 0.000552
# Setting field to 0.000553
# Setting field to 0.000554
# Setting field to 0.000555
# Setting field to 0.000556
# Setting field to 0.000557
# Setting field to 0.000558
# Setting field to 0.000559
# Setting field to 0.00056
# Setting field to 0.000561
# Setting field to 0.000562
# Setting field to 0.000563
# Setting field to 0.000564
# Setting field to 0.000565
# Setting field to 0.000566
# Setting field to 0.000567
# Setting field to 0.000568
# Setting field to 0.000569
# Setting field to 0.00057
# Setting field to 0.000571
# Setting field to 0.000572
# Setting field to 0.000573
# Setting field to 0.000574
# Setting field to 0.000575
# Setting field to 0.000576
# Setting field to 0.000577
# Setting field to 0.000578
# Setting field to 0.000579
# Setting field to 0.00058
# Setting field to 0.000581
# Setting field to 0.000582
# Setting field to 0.000583
# Setting field to 0.000584
# Setting field to 0.000585
# Setting field to 0.000586
# Setting field to 0.000587
# Setting field to 0.000588
# Setting field to 0.000589
# Setting field to 0.00059
# Setting field to 0.000591
# Setting field to 0.000592
# Setting field to 0.000593
# Setting field to 0.000594
# Setting field to 0.000595
# Setting field to 0.000596
# Setting field to 0.000597
# Setting field to 0.000598
# Setting field to 0.000599
# Setting field to 0.0006
# Setting field to 0.000601
# Setting field to 0.000602
# Setting field to 0.000603
# Setting field to 0.000604
# Setting field to 0.000605
# Setting field to 0.000606
# Setting field to 0.000607
# Setting field to 0.000608
# Setting field to 0.000609
# Setting field to 0.00061
# Setting field to 0.000611
# Setting field to 0.000612
# Setting field to 0.000613
# Setting field to 0.000614
# Setting field to 0.000615
# Setting field to 0.000616
# Setting field to 0.000617
# Setting field to 0.000618
# Setting field to 0.000619
# Setting field to 0.00062
# Setting field to 0.000621
# Setting field to 0.000622
# Setting field to 0.000623
# Setting field to 0.000624
# Setting field to 0.000625
# Setting field to 0.000626
# Setting field to 0.000627
# Setting field to 0.000628
# Setting field to 0.000629
# Setting field to 0.00063
# Setting field to 0.000631
# Setting field to 0.000632
# Setting field to 0.000633
# Setting field to 0.000634
# Setting field to 0.000635
# Setting field to 0.000636
# Setting field to 0.000637
# Setting field to 0.000638
# Setting field to 0.000639
# Setting field to 0.00064
# Setting field to 0.000641
# Setting field to 0.000642
# Setting field to 0.000643
# Setting field to 0.000644
# Setting field to 0.000645
# Setting field to 0.000646
# Setting field to 0.000647
# Setting field to 0.000648
# Setting field to 0.000649
# Setting field to 0.00065
# Setting field to 0.000651
# Setting field to 0.000652
# Setting field to 0.000653
# Setting field to 0.000654
# Setting field to 0.000655
# Setting field to 0.000656
# Setting field to 0.000657
# Setting field to 0.000658
# Setting field to 0.000659
# Setting field to 0.00066
# Setting field to 0.000661
# Setting field to 0.000662
# Setting field to 0.000663
# Setting field to 0.000664
# Setting field to 0.000665
# Setting field to 0.000666
# Setting field to 0.000667
# Setting field to 0.000668
# Setting field to 0.000669
# Setting field to 0.00067
# Setting field to 0.000671
# Setting field to 0.000672
# Setting field to 0.000673
# Setting field to 0.000674
# Setting field to 0.000675
# Setting field to 0.000676
# Setting field to 0.000677
# Setting field to 0.000678
# Setting field to 0.000679
# Setting field to 0.00068
# Setting field to 0.000681
# Setting field to 0.000682
# Setting field to 0.000683
# Setting field to 0.000684
# Setting field to 0.000685
# Setting field to 0.000686
# Setting field to 0.000687
# Setting field to 0.000688
# Setting field to 0.000689
# Setting field to 0.00069
# Setting field to 0.000691
# Setting field to 0.000692
# Setting field to 0.000693
# Setting field to 0.000694
# Setting field to 0.000695
# Setting field to 0.000696
# Setting field to 0.000697
# Setting field to 0.000698
# Setting field to 0.000699
# Setting field to 0.0007
# Setting field to 0.000701
# Setting field to 0.000702
# Setting field to 0.000703
# Setting field to 0.000704
# Setting field to 0.000705
# Setting field to 0.000706
# Setting field to 0.000707
# Setting field to 0.000708
# Setting field to 0.000709
# Setting field to 0.00071
# Setting field to 0.000711
# Setting field to 0.000712
# Setting field to 0.000713
# Setting field to 0.000714
# Setting field to 0.000715
# Setting field to 0.000716
# Setting field to 0.000717
# Setting field to 0.000718
# Setting field to 0.000719
# Setting field to 0.00072
# Setting field to 0.000721
# Setting field to 0.000722
# Setting field to 0.000723
# Setting field to 0.000724
# Setting field to 0.000725
# Setting field to 0.000726
# Setting field to 0.000727
# Setting field to 0.000728
# Setting field to 0.000729
# Setting field to 0.00073
# Setting field to 0.000731
# Setting field to 0.000732
# Setting field to 0.000733
# Setting field to 0.000734
# Setting field to 0.000735
# Setting field to 0.000736
# Setting field to 0.000737
# Setting field to 0.000738
# Setting field to 0.000739
# Setting field to 0.00074
# Setting field to 0.000741
# Setting field to 0.000742
# Setting field to 0.000743
# Setting field to 0.000744
# Setting field to 0.000745
# Setting field to 0.000746
# Setting field to 0.000747
# Setting field to 0.000748
# Setting field to 0.000749
# Setting field to 0.00075
# Setting field to 0.000751
# Setting field to 0.000752
# Setting field to 0.000753
# Setting field to 0.000754
# Setting field to 0.000755
# Setting field to 0.000756
# Setting field to 0.000757
# Setting field to 0.000758
# Setting field to 0.000759
# Setting field to 0.00076
# Setting field to 0.000761
# Setting field to 0.000762
# Setting field to 0.000763
# Setting field to 0.000764
# Setting field to 0.000765
# Setting field to 0.000766
# Setting field to 0.000767
# Setting field to 0.000768
# Setting field to 0.000769
# Setting field to 0.00077
# Setting field to 0.000771
# Setting field to 0.000772
# Setting field to 0.000773
# Setting field to 0.000774
# Setting field to 0.000775
# Setting field to 0.000776
# Setting field to 0.000777
# Setting field to 0.000778
# Setting field to 0.000779
# Setting field to 0.00078
# Setting field to 0.000781
# Setting field to 0.000782
# Setting field to 0.000783
# Setting field to 0.000784
# Setting field to 0.000785
# Setting field to 0.000786
# Setting field to 0.000787
# Setting field to 0.000788
# Setting field to 0.000789
# Setting field to 0.00079
# Setting field to 0.000791
# Setting field to 0.000792
# Setting field to 0.000793
# Setting field to 0.000794
# Setting field to 0.000795
# Setting field to 0.000796
# Setting field to 0.000797
# Setting field to 0.000798
# Setting field to 0.000799
# Setting field to 0.0008
# Setting field to 0.000801
# Setting field to 0.000802
# Setting field to 0.000803
# Setting field to 0.000804
# Setting field to 0.000805
# Setting field to 0.000806
# Setting field to 0.000807
# Setting field to 0.000808
# Setting field to 0.000809
# Setting field to 0.00081
# Setting field to 0.000811
# Setting field to 0.000812
# Setting field to 0.000813
# Setting field to 0.000814
# Setting field to 0.000815
# Setting field to 0.000816
# Setting field to 0.000817
# Setting field to 0.000818
# Setting field to 0.000819
# Setting field to 0.00082
# Setting field to 0.000821
# Setting field to 0.000822
# Setting field to 0.000823
# Setting field to 0.000824
# Setting field to 0.000825
# Setting field to 0.000826
# Setting field to 0.000827
# Setting field to 0.000828
# Setting field to 0.000829
# Setting field to 0.00083
# Setting field to 0.000831
# Setting field to 0.000832
# Setting field to 0.000833
# Setting field to 0.000834
# Setting field to 0.000835
# Setting field to 0.000836
# Setting field to 0.000837
# Setting field to 0.000838
# Setting field to 0.000839
# Setting field to 0.00084
# Setting field to 0.000841
# Setting field to 0.000842
# Setting field to 0.000843
# Setting field to 0.000844
# Setting field to 0.000845
# Setting field to 0.000846
# Setting field to 0.000847
# Setting field to 0.000848
# Setting field to 0.000849
# Setting field to 0.00085
# Setting field to 0.000851
# Setting field to 0.000852
# Setting field to 0.000853
# Setting field to 0.000854
# Setting field to 0.000855
# Setting field to 0.000856
# Setting field to 0.000857
# Setting field to 0.000858
# Setting field to 0.000859
# Setting field to 0.00086
# Setting field to 0.000861
# Setting field to 0.000862
# Setting field to 0.000863
# Setting field to 0.000864
# Setting field to 0.000865
# Setting field to 0.000866
# Setting field to 0.000867
# Setting field to 0.000868
# Setting field to 0.000869
# Setting field to 0.00087
# Setting field to 0.000871
# Setting field to 0.000872
# Setting field to 0.000873
# Setting field to 0.000874
# Setting field to 0.000875
# Setting field to 0.000876
# Setting field to 0.000877
# Setting field to 0.000878
# Setting field to 0.000879
# Setting field to 0.00088
# Setting field to 0.000881
# Setting field to 0.000882
# Setting field to 0.000883
# Setting field to 0.000884
# Setting field to 0.000885
# Setting field to 0.000886
# Setting field to 0.000887
# Setting field to 0.000888
# Setting field to 0.000889
# Setting field to 0.00089
# Setting field to 0.000891
# Setting field to 0.000892
# Setting field to 0.000893
# Setting field to 0.000894
# Setting field to 0.000895
# Setting field to 0.000896
# Setting field to 0.000897
# Setting field to 0.000898
# Setting field to 0.000899
# Setting field to 0.0009
# Setting field to 0.000901
# Setting field to 0.000902
# Setting field to 0.000903
# Setting field to 0.000904
# Setting field to 0.000905
# Setting field to 0.000906
# Setting field to 0.000907
# Setting field to 0.000908
# Setting field to 0.000909
# Setting field to 0.00091
# Setting field to 0.000911
# Setting field to 0.000912
# Setting field to 0.000913
# Setting field to 0.000914
# Setting field to 0.000915
# Setting field to 0.000916
# Setting field to 0.000917
# Setting field to 0.000918
# Setting field to 0.000919
# Setting field to 0.00092
# Setting field to 0.000921
# Setting field to 0.000922
# Setting field to 0.000923
# Setting field to 0.000924
# Setting field to 0.000925
# Setting field to 0.000926
# Setting field to 0.000927
# Setting field to 0.000928
# Setting field to 0.000929
# Setting field to 0.00093
# Setting field to 0.000931
# Setting field to 0.000932
# Setting field to 0.000933
# Setting field to 0.000934
# Setting field to 0.000935
# Setting field to 0.000936
# Setting field to 0.000937
# Setting field to 0.000938
# Setting field to 0.000939
# Setting field to 0.00094
# Setting field to 0.000941
# Setting field to 0.000942
# Setting field to 0.000943
# Setting field to 0.000944
# Setting field to 0.000945
# Setting field to 0.000946
# Setting field to 0.000947
# Setting field to 0.000948
# Setting field to 0.000949
# Setting field to 0.00095
# Setting field to 0.000951
# Setting field to 0.000952
# Setting field to 0.000953
# Setting field to 0.000954
# Setting field to 0.000955
# Setting field to 0.000956
# Setting field to 0.000957
# Setting field to 0.000958
# Setting field to 0.000959
# Setting field to 0.00096
# Setting field to 0.000961
# Setting field to 0.000962
# Setting field to 0.000963
# Setting field to 0.000964
# Setting field to 0.000965
# Setting field to 0.000966
# Setting field to 0.000967
# Setting field to 0.000968
# Setting field to 0.000969
# Setting field to 0.00097
# Setting field to 0.000971
# Setting field to 0.000972
# Setting field to 0.000973
# Setting field to 0.000974
# Setting field to 0.000975
# Setting field to 0.000976
# Setting field to 0.000977
# Setting field to 0.000978
# Setting field to 0.000979
# Setting field to 0.00098
# Setting field to 0.000981
# Setting field to 0.000982
# Setting field to 0.000983
# Setting field to 0.000984
# Setting field to 0.000985
# Setting field to 0.000986
# Setting field to 0.000987
# Setting field to 0.000988
# Setting field to 0.000989
# Setting field to 0.00099
# Setting field to 0.000991
# Setting field to 0.000992
# Setting field to 0.000993
# Setting field to 0.000994
# Setting field to 0.000995
# Setting field to 0.000996
# Setting field to 0.000997
# Setting field to 0.000998
# Setting field to 0.000999
# Setting field to 0.001
# Setting field to 0.001001
# Setting field to 0.001002
# Setting field to 0.001003
# Setting field to 0.001004
# Setting field to 0.001005
# Setting field to 0.001006
# Setting field to 0.001007
# Setting field to 0.001008
# Setting field to 0.001009
# Setting field to 0.00101
# Setting field to 0.001011
# Setting field to 0.001012
# Setting field to 0.001013
# Setting field to 0.001014
# Setting field to 0.001015
# Setting field to 0.001016
# Setting field to 0.001017
# Setting field to 0.001018
# Setting field to 0.001019
# Setting field to 0.00102
# Setting field to 0.001021
# Setting field to 0.001022
# Setting field to 0.001023
# Setting field to 0.001024
# Setting field to 0.001025
# Setting field to 0.001026
# Setting field to 0.001027
# Setting field to 0.001028
# Setting field to 0.001029
# Setting field to 0.00103
# Setting field to 0.001031
# Setting field to 0.001032
# Setting field to 0.001033
# Setting field to 0.001034
# Setting field to 0.001035
# Setting field to 0.001036
# Setting field to 0.001037
# Setting field to 0.001038
# Setting field to 0.001039
# Setting field to 0.00104
# Setting field to 0.001041
# Setting field to 0.001042
# Setting field to 0.001043
# Setting field to 0.001044
# Setting field to 0.001045
# Setting field to 0.001046
# Setting field to 0.001047
# Setting field to 0.001048
# Setting field to 0.001049
# Setting field to 0.00105
# Setting field to 0.001051
# Setting field to 0.001052
# Setting field to 0.001053
# Setting field to 0.001054
# Setting field to 0.001055
# Setting field to 0.001056
# Setting field to 0.001057
# Setting field to 0.001058
# Setting field to 0.001059
# Setting field to 0.00106
# Setting field to 0.001061
# Setting field to 0.001062
# Setting field to 0.001063
# Setting field to 0.001064
# Setting field to 0.001065
# Setting field to 0.001066
# Setting field to 0.001067
# Setting field to 0.001068
# Setting field to 0.001069
# Setting field to 0.00107
# Setting field to 0.001071
# Setting field to 0.001072
# Setting field to 0.001073
# Setting field to 0.001074
# Setting field to 0.001075
# Setting field to 0.001076
# Setting field to 0.001077
# Setting field to 0.001078
# Setting field to 0.001079
# Setting field to 0.00108
# Setting field to 0.001081
# Setting field to 0.001082
# Setting field to 0.001083
# Setting field to 0.001084
# Setting field to 0.001085
# Setting field to 0.001086
# Setting field to 0.001087
# Setting field to 0.001088
# Setting field to 0.001089
# Setting field to 0.00109
# Setting field to 0.001091
# Setting field to 0.001092
# Setting field to 0.001093
# Setting field to 0.001094
# Setting field to 0.001095
# Setting field to 0.001096
# Setting field to 0.001097
# Setting field to 0.001098
# Setting field to 0.001099
# Setting field to 0.0011
# Setting field to 0.001101
# Setting field to 0.001102
# Setting field to 0.001103
# Setting field to 0.001104
# Setting field to 0.001105
# Setting field to 0.001106
# Setting field to 0.001107
# Setting field to 0.001108
# Setting field to 0.001109
# Setting field to 0.00111
# Setting field to 0.001111
# Setting field to 0.001112
# Setting field to 0.001113
# Setting field to 0.001114
# Setting field to 0.001115
# Setting field to 0.001116
# Setting field to 0.001117
# Setting field to 0.001118
# Setting field to 0.001119
# Setting field to 0.00112
# Setting field to 0.001121
# Setting field to 0.001122
# Setting field to 0.001123
# Setting field to 0.001124
# Setting field to 0.001125
# Setting field to 0.001126
# Setting field to 0.001127
# Setting field to 0.001128
# Setting field to 0.001129
# Setting field to 0.00113
# Setting field to 0.001131
# Setting field to 0.001132
# Setting field to 0.001133
# Setting field to 0.001134
# Setting field to 0.001135
# Setting field to 0.001136
# Setting field to 0.001137
# Setting field to 0.001138
# Setting field to 0.001139
# Setting field to 0.00114
# Setting field to 0.001141
# Setting field to 0.001142
# Setting field to 0.001143
# Setting field to 0.001144
# Setting field to 0.001145
# Setting field to 0.001146
# Setting field to 0.001147
# Setting field to 0.001148
# Setting field to 0.001149
# Setting field to 0.00115
# Setting field to 0.001151
# Setting field to 0.001152
# Setting field to 0.001153
# Setting field to 0.001154
# Setting field to 0.001155
# Setting field to 0.001156
# Setting field to 0.001157
# Setting field to 0.001158
# Setting field to 0.001159
# Setting field to 0.00116
# Setting field to 0.001161
# Setting field to 0.001162
# Setting field to 0.001163
# Setting field to 0.001164
# Setting field to 0.001165
# Setting field to 0.001166
# Setting field to 0.001167
# Setting field to 0.001168
# Setting field to 0.001169
# Setting field to 0.00117
# Setting field to 0.001171
# Setting field to 0.001172
# Setting field to 0.001173
# Setting field to 0.001174
# Setting field to 0.001175
# Setting field to 0.001176
# Setting field to 0.001177
# Setting field to 0.001178
# Setting field to 0.001179
# Setting field to 0.00118
# Setting field to 0.001181
# Setting field to 0.001182
# Setting field to 0.001183
# Setting field to 0.001184
# Setting field to 0.001185
# Setting field to 0.001186
# Setting field to 0.001187
# Setting field to 0.001188
# Setting field to 0.001189
# Setting field to 0.00119
# Setting field to 0.001191
# Setting field to 0.001192
# Setting field to 0.001193
# Setting field to 0.001194
# Setting field to 0.001195
# Setting field to 0.001196
# Setting field to 0.001197
# Setting field to 0.001198
# Setting field to 0.001199
# Setting field to 0.0012
# Setting field to 0.001201
# Setting field to 0.001202
# Setting field to 0.001203
# Setting field to 0.001204
# Setting field to 0.001205
# Setting field to 0.001206
# Setting field to 0.001207
# Setting field to 0.001208
# Setting field to 0.001209
# Setting field to 0.00121
# Setting field to 0.001211
# Setting field to 0.001212
# Setting field to 0.001213
# Setting field to 0.001214
# Setting field to 0.001215
# Setting field to 0.001216
# Setting field to 0.001217
# Setting field to 0.001218
# Setting field to 0.001219
# Setting field to 0.00122
# Setting field to 0.001221
# Setting field to 0.001222
# Setting field to 0.001223
# Setting field to 0.001224
# Setting field to 0.001225
# Setting field to 0.001226
# Setting field to 0.001227
# Setting field to 0.001228
# Setting field to 0.001229
# Setting field to 0.00123
# Setting field to 0.001231
# Setting field to 0.001232
# Setting field to 0.001233
# Setting field to 0.001234
# Setting field to 0.001235
# Setting field to 0.001236
# Setting field to 0.001237
# Setting field to 0.001238
# Setting field to 0.001239
# Setting field to 0.00124
# Setting field to 0.001241
# Setting field to 0.001242
# Setting field to 0.001243
# Setting field to 0.001244
# Setting field to 0.001245
# Setting field to 0.001246
# Setting field to 0.001247
# Setting field to 0.001248
# Setting field to 0.001249
# Setting field to 0.00125
# Setting field to 0.001251
# Setting field to 0.001252
# Setting field to 0.001253
# Setting field to 0.001254
# Setting field to 0.001255
# Setting field to 0.001256
# Setting field to 0.001257
# Setting field to 0.001258
# Setting field to 0.001259
# Setting field to 0.00126
# Setting field to 0.001261
# Setting field to 0.001262
# Setting field to 0.001263
# Setting field to 0.001264
# Setting field to 0.001265
# Setting field to 0.001266
# Setting field to 0.001267
# Setting field to 0.001268
# Setting field to 0.001269
# Setting field to 0.00127
# Setting field to 0.001271
# Setting field to 0.001272
# Setting field to 0.001273
# Setting field to 0.001274
# Setting field to 0.001275
# Setting field to 0.001276
# Setting field to 0.001277
# Setting field to 0.001278
# Setting field to 0.001279
# Setting field to 0.00128
# Setting field to 0.001281
# Setting field to 0.001282
# Setting field to 0.001283
# Setting field to 0.001284
# Setting field to 0.001285
# Setting field to 0.001286
# Setting field to 0.001287
# Setting field to 0.001288
# Setting field to 0.001289
# Setting field to 0.00129
# Setting field to 0.001291
# Setting field to 0.001292
# Setting field to 0.001293
# Setting field to 0.001294
# Setting field to 0.001295
# Setting field to 0.001296
# Setting field to 0.001297
# Setting field to 0.001298
# Setting field to 0.001299
# Setting field to 0.0013
# Setting field to 0.001301
# Setting field to 0.001302
# Setting field to 0.001303
# Setting field to 0.001304
# Setting field to 0.001305
# Setting field to 0.001306
# Setting field to 0.001307
# Setting field to 0.001308
# Setting field to 0.001309
# Setting field to 0.00131
# Setting field to 0.001311
# Setting field to 0.001312
# Setting field to 0.001313
# Setting field to 0.001314
# Setting field to 0.001315
# Setting field to 0.001316
# Setting field to 0.001317
# Setting field to 0.001318
# Setting field to 0.001319
# Setting field to 0.00132
# Setting field to 0.001321
# Setting field to 0.001322
# Setting field to 0.001323
# Setting field to 0.001324
# Setting field to 0.001325
# Setting field to 0.001326
# Setting field to 0.001327
# Setting field to 0.001328
# Setting field to 0.001329
# Setting field to 0.00133
# Setting field to 0.001331
# Setting field to 0.001332
# Setting field to 0.001333
# Setting field to 0.001334
# Setting field to 0.001335
# Setting field to 0.001336
# Setting field to 0.001337
# Setting field to 0.001338
# Setting field to 0.001339
# Setting field to 0.00134
# Setting field to 0.001341
# Setting field to 0.001342
# Setting field to 0.001343
# Setting field to 0.001344
# Setting field to 0.001345
# Setting field to 0.001346
# Setting field to 0.001347
# Setting field to 0.001348
# Setting field to 0.001349
# Setting field to 0.00135
# Setting field to 0.001351
# Setting field to 0.001352
# Setting field to 0.001353
# Setting field to 0.001354
# Setting field to 0.001355
# Setting field to 0.001356
# Setting field to 0.001357
# Setting field to 0.001358
# Setting field to 0.001359
# Setting field to 0.00136
# Setting field to 0.001361
# Setting field to 0.001362
# Setting field to 0.001363
# Setting field to 0.001364
# Setting field to 0.001365
# Setting field to 0.001366
# Setting field to 0.001367
# Setting field to 0.001368
# Setting field to 0.001369
# Setting field to 0.00137
# Setting field to 0.001371
# Setting field to 0.001372
# Setting field to 0.001373
# Setting field to 0.001374
# Setting field to 0.001375
# Setting field to 0.001376
# Setting field to 0.001377
# Setting field to 0.001378
# Setting field to 0.001379
# Setting field to 0.00138
# Setting field to 0.001381
# Setting field to 0.001382
# Setting field to 0.001383
# Setting field to 0.001384
# Setting field to 0.001385
# Setting field to 0.001386
# Setting field to 0.001387
# Setting field to 0.001388
# Setting field to 0.001389
# Setting field to 0.00139
# Setting field to 0.001391
# Setting field to 0.001392
# Setting field to 0.001393
# Setting field to 0.001394
# Setting field to 0.001395
# Setting field to 0.001396
# Setting field to 0.001397
# Setting field to 0.001398
# Setting field to 0.001399
# Setting field to 0.0014
# Setting field to 0.001401
# Setting field to 0.001402
# Setting field to 0.001403
# Setting field to 0.001404
# Setting field to 0.001405
# Setting field to 0.001406
# Setting field to 0.001407
# Setting field to 0.001408
# Setting field to 0.001409
# Setting field to 0.00141
# Setting field to 0.001411
# Setting field to 0.001412
# Setting field to 0.001413
# Setting field to 0.001414
# Setting field to 0.001415
# Setting field to 0.001416
# Setting field to 0.001417
# Setting field to 0.001418
# Setting field to 0.001419
# Setting field to 0.00142
# Setting field to 0.001421
# Setting field to 0.001422
# Setting field to 0.001423
# Setting field to 0.001424
# Setting field to 0.001425
# Setting field to 0.001426
# Setting field to 0.001427
# Setting field to 0.001428
# Setting field to 0.001429
# Setting field to 0.00143
# Setting field to 0.001431
# Setting field to 0.001432
# Setting field to 0.001433
# Setting field to 0.001434
# Setting field to 0.001435
# Setting field to 0.001436
# Setting field to 0.001437
# Setting field to 0.001438
# Setting field to 0.001439
# Setting field to 0.00144
# Setting field to 0.001441
# Setting field to 0.001442
# Setting field to 0.001443
# Setting field to 0.001444
# Setting field to 0.001445
# Setting field to 0.001446
# Setting field to 0.001447
# Setting field to 0.001448
# Setting field to 0.001449
# Setting field to 0.00145
# Setting field to 0.001451
# Setting field to 0.001452
# Setting field to 0.001453
# Setting field to 0.001454
# Setting field to 0.001455
# Setting field to 0.001456
# Setting field to 0.001457
# Setting field to 0.001458
# Setting field to 0.001459
# Setting field to 0.00146
# Setting field to 0.001461
# Setting field to 0.001462
# Setting field to 0.001463
# Setting field to 0.001464
# Setting field to 0.001465
# Setting field to 0.001466
# Setting field to 0.001467
# Setting field to 0.001468
# Setting field to 0.001469
# Setting field to 0.00147
# Setting field to 0.001471
# Setting field to 0.001472
# Setting field to 0.001473
# Setting field to 0.001474
# Setting field to 0.001475
# Setting field to 0.001476
# Setting field to 0.001477
# Setting field to 0.001478
# Setting field to 0.001479
# Setting field to 0.00148
# Setting field to 0.001481
# Setting field to 0.001482
# Setting field to 0.001483
# Setting field to 0.001484
# Setting field to 0.001485
# Setting field to 0.001486
# Setting field to 0.001487
# Setting field to 0.001488
# Setting field to 0.001489
# Setting field to 0.00149
# Setting field to 0.001491
# Setting field to 0.001492
# Setting field to 0.001493
# Setting field to 0.001494
# Setting field to 0.001495
# Setting field to 0.001496
# Setting field to 0.001497
# Setting field to 0.001498
# Setting field to 0.001499
# Setting field to 0.0015
# Setting field to 0.001501
# Setting field to 0.001502
# Setting field to 0.001503
# Setting field to 0.001504
# Setting field to 0.001505
# Setting field to 0.001506
# Setting field to 0.001507
# Setting field to 0.001508
# Setting field to 0.001509
# Setting field to 0.00151
# Setting field to 0.001511
# Setting field to 0.001512
# Setting field to 0.001513
# Setting field to 0.001514
# Setting field to 0.001515
# Setting field to 0.001516
# Setting field to 0.001517
# Setting field to 0.001518
# Setting field to 0.001519
# Setting field to 0.00152
# Setting field to 0.001521
# Setting field to 0.001522
# Setting field to 0.001523
# Setting field to 0.001524
# Setting field to 0.001525
# Setting field to 0.001526
# Setting field to 0.001527
# Setting field to 0.001528
# Setting field to 0.001529
# Setting field to 0.00153
# Setting field to 0.001531
# Setting field to 0.001532
# Setting field to 0.001533
# Setting field to 0.001534
# Setting field to 0.001535
# Setting field to 0.001536
# Setting field to 0.001537
# Setting field to 0.001538
# Setting field to 0.001539
# Setting field to 0.00154
# Setting field to 0.001541
# Setting field to 0.001542
# Setting field to 0.001543
# Setting field to 0.001544
# Setting field to 0.001545
# Setting field to 0.001546
# Setting field to 0.001547
# Setting field to 0.001548
# Setting field to 0.001549
# Setting field to 0.00155
# Setting field to 0.001551
# Setting field to 0.001552
# Setting field to 0.001553
# Setting field to 0.001554
# Setting field to 0.001555
# Setting field to 0.001556
# Setting field to 0.001557
# Setting field to 0.001558
# Setting field to 0.001559
# Setting field to 0.00156
# Setting field to 0.001561
# Setting field to 0.001562
# Setting field to 0.001563
# Setting field to 0.001564
# Setting field to 0.001565
# Setting field to 0.001566
# Setting field to 0.001567
# Setting field to 0.001568
# Setting field to 0.001569
# Setting field to 0.00157
# Setting field to 0.001571
# Setting field to 0.001572
# Setting field to 0.001573
# Setting field to 0.001574
# Setting field to 0.001575
# Setting field to 0.001576
# Setting field to 0.001577
# Setting field to 0.001578
# Setting field to 0.001579
# Setting field to 0.00158
# Setting field to 0.001581
# Setting field to 0.001582
# Setting field to 0.001583
# Setting field to 0.001584
# Setting field to 0.001585
# Setting field to 0.001586
# Setting field to 0.001587
# Setting field to 0.001588
# Setting field to 0.001589
# Setting field to 0.00159
# Setting field to 0.001591
# Setting field to 0.001592
# Setting field to 0.001593
# Setting field to 0.001594
# Setting field to 0.001595
# Setting field to 0.001596
# Setting field to 0.001597
# Setting field to 0.001598
# Setting field to 0.001599
# Setting field to 0.0016
# Setting field to 0.001601
# Setting field to 0.001602
# Setting field to 0.001603
# Setting field to 0.001604
# Setting field to 0.001605
# Setting field to 0.001606
# Setting field to 0.001607
# Setting field to 0.001608
# Setting field to 0.001609
# Setting field to 0.00161
# Setting field to 0.001611
# Setting field to 0.001612
# Setting field to 0.001613
# Setting field to 0.001614
# Setting field to 0.001615
# Setting field to 0.001616
# Setting field to 0.001617
# Setting field to 0.001618
# Setting field to 0.001619
# Setting field to 0.00162
# Setting field to 0.001621
# Setting field to 0.001622
# Setting field to 0.001623
# Setting field to 0.001624
# Setting field to 0.001625
# Setting field to 0.001626
# Setting field to 0.001627
# Setting field to 0.001628
# Setting field to 0.001629
# Setting field to 0.00163
# Setting field to 0.001631
# Setting field to 0.001632
# Setting field to 0.001633
# Setting field to 0.001634
# Setting field to 0.001635
# Setting field to 0.001636
# Setting field to 0.001637
# Setting field to 0.001638
# Setting field to 0.001639
# Setting field to 0.00164
# Setting field to 0.001641
# Setting field to 0.001642
# Setting field to 0.001643
# Setting field to 0.001644
# Setting field to 0.001645
# Setting field to 0.001646
# Setting field to 0.001647
# Setting field to 0.001648
# Setting field to 0.001649
# Setting field to 0.00165
# Setting field to 0.001651
# Setting field to 0.001652
# Setting field to 0.001653
# Setting field to 0.001654
# Setting field to 0.001655
# Setting field to 0.001656
# Setting field to 0.001657
# Setting field to 0.001658
# Setting field to 0.001659
# Setting field to 0.00166
# Setting field to 0.001661
# Setting field to 0.001662
# Setting field to 0.001663
# Setting field to 0.001664
# Setting field to 0.001665
# Setting field to 0.001666
# Setting field to 0.001667
# Setting field to 0.001668
# Setting field to 0.001669
# Setting field to 0.00167
# Setting field to 0.001671
# Setting field to 0.001672
# Setting field to 0.001673
# Setting field to 0.001674
# Setting field to 0.001675
# Setting field to 0.001676
# Setting field to 0.001677
# Setting field to 0.001678
# Setting field to 0.001679
# Setting field to 0.00168
# Setting field to 0.001681
# Setting field to 0.001682
# Setting field to 0.001683
# Setting field to 0.001684
# Setting field to 0.001685
# Setting field to 0.001686
# Setting field to 0.001687
# Setting field to 0.001688
# Setting field to 0.001689
# Setting field to 0.00169
# Setting field to 0.001691
# Setting field to 0.001692
# Setting field to 0.001693
# Setting field to 0.001694
# Setting field to 0.001695
# Setting field to 0.001696
# Setting field to 0.001697
# Setting field to 0.001698
# Setting field to 0.001699
# Setting field to 0.0017
# Setting field to 0.001701
# Setting field to 0.001702
# Setting field to 0.001703
# Setting field to 0.001704
# Setting field to 0.001705
# Setting field to 0.001706
# Setting field to 0.001707
# Setting field to 0.001708
# Setting field to 0.001709
# Setting field to 0.00171
# Setting field to 0.001711
# Setting field to 0.001712
# Setting field to 0.001713
# Setting field to 0.001714
# Setting field to 0.001715
# Setting field to 0.001716
# Setting field to 0.001717
# Setting field to 0.001718
# Setting field to 0.001719
# Setting field to 0.00172
# Setting field to 0.001721
# Setting field to 0.001722
# Setting field to 0.001723
# Setting field to 0.001724
# Setting field to 0.001725
# Setting field to 0.001726
# Setting field to 0.001727
# Setting field to 0.001728
# Setting field to 0.001729
# Setting field to 0.00173
# Setting field to 0.001731
# Setting field to 0.001732
# Setting field to 0.001733
# Setting field to 0.001734
# Setting field to 0.001735
# Setting field to 0.001736
# Setting field to 0.001737
# Setting field to 0.001738
# Setting field to 0.001739
# Setting field to 0.00174
# Setting field to 0.001741
# Setting field to 0.001742
# Setting field to 0.001743
# Setting field to 0.001744
# Setting field to 0.001745
# Setting field to 0.001746
# Setting field to 0.001747
# Setting field to 0.001748
# Setting field to 0.001749
# Setting field to 0.00175
# Setting field to 0.001751
# Setting field to 0.001752
# Setting field to 0.001753
# Setting field to 0.001754
# Setting field to 0.001755
# Setting field to 0.001756
# Setting field to 0.001757
# Setting field to 0.001758
# Setting field to 0.001759
# Setting field to 0.00176
# Setting field to 0.001761
# Setting field to 0.001762
# Setting field to 0.001763
# Setting field to 0.001764
# Setting field to 0.001765
# Setting field to 0.001766
# Setting field to 0.001767
# Setting field to 0.001768
# Setting field to 0.001769
# Setting field to 0.00177
# Setting field to 0.001771
# Setting field to 0.001772
# Setting field to 0.001773
# Setting field to 0.001774
# Setting field to 0.001775
# Setting field to 0.001776
# Setting field to 0.001777
# Setting field to 0.001778
# Setting field to 0.001779
# Setting field to 0.00178
# Setting field to 0.001781
# Setting field to 0.001782
# Setting field to 0.001783
# Setting field to 0.001784
# Setting field to 0.001785
# Setting field to 0.001786
# Setting field to 0.001787
# Setting field to 0.001788
# Setting field to 0.001789
# Setting field to 0.00179
# Setting field to 0.001791
# Setting field to 0.001792
# Setting field to 0.001793
# Setting field to 0.001794
# Setting field to 0.001795
# Setting field to 0.001796
# Setting field to 0.001797
# Setting field to 0.001798
# Setting field to 0.001799
# Setting field to 0.0018
# Setting field to 0.001801
# Setting field to 0.001802
# Setting field to 0.001803
# Setting field to 0.001804
# Setting field to 0.001805
# Setting field to 0.001806
# Setting field to 0.001807
# Setting field to 0.001808
# Setting field to 0.001809
# Setting field to 0.00181
# Setting field to 0.001811
# Setting field to 0.001812
# Setting field to 0.001813
# Setting field to 0.001814
# Setting field to 0.001815
# Setting field to 0.001816
# Setting field to 0.001817
# Setting field to 0.001818
# Setting field to 0.001819
# Setting field to 0.00182
# Setting field to 0.001821
# Setting field to 0.001822
# Setting field to 0.001823
# Setting field to 0.001824
# Setting field to 0.001825
# Setting field to 0.001826
# Setting field to 0.001827
# Setting field to 0.001828
# Setting field to 0.001829
# Setting field to 0.00183
# Setting field to 0.001831
# Setting field to 0.001832
# Setting field to 0.001833
# Setting field to 0.001834
# Setting field to 0.001835
# Setting field to 0.001836
# Setting field to 0.001837
# Setting field to 0.001838
# Setting field to 0.001839
# ...
# Setting field to 0.001904
# Setting field to 0.001905
# Setting field to 0.001906
# Setting field to 0.001907
# Setting field to 0.001908
# Setting field to 0.001909
# Setting field to 0.00191
# Setting field to 0.001911
# Setting field to 0.001912
# Setting field to 0.001913
# Setting field to 0.001914
# Setting field to 0.001915
# Setting field to 0.001916
# Setting field to 0.001917
# Setting field to 0.001918
# Setting field to 0.001919
# Setting field to 0.00192
# Setting field to 0.001921
# Setting field to 0.001922
# Setting field to 0.001923
# Setting field to 0.001924
# Setting field to 0.001925
# Setting field to 0.001926
# Setting field to 0.001927
# Setting field to 0.001928
# Setting field to 0.001929
# Setting field to 0.00193
# Setting field to 0.001931
# Setting field to 0.001932
# Setting field to 0.001933
# Setting field to 0.001934
# Setting field to 0.001935
# Setting field to 0.001936
# Setting field to 0.001937
# Setting field to 0.001938
# Setting field to 0.001939
# Setting field to 0.00194
# Setting field to 0.001941
# Setting field to 0.001942
# Setting field to 0.001943
# Setting field to 0.001944
# Setting field to 0.001945
# Setting field to 0.001946
# Setting field to 0.001947
# Setting field to 0.001948
# Setting field to 0.001949
# Setting field to 0.00195
# Setting field to 0.001951
# Setting field to 0.001952
# Setting field to 0.001953
# Setting field to 0.001954
# Setting field to 0.001955
# Setting field to 0.001956
# Setting field to 0.001957
# Setting field to 0.001958
# Setting field to 0.001959
# Setting field to 0.00196
# Setting field to 0.001961
# Setting field to 0.001962
# Setting field to 0.001963
# Setting field to 0.001964
# Setting field to 0.001965
# Setting field to 0.001966
# Setting field to 0.001967
# Setting field to 0.001968
# Setting field to 0.001969
# Setting field to 0.00197
# Setting field to 0.001971
# Setting field to 0.001972
# Setting field to 0.001973
# Setting field to 0.001974
# Setting field to 0.001975
# Setting field to 0.001976
# Setting field to 0.001977
# Setting field to 0.001978
# Setting field to 0.001979
# Setting field to 0.00198
# Setting field to 0.001981
# Setting field to 0.001982
# Setting field to 0.001983
# Setting field to 0.001984
# Setting field to 0.001985
# Setting field to 0.001986
# Setting field to 0.001987
# Setting field to 0.001988
# Setting field to 0.001989
# Setting field to 0.00199
# Setting field to 0.001991
# Setting field to 0.001992
# Setting field to 0.001993
# Setting field to 0.001994
# Setting field to 0.001995
# Setting field to 0.001996
# Setting field to 0.001997
# Setting field to 0.001998
# Setting field to 0.001999
# Setting field to 0.002
# Setting field to 0.002001
# Setting field to 0.002002
# Setting field to 0.002003
# Setting field to 0.002004
# Setting field to 0.002005
# Setting field to 0.002006
# Setting field to 0.002007
# Setting field to 0.002008
# Setting field to 0.002009
# Setting field to 0.00201
# Setting field to 0.002011
# Setting field to 0.002012
# Setting field to 0.002013
# Setting field to 0.002014
# Setting field to 0.002015
# Setting field to 0.002016
# Setting field to 0.002017
# Setting field to 0.002018
# Setting field to 0.002019
# Setting field to 0.00202
# Setting field to 0.002021
# Setting field to 0.002022
# Setting field to 0.002023
# Setting field to 0.002024
# Setting field to 0.002025
# Setting field to 0.002026
# Setting field to 0.002027
# Setting field to 0.002028
# Setting field to 0.002029
# Setting field to 0.00203
# Setting field to 0.002031
# Setting field to 0.002032
# Setting field to 0.002033
# Setting field to 0.002034
# Setting field to 0.002035
# Setting field to 0.002036
# Setting field to 0.002037
# Setting field to 0.002038
# Setting field to 0.002039
# Setting field to 0.00204
# Setting field to 0.002041
# Setting field to 0.002042
# Setting field to 0.002043
# Setting field to 0.002044
# Setting field to 0.002045
# Setting field to 0.002046
# Setting field to 0.002047
# Setting field to 0.002048
# Setting field to 0.002049
# Setting field to 0.00205
# Setting field to 0.002051
# Setting field to 0.002052
# Setting field to 0.002053
# Setting field to 0.002054
# Setting field to 0.002055
# Setting field to 0.002056
# Setting field to 0.002057
# Setting field to 0.002058
# Setting field to 0.002059
# Setting field to 0.00206
# Setting field to 0.002061
# Setting field to 0.002062
# Setting field to 0.002063
# Setting field to 0.002064
# Setting field to 0.002065
# Setting field to 0.002066
# Setting field to 0.002067
# Setting field to 0.002068
# Setting field to 0.002069
# Setting field to 0.00207
# Setting field to 0.002071
# Setting field to 0.002072
# Setting field to 0.002073
# Setting field to 0.002074
# Setting field to 0.002075
# Setting field to 0.002076
# Setting field to 0.002077
# Setting field to 0.002078
# Setting field to 0.002079
# Setting field to 0.00208
# Setting field to 0.002081
# Setting field to 0.002082
# Setting field to 0.002083
# Setting field to 0.002084
# Setting field to 0.002085
# Setting field to 0.002086
# Setting field to 0.002087
# Setting field to 0.002088
# Setting field to 0.002089
# Setting field to 0.00209
# Setting field to 0.002091
# Setting field to 0.002092
# Setting field to 0.002093
# Setting field to 0.002094
# Setting field to 0.002095
# Setting field to 0.002096
# Setting field to 0.002097
# Setting field to 0.002098
# Setting field to 0.002099
# Setting field to 0.0021
# Setting field to 0.002101
# Setting field to 0.002102
# Setting field to 0.002103
# Setting field to 0.002104
# Setting field to 0.002105
# Setting field to 0.002106
# Setting field to 0.002107
# Setting field to 0.002108
# Setting field to 0.002109
# Setting field to 0.00211
# Setting field to 0.002111
# Setting field to 0.002112
# Setting field to 0.002113
# Setting field to 0.002114
# Setting field to 0.002115
# Setting field to 0.002116
# Setting field to 0.002117
# Setting field to 0.002118
# Setting field to 0.002119
# Setting field to 0.00212
# Setting field to 0.002121
# Setting field to 0.002122
# Setting field to 0.002123
# Setting field to 0.002124
# Setting field to 0.002125
# Setting field to 0.002126
# Setting field to 0.002127
# Setting field to 0.002128
# Setting field to 0.002129
# Setting field to 0.00213
# Setting field to 0.002131
# Setting field to 0.002132
# Setting field to 0.002133
# Setting field to 0.002134
# Setting field to 0.002135
# Setting field to 0.002136
# Setting field to 0.002137
# Setting field to 0.002138
# Setting field to 0.002139
# Setting field to 0.00214
# Setting field to 0.002141
# Setting field to 0.002142
# Setting field to 0.002143
# Setting field to 0.002144
# Setting field to 0.002145
# Setting field to 0.002146
# Setting field to 0.002147
# Setting field to 0.002148
# Setting field to 0.002149
# Setting field to 0.00215
# Setting field to 0.002151
# Setting field to 0.002152
# Setting field to 0.002153
# Setting field to 0.002154
# Setting field to 0.002155
# Setting field to 0.002156
# Setting field to 0.002157
# Setting field to 0.002158
# Setting field to 0.002159
# Setting field to 0.00216
# Setting field to 0.002161
# Setting field to 0.002162
# Setting field to 0.002163
# Setting field to 0.002164
# Setting field to 0.002165
# Setting field to 0.002166
# Setting field to 0.002167
# Setting field to 0.002168
# Setting field to 0.002169
# Setting field to 0.00217
# Setting field to 0.002171
# Setting field to 0.002172
# Setting field to 0.002173
# Setting field to 0.002174
# Setting field to 0.002175
# Setting field to 0.002176
# Setting field to 0.002177
# Setting field to 0.002178
# Setting field to 0.002179
# Setting field to 0.00218
# Setting field to 0.002181
# Setting field to 0.002182
# Setting field to 0.002183
# Setting field to 0.002184
# Setting field to 0.002185
# Setting field to 0.002186
# Setting field to 0.002187
# Setting field to 0.002188
# Setting field to 0.002189
# Setting field to 0.00219
# Setting field to 0.002191
# Setting field to 0.002192
# Setting field to 0.002193
# Setting field to 0.002194
# Setting field to 0.002195
# Setting field to 0.002196
# Setting field to 0.002197
# Setting field to 0.002198
# Setting field to 0.002199
# Setting field to 0.0022
# Setting field to 0.002201
# Setting field to 0.002202
# Setting field to 0.002203
# Setting field to 0.002204
# Setting field to 0.002205
# Setting field to 0.002206
# Setting field to 0.002207
# Setting field to 0.002208
# Setting field to 0.002209
# Setting field to 0.00221
# Setting field to 0.002211
# Setting field to 0.002212
# Setting field to 0.002213
# Setting field to 0.002214
# Setting field to 0.002215
# Setting field to 0.002216
# Setting field to 0.002217
# Setting field to 0.002218
# Setting field to 0.002219
# Setting field to 0.00222
# Setting field to 0.002221
# Setting field to 0.002222
# Setting field to 0.002223
# Setting field to 0.002224
# Setting field to 0.002225
# Setting field to 0.002226
# Setting field to 0.002227
# Setting field to 0.002228
# Setting field to 0.002229
# Setting field to 0.00223
# Setting field to 0.002231
# Setting field to 0.002232
# Setting field to 0.002233
# Setting field to 0.002234
# Setting field to 0.002235
# Setting field to 0.002236
# Setting field to 0.002237
# Setting field to 0.002238
# Setting field to 0.002239
# Setting field to 0.00224
# Setting field to 0.002241
# Setting field to 0.002242
# Setting field to 0.002243
# Setting field to 0.002244
# Setting field to 0.002245
# Setting field to 0.002246
# Setting field to 0.002247
# Setting field to 0.002248
# Setting field to 0.002249
# Setting field to 0.00225
# Setting field to 0.002251
# Setting field to 0.002252
# Setting field to 0.002253
# Setting field to 0.002254
# Setting field to 0.002255
# Setting field to 0.002256
# Setting field to 0.002257
# Setting field to 0.002258
# Setting field to 0.002259
# Setting field to 0.00226
# Setting field to 0.002261
# Setting field to 0.002262
# Setting field to 0.002263
# Setting field to 0.002264
# Setting field to 0.002265
# Setting field to 0.002266
# Setting field to 0.002267
# Setting field to 0.002268
# Setting field to 0.002269
# Setting field to 0.00227
# Setting field to 0.002271
# Setting field to 0.002272
# Setting field to 0.002273
# Setting field to 0.002274
# Setting field to 0.002275
# Setting field to 0.002276
# Setting field to 0.002277
# Setting field to 0.002278
# Setting field to 0.002279
# Setting field to 0.00228
# Setting field to 0.002281
# Setting field to 0.002282
# Setting field to 0.002283
# Setting field to 0.002284
# Setting field to 0.002285
# Setting field to 0.002286
# Setting field to 0.002287
# Setting field to 0.002288
# Setting field to 0.002289
# Setting field to 0.00229
# Setting field to 0.002291
# Setting field to 0.002292
# Setting field to 0.002293
# Setting field to 0.002294
# Setting field to 0.002295
# Setting field to 0.002296
# Setting field to 0.002297
# Setting field to 0.002298
# Setting field to 0.002299
# Setting field to 0.0023
# Setting field to 0.002301
# Setting field to 0.002302
# Setting field to 0.002303
# Setting field to 0.002304
# Setting field to 0.002305
# Setting field to 0.002306
# Setting field to 0.002307
# Setting field to 0.002308
# Setting field to 0.002309
# Setting field to 0.00231
# Setting field to 0.002311
# Setting field to 0.002312
# Setting field to 0.002313
# Setting field to 0.002314
# Setting field to 0.002315
# Setting field to 0.002316
# Setting field to 0.002317
# Setting field to 0.002318
# Setting field to 0.002319
# Setting field to 0.00232
# Setting field to 0.002321
# Setting field to 0.002322
# Setting field to 0.002323
# Setting field to 0.002324
# Setting field to 0.002325
# Setting field to 0.002326
# Setting field to 0.002327
# Setting field to 0.002328
# Setting field to 0.002329
# Setting field to 0.00233
# Setting field to 0.002331
# Setting field to 0.002332
# Setting field to 0.002333
# Setting field to 0.002334
# Setting field to 0.002335
# Setting field to 0.002336
# Setting field to 0.002337
# Setting field to 0.002338
# Setting field to 0.002339
# Setting field to 0.00234
# Setting field to 0.002341
# Setting field to 0.002342
# Setting field to 0.002343
# Setting field to 0.002344
# Setting field to 0.002345
# Setting field to 0.002346
# Setting field to 0.002347
# Setting field to 0.002348
# Setting field to 0.002349
# Setting field to 0.00235
# Setting field to 0.002351
# Setting field to 0.002352
# Setting field to 0.002353
# Setting field to 0.002354
# Setting field to 0.002355
# Setting field to 0.002356
# Setting field to 0.002357
# Setting field to 0.002358
# Setting field to 0.002359
# Setting field to 0.00236
# Setting field to 0.002361
# Setting field to 0.002362
# Setting field to 0.002363
# Setting field to 0.002364
# Setting field to 0.002365
# Setting field to 0.002366
# Setting field to 0.002367
# Setting field to 0.002368
# Setting field to 0.002369
# Setting field to 0.00237
# Setting field to 0.002371
# Setting field to 0.002372
# Setting field to 0.002373
# Setting field to 0.002374
# Setting field to 0.002375
# Setting field to 0.002376
# Setting field to 0.002377
# Setting field to 0.002378
# Setting field to 0.002379
# Setting field to 0.00238
# Setting field to 0.002381
# Setting field to 0.002382
# Setting field to 0.002383
# Setting field to 0.002384
# Setting field to 0.002385
# Setting field to 0.002386
# Setting field to 0.002387
# Setting field to 0.002388
# Setting field to 0.002389
# Setting field to 0.00239
# Setting field to 0.002391
# Setting field to 0.002392
# Setting field to 0.002393
# Setting field to 0.002394
# Setting field to 0.002395
# Setting field to 0.002396
# Setting field to 0.002397
# Setting field to 0.002398
# Setting field to 0.002399
# Setting field to 0.0024
# Setting field to 0.002401
# Setting field to 0.002402
# Setting field to 0.002403
# Setting field to 0.002404
# Setting field to 0.002405
# Setting field to 0.002406
# Setting field to 0.002407
# Setting field to 0.002408
# Setting field to 0.002409
# Setting field to 0.00241
# Setting field to 0.002411
# Setting field to 0.002412
# Setting field to 0.002413
# Setting field to 0.002414
# Setting field to 0.002415
# Setting field to 0.002416
# Setting field to 0.002417
# Setting field to 0.002418
# Setting field to 0.002419
# Setting field to 0.00242
# Setting field to 0.002421
# Setting field to 0.002422
# Setting field to 0.002423
# Setting field to 0.002424
# Setting field to 0.002425
# Setting field to 0.002426
# Setting field to 0.002427
# Setting field to 0.002428
# Setting field to 0.002429
# Setting field to 0.00243
# Setting field to 0.002431
# Setting field to 0.002432
# Setting field to 0.002433
# Setting field to 0.002434
# Setting field to 0.002435
# Setting field to 0.002436
# Setting field to 0.002437
# Setting field to 0.002438
# Setting field to 0.002439
# Setting field to 0.00244
# Setting field to 0.002441
# Setting field to 0.002442
# Setting field to 0.002443
# Setting field to 0.002444
# Setting field to 0.002445
# Setting field to 0.002446
# Setting field to 0.002447
# Setting field to 0.002448
# Setting field to 0.002449
# Setting field to 0.00245
# Setting field to 0.002451
# Setting field to 0.002452
# Setting field to 0.002453
# Setting field to 0.002454
# Setting field to 0.002455
# Setting field to 0.002456
# Setting field to 0.002457
# Setting field to 0.002458
# Setting field to 0.002459
# Setting field to 0.00246
# Setting field to 0.002461
# Setting field to 0.002462
# Setting field to 0.002463
# Setting field to 0.002464
# Setting field to 0.002465
# Setting field to 0.002466
# Setting field to 0.002467
# Setting field to 0.002468
# Setting field to 0.002469
# Setting field to 0.00247
# Setting field to 0.002471
# Setting field to 0.002472
# Setting field to 0.002473
# Setting field to 0.002474
# Setting field to 0.002475
# Setting field to 0.002476
# Setting field to 0.002477
# Setting field to 0.002478
# Setting field to 0.002479
# Setting field to 0.00248
# Setting field to 0.002481
# Setting field to 0.002482
# Setting field to 0.002483
# Setting field to 0.002484
# Setting field to 0.002485
# Setting field to 0.002486
# Setting field to 0.002487
# Setting field to 0.002488
# Setting field to 0.002489
# Setting field to 0.00249
# Setting field to 0.002491
# Setting field to 0.002492
# Setting field to 0.002493
# Setting field to 0.002494
# Setting field to 0.002495
# Setting field to 0.002496
# Setting field to 0.002497
# Setting field to 0.002498
# Setting field to 0.002499
# ramping up gates
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-235-7e20ca9ad348> in <module>()
#      43     print("ramping up gates")
#      44     for gate in gate_name:
# ---> 45         ramp(MDAC_channels[gate].voltage, gate_voltages, gate_ramp_stepsize, gate_ramp_delay)
#      46     #take a trace around f first after ramping back the gates to check where we are
#      47     print(" Time elapsed: %.4f" % (time.time()-t0))
#
# KeyError: 'V_cut_A'

# %%
power = -33
n_pts = 200
n_avg = 200
f = 4.84725e9 #4.48725
t0 = time.time()
take_trace_at_beginning = True
ramp_back_gates = False

B_fields = np.append(np.append(np.append(np.arange(0,0.2e-3,1e-6), np.arange(0.2e-3,-0.2e-3,-1e-6)), np.arange(-0.2e-3,0.2e-3,1e-6)), np.arange(0.2e-3,-0.2e-3,-1e-6))


gate_voltages = 4
gate_name = ['V_cut_A', 'V_bot_A', 'V_pl_A']

resonators = ['A','C', 'B']
gate_vals = [3.76,2.5, 2.5]
fs = [f_readouts[2], f_readouts[1], f_readouts[3]]

for i in range(0,len(gate_vals)):
    f = fs[i]
    resonator=resonators[i]
    exp = qc.new_experiment("Res %s single freq field sweep all_gates=%.2f f=%.5e power=%d n=%d x %d" %(resonators[i],gate_vals[i],f, power, n_pts, n_avg)  , sample_name="abs_w1_5_1_1")


    #ramp all gates of resonator X
    gate_channels =list(MDAC_channels[resonator].values())
    gate_names = list(MDAC_channels[resonator].keys())

    print("ramping up gates")
    for gate_chan in gate_channels:
        print("ramping gate %s " % gate_chan)
        ramp(gate_chan.voltage, gate_vals[i], gate_ramp_stepsize, gate_ramp_delay)
    #take a trace around f first after ramping back the gates to check where we are
    if take_trace_at_beginning:
        print("Taking single sweep")
        t0=time.time()
        do_single_sweep(n_pts = 100, f_start = f-5e6, f_stop = f+5e6, power=power, n_avg=1000, channel_name='S21')
        print("Taking trace took", time.time()-t0)

    #now do the real thing
    do_field_sweep_single_frequency(B_fields, power=power, n_pts = n_pts, f = f, n_avg=n_avg, channel_name='S21')


    #take a trace around f first after ramping back the gates to check where we are
    print(" Time elapsed: %.4f" % (time.time()-t0))
    for gate_chan in gate_channels:
        print("ramping gate %s down " % gate_chan)
        ramp(gate_chan.voltage, 0, gate_ramp_stepsize, gate_ramp_delay)
# Out:
# ramping up gates
# ramping gate <MDACChannel: MDAC_chan2 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan1 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan3 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan4 of MDAC: MDAC>
# Taking single sweep
# Starting experimental run with id: 71
# Taking trace took 13.065943956375122
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 72
# Setting field to 0.0
# Setting field to 1e-06
# Setting field to 2e-06
# Setting field to 3e-06
# Setting field to 4e-06
# Setting field to 5e-06
# Setting field to 6e-06
# Setting field to 7e-06
# Setting field to 8e-06
# Setting field to 9e-06
# Setting field to 1e-05
# Setting field to 1.1e-05
# Setting field to 1.2e-05
# Setting field to 1.3e-05
# Setting field to 1.4e-05
# Setting field to 1.5e-05
# Setting field to 1.6e-05
# Setting field to 1.7e-05
# Setting field to 1.8e-05
# Setting field to 1.9e-05
# Setting field to 2e-05
# Setting field to 2.1e-05
# Setting field to 2.2e-05
# Setting field to 2.3e-05
# Setting field to 2.4e-05
# Setting field to 2.5e-05
# Setting field to 2.6e-05
# Setting field to 2.7e-05
# Setting field to 2.8e-05
# Setting field to 2.9e-05
# Setting field to 3e-05
# Setting field to 3.1e-05
# Setting field to 3.2e-05
# Setting field to 3.3e-05
# Setting field to 3.4e-05
# Setting field to 3.5e-05
# Setting field to 3.6e-05
# Setting field to 3.7e-05
# Setting field to 3.8e-05
# Setting field to 3.9e-05
# Setting field to 4e-05
# Setting field to 4.1e-05
# Setting field to 4.2e-05
# Setting field to 4.3e-05
# Setting field to 4.4e-05
# Setting field to 4.5e-05
# Setting field to 4.6e-05
# Setting field to 4.7e-05
# Setting field to 4.8e-05
# Setting field to 4.9e-05
# Setting field to 5e-05
# Setting field to 5.1e-05
# Setting field to 5.2e-05
# Setting field to 5.3e-05
# Setting field to 5.4e-05
# Setting field to 5.5e-05
# Setting field to 5.6e-05
# Setting field to 5.7e-05
# Setting field to 5.8e-05
# Setting field to 5.9e-05
# Setting field to 6e-05
# Setting field to 6.1e-05
# Setting field to 6.2e-05
# Setting field to 6.3e-05
# Setting field to 6.4e-05
# Setting field to 6.5e-05
# Setting field to 6.6e-05
# Setting field to 6.7e-05
# Setting field to 6.8e-05
# Setting field to 6.9e-05
# Setting field to 7e-05
# Setting field to 7.1e-05
# Setting field to 7.2e-05
# Setting field to 7.3e-05
# Setting field to 7.4e-05
# Setting field to 7.5e-05
# Setting field to 7.6e-05
# Setting field to 7.7e-05
# Setting field to 7.8e-05
# Setting field to 7.9e-05
# Setting field to 8e-05
# Setting field to 8.1e-05
# Setting field to 8.2e-05
# Setting field to 8.3e-05
# Setting field to 8.4e-05
# Setting field to 8.5e-05
# Setting field to 8.6e-05
# Setting field to 8.7e-05
# Setting field to 8.8e-05
# Setting field to 8.9e-05
# Setting field to 9e-05
# Setting field to 9.1e-05
# Setting field to 9.2e-05
# Setting field to 9.3e-05
# Setting field to 9.4e-05
# Setting field to 9.5e-05
# Setting field to 9.6e-05
# Setting field to 9.7e-05
# Setting field to 9.8e-05
# Setting field to 9.9e-05
# Setting field to 0.0001
# Setting field to 0.000101
# Setting field to 0.000102
# Setting field to 0.000103
# Setting field to 0.000104
# Setting field to 0.000105
# Setting field to 0.000106
# Setting field to 0.000107
# Setting field to 0.000108
# Setting field to 0.000109
# Setting field to 0.00011
# Setting field to 0.000111
# Setting field to 0.000112
# Setting field to 0.000113
# Setting field to 0.000114
# Setting field to 0.000115
# Setting field to 0.000116
# Setting field to 0.000117
# Setting field to 0.000118
# Setting field to 0.000119
# Setting field to 0.00012
# Setting field to 0.000121
# Setting field to 0.000122
# Setting field to 0.000123
# Setting field to 0.000124
# Setting field to 0.000125
# Setting field to 0.000126
# Setting field to 0.000127
# Setting field to 0.000128
# Setting field to 0.000129
# Setting field to 0.00013
# Setting field to 0.000131
# Setting field to 0.000132
# Setting field to 0.000133
# Setting field to 0.000134
# Setting field to 0.000135
# Setting field to 0.000136
# Setting field to 0.000137
# Setting field to 0.000138
# Setting field to 0.000139
# Setting field to 0.00014
# Setting field to 0.000141
# Setting field to 0.000142
# Setting field to 0.000143
# Setting field to 0.000144
# Setting field to 0.000145
# Setting field to 0.000146
# Setting field to 0.000147
# Setting field to 0.000148
# Setting field to 0.000149
# Setting field to 0.00015
# Setting field to 0.000151
# Setting field to 0.000152
# Setting field to 0.000153
# Setting field to 0.000154
# Setting field to 0.000155
# Setting field to 0.000156
# Setting field to 0.000157
# Setting field to 0.000158
# Setting field to 0.000159
# Setting field to 0.00016
# Setting field to 0.000161
# Setting field to 0.000162
# Setting field to 0.000163
# Setting field to 0.000164
# Setting field to 0.000165
# Setting field to 0.000166
# Setting field to 0.000167
# Setting field to 0.000168
# Setting field to 0.000169
# Setting field to 0.00017
# Setting field to 0.000171
# Setting field to 0.000172
# Setting field to 0.000173
# Setting field to 0.000174
# Setting field to 0.000175
# Setting field to 0.000176
# Setting field to 0.000177
# Setting field to 0.000178
# Setting field to 0.000179
# Setting field to 0.00018
# Setting field to 0.000181
# Setting field to 0.000182
# Setting field to 0.000183
# Setting field to 0.000184
# Setting field to 0.000185
# Setting field to 0.000186
# Setting field to 0.000187
# Setting field to 0.000188
# Setting field to 0.000189
# Setting field to 0.00019
# Setting field to 0.000191
# Setting field to 0.000192
# Setting field to 0.000193
# Setting field to 0.000194
# Setting field to 0.000195
# Setting field to 0.000196
# Setting field to 0.000197
# Setting field to 0.000198
# Setting field to 0.000199
# Setting field to 0.0002
# Setting field to 0.0002
# Setting field to 0.000199
# Setting field to 0.000198
# Setting field to 0.000197
# Setting field to 0.000196
# Setting field to 0.000195
# Setting field to 0.000194
# Setting field to 0.000193
# Setting field to 0.000192
# Setting field to 0.000191
# Setting field to 0.00019
# Setting field to 0.000189
# Setting field to 0.000188
# Setting field to 0.000187
# Setting field to 0.000186
# Setting field to 0.000185
# Setting field to 0.000184
# Setting field to 0.000183
# Setting field to 0.000182
# Setting field to 0.000181
# Setting field to 0.00018
# Setting field to 0.000179
# Setting field to 0.000178
# Setting field to 0.000177
# Setting field to 0.000176
# Setting field to 0.000175
# Setting field to 0.000174
# Setting field to 0.000173
# Setting field to 0.000172
# Setting field to 0.000171
# Setting field to 0.00017
# Setting field to 0.000169
# Setting field to 0.000168
# Setting field to 0.000167
# Setting field to 0.000166
# Setting field to 0.000165
# Setting field to 0.000164
# Setting field to 0.000163
# Setting field to 0.000162
# Setting field to 0.000161
# Setting field to 0.00016
# Setting field to 0.000159
# Setting field to 0.000158
# Setting field to 0.000157
# Setting field to 0.000156
# Setting field to 0.000155
# Setting field to 0.000154
# Setting field to 0.000153
# Setting field to 0.000152
# Setting field to 0.000151
# Setting field to 0.00015
# Setting field to 0.000149
# Setting field to 0.000148
# Setting field to 0.000147
# Setting field to 0.000146
# Setting field to 0.000145
# Setting field to 0.000144
# Setting field to 0.000143
# Setting field to 0.000142
# Setting field to 0.000141
# Setting field to 0.00014
# Setting field to 0.000139
# Setting field to 0.000138
# Setting field to 0.000137
# Setting field to 0.000136
# Setting field to 0.000135
# Setting field to 0.000134
# Setting field to 0.000133
# Setting field to 0.000132
# Setting field to 0.000131
# Setting field to 0.00013
# Setting field to 0.000129
# Setting field to 0.000128
# Setting field to 0.000127
# Setting field to 0.000126
# Setting field to 0.000125
# Setting field to 0.000124
# Setting field to 0.000123
# Setting field to 0.000122
# Setting field to 0.000121
# Setting field to 0.00012
# Setting field to 0.000119
# Setting field to 0.000118
# Setting field to 0.000117
# Setting field to 0.000116
# Setting field to 0.000115
# Setting field to 0.000114
# Setting field to 0.000113
# Setting field to 0.000112
# Setting field to 0.000111
# Setting field to 0.00011
# Setting field to 0.000109
# Setting field to 0.000108
# Setting field to 0.000107
# Setting field to 0.000106
# Setting field to 0.000105
# Setting field to 0.000104
# Setting field to 0.000103
# Setting field to 0.000102
# Setting field to 0.000101
# Setting field to 0.0001
# Setting field to 9.9e-05
# Setting field to 9.8e-05
# Setting field to 9.7e-05
# Setting field to 9.6e-05
# Setting field to 9.5e-05
# Setting field to 9.4e-05
# Setting field to 9.3e-05
# Setting field to 9.2e-05
# Setting field to 9.1e-05
# Setting field to 9e-05
# Setting field to 8.9e-05
# Setting field to 8.8e-05
# Setting field to 8.7e-05
# Setting field to 8.6e-05
# Setting field to 8.5e-05
# Setting field to 8.4e-05
# Setting field to 8.3e-05
# Setting field to 8.2e-05
# Setting field to 8.1e-05
# Setting field to 8e-05
# Setting field to 7.9e-05
# Setting field to 7.8e-05
# Setting field to 7.7e-05
# Setting field to 7.6e-05
# Setting field to 7.5e-05
# Setting field to 7.4e-05
# Setting field to 7.3e-05
# Setting field to 7.2e-05
# Setting field to 7.1e-05
# Setting field to 7e-05
# Setting field to 6.9e-05
# Setting field to 6.8e-05
# Setting field to 6.7e-05
# Setting field to 6.6e-05
# Setting field to 6.5e-05
# Setting field to 6.4e-05
# Setting field to 6.3e-05
# Setting field to 6.2e-05
# Setting field to 6.1e-05
# Setting field to 6e-05
# Setting field to 5.9e-05
# Setting field to 5.8e-05
# Setting field to 5.7e-05
# Setting field to 5.6e-05
# Setting field to 5.5e-05
# Setting field to 5.4e-05
# Setting field to 5.3e-05
# Setting field to 5.2e-05
# Setting field to 5.1e-05
# Setting field to 5e-05
# Setting field to 4.9e-05
# Setting field to 4.8e-05
# Setting field to 4.7e-05
# Setting field to 4.6e-05
# Setting field to 4.5e-05
# Setting field to 4.4e-05
# Setting field to 4.3e-05
# Setting field to 4.2e-05
# Setting field to 4.1e-05
# Setting field to 4e-05
# Setting field to 3.9e-05
# Setting field to 3.8e-05
# Setting field to 3.7e-05
# Setting field to 3.6e-05
# Setting field to 3.5e-05
# Setting field to 3.4e-05
# Setting field to 3.3e-05
# Setting field to 3.2e-05
# Setting field to 3.1e-05
# Setting field to 3e-05
# Setting field to 2.9e-05
# Setting field to 2.8e-05
# Setting field to 2.7e-05
# Setting field to 2.6e-05
# Setting field to 2.5e-05
# Setting field to 2.4e-05
# Setting field to 2.3e-05
# Setting field to 2.2e-05
# Setting field to 2.1e-05
# Setting field to 2e-05
# Setting field to 1.9e-05
# Setting field to 1.8e-05
# Setting field to 1.7e-05
# Setting field to 1.6e-05
# Setting field to 1.5e-05
# Setting field to 1.4e-05
# Setting field to 1.3e-05
# Setting field to 1.2e-05
# Setting field to 1.1e-05
# Setting field to 1e-05
# Setting field to 9e-06
# Setting field to 8e-06
# Setting field to 7e-06
# Setting field to 6e-06
# Setting field to 5e-06
# Setting field to 4e-06
# Setting field to 3e-06
# Setting field to 2e-06
# Setting field to 1e-06
# Setting field to 5.69206140555e-19
# Setting field to -9.99999999999e-07
# Setting field to -2e-06
# Setting field to -3e-06
# Setting field to -4e-06
# Setting field to -5e-06
# Setting field to -6e-06
# Setting field to -7e-06
# Setting field to -8e-06
# Setting field to -9e-06
# Setting field to -1e-05
# Setting field to -1.1e-05
# Setting field to -1.2e-05
# Setting field to -1.3e-05
# Setting field to -1.4e-05
# Setting field to -1.5e-05
# Setting field to -1.6e-05
# Setting field to -1.7e-05
# Setting field to -1.8e-05
# Setting field to -1.9e-05
# Setting field to -2e-05
# Setting field to -2.1e-05
# Setting field to -2.2e-05
# Setting field to -2.3e-05
# Setting field to -2.4e-05
# Setting field to -2.5e-05
# Setting field to -2.6e-05
# Setting field to -2.7e-05
# Setting field to -2.8e-05
# Setting field to -2.9e-05
# Setting field to -3e-05
# Setting field to -3.1e-05
# Setting field to -3.2e-05
# Setting field to -3.3e-05
# Setting field to -3.4e-05
# Setting field to -3.5e-05
# Setting field to -3.6e-05
# Setting field to -3.7e-05
# Setting field to -3.8e-05
# Setting field to -3.9e-05
# Setting field to -4e-05
# Setting field to -4.1e-05
# Setting field to -4.2e-05
# Setting field to -4.3e-05
# Setting field to -4.4e-05
# Setting field to -4.5e-05
# Setting field to -4.6e-05
# Setting field to -4.7e-05
# Setting field to -4.8e-05
# Setting field to -4.9e-05
# Setting field to -5e-05
# Setting field to -5.1e-05
# Setting field to -5.2e-05
# Setting field to -5.3e-05
# Setting field to -5.4e-05
# Setting field to -5.5e-05
# Setting field to -5.6e-05
# Setting field to -5.7e-05
# Setting field to -5.8e-05
# Setting field to -5.9e-05
# Setting field to -6e-05
# Setting field to -6.1e-05
# Setting field to -6.2e-05
# Setting field to -6.3e-05
# Setting field to -6.4e-05
# Setting field to -6.5e-05
# Setting field to -6.6e-05
# Setting field to -6.7e-05
# Setting field to -6.8e-05
# Setting field to -6.9e-05
# Setting field to -7e-05
# Setting field to -7.1e-05
# Setting field to -7.2e-05
# Setting field to -7.3e-05
# Setting field to -7.4e-05
# Setting field to -7.5e-05
# Setting field to -7.6e-05
# Setting field to -7.7e-05
# Setting field to -7.8e-05
# Setting field to -7.9e-05
# Setting field to -8e-05
# Setting field to -8.1e-05
# Setting field to -8.2e-05
# Setting field to -8.3e-05
# Setting field to -8.4e-05
# Setting field to -8.5e-05
# Setting field to -8.6e-05
# Setting field to -8.7e-05
# Setting field to -8.8e-05
# Setting field to -8.9e-05
# Setting field to -9e-05
# Setting field to -9.1e-05
# Setting field to -9.2e-05
# Setting field to -9.3e-05
# Setting field to -9.4e-05
# Setting field to -9.5e-05
# Setting field to -9.6e-05
# Setting field to -9.7e-05
# Setting field to -9.8e-05
# Setting field to -9.9e-05
# Setting field to -0.0001
# Setting field to -0.000101
# Setting field to -0.000102
# Setting field to -0.000103
# Setting field to -0.000104
# Setting field to -0.000105
# Setting field to -0.000106
# Setting field to -0.000107
# Setting field to -0.000108
# Setting field to -0.000109
# Setting field to -0.00011
# Setting field to -0.000111
# Setting field to -0.000112
# Setting field to -0.000113
# Setting field to -0.000114
# Setting field to -0.000115
# Setting field to -0.000116
# Setting field to -0.000117
# Setting field to -0.000118
# Setting field to -0.000119
# Setting field to -0.00012
# Setting field to -0.000121
# Setting field to -0.000122
# Setting field to -0.000123
# Setting field to -0.000124
# Setting field to -0.000125
# Setting field to -0.000126
# Setting field to -0.000127
# Setting field to -0.000128
# Setting field to -0.000129
# Setting field to -0.00013
# Setting field to -0.000131
# Setting field to -0.000132
# Setting field to -0.000133
# Setting field to -0.000134
# Setting field to -0.000135
# Setting field to -0.000136
# Setting field to -0.000137
# Setting field to -0.000138
# Setting field to -0.000139
# Setting field to -0.00014
# Setting field to -0.000141
# Setting field to -0.000142
# Setting field to -0.000143
# Setting field to -0.000144
# Setting field to -0.000145
# Setting field to -0.000146
# Setting field to -0.000147
# Setting field to -0.000148
# Setting field to -0.000149
# Setting field to -0.00015
# Setting field to -0.000151
# Setting field to -0.000152
# Setting field to -0.000153
# Setting field to -0.000154
# Setting field to -0.000155
# Setting field to -0.000156
# Setting field to -0.000157
# Setting field to -0.000158
# Setting field to -0.000159
# Setting field to -0.00016
# Setting field to -0.000161
# Setting field to -0.000162
# Setting field to -0.000163
# Setting field to -0.000164
# Setting field to -0.000165
# Setting field to -0.000166
# Setting field to -0.000167
# Setting field to -0.000168
# Setting field to -0.000169
# Setting field to -0.00017
# Setting field to -0.000171
# Setting field to -0.000172
# Setting field to -0.000173
# Setting field to -0.000174
# Setting field to -0.000175
# Setting field to -0.000176
# Setting field to -0.000177
# Setting field to -0.000178
# Setting field to -0.000179
# Setting field to -0.00018
# Setting field to -0.000181
# Setting field to -0.000182
# Setting field to -0.000183
# Setting field to -0.000184
# Setting field to -0.000185
# Setting field to -0.000186
# Setting field to -0.000187
# Setting field to -0.000188
# Setting field to -0.000189
# Setting field to -0.00019
# Setting field to -0.000191
# Setting field to -0.000192
# Setting field to -0.000193
# Setting field to -0.000194
# Setting field to -0.000195
# Setting field to -0.000196
# Setting field to -0.000197
# Setting field to -0.000198
# Setting field to -0.000199
# Setting field to -0.0002
# Setting field to -0.0002
# Setting field to -0.000199
# Setting field to -0.000198
# Setting field to -0.000197
# Setting field to -0.000196
# Setting field to -0.000195
# Setting field to -0.000194
# Setting field to -0.000193
# Setting field to -0.000192
# Setting field to -0.000191
# Setting field to -0.00019
# Setting field to -0.000189
# Setting field to -0.000188
# Setting field to -0.000187
# Setting field to -0.000186
# Setting field to -0.000185
# Setting field to -0.000184
# Setting field to -0.000183
# Setting field to -0.000182
# Setting field to -0.000181
# Setting field to -0.00018
# Setting field to -0.000179
# Setting field to -0.000178
# Setting field to -0.000177
# Setting field to -0.000176
# Setting field to -0.000175
# Setting field to -0.000174
# Setting field to -0.000173
# Setting field to -0.000172
# Setting field to -0.000171
# Setting field to -0.00017
# Setting field to -0.000169
# Setting field to -0.000168
# Setting field to -0.000167
# Setting field to -0.000166
# Setting field to -0.000165
# Setting field to -0.000164
# Setting field to -0.000163
# Setting field to -0.000162
# Setting field to -0.000161
# Setting field to -0.00016
# Setting field to -0.000159
# Setting field to -0.000158
# Setting field to -0.000157
# Setting field to -0.000156
# Setting field to -0.000155
# Setting field to -0.000154
# Setting field to -0.000153
# Setting field to -0.000152
# Setting field to -0.000151
# Setting field to -0.00015
# Setting field to -0.000149
# Setting field to -0.000148
# Setting field to -0.000147
# Setting field to -0.000146
# Setting field to -0.000145
# Setting field to -0.000144
# Setting field to -0.000143
# Setting field to -0.000142
# Setting field to -0.000141
# Setting field to -0.00014
# Setting field to -0.000139
# Setting field to -0.000138
# Setting field to -0.000137
# Setting field to -0.000136
# Setting field to -0.000135
# Setting field to -0.000134
# Setting field to -0.000133
# Setting field to -0.000132
# Setting field to -0.000131
# Setting field to -0.00013
# Setting field to -0.000129
# Setting field to -0.000128
# Setting field to -0.000127
# Setting field to -0.000126
# Setting field to -0.000125
# Setting field to -0.000124
# Setting field to -0.000123
# Setting field to -0.000122
# Setting field to -0.000121
# Setting field to -0.00012
# Setting field to -0.000119
# Setting field to -0.000118
# Setting field to -0.000117
# Setting field to -0.000116
# Setting field to -0.000115
# Setting field to -0.000114
# Setting field to -0.000113
# Setting field to -0.000112
# Setting field to -0.000111
# Setting field to -0.00011
# Setting field to -0.000109
# Setting field to -0.000108
# Setting field to -0.000107
# Setting field to -0.000106
# Setting field to -0.000105
# Setting field to -0.000104
# Setting field to -0.000103
# Setting field to -0.000102
# Setting field to -0.000101
# Setting field to -0.0001
# Setting field to -9.9e-05
# Setting field to -9.8e-05
# Setting field to -9.7e-05
# Setting field to -9.6e-05
# Setting field to -9.5e-05
# Setting field to -9.4e-05
# Setting field to -9.3e-05
# Setting field to -9.2e-05
# Setting field to -9.1e-05
# Setting field to -9e-05
# Setting field to -8.9e-05
# Setting field to -8.8e-05
# Setting field to -8.7e-05
# Setting field to -8.6e-05
# Setting field to -8.5e-05
# Setting field to -8.4e-05
# Setting field to -8.3e-05
# Setting field to -8.2e-05
# Setting field to -8.1e-05
# Setting field to -8e-05
# Setting field to -7.9e-05
# Setting field to -7.8e-05
# Setting field to -7.7e-05
# Setting field to -7.6e-05
# Setting field to -7.5e-05
# Setting field to -7.4e-05
# Setting field to -7.3e-05
# Setting field to -7.2e-05
# Setting field to -7.1e-05
# Setting field to -7e-05
# Setting field to -6.9e-05
# Setting field to -6.8e-05
# Setting field to -6.7e-05
# Setting field to -6.6e-05
# Setting field to -6.5e-05
# Setting field to -6.4e-05
# Setting field to -6.3e-05
# Setting field to -6.2e-05
# Setting field to -6.1e-05
# Setting field to -6e-05
# Setting field to -5.9e-05
# Setting field to -5.8e-05
# Setting field to -5.7e-05
# Setting field to -5.6e-05
# Setting field to -5.5e-05
# Setting field to -5.4e-05
# Setting field to -5.3e-05
# Setting field to -5.2e-05
# Setting field to -5.1e-05
# Setting field to -5e-05
# Setting field to -4.9e-05
# Setting field to -4.8e-05
# Setting field to -4.7e-05
# Setting field to -4.6e-05
# Setting field to -4.5e-05
# Setting field to -4.4e-05
# Setting field to -4.3e-05
# Setting field to -4.2e-05
# Setting field to -4.1e-05
# Setting field to -4e-05
# Setting field to -3.9e-05
# Setting field to -3.8e-05
# Setting field to -3.7e-05
# Setting field to -3.6e-05
# Setting field to -3.5e-05
# Setting field to -3.4e-05
# Setting field to -3.3e-05
# Setting field to -3.2e-05
# Setting field to -3.1e-05
# Setting field to -3e-05
# Setting field to -2.9e-05
# Setting field to -2.8e-05
# Setting field to -2.7e-05
# Setting field to -2.6e-05
# Setting field to -2.5e-05
# Setting field to -2.4e-05
# Setting field to -2.3e-05
# Setting field to -2.2e-05
# Setting field to -2.1e-05
# Setting field to -2e-05
# Setting field to -1.9e-05
# Setting field to -1.8e-05
# Setting field to -1.7e-05
# Setting field to -1.6e-05
# Setting field to -1.5e-05
# Setting field to -1.4e-05
# Setting field to -1.3e-05
# Setting field to -1.2e-05
# Setting field to -1.1e-05
# Setting field to -1e-05
# Setting field to -9e-06
# Setting field to -8e-06
# Setting field to -7e-06
# Setting field to -6e-06
# Setting field to -5e-06
# Setting field to -4e-06
# Setting field to -3e-06
# Setting field to -2e-06
# Setting field to -1e-06
# Setting field to -5.69206140555e-19
# Setting field to 9.99999999999e-07
# Setting field to 2e-06
# Setting field to 3e-06
# Setting field to 4e-06
# Setting field to 5e-06
# Setting field to 6e-06
# Setting field to 7e-06
# Setting field to 8e-06
# Setting field to 9e-06
# Setting field to 1e-05
# Setting field to 1.1e-05
# Setting field to 1.2e-05
# Setting field to 1.3e-05
# Setting field to 1.4e-05
# Setting field to 1.5e-05
# Setting field to 1.6e-05
# Setting field to 1.7e-05
# Setting field to 1.8e-05
# Setting field to 1.9e-05
# Setting field to 2e-05
# Setting field to 2.1e-05
# Setting field to 2.2e-05
# Setting field to 2.3e-05
# Setting field to 2.4e-05
# Setting field to 2.5e-05
# Setting field to 2.6e-05
# Setting field to 2.7e-05
# Setting field to 2.8e-05
# Setting field to 2.9e-05
# Setting field to 3e-05
# Setting field to 3.1e-05
# Setting field to 3.2e-05
# Setting field to 3.3e-05
# Setting field to 3.4e-05
# Setting field to 3.5e-05
# Setting field to 3.6e-05
# Setting field to 3.7e-05
# Setting field to 3.8e-05
# Setting field to 3.9e-05
# Setting field to 4e-05
# Setting field to 4.1e-05
# Setting field to 4.2e-05
# Setting field to 4.3e-05
# Setting field to 4.4e-05
# Setting field to 4.5e-05
# Setting field to 4.6e-05
# Setting field to 4.7e-05
# Setting field to 4.8e-05
# Setting field to 4.9e-05
# Setting field to 5e-05
# Setting field to 5.1e-05
# Setting field to 5.2e-05
# Setting field to 5.3e-05
# Setting field to 5.4e-05
# Setting field to 5.5e-05
# Setting field to 5.6e-05
# Setting field to 5.7e-05
# Setting field to 5.8e-05
# Setting field to 5.9e-05
# Setting field to 6e-05
# Setting field to 6.1e-05
# Setting field to 6.2e-05
# Setting field to 6.3e-05
# Setting field to 6.4e-05
# Setting field to 6.5e-05
# Setting field to 6.6e-05
# Setting field to 6.7e-05
# Setting field to 6.8e-05
# Setting field to 6.9e-05
# Setting field to 7e-05
# Setting field to 7.1e-05
# Setting field to 7.2e-05
# Setting field to 7.3e-05
# Setting field to 7.4e-05
# Setting field to 7.5e-05
# Setting field to 7.6e-05
# Setting field to 7.7e-05
# Setting field to 7.8e-05
# Setting field to 7.9e-05
# Setting field to 8e-05
# Setting field to 8.1e-05
# Setting field to 8.2e-05
# Setting field to 8.3e-05
# Setting field to 8.4e-05
# Setting field to 8.5e-05
# Setting field to 8.6e-05
# Setting field to 8.7e-05
# Setting field to 8.8e-05
# Setting field to 8.9e-05
# Setting field to 9e-05
# Setting field to 9.1e-05
# Setting field to 9.2e-05
# Setting field to 9.3e-05
# Setting field to 9.4e-05
# Setting field to 9.5e-05
# Setting field to 9.6e-05
# Setting field to 9.7e-05
# Setting field to 9.8e-05
# Setting field to 9.9e-05
# Setting field to 0.0001
# Setting field to 0.000101
# Setting field to 0.000102
# Setting field to 0.000103
# Setting field to 0.000104
# Setting field to 0.000105
# Setting field to 0.000106
# Setting field to 0.000107
# Setting field to 0.000108
# Setting field to 0.000109
# Setting field to 0.00011
# Setting field to 0.000111
# Setting field to 0.000112
# Setting field to 0.000113
# Setting field to 0.000114
# Setting field to 0.000115
# Setting field to 0.000116
# Setting field to 0.000117
# Setting field to 0.000118
# Setting field to 0.000119
# Setting field to 0.00012
# Setting field to 0.000121
# Setting field to 0.000122
# Setting field to 0.000123
# Setting field to 0.000124
# Setting field to 0.000125
# Setting field to 0.000126
# Setting field to 0.000127
# Setting field to 0.000128
# Setting field to 0.000129
# Setting field to 0.00013
# Setting field to 0.000131
# Setting field to 0.000132
# Setting field to 0.000133
# Setting field to 0.000134
# Setting field to 0.000135
# Setting field to 0.000136
# Setting field to 0.000137
# Setting field to 0.000138
# Setting field to 0.000139
# Setting field to 0.00014
# Setting field to 0.000141
# Setting field to 0.000142
# Setting field to 0.000143
# Setting field to 0.000144
# Setting field to 0.000145
# Setting field to 0.000146
# Setting field to 0.000147
# Setting field to 0.000148
# Setting field to 0.000149
# Setting field to 0.00015
# Setting field to 0.000151
# Setting field to 0.000152
# Setting field to 0.000153
# Setting field to 0.000154
# Setting field to 0.000155
# Setting field to 0.000156
# Setting field to 0.000157
# Setting field to 0.000158
# Setting field to 0.000159
# Setting field to 0.00016
# Setting field to 0.000161
# Setting field to 0.000162
# Setting field to 0.000163
# Setting field to 0.000164
# Setting field to 0.000165
# Setting field to 0.000166
# Setting field to 0.000167
# Setting field to 0.000168
# Setting field to 0.000169
# Setting field to 0.00017
# Setting field to 0.000171
# Setting field to 0.000172
# Setting field to 0.000173
# Setting field to 0.000174
# Setting field to 0.000175
# Setting field to 0.000176
# Setting field to 0.000177
# Setting field to 0.000178
# Setting field to 0.000179
# Setting field to 0.00018
# Setting field to 0.000181
# Setting field to 0.000182
# Setting field to 0.000183
# Setting field to 0.000184
# Setting field to 0.000185
# Setting field to 0.000186
# Setting field to 0.000187
# Setting field to 0.000188
# Setting field to 0.000189
# Setting field to 0.00019
# Setting field to 0.000191
# Setting field to 0.000192
# Setting field to 0.000193
# Setting field to 0.000194
# Setting field to 0.000195
# Setting field to 0.000196
# Setting field to 0.000197
# Setting field to 0.000198
# Setting field to 0.000199
# Setting field to 0.0002
# Setting field to 0.0002
# Setting field to 0.000199
# Setting field to 0.000198
# Setting field to 0.000197
# Setting field to 0.000196
# Setting field to 0.000195
# Setting field to 0.000194
# Setting field to 0.000193
# Setting field to 0.000192
# Setting field to 0.000191
# Setting field to 0.00019
# Setting field to 0.000189
# Setting field to 0.000188
# Setting field to 0.000187
# Setting field to 0.000186
# Setting field to 0.000185
# Setting field to 0.000184
# Setting field to 0.000183
# Setting field to 0.000182
# Setting field to 0.000181
# Setting field to 0.00018
# Setting field to 0.000179
# Setting field to 0.000178
# Setting field to 0.000177
# Setting field to 0.000176
# Setting field to 0.000175
# Setting field to 0.000174
# Setting field to 0.000173
# Setting field to 0.000172
# Setting field to 0.000171
# Setting field to 0.00017
# Setting field to 0.000169
# Setting field to 0.000168
# Setting field to 0.000167
# Setting field to 0.000166
# Setting field to 0.000165
# Setting field to 0.000164
# Setting field to 0.000163
# Setting field to 0.000162
# Setting field to 0.000161
# Setting field to 0.00016
# Setting field to 0.000159
# Setting field to 0.000158
# Setting field to 0.000157
# Setting field to 0.000156
# Setting field to 0.000155
# Setting field to 0.000154
# Setting field to 0.000153
# Setting field to 0.000152
# Setting field to 0.000151
# Setting field to 0.00015
# Setting field to 0.000149
# Setting field to 0.000148
# Setting field to 0.000147
# Setting field to 0.000146
# Setting field to 0.000145
# Setting field to 0.000144
# Setting field to 0.000143
# Setting field to 0.000142
# Setting field to 0.000141
# Setting field to 0.00014
# Setting field to 0.000139
# Setting field to 0.000138
# Setting field to 0.000137
# Setting field to 0.000136
# Setting field to 0.000135
# Setting field to 0.000134
# Setting field to 0.000133
# Setting field to 0.000132
# Setting field to 0.000131
# Setting field to 0.00013
# Setting field to 0.000129
# Setting field to 0.000128
# Setting field to 0.000127
# Setting field to 0.000126
# Setting field to 0.000125
# Setting field to 0.000124
# Setting field to 0.000123
# Setting field to 0.000122
# Setting field to 0.000121
# Setting field to 0.00012
# Setting field to 0.000119
# Setting field to 0.000118
# Setting field to 0.000117
# Setting field to 0.000116
# Setting field to 0.000115
# Setting field to 0.000114
# Setting field to 0.000113
# Setting field to 0.000112
# Setting field to 0.000111
# Setting field to 0.00011
# Setting field to 0.000109
# Setting field to 0.000108
# Setting field to 0.000107
# Setting field to 0.000106
# Setting field to 0.000105
# Setting field to 0.000104
# Setting field to 0.000103
# Setting field to 0.000102
# Setting field to 0.000101
# Setting field to 0.0001
# Setting field to 9.9e-05
# Setting field to 9.8e-05
# Setting field to 9.7e-05
# Setting field to 9.6e-05
# Setting field to 9.5e-05
# Setting field to 9.4e-05
# Setting field to 9.3e-05
# Setting field to 9.2e-05
# Setting field to 9.1e-05
# Setting field to 9e-05
# Setting field to 8.9e-05
# Setting field to 8.8e-05
# Setting field to 8.7e-05
# Setting field to 8.6e-05
# Setting field to 8.5e-05
# Setting field to 8.4e-05
# Setting field to 8.3e-05
# Setting field to 8.2e-05
# Setting field to 8.1e-05
# Setting field to 8e-05
# Setting field to 7.9e-05
# Setting field to 7.8e-05
# Setting field to 7.7e-05
# Setting field to 7.6e-05
# Setting field to 7.5e-05
# Setting field to 7.4e-05
# Setting field to 7.3e-05
# Setting field to 7.2e-05
# Setting field to 7.1e-05
# Setting field to 7e-05
# Setting field to 6.9e-05
# Setting field to 6.8e-05
# Setting field to 6.7e-05
# Setting field to 6.6e-05
# Setting field to 6.5e-05
# Setting field to 6.4e-05
# Setting field to 6.3e-05
# Setting field to 6.2e-05
# Setting field to 6.1e-05
# Setting field to 6e-05
# Setting field to 5.9e-05
# Setting field to 5.8e-05
# Setting field to 5.7e-05
# Setting field to 5.6e-05
# Setting field to 5.5e-05
# Setting field to 5.4e-05
# Setting field to 5.3e-05
# Setting field to 5.2e-05
# Setting field to 5.1e-05
# Setting field to 5e-05
# Setting field to 4.9e-05
# Setting field to 4.8e-05
# Setting field to 4.7e-05
# Setting field to 4.6e-05
# Setting field to 4.5e-05
# Setting field to 4.4e-05
# Setting field to 4.3e-05
# Setting field to 4.2e-05
# Setting field to 4.1e-05
# Setting field to 4e-05
# Setting field to 3.9e-05
# Setting field to 3.8e-05
# Setting field to 3.7e-05
# Setting field to 3.6e-05
# Setting field to 3.5e-05
# Setting field to 3.4e-05
# Setting field to 3.3e-05
# Setting field to 3.2e-05
# Setting field to 3.1e-05
# Setting field to 3e-05
# Setting field to 2.9e-05
# Setting field to 2.8e-05
# Setting field to 2.7e-05
# Setting field to 2.6e-05
# Setting field to 2.5e-05
# Setting field to 2.4e-05
# Setting field to 2.3e-05
# Setting field to 2.2e-05
# Setting field to 2.1e-05
# Setting field to 2e-05
# Setting field to 1.9e-05
# Setting field to 1.8e-05
# Setting field to 1.7e-05
# Setting field to 1.6e-05
# Setting field to 1.5e-05
# Setting field to 1.4e-05
# Setting field to 1.3e-05
# Setting field to 1.2e-05
# Setting field to 1.1e-05
# Setting field to 1e-05
# Setting field to 9e-06
# Setting field to 8e-06
# Setting field to 7e-06
# Setting field to 6e-06
# Setting field to 5e-06
# Setting field to 4e-06
# Setting field to 3e-06
# Setting field to 2e-06
# Setting field to 1e-06
# Setting field to 5.69206140555e-19
# Setting field to -9.99999999999e-07
# Setting field to -2e-06
# Setting field to -3e-06
# Setting field to -4e-06
# Setting field to -5e-06
# Setting field to -6e-06
# Setting field to -7e-06
# Setting field to -8e-06
# Setting field to -9e-06
# Setting field to -1e-05
# Setting field to -1.1e-05
# Setting field to -1.2e-05
# Setting field to -1.3e-05
# Setting field to -1.4e-05
# Setting field to -1.5e-05
# Setting field to -1.6e-05
# Setting field to -1.7e-05
# Setting field to -1.8e-05
# Setting field to -1.9e-05
# Setting field to -2e-05
# Setting field to -2.1e-05
# Setting field to -2.2e-05
# Setting field to -2.3e-05
# Setting field to -2.4e-05
# Setting field to -2.5e-05
# Setting field to -2.6e-05
# Setting field to -2.7e-05
# Setting field to -2.8e-05
# Setting field to -2.9e-05
# Setting field to -3e-05
# Setting field to -3.1e-05
# Setting field to -3.2e-05
# Setting field to -3.3e-05
# Setting field to -3.4e-05
# Setting field to -3.5e-05
# Setting field to -3.6e-05
# Setting field to -3.7e-05
# Setting field to -3.8e-05
# Setting field to -3.9e-05
# Setting field to -4e-05
# Setting field to -4.1e-05
# Setting field to -4.2e-05
# Setting field to -4.3e-05
# Setting field to -4.4e-05
# Setting field to -4.5e-05
# Setting field to -4.6e-05
# Setting field to -4.7e-05
# Setting field to -4.8e-05
# Setting field to -4.9e-05
# Setting field to -5e-05
# Setting field to -5.1e-05
# Setting field to -5.2e-05
# Setting field to -5.3e-05
# Setting field to -5.4e-05
# Setting field to -5.5e-05
# Setting field to -5.6e-05
# Setting field to -5.7e-05
# Setting field to -5.8e-05
# Setting field to -5.9e-05
# Setting field to -6e-05
# Setting field to -6.1e-05
# Setting field to -6.2e-05
# Setting field to -6.3e-05
# Setting field to -6.4e-05
# Setting field to -6.5e-05
# Setting field to -6.6e-05
# Setting field to -6.7e-05
# Setting field to -6.8e-05
# Setting field to -6.9e-05
# Setting field to -7e-05
# Setting field to -7.1e-05
# Setting field to -7.2e-05
# Setting field to -7.3e-05
# Setting field to -7.4e-05
# Setting field to -7.5e-05
# Setting field to -7.6e-05
# Setting field to -7.7e-05
# Setting field to -7.8e-05
# Setting field to -7.9e-05
# Setting field to -8e-05
# Setting field to -8.1e-05
# Setting field to -8.2e-05
# Setting field to -8.3e-05
# Setting field to -8.4e-05
# Setting field to -8.5e-05
# Setting field to -8.6e-05
# Setting field to -8.7e-05
# Setting field to -8.8e-05
# Setting field to -8.9e-05
# Setting field to -9e-05
# Setting field to -9.1e-05
# Setting field to -9.2e-05
# Setting field to -9.3e-05
# Setting field to -9.4e-05
# Setting field to -9.5e-05
# Setting field to -9.6e-05
# Setting field to -9.7e-05
# Setting field to -9.8e-05
# Setting field to -9.9e-05
# Setting field to -0.0001
# Setting field to -0.000101
# Setting field to -0.000102
# Setting field to -0.000103
# Setting field to -0.000104
# Setting field to -0.000105
# Setting field to -0.000106
# Setting field to -0.000107
# Setting field to -0.000108
# Setting field to -0.000109
# Setting field to -0.00011
# Setting field to -0.000111
# Setting field to -0.000112
# Setting field to -0.000113
# Setting field to -0.000114
# Setting field to -0.000115
# Setting field to -0.000116
# Setting field to -0.000117
# Setting field to -0.000118
# Setting field to -0.000119
# Setting field to -0.00012
# Setting field to -0.000121
# Setting field to -0.000122
# Setting field to -0.000123
# Setting field to -0.000124
# Setting field to -0.000125
# Setting field to -0.000126
# Setting field to -0.000127
# Setting field to -0.000128
# Setting field to -0.000129
# Setting field to -0.00013
# Setting field to -0.000131
# Setting field to -0.000132
# Setting field to -0.000133
# Setting field to -0.000134
# Setting field to -0.000135
# Setting field to -0.000136
# Setting field to -0.000137
# Setting field to -0.000138
# Setting field to -0.000139
# Setting field to -0.00014
# Setting field to -0.000141
# Setting field to -0.000142
# Setting field to -0.000143
# Setting field to -0.000144
# Setting field to -0.000145
# Setting field to -0.000146
# Setting field to -0.000147
# Setting field to -0.000148
# Setting field to -0.000149
# Setting field to -0.00015
# Setting field to -0.000151
# Setting field to -0.000152
# Setting field to -0.000153
# Setting field to -0.000154
# Setting field to -0.000155
# Setting field to -0.000156
# Setting field to -0.000157
# Setting field to -0.000158
# Setting field to -0.000159
# Setting field to -0.00016
# Setting field to -0.000161
# Setting field to -0.000162
# Setting field to -0.000163
# Setting field to -0.000164
# Setting field to -0.000165
# Setting field to -0.000166
# Setting field to -0.000167
# Setting field to -0.000168
# Setting field to -0.000169
# Setting field to -0.00017
# Setting field to -0.000171
# Setting field to -0.000172
# Setting field to -0.000173
# Setting field to -0.000174
# Setting field to -0.000175
# Setting field to -0.000176
# Setting field to -0.000177
# Setting field to -0.000178
# Setting field to -0.000179
# Setting field to -0.00018
# Setting field to -0.000181
# Setting field to -0.000182
# Setting field to -0.000183
# Setting field to -0.000184
# Setting field to -0.000185
# Setting field to -0.000186
# Setting field to -0.000187
# Setting field to -0.000188
# Setting field to -0.000189
# Setting field to -0.00019
# Setting field to -0.000191
# Setting field to -0.000192
# Setting field to -0.000193
# Setting field to -0.000194
# Setting field to -0.000195
# Setting field to -0.000196
# Setting field to -0.000197
# Setting field to -0.000198
# Setting field to -0.000199
# Setting field to -0.0002
#  Time elapsed: 8041.3675
# ramping gate <MDACChannel: MDAC_chan2 of MDAC: MDAC> down
# ramping gate <MDACChannel: MDAC_chan1 of MDAC: MDAC> down
# ramping gate <MDACChannel: MDAC_chan3 of MDAC: MDAC> down
# ramping gate <MDACChannel: MDAC_chan4 of MDAC: MDAC> down
# ramping up gates
# ramping gate <MDACChannel: MDAC_chan25 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan26 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan9 of MDAC: MDAC>
# ramping gate <MDACChannel: MDAC_chan27 of MDAC: MDAC>
# Taking single sweep
# Starting experimental run with id: 73
# Taking trace took 13.072786092758179
# Instrument T_probe already exists.
# Path of network drive(set this manually dear USER):  \\MININT-ETA6HHA\Desktop\BF Log Files\
# Starting experimental run with id: 74
# Setting field to 0.0
# Setting field to 1e-06
# Setting field to 2e-06
# Setting field to 3e-06
# Setting field to 4e-06
# Setting field to 5e-06
# Setting field to 6e-06
# Setting field to 7e-06
# Setting field to 8e-06
# Setting field to 9e-06
# Setting field to 1e-05
# Setting field to 1.1e-05
# Setting field to 1.2e-05
# Setting field to 1.3e-05
# Setting field to 1.4e-05
# Setting field to 1.5e-05
# Setting field to 1.6e-05
# Setting field to 1.7e-05
# Setting field to 1.8e-05
# Setting field to 1.9e-05
# Setting field to 2e-05
# Setting field to 2.1e-05
# Setting field to 2.2e-05
# Setting field to 2.3e-05
# Setting field to 2.4e-05
# Setting field to 2.5e-05
# Setting field to 2.6e-05
# Setting field to 2.7e-05
# Setting field to 2.8e-05
# Setting field to 2.9e-05
# Setting field to 3e-05
# Setting field to 3.1e-05
# Setting field to 3.2e-05
# Setting field to 3.3e-05
# Setting field to 3.4e-05
# Setting field to 3.5e-05
# Setting field to 3.6e-05
# Setting field to 3.7e-05
# Setting field to 3.8e-05
# Setting field to 3.9e-05
# Setting field to 4e-05
# Setting field to 4.1e-05
# Setting field to 4.2e-05
# Setting field to 4.3e-05
# Setting field to 4.4e-05
# Setting field to 4.5e-05
# Setting field to 4.6e-05
# Setting field to 4.7e-05
# Setting field to 4.8e-05
# Setting field to 4.9e-05
# Setting field to 5e-05
# Setting field to 5.1e-05
# Setting field to 5.2e-05
# Setting field to 5.3e-05
# Setting field to 5.4e-05
# Setting field to 5.5e-05
# Setting field to 5.6e-05
# Setting field to 5.7e-05
# Setting field to 5.8e-05
# Setting field to 5.9e-05
# Setting field to 6e-05
# Setting field to 6.1e-05
# Setting field to 6.2e-05
# Setting field to 6.3e-05
# Setting field to 6.4e-05
# Setting field to 6.5e-05
# Setting field to 6.6e-05
# Setting field to 6.7e-05
# Setting field to 6.8e-05
# Setting field to 6.9e-05
# Setting field to 7e-05
# Setting field to 7.1e-05
# Setting field to 7.2e-05
# Setting field to 7.3e-05
# Setting field to 7.4e-05
# Setting field to 7.5e-05
# Setting field to 7.6e-05
# Setting field to 7.7e-05
# Setting field to 7.8e-05
# Setting field to 7.9e-05
# Setting field to 8e-05
# Setting field to 8.1e-05
# Setting field to 8.2e-05
# Setting field to 8.3e-05
# Setting field to 8.4e-05
# Setting field to 8.5e-05
# Setting field to 8.6e-05
# Setting field to 8.7e-05
# Setting field to 8.8e-05
# Setting field to 8.9e-05
# Setting field to 9e-05
# Setting field to 9.1e-05
# Setting field to 9.2e-05
# Setting field to 9.3e-05
# Setting field to 9.4e-05
# Setting field to 9.5e-05
# Setting field to 9.6e-05
# Setting field to 9.7e-05
# Setting field to 9.8e-05
# Setting field to 9.9e-05
# Setting field to 0.0001
# Setting field to 0.000101
# Setting field to 0.000102
# Setting field to 0.000103
# Setting field to 0.000104
# Setting field to 0.000105
# Setting field to 0.000106
# Setting field to 0.000107
# Setting field to 0.000108
# Setting field to 0.000109
# Setting field to 0.00011
# Setting field to 0.000111
# Setting field to 0.000112
# Setting field to 0.000113
# Setting field to 0.000114
# Setting field to 0.000115
# Setting field to 0.000116
# Setting field to 0.000117
# Setting field to 0.000118
# Setting field to 0.000119
# Setting field to 0.00012
# Setting field to 0.000121
# Setting field to 0.000122
# Setting field to 0.000123
# Setting field to 0.000124
# Setting field to 0.000125
# Setting field to 0.000126
# Setting field to 0.000127
# Setting field to 0.000128
# Setting field to 0.000129
# Setting field to 0.00013
# Setting field to 0.000131
# Setting field to 0.000132
# Setting field to 0.000133
# Setting field to 0.000134
# Setting field to 0.000135
# Setting field to 0.000136
# Setting field to 0.000137
# Setting field to 0.000138
# Setting field to 0.000139
# Setting field to 0.00014
# Setting field to 0.000141
# Setting field to 0.000142
# Setting field to 0.000143
# Setting field to 0.000144
# Setting field to 0.000145
# Setting field to 0.000146
# Setting field to 0.000147
# Setting field to 0.000148
# Setting field to 0.000149
# Setting field to 0.00015
# Setting field to 0.000151
# Setting field to 0.000152
# Setting field to 0.000153
# Setting field to 0.000154
# Setting field to 0.000155
# Setting field to 0.000156
# Setting field to 0.000157
# Setting field to 0.000158
# Setting field to 0.000159
# Setting field to 0.00016
# Setting field to 0.000161
# Setting field to 0.000162
# Setting field to 0.000163
# Setting field to 0.000164
# Setting field to 0.000165
# Setting field to 0.000166
# Setting field to 0.000167
# Setting field to 0.000168
# Setting field to 0.000169
# Setting field to 0.00017
# Setting field to 0.000171
# Setting field to 0.000172
# Setting field to 0.000173
# Setting field to 0.000174
# Setting field to 0.000175
# Setting field to 0.000176
# Setting field to 0.000177
# Setting field to 0.000178
# Setting field to 0.000179
# Setting field to 0.00018
# Setting field to 0.000181
# Setting field to 0.000182
# Setting field to 0.000183
# Setting field to 0.000184
# Setting field to 0.000185
# Setting field to 0.000186
# Setting field to 0.000187
# Setting field to 0.000188
# Setting field to 0.000189
# Setting field to 0.00019
# Setting field to 0.000191
# Setting field to 0.000192
# Setting field to 0.000193
# Setting field to 0.000194
# Setting field to 0.000195
# Setting field to 0.000196
# Setting field to 0.000197
# Setting field to 0.000198
# Setting field to 0.000199
# Setting field to 0.0002
# Setting field to 0.0002
# Setting field to 0.000199
# Setting field to 0.000198
# Setting field to 0.000197
# Setting field to 0.000196
# Setting field to 0.000195
# Setting field to 0.000194
# Setting field to 0.000193
# Setting field to 0.000192
# Setting field to 0.000191
# Setting field to 0.00019
# Setting field to 0.000189
# Setting field to 0.000188
# Setting field to 0.000187
# Setting field to 0.000186
# Setting field to 0.000185
# Setting field to 0.000184
# Setting field to 0.000183
# Setting field to 0.000182
# Setting field to 0.000181
# Setting field to 0.00018
# Setting field to 0.000179
# Setting field to 0.000178
# Setting field to 0.000177
# Setting field to 0.000176
# Setting field to 0.000175
# Setting field to 0.000174
# Setting field to 0.000173
# Setting field to 0.000172
# Setting field to 0.000171
# Setting field to 0.00017
# Setting field to 0.000169
# Setting field to 0.000168
# Setting field to 0.000167
# Setting field to 0.000166
# Setting field to 0.000165
# Setting field to 0.000164
# Setting field to 0.000163
# Setting field to 0.000162
# Setting field to 0.000161
# Setting field to 0.00016
# Setting field to 0.000159
# Setting field to 0.000158
# Setting field to 0.000157
# Setting field to 0.000156
# Setting field to 0.000155
# Setting field to 0.000154
# Setting field to 0.000153
# Setting field to 0.000152
# Setting field to 0.000151
# Setting field to 0.00015
# Setting field to 0.000149
# Setting field to 0.000148
# Setting field to 0.000147
# Setting field to 0.000146
# Setting field to 0.000145
# Setting field to 0.000144
# Setting field to 0.000143
# Setting field to 0.000142
# Setting field to 0.000141
# Setting field to 0.00014
# Setting field to 0.000139
# Setting field to 0.000138
# Setting field to 0.000137
# Setting field to 0.000136
# Setting field to 0.000135
# Setting field to 0.000134
# Setting field to 0.000133
# Setting field to 0.000132
# Setting field to 0.000131
# Setting field to 0.00013
# Setting field to 0.000129
# Setting field to 0.000128
# Setting field to 0.000127
# Setting field to 0.000126
# Setting field to 0.000125
# Setting field to 0.000124
# Setting field to 0.000123
# Setting field to 0.000122
# Setting field to 0.000121
# Setting field to 0.00012
# Setting field to 0.000119
# Setting field to 0.000118
# Setting field to 0.000117
# Setting field to 0.000116
# Setting field to 0.000115
# Setting field to 0.000114
# Setting field to 0.000113
# Setting field to 0.000112
# Setting field to 0.000111
# Setting field to 0.00011
# Setting field to 0.000109
# Setting field to 0.000108
# Setting field to 0.000107
# Setting field to 0.000106
# Setting field to 0.000105
# Setting field to 0.000104
# Setting field to 0.000103
# Setting field to 0.000102
# Setting field to 0.000101
# Setting field to 0.0001
# Setting field to 9.9e-05
# Setting field to 9.8e-05
# Setting field to 9.7e-05
# Setting field to 9.6e-05
# Setting field to 9.5e-05
# Setting field to 9.4e-05
# Setting field to 9.3e-05
# Setting field to 9.2e-05
# Setting field to 9.1e-05
# Setting field to 9e-05
# Setting field to 8.9e-05
# Setting field to 8.8e-05
# Setting field to 8.7e-05
# Setting field to 8.6e-05
# Setting field to 8.5e-05
# Setting field to 8.4e-05
# Setting field to 8.3e-05
# Setting field to 8.2e-05
# Setting field to 8.1e-05
# Setting field to 8e-05
# Setting field to 7.9e-05
# Setting field to 7.8e-05
# Setting field to 7.7e-05
# Setting field to 7.6e-05
# Setting field to 7.5e-05
# Setting field to 7.4e-05
# Setting field to 7.3e-05
# Setting field to 7.2e-05
# Setting field to 7.1e-05
# Setting field to 7e-05
# Setting field to 6.9e-05
# Setting field to 6.8e-05
# Setting field to 6.7e-05
# Setting field to 6.6e-05
# Setting field to 6.5e-05
# Setting field to 6.4e-05
# Setting field to 6.3e-05
# Setting field to 6.2e-05
# Setting field to 6.1e-05
# Setting field to 6e-05
# Setting field to 5.9e-05
# Setting field to 5.8e-05
# Setting field to 5.7e-05
# Setting field to 5.6e-05
# Setting field to 5.5e-05
# Setting field to 5.4e-05
# Setting field to 5.3e-05
# Setting field to 5.2e-05
# Setting field to 5.1e-05
# Setting field to 5e-05
# Setting field to 4.9e-05
# Setting field to 4.8e-05
# Setting field to 4.7e-05
# Setting field to 4.6e-05
# Setting field to 4.5e-05
# Setting field to 4.4e-05
# Setting field to 4.3e-05
# Setting field to 4.2e-05
# Setting field to 4.1e-05
# Setting field to 4e-05
# Setting field to 3.9e-05
# Setting field to 3.8e-05
# Setting field to 3.7e-05
# Setting field to 3.6e-05
# Setting field to 3.5e-05
# Setting field to 3.4e-05
# Setting field to 3.3e-05
# Setting field to 3.2e-05
# Setting field to 3.1e-05
# Setting field to 3e-05
# Setting field to 2.9e-05
# Setting field to 2.8e-05
# Setting field to 2.7e-05
# Setting field to 2.6e-05
# Setting field to 2.5e-05
# Setting field to 2.4e-05
# Setting field to 2.3e-05
# Setting field to 2.2e-05
# Setting field to 2.1e-05
# Setting field to 2e-05
# Setting field to 1.9e-05
# Setting field to 1.8e-05
# Setting field to 1.7e-05
# Setting field to 1.6e-05
# Setting field to 1.5e-05
# Setting field to 1.4e-05
# Setting field to 1.3e-05
# Setting field to 1.2e-05
# Setting field to 1.1e-05
# Setting field to 1e-05
# Setting field to 9e-06
# Setting field to 8e-06
# Setting field to 7e-06
# Setting field to 6e-06
# Setting field to 5e-06
# Setting field to 4e-06
# Setting field to 3e-06
# Setting field to 2e-06
# Setting field to 1e-06
# Setting field to 5.69206140555e-19
# Setting field to -9.99999999999e-07
# Setting field to -2e-06
# Setting field to -3e-06
# Setting field to -4e-06
# Setting field to -5e-06
# Setting field to -6e-06
# Setting field to -7e-06
# Setting field to -8e-06
# Setting field to -9e-06
# Setting field to -1e-05
# Setting field to -1.1e-05
# Setting field to -1.2e-05
# Setting field to -1.3e-05
# Setting field to -1.4e-05
# Setting field to -1.5e-05
# Setting field to -1.6e-05
# Setting field to -1.7e-05
# Setting field to -1.8e-05
# Setting field to -1.9e-05
# ...
# Setting field to -1.1e-05
# Setting field to -1e-05
# Setting field to -9e-06
# Setting field to -8e-06
# Setting field to -7e-06
# Setting field to -6e-06
# Setting field to -5e-06
# Setting field to -4e-06
# Setting field to -3e-06
# Setting field to -2e-06
# Setting field to -1e-06
# Setting field to -5.69206140555e-19
# Setting field to 9.99999999999e-07
# Setting field to 2e-06
# Setting field to 3e-06
# Setting field to 4e-06
# Setting field to 5e-06
# Setting field to 6e-06
# Setting field to 7e-06
# Setting field to 8e-06
# Setting field to 9e-06
# Setting field to 1e-05
# Setting field to 1.1e-05
# Setting field to 1.2e-05
# Setting field to 1.3e-05
# Setting field to 1.4e-05
# Setting field to 1.5e-05
# Setting field to 1.6e-05
# Setting field to 1.7e-05
# Setting field to 1.8e-05
# Setting field to 1.9e-05
# Setting field to 2e-05
# Setting field to 2.1e-05
# Setting field to 2.2e-05
# Setting field to 2.3e-05
# Setting field to 2.4e-05
# Setting field to 2.5e-05
# Setting field to 2.6e-05
# Setting field to 2.7e-05
# Setting field to 2.8e-05
# Setting field to 2.9e-05
# Setting field to 3e-05
# Setting field to 3.1e-05
# Setting field to 3.2e-05
# Setting field to 3.3e-05
# Setting field to 3.4e-05
# Setting field to 3.5e-05
# Setting field to 3.6e-05
# Setting field to 3.7e-05
# Setting field to 3.8e-05
# Setting field to 3.9e-05
# Setting field to 4e-05
# Setting field to 4.1e-05
# Setting field to 4.2e-05
# Setting field to 4.3e-05
# Setting field to 4.4e-05
# Setting field to 4.5e-05
# Setting field to 4.6e-05
# Setting field to 4.7e-05
# Setting field to 4.8e-05
# Setting field to 4.9e-05
# Setting field to 5e-05
# Setting field to 5.1e-05
# Setting field to 5.2e-05
# Setting field to 5.3e-05
# Setting field to 5.4e-05
# Setting field to 5.5e-05
# Setting field to 5.6e-05
# Setting field to 5.7e-05
# Setting field to 5.8e-05
# Setting field to 5.9e-05
# Setting field to 6e-05
# Setting field to 6.1e-05
# Setting field to 6.2e-05
# Setting field to 6.3e-05
# Setting field to 6.4e-05
# Setting field to 6.5e-05
# Setting field to 6.6e-05
# Setting field to 6.7e-05
# Setting field to 6.8e-05
# Setting field to 6.9e-05
# Setting field to 7e-05
# Setting field to 7.1e-05
# Setting field to 7.2e-05
# Setting field to 7.3e-05
# Setting field to 7.4e-05
# Setting field to 7.5e-05
# Setting field to 7.6e-05
# Setting field to 7.7e-05
# Setting field to 7.8e-05
# Setting field to 7.9e-05
# Setting field to 8e-05
# Setting field to 8.1e-05
# Setting field to 8.2e-05
# Setting field to 8.3e-05
# Setting field to 8.4e-05
# Setting field to 8.5e-05
# Setting field to 8.6e-05
# Setting field to 8.7e-05
# Setting field to 8.8e-05
# Setting field to 8.9e-05
# Setting field to 9e-05
# Setting field to 9.1e-05
# Setting field to 9.2e-05
# Setting field to 9.3e-05
# Setting field to 9.4e-05
# Setting field to 9.5e-05
# Setting field to 9.6e-05
# Setting field to 9.7e-05
# Setting field to 9.8e-05
# Setting field to 9.9e-05
# Setting field to 0.0001
# Setting field to 0.000101
# Setting field to 0.000102
# Setting field to 0.000103
# Setting field to 0.000104
# Setting field to 0.000105
# Setting field to 0.000106
# Setting field to 0.000107
# Setting field to 0.000108
# Setting field to 0.000109
# Setting field to 0.00011
# Setting field to 0.000111
# Setting field to 0.000112
# Setting field to 0.000113
# Setting field to 0.000114
# Setting field to 0.000115
# Setting field to 0.000116
# Setting field to 0.000117
# Setting field to 0.000118
# Setting field to 0.000119
# Setting field to 0.00012
# Setting field to 0.000121
# Setting field to 0.000122
# Setting field to 0.000123
# Setting field to 0.000124
# Setting field to 0.000125
# Setting field to 0.000126
# Setting field to 0.000127
# Setting field to 0.000128
# Setting field to 0.000129
# Setting field to 0.00013
# Setting field to 0.000131
# Setting field to 0.000132
# Setting field to 0.000133
# Setting field to 0.000134
# Setting field to 0.000135
# Setting field to 0.000136
# Setting field to 0.000137
# Setting field to 0.000138
# Setting field to 0.000139
# Setting field to 0.00014
# Setting field to 0.000141
# Setting field to 0.000142
# Setting field to 0.000143
# Setting field to 0.000144
# Setting field to 0.000145
# Setting field to 0.000146
# Setting field to 0.000147
# Setting field to 0.000148
# Setting field to 0.000149
# Setting field to 0.00015
# Setting field to 0.000151
# Setting field to 0.000152
# Setting field to 0.000153
# Setting field to 0.000154
# Setting field to 0.000155
# Setting field to 0.000156
# Setting field to 0.000157
# Setting field to 0.000158
# Setting field to 0.000159
# Setting field to 0.00016
# Setting field to 0.000161
# Setting field to 0.000162
# Setting field to 0.000163
# Setting field to 0.000164
# Setting field to 0.000165
# Setting field to 0.000166
# Setting field to 0.000167
# Setting field to 0.000168
# Setting field to 0.000169
# Setting field to 0.00017
# Setting field to 0.000171
# Setting field to 0.000172
# Setting field to 0.000173
# Setting field to 0.000174
# Setting field to 0.000175
# Setting field to 0.000176
# Setting field to 0.000177
# Setting field to 0.000178
# Setting field to 0.000179
# Setting field to 0.00018
# Setting field to 0.000181
# Setting field to 0.000182
# Setting field to 0.000183
# Setting field to 0.000184
# Setting field to 0.000185
# Setting field to 0.000186
# Setting field to 0.000187
# Setting field to 0.000188
# Setting field to 0.000189
# Setting field to 0.00019
# Setting field to 0.000191
# Setting field to 0.000192
# Setting field to 0.000193
# Setting field to 0.000194
# Setting field to 0.000195
# Setting field to 0.000196
# Setting field to 0.000197
# Setting field to 0.000198
# Setting field to 0.000199
# Setting field to 0.0002
# Setting field to 0.0002
# Setting field to 0.000199
# Setting field to 0.000198
# Setting field to 0.000197
# Setting field to 0.000196
# Setting field to 0.000195
# Setting field to 0.000194
# Setting field to 0.000193
# Setting field to 0.000192
# Setting field to 0.000191
# Setting field to 0.00019
# Setting field to 0.000189
# Setting field to 0.000188
# Setting field to 0.000187
# Setting field to 0.000186
# Setting field to 0.000185
# Setting field to 0.000184
# Setting field to 0.000183
# Setting field to 0.000182
# Setting field to 0.000181
# Setting field to 0.00018
# Setting field to 0.000179
# Setting field to 0.000178
# Setting field to 0.000177
# Setting field to 0.000176
# Setting field to 0.000175
# Setting field to 0.000174
# Setting field to 0.000173
# Setting field to 0.000172
# Setting field to 0.000171
# Setting field to 0.00017
# Setting field to 0.000169
# Setting field to 0.000168
# Setting field to 0.000167
# Setting field to 0.000166
# Setting field to 0.000165
# Setting field to 0.000164
# Setting field to 0.000163
# Setting field to 0.000162
# Setting field to 0.000161
# Setting field to 0.00016
# Setting field to 0.000159
# Setting field to 0.000158
# Setting field to 0.000157
# Setting field to 0.000156
# Setting field to 0.000155
# Setting field to 0.000154
# Setting field to 0.000153
# Setting field to 0.000152
# Setting field to 0.000151
# Setting field to 0.00015
# Setting field to 0.000149
# Setting field to 0.000148
# Setting field to 0.000147
# Setting field to 0.000146
# Setting field to 0.000145
# Setting field to 0.000144
# Setting field to 0.000143
# Setting field to 0.000142
# Setting field to 0.000141
# Setting field to 0.00014
# Setting field to 0.000139
# Setting field to 0.000138
# Setting field to 0.000137
# Setting field to 0.000136
# Setting field to 0.000135
# Setting field to 0.000134
# Setting field to 0.000133
# Setting field to 0.000132
# Setting field to 0.000131
# Setting field to 0.00013
# Setting field to 0.000129
# Setting field to 0.000128
# Setting field to 0.000127
# Setting field to 0.000126
# Setting field to 0.000125
# Setting field to 0.000124
# Setting field to 0.000123
# Setting field to 0.000122
# Setting field to 0.000121
# Setting field to 0.00012
# Setting field to 0.000119
# Setting field to 0.000118
# Setting field to 0.000117
# Setting field to 0.000116
# Setting field to 0.000115
# Setting field to 0.000114
# Setting field to 0.000113
# Setting field to 0.000112
# Setting field to 0.000111
# Setting field to 0.00011
# Setting field to 0.000109
# Setting field to 0.000108
# Setting field to 0.000107
# Setting field to 0.000106
# Setting field to 0.000105
# Setting field to 0.000104
# Setting field to 0.000103
# Setting field to 0.000102
# Setting field to 0.000101
# Setting field to 0.0001
# Setting field to 9.9e-05
# Setting field to 9.8e-05
# Setting field to 9.7e-05
# Setting field to 9.6e-05
# Setting field to 9.5e-05
# Setting field to 9.4e-05
# Setting field to 9.3e-05
# Setting field to 9.2e-05
# Setting field to 9.1e-05
# Setting field to 9e-05
# Setting field to 8.9e-05
# Setting field to 8.8e-05
# Setting field to 8.7e-05
# Setting field to 8.6e-05
# Setting field to 8.5e-05
# Setting field to 8.4e-05
# Setting field to 8.3e-05
# Setting field to 8.2e-05
# Setting field to 8.1e-05
# Setting field to 8e-05
# Setting field to 7.9e-05
# Setting field to 7.8e-05
# Setting field to 7.7e-05
# Setting field to 7.6e-05
# Setting field to 7.5e-05
# Setting field to 7.4e-05
# Setting field to 7.3e-05
# Setting field to 7.2e-05
# Setting field to 7.1e-05
# Setting field to 7e-05
# Setting field to 6.9e-05
# Setting field to 6.8e-05
# Setting field to 6.7e-05
# Setting field to 6.6e-05
# Setting field to 6.5e-05
# Setting field to 6.4e-05
# Setting field to 6.3e-05
# Setting field to 6.2e-05
# Setting field to 6.1e-05
# Setting field to 6e-05
# Setting field to 5.9e-05
# Setting field to 5.8e-05
# Setting field to 5.7e-05
# Setting field to 5.6e-05
# Setting field to 5.5e-05
# Setting field to 5.4e-05
# Setting field to 5.3e-05
# Setting field to 5.2e-05
# Setting field to 5.1e-05
# Setting field to 5e-05
# Setting field to 4.9e-05
# Setting field to 4.8e-05
# Setting field to 4.7e-05
# Setting field to 4.6e-05
# Setting field to 4.5e-05
# Setting field to 4.4e-05
# Setting field to 4.3e-05
# Setting field to 4.2e-05
# Setting field to 4.1e-05
# Setting field to 4e-05
# Setting field to 3.9e-05
# Setting field to 3.8e-05
# Setting field to 3.7e-05
# Setting field to 3.6e-05
# Setting field to 3.5e-05
# Setting field to 3.4e-05
# Setting field to 3.3e-05
# Setting field to 3.2e-05
# Setting field to 3.1e-05
# Setting field to 3e-05
# Setting field to 2.9e-05
# Setting field to 2.8e-05
# Setting field to 2.7e-05
# Setting field to 2.6e-05
# Setting field to 2.5e-05
# Setting field to 2.4e-05
# Setting field to 2.3e-05
# Setting field to 2.2e-05
# Setting field to 2.1e-05
# Setting field to 2e-05
# Setting field to 1.9e-05
# Setting field to 1.8e-05
# Setting field to 1.7e-05
# Setting field to 1.6e-05
# Setting field to 1.5e-05
# Setting field to 1.4e-05
# Setting field to 1.3e-05
# Setting field to 1.2e-05
# Setting field to 1.1e-05
# Setting field to 1e-05
# Setting field to 9e-06
# Setting field to 8e-06
# Setting field to 7e-06
# Setting field to 6e-06
# Setting field to 5e-06
# Setting field to 4e-06
# Setting field to 3e-06
# Setting field to 2e-06
# Setting field to 1e-06
# Setting field to 5.69206140555e-19
# Setting field to -9.99999999999e-07
# Setting field to -2e-06
# Setting field to -3e-06
# Setting field to -4e-06
# Setting field to -5e-06
# Setting field to -6e-06
# Setting field to -7e-06
# Setting field to -8e-06
# Setting field to -9e-06
# Setting field to -1e-05
# Setting field to -1.1e-05
# Setting field to -1.2e-05
# Setting field to -1.3e-05
# Setting field to -1.4e-05
# Setting field to -1.5e-05
# Setting field to -1.6e-05
# Setting field to -1.7e-05
# Setting field to -1.8e-05
# Setting field to -1.9e-05
# Setting field to -2e-05
# Setting field to -2.1e-05
# Setting field to -2.2e-05
# Setting field to -2.3e-05
# Setting field to -2.4e-05
# Setting field to -2.5e-05
# Setting field to -2.6e-05
# Setting field to -2.7e-05
# Setting field to -2.8e-05
# Setting field to -2.9e-05
# Setting field to -3e-05
# Setting field to -3.1e-05
# Setting field to -3.2e-05
# Setting field to -3.3e-05
# Setting field to -3.4e-05
# Setting field to -3.5e-05
# Setting field to -3.6e-05
# Setting field to -3.7e-05
# Setting field to -3.8e-05
# Setting field to -3.9e-05
# Setting field to -4e-05
# Setting field to -4.1e-05
# Setting field to -4.2e-05
# Setting field to -4.3e-05
# Setting field to -4.4e-05
# Setting field to -4.5e-05
# Setting field to -4.6e-05
# Setting field to -4.7e-05
# Setting field to -4.8e-05
# Setting field to -4.9e-05
# Setting field to -5e-05
# Setting field to -5.1e-05
# Setting field to -5.2e-05
# Setting field to -5.3e-05
# Setting field to -5.4e-05
# Setting field to -5.5e-05
# Setting field to -5.6e-05
# Setting field to -5.7e-05
# Setting field to -5.8e-05
# Setting field to -5.9e-05
# Setting field to -6e-05
# Setting field to -6.1e-05
# Setting field to -6.2e-05
# Setting field to -6.3e-05
# Setting field to -6.4e-05
# Setting field to -6.5e-05
# Setting field to -6.6e-05
# Setting field to -6.7e-05
# Setting field to -6.8e-05
# Setting field to -6.9e-05
# Setting field to -7e-05
# Setting field to -7.1e-05
# Setting field to -7.2e-05
# Setting field to -7.3e-05
# Setting field to -7.4e-05
# Setting field to -7.5e-05
# Setting field to -7.6e-05
# Setting field to -7.7e-05
# Setting field to -7.8e-05
# Setting field to -7.9e-05
# Setting field to -8e-05
# Setting field to -8.1e-05
# Setting field to -8.2e-05
# Setting field to -8.3e-05
# Setting field to -8.4e-05
# Setting field to -8.5e-05
# Setting field to -8.6e-05
# Setting field to -8.7e-05
# Setting field to -8.8e-05
# Setting field to -8.9e-05
# Setting field to -9e-05
# Setting field to -9.1e-05
# Setting field to -9.2e-05
# Setting field to -9.3e-05
# Setting field to -9.4e-05
# Setting field to -9.5e-05
# Setting field to -9.6e-05
# Setting field to -9.7e-05
# Setting field to -9.8e-05
# Setting field to -9.9e-05
# Setting field to -0.0001
# Setting field to -0.000101
# Setting field to -0.000102
# Setting field to -0.000103
# Setting field to -0.000104
# Setting field to -0.000105
# Setting field to -0.000106
# Setting field to -0.000107
# Setting field to -0.000108
# Setting field to -0.000109
# Setting field to -0.00011
# Setting field to -0.000111
# Setting field to -0.000112
# Setting field to -0.000113
# Setting field to -0.000114
# Setting field to -0.000115
# Setting field to -0.000116
# Setting field to -0.000117
# Setting field to -0.000118
# Setting field to -0.000119
# Setting field to -0.00012
# Setting field to -0.000121
# Setting field to -0.000122
# Setting field to -0.000123
# Setting field to -0.000124
# Setting field to -0.000125
# Setting field to -0.000126
# Setting field to -0.000127
# Setting field to -0.000128
# Setting field to -0.000129
# Setting field to -0.00013
# Setting field to -0.000131
# Setting field to -0.000132
# Setting field to -0.000133
# Setting field to -0.000134
# Setting field to -0.000135
# Setting field to -0.000136
# Setting field to -0.000137
# Setting field to -0.000138
# Setting field to -0.000139
# Setting field to -0.00014
# Setting field to -0.000141
# Setting field to -0.000142
# Setting field to -0.000143
# Setting field to -0.000144
# Setting field to -0.000145
# Setting field to -0.000146
# Setting field to -0.000147
# Setting field to -0.000148
# Setting field to -0.000149
# Setting field to -0.00015
# Setting field to -0.000151
# Setting field to -0.000152
# Setting field to -0.000153
# Setting field to -0.000154
# Setting field to -0.000155
# Setting field to -0.000156
# Setting field to -0.000157
# Setting field to -0.000158
# Setting field to -0.000159
# Setting field to -0.00016
# Setting field to -0.000161
# Setting field to -0.000162
# Setting field to -0.000163
# Setting field to -0.000164
# Setting field to -0.000165
# Setting field to -0.000166
# Setting field to -0.000167
# Setting field to -0.000168
# Setting field to -0.000169
# Setting field to -0.00017
# Setting field to -0.000171
# Setting field to -0.000172
# Setting field to -0.000173
# Setting field to -0.000174
# Setting field to -0.000175
# Setting field to -0.000176
# Setting field to -0.000177
# Setting field to -0.000178
# Setting field to -0.000179
# Setting field to -0.00018
# Setting field to -0.000181
# Setting field to -0.000182
# Setting field to -0.000183
# Setting field to -0.000184
# Setting field to -0.000185
# Setting field to -0.000186
# Setting field to -0.000187
# Setting field to -0.000188
# Setting field to -0.000189
# Setting field to -0.00019
# Setting field to -0.000191
# Setting field to -0.000192
# Setting field to -0.000193
# Setting field to -0.000194
# Setting field to -0.000195
# Setting field to -0.000196
# Setting field to -0.000197
# Setting field to -0.000198
# Setting field to -0.000199
# Setting field to -0.0002
#  Time elapsed: 7444.2712
# ramping gate <MDACChannel: MDAC_chan9 of MDAC: MDAC> down
# ramping gate <MDACChannel: MDAC_chan10 of MDAC: MDAC> down
# ramping gate <MDACChannel: MDAC_chan11 of MDAC: MDAC> down
# ramping gate <MDACChannel: MDAC_chan1 of MDAC: MDAC> down
